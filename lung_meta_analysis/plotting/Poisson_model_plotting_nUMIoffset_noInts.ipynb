# %% [markdown]
# This notebook contains the plotting functions used to plot the results of the meta-analysis without interaction terms on the full data without modeling smoking associations (Supplementary Figures 7,8). Note that the model results with interaction terms are taken into account in these plots.

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors, patches
import seaborn as sns
import logging, warnings
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

output_folder = 'diffxpy_out/'

base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm'

# %%
res_lvl2_ints = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ints_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ints_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_summary.csv', index_col=0)
res_lvl2_ints_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl2_full.csv', index_col=0)

# %%
res_lvl2 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_noInts_lvl2_full.csv', index_col=0)
res_lvl2_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl2_full.csv', index_col=0)
res_lvl2_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl2_summary.csv', index_col=0)
res_lvl2_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_noInts_lvl2_full.csv', index_col=0)

# %%
res_lvl3_ints = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ints_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ints_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_summary.csv', index_col=0)
res_lvl3_ints_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl3_full.csv', index_col=0)

# %%
res_lvl3 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_noInts_lvl3_full.csv', index_col=0)
res_lvl3_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl3_full.csv', index_col=0)
res_lvl3_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl3_summary.csv', index_col=0)
res_lvl3_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_noInts_lvl3_full.csv', index_col=0)

# %%
res_lvl3.head()
# Out:
#       gene cell_identity    covariate      coef   coef_sd      pval  adj_pvals
# 0     ACE2   Macrophages  sex[T.male]  0.264930  0.203802  0.193623   0.249922
# 1     ACE2   Macrophages          age  0.008422  0.006693  0.208268   0.249922
# 2  TMPRSS2   Macrophages  sex[T.male] -0.094569  0.057101  0.097688   0.195375
# 3  TMPRSS2   Macrophages          age -0.001177  0.001983  0.552809   0.552809
# 4     CTSL   Macrophages  sex[T.male] -0.144491  0.002286  0.000000   0.000000

# %%
res_lvl3.dtypes
# Out:
# gene              object
# cell_identity     object
# covariate         object
# coef             float64
# coef_sd          float64
# pval             float64
# adj_pvals        float64
# dtype: object

# %% [markdown]
# # Plotting

# %%
sns.set(font_scale=2.2, style='white')

# %%
res_lvl3.head()
res_lvl3_ints.head()
# Out:
#       gene cell_identity    covariate      coef   coef_sd      pval  adj_pvals
# 0     ACE2   Macrophages  sex[T.male]  0.264930  0.203802  0.193623   0.249922
# 1     ACE2   Macrophages          age  0.008422  0.006693  0.208268   0.249922
# 2  TMPRSS2   Macrophages  sex[T.male] -0.094569  0.057101  0.097688   0.195375
# 3  TMPRSS2   Macrophages          age -0.001177  0.001983  0.552809   0.552809
# 4     CTSL   Macrophages  sex[T.male] -0.144491  0.002286  0.000000   0.000000
#       gene cell_identity    covariate eval_at      coef   coef_sd      pval  \
# 0     ACE2   Macrophages  sex[T.male]    32yr  0.930120  0.334093  0.005369
# 1     ACE2   Macrophages  sex[T.male]    62yr -0.201575  0.272548  0.459546
# 2     ACE2   Macrophages          age       F  0.028696  0.010247  0.005104
# 3     ACE2   Macrophages          age       M -0.009027  0.009343  0.333958
# 4  TMPRSS2   Macrophages  sex[T.male]    32yr -0.101809  0.080804  0.207686
#
#    adj_pvals
# 0   0.010738
# 1   0.551455
# 2   0.010738
# 3   0.445277
# 4   0.356032

# %%
res_lvl3
# Out:
#         gene          cell_identity    covariate      coef   coef_sd  \
# 0       ACE2            Macrophages  sex[T.male]  0.264930  0.203802
# 1       ACE2            Macrophages          age  0.008422  0.006693
# 2    TMPRSS2            Macrophages  sex[T.male] -0.094569  0.057101
# 62    9.746445e-01   9.746445e-01
# 63    2.528520e-03   1.517112e-02
# 64    1.454131e-01   1.454131e-01
# 65    1.006547e-01   1.342063e-01
# 66    6.960809e-07   1.392162e-06
# 67    2.801582e-08   1.120633e-07
# 68    7.531368e-01   7.531368e-01
# 69    5.658445e-01   7.531368e-01
# 70    2.539253e-04   1.015701e-03
# 71    9.699350e-02   1.939870e-01
# 72    1.883293e-02   3.766587e-02
# 73    8.535224e-01   9.520913e-01
# 74    5.136799e-02   7.705198e-02
# 75    9.520913e-01   9.520913e-01
# 76    8.159907e-13   2.447972e-12
# 77    2.938544e-21   1.763126e-20
# 78    5.620876e-01   5.620876e-01
# 79    4.112495e-01   5.483327e-01
# 80    4.910181e-65   1.964073e-64
# 81    3.567824e-55   7.135647e-55
# 82    1.980486e-01   3.255558e-01
# 83    2.441668e-01   3.255558e-01
# 84    6.479082e-01   6.479082e-01
# 85    8.370768e-02   3.255558e-01
# 86    3.553690e-02   5.330534e-02
# 87    1.293628e-02   2.587257e-02
# 88    9.600860e-05   5.760516e-04
# 89    1.506828e-01   1.808194e-01
# 90    6.800405e-01   6.800405e-01
# 91    1.366528e-03   4.099585e-03
# 92    9.776170e-01   9.776170e-01
# 93    1.895277e-01   3.790554e-01
# 94    4.249492e-02   1.699797e-01
# 95    4.056920e-01   5.409227e-01
# 96    7.316618e-01   7.316618e-01
# 97    7.151659e-01   7.316618e-01
# 98    1.879975e-02   3.759949e-02
# 99    3.857606e-01   5.786408e-01
# 100   2.139695e-04   1.283817e-03
# 101   3.461228e-03   1.038368e-02
# 102   2.242400e-01   2.242400e-01
# 103   2.052740e-01   2.242400e-01
# 104   5.071703e-04   1.014341e-03
# 105   5.421110e-08   2.168444e-07
# 106   3.886994e-07   3.886994e-07
# 107   8.304113e-22   1.660823e-21
# 108   1.984086e-01   3.968171e-01
# 109   8.836393e-01   8.836393e-01

# %% [markdown]
# ## Level 3

# %%
res_lvl3['cell_identity'].unique()
# Out:
# array(['Macrophages', 'AT2', 'Basal', 'T cell lineage', 'Monocytes',
#        'Multiciliated lineage', 'AT1', 'Submucosal Secretory',
#        'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells',
#        'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous',
#        'Lymphatic EC', 'Arterial', 'Rare', 'Myofibroblasts', 'MDC',
#        'Airway smooth muscle'], dtype=object)

# %%
# Prep plotting

# Order cell identity category
res_lvl3['cell_identity'] = res_lvl3['cell_identity'].astype('category').cat.set_categories(['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2', 'Arterial', 'Capillary', 'Venous', 'Lymphatic EC', 'Fibroblasts', 'Myofibroblasts', 'Airway smooth muscle', 'B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'MDC', 'Mast cells'], ordered=True)
res_lvl3 = res_lvl3.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2'], 'Endothelial':['Arterial', 'Capillary', 'Venous', 'Lymphatic EC'], 'Stroma':['Fibroblasts', 'Myofibroblasts', 'Airway smooth muscle'], 'Immune':['B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'MDC', 'Mast cells']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl3['compartment'] = [ct_mapping_up[ct] for ct in res_lvl3['cell_identity']]

# Check if bulk and sc effect directions agree
res_lvl3_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl3_pseudo[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl3.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl3[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl3['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl3['coef'].loc[res_lvl3.index[i]]* res_lvl3_pseudo['coef'].loc[res_lvl3.index[i]]) > 0) for i,val in enumerate(res_lvl3['adj_pvals'])]


# Check if simple and complex models agree

# Check if bulk and sc effect directions agree in interaction model
res_lvl3_ints_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl3_ints_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3_ints.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl3_ints[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3_ints['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl3_ints['coef'].loc[res_lvl3_ints.index[i]]* res_lvl3_ints_pseudo['coef'].loc[res_lvl3_ints.index[i]]) > 0) for i,val in enumerate(res_lvl3_ints['adj_pvals'])]

# Criteria:
# 1. No "indication" in opposite direction (significant and pseudo agrees)
# 2. At least 1 "indication" in the correct direction.

bulk_complex_agree = []

for idx in res_lvl3.index:
    mask = [str(idx) in str(i) for i in res_lvl3_ints.index]
    tmp = res_lvl3_ints.loc[mask]
    complex_vals = tmp['coef'].loc[tmp['signif_bulk_agree'].values].values

    if len(complex_vals) == 0:
        # No indication in complex interaction model
        bulk_complex_agree.append(False)

    else:
        # Check that all indications or robust trends point in the same direction
        # as the simple model case:
        int_agree = np.all([res_lvl3['coef'].loc[idx]*val > 0 for val in complex_vals])
        val = res_lvl3['signif_bulk_agree'].loc[idx] and int_agree
        bulk_complex_agree.append(val)
        
res_lvl3['signif_bulk_complex_agree'] = bulk_complex_agree


res_lvl3['compartment'] = res_lvl3['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl3['covariate_simple'] = res_lvl3['covariate'].astype('category').cat.rename_categories(['Age', 'Sex'])

# Assign eval_at numbers
res_lvl3 = res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()


leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl3_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

xlims_top = [[None, None, None],
             [None, None, None],
             [None, None, None],
             [None, None, None]]
xlims_bot = [[None, None, None],
             [None ,None, None],
             [None, None, None],
             [None, None, None]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl3_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# (-0.012853505696028854, 0.02459301638544525)
# <ErrorbarContainer object of 3 artists>
# (-0.340339003187177, 0.982618992519171)
# <ErrorbarContainer object of 3 artists>
# (-0.023968555216295456, 0.07057706834163535)
# <ErrorbarContainer object of 3 artists>
# (0.0, 1.437289251591412)
# <ErrorbarContainer object of 3 artists>
# (-0.007853399453653924, 0.02414596701398414)
# <ErrorbarContainer object of 3 artists>
# (-1.1827500664968507, 1.0476011561453307)
# <ErrorbarContainer object of 3 artists>
# (-0.03259307116524729, 0.1642508874817885)
# <ErrorbarContainer object of 3 artists>
# (-0.6017018257777953, 1.273560700001568)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])
# Out:
#                                               gene          cell_identity  \
# Basal_age_ACE2                                ACE2                  Basal
# Basal_age_CTSL                                CTSL                  Basal
# Basal_age_TMPRSS2                          TMPRSS2                  Basal
# Basal_sex[T.male]_ACE2                        ACE2                  Basal
# Basal_sex[T.male]_CTSL                        CTSL                  Basal
# Basal_sex[T.male]_TMPRSS2                  TMPRSS2                  Basal
# Multiciliated_lineage_age_ACE2                ACE2  Multiciliated lineage
# Multiciliated_lineage_age_CTSL                CTSL  Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2          TMPRSS2  Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2        ACE2  Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL        CTSL  Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2  TMPRSS2  Multiciliated lineage
# Secretory_age_ACE2                            ACE2              Secretory
# Secretory_age_CTSL                            CTSL              Secretory
# Secretory_age_TMPRSS2                      TMPRSS2              Secretory
# Secretory_sex[T.male]_ACE2                    ACE2              Secretory
# Secretory_sex[T.male]_CTSL                    CTSL              Secretory
# Secretory_sex[T.male]_TMPRSS2              TMPRSS2              Secretory
# Rare_age_ACE2                                 ACE2                   Rare
# Rare_age_CTSL                                 CTSL                   Rare
# Rare_age_TMPRSS2                           TMPRSS2                   Rare
# Rare_sex[T.male]_ACE2                         ACE2                   Rare
# Rare_sex[T.male]_CTSL                         CTSL                   Rare
# Rare_sex[T.male]_TMPRSS2                   TMPRSS2                   Rare
# Submucosal_Secretory_age_ACE2                 ACE2   Submucosal Secretory
# Submucosal_Secretory_age_CTSL                 CTSL   Submucosal Secretory
# Submucosal_Secretory_age_TMPRSS2           TMPRSS2   Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_ACE2         ACE2   Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_CTSL         CTSL   Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_TMPRSS2   TMPRSS2   Submucosal Secretory
# AT1_age_ACE2                                  ACE2                    AT1
# AT1_age_CTSL                                  CTSL                    AT1
# AT1_age_TMPRSS2                            TMPRSS2                    AT1
# AT1_sex[T.male]_ACE2                          ACE2                    AT1
# AT1_sex[T.male]_CTSL                          CTSL                    AT1
# AT1_sex[T.male]_TMPRSS2                    TMPRSS2                    AT1
# AT2_age_ACE2                                  ACE2                    AT2
# AT2_age_CTSL                                  CTSL                    AT2
# AT2_age_TMPRSS2                            TMPRSS2                    AT2
# AT2_sex[T.male]_ACE2                          ACE2                    AT2
# AT2_sex[T.male]_CTSL                          CTSL                    AT2
# AT2_sex[T.male]_TMPRSS2                    TMPRSS2                    AT2
# Arterial_age_CTSL                             CTSL               Arterial
# Arterial_age_TMPRSS2                       TMPRSS2               Arterial
# Arterial_sex[T.male]_CTSL                     CTSL               Arterial
# Arterial_sex[T.male]_TMPRSS2               TMPRSS2               Arterial
# Capillary_age_ACE2                            ACE2              Capillary
# Capillary_age_CTSL                            CTSL              Capillary
# Capillary_age_TMPRSS2                      TMPRSS2              Capillary
# Capillary_sex[T.male]_ACE2                    ACE2              Capillary
# Capillary_sex[T.male]_CTSL                    CTSL              Capillary
# Capillary_sex[T.male]_TMPRSS2              TMPRSS2              Capillary
# Venous_age_CTSL                               CTSL                 Venous
# Venous_age_TMPRSS2                         TMPRSS2                 Venous
# Venous_sex[T.male]_CTSL                       CTSL                 Venous
# Venous_sex[T.male]_TMPRSS2                 TMPRSS2                 Venous
# Lymphatic_EC_age_ACE2                         ACE2           Lymphatic EC
# Lymphatic_EC_age_CTSL                         CTSL           Lymphatic EC
# Lymphatic_EC_age_TMPRSS2                   TMPRSS2           Lymphatic EC
# Lymphatic_EC_sex[T.male]_ACE2                 ACE2           Lymphatic EC
# Lymphatic_EC_sex[T.male]_CTSL                 CTSL           Lymphatic EC
# Lymphatic_EC_sex[T.male]_TMPRSS2           TMPRSS2           Lymphatic EC
# Fibroblasts_age_ACE2                          ACE2            Fibroblasts
# Fibroblasts_age_CTSL                          CTSL            Fibroblasts
# Fibroblasts_age_TMPRSS2                    TMPRSS2            Fibroblasts
# Fibroblasts_sex[T.male]_ACE2                  ACE2            Fibroblasts
# Fibroblasts_sex[T.male]_CTSL                  CTSL            Fibroblasts
# Fibroblasts_sex[T.male]_TMPRSS2            TMPRSS2            Fibroblasts
# Myofibroblasts_age_CTSL                       CTSL         Myofibroblasts
# Myofibroblasts_age_TMPRSS2                 TMPRSS2         Myofibroblasts
# Myofibroblasts_sex[T.male]_CTSL               CTSL         Myofibroblasts
# Myofibroblasts_sex[T.male]_TMPRSS2         TMPRSS2         Myofibroblasts
# Airway_smooth_muscle_age_CTSL                 CTSL   Airway smooth muscle
# Airway_smooth_muscle_sex[T.male]_CTSL         CTSL   Airway smooth muscle
# B_cell_lineage_age_CTSL                       CTSL         B cell lineage
# B_cell_lineage_age_TMPRSS2                 TMPRSS2         B cell lineage
# B_cell_lineage_sex[T.male]_CTSL               CTSL         B cell lineage
# B_cell_lineage_sex[T.male]_TMPRSS2         TMPRSS2         B cell lineage
# T_cell_lineage_age_ACE2                       ACE2         T cell lineage
# T_cell_lineage_age_CTSL                       CTSL         T cell lineage
# T_cell_lineage_age_TMPRSS2                 TMPRSS2         T cell lineage
# T_cell_lineage_sex[T.male]_ACE2               ACE2         T cell lineage
# T_cell_lineage_sex[T.male]_CTSL               CTSL         T cell lineage
# T_cell_lineage_sex[T.male]_TMPRSS2         TMPRSS2         T cell lineage
# Innate_lymphoid_cells_age_CTSL                CTSL  Innate lymphoid cells
# Innate_lymphoid_cells_age_TMPRSS2          TMPRSS2  Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_CTSL        CTSL  Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2  TMPRSS2  Innate lymphoid cells
# Dendritic_cells_age_CTSL                      CTSL        Dendritic cells
# Dendritic_cells_age_TMPRSS2                TMPRSS2        Dendritic cells
# Dendritic_cells_sex[T.male]_CTSL              CTSL        Dendritic cells
# Dendritic_cells_sex[T.male]_TMPRSS2        TMPRSS2        Dendritic cells
# Macrophages_age_ACE2                          ACE2            Macrophages
# Macrophages_age_CTSL                          CTSL            Macrophages
# Macrophages_age_TMPRSS2                    TMPRSS2            Macrophages
# Macrophages_sex[T.male]_ACE2                  ACE2            Macrophages
# Macrophages_sex[T.male]_CTSL                  CTSL            Macrophages
# Macrophages_sex[T.male]_TMPRSS2            TMPRSS2            Macrophages
# Monocytes_age_ACE2                            ACE2              Monocytes
# Monocytes_age_CTSL                            CTSL              Monocytes
# Monocytes_age_TMPRSS2                      TMPRSS2              Monocytes
# Monocytes_sex[T.male]_ACE2                    ACE2              Monocytes
# Monocytes_sex[T.male]_CTSL                    CTSL              Monocytes
# Monocytes_sex[T.male]_TMPRSS2              TMPRSS2              Monocytes
# MDC_age_CTSL                                  CTSL                    MDC
# MDC_sex[T.male]_CTSL                          CTSL                    MDC
# Mast_cells_age_CTSL                           CTSL             Mast cells
# Mast_cells_age_TMPRSS2                     TMPRSS2             Mast cells
# Mast_cells_sex[T.male]_CTSL                   CTSL             Mast cells
# Mast_cells_sex[T.male]_TMPRSS2             TMPRSS2             Mast cells
#
#                                              covariate      coef   coef_sd  \
# Basal_age_ACE2                                     age  0.004164  0.001286
# Basal_age_CTSL                                     age  0.005529  0.000295
# Basal_age_TMPRSS2                                  age  0.004448  0.000491
# Basal_sex[T.male]_ACE2                     sex[T.male]  0.027527  0.047107
# Basal_sex[T.male]_CTSL                     sex[T.male] -0.178596  0.010448
# Basal_sex[T.male]_TMPRSS2                  sex[T.male]  0.318730  0.020012
# Multiciliated_lineage_age_ACE2                     age  0.007502  0.002622
# Multiciliated_lineage_age_CTSL                     age -0.001246  0.000523
# Multiciliated_lineage_age_TMPRSS2                  age  0.000092  0.000620
# Multiciliated_lineage_sex[T.male]_ACE2     sex[T.male]  0.230449  0.079931
# Multiciliated_lineage_sex[T.male]_CTSL     sex[T.male] -0.062303  0.016138
# Multiciliated_lineage_sex[T.male]_TMPRSS2  sex[T.male]  0.181666  0.018777
# Secretory_age_ACE2                                 age -0.007868  0.003284
# Secretory_age_CTSL                                 age  0.005078  0.001504
# Secretory_age_TMPRSS2                              age -0.003760  0.000877
# Secretory_sex[T.male]_ACE2                 sex[T.male]  0.241538  0.079763
# Secretory_sex[T.male]_CTSL                 sex[T.male] -0.009883  0.037200
# Secretory_sex[T.male]_TMPRSS2              sex[T.male]  0.261965  0.023658
# Rare_age_ACE2                                      age  0.008384  0.022975
# Rare_age_CTSL                                      age  0.006370  0.002179
# Rare_age_TMPRSS2                                   age -0.002837  0.003271
# Rare_sex[T.male]_ACE2                      sex[T.male] -0.280205  0.817124
# Rare_sex[T.male]_CTSL                      sex[T.male]  0.286584  0.077415
# Rare_sex[T.male]_TMPRSS2                   sex[T.male]  0.283619  0.120716
# Submucosal_Secretory_age_ACE2                      age  0.005288  0.002329
# Submucosal_Secretory_age_CTSL                      age  0.006855  0.000687
# Submucosal_Secretory_age_TMPRSS2                   age  0.001744  0.000579
# Submucosal_Secretory_sex[T.male]_ACE2      sex[T.male]  0.004671  0.096946
# Submucosal_Secretory_sex[T.male]_CTSL      sex[T.male] -0.105026  0.026610
# Submucosal_Secretory_sex[T.male]_TMPRSS2   sex[T.male]  0.310393  0.023955
# AT1_age_ACE2                                       age  0.014541  0.005878
# AT1_age_CTSL                                       age  0.002650  0.000769
# AT1_age_TMPRSS2                                    age  0.011628  0.000694
# AT1_sex[T.male]_ACE2                       sex[T.male]  0.494016  0.182827
# AT1_sex[T.male]_CTSL                       sex[T.male]  0.253679  0.026045
# AT1_sex[T.male]_TMPRSS2                    sex[T.male]  0.629844  0.018878
# AT2_age_ACE2                                       age  0.012644  0.001570
# AT2_age_CTSL                                       age -0.003468  0.000349
# AT2_age_TMPRSS2                                    age  0.022656  0.000234
# AT2_sex[T.male]_ACE2                       sex[T.male]  0.868916  0.053569
# AT2_sex[T.male]_CTSL                       sex[T.male]  0.092925  0.013407
# AT2_sex[T.male]_TMPRSS2                    sex[T.male]  0.022611  0.007279
# Arterial_age_CTSL                                  age  0.002120  0.002550
# Arterial_age_TMPRSS2                               age  0.019579  0.014924
# Arterial_sex[T.male]_CTSL                  sex[T.male]  0.145467  0.071707
# Arterial_sex[T.male]_TMPRSS2               sex[T.male]  0.018597  0.662853
# Capillary_age_ACE2                                 age  0.017790  0.034241
# Capillary_age_CTSL                                 age  0.004766  0.001578
# Capillary_age_TMPRSS2                              age  0.010801  0.012429
# Capillary_sex[T.male]_ACE2                 sex[T.male]  0.140107  1.074070
# Capillary_sex[T.male]_CTSL                 sex[T.male]  0.001153  0.036277
# Capillary_sex[T.male]_TMPRSS2              sex[T.male]  1.366505  0.671478
# Venous_age_CTSL                                    age  0.002540  0.001469
# Venous_age_TMPRSS2                                 age -0.019671  0.016890
# Venous_sex[T.male]_CTSL                    sex[T.male]  0.022650  0.049598
# Venous_sex[T.male]_TMPRSS2                 sex[T.male]  1.231381  0.956687
# Lymphatic_EC_age_ACE2                              age  0.066280  0.026666
# Lymphatic_EC_age_CTSL                              age  0.004586  0.001432
# Lymphatic_EC_age_TMPRSS2                           age -0.008078  0.005621
# Lymphatic_EC_sex[T.male]_ACE2              sex[T.male]  1.368847  0.651154
# Lymphatic_EC_sex[T.male]_CTSL              sex[T.male]  0.012329  0.029895
# Lymphatic_EC_sex[T.male]_TMPRSS2           sex[T.male]  0.654670  0.167844
# Fibroblasts_age_ACE2                               age  0.001492  0.008083
# Fibroblasts_age_CTSL                               age -0.006399  0.000676
# Fibroblasts_age_TMPRSS2                            age -0.000670  0.011157
# Fibroblasts_sex[T.male]_ACE2               sex[T.male] -0.963595  0.410246
# Fibroblasts_sex[T.male]_CTSL               sex[T.male]  0.157893  0.022057
# Fibroblasts_sex[T.male]_TMPRSS2            sex[T.male]  0.946222  0.485642
# Myofibroblasts_age_CTSL                            age  0.017263  0.003175
# Myofibroblasts_age_TMPRSS2                         age  0.022691  0.017914
# Myofibroblasts_sex[T.male]_CTSL            sex[T.male]  0.306646  0.088194
# Myofibroblasts_sex[T.male]_TMPRSS2         sex[T.male] -1.081370  0.889775
# Airway_smooth_muscle_age_CTSL                      age -0.000584  0.003992
# Airway_smooth_muscle_sex[T.male]_CTSL      sex[T.male] -0.106002  0.082422
# B_cell_lineage_age_CTSL                            age -0.003981  0.002398
# B_cell_lineage_age_TMPRSS2                         age -0.005284  0.009202
# B_cell_lineage_sex[T.male]_CTSL            sex[T.male] -0.259621  0.070968
# B_cell_lineage_sex[T.male]_TMPRSS2         sex[T.male]  0.104255  0.331488
# T_cell_lineage_age_ACE2                            age -0.006742  0.018993
# T_cell_lineage_age_CTSL                            age  0.030963  0.001406
# T_cell_lineage_age_TMPRSS2                         age -0.003390  0.003400
# T_cell_lineage_sex[T.male]_ACE2            sex[T.male]  0.353216  0.528388
# T_cell_lineage_sex[T.male]_CTSL            sex[T.male]  0.382625  0.034855
# T_cell_lineage_sex[T.male]_TMPRSS2         sex[T.male]  0.424947  0.086699
# Innate_lymphoid_cells_age_CTSL                     age  0.021072  0.002007
# Innate_lymphoid_cells_age_TMPRSS2                  age -0.000995  0.010519
# Innate_lymphoid_cells_sex[T.male]_CTSL     sex[T.male]  0.738978  0.049821
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2  sex[T.male] -0.155304  0.302537
# Dendritic_cells_age_CTSL                           age  0.015163  0.000969
# Dendritic_cells_age_TMPRSS2                        age -0.008650  0.010527
# Dendritic_cells_sex[T.male]_CTSL           sex[T.male] -0.487818  0.028644
# Dendritic_cells_sex[T.male]_TMPRSS2        sex[T.male]  0.171988  0.296662
# Macrophages_age_ACE2                               age  0.008422  0.006693
# Macrophages_age_CTSL                               age  0.003185  0.000079
# Macrophages_age_TMPRSS2                            age -0.001177  0.001983
# Macrophages_sex[T.male]_ACE2               sex[T.male]  0.264930  0.203802
# B_cell_lineage_age_CTSL                     9.699350e-02   1.939870e-01
# B_cell_lineage_age_TMPRSS2                  5.658445e-01   7.531368e-01
# B_cell_lineage_sex[T.male]_CTSL             2.539253e-04   1.015701e-03
# B_cell_lineage_sex[T.male]_TMPRSS2          7.531368e-01   7.531368e-01
# T_cell_lineage_age_ACE2                     7.226171e-01   7.226171e-01
# T_cell_lineage_age_CTSL                    1.578595e-107  9.471572e-107
# T_cell_lineage_age_TMPRSS2                  3.187745e-01   4.781618e-01
# T_cell_lineage_sex[T.male]_ACE2             5.038283e-01   6.045940e-01
# T_cell_lineage_sex[T.male]_CTSL             4.896204e-28   1.468861e-27
# T_cell_lineage_sex[T.male]_TMPRSS2          9.515144e-07   1.903029e-06
# Innate_lymphoid_cells_age_CTSL              8.741529e-26   1.748306e-25
# Innate_lymphoid_cells_age_TMPRSS2           9.246677e-01   9.246677e-01
# Innate_lymphoid_cells_sex[T.male]_CTSL      9.000006e-50   3.600002e-49
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2   6.077150e-01   8.102867e-01
# Dendritic_cells_age_CTSL                    3.567824e-55   7.135647e-55
# Dendritic_cells_age_TMPRSS2                 4.112495e-01   5.483327e-01
# Dendritic_cells_sex[T.male]_CTSL            4.910181e-65   1.964073e-64
# Dendritic_cells_sex[T.male]_TMPRSS2         5.620876e-01   5.620876e-01
# Macrophages_age_ACE2                        2.082681e-01   2.499217e-01
# Macrophages_age_CTSL                        0.000000e+00   0.000000e+00
# Macrophages_age_TMPRSS2                     5.528093e-01   5.528093e-01
# Macrophages_sex[T.male]_ACE2                1.936233e-01   2.499217e-01
# Macrophages_sex[T.male]_CTSL                0.000000e+00   0.000000e+00
# Macrophages_sex[T.male]_TMPRSS2             9.768750e-02   1.953750e-01
# Monocytes_age_ACE2                          1.357069e-01   1.357069e-01
# Monocytes_age_CTSL                          2.215098e-10   4.430196e-10
# Monocytes_age_TMPRSS2                       4.319063e-02   5.182876e-02
# Monocytes_sex[T.male]_ACE2                  1.394247e-02   2.091371e-02
# Monocytes_sex[T.male]_CTSL                  4.944319e-63   1.483296e-62
# Monocytes_sex[T.male]_TMPRSS2               5.215319e-85   3.129191e-84
# MDC_age_CTSL                                8.304113e-22   1.660823e-21
# MDC_sex[T.male]_CTSL                        3.886994e-07   3.886994e-07
# Mast_cells_age_CTSL                         2.801582e-08   1.120633e-07
# Mast_cells_age_TMPRSS2                      1.006547e-01   1.342063e-01
# Mast_cells_sex[T.male]_CTSL                 6.960809e-07   1.392162e-06
# Mast_cells_sex[T.male]_TMPRSS2              1.454131e-01   1.454131e-01
#
#                                            compartment  signif_bulk_agree  \
# Basal_age_ACE2                              Epithelial              False
# Basal_age_CTSL                              Epithelial              False
# Basal_age_TMPRSS2                           Epithelial               True
# Basal_sex[T.male]_ACE2                      Epithelial              False
# Basal_sex[T.male]_CTSL                      Epithelial               True
# Basal_sex[T.male]_TMPRSS2                   Epithelial               True
# Multiciliated_lineage_age_ACE2              Epithelial               True
# Multiciliated_lineage_age_CTSL              Epithelial              False
# Multiciliated_lineage_age_TMPRSS2           Epithelial              False
# Multiciliated_lineage_sex[T.male]_ACE2      Epithelial               True
# Multiciliated_lineage_sex[T.male]_CTSL      Epithelial               True
# Multiciliated_lineage_sex[T.male]_TMPRSS2   Epithelial               True
# Secretory_age_ACE2                          Epithelial               True
# Secretory_age_CTSL                          Epithelial              False
# Secretory_age_TMPRSS2                       Epithelial               True
# Secretory_sex[T.male]_ACE2                  Epithelial               True
# Secretory_sex[T.male]_CTSL                  Epithelial              False
# Secretory_sex[T.male]_TMPRSS2               Epithelial               True
# Rare_age_ACE2                               Epithelial              False
# Rare_age_CTSL                               Epithelial               True
# Rare_age_TMPRSS2                            Epithelial              False
# Rare_sex[T.male]_ACE2                       Epithelial              False
# Rare_sex[T.male]_CTSL                       Epithelial              False
# Rare_sex[T.male]_TMPRSS2                    Epithelial              False
# Submucosal_Secretory_age_ACE2               Epithelial               True
# Submucosal_Secretory_age_CTSL               Epithelial               True
# Submucosal_Secretory_age_TMPRSS2            Epithelial              False
# Submucosal_Secretory_sex[T.male]_ACE2       Epithelial              False
# Submucosal_Secretory_sex[T.male]_CTSL       Epithelial               True
# Submucosal_Secretory_sex[T.male]_TMPRSS2    Epithelial               True
# AT1_age_ACE2                                Epithelial              False
# AT1_age_CTSL                                Epithelial               True
# AT1_age_TMPRSS2                             Epithelial               True
# AT1_sex[T.male]_ACE2                        Epithelial               True
# AT1_sex[T.male]_CTSL                        Epithelial               True
# AT1_sex[T.male]_TMPRSS2                     Epithelial               True
# AT2_age_ACE2                                Epithelial               True
# AT2_age_CTSL                                Epithelial               True
# AT2_age_TMPRSS2                             Epithelial               True
# AT2_sex[T.male]_ACE2                        Epithelial               True
# AT2_sex[T.male]_CTSL                        Epithelial               True
# AT2_sex[T.male]_TMPRSS2                     Epithelial               True
# Arterial_age_CTSL                          Endothelial              False
# Arterial_age_TMPRSS2                       Endothelial              False
# Arterial_sex[T.male]_CTSL                  Endothelial              False
# Arterial_sex[T.male]_TMPRSS2               Endothelial              False
# Capillary_age_ACE2                         Endothelial              False
# Capillary_age_CTSL                         Endothelial              False
# Capillary_age_TMPRSS2                      Endothelial              False
# Capillary_sex[T.male]_ACE2                 Endothelial              False
# Capillary_sex[T.male]_CTSL                 Endothelial              False
# Capillary_sex[T.male]_TMPRSS2              Endothelial              False
# Venous_age_CTSL                            Endothelial              False
# Venous_age_TMPRSS2                         Endothelial              False
# Venous_sex[T.male]_CTSL                    Endothelial              False
# Venous_sex[T.male]_TMPRSS2                 Endothelial              False
# Lymphatic_EC_age_ACE2                      Endothelial               True
# Lymphatic_EC_age_CTSL                      Endothelial               True
# Lymphatic_EC_age_TMPRSS2                   Endothelial              False
# Lymphatic_EC_sex[T.male]_ACE2              Endothelial              False
# Lymphatic_EC_sex[T.male]_CTSL              Endothelial              False
# Lymphatic_EC_sex[T.male]_TMPRSS2           Endothelial               True
# Fibroblasts_age_ACE2                            Stroma              False
# Fibroblasts_age_CTSL                            Stroma               True
# Fibroblasts_age_TMPRSS2                         Stroma              False
# Fibroblasts_sex[T.male]_ACE2                    Stroma              False
# Fibroblasts_sex[T.male]_CTSL                    Stroma               True
# Fibroblasts_sex[T.male]_TMPRSS2                 Stroma              False
# Myofibroblasts_age_CTSL                         Stroma               True
# Myofibroblasts_age_TMPRSS2                      Stroma              False
# Myofibroblasts_sex[T.male]_CTSL                 Stroma               True
# Myofibroblasts_sex[T.male]_TMPRSS2              Stroma              False
# Airway_smooth_muscle_age_CTSL                   Stroma              False
# Airway_smooth_muscle_sex[T.male]_CTSL           Stroma              False
# B_cell_lineage_age_CTSL                         Immune              False
# B_cell_lineage_age_TMPRSS2                      Immune              False
# B_cell_lineage_sex[T.male]_CTSL                 Immune               True
# B_cell_lineage_sex[T.male]_TMPRSS2              Immune              False
# T_cell_lineage_age_ACE2                         Immune              False
# T_cell_lineage_age_CTSL                         Immune               True
# T_cell_lineage_age_TMPRSS2                      Immune              False
# T_cell_lineage_sex[T.male]_ACE2                 Immune              False
# T_cell_lineage_sex[T.male]_CTSL                 Immune               True
# T_cell_lineage_sex[T.male]_TMPRSS2              Immune               True
# Innate_lymphoid_cells_age_CTSL                  Immune               True
# Innate_lymphoid_cells_age_TMPRSS2               Immune              False
# Innate_lymphoid_cells_sex[T.male]_CTSL          Immune               True
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2       Immune              False
# Dendritic_cells_age_CTSL                        Immune               True
# Dendritic_cells_age_TMPRSS2                     Immune              False
# Dendritic_cells_sex[T.male]_CTSL                Immune               True
# Dendritic_cells_sex[T.male]_TMPRSS2             Immune              False
# Macrophages_age_ACE2                            Immune              False
# Macrophages_age_CTSL                            Immune               True
# Macrophages_age_TMPRSS2                         Immune              False
# Macrophages_sex[T.male]_ACE2                    Immune              False
# Macrophages_sex[T.male]_CTSL                    Immune               True
# Macrophages_sex[T.male]_TMPRSS2                 Immune              False
# Monocytes_age_ACE2                              Immune              False
# Monocytes_age_CTSL                              Immune              False
# Monocytes_age_TMPRSS2                           Immune              False
# Monocytes_sex[T.male]_ACE2                      Immune               True
# Monocytes_sex[T.male]_CTSL                      Immune               True
# Monocytes_sex[T.male]_TMPRSS2                   Immune               True
# MDC_age_CTSL                                    Immune               True
# MDC_sex[T.male]_CTSL                            Immune              False
# Mast_cells_age_CTSL                             Immune              False
# Mast_cells_age_TMPRSS2                          Immune              False
# Mast_cells_sex[T.male]_CTSL                     Immune              False
# Mast_cells_sex[T.male]_TMPRSS2                  Immune              False
#
#                                            signif_bulk_complex_agree  \
# Basal_age_ACE2                                                 False
# Basal_age_CTSL                                                 False
# Basal_age_TMPRSS2                                               True
# Basal_sex[T.male]_ACE2                                         False
# Basal_sex[T.male]_CTSL                                          True
# Basal_sex[T.male]_TMPRSS2                                       True
# Multiciliated_lineage_age_ACE2                                  True
# Multiciliated_lineage_age_CTSL                                 False
# Multiciliated_lineage_age_TMPRSS2                              False
# Multiciliated_lineage_sex[T.male]_ACE2                          True
# Multiciliated_lineage_sex[T.male]_CTSL                          True
# Multiciliated_lineage_sex[T.male]_TMPRSS2                       True
# Secretory_age_ACE2                                              True
# Secretory_age_CTSL                                             False
# Secretory_age_TMPRSS2                                          False
# Secretory_sex[T.male]_ACE2                                      True
# Secretory_sex[T.male]_CTSL                                     False
# Secretory_sex[T.male]_TMPRSS2                                  False
# Rare_age_ACE2                                                  False
# Rare_age_CTSL                                                   True
# Rare_age_TMPRSS2                                               False
# Rare_sex[T.male]_ACE2                                          False
# Rare_sex[T.male]_CTSL                                          False
# Rare_sex[T.male]_TMPRSS2                                       False
# Submucosal_Secretory_age_ACE2                                  False
# Submucosal_Secretory_age_CTSL                                   True
# Submucosal_Secretory_age_TMPRSS2                               False
# Submucosal_Secretory_sex[T.male]_ACE2                          False
# Submucosal_Secretory_sex[T.male]_CTSL                           True
# Submucosal_Secretory_sex[T.male]_TMPRSS2                       False
# AT1_age_ACE2                                                   False
# AT1_age_CTSL                                                    True
# AT1_age_TMPRSS2                                                 True
# AT1_sex[T.male]_ACE2                                            True
# AT1_sex[T.male]_CTSL                                            True
# AT1_sex[T.male]_TMPRSS2                                         True
# AT2_age_ACE2                                                    True
# AT2_age_CTSL                                                    True
# AT2_age_TMPRSS2                                                 True
# AT2_sex[T.male]_ACE2                                            True
# AT2_sex[T.male]_CTSL                                            True
# AT2_sex[T.male]_TMPRSS2                                         True
# Arterial_age_CTSL                                              False
# Arterial_age_TMPRSS2                                           False
# Arterial_sex[T.male]_CTSL                                      False
# Arterial_sex[T.male]_TMPRSS2                                   False
# Capillary_age_ACE2                                             False
# Capillary_age_CTSL                                             False
# Capillary_age_TMPRSS2                                          False
# Capillary_sex[T.male]_ACE2                                     False
# Capillary_sex[T.male]_CTSL                                     False
# Capillary_sex[T.male]_TMPRSS2                                  False
# Venous_age_CTSL                                                False
# Venous_age_TMPRSS2                                             False
# Venous_sex[T.male]_CTSL                                        False
# Venous_sex[T.male]_TMPRSS2                                     False
# Lymphatic_EC_age_ACE2                                          False
# Lymphatic_EC_age_CTSL                                           True
# Lymphatic_EC_age_TMPRSS2                                       False
# Lymphatic_EC_sex[T.male]_ACE2                                  False
# Lymphatic_EC_sex[T.male]_CTSL                                  False
# Lymphatic_EC_sex[T.male]_TMPRSS2                                True
# Fibroblasts_age_ACE2                                           False
# Fibroblasts_age_CTSL                                           False
# Fibroblasts_age_TMPRSS2                                        False
# Fibroblasts_sex[T.male]_ACE2                                   False
# Fibroblasts_sex[T.male]_CTSL                                    True
# Fibroblasts_sex[T.male]_TMPRSS2                                False
# Myofibroblasts_age_CTSL                                         True
# Myofibroblasts_age_TMPRSS2                                     False
# Myofibroblasts_sex[T.male]_CTSL                                 True
# Myofibroblasts_sex[T.male]_TMPRSS2                             False
# Airway_smooth_muscle_age_CTSL                                  False
# Airway_smooth_muscle_sex[T.male]_CTSL                          False
# B_cell_lineage_age_CTSL                                        False
# B_cell_lineage_age_TMPRSS2                                     False
# B_cell_lineage_sex[T.male]_CTSL                                 True
# B_cell_lineage_sex[T.male]_TMPRSS2                             False
# T_cell_lineage_age_ACE2                                        False
# T_cell_lineage_age_CTSL                                         True
# T_cell_lineage_age_TMPRSS2                                     False
# T_cell_lineage_sex[T.male]_ACE2                                False
# T_cell_lineage_sex[T.male]_CTSL                                False
# T_cell_lineage_sex[T.male]_TMPRSS2                              True
# Innate_lymphoid_cells_age_CTSL                                  True
# Innate_lymphoid_cells_age_TMPRSS2                              False
# Innate_lymphoid_cells_sex[T.male]_CTSL                          True
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2                      False
# Dendritic_cells_age_CTSL                                        True
# Dendritic_cells_age_TMPRSS2                                    False
# Dendritic_cells_sex[T.male]_CTSL                                True
# Dendritic_cells_sex[T.male]_TMPRSS2                            False
# Macrophages_age_ACE2                                           False
# Macrophages_age_CTSL                                            True
# Macrophages_age_TMPRSS2                                        False
# Macrophages_sex[T.male]_ACE2                                   False
# Macrophages_sex[T.male]_CTSL                                    True
# Macrophages_sex[T.male]_TMPRSS2                                False
# Monocytes_age_ACE2                                             False
# Monocytes_age_CTSL                                             False
# Monocytes_age_TMPRSS2                                          False
# Monocytes_sex[T.male]_ACE2                                     False
# Monocytes_sex[T.male]_CTSL                                      True
# Monocytes_sex[T.male]_TMPRSS2                                   True
# MDC_age_CTSL                                                    True
# MDC_sex[T.male]_CTSL                                           False
# Mast_cells_age_CTSL                                            False
# Mast_cells_age_TMPRSS2                                         False
# Mast_cells_sex[T.male]_CTSL                                    False
# Mast_cells_sex[T.male]_TMPRSS2                                 False
#
#                                           covariate_simple
# Basal_age_ACE2                                         Age
# Basal_age_CTSL                                         Age
# Basal_age_TMPRSS2                                      Age
# Basal_sex[T.male]_ACE2                                 Sex
# Basal_sex[T.male]_CTSL                                 Sex
# Basal_sex[T.male]_TMPRSS2                              Sex
# Multiciliated_lineage_age_ACE2                         Age
# Multiciliated_lineage_age_CTSL                         Age
# Multiciliated_lineage_age_TMPRSS2                      Age
# Multiciliated_lineage_sex[T.male]_ACE2                 Sex
# Multiciliated_lineage_sex[T.male]_CTSL                 Sex
# Multiciliated_lineage_sex[T.male]_TMPRSS2              Sex
# Secretory_age_ACE2                                     Age
# Secretory_age_CTSL                                     Age
# Secretory_age_TMPRSS2                                  Age
# Secretory_sex[T.male]_ACE2                             Sex
# Secretory_sex[T.male]_CTSL                             Sex
# Secretory_sex[T.male]_TMPRSS2                          Sex
# Rare_age_ACE2                                          Age
# Rare_age_CTSL                                          Age
# Rare_age_TMPRSS2                                       Age
# Rare_sex[T.male]_ACE2                                  Sex
# Rare_sex[T.male]_CTSL                                  Sex
# Rare_sex[T.male]_TMPRSS2                               Sex
# Submucosal_Secretory_age_ACE2                          Age
# Submucosal_Secretory_age_CTSL                          Age
# Submucosal_Secretory_age_TMPRSS2                       Age
# Submucosal_Secretory_sex[T.male]_ACE2                  Sex
# Submucosal_Secretory_sex[T.male]_CTSL                  Sex
# Submucosal_Secretory_sex[T.male]_TMPRSS2               Sex
# AT1_age_ACE2                                           Age
# AT1_age_CTSL                                           Age
# AT1_age_TMPRSS2                                        Age
# AT1_sex[T.male]_ACE2                                   Sex
# AT1_sex[T.male]_CTSL                                   Sex
# AT1_sex[T.male]_TMPRSS2                                Sex
# AT2_age_ACE2                                           Age
# AT2_age_CTSL                                           Age
# AT2_age_TMPRSS2                                        Age
# AT2_sex[T.male]_ACE2                                   Sex
# AT2_sex[T.male]_CTSL                                   Sex
# AT2_sex[T.male]_TMPRSS2                                Sex
# Arterial_age_CTSL                                      Age
# Arterial_age_TMPRSS2                                   Age
# Arterial_sex[T.male]_CTSL                              Sex
# Arterial_sex[T.male]_TMPRSS2                           Sex
# Capillary_age_ACE2                                     Age
# Capillary_age_CTSL                                     Age
# Capillary_age_TMPRSS2                                  Age
# Capillary_sex[T.male]_ACE2                             Sex
# Capillary_sex[T.male]_CTSL                             Sex
# Capillary_sex[T.male]_TMPRSS2                          Sex
# Venous_age_CTSL                                        Age
# Venous_age_TMPRSS2                                     Age
# Venous_sex[T.male]_CTSL                                Sex
# Venous_sex[T.male]_TMPRSS2                             Sex
# Lymphatic_EC_age_ACE2                                  Age
# Lymphatic_EC_age_CTSL                                  Age
# Lymphatic_EC_age_TMPRSS2                               Age
# Lymphatic_EC_sex[T.male]_ACE2                          Sex
# Lymphatic_EC_sex[T.male]_CTSL                          Sex
# Lymphatic_EC_sex[T.male]_TMPRSS2                       Sex
# Fibroblasts_age_ACE2                                   Age
# Fibroblasts_age_CTSL                                   Age
# Fibroblasts_age_TMPRSS2                                Age
# Fibroblasts_sex[T.male]_ACE2                           Sex
# Fibroblasts_sex[T.male]_CTSL                           Sex
# Fibroblasts_sex[T.male]_TMPRSS2                        Sex
# Myofibroblasts_age_CTSL                                Age
# Myofibroblasts_age_TMPRSS2                             Age
# Myofibroblasts_sex[T.male]_CTSL                        Sex
# Myofibroblasts_sex[T.male]_TMPRSS2                     Sex
# Airway_smooth_muscle_age_CTSL                          Age
# Airway_smooth_muscle_sex[T.male]_CTSL                  Sex
# B_cell_lineage_age_CTSL                                Age
# B_cell_lineage_age_TMPRSS2                             Age
# B_cell_lineage_sex[T.male]_CTSL                        Sex
# B_cell_lineage_sex[T.male]_TMPRSS2                     Sex
# T_cell_lineage_age_ACE2                                Age
# T_cell_lineage_age_CTSL                                Age
# T_cell_lineage_age_TMPRSS2                             Age
# T_cell_lineage_sex[T.male]_ACE2                        Sex
# T_cell_lineage_sex[T.male]_CTSL                        Sex
# T_cell_lineage_sex[T.male]_TMPRSS2                     Sex
# Innate_lymphoid_cells_age_CTSL                         Age
# Innate_lymphoid_cells_age_TMPRSS2                      Age
# Innate_lymphoid_cells_sex[T.male]_CTSL                 Sex
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2              Sex
# Dendritic_cells_age_CTSL                               Age
# Dendritic_cells_age_TMPRSS2                            Age
# Dendritic_cells_sex[T.male]_CTSL                       Sex
# Dendritic_cells_sex[T.male]_TMPRSS2                    Sex
# Macrophages_age_ACE2                                   Age
# Macrophages_age_CTSL                                   Age
# Macrophages_age_TMPRSS2                                Age
# Macrophages_sex[T.male]_ACE2                           Sex
# Macrophages_sex[T.male]_CTSL                           Sex
# Macrophages_sex[T.male]_TMPRSS2                        Sex
# Monocytes_age_ACE2                                     Age
# Monocytes_age_CTSL                                     Age
# Monocytes_age_TMPRSS2                                  Age
# Monocytes_sex[T.male]_ACE2                             Sex
# Monocytes_sex[T.male]_CTSL                             Sex
# Monocytes_sex[T.male]_TMPRSS2                          Sex
# MDC_age_CTSL                                           Age
# MDC_sex[T.male]_CTSL                                   Sex
# Mast_cells_age_CTSL                                    Age
# Mast_cells_age_TMPRSS2                                 Age
# Mast_cells_sex[T.male]_CTSL                            Sex
# Mast_cells_sex[T.male]_TMPRSS2                         Sex

# %% [markdown]
# ## Level 2

# %%
res_lvl2['cell_identity'].unique()
# Out:
# array(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid',
#        'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland',
#        'Smooth Muscle', 'Lymphatics', 'Mesothelium', 'Granulocytes'],
#       dtype=object)

# %%
# Prep plotting

# Order cell identity category
res_lvl2['cell_identity'] = res_lvl2['cell_identity'].astype('category').cat.set_categories(['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium', 'Blood vessels', 'Lymphatics', 'Fibroblast lineage', 'Smooth Muscle', 'Mesothelium', 'Lymphoid', 'Myeloid', 'Granulocytes'], ordered=True)
res_lvl2 = res_lvl2.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium'], 'Endothelial':['Blood vessels', 'Lymphatics'], 'Stroma':['Fibroblast lineage', 'Smooth Muscle', 'Mesothelium'], 'Immune':['Lymphoid', 'Myeloid', 'Granulocytes']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl2['compartment'] = [ct_mapping_up[ct] for ct in res_lvl2['cell_identity']]        

# Check if bulk and sc effect directions agree
res_lvl2_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl2_pseudo[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl2.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl2[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl2['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl2['coef'].loc[res_lvl2.index[i]]* res_lvl2_pseudo['coef'].loc[res_lvl2.index[i]]) > 0) for i,val in enumerate(res_lvl2['adj_pvals'])]


# Check if simple and complex models agree

# Check if bulk and sc effect directions agree in interaction model
res_lvl2_ints_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl2_ints_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2_ints.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl2_ints[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2_ints['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl2_ints['coef'].loc[res_lvl2_ints.index[i]]* res_lvl2_ints_pseudo['coef'].loc[res_lvl2_ints.index[i]]) > 0) for i,val in enumerate(res_lvl2_ints['adj_pvals'])]

# Criteria:
# 1. No "indication" in opposite direction (significant and pseudo agrees)
# 2. At least 1 "indication" in the correct direction.

bulk_complex_agree = []

for idx in res_lvl2.index:
    mask = [str(idx) in str(i) for i in res_lvl2_ints.index]
    tmp = res_lvl2_ints.loc[mask]
    complex_vals = tmp['coef'].loc[tmp['signif_bulk_agree'].values].values

    if len(complex_vals) == 0:
        # No indication in complex interaction model
        bulk_complex_agree.append(False)

    else:
        # Check that all indications or robust trends point in the same direction
        # as the simple model case:
        int_agree = np.all([res_lvl2['coef'].loc[idx]*val > 0 for val in complex_vals])
        val = res_lvl2['signif_bulk_agree'].loc[idx] and int_agree
        bulk_complex_agree.append(val)
        
res_lvl2['signif_bulk_complex_agree'] = bulk_complex_agree


res_lvl2['compartment'] = res_lvl2['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl2['covariate_simple'] = res_lvl2['covariate'].astype('category').cat.rename_categories(['Age', 'Sex'])

res_lvl2 = res_lvl2.sort_values(by=['cell_identity', 'covariate', 'gene'])

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()


leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl2_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl2.sort_values(by=[ 'covariate', 'cell_identity',  'gene'])
# Out:
#                                             gene        cell_identity  \
# Airway_epithelium_age_ACE2                  ACE2    Airway epithelium
# Airway_epithelium_age_CTSL                  CTSL    Airway epithelium
# Airway_epithelium_age_TMPRSS2            TMPRSS2    Airway epithelium
# Submucosal_Gland_age_ACE2                   ACE2     Submucosal Gland
# Submucosal_Gland_age_CTSL                   CTSL     Submucosal Gland
# Submucosal_Gland_age_TMPRSS2             TMPRSS2     Submucosal Gland
# Alveolar_epithelium_age_ACE2                ACE2  Alveolar epithelium
# Alveolar_epithelium_age_CTSL                CTSL  Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2          TMPRSS2  Alveolar epithelium
# Blood_vessels_age_ACE2                      ACE2        Blood vessels
# Blood_vessels_age_CTSL                      CTSL        Blood vessels
# Blood_vessels_age_TMPRSS2                TMPRSS2        Blood vessels
# Lymphatics_age_ACE2                         ACE2           Lymphatics
# Lymphatics_age_CTSL                         CTSL           Lymphatics
# Lymphatics_age_TMPRSS2                   TMPRSS2           Lymphatics
# Fibroblast_lineage_age_ACE2                 ACE2   Fibroblast lineage
# Fibroblast_lineage_age_CTSL                 CTSL   Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2           TMPRSS2   Fibroblast lineage
# Smooth_Muscle_age_ACE2                      ACE2        Smooth Muscle
# Smooth_Muscle_age_CTSL                      CTSL        Smooth Muscle
# Smooth_Muscle_age_TMPRSS2                TMPRSS2        Smooth Muscle
# Mesothelium_age_CTSL                        CTSL          Mesothelium
# Mesothelium_age_TMPRSS2                  TMPRSS2          Mesothelium
# Lymphoid_age_ACE2                           ACE2             Lymphoid
# Lymphoid_age_CTSL                           CTSL             Lymphoid
# Lymphoid_age_TMPRSS2                     TMPRSS2             Lymphoid
# Myeloid_age_ACE2                            ACE2              Myeloid
# Myeloid_age_CTSL                            CTSL              Myeloid
# Myeloid_age_TMPRSS2                      TMPRSS2              Myeloid
# Granulocytes_age_CTSL                       CTSL         Granulocytes
# Airway_epithelium_sex[T.male]_ACE2          ACE2    Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL          CTSL    Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2    TMPRSS2    Airway epithelium
# Submucosal_Gland_sex[T.male]_ACE2           ACE2     Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL           CTSL     Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2     TMPRSS2     Submucosal Gland
# Alveolar_epithelium_sex[T.male]_ACE2        ACE2  Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL        CTSL  Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2  TMPRSS2  Alveolar epithelium
# Blood_vessels_sex[T.male]_ACE2              ACE2        Blood vessels
# Blood_vessels_sex[T.male]_CTSL              CTSL        Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2        TMPRSS2        Blood vessels
# Lymphatics_sex[T.male]_ACE2                 ACE2           Lymphatics
# Lymphatics_sex[T.male]_CTSL                 CTSL           Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2           TMPRSS2           Lymphatics
# Fibroblast_lineage_sex[T.male]_ACE2         ACE2   Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL         CTSL   Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2   TMPRSS2   Fibroblast lineage
# Smooth_Muscle_sex[T.male]_ACE2              ACE2        Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL              CTSL        Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2        TMPRSS2        Smooth Muscle
# Mesothelium_sex[T.male]_CTSL                CTSL          Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2          TMPRSS2          Mesothelium
# Lymphoid_sex[T.male]_ACE2                   ACE2             Lymphoid
# Lymphoid_sex[T.male]_CTSL                   CTSL             Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2             TMPRSS2             Lymphoid
# Myeloid_sex[T.male]_ACE2                    ACE2              Myeloid
# Myeloid_sex[T.male]_CTSL                    CTSL              Myeloid
# Myeloid_sex[T.male]_TMPRSS2              TMPRSS2              Myeloid
# Granulocytes_sex[T.male]_CTSL               CTSL         Granulocytes
#
#                                            covariate      coef   coef_sd  \
# Airway_epithelium_age_ACE2                       age  0.003375  0.001056
# Airway_epithelium_age_CTSL                       age  0.003844  0.000245
# Airway_epithelium_age_TMPRSS2                    age  0.000354  0.000325
# Submucosal_Gland_age_ACE2                        age  0.005288  0.002329
# Submucosal_Gland_age_CTSL                        age  0.006855  0.000687
# Submucosal_Gland_age_TMPRSS2                     age  0.001744  0.000579
# Smooth_Muscle_sex[T.male]_CTSL           sex[T.male] -0.404851  0.023214
# Smooth_Muscle_sex[T.male]_TMPRSS2        sex[T.male]  0.121927  0.249247
# Mesothelium_sex[T.male]_CTSL             sex[T.male]  0.435390  0.058712
# Mesothelium_sex[T.male]_TMPRSS2          sex[T.male] -1.643599  0.365618
# Lymphoid_sex[T.male]_ACE2                sex[T.male]  0.309828  0.332550
# Lymphoid_sex[T.male]_CTSL                sex[T.male]  0.387098  0.022928
# Lymphoid_sex[T.male]_TMPRSS2             sex[T.male]  0.331965  0.072183
# Myeloid_sex[T.male]_ACE2                 sex[T.male]  0.534434  0.178015
# Myeloid_sex[T.male]_CTSL                 sex[T.male] -0.102910  0.002132
# Myeloid_sex[T.male]_TMPRSS2              sex[T.male]  0.551324  0.040177
# Granulocytes_sex[T.male]_CTSL            sex[T.male]  0.334962  0.279478
#
#                                                  pval     adj_pvals  \
# Airway_epithelium_age_ACE2               1.402285e-03  2.103428e-03
# Airway_epithelium_age_CTSL               1.711103e-55  5.133310e-55
# Airway_epithelium_age_TMPRSS2            2.767636e-01  2.767636e-01
# Submucosal_Gland_age_ACE2                2.319545e-02  2.783454e-02
# Submucosal_Gland_age_CTSL                1.989950e-23  5.969850e-23
# Submucosal_Gland_age_TMPRSS2             2.580443e-03  3.870664e-03
# Alveolar_epithelium_age_ACE2             1.063568e-22  1.063568e-22
# Alveolar_epithelium_age_CTSL             2.775175e-56  5.550349e-56
# Alveolar_epithelium_age_TMPRSS2          0.000000e+00  0.000000e+00
# Blood_vessels_age_ACE2                   6.428875e-01  7.714650e-01
# Blood_vessels_age_CTSL                   8.182115e-02  1.636423e-01
# Blood_vessels_age_TMPRSS2                8.548018e-01  8.548018e-01
# Lymphatics_age_ACE2                      1.293628e-02  2.587257e-02
# Lymphatics_age_CTSL                      1.366528e-03  4.099585e-03
# Lymphatics_age_TMPRSS2                   1.506828e-01  1.808194e-01
# Fibroblast_lineage_age_ACE2              4.750683e-01  5.700820e-01
# Fibroblast_lineage_age_CTSL              0.000000e+00  0.000000e+00
# Fibroblast_lineage_age_TMPRSS2           1.522644e-04  2.283966e-04
# Smooth_Muscle_age_ACE2                   9.431641e-01  9.431641e-01
# Smooth_Muscle_age_CTSL                   3.517827e-94  2.110696e-93
# Smooth_Muscle_age_TMPRSS2                1.320078e-01  2.640157e-01
# Mesothelium_age_CTSL                     5.159104e-01  5.159104e-01
# Mesothelium_age_TMPRSS2                  1.112366e-05  1.483155e-05
# Lymphoid_age_ACE2                        1.226230e-02  1.839345e-02
# Lymphoid_age_CTSL                        8.747266e-15  2.624180e-14
# Lymphoid_age_TMPRSS2                     2.701543e-02  3.241852e-02
# Myeloid_age_ACE2                         7.859520e-01  7.859520e-01
# Myeloid_age_CTSL                         3.866532e-40  7.733064e-40
# Myeloid_age_TMPRSS2                      1.292802e-01  1.551362e-01
# Granulocytes_age_CTSL                    3.404697e-02  6.809394e-02
# Airway_epithelium_sex[T.male]_ACE2       7.403222e-02  8.883866e-02
# Airway_epithelium_sex[T.male]_CTSL       1.550301e-51  3.100601e-51
# Airway_epithelium_sex[T.male]_TMPRSS2    1.076613e-59  6.459678e-59
# Submucosal_Gland_sex[T.male]_ACE2        9.615734e-01  9.615734e-01
# Submucosal_Gland_sex[T.male]_CTSL        7.920343e-05  1.584069e-04
# Submucosal_Gland_sex[T.male]_TMPRSS2     2.141115e-38  1.284669e-37
# Alveolar_epithelium_sex[T.male]_ACE2     4.758037e-57  1.427411e-56
# Alveolar_epithelium_sex[T.male]_CTSL     1.996646e-34  2.395975e-34
# Alveolar_epithelium_sex[T.male]_TMPRSS2  9.499591e-45  1.424939e-44
# Blood_vessels_sex[T.male]_ACE2           3.059992e-03  9.179977e-03
# Blood_vessels_sex[T.male]_CTSL           8.194994e-05  4.916996e-04
# Blood_vessels_sex[T.male]_TMPRSS2        1.909915e-01  2.864873e-01
# Lymphatics_sex[T.male]_ACE2              3.553690e-02  5.330534e-02
# Lymphatics_sex[T.male]_CTSL              6.800405e-01  6.800405e-01
# Lymphatics_sex[T.male]_TMPRSS2           9.600860e-05  5.760516e-04
# Fibroblast_lineage_sex[T.male]_ACE2      8.213142e-01  8.213142e-01
# Fibroblast_lineage_sex[T.male]_CTSL      0.000000e+00  0.000000e+00
# Fibroblast_lineage_sex[T.male]_TMPRSS2   5.095326e-08  1.019065e-07
# Smooth_Muscle_sex[T.male]_ACE2           6.492783e-01  7.791340e-01
# Smooth_Muscle_sex[T.male]_CTSL           4.078290e-68  1.223487e-67
# Smooth_Muscle_sex[T.male]_TMPRSS2        6.247136e-01  7.791340e-01
# Mesothelium_sex[T.male]_CTSL             1.210158e-13  4.840631e-13
# Mesothelium_sex[T.male]_TMPRSS2          6.944097e-06  1.388819e-05
# Lymphoid_sex[T.male]_ACE2                3.515054e-01  3.515054e-01
# Lymphoid_sex[T.male]_CTSL                5.999413e-64  3.599648e-63
# Lymphoid_sex[T.male]_TMPRSS2             4.246695e-06  8.493389e-06
# Myeloid_sex[T.male]_ACE2                 2.680519e-03  4.020779e-03
# Myeloid_sex[T.male]_CTSL                 0.000000e+00  0.000000e+00
# Myeloid_sex[T.male]_TMPRSS2              7.472898e-43  2.241870e-42
# Granulocytes_sex[T.male]_CTSL            2.307126e-01  2.307126e-01
#
#                                          compartment  signif_bulk_agree  \
# Airway_epithelium_age_ACE2                Epithelial              False
# Airway_epithelium_age_CTSL                Epithelial               True
# Airway_epithelium_age_TMPRSS2             Epithelial              False
# Submucosal_Gland_age_ACE2                 Epithelial               True
# Submucosal_Gland_age_CTSL                 Epithelial               True
# Submucosal_Gland_age_TMPRSS2              Epithelial              False
# Alveolar_epithelium_age_ACE2              Epithelial               True
# Alveolar_epithelium_age_CTSL              Epithelial               True
# Alveolar_epithelium_age_TMPRSS2           Epithelial               True
# Blood_vessels_age_ACE2                   Endothelial              False
# Blood_vessels_age_CTSL                   Endothelial              False
# Blood_vessels_age_TMPRSS2                Endothelial              False
# Lymphatics_age_ACE2                      Endothelial               True
# Lymphatics_age_CTSL                      Endothelial               True
# Lymphatics_age_TMPRSS2                   Endothelial              False
# Fibroblast_lineage_age_ACE2                   Stroma              False
# Fibroblast_lineage_age_CTSL                   Stroma               True
# Fibroblast_lineage_age_TMPRSS2                Stroma               True
# Smooth_Muscle_age_ACE2                        Stroma              False
# Smooth_Muscle_age_CTSL                        Stroma               True
# Smooth_Muscle_age_TMPRSS2                     Stroma              False
# Mesothelium_age_CTSL                          Stroma              False
# Mesothelium_age_TMPRSS2                       Stroma               True
# Lymphoid_age_ACE2                             Immune               True
# Lymphoid_age_CTSL                             Immune               True
# Lymphoid_age_TMPRSS2                          Immune               True
# Myeloid_age_ACE2                              Immune              False
# Myeloid_age_CTSL                              Immune              False
# Myeloid_age_TMPRSS2                           Immune              False
# Granulocytes_age_CTSL                         Immune              False
# Airway_epithelium_sex[T.male]_ACE2        Epithelial              False
# Airway_epithelium_sex[T.male]_CTSL        Epithelial               True
# Airway_epithelium_sex[T.male]_TMPRSS2     Epithelial               True
# Submucosal_Gland_sex[T.male]_ACE2         Epithelial              False
# Submucosal_Gland_sex[T.male]_CTSL         Epithelial               True
# Submucosal_Gland_sex[T.male]_TMPRSS2      Epithelial               True
# Alveolar_epithelium_sex[T.male]_ACE2      Epithelial               True
# Alveolar_epithelium_sex[T.male]_CTSL      Epithelial               True
# Alveolar_epithelium_sex[T.male]_TMPRSS2   Epithelial               True
# Blood_vessels_sex[T.male]_ACE2           Endothelial               True
# Blood_vessels_sex[T.male]_CTSL           Endothelial               True
# Blood_vessels_sex[T.male]_TMPRSS2        Endothelial              False
# Lymphatics_sex[T.male]_ACE2              Endothelial              False
# Lymphatics_sex[T.male]_CTSL              Endothelial              False
# Lymphatics_sex[T.male]_TMPRSS2           Endothelial               True
# Fibroblast_lineage_sex[T.male]_ACE2           Stroma              False
# Fibroblast_lineage_sex[T.male]_CTSL           Stroma               True
# Fibroblast_lineage_sex[T.male]_TMPRSS2        Stroma               True
# Smooth_Muscle_sex[T.male]_ACE2                Stroma              False
# Smooth_Muscle_sex[T.male]_CTSL                Stroma               True
# Smooth_Muscle_sex[T.male]_TMPRSS2             Stroma              False
# Mesothelium_sex[T.male]_CTSL                  Stroma              False
# Mesothelium_sex[T.male]_TMPRSS2               Stroma               True
# Lymphoid_sex[T.male]_ACE2                     Immune              False
# Lymphoid_sex[T.male]_CTSL                     Immune               True
# Lymphoid_sex[T.male]_TMPRSS2                  Immune               True
# Myeloid_sex[T.male]_ACE2                      Immune               True
# Myeloid_sex[T.male]_CTSL                      Immune               True
# Myeloid_sex[T.male]_TMPRSS2                   Immune               True
# Granulocytes_sex[T.male]_CTSL                 Immune              False
#
#                                          signif_bulk_complex_agree  \
# Airway_epithelium_age_ACE2                                   False
# Airway_epithelium_age_CTSL                                    True
# Airway_epithelium_age_TMPRSS2                                False
# Submucosal_Gland_age_ACE2                                    False
# Submucosal_Gland_age_CTSL                                     True
# Submucosal_Gland_age_TMPRSS2                                 False
# Alveolar_epithelium_age_ACE2                                  True
# Alveolar_epithelium_age_CTSL                                  True
# Alveolar_epithelium_age_TMPRSS2                               True
# Blood_vessels_age_ACE2                                       False
# Blood_vessels_age_CTSL                                       False
# Blood_vessels_age_TMPRSS2                                    False
# Lymphatics_age_ACE2                                          False
# Lymphatics_age_CTSL                                           True
# Lymphatics_age_TMPRSS2                                       False
# Fibroblast_lineage_age_ACE2                                  False
# Fibroblast_lineage_age_CTSL                                  False
# Fibroblast_lineage_age_TMPRSS2                                True
# Smooth_Muscle_age_ACE2                                       False
# Smooth_Muscle_age_CTSL                                        True
# Smooth_Muscle_age_TMPRSS2                                    False
# Mesothelium_age_CTSL                                         False
# Mesothelium_age_TMPRSS2                                       True
# Lymphoid_age_ACE2                                            False
# Lymphoid_age_CTSL                                             True
# Lymphoid_age_TMPRSS2                                         False
# Myeloid_age_ACE2                                             False
# Myeloid_age_CTSL                                             False
# Myeloid_age_TMPRSS2                                          False
# Granulocytes_age_CTSL                                        False
# Airway_epithelium_sex[T.male]_ACE2                           False
# Airway_epithelium_sex[T.male]_CTSL                            True
# Airway_epithelium_sex[T.male]_TMPRSS2                         True
# Submucosal_Gland_sex[T.male]_ACE2                            False
# Submucosal_Gland_sex[T.male]_CTSL                             True
# Submucosal_Gland_sex[T.male]_TMPRSS2                         False
# Alveolar_epithelium_sex[T.male]_ACE2                          True
# Alveolar_epithelium_sex[T.male]_CTSL                          True
# Alveolar_epithelium_sex[T.male]_TMPRSS2                       True
# Blood_vessels_sex[T.male]_ACE2                               False
# Blood_vessels_sex[T.male]_CTSL                                True
# Blood_vessels_sex[T.male]_TMPRSS2                            False
# Lymphatics_sex[T.male]_ACE2                                  False
# Lymphatics_sex[T.male]_CTSL                                  False
# Lymphatics_sex[T.male]_TMPRSS2                                True
# Fibroblast_lineage_sex[T.male]_ACE2                          False
# Fibroblast_lineage_sex[T.male]_CTSL                           True
# Fibroblast_lineage_sex[T.male]_TMPRSS2                        True
# Smooth_Muscle_sex[T.male]_ACE2                               False
# Smooth_Muscle_sex[T.male]_CTSL                                True
# Smooth_Muscle_sex[T.male]_TMPRSS2                            False
# Mesothelium_sex[T.male]_CTSL                                 False
# Mesothelium_sex[T.male]_TMPRSS2                              False
# Lymphoid_sex[T.male]_ACE2                                    False
# Lymphoid_sex[T.male]_CTSL                                    False
# Lymphoid_sex[T.male]_TMPRSS2                                  True
# Myeloid_sex[T.male]_ACE2                                      True
# Myeloid_sex[T.male]_CTSL                                      True
# Myeloid_sex[T.male]_TMPRSS2                                   True
# Granulocytes_sex[T.male]_CTSL                                False
#
#                                         covariate_simple
# Airway_epithelium_age_ACE2                           Age
# Airway_epithelium_age_CTSL                           Age
# Airway_epithelium_age_TMPRSS2                        Age
# Submucosal_Gland_age_ACE2                            Age
# Submucosal_Gland_age_CTSL                            Age
# Submucosal_Gland_age_TMPRSS2                         Age
# Alveolar_epithelium_age_ACE2                         Age
# Alveolar_epithelium_age_CTSL                         Age
# Alveolar_epithelium_age_TMPRSS2                      Age
# Blood_vessels_age_ACE2                               Age
# Blood_vessels_age_CTSL                               Age
# Blood_vessels_age_TMPRSS2                            Age
# Lymphatics_age_ACE2                                  Age
# Lymphatics_age_CTSL                                  Age
# Lymphatics_age_TMPRSS2                               Age
# Fibroblast_lineage_age_ACE2                          Age
# Fibroblast_lineage_age_CTSL                          Age
# Fibroblast_lineage_age_TMPRSS2                       Age
# Smooth_Muscle_age_ACE2                               Age
# Smooth_Muscle_age_CTSL                               Age
# Smooth_Muscle_age_TMPRSS2                            Age
# Mesothelium_age_CTSL                                 Age
# Mesothelium_age_TMPRSS2                              Age
# Lymphoid_age_ACE2                                    Age
# Lymphoid_age_CTSL                                    Age
# Lymphoid_age_TMPRSS2                                 Age
# Myeloid_age_ACE2                                     Age
# Myeloid_age_CTSL                                     Age
# Myeloid_age_TMPRSS2                                  Age
# Granulocytes_age_CTSL                                Age
# Airway_epithelium_sex[T.male]_ACE2                   Sex
# Airway_epithelium_sex[T.male]_CTSL                   Sex
# Airway_epithelium_sex[T.male]_TMPRSS2                Sex
# Submucosal_Gland_sex[T.male]_ACE2                    Sex
# Submucosal_Gland_sex[T.male]_CTSL                    Sex
# Submucosal_Gland_sex[T.male]_TMPRSS2                 Sex
# Alveolar_epithelium_sex[T.male]_ACE2                 Sex
# Alveolar_epithelium_sex[T.male]_CTSL                 Sex
# Alveolar_epithelium_sex[T.male]_TMPRSS2              Sex
# Blood_vessels_sex[T.male]_ACE2                       Sex
# Blood_vessels_sex[T.male]_CTSL                       Sex
# Blood_vessels_sex[T.male]_TMPRSS2                    Sex
# Lymphatics_sex[T.male]_ACE2                          Sex
# Lymphatics_sex[T.male]_CTSL                          Sex
# Lymphatics_sex[T.male]_TMPRSS2                       Sex
# Fibroblast_lineage_sex[T.male]_ACE2                  Sex
# Fibroblast_lineage_sex[T.male]_CTSL                  Sex
# Fibroblast_lineage_sex[T.male]_TMPRSS2               Sex
# Smooth_Muscle_sex[T.male]_ACE2                       Sex
# Smooth_Muscle_sex[T.male]_CTSL                       Sex
# Smooth_Muscle_sex[T.male]_TMPRSS2                    Sex
# Mesothelium_sex[T.male]_CTSL                         Sex
# Mesothelium_sex[T.male]_TMPRSS2                      Sex
# Lymphoid_sex[T.male]_ACE2                            Sex
# Lymphoid_sex[T.male]_CTSL                            Sex
# Lymphoid_sex[T.male]_TMPRSS2                         Sex
# Myeloid_sex[T.male]_ACE2                             Sex
# Myeloid_sex[T.male]_CTSL                             Sex
# Myeloid_sex[T.male]_TMPRSS2                          Sex
# Granulocytes_sex[T.male]_CTSL                        Sex

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

xlims_top = [[None, None, None],
             [None, None, None],
             [None, None, None],
             [None, None, None]]
xlims_bot = [[None, None, None],
             [None ,None, None],
             [None, None, None],
             [None, None, None]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl2_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# (-0.006580603187343772, 0.02343355365126409)
# <ErrorbarContainer object of 3 artists>
# (-0.18408996080019624, 0.9145452649772066)
# <ErrorbarContainer object of 3 artists>
# (-0.01179559380816523, 0.06999740351267676)
# <ErrorbarContainer object of 3 artists>
# (0.0, 1.437289251591412)
# <ErrorbarContainer object of 3 artists>
# (-0.019941573119526605, 0.07193674876242599)
# <ErrorbarContainer object of 3 artists>
# (-1.7475480110932944, 0.5393392160583887)
# <ErrorbarContainer object of 3 artists>
# (-0.029986027384502737, 0.008651484128807316)
# <ErrorbarContainer object of 3 artists>
# (-0.14591555752454882, 0.7533236226546337)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')
