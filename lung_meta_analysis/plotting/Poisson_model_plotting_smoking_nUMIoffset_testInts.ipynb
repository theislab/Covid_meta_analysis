# %% [markdown]
# This notebook contains the plotting functions used to plot the results of the meta-analysis with interaction terms (Supplementary Figures 5,6).

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors, patches
import seaborn as sns
import logging, warnings
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

output_folder = 'diffxpy_out/'

base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm_smoking'

# %%
res_lvl2 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_summary.csv', index_col=0)
res_lvl2_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl2_full.csv', index_col=0)

# %%
res_lvl3 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_summary.csv', index_col=0)
res_lvl3_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl3_full.csv', index_col=0)

# %%
res_lvl3.head()
# Out:
#    gene cell_identity    covariate  eval_at      coef   coef_sd      pval  \
# 0  ACE2   Macrophages  sex[T.male]  31yr NS  0.815131  0.363377  0.024883
# 1  ACE2   Macrophages  sex[T.male]   31yr S  0.103947  0.766362  0.892108
# 2  ACE2   Macrophages  sex[T.male]  62yr NS -0.621819  0.501752  0.215236
# 3  ACE2   Macrophages  sex[T.male]   62yr S -1.333003  0.584259  0.022517
# 4  ACE2   Macrophages          age     F NS  0.021959  0.009962  0.027511
#
#    adj_pvals
# 0   0.049766
# 1   0.917597
# 2   0.286981
# 3   0.047683
# 4   0.052126

# %%
res_lvl3.dtypes
# Out:
# gene              object
# cell_identity     object
# covariate         object
# eval_at           object
# coef             float64
# coef_sd          float64
# pval             float64
# adj_pvals        float64
# dtype: object

# %% [markdown]
# # Plotting

# %%
sns.set(font_scale=1.5, style='white')

# %% [markdown]
# ## Level 3

# %%
res_lvl3['cell_identity'].unique()
# Out:
# array(['Macrophages', 'Basal', 'AT2', 'T cell lineage', 'Monocytes',
#        'Multiciliated lineage', 'Submucosal Secretory', 'AT1',
#        'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells',
#        'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous',
#        'Lymphatic EC', 'Arterial', 'Rare', 'Airway smooth muscle'],
#       dtype=object)

# %%
# Prep plotting

# Order cell identity category
res_lvl3['cell_identity'] = res_lvl3['cell_identity'].astype('category').cat.set_categories(['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2', 'Arterial', 'Capillary', 'Venous', 'Lymphatic EC', 'Fibroblasts', 'Airway smooth muscle', 'B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'Mast cells'], ordered=True)
res_lvl3 = res_lvl3.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2'], 'Endothelial':['Arterial', 'Capillary', 'Venous', 'Lymphatic EC'], 'Stroma':['Fibroblasts', 'Airway smooth muscle'], 'Immune':['B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'Mast cells']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl3['compartment'] = [ct_mapping_up[ct] for ct in res_lvl3['cell_identity']]        

# Check if bulk and sc effect directions agree
res_lvl3_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl3_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl3[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl3['coef'].loc[res_lvl3.index[i]]* res_lvl3_pseudo['coef'].loc[res_lvl3.index[i]]) > 0) for i,val in enumerate(res_lvl3['adj_pvals'])]


res_lvl3['compartment'] = res_lvl3['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl3['covariate_simple'] = res_lvl3['covariate'].astype('category').cat.rename_categories(['Age', 'Sex', 'Smoking_status'])

# Assign eval_at numbers
res_lvl3 = res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])

eval_encoding = {
    'age':{'F NS':0, 'M NS':1, 'F S':2, 'M S':3},
    'sex[T.male]':{'31yr NS':0, '31yr S':1, '62yr NS':2, '62yr S':3},
    'smoking_status[T.True]':{'F 31yr':0, 'M 31yr':1, 'F 62yr':2, 'M 62yr':3}
}

res_lvl3['eval_num'] = [eval_encoding[res_lvl3['covariate'].loc[idx]][res_lvl3['eval_at'].loc[idx]] 
                        for idx in res_lvl3.index]

res_lvl3['gene_eval'] = [' '.join([i,str(j)]) for i,j in zip(res_lvl3['gene'], res_lvl3['eval_num'])]

# %%
res_lvl3
# Out:
#                                                        gene  \
# Basal_age_ACE2_M_NS                                    ACE2
# Basal_age_ACE2_F_S                                     ACE2
# Basal_age_ACE2_F_NS                                    ACE2
# Basal_age_ACE2_M_S                                     ACE2
# Basal_age_CTSL_M_S                                     CTSL
# Basal_age_CTSL_M_NS                                    CTSL
# Basal_age_CTSL_F_S                                     CTSL
# Basal_age_CTSL_F_NS                                    CTSL
# Basal_age_TMPRSS2_F_NS                              TMPRSS2
# Basal_age_TMPRSS2_M_NS                              TMPRSS2
# Basal_age_TMPRSS2_F_S                               TMPRSS2
# Basal_age_TMPRSS2_M_S                               TMPRSS2
# Basal_sex[T.male]_ACE2_62yr_S                          ACE2
# Basal_sex[T.male]_ACE2_62yr_NS                         ACE2
# Basal_sex[T.male]_ACE2_31yr_S                          ACE2
# Basal_sex[T.male]_ACE2_31yr_NS                         ACE2
# Basal_sex[T.male]_CTSL_62yr_S                          CTSL
# Basal_sex[T.male]_CTSL_62yr_NS                         CTSL
# Basal_sex[T.male]_CTSL_31yr_NS                         CTSL
# Basal_sex[T.male]_CTSL_31yr_S                          CTSL
# Basal_sex[T.male]_TMPRSS2_62yr_NS                   TMPRSS2
# Basal_sex[T.male]_TMPRSS2_31yr_S                    TMPRSS2
# Basal_sex[T.male]_TMPRSS2_31yr_NS                   TMPRSS2
# Basal_sex[T.male]_TMPRSS2_62yr_S                    TMPRSS2
# Basal_smoking_status[T.True]_ACE2_M_62yr               ACE2
# Basal_smoking_status[T.True]_ACE2_M_31yr               ACE2
# Basal_smoking_status[T.True]_ACE2_F_62yr               ACE2
# Basal_smoking_status[T.True]_ACE2_F_31yr               ACE2
# Basal_smoking_status[T.True]_CTSL_M_62yr               CTSL
# Basal_smoking_status[T.True]_CTSL_F_31yr               CTSL
# Basal_smoking_status[T.True]_CTSL_F_62yr               CTSL
# Basal_smoking_status[T.True]_CTSL_M_31yr               CTSL
# Basal_smoking_status[T.True]_TMPRSS2_M_62yr         TMPRSS2
# Basal_smoking_status[T.True]_TMPRSS2_M_31yr         TMPRSS2
# Basal_smoking_status[T.True]_TMPRSS2_F_62yr         TMPRSS2
# Basal_smoking_status[T.True]_TMPRSS2_F_31yr         TMPRSS2
# Multiciliated_lineage_age_ACE2_M_S                     ACE2
# Multiciliated_lineage_age_ACE2_M_NS                    ACE2
# Multiciliated_lineage_age_ACE2_F_S                     ACE2
# Multiciliated_lineage_age_ACE2_F_NS                    ACE2
# Multiciliated_lineage_age_CTSL_M_S                     CTSL
# Multiciliated_lineage_age_CTSL_M_NS                    CTSL
# Multiciliated_lineage_age_CTSL_F_S                     CTSL
# Multiciliated_lineage_age_CTSL_F_NS                    CTSL
# Multiciliated_lineage_age_TMPRSS2_F_NS              TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_F_S               TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_M_NS              TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_M_S               TMPRSS2
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_S          ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_NS         ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_S          ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_NS         ACE2
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_NS         CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_S          CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_NS         CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_S          CTSL
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_S    TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_NS   TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_S    TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_NS   TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Secretory_age_ACE2_F_NS                                ACE2
# Secretory_age_ACE2_F_S                                 ACE2
# Secretory_age_ACE2_M_NS                                ACE2
# Secretory_age_ACE2_M_S                                 ACE2
# Secretory_age_CTSL_F_NS                                CTSL
# Secretory_age_CTSL_F_S                                 CTSL
# Secretory_age_CTSL_M_NS                                CTSL
# Secretory_age_CTSL_M_S                                 CTSL
# Secretory_age_TMPRSS2_F_NS                          TMPRSS2
# Secretory_age_TMPRSS2_F_S                           TMPRSS2
# Secretory_age_TMPRSS2_M_NS                          TMPRSS2
# Secretory_age_TMPRSS2_M_S                           TMPRSS2
# Secretory_sex[T.male]_ACE2_62yr_S                      ACE2
# Secretory_sex[T.male]_ACE2_62yr_NS                     ACE2
# Secretory_sex[T.male]_ACE2_31yr_S                      ACE2
# Secretory_sex[T.male]_ACE2_31yr_NS                     ACE2
# Secretory_sex[T.male]_CTSL_31yr_S                      CTSL
# Secretory_sex[T.male]_CTSL_62yr_NS                     CTSL
# Secretory_sex[T.male]_CTSL_62yr_S                      CTSL
# Secretory_sex[T.male]_CTSL_31yr_NS                     CTSL
# Secretory_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2
# Secretory_smoking_status[T.True]_ACE2_F_31yr           ACE2
# Secretory_smoking_status[T.True]_ACE2_M_62yr           ACE2
# Secretory_smoking_status[T.True]_ACE2_M_31yr           ACE2
# Secretory_smoking_status[T.True]_ACE2_F_62yr           ACE2
# Secretory_smoking_status[T.True]_CTSL_F_31yr           CTSL
# Secretory_smoking_status[T.True]_CTSL_F_62yr           CTSL
# Secretory_smoking_status[T.True]_CTSL_M_31yr           CTSL
# Secretory_smoking_status[T.True]_CTSL_M_62yr           CTSL
# Secretory_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2
# Secretory_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2
# Secretory_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2
# Secretory_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2
# Rare_age_ACE2_F_NS                                     ACE2
# Rare_age_ACE2_F_S                                      ACE2
# Rare_age_ACE2_M_NS                                     ACE2
# Rare_age_ACE2_M_S                                      ACE2
# Rare_age_CTSL_F_S                                      CTSL
# Rare_age_CTSL_F_NS                                     CTSL
# Rare_age_CTSL_M_NS                                     CTSL
# Rare_age_CTSL_M_S                                      CTSL
# Rare_age_TMPRSS2_M_S                                TMPRSS2
# Rare_age_TMPRSS2_M_NS                               TMPRSS2
# Rare_age_TMPRSS2_F_NS                               TMPRSS2
# Rare_age_TMPRSS2_F_S                                TMPRSS2
# Rare_sex[T.male]_ACE2_62yr_S                           ACE2
# Rare_sex[T.male]_ACE2_62yr_NS                          ACE2
# Rare_sex[T.male]_ACE2_31yr_NS                          ACE2
# Rare_sex[T.male]_ACE2_31yr_S                           ACE2
# Rare_sex[T.male]_CTSL_31yr_NS                          CTSL
# Rare_sex[T.male]_CTSL_31yr_S                           CTSL
# Rare_sex[T.male]_CTSL_62yr_NS                          CTSL
# Rare_sex[T.male]_CTSL_62yr_S                           CTSL
# Rare_sex[T.male]_TMPRSS2_31yr_NS                    TMPRSS2
# Rare_sex[T.male]_TMPRSS2_62yr_NS                    TMPRSS2
# Rare_sex[T.male]_TMPRSS2_62yr_S                     TMPRSS2
# Rare_sex[T.male]_TMPRSS2_31yr_S                     TMPRSS2
# Rare_smoking_status[T.True]_ACE2_F_31yr                ACE2
# Rare_smoking_status[T.True]_ACE2_F_62yr                ACE2
# Rare_smoking_status[T.True]_ACE2_M_31yr                ACE2
# Rare_smoking_status[T.True]_ACE2_M_62yr                ACE2
# Rare_smoking_status[T.True]_CTSL_F_31yr                CTSL
# Rare_smoking_status[T.True]_CTSL_F_62yr                CTSL
# Rare_smoking_status[T.True]_CTSL_M_31yr                CTSL
# Rare_smoking_status[T.True]_CTSL_M_62yr                CTSL
# Rare_smoking_status[T.True]_TMPRSS2_M_62yr          TMPRSS2
# Rare_smoking_status[T.True]_TMPRSS2_M_31yr          TMPRSS2
# Rare_smoking_status[T.True]_TMPRSS2_F_62yr          TMPRSS2
# Rare_smoking_status[T.True]_TMPRSS2_F_31yr          TMPRSS2
# Submucosal_Secretory_age_ACE2_F_NS                     ACE2
# Submucosal_Secretory_age_ACE2_M_NS                     ACE2
# Submucosal_Secretory_age_ACE2_M_S                      ACE2
# Submucosal_Secretory_age_ACE2_F_S                      ACE2
# Submucosal_Secretory_age_CTSL_F_NS                     CTSL
# Submucosal_Secretory_age_CTSL_F_S                      CTSL
# Submucosal_Secretory_age_CTSL_M_NS                     CTSL
# Submucosal_Secretory_age_CTSL_M_S                      CTSL
# Submucosal_Secretory_age_TMPRSS2_F_S                TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_M_NS               TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_F_NS               TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_M_S                TMPRSS2
# Submucosal_Secretory_sex[T.male]_ACE2_31yr_NS          ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_31yr_S           ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_62yr_NS          ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_62yr_S           ACE2
# Submucosal_Secretory_sex[T.male]_CTSL_31yr_NS          CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_31yr_S           CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_62yr_NS          CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_62yr_S           CTSL
# Submucosal_Secretory_sex[T.male]_TMPRSS2_31yr_NS    TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_31yr_S     TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr_NS    TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr_S     TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# AT1_age_ACE2_M_S                                       ACE2
# AT1_age_ACE2_M_NS                                      ACE2
# AT1_age_ACE2_F_NS                                      ACE2
# AT1_age_ACE2_F_S                                       ACE2
# AT1_age_CTSL_M_NS                                      CTSL
# AT1_age_CTSL_F_S                                       CTSL
# AT1_age_CTSL_F_NS                                      CTSL
# AT1_age_CTSL_M_S                                       CTSL
# AT1_age_TMPRSS2_F_NS                                TMPRSS2
# AT1_age_TMPRSS2_M_S                                 TMPRSS2
# AT1_age_TMPRSS2_M_NS                                TMPRSS2
# AT1_age_TMPRSS2_F_S                                 TMPRSS2
# AT1_sex[T.male]_ACE2_62yr_S                            ACE2
# AT1_sex[T.male]_ACE2_62yr_NS                           ACE2
# AT1_sex[T.male]_ACE2_31yr_S                            ACE2
# AT1_sex[T.male]_ACE2_31yr_NS                           ACE2
# AT1_sex[T.male]_CTSL_62yr_S                            CTSL
# AT1_sex[T.male]_CTSL_62yr_NS                           CTSL
# AT1_sex[T.male]_CTSL_31yr_S                            CTSL
# AT1_sex[T.male]_CTSL_31yr_NS                           CTSL
# AT1_sex[T.male]_TMPRSS2_31yr_NS                     TMPRSS2
# AT1_sex[T.male]_TMPRSS2_31yr_S                      TMPRSS2
# AT1_sex[T.male]_TMPRSS2_62yr_NS                     TMPRSS2
# AT1_sex[T.male]_TMPRSS2_62yr_S                      TMPRSS2
# AT1_smoking_status[T.True]_ACE2_M_62yr                 ACE2
# AT1_smoking_status[T.True]_ACE2_M_31yr                 ACE2
# AT1_smoking_status[T.True]_ACE2_F_62yr                 ACE2
# AT1_smoking_status[T.True]_ACE2_F_31yr                 ACE2
# AT1_smoking_status[T.True]_CTSL_M_31yr                 CTSL
# AT1_smoking_status[T.True]_CTSL_M_62yr                 CTSL
# AT1_smoking_status[T.True]_CTSL_F_62yr                 CTSL
# AT1_smoking_status[T.True]_CTSL_F_31yr                 CTSL
# AT1_smoking_status[T.True]_TMPRSS2_M_31yr           TMPRSS2
# AT1_smoking_status[T.True]_TMPRSS2_F_62yr           TMPRSS2
# AT1_smoking_status[T.True]_TMPRSS2_F_31yr           TMPRSS2
# AT1_smoking_status[T.True]_TMPRSS2_M_62yr           TMPRSS2
# AT2_age_ACE2_F_NS                                      ACE2
# AT2_age_ACE2_F_S                                       ACE2
# AT2_age_ACE2_M_NS                                      ACE2
# AT2_age_ACE2_M_S                                       ACE2
# AT2_age_CTSL_M_S                                       CTSL
# AT2_age_CTSL_M_NS                                      CTSL
# AT2_age_CTSL_F_S                                       CTSL
# AT2_age_CTSL_F_NS                                      CTSL
# AT2_age_TMPRSS2_M_S                                 TMPRSS2
# AT2_age_TMPRSS2_F_NS                                TMPRSS2
# AT2_age_TMPRSS2_F_S                                 TMPRSS2
# AT2_age_TMPRSS2_M_NS                                TMPRSS2
# AT2_sex[T.male]_ACE2_62yr_S                            ACE2
# AT2_sex[T.male]_ACE2_31yr_NS                           ACE2
# AT2_sex[T.male]_ACE2_62yr_NS                           ACE2
# AT2_sex[T.male]_ACE2_31yr_S                            ACE2
# AT2_sex[T.male]_CTSL_31yr_NS                           CTSL
# AT2_sex[T.male]_CTSL_31yr_S                            CTSL
# AT2_sex[T.male]_CTSL_62yr_NS                           CTSL
# AT2_sex[T.male]_CTSL_62yr_S                            CTSL
# AT2_sex[T.male]_TMPRSS2_31yr_S                      TMPRSS2
# AT2_sex[T.male]_TMPRSS2_62yr_NS                     TMPRSS2
# AT2_sex[T.male]_TMPRSS2_62yr_S                      TMPRSS2
# AT2_sex[T.male]_TMPRSS2_31yr_NS                     TMPRSS2
# AT2_smoking_status[T.True]_ACE2_F_31yr                 ACE2
# AT2_smoking_status[T.True]_ACE2_F_62yr                 ACE2
# AT2_smoking_status[T.True]_ACE2_M_31yr                 ACE2
# AT2_smoking_status[T.True]_ACE2_M_62yr                 ACE2
# AT2_smoking_status[T.True]_CTSL_M_62yr                 CTSL
# AT2_smoking_status[T.True]_CTSL_M_31yr                 CTSL
# AT2_smoking_status[T.True]_CTSL_F_62yr                 CTSL
# AT2_smoking_status[T.True]_CTSL_F_31yr                 CTSL
# AT2_smoking_status[T.True]_TMPRSS2_M_62yr           TMPRSS2
# AT2_smoking_status[T.True]_TMPRSS2_M_31yr           TMPRSS2
# AT2_smoking_status[T.True]_TMPRSS2_F_62yr           TMPRSS2
# AT2_smoking_status[T.True]_TMPRSS2_F_31yr           TMPRSS2
# Arterial_age_CTSL_F_NS                                 CTSL
# Arterial_age_CTSL_F_S                                  CTSL
# Arterial_age_CTSL_M_S                                  CTSL
# Arterial_age_CTSL_M_NS                                 CTSL
# Arterial_sex[T.male]_CTSL_31yr_NS                      CTSL
# Arterial_sex[T.male]_CTSL_31yr_S                       CTSL
# Arterial_sex[T.male]_CTSL_62yr_NS                      CTSL
# Arterial_sex[T.male]_CTSL_62yr_S                       CTSL
# Arterial_smoking_status[T.True]_CTSL_F_31yr            CTSL
# Arterial_smoking_status[T.True]_CTSL_F_62yr            CTSL
# Arterial_smoking_status[T.True]_CTSL_M_62yr            CTSL
# Arterial_smoking_status[T.True]_CTSL_M_31yr            CTSL
# Capillary_age_CTSL_M_S                                 CTSL
# Capillary_age_CTSL_M_NS                                CTSL
# Capillary_age_CTSL_F_S                                 CTSL
# Capillary_age_CTSL_F_NS                                CTSL
# Capillary_age_TMPRSS2_M_S                           TMPRSS2
# Capillary_age_TMPRSS2_F_NS                          TMPRSS2
# Capillary_age_TMPRSS2_F_S                           TMPRSS2
# Capillary_age_TMPRSS2_M_NS                          TMPRSS2
# Capillary_sex[T.male]_CTSL_62yr_S                      CTSL
# Capillary_sex[T.male]_CTSL_62yr_NS                     CTSL
# Capillary_sex[T.male]_CTSL_31yr_S                      CTSL
# Capillary_sex[T.male]_CTSL_31yr_NS                     CTSL
# Capillary_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2
# Capillary_smoking_status[T.True]_CTSL_M_31yr           CTSL
# Capillary_smoking_status[T.True]_CTSL_F_62yr           CTSL
# Capillary_smoking_status[T.True]_CTSL_F_31yr           CTSL
# Capillary_smoking_status[T.True]_CTSL_M_62yr           CTSL
# Capillary_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2
# Capillary_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2
# Capillary_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2
# Capillary_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2
# Venous_age_CTSL_F_NS                                   CTSL
# Venous_age_CTSL_F_S                                    CTSL
# Venous_age_CTSL_M_NS                                   CTSL
# Venous_age_CTSL_M_S                                    CTSL
# Venous_age_TMPRSS2_M_S                              TMPRSS2
# Venous_age_TMPRSS2_M_NS                             TMPRSS2
# Venous_age_TMPRSS2_F_S                              TMPRSS2
# Venous_age_TMPRSS2_F_NS                             TMPRSS2
# Venous_sex[T.male]_CTSL_31yr_NS                        CTSL
# Venous_sex[T.male]_CTSL_31yr_S                         CTSL
# Venous_sex[T.male]_CTSL_62yr_NS                        CTSL
# Venous_sex[T.male]_CTSL_62yr_S                         CTSL
# Venous_sex[T.male]_TMPRSS2_31yr_NS                  TMPRSS2
# Venous_sex[T.male]_TMPRSS2_31yr_S                   TMPRSS2
# Venous_sex[T.male]_TMPRSS2_62yr_NS                  TMPRSS2
# Venous_sex[T.male]_TMPRSS2_62yr_S                   TMPRSS2
# Venous_smoking_status[T.True]_CTSL_F_31yr              CTSL
# Venous_smoking_status[T.True]_CTSL_F_62yr              CTSL
# Venous_smoking_status[T.True]_CTSL_M_62yr              CTSL
# Venous_smoking_status[T.True]_CTSL_M_31yr              CTSL
# Venous_smoking_status[T.True]_TMPRSS2_M_62yr        TMPRSS2
# Venous_smoking_status[T.True]_TMPRSS2_F_62yr        TMPRSS2
# Venous_smoking_status[T.True]_TMPRSS2_F_31yr        TMPRSS2
# Venous_smoking_status[T.True]_TMPRSS2_M_31yr        TMPRSS2
# Lymphatic_EC_age_CTSL_M_NS                             CTSL
# Lymphatic_EC_age_CTSL_M_S                              CTSL
# Lymphatic_EC_age_CTSL_F_NS                             CTSL
# Lymphatic_EC_age_CTSL_F_S                              CTSL
# Lymphatic_EC_age_TMPRSS2_M_S                        TMPRSS2
# Lymphatic_EC_age_TMPRSS2_M_NS                       TMPRSS2
# Lymphatic_EC_age_TMPRSS2_F_S                        TMPRSS2
# Lymphatic_EC_age_TMPRSS2_F_NS                       TMPRSS2
# Lymphatic_EC_sex[T.male]_CTSL_31yr_NS                  CTSL
# Lymphatic_EC_sex[T.male]_CTSL_31yr_S                   CTSL
# Lymphatic_EC_sex[T.male]_CTSL_62yr_NS                  CTSL
# Lymphatic_EC_sex[T.male]_CTSL_62yr_S                   CTSL
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr_S             TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr_NS            TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_31yr_S             TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_31yr_NS            TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_CTSL_F_62yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_CTSL_M_62yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_CTSL_M_31yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_CTSL_F_31yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_M_62yr  TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_M_31yr  TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_F_62yr  TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_F_31yr  TMPRSS2
# Fibroblasts_age_ACE2_M_S                               ACE2
# Fibroblasts_age_ACE2_M_NS                              ACE2
# Fibroblasts_age_ACE2_F_S                               ACE2
# Fibroblasts_age_ACE2_F_NS                              ACE2
# Fibroblasts_age_CTSL_F_NS                              CTSL
# Fibroblasts_age_CTSL_F_S                               CTSL
# Fibroblasts_age_CTSL_M_S                               CTSL
# Fibroblasts_age_CTSL_M_NS                              CTSL
# Fibroblasts_age_TMPRSS2_F_S                         TMPRSS2
# Fibroblasts_age_TMPRSS2_M_S                         TMPRSS2
# Fibroblasts_age_TMPRSS2_M_NS                        TMPRSS2
# Fibroblasts_age_TMPRSS2_F_NS                        TMPRSS2
# Fibroblasts_sex[T.male]_ACE2_62yr_S                    ACE2
# Fibroblasts_sex[T.male]_ACE2_62yr_NS                   ACE2
# Fibroblasts_sex[T.male]_ACE2_31yr_S                    ACE2
# Fibroblasts_sex[T.male]_ACE2_31yr_NS                   ACE2
# Fibroblasts_sex[T.male]_CTSL_31yr_NS                   CTSL
# Fibroblasts_sex[T.male]_CTSL_62yr_NS                   CTSL
# Fibroblasts_sex[T.male]_CTSL_62yr_S                    CTSL
# Fibroblasts_sex[T.male]_CTSL_31yr_S                    CTSL
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2
# Fibroblasts_smoking_status[T.True]_ACE2_M_62yr         ACE2
# Fibroblasts_smoking_status[T.True]_ACE2_M_31yr         ACE2
# Fibroblasts_smoking_status[T.True]_ACE2_F_62yr         ACE2
# Fibroblasts_smoking_status[T.True]_ACE2_F_31yr         ACE2
# Fibroblasts_smoking_status[T.True]_CTSL_F_31yr         CTSL
# Fibroblasts_smoking_status[T.True]_CTSL_F_62yr         CTSL
# Fibroblasts_smoking_status[T.True]_CTSL_M_31yr         CTSL
# Fibroblasts_smoking_status[T.True]_CTSL_M_62yr         CTSL
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2
# Airway_smooth_muscle_age_CTSL_M_S                      CTSL
# Airway_smooth_muscle_age_CTSL_M_NS                     CTSL
# Airway_smooth_muscle_age_CTSL_F_S                      CTSL
# Airway_smooth_muscle_age_CTSL_F_NS                     CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_S           CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_NS          CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_S           CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_NS          CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# B_cell_lineage_age_CTSL_F_S                            CTSL
# B_cell_lineage_age_CTSL_M_NS                           CTSL
# B_cell_lineage_age_CTSL_M_S                            CTSL
# B_cell_lineage_age_CTSL_F_NS                           CTSL
# B_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2
# B_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2
# B_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2
# B_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2
# B_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL
# B_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL
# B_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL
# B_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2
# B_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL
# B_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL
# B_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL
# B_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# T_cell_lineage_age_ACE2_F_NS                           ACE2
# T_cell_lineage_age_ACE2_F_S                            ACE2
# T_cell_lineage_age_ACE2_M_NS                           ACE2
# T_cell_lineage_age_ACE2_M_S                            ACE2
# T_cell_lineage_age_CTSL_F_S                            CTSL
# T_cell_lineage_age_CTSL_M_NS                           CTSL
# T_cell_lineage_age_CTSL_M_S                            CTSL
# T_cell_lineage_age_CTSL_F_NS                           CTSL
# T_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2
# T_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2
# T_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2
# T_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2
# T_cell_lineage_sex[T.male]_ACE2_62yr_S                 ACE2
# T_cell_lineage_sex[T.male]_ACE2_62yr_NS                ACE2
# T_cell_lineage_sex[T.male]_ACE2_31yr_S                 ACE2
# T_cell_lineage_sex[T.male]_ACE2_31yr_NS                ACE2
# T_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL
# T_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL
# T_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL
# T_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2
# T_cell_lineage_smoking_status[T.True]_ACE2_F_62yr      ACE2
# T_cell_lineage_smoking_status[T.True]_ACE2_F_31yr      ACE2
# T_cell_lineage_smoking_status[T.True]_ACE2_M_62yr      ACE2
# T_cell_lineage_smoking_status[T.True]_ACE2_M_31yr      ACE2
# T_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL
# T_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL
# T_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL
# T_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# Innate_lymphoid_cells_age_CTSL_M_S                     CTSL
# Innate_lymphoid_cells_age_CTSL_M_NS                    CTSL
# Innate_lymphoid_cells_age_CTSL_F_S                     CTSL
# Innate_lymphoid_cells_age_CTSL_F_NS                    CTSL
# Innate_lymphoid_cells_age_TMPRSS2_F_S               TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_F_NS              TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_M_NS              TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_M_S               TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_S          CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_NS         CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_S          CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_NS         CTSL
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_NS   TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_S    TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_NS   TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_S    TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Dendritic_cells_age_CTSL_M_NS                          CTSL
# Dendritic_cells_age_CTSL_M_S                           CTSL
# Dendritic_cells_age_CTSL_F_NS                          CTSL
# Dendritic_cells_age_CTSL_F_S                           CTSL
# Dendritic_cells_age_TMPRSS2_F_S                     TMPRSS2
# Dendritic_cells_age_TMPRSS2_M_NS                    TMPRSS2
# Dendritic_cells_age_TMPRSS2_M_S                     TMPRSS2
# Dendritic_cells_age_TMPRSS2_F_NS                    TMPRSS2
# Dendritic_cells_sex[T.male]_CTSL_31yr_NS               CTSL
# Dendritic_cells_sex[T.male]_CTSL_31yr_S                CTSL
# Dendritic_cells_sex[T.male]_CTSL_62yr_NS               CTSL
# Dendritic_cells_sex[T.male]_CTSL_62yr_S                CTSL
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_NS         TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_S          TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_NS         TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_S          TMPRSS2
# Dendritic_cells_smoking_status[T.True]_CTSL_M_62yr     CTSL
# Dendritic_cells_smoking_status[T.True]_CTSL_M_31yr     CTSL
# Dendritic_cells_smoking_status[T.True]_CTSL_F_62yr     CTSL
# Dendritic_cells_smoking_status[T.True]_CTSL_F_31yr     CTSL
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Macrophages_age_ACE2_F_NS                              ACE2
# Macrophages_age_ACE2_F_S                               ACE2
# Macrophages_age_ACE2_M_S                               ACE2
# Macrophages_age_ACE2_M_NS                              ACE2
# Macrophages_age_CTSL_M_S                               CTSL
# Macrophages_age_CTSL_M_NS                              CTSL
# Macrophages_age_CTSL_F_NS                              CTSL
# Macrophages_age_CTSL_F_S                               CTSL
# Macrophages_age_TMPRSS2_F_NS                        TMPRSS2
# Macrophages_age_TMPRSS2_F_S                         TMPRSS2
# Macrophages_age_TMPRSS2_M_NS                        TMPRSS2
# Macrophages_age_TMPRSS2_M_S                         TMPRSS2
# Macrophages_sex[T.male]_ACE2_31yr_NS                   ACE2
# Macrophages_sex[T.male]_ACE2_31yr_S                    ACE2
# Macrophages_sex[T.male]_ACE2_62yr_NS                   ACE2
# Macrophages_sex[T.male]_ACE2_62yr_S                    ACE2
# Macrophages_sex[T.male]_CTSL_62yr_S                    CTSL
# Macrophages_sex[T.male]_CTSL_62yr_NS                   CTSL
# Macrophages_sex[T.male]_CTSL_31yr_S                    CTSL
# Macrophages_sex[T.male]_CTSL_31yr_NS                   CTSL
# Macrophages_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2
# Macrophages_smoking_status[T.True]_ACE2_F_31yr         ACE2
# Macrophages_smoking_status[T.True]_ACE2_F_62yr         ACE2
# Macrophages_smoking_status[T.True]_ACE2_M_31yr         ACE2
# Macrophages_smoking_status[T.True]_ACE2_M_62yr         ACE2
# Macrophages_smoking_status[T.True]_CTSL_M_62yr         CTSL
# Macrophages_smoking_status[T.True]_CTSL_M_31yr         CTSL
# Macrophages_smoking_status[T.True]_CTSL_F_62yr         CTSL
# Macrophages_smoking_status[T.True]_CTSL_F_31yr         CTSL
# Macrophages_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2
# Macrophages_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2
# Macrophages_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2
# Macrophages_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2
# Monocytes_age_ACE2_M_S                                 ACE2
# Monocytes_age_ACE2_M_NS                                ACE2
# Monocytes_age_ACE2_F_S                                 ACE2
# Monocytes_age_ACE2_F_NS                                ACE2
# Monocytes_age_CTSL_M_S                                 CTSL
# Monocytes_age_CTSL_M_NS                                CTSL
# Monocytes_age_CTSL_F_S                                 CTSL
# Monocytes_age_CTSL_F_NS                                CTSL
# Monocytes_age_TMPRSS2_F_NS                          TMPRSS2
# Monocytes_age_TMPRSS2_M_NS                          TMPRSS2
# Monocytes_age_TMPRSS2_M_S                           TMPRSS2
# Monocytes_age_TMPRSS2_F_S                           TMPRSS2
# Monocytes_sex[T.male]_ACE2_31yr_NS                     ACE2
# Monocytes_sex[T.male]_ACE2_62yr_S                      ACE2
# Monocytes_sex[T.male]_ACE2_62yr_NS                     ACE2
# Monocytes_sex[T.male]_ACE2_31yr_S                      ACE2
# Monocytes_sex[T.male]_CTSL_62yr_S                      CTSL
# Monocytes_sex[T.male]_CTSL_62yr_NS                     CTSL
# Monocytes_sex[T.male]_CTSL_31yr_S                      CTSL
# Monocytes_sex[T.male]_CTSL_31yr_NS                     CTSL
# Monocytes_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2
# Monocytes_smoking_status[T.True]_ACE2_F_31yr           ACE2
# Monocytes_smoking_status[T.True]_ACE2_F_62yr           ACE2
# Monocytes_smoking_status[T.True]_ACE2_M_31yr           ACE2
# Monocytes_smoking_status[T.True]_ACE2_M_62yr           ACE2
# Monocytes_smoking_status[T.True]_CTSL_M_31yr           CTSL
# Monocytes_smoking_status[T.True]_CTSL_F_62yr           CTSL
# Monocytes_smoking_status[T.True]_CTSL_F_31yr           CTSL
# Monocytes_smoking_status[T.True]_CTSL_M_62yr           CTSL
# Monocytes_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2
# Monocytes_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2
# Monocytes_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2
# Monocytes_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2
# Mast_cells_age_CTSL_M_S                                CTSL
# Mast_cells_age_CTSL_M_NS                               CTSL
# Mast_cells_age_CTSL_F_S                                CTSL
# Mast_cells_age_CTSL_F_NS                               CTSL
# Mast_cells_age_TMPRSS2_M_NS                         TMPRSS2
# Mast_cells_age_TMPRSS2_M_S                          TMPRSS2
# Mast_cells_age_TMPRSS2_F_S                          TMPRSS2
# Mast_cells_age_TMPRSS2_F_NS                         TMPRSS2
# Mast_cells_sex[T.male]_CTSL_31yr_NS                    CTSL
# Mast_cells_sex[T.male]_CTSL_62yr_S                     CTSL
# Mast_cells_sex[T.male]_CTSL_62yr_NS                    CTSL
# Mast_cells_sex[T.male]_CTSL_31yr_S                     CTSL
# Mast_cells_sex[T.male]_TMPRSS2_62yr_S               TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_62yr_NS              TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_31yr_S               TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_31yr_NS              TMPRSS2
# Mast_cells_smoking_status[T.True]_CTSL_F_62yr          CTSL
# Mast_cells_smoking_status[T.True]_CTSL_F_31yr          CTSL
# Mast_cells_smoking_status[T.True]_CTSL_M_62yr          CTSL
# Mast_cells_smoking_status[T.True]_CTSL_M_31yr          CTSL
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_62yr    TMPRSS2
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_62yr    TMPRSS2
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_31yr    TMPRSS2
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_31yr    TMPRSS2
#
#                                                             cell_identity  \
# Basal_age_ACE2_M_NS                                                 Basal
# Basal_age_ACE2_F_S                                                  Basal
# Basal_age_ACE2_F_NS                                                 Basal
# Basal_age_ACE2_M_S                                                  Basal
# Basal_age_CTSL_M_S                                                  Basal
# Basal_age_CTSL_M_NS                                                 Basal
# Basal_age_CTSL_F_S                                                  Basal
# Basal_age_CTSL_F_NS                                                 Basal
# Basal_age_TMPRSS2_F_NS                                              Basal
# Basal_age_TMPRSS2_M_NS                                              Basal
# Basal_age_TMPRSS2_F_S                                               Basal
# Basal_age_TMPRSS2_M_S                                               Basal
# Basal_sex[T.male]_ACE2_62yr_S                                       Basal
# Basal_sex[T.male]_ACE2_62yr_NS                                      Basal
# Basal_sex[T.male]_ACE2_31yr_S                                       Basal
# Basal_sex[T.male]_ACE2_31yr_NS                                      Basal
# Basal_sex[T.male]_CTSL_62yr_S                                       Basal
# Basal_sex[T.male]_CTSL_62yr_NS                                      Basal
# Basal_sex[T.male]_CTSL_31yr_NS                                      Basal
# Basal_sex[T.male]_CTSL_31yr_S                                       Basal
# Basal_sex[T.male]_TMPRSS2_62yr_NS                                   Basal
# Basal_sex[T.male]_TMPRSS2_31yr_S                                    Basal
# Basal_sex[T.male]_TMPRSS2_31yr_NS                                   Basal
# Basal_sex[T.male]_TMPRSS2_62yr_S                                    Basal
# Basal_smoking_status[T.True]_ACE2_M_62yr                            Basal
# Basal_smoking_status[T.True]_ACE2_M_31yr                            Basal
# Basal_smoking_status[T.True]_ACE2_F_62yr                            Basal
# Basal_smoking_status[T.True]_ACE2_F_31yr                            Basal
# Basal_smoking_status[T.True]_CTSL_M_62yr                            Basal
# Basal_smoking_status[T.True]_CTSL_F_31yr                            Basal
# Basal_smoking_status[T.True]_CTSL_F_62yr                            Basal
# Basal_smoking_status[T.True]_CTSL_M_31yr                            Basal
# Basal_smoking_status[T.True]_TMPRSS2_M_62yr                         Basal
# Basal_smoking_status[T.True]_TMPRSS2_M_31yr                         Basal
# Basal_smoking_status[T.True]_TMPRSS2_F_62yr                         Basal
# Basal_smoking_status[T.True]_TMPRSS2_F_31yr                         Basal
# Multiciliated_lineage_age_ACE2_M_S                  Multiciliated lineage
# Multiciliated_lineage_age_ACE2_M_NS                 Multiciliated lineage
# Multiciliated_lineage_age_ACE2_F_S                  Multiciliated lineage
# Multiciliated_lineage_age_ACE2_F_NS                 Multiciliated lineage
# Multiciliated_lineage_age_CTSL_M_S                  Multiciliated lineage
# Multiciliated_lineage_age_CTSL_M_NS                 Multiciliated lineage
# Multiciliated_lineage_age_CTSL_F_S                  Multiciliated lineage
# Multiciliated_lineage_age_CTSL_F_NS                 Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_F_NS              Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_F_S               Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_M_NS              Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_M_S               Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_S    Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_NS   Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_S    Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_NS   Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Secretory_age_ACE2_F_NS                                         Secretory
# Secretory_age_ACE2_F_S                                          Secretory
# Secretory_age_ACE2_M_NS                                         Secretory
# Secretory_age_ACE2_M_S                                          Secretory
# Secretory_age_CTSL_F_NS                                         Secretory
# Secretory_age_CTSL_F_S                                          Secretory
# Secretory_age_CTSL_M_NS                                         Secretory
# Secretory_age_CTSL_M_S                                          Secretory
# Secretory_age_TMPRSS2_F_NS                                      Secretory
# Secretory_age_TMPRSS2_F_S                                       Secretory
# Secretory_age_TMPRSS2_M_NS                                      Secretory
# Secretory_age_TMPRSS2_M_S                                       Secretory
# Secretory_sex[T.male]_ACE2_62yr_S                               Secretory
# Secretory_sex[T.male]_ACE2_62yr_NS                              Secretory
# Secretory_sex[T.male]_ACE2_31yr_S                               Secretory
# Secretory_sex[T.male]_ACE2_31yr_NS                              Secretory
# Secretory_sex[T.male]_CTSL_31yr_S                               Secretory
# Secretory_sex[T.male]_CTSL_62yr_NS                              Secretory
# Secretory_sex[T.male]_CTSL_62yr_S                               Secretory
# Secretory_sex[T.male]_CTSL_31yr_NS                              Secretory
# Secretory_sex[T.male]_TMPRSS2_62yr_S                            Secretory
# Secretory_sex[T.male]_TMPRSS2_62yr_NS                           Secretory
# Secretory_sex[T.male]_TMPRSS2_31yr_S                            Secretory
# Secretory_sex[T.male]_TMPRSS2_31yr_NS                           Secretory
# Secretory_smoking_status[T.True]_ACE2_F_31yr                    Secretory
# Secretory_smoking_status[T.True]_ACE2_M_62yr                    Secretory
# Secretory_smoking_status[T.True]_ACE2_M_31yr                    Secretory
# Secretory_smoking_status[T.True]_ACE2_F_62yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_F_31yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_F_62yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_M_31yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_M_62yr                    Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_F_62yr                 Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_M_31yr                 Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_F_31yr                 Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_M_62yr                 Secretory
# Rare_age_ACE2_F_NS                                                   Rare
# Rare_age_ACE2_F_S                                                    Rare
# Rare_age_ACE2_M_NS                                                   Rare
# Rare_age_ACE2_M_S                                                    Rare
# Rare_age_CTSL_F_S                                                    Rare
# Rare_age_CTSL_F_NS                                                   Rare
# Rare_age_CTSL_M_NS                                                   Rare
# Rare_age_CTSL_M_S                                                    Rare
# Rare_age_TMPRSS2_M_S                                                 Rare
# Rare_age_TMPRSS2_M_NS                                                Rare
# Rare_age_TMPRSS2_F_NS                                                Rare
# Rare_age_TMPRSS2_F_S                                                 Rare
# Rare_sex[T.male]_ACE2_62yr_S                                         Rare
# Rare_sex[T.male]_ACE2_62yr_NS                                        Rare
# Rare_sex[T.male]_ACE2_31yr_NS                                        Rare
# Rare_sex[T.male]_ACE2_31yr_S                                         Rare
# Rare_sex[T.male]_CTSL_31yr_NS                                        Rare
# Rare_sex[T.male]_CTSL_31yr_S                                         Rare
# Rare_sex[T.male]_CTSL_62yr_NS                                        Rare
# Rare_sex[T.male]_CTSL_62yr_S                                         Rare
# Rare_sex[T.male]_TMPRSS2_31yr_NS                                     Rare
# Rare_sex[T.male]_TMPRSS2_62yr_NS                                     Rare
# Rare_sex[T.male]_TMPRSS2_62yr_S                                      Rare
# Rare_sex[T.male]_TMPRSS2_31yr_S                                      Rare
# Rare_smoking_status[T.True]_ACE2_F_31yr                              Rare
# Rare_smoking_status[T.True]_ACE2_F_62yr                              Rare
# Rare_smoking_status[T.True]_ACE2_M_31yr                              Rare
# Rare_smoking_status[T.True]_ACE2_M_62yr                              Rare
# Rare_smoking_status[T.True]_CTSL_F_31yr                              Rare
# Rare_smoking_status[T.True]_CTSL_F_62yr                              Rare
# Rare_smoking_status[T.True]_CTSL_M_31yr                              Rare
# Rare_smoking_status[T.True]_CTSL_M_62yr                              Rare
# ...
# Fibroblasts_age_ACE2_F_S                               ACE2 2
# Fibroblasts_age_ACE2_F_NS                              ACE2 0
# Fibroblasts_age_CTSL_F_NS                              CTSL 0
# Fibroblasts_age_CTSL_F_S                               CTSL 2
# Fibroblasts_age_CTSL_M_S                               CTSL 3
# Fibroblasts_age_CTSL_M_NS                              CTSL 1
# Fibroblasts_age_TMPRSS2_F_S                         TMPRSS2 2
# Fibroblasts_age_TMPRSS2_M_S                         TMPRSS2 3
# Fibroblasts_age_TMPRSS2_M_NS                        TMPRSS2 1
# Fibroblasts_age_TMPRSS2_F_NS                        TMPRSS2 0
# Fibroblasts_sex[T.male]_ACE2_62yr_S                    ACE2 3
# Fibroblasts_sex[T.male]_ACE2_62yr_NS                   ACE2 2
# Fibroblasts_sex[T.male]_ACE2_31yr_S                    ACE2 1
# Fibroblasts_sex[T.male]_ACE2_31yr_NS                   ACE2 0
# Fibroblasts_sex[T.male]_CTSL_31yr_NS                   CTSL 0
# Fibroblasts_sex[T.male]_CTSL_62yr_NS                   CTSL 2
# Fibroblasts_sex[T.male]_CTSL_62yr_S                    CTSL 3
# Fibroblasts_sex[T.male]_CTSL_31yr_S                    CTSL 1
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2 2
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2 3
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2 0
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2 1
# Fibroblasts_smoking_status[T.True]_ACE2_M_62yr         ACE2 3
# Fibroblasts_smoking_status[T.True]_ACE2_M_31yr         ACE2 1
# Fibroblasts_smoking_status[T.True]_ACE2_F_62yr         ACE2 2
# Fibroblasts_smoking_status[T.True]_ACE2_F_31yr         ACE2 0
# Fibroblasts_smoking_status[T.True]_CTSL_F_31yr         CTSL 0
# Fibroblasts_smoking_status[T.True]_CTSL_F_62yr         CTSL 2
# Fibroblasts_smoking_status[T.True]_CTSL_M_31yr         CTSL 1
# Fibroblasts_smoking_status[T.True]_CTSL_M_62yr         CTSL 3
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2 2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2 0
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2 3
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2 1
# Airway_smooth_muscle_age_CTSL_M_S                      CTSL 3
# Airway_smooth_muscle_age_CTSL_M_NS                     CTSL 1
# Airway_smooth_muscle_age_CTSL_F_S                      CTSL 2
# Airway_smooth_muscle_age_CTSL_F_NS                     CTSL 0
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_S           CTSL 3
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_NS          CTSL 2
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_S           CTSL 1
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_NS          CTSL 0
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 2
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 0
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 1
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 3
# B_cell_lineage_age_CTSL_F_S                            CTSL 2
# B_cell_lineage_age_CTSL_M_NS                           CTSL 1
# B_cell_lineage_age_CTSL_M_S                            CTSL 3
# B_cell_lineage_age_CTSL_F_NS                           CTSL 0
# B_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2 3
# B_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2 1
# B_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2 0
# B_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2 2
# B_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL 0
# B_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL 1
# B_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL 2
# B_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL 3
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2 3
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2 2
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2 1
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2 0
# B_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL 0
# B_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL 2
# B_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL 1
# B_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL 3
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 0
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 1
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 3
# T_cell_lineage_age_ACE2_F_NS                           ACE2 0
# T_cell_lineage_age_ACE2_F_S                            ACE2 2
# T_cell_lineage_age_ACE2_M_NS                           ACE2 1
# T_cell_lineage_age_ACE2_M_S                            ACE2 3
# T_cell_lineage_age_CTSL_F_S                            CTSL 2
# T_cell_lineage_age_CTSL_M_NS                           CTSL 1
# T_cell_lineage_age_CTSL_M_S                            CTSL 3
# T_cell_lineage_age_CTSL_F_NS                           CTSL 0
# T_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2 0
# T_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2 2
# T_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2 1
# T_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2 3
# T_cell_lineage_sex[T.male]_ACE2_62yr_S                 ACE2 3
# T_cell_lineage_sex[T.male]_ACE2_62yr_NS                ACE2 2
# T_cell_lineage_sex[T.male]_ACE2_31yr_S                 ACE2 1
# T_cell_lineage_sex[T.male]_ACE2_31yr_NS                ACE2 0
# T_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL 2
# T_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL 3
# T_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL 1
# T_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL 0
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2 0
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2 1
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2 2
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2 3
# T_cell_lineage_smoking_status[T.True]_ACE2_F_62yr      ACE2 2
# T_cell_lineage_smoking_status[T.True]_ACE2_F_31yr      ACE2 0
# T_cell_lineage_smoking_status[T.True]_ACE2_M_62yr      ACE2 3
# T_cell_lineage_smoking_status[T.True]_ACE2_M_31yr      ACE2 1
# T_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL 0
# T_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL 2
# T_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL 1
# T_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL 3
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 0
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 1
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 3
# Innate_lymphoid_cells_age_CTSL_M_S                     CTSL 3
# Innate_lymphoid_cells_age_CTSL_M_NS                    CTSL 1
# Innate_lymphoid_cells_age_CTSL_F_S                     CTSL 2
# Innate_lymphoid_cells_age_CTSL_F_NS                    CTSL 0
# Innate_lymphoid_cells_age_TMPRSS2_F_S               TMPRSS2 2
# Innate_lymphoid_cells_age_TMPRSS2_F_NS              TMPRSS2 0
# Innate_lymphoid_cells_age_TMPRSS2_M_NS              TMPRSS2 1
# Innate_lymphoid_cells_age_TMPRSS2_M_S               TMPRSS2 3
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_S          CTSL 3
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_NS         CTSL 2
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_S          CTSL 1
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_NS         CTSL 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_NS   TMPRSS2 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_S    TMPRSS2 1
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_NS   TMPRSS2 2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_S    TMPRSS2 3
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 3
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 2
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 0
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 1
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 1
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 0
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 3
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 2
# Dendritic_cells_age_CTSL_M_NS                          CTSL 1
# Dendritic_cells_age_CTSL_M_S                           CTSL 3
# Dendritic_cells_age_CTSL_F_NS                          CTSL 0
# Dendritic_cells_age_CTSL_F_S                           CTSL 2
# Dendritic_cells_age_TMPRSS2_F_S                     TMPRSS2 2
# Dendritic_cells_age_TMPRSS2_M_NS                    TMPRSS2 1
# Dendritic_cells_age_TMPRSS2_M_S                     TMPRSS2 3
# Dendritic_cells_age_TMPRSS2_F_NS                    TMPRSS2 0
# Dendritic_cells_sex[T.male]_CTSL_31yr_NS               CTSL 0
# Dendritic_cells_sex[T.male]_CTSL_31yr_S                CTSL 1
# Dendritic_cells_sex[T.male]_CTSL_62yr_NS               CTSL 2
# Dendritic_cells_sex[T.male]_CTSL_62yr_S                CTSL 3
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_NS         TMPRSS2 0
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_S          TMPRSS2 1
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_NS         TMPRSS2 2
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_S          TMPRSS2 3
# Dendritic_cells_smoking_status[T.True]_CTSL_M_62yr     CTSL 3
# Dendritic_cells_smoking_status[T.True]_CTSL_M_31yr     CTSL 1
# Dendritic_cells_smoking_status[T.True]_CTSL_F_62yr     CTSL 2
# Dendritic_cells_smoking_status[T.True]_CTSL_F_31yr     CTSL 0
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 0
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 1
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 3
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 2
# Macrophages_age_ACE2_F_NS                              ACE2 0
# Macrophages_age_ACE2_F_S                               ACE2 2
# Macrophages_age_ACE2_M_S                               ACE2 3
# Macrophages_age_ACE2_M_NS                              ACE2 1
# Macrophages_age_CTSL_M_S                               CTSL 3
# Macrophages_age_CTSL_M_NS                              CTSL 1
# Macrophages_age_CTSL_F_NS                              CTSL 0
# Macrophages_age_CTSL_F_S                               CTSL 2
# Macrophages_age_TMPRSS2_F_NS                        TMPRSS2 0
# Macrophages_age_TMPRSS2_F_S                         TMPRSS2 2
# Macrophages_age_TMPRSS2_M_NS                        TMPRSS2 1
# Macrophages_age_TMPRSS2_M_S                         TMPRSS2 3
# Macrophages_sex[T.male]_ACE2_31yr_NS                   ACE2 0
# Macrophages_sex[T.male]_ACE2_31yr_S                    ACE2 1
# Macrophages_sex[T.male]_ACE2_62yr_NS                   ACE2 2
# Macrophages_sex[T.male]_ACE2_62yr_S                    ACE2 3
# Macrophages_sex[T.male]_CTSL_62yr_S                    CTSL 3
# Macrophages_sex[T.male]_CTSL_62yr_NS                   CTSL 2
# Macrophages_sex[T.male]_CTSL_31yr_S                    CTSL 1
# Macrophages_sex[T.male]_CTSL_31yr_NS                   CTSL 0
# Macrophages_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2 0
# Macrophages_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2 1
# Macrophages_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2 2
# Macrophages_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2 3
# Macrophages_smoking_status[T.True]_ACE2_F_31yr         ACE2 0
# Macrophages_smoking_status[T.True]_ACE2_F_62yr         ACE2 2
# Macrophages_smoking_status[T.True]_ACE2_M_31yr         ACE2 1
# Macrophages_smoking_status[T.True]_ACE2_M_62yr         ACE2 3
# Macrophages_smoking_status[T.True]_CTSL_M_62yr         CTSL 3
# Macrophages_smoking_status[T.True]_CTSL_M_31yr         CTSL 1
# Macrophages_smoking_status[T.True]_CTSL_F_62yr         CTSL 2
# Macrophages_smoking_status[T.True]_CTSL_F_31yr         CTSL 0
# Macrophages_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2 3
# Macrophages_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2 1
# Macrophages_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2 2
# Macrophages_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2 0
# Monocytes_age_ACE2_M_S                                 ACE2 3
# Monocytes_age_ACE2_M_NS                                ACE2 1
# Monocytes_age_ACE2_F_S                                 ACE2 2
# Monocytes_age_ACE2_F_NS                                ACE2 0
# Monocytes_age_CTSL_M_S                                 CTSL 3
# Monocytes_age_CTSL_M_NS                                CTSL 1
# Monocytes_age_CTSL_F_S                                 CTSL 2
# Monocytes_age_CTSL_F_NS                                CTSL 0
# Monocytes_age_TMPRSS2_F_NS                          TMPRSS2 0
# Monocytes_age_TMPRSS2_M_NS                          TMPRSS2 1
# Monocytes_age_TMPRSS2_M_S                           TMPRSS2 3
# Monocytes_age_TMPRSS2_F_S                           TMPRSS2 2
# Monocytes_sex[T.male]_ACE2_31yr_NS                     ACE2 0
# Monocytes_sex[T.male]_ACE2_62yr_S                      ACE2 3
# Monocytes_sex[T.male]_ACE2_62yr_NS                     ACE2 2
# Monocytes_sex[T.male]_ACE2_31yr_S                      ACE2 1
# Monocytes_sex[T.male]_CTSL_62yr_S                      CTSL 3
# Monocytes_sex[T.male]_CTSL_62yr_NS                     CTSL 2
# Monocytes_sex[T.male]_CTSL_31yr_S                      CTSL 1
# Monocytes_sex[T.male]_CTSL_31yr_NS                     CTSL 0
# Monocytes_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2 0
# Monocytes_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2 2
# Monocytes_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2 3
# Monocytes_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2 1
# Monocytes_smoking_status[T.True]_ACE2_F_31yr           ACE2 0
# Monocytes_smoking_status[T.True]_ACE2_F_62yr           ACE2 2
# Monocytes_smoking_status[T.True]_ACE2_M_31yr           ACE2 1
# Monocytes_smoking_status[T.True]_ACE2_M_62yr           ACE2 3
# Monocytes_smoking_status[T.True]_CTSL_M_31yr           CTSL 1
# Monocytes_smoking_status[T.True]_CTSL_F_62yr           CTSL 2
# Monocytes_smoking_status[T.True]_CTSL_F_31yr           CTSL 0
# Monocytes_smoking_status[T.True]_CTSL_M_62yr           CTSL 3
# Monocytes_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2 1
# Monocytes_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2 3
# Monocytes_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2 0
# Monocytes_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2 2
# Mast_cells_age_CTSL_M_S                                CTSL 3
# Mast_cells_age_CTSL_M_NS                               CTSL 1
# Mast_cells_age_CTSL_F_S                                CTSL 2
# Mast_cells_age_CTSL_F_NS                               CTSL 0
# Mast_cells_age_TMPRSS2_M_NS                         TMPRSS2 1
# Mast_cells_age_TMPRSS2_M_S                          TMPRSS2 3
# Mast_cells_age_TMPRSS2_F_S                          TMPRSS2 2
# Mast_cells_age_TMPRSS2_F_NS                         TMPRSS2 0
# Mast_cells_sex[T.male]_CTSL_31yr_NS                    CTSL 0
# Mast_cells_sex[T.male]_CTSL_62yr_S                     CTSL 3
# Mast_cells_sex[T.male]_CTSL_62yr_NS                    CTSL 2
# Mast_cells_sex[T.male]_CTSL_31yr_S                     CTSL 1
# Mast_cells_sex[T.male]_TMPRSS2_62yr_S               TMPRSS2 3
# Mast_cells_sex[T.male]_TMPRSS2_62yr_NS              TMPRSS2 2
# Mast_cells_sex[T.male]_TMPRSS2_31yr_S               TMPRSS2 1
# Mast_cells_sex[T.male]_TMPRSS2_31yr_NS              TMPRSS2 0
# Mast_cells_smoking_status[T.True]_CTSL_F_62yr          CTSL 2
# Mast_cells_smoking_status[T.True]_CTSL_F_31yr          CTSL 0
# Mast_cells_smoking_status[T.True]_CTSL_M_62yr          CTSL 3
# Mast_cells_smoking_status[T.True]_CTSL_M_31yr          CTSL 1
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_62yr    TMPRSS2 3
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_62yr    TMPRSS2 2
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_31yr    TMPRSS2 0
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_31yr    TMPRSS2 1

# %%
def lighten_color(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    
    Thanks to: https://stackoverflow.com/questions/37765197/darken-or-lighten-a-color-in-matplotlib
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.2
for i in range(3):
    for alpha in range(4):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.2
for alpha in range(4):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(4)]

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(5.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(4)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-2.0, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(4)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [-0.7, -0.1], frameon=False, title=None)

#Smoking legend
smoking_labs = [j[0] for j in sorted(list(eval_encoding['smoking_status[T.True]'].items()), key=lambda i: i[1])]
smoking_handles = [patches.Patch(color=shades[i], label=smoking_labs[i]) for i in range(4)]
leg_smoking = plt.legend(handles=smoking_handles, bbox_to_anchor = [0.6, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[4], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[8], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)
plt.gca().add_artist(leg_smoking)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl3_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.2
for i in range(3):
    for alpha in range(4):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.2
for alpha in range(4):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(4)]

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

xlims_top = [[0.045, 1.15, 1.2],
             [0.061, 2.05, 3.7],
             [0.122, 2.19, 4.35],
             [0.142, 4.7, 2.8]]
xlims_bot = [[-0.031, -0.89, -1.25],
             [-0.065,-1.15, -6.35],
             [-0.14, -2.7, -1.5],
             [-0.095, -1.95, -3.3]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(5.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(4)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-2.0, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(4)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [-0.7, -0.1], frameon=False, title=None)

#Smoking legend
smoking_labs = [j[0] for j in sorted(list(eval_encoding['smoking_status[T.True]'].items()), key=lambda i: i[1])]
smoking_handles = [patches.Patch(color=shades[i], label=smoking_labs[i]) for i in range(4)]
leg_smoking = plt.legend(handles=smoking_handles, bbox_to_anchor = [0.6, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[4], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[8], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)
plt.gca().add_artist(leg_smoking)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl3_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# <ErrorbarContainer object of 3 artists>
# (-0.031, 0.045)
# <ErrorbarContainer object of 3 artists>
# (-0.89, 1.15)
# <ErrorbarContainer object of 3 artists>
# (-1.25, 1.2)
# <ErrorbarContainer object of 3 artists>
# (-0.065, 0.061)
# <ErrorbarContainer object of 3 artists>
# (-1.15, 2.05)
# <ErrorbarContainer object of 3 artists>
# (-6.35, 3.7)
# <ErrorbarContainer object of 3 artists>
# (-0.14, 0.122)
# <ErrorbarContainer object of 3 artists>
# (-2.7, 2.19)
# <ErrorbarContainer object of 3 artists>
# (-1.5, 4.35)
# <ErrorbarContainer object of 3 artists>
# (-0.095, 0.142)
# <ErrorbarContainer object of 3 artists>
# (-1.95, 4.7)
# <ErrorbarContainer object of 3 artists>
# (-3.3, 2.8)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])
# Out:
#                                                        gene  \
# Basal_age_ACE2_M_NS                                    ACE2
# Basal_age_ACE2_F_S                                     ACE2
# Basal_age_ACE2_F_NS                                    ACE2
# Basal_age_ACE2_M_S                                     ACE2
# Basal_age_CTSL_M_S                                     CTSL
# Basal_age_CTSL_M_NS                                    CTSL
# Basal_age_CTSL_F_S                                     CTSL
# Basal_age_CTSL_F_NS                                    CTSL
# Basal_age_TMPRSS2_F_NS                              TMPRSS2
# Basal_age_TMPRSS2_M_NS                              TMPRSS2
# Basal_age_TMPRSS2_F_S                               TMPRSS2
# Basal_age_TMPRSS2_M_S                               TMPRSS2
# Basal_sex[T.male]_ACE2_62yr_S                          ACE2
# Basal_sex[T.male]_ACE2_62yr_NS                         ACE2
# Basal_sex[T.male]_ACE2_31yr_S                          ACE2
# Basal_sex[T.male]_ACE2_31yr_NS                         ACE2
# Basal_sex[T.male]_CTSL_62yr_S                          CTSL
# Basal_sex[T.male]_CTSL_62yr_NS                         CTSL
# Basal_sex[T.male]_CTSL_31yr_NS                         CTSL
# Basal_sex[T.male]_CTSL_31yr_S                          CTSL
# Basal_sex[T.male]_TMPRSS2_62yr_NS                   TMPRSS2
# Basal_sex[T.male]_TMPRSS2_31yr_S                    TMPRSS2
# Basal_sex[T.male]_TMPRSS2_31yr_NS                   TMPRSS2
# Basal_sex[T.male]_TMPRSS2_62yr_S                    TMPRSS2
# Basal_smoking_status[T.True]_ACE2_M_62yr               ACE2
# Basal_smoking_status[T.True]_ACE2_M_31yr               ACE2
# Basal_smoking_status[T.True]_ACE2_F_62yr               ACE2
# Basal_smoking_status[T.True]_ACE2_F_31yr               ACE2
# Basal_smoking_status[T.True]_CTSL_M_62yr               CTSL
# Basal_smoking_status[T.True]_CTSL_F_31yr               CTSL
# Basal_smoking_status[T.True]_CTSL_F_62yr               CTSL
# Basal_smoking_status[T.True]_CTSL_M_31yr               CTSL
# Basal_smoking_status[T.True]_TMPRSS2_M_62yr         TMPRSS2
# Basal_smoking_status[T.True]_TMPRSS2_M_31yr         TMPRSS2
# Basal_smoking_status[T.True]_TMPRSS2_F_62yr         TMPRSS2
# Basal_smoking_status[T.True]_TMPRSS2_F_31yr         TMPRSS2
# Multiciliated_lineage_age_ACE2_M_S                     ACE2
# Multiciliated_lineage_age_ACE2_M_NS                    ACE2
# Multiciliated_lineage_age_ACE2_F_S                     ACE2
# Multiciliated_lineage_age_ACE2_F_NS                    ACE2
# Multiciliated_lineage_age_CTSL_M_S                     CTSL
# Multiciliated_lineage_age_CTSL_M_NS                    CTSL
# Multiciliated_lineage_age_CTSL_F_S                     CTSL
# Multiciliated_lineage_age_CTSL_F_NS                    CTSL
# Multiciliated_lineage_age_TMPRSS2_F_NS              TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_F_S               TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_M_NS              TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_M_S               TMPRSS2
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_S          ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_NS         ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_S          ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_NS         ACE2
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_NS         CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_S          CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_NS         CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_S          CTSL
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_S    TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_NS   TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_S    TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_NS   TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_AC...     ACE2
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_CT...     CTSL
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Secretory_age_ACE2_F_NS                                ACE2
# Secretory_age_ACE2_F_S                                 ACE2
# Secretory_age_ACE2_M_NS                                ACE2
# Secretory_age_ACE2_M_S                                 ACE2
# Secretory_age_CTSL_F_NS                                CTSL
# Secretory_age_CTSL_F_S                                 CTSL
# Secretory_age_CTSL_M_NS                                CTSL
# Secretory_age_CTSL_M_S                                 CTSL
# Secretory_age_TMPRSS2_F_NS                          TMPRSS2
# Secretory_age_TMPRSS2_F_S                           TMPRSS2
# Secretory_age_TMPRSS2_M_NS                          TMPRSS2
# Secretory_age_TMPRSS2_M_S                           TMPRSS2
# Secretory_sex[T.male]_ACE2_62yr_S                      ACE2
# Secretory_sex[T.male]_ACE2_62yr_NS                     ACE2
# Secretory_sex[T.male]_ACE2_31yr_S                      ACE2
# Secretory_sex[T.male]_ACE2_31yr_NS                     ACE2
# Secretory_sex[T.male]_CTSL_31yr_S                      CTSL
# Secretory_sex[T.male]_CTSL_62yr_NS                     CTSL
# Secretory_sex[T.male]_CTSL_62yr_S                      CTSL
# Secretory_sex[T.male]_CTSL_31yr_NS                     CTSL
# Secretory_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2
# Secretory_smoking_status[T.True]_ACE2_F_31yr           ACE2
# Secretory_smoking_status[T.True]_ACE2_M_62yr           ACE2
# Secretory_smoking_status[T.True]_ACE2_M_31yr           ACE2
# Secretory_smoking_status[T.True]_ACE2_F_62yr           ACE2
# Secretory_smoking_status[T.True]_CTSL_F_31yr           CTSL
# Secretory_smoking_status[T.True]_CTSL_F_62yr           CTSL
# Secretory_smoking_status[T.True]_CTSL_M_31yr           CTSL
# Secretory_smoking_status[T.True]_CTSL_M_62yr           CTSL
# Secretory_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2
# Secretory_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2
# Secretory_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2
# Secretory_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2
# Rare_age_ACE2_F_NS                                     ACE2
# Rare_age_ACE2_F_S                                      ACE2
# Rare_age_ACE2_M_NS                                     ACE2
# Rare_age_ACE2_M_S                                      ACE2
# Rare_age_CTSL_F_S                                      CTSL
# Rare_age_CTSL_F_NS                                     CTSL
# Rare_age_CTSL_M_NS                                     CTSL
# Rare_age_CTSL_M_S                                      CTSL
# Rare_age_TMPRSS2_M_S                                TMPRSS2
# Rare_age_TMPRSS2_M_NS                               TMPRSS2
# Rare_age_TMPRSS2_F_NS                               TMPRSS2
# Rare_age_TMPRSS2_F_S                                TMPRSS2
# Rare_sex[T.male]_ACE2_62yr_S                           ACE2
# Rare_sex[T.male]_ACE2_62yr_NS                          ACE2
# Rare_sex[T.male]_ACE2_31yr_NS                          ACE2
# Rare_sex[T.male]_ACE2_31yr_S                           ACE2
# Rare_sex[T.male]_CTSL_31yr_NS                          CTSL
# Rare_sex[T.male]_CTSL_31yr_S                           CTSL
# Rare_sex[T.male]_CTSL_62yr_NS                          CTSL
# Rare_sex[T.male]_CTSL_62yr_S                           CTSL
# Rare_sex[T.male]_TMPRSS2_31yr_NS                    TMPRSS2
# Rare_sex[T.male]_TMPRSS2_62yr_NS                    TMPRSS2
# Rare_sex[T.male]_TMPRSS2_62yr_S                     TMPRSS2
# Rare_sex[T.male]_TMPRSS2_31yr_S                     TMPRSS2
# Rare_smoking_status[T.True]_ACE2_F_31yr                ACE2
# Rare_smoking_status[T.True]_ACE2_F_62yr                ACE2
# Rare_smoking_status[T.True]_ACE2_M_31yr                ACE2
# Rare_smoking_status[T.True]_ACE2_M_62yr                ACE2
# Rare_smoking_status[T.True]_CTSL_F_31yr                CTSL
# Rare_smoking_status[T.True]_CTSL_F_62yr                CTSL
# Rare_smoking_status[T.True]_CTSL_M_31yr                CTSL
# Rare_smoking_status[T.True]_CTSL_M_62yr                CTSL
# Rare_smoking_status[T.True]_TMPRSS2_M_62yr          TMPRSS2
# Rare_smoking_status[T.True]_TMPRSS2_M_31yr          TMPRSS2
# Rare_smoking_status[T.True]_TMPRSS2_F_62yr          TMPRSS2
# Rare_smoking_status[T.True]_TMPRSS2_F_31yr          TMPRSS2
# Submucosal_Secretory_age_ACE2_F_NS                     ACE2
# Submucosal_Secretory_age_ACE2_M_NS                     ACE2
# Submucosal_Secretory_age_ACE2_M_S                      ACE2
# Submucosal_Secretory_age_ACE2_F_S                      ACE2
# Submucosal_Secretory_age_CTSL_F_NS                     CTSL
# Submucosal_Secretory_age_CTSL_F_S                      CTSL
# Submucosal_Secretory_age_CTSL_M_NS                     CTSL
# Submucosal_Secretory_age_CTSL_M_S                      CTSL
# Submucosal_Secretory_age_TMPRSS2_F_S                TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_M_NS               TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_F_NS               TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_M_S                TMPRSS2
# Submucosal_Secretory_sex[T.male]_ACE2_31yr_NS          ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_31yr_S           ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_62yr_NS          ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_62yr_S           ACE2
# Submucosal_Secretory_sex[T.male]_CTSL_31yr_NS          CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_31yr_S           CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_62yr_NS          CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_62yr_S           CTSL
# Submucosal_Secretory_sex[T.male]_TMPRSS2_31yr_NS    TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_31yr_S     TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr_NS    TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr_S     TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_ACE...     ACE2
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_CTS...     CTSL
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# AT1_age_ACE2_M_S                                       ACE2
# AT1_age_ACE2_M_NS                                      ACE2
# AT1_age_ACE2_F_NS                                      ACE2
# AT1_age_ACE2_F_S                                       ACE2
# AT1_age_CTSL_M_NS                                      CTSL
# AT1_age_CTSL_F_S                                       CTSL
# AT1_age_CTSL_F_NS                                      CTSL
# AT1_age_CTSL_M_S                                       CTSL
# AT1_age_TMPRSS2_F_NS                                TMPRSS2
# AT1_age_TMPRSS2_M_S                                 TMPRSS2
# AT1_age_TMPRSS2_M_NS                                TMPRSS2
# AT1_age_TMPRSS2_F_S                                 TMPRSS2
# AT1_sex[T.male]_ACE2_62yr_S                            ACE2
# AT1_sex[T.male]_ACE2_62yr_NS                           ACE2
# AT1_sex[T.male]_ACE2_31yr_S                            ACE2
# AT1_sex[T.male]_ACE2_31yr_NS                           ACE2
# AT1_sex[T.male]_CTSL_62yr_S                            CTSL
# AT1_sex[T.male]_CTSL_62yr_NS                           CTSL
# AT1_sex[T.male]_CTSL_31yr_S                            CTSL
# AT1_sex[T.male]_CTSL_31yr_NS                           CTSL
# AT1_sex[T.male]_TMPRSS2_31yr_NS                     TMPRSS2
# AT1_sex[T.male]_TMPRSS2_31yr_S                      TMPRSS2
# AT1_sex[T.male]_TMPRSS2_62yr_NS                     TMPRSS2
# AT1_sex[T.male]_TMPRSS2_62yr_S                      TMPRSS2
# AT1_smoking_status[T.True]_ACE2_M_62yr                 ACE2
# AT1_smoking_status[T.True]_ACE2_M_31yr                 ACE2
# AT1_smoking_status[T.True]_ACE2_F_62yr                 ACE2
# AT1_smoking_status[T.True]_ACE2_F_31yr                 ACE2
# AT1_smoking_status[T.True]_CTSL_M_31yr                 CTSL
# AT1_smoking_status[T.True]_CTSL_M_62yr                 CTSL
# AT1_smoking_status[T.True]_CTSL_F_62yr                 CTSL
# AT1_smoking_status[T.True]_CTSL_F_31yr                 CTSL
# AT1_smoking_status[T.True]_TMPRSS2_M_31yr           TMPRSS2
# AT1_smoking_status[T.True]_TMPRSS2_F_62yr           TMPRSS2
# AT1_smoking_status[T.True]_TMPRSS2_F_31yr           TMPRSS2
# AT1_smoking_status[T.True]_TMPRSS2_M_62yr           TMPRSS2
# AT2_age_ACE2_F_NS                                      ACE2
# AT2_age_ACE2_F_S                                       ACE2
# AT2_age_ACE2_M_NS                                      ACE2
# AT2_age_ACE2_M_S                                       ACE2
# AT2_age_CTSL_M_S                                       CTSL
# AT2_age_CTSL_M_NS                                      CTSL
# AT2_age_CTSL_F_S                                       CTSL
# AT2_age_CTSL_F_NS                                      CTSL
# AT2_age_TMPRSS2_M_S                                 TMPRSS2
# AT2_age_TMPRSS2_F_NS                                TMPRSS2
# AT2_age_TMPRSS2_F_S                                 TMPRSS2
# AT2_age_TMPRSS2_M_NS                                TMPRSS2
# AT2_sex[T.male]_ACE2_62yr_S                            ACE2
# AT2_sex[T.male]_ACE2_31yr_NS                           ACE2
# AT2_sex[T.male]_ACE2_62yr_NS                           ACE2
# AT2_sex[T.male]_ACE2_31yr_S                            ACE2
# AT2_sex[T.male]_CTSL_31yr_NS                           CTSL
# AT2_sex[T.male]_CTSL_31yr_S                            CTSL
# AT2_sex[T.male]_CTSL_62yr_NS                           CTSL
# AT2_sex[T.male]_CTSL_62yr_S                            CTSL
# AT2_sex[T.male]_TMPRSS2_31yr_S                      TMPRSS2
# AT2_sex[T.male]_TMPRSS2_62yr_NS                     TMPRSS2
# AT2_sex[T.male]_TMPRSS2_62yr_S                      TMPRSS2
# AT2_sex[T.male]_TMPRSS2_31yr_NS                     TMPRSS2
# AT2_smoking_status[T.True]_ACE2_F_31yr                 ACE2
# AT2_smoking_status[T.True]_ACE2_F_62yr                 ACE2
# AT2_smoking_status[T.True]_ACE2_M_31yr                 ACE2
# AT2_smoking_status[T.True]_ACE2_M_62yr                 ACE2
# AT2_smoking_status[T.True]_CTSL_M_62yr                 CTSL
# AT2_smoking_status[T.True]_CTSL_M_31yr                 CTSL
# AT2_smoking_status[T.True]_CTSL_F_62yr                 CTSL
# AT2_smoking_status[T.True]_CTSL_F_31yr                 CTSL
# AT2_smoking_status[T.True]_TMPRSS2_M_62yr           TMPRSS2
# AT2_smoking_status[T.True]_TMPRSS2_M_31yr           TMPRSS2
# AT2_smoking_status[T.True]_TMPRSS2_F_62yr           TMPRSS2
# AT2_smoking_status[T.True]_TMPRSS2_F_31yr           TMPRSS2
# Arterial_age_CTSL_F_NS                                 CTSL
# Arterial_age_CTSL_F_S                                  CTSL
# Arterial_age_CTSL_M_S                                  CTSL
# Arterial_age_CTSL_M_NS                                 CTSL
# Arterial_sex[T.male]_CTSL_31yr_NS                      CTSL
# Arterial_sex[T.male]_CTSL_31yr_S                       CTSL
# Arterial_sex[T.male]_CTSL_62yr_NS                      CTSL
# Arterial_sex[T.male]_CTSL_62yr_S                       CTSL
# Arterial_smoking_status[T.True]_CTSL_F_31yr            CTSL
# Arterial_smoking_status[T.True]_CTSL_F_62yr            CTSL
# Arterial_smoking_status[T.True]_CTSL_M_62yr            CTSL
# Arterial_smoking_status[T.True]_CTSL_M_31yr            CTSL
# Capillary_age_CTSL_M_S                                 CTSL
# Capillary_age_CTSL_M_NS                                CTSL
# Capillary_age_CTSL_F_S                                 CTSL
# Capillary_age_CTSL_F_NS                                CTSL
# Capillary_age_TMPRSS2_M_S                           TMPRSS2
# Capillary_age_TMPRSS2_F_NS                          TMPRSS2
# Capillary_age_TMPRSS2_F_S                           TMPRSS2
# Capillary_age_TMPRSS2_M_NS                          TMPRSS2
# Capillary_sex[T.male]_CTSL_62yr_S                      CTSL
# Capillary_sex[T.male]_CTSL_62yr_NS                     CTSL
# Capillary_sex[T.male]_CTSL_31yr_S                      CTSL
# Capillary_sex[T.male]_CTSL_31yr_NS                     CTSL
# Capillary_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2
# Capillary_smoking_status[T.True]_CTSL_M_31yr           CTSL
# Capillary_smoking_status[T.True]_CTSL_F_62yr           CTSL
# Capillary_smoking_status[T.True]_CTSL_F_31yr           CTSL
# Capillary_smoking_status[T.True]_CTSL_M_62yr           CTSL
# Capillary_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2
# Capillary_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2
# Capillary_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2
# Capillary_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2
# Venous_age_CTSL_F_NS                                   CTSL
# Venous_age_CTSL_F_S                                    CTSL
# Venous_age_CTSL_M_NS                                   CTSL
# Venous_age_CTSL_M_S                                    CTSL
# Venous_age_TMPRSS2_M_S                              TMPRSS2
# Venous_age_TMPRSS2_M_NS                             TMPRSS2
# Venous_age_TMPRSS2_F_S                              TMPRSS2
# Venous_age_TMPRSS2_F_NS                             TMPRSS2
# Venous_sex[T.male]_CTSL_31yr_NS                        CTSL
# Venous_sex[T.male]_CTSL_31yr_S                         CTSL
# Venous_sex[T.male]_CTSL_62yr_NS                        CTSL
# Venous_sex[T.male]_CTSL_62yr_S                         CTSL
# Venous_sex[T.male]_TMPRSS2_31yr_NS                  TMPRSS2
# Venous_sex[T.male]_TMPRSS2_31yr_S                   TMPRSS2
# Venous_sex[T.male]_TMPRSS2_62yr_NS                  TMPRSS2
# Venous_sex[T.male]_TMPRSS2_62yr_S                   TMPRSS2
# Venous_smoking_status[T.True]_CTSL_F_31yr              CTSL
# Venous_smoking_status[T.True]_CTSL_F_62yr              CTSL
# Venous_smoking_status[T.True]_CTSL_M_62yr              CTSL
# Venous_smoking_status[T.True]_CTSL_M_31yr              CTSL
# Venous_smoking_status[T.True]_TMPRSS2_M_62yr        TMPRSS2
# Venous_smoking_status[T.True]_TMPRSS2_F_62yr        TMPRSS2
# Venous_smoking_status[T.True]_TMPRSS2_F_31yr        TMPRSS2
# Venous_smoking_status[T.True]_TMPRSS2_M_31yr        TMPRSS2
# Lymphatic_EC_age_CTSL_M_NS                             CTSL
# Lymphatic_EC_age_CTSL_M_S                              CTSL
# Lymphatic_EC_age_CTSL_F_NS                             CTSL
# Lymphatic_EC_age_CTSL_F_S                              CTSL
# Lymphatic_EC_age_TMPRSS2_M_S                        TMPRSS2
# Lymphatic_EC_age_TMPRSS2_M_NS                       TMPRSS2
# Lymphatic_EC_age_TMPRSS2_F_S                        TMPRSS2
# Lymphatic_EC_age_TMPRSS2_F_NS                       TMPRSS2
# Lymphatic_EC_sex[T.male]_CTSL_31yr_NS                  CTSL
# Lymphatic_EC_sex[T.male]_CTSL_31yr_S                   CTSL
# Lymphatic_EC_sex[T.male]_CTSL_62yr_NS                  CTSL
# Lymphatic_EC_sex[T.male]_CTSL_62yr_S                   CTSL
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr_S             TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr_NS            TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_31yr_S             TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_31yr_NS            TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_CTSL_F_62yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_CTSL_M_62yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_CTSL_M_31yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_CTSL_F_31yr        CTSL
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_M_62yr  TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_M_31yr  TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_F_62yr  TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2_F_31yr  TMPRSS2
# Fibroblasts_age_ACE2_M_S                               ACE2
# Fibroblasts_age_ACE2_M_NS                              ACE2
# Fibroblasts_age_ACE2_F_S                               ACE2
# Fibroblasts_age_ACE2_F_NS                              ACE2
# Fibroblasts_age_CTSL_F_NS                              CTSL
# Fibroblasts_age_CTSL_F_S                               CTSL
# Fibroblasts_age_CTSL_M_S                               CTSL
# Fibroblasts_age_CTSL_M_NS                              CTSL
# Fibroblasts_age_TMPRSS2_F_S                         TMPRSS2
# Fibroblasts_age_TMPRSS2_M_S                         TMPRSS2
# Fibroblasts_age_TMPRSS2_M_NS                        TMPRSS2
# Fibroblasts_age_TMPRSS2_F_NS                        TMPRSS2
# Fibroblasts_sex[T.male]_ACE2_62yr_S                    ACE2
# Fibroblasts_sex[T.male]_ACE2_62yr_NS                   ACE2
# Fibroblasts_sex[T.male]_ACE2_31yr_S                    ACE2
# Fibroblasts_sex[T.male]_ACE2_31yr_NS                   ACE2
# Fibroblasts_sex[T.male]_CTSL_31yr_NS                   CTSL
# Fibroblasts_sex[T.male]_CTSL_62yr_NS                   CTSL
# Fibroblasts_sex[T.male]_CTSL_62yr_S                    CTSL
# Fibroblasts_sex[T.male]_CTSL_31yr_S                    CTSL
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2
# Fibroblasts_smoking_status[T.True]_ACE2_M_62yr         ACE2
# Fibroblasts_smoking_status[T.True]_ACE2_M_31yr         ACE2
# Fibroblasts_smoking_status[T.True]_ACE2_F_62yr         ACE2
# Fibroblasts_smoking_status[T.True]_ACE2_F_31yr         ACE2
# Fibroblasts_smoking_status[T.True]_CTSL_F_31yr         CTSL
# Fibroblasts_smoking_status[T.True]_CTSL_F_62yr         CTSL
# Fibroblasts_smoking_status[T.True]_CTSL_M_31yr         CTSL
# Fibroblasts_smoking_status[T.True]_CTSL_M_62yr         CTSL
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2
# Airway_smooth_muscle_age_CTSL_M_S                      CTSL
# Airway_smooth_muscle_age_CTSL_M_NS                     CTSL
# Airway_smooth_muscle_age_CTSL_F_S                      CTSL
# Airway_smooth_muscle_age_CTSL_F_NS                     CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_S           CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_NS          CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_S           CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_NS          CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL
# B_cell_lineage_age_CTSL_F_S                            CTSL
# B_cell_lineage_age_CTSL_M_NS                           CTSL
# B_cell_lineage_age_CTSL_M_S                            CTSL
# B_cell_lineage_age_CTSL_F_NS                           CTSL
# B_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2
# B_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2
# B_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2
# B_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2
# B_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL
# B_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL
# B_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL
# B_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2
# B_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL
# B_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL
# B_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL
# B_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# T_cell_lineage_age_ACE2_F_NS                           ACE2
# T_cell_lineage_age_ACE2_F_S                            ACE2
# T_cell_lineage_age_ACE2_M_NS                           ACE2
# T_cell_lineage_age_ACE2_M_S                            ACE2
# T_cell_lineage_age_CTSL_F_S                            CTSL
# T_cell_lineage_age_CTSL_M_NS                           CTSL
# T_cell_lineage_age_CTSL_M_S                            CTSL
# T_cell_lineage_age_CTSL_F_NS                           CTSL
# T_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2
# T_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2
# T_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2
# T_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2
# T_cell_lineage_sex[T.male]_ACE2_62yr_S                 ACE2
# T_cell_lineage_sex[T.male]_ACE2_62yr_NS                ACE2
# T_cell_lineage_sex[T.male]_ACE2_31yr_S                 ACE2
# T_cell_lineage_sex[T.male]_ACE2_31yr_NS                ACE2
# T_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL
# T_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL
# T_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL
# T_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2
# T_cell_lineage_smoking_status[T.True]_ACE2_F_62yr      ACE2
# T_cell_lineage_smoking_status[T.True]_ACE2_F_31yr      ACE2
# T_cell_lineage_smoking_status[T.True]_ACE2_M_62yr      ACE2
# T_cell_lineage_smoking_status[T.True]_ACE2_M_31yr      ACE2
# T_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL
# T_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL
# T_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL
# T_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2
# Innate_lymphoid_cells_age_CTSL_M_S                     CTSL
# Innate_lymphoid_cells_age_CTSL_M_NS                    CTSL
# Innate_lymphoid_cells_age_CTSL_F_S                     CTSL
# Innate_lymphoid_cells_age_CTSL_F_NS                    CTSL
# Innate_lymphoid_cells_age_TMPRSS2_F_S               TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_F_NS              TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_M_NS              TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_M_S               TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_S          CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_NS         CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_S          CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_NS         CTSL
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_NS   TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_S    TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_NS   TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_S    TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Dendritic_cells_age_CTSL_M_NS                          CTSL
# Dendritic_cells_age_CTSL_M_S                           CTSL
# Dendritic_cells_age_CTSL_F_NS                          CTSL
# Dendritic_cells_age_CTSL_F_S                           CTSL
# Dendritic_cells_age_TMPRSS2_F_S                     TMPRSS2
# Dendritic_cells_age_TMPRSS2_M_NS                    TMPRSS2
# Dendritic_cells_age_TMPRSS2_M_S                     TMPRSS2
# Dendritic_cells_age_TMPRSS2_F_NS                    TMPRSS2
# Dendritic_cells_sex[T.male]_CTSL_31yr_NS               CTSL
# Dendritic_cells_sex[T.male]_CTSL_31yr_S                CTSL
# Dendritic_cells_sex[T.male]_CTSL_62yr_NS               CTSL
# Dendritic_cells_sex[T.male]_CTSL_62yr_S                CTSL
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_NS         TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_S          TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_NS         TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_S          TMPRSS2
# Dendritic_cells_smoking_status[T.True]_CTSL_M_62yr     CTSL
# Dendritic_cells_smoking_status[T.True]_CTSL_M_31yr     CTSL
# Dendritic_cells_smoking_status[T.True]_CTSL_F_62yr     CTSL
# Dendritic_cells_smoking_status[T.True]_CTSL_F_31yr     CTSL
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2
# Macrophages_age_ACE2_F_NS                              ACE2
# Macrophages_age_ACE2_F_S                               ACE2
# Macrophages_age_ACE2_M_S                               ACE2
# Macrophages_age_ACE2_M_NS                              ACE2
# Macrophages_age_CTSL_M_S                               CTSL
# Macrophages_age_CTSL_M_NS                              CTSL
# Macrophages_age_CTSL_F_NS                              CTSL
# Macrophages_age_CTSL_F_S                               CTSL
# Macrophages_age_TMPRSS2_F_NS                        TMPRSS2
# Macrophages_age_TMPRSS2_F_S                         TMPRSS2
# Macrophages_age_TMPRSS2_M_NS                        TMPRSS2
# Macrophages_age_TMPRSS2_M_S                         TMPRSS2
# Macrophages_sex[T.male]_ACE2_31yr_NS                   ACE2
# Macrophages_sex[T.male]_ACE2_31yr_S                    ACE2
# Macrophages_sex[T.male]_ACE2_62yr_NS                   ACE2
# Macrophages_sex[T.male]_ACE2_62yr_S                    ACE2
# Macrophages_sex[T.male]_CTSL_62yr_S                    CTSL
# Macrophages_sex[T.male]_CTSL_62yr_NS                   CTSL
# Macrophages_sex[T.male]_CTSL_31yr_S                    CTSL
# Macrophages_sex[T.male]_CTSL_31yr_NS                   CTSL
# Macrophages_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2
# Macrophages_smoking_status[T.True]_ACE2_F_31yr         ACE2
# Macrophages_smoking_status[T.True]_ACE2_F_62yr         ACE2
# Macrophages_smoking_status[T.True]_ACE2_M_31yr         ACE2
# Macrophages_smoking_status[T.True]_ACE2_M_62yr         ACE2
# Macrophages_smoking_status[T.True]_CTSL_M_62yr         CTSL
# Macrophages_smoking_status[T.True]_CTSL_M_31yr         CTSL
# Macrophages_smoking_status[T.True]_CTSL_F_62yr         CTSL
# Macrophages_smoking_status[T.True]_CTSL_F_31yr         CTSL
# Macrophages_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2
# Macrophages_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2
# Macrophages_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2
# Macrophages_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2
# Monocytes_age_ACE2_M_S                                 ACE2
# Monocytes_age_ACE2_M_NS                                ACE2
# Monocytes_age_ACE2_F_S                                 ACE2
# Monocytes_age_ACE2_F_NS                                ACE2
# Monocytes_age_CTSL_M_S                                 CTSL
# Monocytes_age_CTSL_M_NS                                CTSL
# Monocytes_age_CTSL_F_S                                 CTSL
# Monocytes_age_CTSL_F_NS                                CTSL
# Monocytes_age_TMPRSS2_F_NS                          TMPRSS2
# Monocytes_age_TMPRSS2_M_NS                          TMPRSS2
# Monocytes_age_TMPRSS2_M_S                           TMPRSS2
# Monocytes_age_TMPRSS2_F_S                           TMPRSS2
# Monocytes_sex[T.male]_ACE2_31yr_NS                     ACE2
# Monocytes_sex[T.male]_ACE2_62yr_S                      ACE2
# Monocytes_sex[T.male]_ACE2_62yr_NS                     ACE2
# Monocytes_sex[T.male]_ACE2_31yr_S                      ACE2
# Monocytes_sex[T.male]_CTSL_62yr_S                      CTSL
# Monocytes_sex[T.male]_CTSL_62yr_NS                     CTSL
# Monocytes_sex[T.male]_CTSL_31yr_S                      CTSL
# Monocytes_sex[T.male]_CTSL_31yr_NS                     CTSL
# Monocytes_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2
# Monocytes_smoking_status[T.True]_ACE2_F_31yr           ACE2
# Monocytes_smoking_status[T.True]_ACE2_F_62yr           ACE2
# Monocytes_smoking_status[T.True]_ACE2_M_31yr           ACE2
# Monocytes_smoking_status[T.True]_ACE2_M_62yr           ACE2
# Monocytes_smoking_status[T.True]_CTSL_M_31yr           CTSL
# Monocytes_smoking_status[T.True]_CTSL_F_62yr           CTSL
# Monocytes_smoking_status[T.True]_CTSL_F_31yr           CTSL
# Monocytes_smoking_status[T.True]_CTSL_M_62yr           CTSL
# Monocytes_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2
# Monocytes_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2
# Monocytes_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2
# Monocytes_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2
# Mast_cells_age_CTSL_M_S                                CTSL
# Mast_cells_age_CTSL_M_NS                               CTSL
# Mast_cells_age_CTSL_F_S                                CTSL
# Mast_cells_age_CTSL_F_NS                               CTSL
# Mast_cells_age_TMPRSS2_M_NS                         TMPRSS2
# Mast_cells_age_TMPRSS2_M_S                          TMPRSS2
# Mast_cells_age_TMPRSS2_F_S                          TMPRSS2
# Mast_cells_age_TMPRSS2_F_NS                         TMPRSS2
# Mast_cells_sex[T.male]_CTSL_31yr_NS                    CTSL
# Mast_cells_sex[T.male]_CTSL_62yr_S                     CTSL
# Mast_cells_sex[T.male]_CTSL_62yr_NS                    CTSL
# Mast_cells_sex[T.male]_CTSL_31yr_S                     CTSL
# Mast_cells_sex[T.male]_TMPRSS2_62yr_S               TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_62yr_NS              TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_31yr_S               TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_31yr_NS              TMPRSS2
# Mast_cells_smoking_status[T.True]_CTSL_F_62yr          CTSL
# Mast_cells_smoking_status[T.True]_CTSL_F_31yr          CTSL
# Mast_cells_smoking_status[T.True]_CTSL_M_62yr          CTSL
# Mast_cells_smoking_status[T.True]_CTSL_M_31yr          CTSL
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_62yr    TMPRSS2
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_62yr    TMPRSS2
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_31yr    TMPRSS2
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_31yr    TMPRSS2
#
#                                                             cell_identity  \
# Basal_age_ACE2_M_NS                                                 Basal
# Basal_age_ACE2_F_S                                                  Basal
# Basal_age_ACE2_F_NS                                                 Basal
# Basal_age_ACE2_M_S                                                  Basal
# Basal_age_CTSL_M_S                                                  Basal
# Basal_age_CTSL_M_NS                                                 Basal
# Basal_age_CTSL_F_S                                                  Basal
# Basal_age_CTSL_F_NS                                                 Basal
# Basal_age_TMPRSS2_F_NS                                              Basal
# Basal_age_TMPRSS2_M_NS                                              Basal
# Basal_age_TMPRSS2_F_S                                               Basal
# Basal_age_TMPRSS2_M_S                                               Basal
# Basal_sex[T.male]_ACE2_62yr_S                                       Basal
# Basal_sex[T.male]_ACE2_62yr_NS                                      Basal
# Basal_sex[T.male]_ACE2_31yr_S                                       Basal
# Basal_sex[T.male]_ACE2_31yr_NS                                      Basal
# Basal_sex[T.male]_CTSL_62yr_S                                       Basal
# Basal_sex[T.male]_CTSL_62yr_NS                                      Basal
# Basal_sex[T.male]_CTSL_31yr_NS                                      Basal
# Basal_sex[T.male]_CTSL_31yr_S                                       Basal
# Basal_sex[T.male]_TMPRSS2_62yr_NS                                   Basal
# Basal_sex[T.male]_TMPRSS2_31yr_S                                    Basal
# Basal_sex[T.male]_TMPRSS2_31yr_NS                                   Basal
# Basal_sex[T.male]_TMPRSS2_62yr_S                                    Basal
# Basal_smoking_status[T.True]_ACE2_M_62yr                            Basal
# Basal_smoking_status[T.True]_ACE2_M_31yr                            Basal
# Basal_smoking_status[T.True]_ACE2_F_62yr                            Basal
# Basal_smoking_status[T.True]_ACE2_F_31yr                            Basal
# Basal_smoking_status[T.True]_CTSL_M_62yr                            Basal
# Basal_smoking_status[T.True]_CTSL_F_31yr                            Basal
# Basal_smoking_status[T.True]_CTSL_F_62yr                            Basal
# Basal_smoking_status[T.True]_CTSL_M_31yr                            Basal
# Basal_smoking_status[T.True]_TMPRSS2_M_62yr                         Basal
# Basal_smoking_status[T.True]_TMPRSS2_M_31yr                         Basal
# Basal_smoking_status[T.True]_TMPRSS2_F_62yr                         Basal
# Basal_smoking_status[T.True]_TMPRSS2_F_31yr                         Basal
# Multiciliated_lineage_age_ACE2_M_S                  Multiciliated lineage
# Multiciliated_lineage_age_ACE2_M_NS                 Multiciliated lineage
# Multiciliated_lineage_age_ACE2_F_S                  Multiciliated lineage
# Multiciliated_lineage_age_ACE2_F_NS                 Multiciliated lineage
# Multiciliated_lineage_age_CTSL_M_S                  Multiciliated lineage
# Multiciliated_lineage_age_CTSL_M_NS                 Multiciliated lineage
# Multiciliated_lineage_age_CTSL_F_S                  Multiciliated lineage
# Multiciliated_lineage_age_CTSL_F_NS                 Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_F_NS              Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_F_S               Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_M_NS              Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_M_S               Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_62yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_31yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_31yr_NS      Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_62yr_S       Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_S    Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr_NS   Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_S    Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_31yr_NS   Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_AC...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CT...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Secretory_age_ACE2_F_NS                                         Secretory
# Secretory_age_ACE2_F_S                                          Secretory
# Secretory_age_ACE2_M_NS                                         Secretory
# Secretory_age_ACE2_M_S                                          Secretory
# Secretory_age_CTSL_F_NS                                         Secretory
# Secretory_age_CTSL_F_S                                          Secretory
# Secretory_age_CTSL_M_NS                                         Secretory
# Secretory_age_CTSL_M_S                                          Secretory
# Secretory_age_TMPRSS2_F_NS                                      Secretory
# Secretory_age_TMPRSS2_F_S                                       Secretory
# Secretory_age_TMPRSS2_M_NS                                      Secretory
# Secretory_age_TMPRSS2_M_S                                       Secretory
# Secretory_sex[T.male]_ACE2_62yr_S                               Secretory
# Secretory_sex[T.male]_ACE2_62yr_NS                              Secretory
# Secretory_sex[T.male]_ACE2_31yr_S                               Secretory
# Secretory_sex[T.male]_ACE2_31yr_NS                              Secretory
# Secretory_sex[T.male]_CTSL_31yr_S                               Secretory
# Secretory_sex[T.male]_CTSL_62yr_NS                              Secretory
# Secretory_sex[T.male]_CTSL_62yr_S                               Secretory
# Secretory_sex[T.male]_CTSL_31yr_NS                              Secretory
# Secretory_sex[T.male]_TMPRSS2_62yr_S                            Secretory
# Secretory_sex[T.male]_TMPRSS2_62yr_NS                           Secretory
# Secretory_sex[T.male]_TMPRSS2_31yr_S                            Secretory
# Secretory_sex[T.male]_TMPRSS2_31yr_NS                           Secretory
# Secretory_smoking_status[T.True]_ACE2_F_31yr                    Secretory
# Secretory_smoking_status[T.True]_ACE2_M_62yr                    Secretory
# Secretory_smoking_status[T.True]_ACE2_M_31yr                    Secretory
# Secretory_smoking_status[T.True]_ACE2_F_62yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_F_31yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_F_62yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_M_31yr                    Secretory
# Secretory_smoking_status[T.True]_CTSL_M_62yr                    Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_F_62yr                 Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_M_31yr                 Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_F_31yr                 Secretory
# Secretory_smoking_status[T.True]_TMPRSS2_M_62yr                 Secretory
# Rare_age_ACE2_F_NS                                                   Rare
# Rare_age_ACE2_F_S                                                    Rare
# Rare_age_ACE2_M_NS                                                   Rare
# Rare_age_ACE2_M_S                                                    Rare
# Rare_age_CTSL_F_S                                                    Rare
# Rare_age_CTSL_F_NS                                                   Rare
# Rare_age_CTSL_M_NS                                                   Rare
# Rare_age_CTSL_M_S                                                    Rare
# Rare_age_TMPRSS2_M_S                                                 Rare
# Rare_age_TMPRSS2_M_NS                                                Rare
# Rare_age_TMPRSS2_F_NS                                                Rare
# Rare_age_TMPRSS2_F_S                                                 Rare
# Rare_sex[T.male]_ACE2_62yr_S                                         Rare
# Rare_sex[T.male]_ACE2_62yr_NS                                        Rare
# Rare_sex[T.male]_ACE2_31yr_NS                                        Rare
# Rare_sex[T.male]_ACE2_31yr_S                                         Rare
# Rare_sex[T.male]_CTSL_31yr_NS                                        Rare
# Rare_sex[T.male]_CTSL_31yr_S                                         Rare
# Rare_sex[T.male]_CTSL_62yr_NS                                        Rare
# Rare_sex[T.male]_CTSL_62yr_S                                         Rare
# Rare_sex[T.male]_TMPRSS2_31yr_NS                                     Rare
# Rare_sex[T.male]_TMPRSS2_62yr_NS                                     Rare
# Rare_sex[T.male]_TMPRSS2_62yr_S                                      Rare
# Rare_sex[T.male]_TMPRSS2_31yr_S                                      Rare
# Rare_smoking_status[T.True]_ACE2_F_31yr                              Rare
# Rare_smoking_status[T.True]_ACE2_F_62yr                              Rare
# Rare_smoking_status[T.True]_ACE2_M_31yr                              Rare
# Rare_smoking_status[T.True]_ACE2_M_62yr                              Rare
# Rare_smoking_status[T.True]_CTSL_F_31yr                              Rare
# Rare_smoking_status[T.True]_CTSL_F_62yr                              Rare
# Rare_smoking_status[T.True]_CTSL_M_31yr                              Rare
# Rare_smoking_status[T.True]_CTSL_M_62yr                              Rare
# ...
# Fibroblasts_age_ACE2_F_S                               ACE2 2
# Fibroblasts_age_ACE2_F_NS                              ACE2 0
# Fibroblasts_age_CTSL_F_NS                              CTSL 0
# Fibroblasts_age_CTSL_F_S                               CTSL 2
# Fibroblasts_age_CTSL_M_S                               CTSL 3
# Fibroblasts_age_CTSL_M_NS                              CTSL 1
# Fibroblasts_age_TMPRSS2_F_S                         TMPRSS2 2
# Fibroblasts_age_TMPRSS2_M_S                         TMPRSS2 3
# Fibroblasts_age_TMPRSS2_M_NS                        TMPRSS2 1
# Fibroblasts_age_TMPRSS2_F_NS                        TMPRSS2 0
# Fibroblasts_sex[T.male]_ACE2_62yr_S                    ACE2 3
# Fibroblasts_sex[T.male]_ACE2_62yr_NS                   ACE2 2
# Fibroblasts_sex[T.male]_ACE2_31yr_S                    ACE2 1
# Fibroblasts_sex[T.male]_ACE2_31yr_NS                   ACE2 0
# Fibroblasts_sex[T.male]_CTSL_31yr_NS                   CTSL 0
# Fibroblasts_sex[T.male]_CTSL_62yr_NS                   CTSL 2
# Fibroblasts_sex[T.male]_CTSL_62yr_S                    CTSL 3
# Fibroblasts_sex[T.male]_CTSL_31yr_S                    CTSL 1
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2 2
# Fibroblasts_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2 3
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2 0
# Fibroblasts_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2 1
# Fibroblasts_smoking_status[T.True]_ACE2_M_62yr         ACE2 3
# Fibroblasts_smoking_status[T.True]_ACE2_M_31yr         ACE2 1
# Fibroblasts_smoking_status[T.True]_ACE2_F_62yr         ACE2 2
# Fibroblasts_smoking_status[T.True]_ACE2_F_31yr         ACE2 0
# Fibroblasts_smoking_status[T.True]_CTSL_F_31yr         CTSL 0
# Fibroblasts_smoking_status[T.True]_CTSL_F_62yr         CTSL 2
# Fibroblasts_smoking_status[T.True]_CTSL_M_31yr         CTSL 1
# Fibroblasts_smoking_status[T.True]_CTSL_M_62yr         CTSL 3
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2 2
# Fibroblasts_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2 0
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2 3
# Fibroblasts_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2 1
# Airway_smooth_muscle_age_CTSL_M_S                      CTSL 3
# Airway_smooth_muscle_age_CTSL_M_NS                     CTSL 1
# Airway_smooth_muscle_age_CTSL_F_S                      CTSL 2
# Airway_smooth_muscle_age_CTSL_F_NS                     CTSL 0
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_S           CTSL 3
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr_NS          CTSL 2
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_S           CTSL 1
# Airway_smooth_muscle_sex[T.male]_CTSL_31yr_NS          CTSL 0
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 2
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 0
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 1
# Airway_smooth_muscle_smoking_status[T.True]_CTS...     CTSL 3
# B_cell_lineage_age_CTSL_F_S                            CTSL 2
# B_cell_lineage_age_CTSL_M_NS                           CTSL 1
# B_cell_lineage_age_CTSL_M_S                            CTSL 3
# B_cell_lineage_age_CTSL_F_NS                           CTSL 0
# B_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2 3
# B_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2 1
# B_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2 0
# B_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2 2
# B_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL 0
# B_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL 1
# B_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL 2
# B_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL 3
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2 3
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2 2
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2 1
# B_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2 0
# B_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL 0
# B_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL 2
# B_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL 1
# B_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL 3
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 0
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 2
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 1
# B_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 3
# T_cell_lineage_age_ACE2_F_NS                           ACE2 0
# T_cell_lineage_age_ACE2_F_S                            ACE2 2
# T_cell_lineage_age_ACE2_M_NS                           ACE2 1
# T_cell_lineage_age_ACE2_M_S                            ACE2 3
# T_cell_lineage_age_CTSL_F_S                            CTSL 2
# T_cell_lineage_age_CTSL_M_NS                           CTSL 1
# T_cell_lineage_age_CTSL_M_S                            CTSL 3
# T_cell_lineage_age_CTSL_F_NS                           CTSL 0
# T_cell_lineage_age_TMPRSS2_F_NS                     TMPRSS2 0
# T_cell_lineage_age_TMPRSS2_F_S                      TMPRSS2 2
# T_cell_lineage_age_TMPRSS2_M_NS                     TMPRSS2 1
# T_cell_lineage_age_TMPRSS2_M_S                      TMPRSS2 3
# T_cell_lineage_sex[T.male]_ACE2_62yr_S                 ACE2 3
# T_cell_lineage_sex[T.male]_ACE2_62yr_NS                ACE2 2
# T_cell_lineage_sex[T.male]_ACE2_31yr_S                 ACE2 1
# T_cell_lineage_sex[T.male]_ACE2_31yr_NS                ACE2 0
# T_cell_lineage_sex[T.male]_CTSL_62yr_NS                CTSL 2
# T_cell_lineage_sex[T.male]_CTSL_62yr_S                 CTSL 3
# T_cell_lineage_sex[T.male]_CTSL_31yr_S                 CTSL 1
# T_cell_lineage_sex[T.male]_CTSL_31yr_NS                CTSL 0
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_NS          TMPRSS2 0
# T_cell_lineage_sex[T.male]_TMPRSS2_31yr_S           TMPRSS2 1
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_NS          TMPRSS2 2
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr_S           TMPRSS2 3
# T_cell_lineage_smoking_status[T.True]_ACE2_F_62yr      ACE2 2
# T_cell_lineage_smoking_status[T.True]_ACE2_F_31yr      ACE2 0
# T_cell_lineage_smoking_status[T.True]_ACE2_M_62yr      ACE2 3
# T_cell_lineage_smoking_status[T.True]_ACE2_M_31yr      ACE2 1
# T_cell_lineage_smoking_status[T.True]_CTSL_F_31yr      CTSL 0
# T_cell_lineage_smoking_status[T.True]_CTSL_F_62yr      CTSL 2
# T_cell_lineage_smoking_status[T.True]_CTSL_M_31yr      CTSL 1
# T_cell_lineage_smoking_status[T.True]_CTSL_M_62yr      CTSL 3
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 0
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_F...  TMPRSS2 2
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 1
# T_cell_lineage_smoking_status[T.True]_TMPRSS2_M...  TMPRSS2 3
# Innate_lymphoid_cells_age_CTSL_M_S                     CTSL 3
# Innate_lymphoid_cells_age_CTSL_M_NS                    CTSL 1
# Innate_lymphoid_cells_age_CTSL_F_S                     CTSL 2
# Innate_lymphoid_cells_age_CTSL_F_NS                    CTSL 0
# Innate_lymphoid_cells_age_TMPRSS2_F_S               TMPRSS2 2
# Innate_lymphoid_cells_age_TMPRSS2_F_NS              TMPRSS2 0
# Innate_lymphoid_cells_age_TMPRSS2_M_NS              TMPRSS2 1
# Innate_lymphoid_cells_age_TMPRSS2_M_S               TMPRSS2 3
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_S          CTSL 3
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr_NS         CTSL 2
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_S          CTSL 1
# Innate_lymphoid_cells_sex[T.male]_CTSL_31yr_NS         CTSL 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_NS   TMPRSS2 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_31yr_S    TMPRSS2 1
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_NS   TMPRSS2 2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr_S    TMPRSS2 3
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 3
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 2
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 0
# Innate_lymphoid_cells_smoking_status[T.True]_CT...     CTSL 1
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 1
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 0
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 3
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2 2
# Dendritic_cells_age_CTSL_M_NS                          CTSL 1
# Dendritic_cells_age_CTSL_M_S                           CTSL 3
# Dendritic_cells_age_CTSL_F_NS                          CTSL 0
# Dendritic_cells_age_CTSL_F_S                           CTSL 2
# Dendritic_cells_age_TMPRSS2_F_S                     TMPRSS2 2
# Dendritic_cells_age_TMPRSS2_M_NS                    TMPRSS2 1
# Dendritic_cells_age_TMPRSS2_M_S                     TMPRSS2 3
# Dendritic_cells_age_TMPRSS2_F_NS                    TMPRSS2 0
# Dendritic_cells_sex[T.male]_CTSL_31yr_NS               CTSL 0
# Dendritic_cells_sex[T.male]_CTSL_31yr_S                CTSL 1
# Dendritic_cells_sex[T.male]_CTSL_62yr_NS               CTSL 2
# Dendritic_cells_sex[T.male]_CTSL_62yr_S                CTSL 3
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_NS         TMPRSS2 0
# Dendritic_cells_sex[T.male]_TMPRSS2_31yr_S          TMPRSS2 1
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_NS         TMPRSS2 2
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr_S          TMPRSS2 3
# Dendritic_cells_smoking_status[T.True]_CTSL_M_62yr     CTSL 3
# Dendritic_cells_smoking_status[T.True]_CTSL_M_31yr     CTSL 1
# Dendritic_cells_smoking_status[T.True]_CTSL_F_62yr     CTSL 2
# Dendritic_cells_smoking_status[T.True]_CTSL_F_31yr     CTSL 0
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 0
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 1
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 3
# Dendritic_cells_smoking_status[T.True]_TMPRSS2_...  TMPRSS2 2
# Macrophages_age_ACE2_F_NS                              ACE2 0
# Macrophages_age_ACE2_F_S                               ACE2 2
# Macrophages_age_ACE2_M_S                               ACE2 3
# Macrophages_age_ACE2_M_NS                              ACE2 1
# Macrophages_age_CTSL_M_S                               CTSL 3
# Macrophages_age_CTSL_M_NS                              CTSL 1
# Macrophages_age_CTSL_F_NS                              CTSL 0
# Macrophages_age_CTSL_F_S                               CTSL 2
# Macrophages_age_TMPRSS2_F_NS                        TMPRSS2 0
# Macrophages_age_TMPRSS2_F_S                         TMPRSS2 2
# Macrophages_age_TMPRSS2_M_NS                        TMPRSS2 1
# Macrophages_age_TMPRSS2_M_S                         TMPRSS2 3
# Macrophages_sex[T.male]_ACE2_31yr_NS                   ACE2 0
# Macrophages_sex[T.male]_ACE2_31yr_S                    ACE2 1
# Macrophages_sex[T.male]_ACE2_62yr_NS                   ACE2 2
# Macrophages_sex[T.male]_ACE2_62yr_S                    ACE2 3
# Macrophages_sex[T.male]_CTSL_62yr_S                    CTSL 3
# Macrophages_sex[T.male]_CTSL_62yr_NS                   CTSL 2
# Macrophages_sex[T.male]_CTSL_31yr_S                    CTSL 1
# Macrophages_sex[T.male]_CTSL_31yr_NS                   CTSL 0
# Macrophages_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2 0
# Macrophages_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2 1
# Macrophages_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2 2
# Macrophages_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2 3
# Macrophages_smoking_status[T.True]_ACE2_F_31yr         ACE2 0
# Macrophages_smoking_status[T.True]_ACE2_F_62yr         ACE2 2
# Macrophages_smoking_status[T.True]_ACE2_M_31yr         ACE2 1
# Macrophages_smoking_status[T.True]_ACE2_M_62yr         ACE2 3
# Macrophages_smoking_status[T.True]_CTSL_M_62yr         CTSL 3
# Macrophages_smoking_status[T.True]_CTSL_M_31yr         CTSL 1
# Macrophages_smoking_status[T.True]_CTSL_F_62yr         CTSL 2
# Macrophages_smoking_status[T.True]_CTSL_F_31yr         CTSL 0
# Macrophages_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2 3
# Macrophages_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2 1
# Macrophages_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2 2
# Macrophages_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2 0
# Monocytes_age_ACE2_M_S                                 ACE2 3
# Monocytes_age_ACE2_M_NS                                ACE2 1
# Monocytes_age_ACE2_F_S                                 ACE2 2
# Monocytes_age_ACE2_F_NS                                ACE2 0
# Monocytes_age_CTSL_M_S                                 CTSL 3
# Monocytes_age_CTSL_M_NS                                CTSL 1
# Monocytes_age_CTSL_F_S                                 CTSL 2
# Monocytes_age_CTSL_F_NS                                CTSL 0
# Monocytes_age_TMPRSS2_F_NS                          TMPRSS2 0
# Monocytes_age_TMPRSS2_M_NS                          TMPRSS2 1
# Monocytes_age_TMPRSS2_M_S                           TMPRSS2 3
# Monocytes_age_TMPRSS2_F_S                           TMPRSS2 2
# Monocytes_sex[T.male]_ACE2_31yr_NS                     ACE2 0
# Monocytes_sex[T.male]_ACE2_62yr_S                      ACE2 3
# Monocytes_sex[T.male]_ACE2_62yr_NS                     ACE2 2
# Monocytes_sex[T.male]_ACE2_31yr_S                      ACE2 1
# Monocytes_sex[T.male]_CTSL_62yr_S                      CTSL 3
# Monocytes_sex[T.male]_CTSL_62yr_NS                     CTSL 2
# Monocytes_sex[T.male]_CTSL_31yr_S                      CTSL 1
# Monocytes_sex[T.male]_CTSL_31yr_NS                     CTSL 0
# Monocytes_sex[T.male]_TMPRSS2_31yr_NS               TMPRSS2 0
# Monocytes_sex[T.male]_TMPRSS2_62yr_NS               TMPRSS2 2
# Monocytes_sex[T.male]_TMPRSS2_62yr_S                TMPRSS2 3
# Monocytes_sex[T.male]_TMPRSS2_31yr_S                TMPRSS2 1
# Monocytes_smoking_status[T.True]_ACE2_F_31yr           ACE2 0
# Monocytes_smoking_status[T.True]_ACE2_F_62yr           ACE2 2
# Monocytes_smoking_status[T.True]_ACE2_M_31yr           ACE2 1
# Monocytes_smoking_status[T.True]_ACE2_M_62yr           ACE2 3
# Monocytes_smoking_status[T.True]_CTSL_M_31yr           CTSL 1
# Monocytes_smoking_status[T.True]_CTSL_F_62yr           CTSL 2
# Monocytes_smoking_status[T.True]_CTSL_F_31yr           CTSL 0
# Monocytes_smoking_status[T.True]_CTSL_M_62yr           CTSL 3
# Monocytes_smoking_status[T.True]_TMPRSS2_M_31yr     TMPRSS2 1
# Monocytes_smoking_status[T.True]_TMPRSS2_M_62yr     TMPRSS2 3
# Monocytes_smoking_status[T.True]_TMPRSS2_F_31yr     TMPRSS2 0
# Monocytes_smoking_status[T.True]_TMPRSS2_F_62yr     TMPRSS2 2
# Mast_cells_age_CTSL_M_S                                CTSL 3
# Mast_cells_age_CTSL_M_NS                               CTSL 1
# Mast_cells_age_CTSL_F_S                                CTSL 2
# Mast_cells_age_CTSL_F_NS                               CTSL 0
# Mast_cells_age_TMPRSS2_M_NS                         TMPRSS2 1
# Mast_cells_age_TMPRSS2_M_S                          TMPRSS2 3
# Mast_cells_age_TMPRSS2_F_S                          TMPRSS2 2
# Mast_cells_age_TMPRSS2_F_NS                         TMPRSS2 0
# Mast_cells_sex[T.male]_CTSL_31yr_NS                    CTSL 0
# Mast_cells_sex[T.male]_CTSL_62yr_S                     CTSL 3
# Mast_cells_sex[T.male]_CTSL_62yr_NS                    CTSL 2
# Mast_cells_sex[T.male]_CTSL_31yr_S                     CTSL 1
# Mast_cells_sex[T.male]_TMPRSS2_62yr_S               TMPRSS2 3
# Mast_cells_sex[T.male]_TMPRSS2_62yr_NS              TMPRSS2 2
# Mast_cells_sex[T.male]_TMPRSS2_31yr_S               TMPRSS2 1
# Mast_cells_sex[T.male]_TMPRSS2_31yr_NS              TMPRSS2 0
# Mast_cells_smoking_status[T.True]_CTSL_F_62yr          CTSL 2
# Mast_cells_smoking_status[T.True]_CTSL_F_31yr          CTSL 0
# Mast_cells_smoking_status[T.True]_CTSL_M_62yr          CTSL 3
# Mast_cells_smoking_status[T.True]_CTSL_M_31yr          CTSL 1
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_62yr    TMPRSS2 3
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_62yr    TMPRSS2 2
# Mast_cells_smoking_status[T.True]_TMPRSS2_F_31yr    TMPRSS2 0
# Mast_cells_smoking_status[T.True]_TMPRSS2_M_31yr    TMPRSS2 1

# %% [markdown]
# ## Level 2

# %%
res_lvl2['cell_identity'].unique()
# Out:
# array(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid',
#        'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland',
#        'Smooth Muscle', 'Lymphatics', 'Mesothelium'], dtype=object)

# %%
# Prep plotting

# Order cell identity category
res_lvl2['cell_identity'] = res_lvl2['cell_identity'].astype('category').cat.set_categories(['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium', 'Blood vessels', 'Lymphatics', 'Fibroblast lineage', 'Smooth Muscle', 'Mesothelium', 'Lymphoid', 'Myeloid'], ordered=True)
res_lvl2 = res_lvl2.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium'], 'Endothelial':['Blood vessels', 'Lymphatics'], 'Stroma':['Fibroblast lineage', 'Smooth Muscle', 'Mesothelium'], 'Immune':['Lymphoid', 'Myeloid']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl2['compartment'] = [ct_mapping_up[ct] for ct in res_lvl2['cell_identity']]        

# Check if bulk and sc effect directions agree
res_lvl2_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl2_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl2[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl2['coef'].loc[res_lvl2.index[i]]* res_lvl2_pseudo['coef'].loc[res_lvl2.index[i]]) > 0) for i,val in enumerate(res_lvl2['adj_pvals'])]


res_lvl2['compartment'] = res_lvl2['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl2['covariate_simple'] = res_lvl2['covariate'].astype('category').cat.rename_categories(['Age', 'Sex', 'Smoking_status'])

# Assign eval_at numbers
res_lvl2 = res_lvl2.sort_values(by=['cell_identity', 'covariate', 'gene'])

eval_encoding = {
    'age':{'F NS':0, 'M NS':1, 'F S':2, 'M S':3},
    'sex[T.male]':{'31yr NS':0, '31yr S':1, '62yr NS':2, '62yr S':3},
    'smoking_status[T.True]':{'F 31yr':0, 'M 31yr':1, 'F 62yr':2, 'M 62yr':3}
}

res_lvl2['eval_num'] = [eval_encoding[res_lvl2['covariate'].loc[idx]][res_lvl2['eval_at'].loc[idx]] 
                        for idx in res_lvl2.index]

res_lvl2['gene_eval'] = [' '.join([i,str(j)]) for i,j in zip(res_lvl2['gene'], res_lvl2['eval_num'])]

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.2
for i in range(3):
    for alpha in range(4):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.2
for alpha in range(4):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(4)]

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(5.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(4)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-2.0, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(4)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [-0.7, -0.1], frameon=False, title=None)

#Smoking legend
smoking_labs = [j[0] for j in sorted(list(eval_encoding['smoking_status[T.True]'].items()), key=lambda i: i[1])]
smoking_handles = [patches.Patch(color=shades[i], label=smoking_labs[i]) for i in range(4)]
leg_smoking = plt.legend(handles=smoking_handles, bbox_to_anchor = [0.6, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[4], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[8], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)
plt.gca().add_artist(leg_smoking)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl2_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl2.sort_values(by=[ 'covariate', 'cell_identity',  'gene'])
# Out:
#                                                        gene  \
# Airway_epithelium_age_ACE2_F_NS                        ACE2
# Airway_epithelium_age_ACE2_F_S                         ACE2
# Airway_epithelium_age_ACE2_M_NS                        ACE2
# Airway_epithelium_age_ACE2_M_S                         ACE2
# Airway_epithelium_age_CTSL_F_NS                        CTSL
# Airway_epithelium_age_CTSL_M_NS                        CTSL
# Airway_epithelium_age_CTSL_F_S                         CTSL
# Airway_epithelium_age_CTSL_M_S                         CTSL
# Airway_epithelium_age_TMPRSS2_F_NS                  TMPRSS2
# Airway_epithelium_age_TMPRSS2_F_S                   TMPRSS2
# Airway_epithelium_age_TMPRSS2_M_NS                  TMPRSS2
# Airway_epithelium_age_TMPRSS2_M_S                   TMPRSS2
# Submucosal_Gland_age_ACE2_F_NS                         ACE2
# Submucosal_Gland_age_ACE2_F_S                          ACE2
# Submucosal_Gland_age_ACE2_M_NS                         ACE2
# Submucosal_Gland_age_ACE2_M_S                          ACE2
# Submucosal_Gland_age_CTSL_F_S                          CTSL
# Submucosal_Gland_age_CTSL_F_NS                         CTSL
# Submucosal_Gland_age_CTSL_M_S                          CTSL
# Submucosal_Gland_age_CTSL_M_NS                         CTSL
# Submucosal_Gland_age_TMPRSS2_F_NS                   TMPRSS2
# Submucosal_Gland_age_TMPRSS2_F_S                    TMPRSS2
# Submucosal_Gland_age_TMPRSS2_M_NS                   TMPRSS2
# Submucosal_Gland_age_TMPRSS2_M_S                    TMPRSS2
# Alveolar_epithelium_age_ACE2_F_NS                      ACE2
# Alveolar_epithelium_age_ACE2_F_S                       ACE2
# Alveolar_epithelium_age_ACE2_M_NS                      ACE2
# Alveolar_epithelium_age_ACE2_M_S                       ACE2
# Alveolar_epithelium_age_CTSL_F_S                       CTSL
# Alveolar_epithelium_age_CTSL_M_NS                      CTSL
# Alveolar_epithelium_age_CTSL_M_S                       CTSL
# Alveolar_epithelium_age_CTSL_F_NS                      CTSL
# Alveolar_epithelium_age_TMPRSS2_M_S                 TMPRSS2
# Alveolar_epithelium_age_TMPRSS2_M_NS                TMPRSS2
# Alveolar_epithelium_age_TMPRSS2_F_NS                TMPRSS2
# Alveolar_epithelium_age_TMPRSS2_F_S                 TMPRSS2
# Blood_vessels_age_ACE2_M_S                             ACE2
# Blood_vessels_age_ACE2_M_NS                            ACE2
# Blood_vessels_age_ACE2_F_S                             ACE2
# Blood_vessels_age_ACE2_F_NS                            ACE2
# Blood_vessels_age_CTSL_F_S                             CTSL
# Blood_vessels_age_CTSL_F_NS                            CTSL
# Blood_vessels_age_CTSL_M_S                             CTSL
# Blood_vessels_age_CTSL_M_NS                            CTSL
# Blood_vessels_age_TMPRSS2_F_NS                      TMPRSS2
# Blood_vessels_age_TMPRSS2_F_S                       TMPRSS2
# Blood_vessels_age_TMPRSS2_M_S                       TMPRSS2
# Blood_vessels_age_TMPRSS2_M_NS                      TMPRSS2
# Lymphatics_age_CTSL_M_NS                               CTSL
# Lymphatics_age_CTSL_F_S                                CTSL
# Lymphatics_age_CTSL_F_NS                               CTSL
# Lymphatics_age_CTSL_M_S                                CTSL
# Lymphatics_age_TMPRSS2_F_NS                         TMPRSS2
# Lymphatics_age_TMPRSS2_F_S                          TMPRSS2
# Lymphatics_age_TMPRSS2_M_NS                         TMPRSS2
# Lymphatics_age_TMPRSS2_M_S                          TMPRSS2
# Fibroblast_lineage_age_ACE2_F_NS                       ACE2
# Fibroblast_lineage_age_ACE2_F_S                        ACE2
# Fibroblast_lineage_age_ACE2_M_NS                       ACE2
# Fibroblast_lineage_age_ACE2_M_S                        ACE2
# Fibroblast_lineage_age_CTSL_M_S                        CTSL
# Fibroblast_lineage_age_CTSL_M_NS                       CTSL
# Fibroblast_lineage_age_CTSL_F_NS                       CTSL
# Fibroblast_lineage_age_CTSL_F_S                        CTSL
# Fibroblast_lineage_age_TMPRSS2_M_S                  TMPRSS2
# Fibroblast_lineage_age_TMPRSS2_M_NS                 TMPRSS2
# Fibroblast_lineage_age_TMPRSS2_F_S                  TMPRSS2
# Fibroblast_lineage_age_TMPRSS2_F_NS                 TMPRSS2
# Smooth_Muscle_age_ACE2_F_NS                            ACE2
# Smooth_Muscle_age_ACE2_F_S                             ACE2
# Smooth_Muscle_age_ACE2_M_NS                            ACE2
# Smooth_Muscle_age_ACE2_M_S                             ACE2
# Smooth_Muscle_age_CTSL_M_S                             CTSL
# Smooth_Muscle_age_CTSL_M_NS                            CTSL
# Smooth_Muscle_age_CTSL_F_S                             CTSL
# Smooth_Muscle_age_CTSL_F_NS                            CTSL
# Smooth_Muscle_age_TMPRSS2_F_S                       TMPRSS2
# Smooth_Muscle_age_TMPRSS2_M_NS                      TMPRSS2
# Smooth_Muscle_age_TMPRSS2_M_S                       TMPRSS2
# Smooth_Muscle_age_TMPRSS2_F_NS                      TMPRSS2
# Mesothelium_age_CTSL_M_S                               CTSL
# Mesothelium_age_CTSL_M_NS                              CTSL
# Mesothelium_age_CTSL_F_S                               CTSL
# Mesothelium_age_CTSL_F_NS                              CTSL
# Mesothelium_age_TMPRSS2_M_S                         TMPRSS2
# Mesothelium_age_TMPRSS2_F_S                         TMPRSS2
# Mesothelium_age_TMPRSS2_F_NS                        TMPRSS2
# Mesothelium_age_TMPRSS2_M_NS                        TMPRSS2
# Lymphoid_age_ACE2_M_S                                  ACE2
# Lymphoid_age_ACE2_M_NS                                 ACE2
# Lymphoid_age_ACE2_F_S                                  ACE2
# Lymphoid_age_ACE2_F_NS                                 ACE2
# Lymphoid_age_CTSL_M_S                                  CTSL
# Lymphoid_age_CTSL_M_NS                                 CTSL
# Lymphoid_age_CTSL_F_S                                  CTSL
# Lymphoid_age_CTSL_F_NS                                 CTSL
# Lymphoid_age_TMPRSS2_F_NS                           TMPRSS2
# Lymphoid_age_TMPRSS2_M_NS                           TMPRSS2
# Lymphoid_age_TMPRSS2_F_S                            TMPRSS2
# Lymphoid_age_TMPRSS2_M_S                            TMPRSS2
# Myeloid_age_ACE2_F_S                                   ACE2
# Myeloid_age_ACE2_M_S                                   ACE2
# Myeloid_age_ACE2_M_NS                                  ACE2
# Myeloid_age_ACE2_F_NS                                  ACE2
# Myeloid_age_CTSL_M_S                                   CTSL
# Myeloid_age_CTSL_M_NS                                  CTSL
# Myeloid_age_CTSL_F_S                                   CTSL
# Myeloid_age_CTSL_F_NS                                  CTSL
# Myeloid_age_TMPRSS2_F_NS                            TMPRSS2
# Myeloid_age_TMPRSS2_F_S                             TMPRSS2
# Myeloid_age_TMPRSS2_M_S                             TMPRSS2
# Myeloid_age_TMPRSS2_M_NS                            TMPRSS2
# Airway_epithelium_sex[T.male]_ACE2_31yr_NS             ACE2
# Airway_epithelium_sex[T.male]_ACE2_31yr_S              ACE2
# Airway_epithelium_sex[T.male]_ACE2_62yr_NS             ACE2
# Airway_epithelium_sex[T.male]_ACE2_62yr_S              ACE2
# Airway_epithelium_sex[T.male]_CTSL_62yr_NS             CTSL
# Airway_epithelium_sex[T.male]_CTSL_31yr_S              CTSL
# Airway_epithelium_sex[T.male]_CTSL_31yr_NS             CTSL
# Airway_epithelium_sex[T.male]_CTSL_62yr_S              CTSL
# Airway_epithelium_sex[T.male]_TMPRSS2_31yr_NS       TMPRSS2
# Airway_epithelium_sex[T.male]_TMPRSS2_31yr_S        TMPRSS2
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr_NS       TMPRSS2
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr_S        TMPRSS2
# Submucosal_Gland_sex[T.male]_ACE2_31yr_S               ACE2
# Submucosal_Gland_sex[T.male]_ACE2_62yr_NS              ACE2
# Submucosal_Gland_sex[T.male]_ACE2_62yr_S               ACE2
# Submucosal_Gland_sex[T.male]_ACE2_31yr_NS              ACE2
# Submucosal_Gland_sex[T.male]_CTSL_62yr_NS              CTSL
# Submucosal_Gland_sex[T.male]_CTSL_31yr_NS              CTSL
# Submucosal_Gland_sex[T.male]_CTSL_31yr_S               CTSL
# Submucosal_Gland_sex[T.male]_CTSL_62yr_S               CTSL
# Submucosal_Gland_sex[T.male]_TMPRSS2_31yr_NS        TMPRSS2
# Submucosal_Gland_sex[T.male]_TMPRSS2_31yr_S         TMPRSS2
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr_S         TMPRSS2
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr_NS        TMPRSS2
# Alveolar_epithelium_sex[T.male]_ACE2_31yr_NS           ACE2
# Alveolar_epithelium_sex[T.male]_ACE2_31yr_S            ACE2
# Alveolar_epithelium_sex[T.male]_ACE2_62yr_S            ACE2
# Alveolar_epithelium_sex[T.male]_ACE2_62yr_NS           ACE2
# Alveolar_epithelium_sex[T.male]_CTSL_31yr_NS           CTSL
# Alveolar_epithelium_sex[T.male]_CTSL_62yr_S            CTSL
# Alveolar_epithelium_sex[T.male]_CTSL_31yr_S            CTSL
# Alveolar_epithelium_sex[T.male]_CTSL_62yr_NS           CTSL
# Alveolar_epithelium_sex[T.male]_TMPRSS2_31yr_NS     TMPRSS2
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr_S      TMPRSS2
# Alveolar_epithelium_sex[T.male]_TMPRSS2_31yr_S      TMPRSS2
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr_NS     TMPRSS2
# Blood_vessels_sex[T.male]_ACE2_31yr_NS                 ACE2
# Blood_vessels_sex[T.male]_ACE2_62yr_S                  ACE2
# Blood_vessels_sex[T.male]_ACE2_31yr_S                  ACE2
# Blood_vessels_sex[T.male]_ACE2_62yr_NS                 ACE2
# Blood_vessels_sex[T.male]_CTSL_31yr_NS                 CTSL
# Blood_vessels_sex[T.male]_CTSL_31yr_S                  CTSL
# Blood_vessels_sex[T.male]_CTSL_62yr_NS                 CTSL
# Blood_vessels_sex[T.male]_CTSL_62yr_S                  CTSL
# Blood_vessels_sex[T.male]_TMPRSS2_62yr_S            TMPRSS2
# Blood_vessels_sex[T.male]_TMPRSS2_62yr_NS           TMPRSS2
# Blood_vessels_sex[T.male]_TMPRSS2_31yr_S            TMPRSS2
# Blood_vessels_sex[T.male]_TMPRSS2_31yr_NS           TMPRSS2
# Lymphatics_sex[T.male]_CTSL_31yr_NS                    CTSL
# Lymphatics_sex[T.male]_CTSL_62yr_NS                    CTSL
# Lymphatics_sex[T.male]_CTSL_31yr_S                     CTSL
# Lymphatics_sex[T.male]_CTSL_62yr_S                     CTSL
# Lymphatics_sex[T.male]_TMPRSS2_62yr_NS              TMPRSS2
# Lymphatics_sex[T.male]_TMPRSS2_62yr_S               TMPRSS2
# Lymphatics_sex[T.male]_TMPRSS2_31yr_NS              TMPRSS2
# Lymphatics_sex[T.male]_TMPRSS2_31yr_S               TMPRSS2
# Fibroblast_lineage_sex[T.male]_ACE2_31yr_NS            ACE2
# Fibroblast_lineage_sex[T.male]_ACE2_31yr_S             ACE2
# Fibroblast_lineage_sex[T.male]_ACE2_62yr_NS            ACE2
# Fibroblast_lineage_sex[T.male]_ACE2_62yr_S             ACE2
# Fibroblast_lineage_sex[T.male]_CTSL_62yr_S             CTSL
# Fibroblast_lineage_sex[T.male]_CTSL_31yr_S             CTSL
# Fibroblast_lineage_sex[T.male]_CTSL_31yr_NS            CTSL
# Fibroblast_lineage_sex[T.male]_CTSL_62yr_NS            CTSL
# Fibroblast_lineage_sex[T.male]_TMPRSS2_31yr_NS      TMPRSS2
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr_NS      TMPRSS2
# Fibroblast_lineage_sex[T.male]_TMPRSS2_31yr_S       TMPRSS2
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr_S       TMPRSS2
# Smooth_Muscle_sex[T.male]_ACE2_31yr_NS                 ACE2
# Smooth_Muscle_sex[T.male]_ACE2_31yr_S                  ACE2
# Smooth_Muscle_sex[T.male]_ACE2_62yr_NS                 ACE2
# Smooth_Muscle_sex[T.male]_ACE2_62yr_S                  ACE2
# Smooth_Muscle_sex[T.male]_CTSL_31yr_NS                 CTSL
# Smooth_Muscle_sex[T.male]_CTSL_62yr_S                  CTSL
# Smooth_Muscle_sex[T.male]_CTSL_62yr_NS                 CTSL
# Smooth_Muscle_sex[T.male]_CTSL_31yr_S                  CTSL
# Smooth_Muscle_sex[T.male]_TMPRSS2_31yr_NS           TMPRSS2
# Smooth_Muscle_sex[T.male]_TMPRSS2_31yr_S            TMPRSS2
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr_NS           TMPRSS2
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr_S            TMPRSS2
# Mesothelium_sex[T.male]_CTSL_62yr_S                    CTSL
# Mesothelium_sex[T.male]_CTSL_62yr_NS                   CTSL
# Mesothelium_sex[T.male]_CTSL_31yr_S                    CTSL
# Mesothelium_sex[T.male]_CTSL_31yr_NS                   CTSL
# Mesothelium_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2
# Mesothelium_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2
# Mesothelium_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2
# Mesothelium_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2
# Lymphoid_sex[T.male]_ACE2_62yr_S                       ACE2
# Lymphoid_sex[T.male]_ACE2_62yr_NS                      ACE2
# Lymphoid_sex[T.male]_ACE2_31yr_S                       ACE2
# Lymphoid_sex[T.male]_ACE2_31yr_NS                      ACE2
# Lymphoid_sex[T.male]_CTSL_62yr_S                       CTSL
# Lymphoid_sex[T.male]_CTSL_31yr_S                       CTSL
# Lymphoid_sex[T.male]_CTSL_31yr_NS                      CTSL
# Lymphoid_sex[T.male]_CTSL_62yr_NS                      CTSL
# Lymphoid_sex[T.male]_TMPRSS2_62yr_NS                TMPRSS2
# Lymphoid_sex[T.male]_TMPRSS2_31yr_S                 TMPRSS2
# Lymphoid_sex[T.male]_TMPRSS2_31yr_NS                TMPRSS2
# Lymphoid_sex[T.male]_TMPRSS2_62yr_S                 TMPRSS2
# Myeloid_sex[T.male]_ACE2_62yr_S                        ACE2
# Myeloid_sex[T.male]_ACE2_62yr_NS                       ACE2
# Myeloid_sex[T.male]_ACE2_31yr_S                        ACE2
# Myeloid_sex[T.male]_ACE2_31yr_NS                       ACE2
# Myeloid_sex[T.male]_CTSL_62yr_S                        CTSL
# Myeloid_sex[T.male]_CTSL_62yr_NS                       CTSL
# Myeloid_sex[T.male]_CTSL_31yr_S                        CTSL
# Myeloid_sex[T.male]_CTSL_31yr_NS                       CTSL
# Myeloid_sex[T.male]_TMPRSS2_62yr_S                  TMPRSS2
# Myeloid_sex[T.male]_TMPRSS2_62yr_NS                 TMPRSS2
# Myeloid_sex[T.male]_TMPRSS2_31yr_S                  TMPRSS2
# Myeloid_sex[T.male]_TMPRSS2_31yr_NS                 TMPRSS2
# Airway_epithelium_smoking_status[T.True]_ACE2_F...     ACE2
# Airway_epithelium_smoking_status[T.True]_ACE2_F...     ACE2
# Airway_epithelium_smoking_status[T.True]_ACE2_M...     ACE2
# Airway_epithelium_smoking_status[T.True]_ACE2_M...     ACE2
# Airway_epithelium_smoking_status[T.True]_CTSL_M...     CTSL
# Airway_epithelium_smoking_status[T.True]_CTSL_M...     CTSL
# Airway_epithelium_smoking_status[T.True]_CTSL_F...     CTSL
# Airway_epithelium_smoking_status[T.True]_CTSL_F...     CTSL
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2
# Submucosal_Gland_smoking_status[T.True]_ACE2_F_...     ACE2
# Submucosal_Gland_smoking_status[T.True]_ACE2_F_...     ACE2
# Submucosal_Gland_smoking_status[T.True]_ACE2_M_...     ACE2
# Submucosal_Gland_smoking_status[T.True]_ACE2_M_...     ACE2
# Submucosal_Gland_smoking_status[T.True]_CTSL_F_...     CTSL
# Submucosal_Gland_smoking_status[T.True]_CTSL_F_...     CTSL
# Submucosal_Gland_smoking_status[T.True]_CTSL_M_...     CTSL
# Submucosal_Gland_smoking_status[T.True]_CTSL_M_...     CTSL
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2
# Blood_vessels_smoking_status[T.True]_ACE2_M_62yr       ACE2
# Blood_vessels_smoking_status[T.True]_ACE2_F_62yr       ACE2
# Blood_vessels_smoking_status[T.True]_ACE2_F_31yr       ACE2
# Blood_vessels_smoking_status[T.True]_ACE2_M_31yr       ACE2
# Blood_vessels_smoking_status[T.True]_CTSL_F_31yr       CTSL
# Blood_vessels_smoking_status[T.True]_CTSL_F_62yr       CTSL
# Blood_vessels_smoking_status[T.True]_CTSL_M_31yr       CTSL
# Blood_vessels_smoking_status[T.True]_CTSL_M_62yr       CTSL
# Blood_vessels_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2
# Blood_vessels_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2
# Blood_vessels_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2
# Blood_vessels_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2
# Lymphatics_smoking_status[T.True]_CTSL_M_62yr          CTSL
# Lymphatics_smoking_status[T.True]_CTSL_M_31yr          CTSL
# Lymphatics_smoking_status[T.True]_CTSL_F_31yr          CTSL
# Lymphatics_smoking_status[T.True]_CTSL_F_62yr          CTSL
# Lymphatics_smoking_status[T.True]_TMPRSS2_F_31yr    TMPRSS2
# Lymphatics_smoking_status[T.True]_TMPRSS2_F_62yr    TMPRSS2
# Lymphatics_smoking_status[T.True]_TMPRSS2_M_31yr    TMPRSS2
# Lymphatics_smoking_status[T.True]_TMPRSS2_M_62yr    TMPRSS2
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2
# Smooth_Muscle_smoking_status[T.True]_ACE2_M_62yr       ACE2
# Smooth_Muscle_smoking_status[T.True]_ACE2_M_31yr       ACE2
# Smooth_Muscle_smoking_status[T.True]_ACE2_F_31yr       ACE2
# Smooth_Muscle_smoking_status[T.True]_ACE2_F_62yr       ACE2
# Smooth_Muscle_smoking_status[T.True]_CTSL_M_31yr       CTSL
# Smooth_Muscle_smoking_status[T.True]_CTSL_F_62yr       CTSL
# Smooth_Muscle_smoking_status[T.True]_CTSL_F_31yr       CTSL
# Smooth_Muscle_smoking_status[T.True]_CTSL_M_62yr       CTSL
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2
# Mesothelium_smoking_status[T.True]_CTSL_F_62yr         CTSL
# Mesothelium_smoking_status[T.True]_CTSL_F_31yr         CTSL
# Mesothelium_smoking_status[T.True]_CTSL_M_62yr         CTSL
# Mesothelium_smoking_status[T.True]_CTSL_M_31yr         CTSL
# Mesothelium_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2
# Mesothelium_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2
# Mesothelium_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2
# Mesothelium_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2
# Lymphoid_smoking_status[T.True]_ACE2_M_62yr            ACE2
# Lymphoid_smoking_status[T.True]_ACE2_M_31yr            ACE2
# Lymphoid_smoking_status[T.True]_ACE2_F_31yr            ACE2
# Lymphoid_smoking_status[T.True]_ACE2_F_62yr            ACE2
# Lymphoid_smoking_status[T.True]_CTSL_M_62yr            CTSL
# Lymphoid_smoking_status[T.True]_CTSL_F_62yr            CTSL
# Lymphoid_smoking_status[T.True]_CTSL_F_31yr            CTSL
# Lymphoid_smoking_status[T.True]_CTSL_M_31yr            CTSL
# Lymphoid_smoking_status[T.True]_TMPRSS2_M_62yr      TMPRSS2
# Lymphoid_smoking_status[T.True]_TMPRSS2_M_31yr      TMPRSS2
# Lymphoid_smoking_status[T.True]_TMPRSS2_F_62yr      TMPRSS2
# Lymphoid_smoking_status[T.True]_TMPRSS2_F_31yr      TMPRSS2
# Myeloid_smoking_status[T.True]_ACE2_M_62yr             ACE2
# Myeloid_smoking_status[T.True]_ACE2_M_31yr             ACE2
# Myeloid_smoking_status[T.True]_ACE2_F_62yr             ACE2
# Myeloid_smoking_status[T.True]_ACE2_F_31yr             ACE2
# Myeloid_smoking_status[T.True]_CTSL_M_62yr             CTSL
# Myeloid_smoking_status[T.True]_CTSL_M_31yr             CTSL
# Myeloid_smoking_status[T.True]_CTSL_F_62yr             CTSL
# Myeloid_smoking_status[T.True]_CTSL_F_31yr             CTSL
# Myeloid_smoking_status[T.True]_TMPRSS2_M_62yr       TMPRSS2
# Myeloid_smoking_status[T.True]_TMPRSS2_M_31yr       TMPRSS2
# Myeloid_smoking_status[T.True]_TMPRSS2_F_62yr       TMPRSS2
# Myeloid_smoking_status[T.True]_TMPRSS2_F_31yr       TMPRSS2
#
#                                                           cell_identity  \
# Airway_epithelium_age_ACE2_F_NS                       Airway epithelium
# Airway_epithelium_age_ACE2_F_S                        Airway epithelium
# Airway_epithelium_age_ACE2_M_NS                       Airway epithelium
# Airway_epithelium_age_ACE2_M_S                        Airway epithelium
# Airway_epithelium_age_CTSL_F_NS                       Airway epithelium
# Airway_epithelium_age_CTSL_M_NS                       Airway epithelium
# Airway_epithelium_age_CTSL_F_S                        Airway epithelium
# Airway_epithelium_age_CTSL_M_S                        Airway epithelium
# Airway_epithelium_age_TMPRSS2_F_NS                    Airway epithelium
# Airway_epithelium_age_TMPRSS2_F_S                     Airway epithelium
# Airway_epithelium_age_TMPRSS2_M_NS                    Airway epithelium
# Airway_epithelium_age_TMPRSS2_M_S                     Airway epithelium
# Submucosal_Gland_age_ACE2_F_NS                         Submucosal Gland
# Submucosal_Gland_age_ACE2_F_S                          Submucosal Gland
# Submucosal_Gland_age_ACE2_M_NS                         Submucosal Gland
# Submucosal_Gland_age_ACE2_M_S                          Submucosal Gland
# Submucosal_Gland_age_CTSL_F_S                          Submucosal Gland
# Submucosal_Gland_age_CTSL_F_NS                         Submucosal Gland
# Submucosal_Gland_age_CTSL_M_S                          Submucosal Gland
# Submucosal_Gland_age_CTSL_M_NS                         Submucosal Gland
# Submucosal_Gland_age_TMPRSS2_F_NS                      Submucosal Gland
# Submucosal_Gland_age_TMPRSS2_F_S                       Submucosal Gland
# Submucosal_Gland_age_TMPRSS2_M_NS                      Submucosal Gland
# Submucosal_Gland_age_TMPRSS2_M_S                       Submucosal Gland
# Alveolar_epithelium_age_ACE2_F_NS                   Alveolar epithelium
# Alveolar_epithelium_age_ACE2_F_S                    Alveolar epithelium
# Alveolar_epithelium_age_ACE2_M_NS                   Alveolar epithelium
# Alveolar_epithelium_age_ACE2_M_S                    Alveolar epithelium
# Alveolar_epithelium_age_CTSL_F_S                    Alveolar epithelium
# Alveolar_epithelium_age_CTSL_M_NS                   Alveolar epithelium
# Alveolar_epithelium_age_CTSL_M_S                    Alveolar epithelium
# Alveolar_epithelium_age_CTSL_F_NS                   Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2_M_S                 Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2_M_NS                Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2_F_NS                Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2_F_S                 Alveolar epithelium
# Blood_vessels_age_ACE2_M_S                                Blood vessels
# Blood_vessels_age_ACE2_M_NS                               Blood vessels
# Blood_vessels_age_ACE2_F_S                                Blood vessels
# Blood_vessels_age_ACE2_F_NS                               Blood vessels
# Blood_vessels_age_CTSL_F_S                                Blood vessels
# Blood_vessels_age_CTSL_F_NS                               Blood vessels
# Blood_vessels_age_CTSL_M_S                                Blood vessels
# Blood_vessels_age_CTSL_M_NS                               Blood vessels
# Blood_vessels_age_TMPRSS2_F_NS                            Blood vessels
# Blood_vessels_age_TMPRSS2_F_S                             Blood vessels
# Blood_vessels_age_TMPRSS2_M_S                             Blood vessels
# Blood_vessels_age_TMPRSS2_M_NS                            Blood vessels
# Lymphatics_age_CTSL_M_NS                                     Lymphatics
# Lymphatics_age_CTSL_F_S                                      Lymphatics
# Lymphatics_age_CTSL_F_NS                                     Lymphatics
# Lymphatics_age_CTSL_M_S                                      Lymphatics
# Lymphatics_age_TMPRSS2_F_NS                                  Lymphatics
# Lymphatics_age_TMPRSS2_F_S                                   Lymphatics
# Lymphatics_age_TMPRSS2_M_NS                                  Lymphatics
# Lymphatics_age_TMPRSS2_M_S                                   Lymphatics
# Fibroblast_lineage_age_ACE2_F_NS                     Fibroblast lineage
# Fibroblast_lineage_age_ACE2_F_S                      Fibroblast lineage
# Fibroblast_lineage_age_ACE2_M_NS                     Fibroblast lineage
# Fibroblast_lineage_age_ACE2_M_S                      Fibroblast lineage
# Fibroblast_lineage_age_CTSL_M_S                      Fibroblast lineage
# Fibroblast_lineage_age_CTSL_M_NS                     Fibroblast lineage
# Fibroblast_lineage_age_CTSL_F_NS                     Fibroblast lineage
# Fibroblast_lineage_age_CTSL_F_S                      Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2_M_S                   Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2_M_NS                  Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2_F_S                   Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2_F_NS                  Fibroblast lineage
# Smooth_Muscle_age_ACE2_F_NS                               Smooth Muscle
# Smooth_Muscle_age_ACE2_F_S                                Smooth Muscle
# Smooth_Muscle_age_ACE2_M_NS                               Smooth Muscle
# Smooth_Muscle_age_ACE2_M_S                                Smooth Muscle
# Smooth_Muscle_age_CTSL_M_S                                Smooth Muscle
# Smooth_Muscle_age_CTSL_M_NS                               Smooth Muscle
# Smooth_Muscle_age_CTSL_F_S                                Smooth Muscle
# Smooth_Muscle_age_CTSL_F_NS                               Smooth Muscle
# Smooth_Muscle_age_TMPRSS2_F_S                             Smooth Muscle
# Smooth_Muscle_age_TMPRSS2_M_NS                            Smooth Muscle
# Smooth_Muscle_age_TMPRSS2_M_S                             Smooth Muscle
# Smooth_Muscle_age_TMPRSS2_F_NS                            Smooth Muscle
# Mesothelium_age_CTSL_M_S                                    Mesothelium
# Mesothelium_age_CTSL_M_NS                                   Mesothelium
# Mesothelium_age_CTSL_F_S                                    Mesothelium
# Mesothelium_age_CTSL_F_NS                                   Mesothelium
# Mesothelium_age_TMPRSS2_M_S                                 Mesothelium
# Mesothelium_age_TMPRSS2_F_S                                 Mesothelium
# Mesothelium_age_TMPRSS2_F_NS                                Mesothelium
# Mesothelium_age_TMPRSS2_M_NS                                Mesothelium
# Lymphoid_age_ACE2_M_S                                          Lymphoid
# Lymphoid_age_ACE2_M_NS                                         Lymphoid
# Lymphoid_age_ACE2_F_S                                          Lymphoid
# Lymphoid_age_ACE2_F_NS                                         Lymphoid
# Lymphoid_age_CTSL_M_S                                          Lymphoid
# Lymphoid_age_CTSL_M_NS                                         Lymphoid
# Lymphoid_age_CTSL_F_S                                          Lymphoid
# Lymphoid_age_CTSL_F_NS                                         Lymphoid
# Lymphoid_age_TMPRSS2_F_NS                                      Lymphoid
# Lymphoid_age_TMPRSS2_M_NS                                      Lymphoid
# Lymphoid_age_TMPRSS2_F_S                                       Lymphoid
# Lymphoid_age_TMPRSS2_M_S                                       Lymphoid
# Myeloid_age_ACE2_F_S                                            Myeloid
# Myeloid_age_ACE2_M_S                                            Myeloid
# Myeloid_age_ACE2_M_NS                                           Myeloid
# Myeloid_age_ACE2_F_NS                                           Myeloid
# Myeloid_age_CTSL_M_S                                            Myeloid
# Myeloid_age_CTSL_M_NS                                           Myeloid
# Myeloid_age_CTSL_F_S                                            Myeloid
# Myeloid_age_CTSL_F_NS                                           Myeloid
# Myeloid_age_TMPRSS2_F_NS                                        Myeloid
# Myeloid_age_TMPRSS2_F_S                                         Myeloid
# Myeloid_age_TMPRSS2_M_S                                         Myeloid
# Myeloid_age_TMPRSS2_M_NS                                        Myeloid
# Airway_epithelium_sex[T.male]_ACE2_31yr_NS            Airway epithelium
# Airway_epithelium_sex[T.male]_ACE2_31yr_S             Airway epithelium
# Airway_epithelium_sex[T.male]_ACE2_62yr_NS            Airway epithelium
# Airway_epithelium_sex[T.male]_ACE2_62yr_S             Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL_62yr_NS            Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL_31yr_S             Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL_31yr_NS            Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL_62yr_S             Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2_31yr_NS         Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2_31yr_S          Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr_NS         Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr_S          Airway epithelium
# Submucosal_Gland_sex[T.male]_ACE2_31yr_S               Submucosal Gland
# Submucosal_Gland_sex[T.male]_ACE2_62yr_NS              Submucosal Gland
# Submucosal_Gland_sex[T.male]_ACE2_62yr_S               Submucosal Gland
# Submucosal_Gland_sex[T.male]_ACE2_31yr_NS              Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL_62yr_NS              Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL_31yr_NS              Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL_31yr_S               Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL_62yr_S               Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2_31yr_NS           Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2_31yr_S            Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr_S            Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr_NS           Submucosal Gland
# Alveolar_epithelium_sex[T.male]_ACE2_31yr_NS        Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_ACE2_31yr_S         Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_ACE2_62yr_S         Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_ACE2_62yr_NS        Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL_31yr_NS        Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL_62yr_S         Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL_31yr_S         Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL_62yr_NS        Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2_31yr_NS     Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr_S      Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2_31yr_S      Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr_NS     Alveolar epithelium
# Blood_vessels_sex[T.male]_ACE2_31yr_NS                    Blood vessels
# Blood_vessels_sex[T.male]_ACE2_62yr_S                     Blood vessels
# Blood_vessels_sex[T.male]_ACE2_31yr_S                     Blood vessels
# Blood_vessels_sex[T.male]_ACE2_62yr_NS                    Blood vessels
# Blood_vessels_sex[T.male]_CTSL_31yr_NS                    Blood vessels
# Blood_vessels_sex[T.male]_CTSL_31yr_S                     Blood vessels
# Blood_vessels_sex[T.male]_CTSL_62yr_NS                    Blood vessels
# Blood_vessels_sex[T.male]_CTSL_62yr_S                     Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2_62yr_S                  Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2_62yr_NS                 Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2_31yr_S                  Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2_31yr_NS                 Blood vessels
# Lymphatics_sex[T.male]_CTSL_31yr_NS                          Lymphatics
# Lymphatics_sex[T.male]_CTSL_62yr_NS                          Lymphatics
# Lymphatics_sex[T.male]_CTSL_31yr_S                           Lymphatics
# Lymphatics_sex[T.male]_CTSL_62yr_S                           Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2_62yr_NS                       Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2_62yr_S                        Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2_31yr_NS                       Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2_31yr_S                        Lymphatics
# Fibroblast_lineage_sex[T.male]_ACE2_31yr_NS          Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_ACE2_31yr_S           Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_ACE2_62yr_NS          Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_ACE2_62yr_S           Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL_62yr_S           Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL_31yr_S           Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL_31yr_NS          Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL_62yr_NS          Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2_31yr_NS       Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr_NS       Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2_31yr_S        Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr_S        Fibroblast lineage
# Smooth_Muscle_sex[T.male]_ACE2_31yr_NS                    Smooth Muscle
# Smooth_Muscle_sex[T.male]_ACE2_31yr_S                     Smooth Muscle
# Smooth_Muscle_sex[T.male]_ACE2_62yr_NS                    Smooth Muscle
# Smooth_Muscle_sex[T.male]_ACE2_62yr_S                     Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL_31yr_NS                    Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL_62yr_S                     Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL_62yr_NS                    Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL_31yr_S                     Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2_31yr_NS                 Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2_31yr_S                  Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr_NS                 Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr_S                  Smooth Muscle
# Mesothelium_sex[T.male]_CTSL_62yr_S                         Mesothelium
# Mesothelium_sex[T.male]_CTSL_62yr_NS                        Mesothelium
# Mesothelium_sex[T.male]_CTSL_31yr_S                         Mesothelium
# Mesothelium_sex[T.male]_CTSL_31yr_NS                        Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2_62yr_S                      Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2_62yr_NS                     Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2_31yr_S                      Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2_31yr_NS                     Mesothelium
# Lymphoid_sex[T.male]_ACE2_62yr_S                               Lymphoid
# Lymphoid_sex[T.male]_ACE2_62yr_NS                              Lymphoid
# Lymphoid_sex[T.male]_ACE2_31yr_S                               Lymphoid
# Lymphoid_sex[T.male]_ACE2_31yr_NS                              Lymphoid
# Lymphoid_sex[T.male]_CTSL_62yr_S                               Lymphoid
# Lymphoid_sex[T.male]_CTSL_31yr_S                               Lymphoid
# Lymphoid_sex[T.male]_CTSL_31yr_NS                              Lymphoid
# Lymphoid_sex[T.male]_CTSL_62yr_NS                              Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2_62yr_NS                           Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2_31yr_S                            Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2_31yr_NS                           Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2_62yr_S                            Lymphoid
# Myeloid_sex[T.male]_ACE2_62yr_S                                 Myeloid
# Myeloid_sex[T.male]_ACE2_62yr_NS                                Myeloid
# Myeloid_sex[T.male]_ACE2_31yr_S                                 Myeloid
# Myeloid_sex[T.male]_ACE2_31yr_NS                                Myeloid
# Myeloid_sex[T.male]_CTSL_62yr_S                                 Myeloid
# Myeloid_sex[T.male]_CTSL_62yr_NS                                Myeloid
# Myeloid_sex[T.male]_CTSL_31yr_S                                 Myeloid
# Myeloid_sex[T.male]_CTSL_31yr_NS                                Myeloid
# Myeloid_sex[T.male]_TMPRSS2_62yr_S                              Myeloid
# Myeloid_sex[T.male]_TMPRSS2_62yr_NS                             Myeloid
# Myeloid_sex[T.male]_TMPRSS2_31yr_S                              Myeloid
# Myeloid_sex[T.male]_TMPRSS2_31yr_NS                             Myeloid
# Airway_epithelium_smoking_status[T.True]_ACE2_F...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_ACE2_F...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_ACE2_M...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_ACE2_M...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_CTSL_M...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_CTSL_M...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_CTSL_F...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_CTSL_F...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_TMPRSS...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_TMPRSS...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_TMPRSS...    Airway epithelium
# Airway_epithelium_smoking_status[T.True]_TMPRSS...    Airway epithelium
# Submucosal_Gland_smoking_status[T.True]_ACE2_F_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_ACE2_F_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_ACE2_M_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_ACE2_M_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_CTSL_F_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_CTSL_F_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_CTSL_M_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_CTSL_M_...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...     Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...     Submucosal Gland
# Alveolar_epithelium_smoking_status[T.True]_ACE2...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_ACE2...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_ACE2...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_ACE2...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_CTSL...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_CTSL...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_CTSL...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_CTSL...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  Alveolar epithelium
# Blood_vessels_smoking_status[T.True]_ACE2_M_62yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_ACE2_F_62yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_ACE2_F_31yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_ACE2_M_31yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_CTSL_F_31yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_CTSL_F_62yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_CTSL_M_31yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_CTSL_M_62yr          Blood vessels
# Blood_vessels_smoking_status[T.True]_TMPRSS2_M_...        Blood vessels
# Blood_vessels_smoking_status[T.True]_TMPRSS2_M_...        Blood vessels
# Blood_vessels_smoking_status[T.True]_TMPRSS2_F_...        Blood vessels
# Blood_vessels_smoking_status[T.True]_TMPRSS2_F_...        Blood vessels
# Lymphatics_smoking_status[T.True]_CTSL_M_62yr                Lymphatics
# Lymphatics_smoking_status[T.True]_CTSL_M_31yr                Lymphatics
# Lymphatics_smoking_status[T.True]_CTSL_F_31yr                Lymphatics
# Lymphatics_smoking_status[T.True]_CTSL_F_62yr                Lymphatics
# Lymphatics_smoking_status[T.True]_TMPRSS2_F_31yr             Lymphatics
# Lymphatics_smoking_status[T.True]_TMPRSS2_F_62yr             Lymphatics
# Lymphatics_smoking_status[T.True]_TMPRSS2_M_31yr             Lymphatics
# Lymphatics_smoking_status[T.True]_TMPRSS2_M_62yr             Lymphatics
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...   Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...   Fibroblast lineage
# Smooth_Muscle_smoking_status[T.True]_ACE2_M_62yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_ACE2_M_31yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_ACE2_F_31yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_ACE2_F_62yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_CTSL_M_31yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_CTSL_F_62yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_CTSL_F_31yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_CTSL_M_62yr          Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_M_...        Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_M_...        Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_F_...        Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_F_...        Smooth Muscle
# Mesothelium_smoking_status[T.True]_CTSL_F_62yr              Mesothelium
# Mesothelium_smoking_status[T.True]_CTSL_F_31yr              Mesothelium
# Mesothelium_smoking_status[T.True]_CTSL_M_62yr              Mesothelium
# Mesothelium_smoking_status[T.True]_CTSL_M_31yr              Mesothelium
# Mesothelium_smoking_status[T.True]_TMPRSS2_F_62yr           Mesothelium
# Mesothelium_smoking_status[T.True]_TMPRSS2_M_31yr           Mesothelium
# Mesothelium_smoking_status[T.True]_TMPRSS2_F_31yr           Mesothelium
# Mesothelium_smoking_status[T.True]_TMPRSS2_M_62yr           Mesothelium
# Lymphoid_smoking_status[T.True]_ACE2_M_62yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_ACE2_M_31yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_ACE2_F_31yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_ACE2_F_62yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_CTSL_M_62yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_CTSL_F_62yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_CTSL_F_31yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_CTSL_M_31yr                    Lymphoid
# Lymphoid_smoking_status[T.True]_TMPRSS2_M_62yr                 Lymphoid
# Lymphoid_smoking_status[T.True]_TMPRSS2_M_31yr                 Lymphoid
# Lymphoid_smoking_status[T.True]_TMPRSS2_F_62yr                 Lymphoid
# Lymphoid_smoking_status[T.True]_TMPRSS2_F_31yr                 Lymphoid
# Myeloid_smoking_status[T.True]_ACE2_M_62yr                      Myeloid
# Myeloid_smoking_status[T.True]_ACE2_M_31yr                      Myeloid
# Myeloid_smoking_status[T.True]_ACE2_F_62yr                      Myeloid
# Myeloid_smoking_status[T.True]_ACE2_F_31yr                      Myeloid
# Myeloid_smoking_status[T.True]_CTSL_M_62yr                      Myeloid
# Myeloid_smoking_status[T.True]_CTSL_M_31yr                      Myeloid
# Myeloid_smoking_status[T.True]_CTSL_F_62yr                      Myeloid
# Myeloid_smoking_status[T.True]_CTSL_F_31yr                      Myeloid
# Myeloid_smoking_status[T.True]_TMPRSS2_M_62yr                   Myeloid
# Myeloid_smoking_status[T.True]_TMPRSS2_M_31yr                   Myeloid
# Myeloid_smoking_status[T.True]_TMPRSS2_F_62yr                   Myeloid
# Myeloid_smoking_status[T.True]_TMPRSS2_F_31yr                   Myeloid
#
#                                                                  covariate  \
# Airway_epithelium_age_ACE2_F_NS                                        age
# Airway_epithelium_age_ACE2_F_S                                         age
# Airway_epithelium_age_ACE2_M_NS                                        age
# Airway_epithelium_age_ACE2_M_S                                         age
# Airway_epithelium_age_CTSL_F_NS                                        age
# Airway_epithelium_age_CTSL_M_NS                                        age
# Airway_epithelium_age_CTSL_F_S                                         age
# Airway_epithelium_age_CTSL_M_S                                         age
# Airway_epithelium_age_TMPRSS2_F_NS                                     age
# Airway_epithelium_age_TMPRSS2_F_S                                      age
# Airway_epithelium_age_TMPRSS2_M_NS                                     age
# Airway_epithelium_age_TMPRSS2_M_S                                      age
# Submucosal_Gland_age_ACE2_F_NS                                         age
# Submucosal_Gland_age_ACE2_F_S                                          age
# Submucosal_Gland_age_ACE2_M_NS                                         age
# Submucosal_Gland_age_ACE2_M_S                                          age
# Submucosal_Gland_age_CTSL_F_S                                          age
# Submucosal_Gland_age_CTSL_F_NS                                         age
# ...
# Mesothelium_age_TMPRSS2_F_NS                        TMPRSS2 0
# Mesothelium_age_TMPRSS2_M_NS                        TMPRSS2 1
# Lymphoid_age_ACE2_M_S                                  ACE2 3
# Lymphoid_age_ACE2_M_NS                                 ACE2 1
# Lymphoid_age_ACE2_F_S                                  ACE2 2
# Lymphoid_age_ACE2_F_NS                                 ACE2 0
# Lymphoid_age_CTSL_M_S                                  CTSL 3
# Lymphoid_age_CTSL_M_NS                                 CTSL 1
# Lymphoid_age_CTSL_F_S                                  CTSL 2
# Lymphoid_age_CTSL_F_NS                                 CTSL 0
# Lymphoid_age_TMPRSS2_F_NS                           TMPRSS2 0
# Lymphoid_age_TMPRSS2_M_NS                           TMPRSS2 1
# Lymphoid_age_TMPRSS2_F_S                            TMPRSS2 2
# Lymphoid_age_TMPRSS2_M_S                            TMPRSS2 3
# Myeloid_age_ACE2_F_S                                   ACE2 2
# Myeloid_age_ACE2_M_S                                   ACE2 3
# Myeloid_age_ACE2_M_NS                                  ACE2 1
# Myeloid_age_ACE2_F_NS                                  ACE2 0
# Myeloid_age_CTSL_M_S                                   CTSL 3
# Myeloid_age_CTSL_M_NS                                  CTSL 1
# Myeloid_age_CTSL_F_S                                   CTSL 2
# Myeloid_age_CTSL_F_NS                                  CTSL 0
# Myeloid_age_TMPRSS2_F_NS                            TMPRSS2 0
# Myeloid_age_TMPRSS2_F_S                             TMPRSS2 2
# Myeloid_age_TMPRSS2_M_S                             TMPRSS2 3
# Myeloid_age_TMPRSS2_M_NS                            TMPRSS2 1
# Airway_epithelium_sex[T.male]_ACE2_31yr_NS             ACE2 0
# Airway_epithelium_sex[T.male]_ACE2_31yr_S              ACE2 1
# Airway_epithelium_sex[T.male]_ACE2_62yr_NS             ACE2 2
# Airway_epithelium_sex[T.male]_ACE2_62yr_S              ACE2 3
# Airway_epithelium_sex[T.male]_CTSL_62yr_NS             CTSL 2
# Airway_epithelium_sex[T.male]_CTSL_31yr_S              CTSL 1
# Airway_epithelium_sex[T.male]_CTSL_31yr_NS             CTSL 0
# Airway_epithelium_sex[T.male]_CTSL_62yr_S              CTSL 3
# Airway_epithelium_sex[T.male]_TMPRSS2_31yr_NS       TMPRSS2 0
# Airway_epithelium_sex[T.male]_TMPRSS2_31yr_S        TMPRSS2 1
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr_NS       TMPRSS2 2
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr_S        TMPRSS2 3
# Submucosal_Gland_sex[T.male]_ACE2_31yr_S               ACE2 1
# Submucosal_Gland_sex[T.male]_ACE2_62yr_NS              ACE2 2
# Submucosal_Gland_sex[T.male]_ACE2_62yr_S               ACE2 3
# Submucosal_Gland_sex[T.male]_ACE2_31yr_NS              ACE2 0
# Submucosal_Gland_sex[T.male]_CTSL_62yr_NS              CTSL 2
# Submucosal_Gland_sex[T.male]_CTSL_31yr_NS              CTSL 0
# Submucosal_Gland_sex[T.male]_CTSL_31yr_S               CTSL 1
# Submucosal_Gland_sex[T.male]_CTSL_62yr_S               CTSL 3
# Submucosal_Gland_sex[T.male]_TMPRSS2_31yr_NS        TMPRSS2 0
# Submucosal_Gland_sex[T.male]_TMPRSS2_31yr_S         TMPRSS2 1
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr_S         TMPRSS2 3
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr_NS        TMPRSS2 2
# Alveolar_epithelium_sex[T.male]_ACE2_31yr_NS           ACE2 0
# Alveolar_epithelium_sex[T.male]_ACE2_31yr_S            ACE2 1
# Alveolar_epithelium_sex[T.male]_ACE2_62yr_S            ACE2 3
# Alveolar_epithelium_sex[T.male]_ACE2_62yr_NS           ACE2 2
# Alveolar_epithelium_sex[T.male]_CTSL_31yr_NS           CTSL 0
# Alveolar_epithelium_sex[T.male]_CTSL_62yr_S            CTSL 3
# Alveolar_epithelium_sex[T.male]_CTSL_31yr_S            CTSL 1
# Alveolar_epithelium_sex[T.male]_CTSL_62yr_NS           CTSL 2
# Alveolar_epithelium_sex[T.male]_TMPRSS2_31yr_NS     TMPRSS2 0
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr_S      TMPRSS2 3
# Alveolar_epithelium_sex[T.male]_TMPRSS2_31yr_S      TMPRSS2 1
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr_NS     TMPRSS2 2
# Blood_vessels_sex[T.male]_ACE2_31yr_NS                 ACE2 0
# Blood_vessels_sex[T.male]_ACE2_62yr_S                  ACE2 3
# Blood_vessels_sex[T.male]_ACE2_31yr_S                  ACE2 1
# Blood_vessels_sex[T.male]_ACE2_62yr_NS                 ACE2 2
# Blood_vessels_sex[T.male]_CTSL_31yr_NS                 CTSL 0
# Blood_vessels_sex[T.male]_CTSL_31yr_S                  CTSL 1
# Blood_vessels_sex[T.male]_CTSL_62yr_NS                 CTSL 2
# Blood_vessels_sex[T.male]_CTSL_62yr_S                  CTSL 3
# Blood_vessels_sex[T.male]_TMPRSS2_62yr_S            TMPRSS2 3
# Blood_vessels_sex[T.male]_TMPRSS2_62yr_NS           TMPRSS2 2
# Blood_vessels_sex[T.male]_TMPRSS2_31yr_S            TMPRSS2 1
# Blood_vessels_sex[T.male]_TMPRSS2_31yr_NS           TMPRSS2 0
# Lymphatics_sex[T.male]_CTSL_31yr_NS                    CTSL 0
# Lymphatics_sex[T.male]_CTSL_62yr_NS                    CTSL 2
# Lymphatics_sex[T.male]_CTSL_31yr_S                     CTSL 1
# Lymphatics_sex[T.male]_CTSL_62yr_S                     CTSL 3
# Lymphatics_sex[T.male]_TMPRSS2_62yr_NS              TMPRSS2 2
# Lymphatics_sex[T.male]_TMPRSS2_62yr_S               TMPRSS2 3
# Lymphatics_sex[T.male]_TMPRSS2_31yr_NS              TMPRSS2 0
# Lymphatics_sex[T.male]_TMPRSS2_31yr_S               TMPRSS2 1
# Fibroblast_lineage_sex[T.male]_ACE2_31yr_NS            ACE2 0
# Fibroblast_lineage_sex[T.male]_ACE2_31yr_S             ACE2 1
# Fibroblast_lineage_sex[T.male]_ACE2_62yr_NS            ACE2 2
# Fibroblast_lineage_sex[T.male]_ACE2_62yr_S             ACE2 3
# Fibroblast_lineage_sex[T.male]_CTSL_62yr_S             CTSL 3
# Fibroblast_lineage_sex[T.male]_CTSL_31yr_S             CTSL 1
# Fibroblast_lineage_sex[T.male]_CTSL_31yr_NS            CTSL 0
# Fibroblast_lineage_sex[T.male]_CTSL_62yr_NS            CTSL 2
# Fibroblast_lineage_sex[T.male]_TMPRSS2_31yr_NS      TMPRSS2 0
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr_NS      TMPRSS2 2
# Fibroblast_lineage_sex[T.male]_TMPRSS2_31yr_S       TMPRSS2 1
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr_S       TMPRSS2 3
# Smooth_Muscle_sex[T.male]_ACE2_31yr_NS                 ACE2 0
# Smooth_Muscle_sex[T.male]_ACE2_31yr_S                  ACE2 1
# Smooth_Muscle_sex[T.male]_ACE2_62yr_NS                 ACE2 2
# Smooth_Muscle_sex[T.male]_ACE2_62yr_S                  ACE2 3
# Smooth_Muscle_sex[T.male]_CTSL_31yr_NS                 CTSL 0
# Smooth_Muscle_sex[T.male]_CTSL_62yr_S                  CTSL 3
# Smooth_Muscle_sex[T.male]_CTSL_62yr_NS                 CTSL 2
# Smooth_Muscle_sex[T.male]_CTSL_31yr_S                  CTSL 1
# Smooth_Muscle_sex[T.male]_TMPRSS2_31yr_NS           TMPRSS2 0
# Smooth_Muscle_sex[T.male]_TMPRSS2_31yr_S            TMPRSS2 1
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr_NS           TMPRSS2 2
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr_S            TMPRSS2 3
# Mesothelium_sex[T.male]_CTSL_62yr_S                    CTSL 3
# Mesothelium_sex[T.male]_CTSL_62yr_NS                   CTSL 2
# Mesothelium_sex[T.male]_CTSL_31yr_S                    CTSL 1
# Mesothelium_sex[T.male]_CTSL_31yr_NS                   CTSL 0
# Mesothelium_sex[T.male]_TMPRSS2_62yr_S              TMPRSS2 3
# Mesothelium_sex[T.male]_TMPRSS2_62yr_NS             TMPRSS2 2
# Mesothelium_sex[T.male]_TMPRSS2_31yr_S              TMPRSS2 1
# Mesothelium_sex[T.male]_TMPRSS2_31yr_NS             TMPRSS2 0
# Lymphoid_sex[T.male]_ACE2_62yr_S                       ACE2 3
# Lymphoid_sex[T.male]_ACE2_62yr_NS                      ACE2 2
# Lymphoid_sex[T.male]_ACE2_31yr_S                       ACE2 1
# Lymphoid_sex[T.male]_ACE2_31yr_NS                      ACE2 0
# Lymphoid_sex[T.male]_CTSL_62yr_S                       CTSL 3
# Lymphoid_sex[T.male]_CTSL_31yr_S                       CTSL 1
# Lymphoid_sex[T.male]_CTSL_31yr_NS                      CTSL 0
# Lymphoid_sex[T.male]_CTSL_62yr_NS                      CTSL 2
# Lymphoid_sex[T.male]_TMPRSS2_62yr_NS                TMPRSS2 2
# Lymphoid_sex[T.male]_TMPRSS2_31yr_S                 TMPRSS2 1
# Lymphoid_sex[T.male]_TMPRSS2_31yr_NS                TMPRSS2 0
# Lymphoid_sex[T.male]_TMPRSS2_62yr_S                 TMPRSS2 3
# Myeloid_sex[T.male]_ACE2_62yr_S                        ACE2 3
# Myeloid_sex[T.male]_ACE2_62yr_NS                       ACE2 2
# Myeloid_sex[T.male]_ACE2_31yr_S                        ACE2 1
# Myeloid_sex[T.male]_ACE2_31yr_NS                       ACE2 0
# Myeloid_sex[T.male]_CTSL_62yr_S                        CTSL 3
# Myeloid_sex[T.male]_CTSL_62yr_NS                       CTSL 2
# Myeloid_sex[T.male]_CTSL_31yr_S                        CTSL 1
# Myeloid_sex[T.male]_CTSL_31yr_NS                       CTSL 0
# Myeloid_sex[T.male]_TMPRSS2_62yr_S                  TMPRSS2 3
# Myeloid_sex[T.male]_TMPRSS2_62yr_NS                 TMPRSS2 2
# Myeloid_sex[T.male]_TMPRSS2_31yr_S                  TMPRSS2 1
# Myeloid_sex[T.male]_TMPRSS2_31yr_NS                 TMPRSS2 0
# Airway_epithelium_smoking_status[T.True]_ACE2_F...     ACE2 0
# Airway_epithelium_smoking_status[T.True]_ACE2_F...     ACE2 2
# Airway_epithelium_smoking_status[T.True]_ACE2_M...     ACE2 1
# Airway_epithelium_smoking_status[T.True]_ACE2_M...     ACE2 3
# Airway_epithelium_smoking_status[T.True]_CTSL_M...     CTSL 1
# Airway_epithelium_smoking_status[T.True]_CTSL_M...     CTSL 3
# Airway_epithelium_smoking_status[T.True]_CTSL_F...     CTSL 0
# Airway_epithelium_smoking_status[T.True]_CTSL_F...     CTSL 2
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2 3
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2 1
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2 2
# Airway_epithelium_smoking_status[T.True]_TMPRSS...  TMPRSS2 0
# Submucosal_Gland_smoking_status[T.True]_ACE2_F_...     ACE2 0
# Submucosal_Gland_smoking_status[T.True]_ACE2_F_...     ACE2 2
# Submucosal_Gland_smoking_status[T.True]_ACE2_M_...     ACE2 1
# Submucosal_Gland_smoking_status[T.True]_ACE2_M_...     ACE2 3
# Submucosal_Gland_smoking_status[T.True]_CTSL_F_...     CTSL 0
# Submucosal_Gland_smoking_status[T.True]_CTSL_F_...     CTSL 2
# Submucosal_Gland_smoking_status[T.True]_CTSL_M_...     CTSL 1
# Submucosal_Gland_smoking_status[T.True]_CTSL_M_...     CTSL 3
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2 0
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2 2
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2 3
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2...  TMPRSS2 1
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2 0
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2 2
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2 1
# Alveolar_epithelium_smoking_status[T.True]_ACE2...     ACE2 3
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL 3
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL 0
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL 1
# Alveolar_epithelium_smoking_status[T.True]_CTSL...     CTSL 2
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2 3
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2 1
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2 0
# Alveolar_epithelium_smoking_status[T.True]_TMPR...  TMPRSS2 2
# Blood_vessels_smoking_status[T.True]_ACE2_M_62yr       ACE2 3
# Blood_vessels_smoking_status[T.True]_ACE2_F_62yr       ACE2 2
# Blood_vessels_smoking_status[T.True]_ACE2_F_31yr       ACE2 0
# Blood_vessels_smoking_status[T.True]_ACE2_M_31yr       ACE2 1
# Blood_vessels_smoking_status[T.True]_CTSL_F_31yr       CTSL 0
# Blood_vessels_smoking_status[T.True]_CTSL_F_62yr       CTSL 2
# Blood_vessels_smoking_status[T.True]_CTSL_M_31yr       CTSL 1
# Blood_vessels_smoking_status[T.True]_CTSL_M_62yr       CTSL 3
# Blood_vessels_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2 3
# Blood_vessels_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2 1
# Blood_vessels_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2 2
# Blood_vessels_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2 0
# Lymphatics_smoking_status[T.True]_CTSL_M_62yr          CTSL 3
# Lymphatics_smoking_status[T.True]_CTSL_M_31yr          CTSL 1
# Lymphatics_smoking_status[T.True]_CTSL_F_31yr          CTSL 0
# Lymphatics_smoking_status[T.True]_CTSL_F_62yr          CTSL 2
# Lymphatics_smoking_status[T.True]_TMPRSS2_F_31yr    TMPRSS2 0
# Lymphatics_smoking_status[T.True]_TMPRSS2_F_62yr    TMPRSS2 2
# Lymphatics_smoking_status[T.True]_TMPRSS2_M_31yr    TMPRSS2 1
# Lymphatics_smoking_status[T.True]_TMPRSS2_M_62yr    TMPRSS2 3
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2 0
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2 1
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2 3
# Fibroblast_lineage_smoking_status[T.True]_ACE2_...     ACE2 2
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL 3
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL 1
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL 2
# Fibroblast_lineage_smoking_status[T.True]_CTSL_...     CTSL 0
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2 1
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2 2
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2 0
# Fibroblast_lineage_smoking_status[T.True]_TMPRS...  TMPRSS2 3
# Smooth_Muscle_smoking_status[T.True]_ACE2_M_62yr       ACE2 3
# Smooth_Muscle_smoking_status[T.True]_ACE2_M_31yr       ACE2 1
# Smooth_Muscle_smoking_status[T.True]_ACE2_F_31yr       ACE2 0
# Smooth_Muscle_smoking_status[T.True]_ACE2_F_62yr       ACE2 2
# Smooth_Muscle_smoking_status[T.True]_CTSL_M_31yr       CTSL 1
# Smooth_Muscle_smoking_status[T.True]_CTSL_F_62yr       CTSL 2
# Smooth_Muscle_smoking_status[T.True]_CTSL_F_31yr       CTSL 0
# Smooth_Muscle_smoking_status[T.True]_CTSL_M_62yr       CTSL 3
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2 1
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_M_...  TMPRSS2 3
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2 0
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2_F_...  TMPRSS2 2
# Mesothelium_smoking_status[T.True]_CTSL_F_62yr         CTSL 2
# Mesothelium_smoking_status[T.True]_CTSL_F_31yr         CTSL 0
# Mesothelium_smoking_status[T.True]_CTSL_M_62yr         CTSL 3
# Mesothelium_smoking_status[T.True]_CTSL_M_31yr         CTSL 1
# Mesothelium_smoking_status[T.True]_TMPRSS2_F_62yr   TMPRSS2 2
# Mesothelium_smoking_status[T.True]_TMPRSS2_M_31yr   TMPRSS2 1
# Mesothelium_smoking_status[T.True]_TMPRSS2_F_31yr   TMPRSS2 0
# Mesothelium_smoking_status[T.True]_TMPRSS2_M_62yr   TMPRSS2 3
# Lymphoid_smoking_status[T.True]_ACE2_M_62yr            ACE2 3
# Lymphoid_smoking_status[T.True]_ACE2_M_31yr            ACE2 1
# Lymphoid_smoking_status[T.True]_ACE2_F_31yr            ACE2 0
# Lymphoid_smoking_status[T.True]_ACE2_F_62yr            ACE2 2
# Lymphoid_smoking_status[T.True]_CTSL_M_62yr            CTSL 3
# Lymphoid_smoking_status[T.True]_CTSL_F_62yr            CTSL 2
# Lymphoid_smoking_status[T.True]_CTSL_F_31yr            CTSL 0
# Lymphoid_smoking_status[T.True]_CTSL_M_31yr            CTSL 1
# Lymphoid_smoking_status[T.True]_TMPRSS2_M_62yr      TMPRSS2 3
# Lymphoid_smoking_status[T.True]_TMPRSS2_M_31yr      TMPRSS2 1
# Lymphoid_smoking_status[T.True]_TMPRSS2_F_62yr      TMPRSS2 2
# Lymphoid_smoking_status[T.True]_TMPRSS2_F_31yr      TMPRSS2 0
# Myeloid_smoking_status[T.True]_ACE2_M_62yr             ACE2 3
# Myeloid_smoking_status[T.True]_ACE2_M_31yr             ACE2 1
# Myeloid_smoking_status[T.True]_ACE2_F_62yr             ACE2 2
# Myeloid_smoking_status[T.True]_ACE2_F_31yr             ACE2 0
# Myeloid_smoking_status[T.True]_CTSL_M_62yr             CTSL 3
# Myeloid_smoking_status[T.True]_CTSL_M_31yr             CTSL 1
# Myeloid_smoking_status[T.True]_CTSL_F_62yr             CTSL 2
# Myeloid_smoking_status[T.True]_CTSL_F_31yr             CTSL 0
# Myeloid_smoking_status[T.True]_TMPRSS2_M_62yr       TMPRSS2 3
# Myeloid_smoking_status[T.True]_TMPRSS2_M_31yr       TMPRSS2 1
# Myeloid_smoking_status[T.True]_TMPRSS2_F_62yr       TMPRSS2 2
# Myeloid_smoking_status[T.True]_TMPRSS2_F_31yr       TMPRSS2 0

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.2
for i in range(3):
    for alpha in range(4):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.2
for alpha in range(4):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(4)]

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

xlims_top = [[None, None, None],
             [None, 1.25, None],
             [0.122, 2.0, None],
             [None, None, None]]
xlims_bot = [[None, None, None],
             [None, None, -3.2],
             [-0.058, -3.05, -4.5],
             [None, None, None]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(5.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(4)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-2.0, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(4)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [-0.7, -0.1], frameon=False, title=None)

#Smoking legend
smoking_labs = [j[0] for j in sorted(list(eval_encoding['smoking_status[T.True]'].items()), key=lambda i: i[1])]
smoking_handles = [patches.Patch(color=shades[i], label=smoking_labs[i]) for i in range(4)]
leg_smoking = plt.legend(handles=smoking_handles, bbox_to_anchor = [0.6, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[4], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[8], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.3, 2.1], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)
plt.gca().add_artist(leg_smoking)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl2_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# <ErrorbarContainer object of 3 artists>
# (-0.01875014535473571, 0.04265782891058251)
# <ErrorbarContainer object of 3 artists>
# (-0.5201315036636309, 1.1310905174057635)
# <ErrorbarContainer object of 3 artists>
# (-1.1753694888924895, 0.767282121799882)
# <ErrorbarContainer object of 3 artists>
# (-0.08943513159283921, 0.018369905771755807)
# <ErrorbarContainer object of 3 artists>
# (-1.2409092843495075, 1.25)
# <ErrorbarContainer object of 3 artists>
# (-3.2, 2.3757172304810714)
# <ErrorbarContainer object of 3 artists>
# (-0.058, 0.122)
# <ErrorbarContainer object of 3 artists>
# (-3.05, 2.0)
# <ErrorbarContainer object of 3 artists>
# (-4.5, 6.45891399774852)
# <ErrorbarContainer object of 3 artists>
# (-0.06541878039750679, 0.056021610078460064)
# <ErrorbarContainer object of 3 artists>
# (-1.2732048063396193, 1.7954974325289956)
# <ErrorbarContainer object of 3 artists>
# (-1.8712348362300557, 1.4531056357131844)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')
