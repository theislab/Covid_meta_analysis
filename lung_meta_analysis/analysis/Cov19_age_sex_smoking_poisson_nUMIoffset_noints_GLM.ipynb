# %% [markdown]
# This notebook contains the code for the meta-analysis of healthy lung data for ACE2, TMPRSS2, and CTSL. It contains the simple model without interaction terms that was run on the cell-level data (not pseudo-bulk, no holdout analysis)

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors
from matplotlib import patches
import seaborn as sns
import batchglm
import diffxpy.api as de
import patsy as pat
from statsmodels.stats.multitest import multipletests
import logging, warnings
import statsmodels.api as sm
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
de.__version__

logging.getLogger("tensorflow").setLevel(logging.ERROR)
logging.getLogger("batchglm").setLevel(logging.INFO)
logging.getLogger("diffxpy").setLevel(logging.INFO)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1
# 'v0.7.3'

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

adata_diffxpy = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study/COVID19_lung_atlas_revision_v3.h5ad'

output_folder = 'diffxpy_out/'

de_output_base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm_smoking_nUMIoffset_noInts'

# %% [markdown]
# # Read the data

# %%
adata = sc.read(adata_diffxpy)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1320896 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new'

# %%
adata.obs.age = adata.obs.age.astype(float)

# %%
adata.obs.dtypes
# Out:
# age                         float64
# anatomical_region          category
# donor                      category
# last_author/PI             category
# lung_vs_nasal              category
# notes                      category
# original_celltype_ann      category
# sample                     category
# sex                        category
# smoking                    category
# total_counts                float64
# smoked_boolean             category
# last_author_sample_name    category
# ann_level_1                category
# ann_level_2                category
# ann_level_3                category
# ann_level_4                category
# ann_level_5                category
# ann_highest_res               int64
# ann_new                        bool
# dtype: object

# %%
adata.obs['dataset'] = adata.obs['last_author/PI']

# %%
adata.obs.dataset.value_counts()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    95303
# Spence                      78401
# Barbry/Leroy                76981
# Krasnow/Quake               60993
# Meyer                       57020
# Rawlins                     53409
# Regev                       43527
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Misharin                    28329
# Xavier/Regev                25552
# Spira/Campbell              24455
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Schultze                    22641
# Schiller                    20776
# Nawijn                      18197
# Teichmann                   12971
# Kropski/Banovich_dnar        8359
# Shalek                       7603
# Linnarsson                   4640
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      2207
# Schultze/Falk                1965
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64

# %% [markdown]
# # Filter the data

# %% [markdown]
# Keep only datsets with:
# - more than 1 donor
# - non-fetal
# - lung

# %%
# Remove fetal datasets
dats_to_remove = set(['Rawlins', 'Spence', 'Linnarsson'])

# %%
dat = adata.obs.groupby(['donor']).agg({'sex':'first', 'age':'first', 'dataset':'first'})

# Single donor filter
don_tab = dat['dataset'].value_counts()
dats_to_remove.update(set(don_tab.index[don_tab == 1]))

# %%
dats_to_remove = list(dats_to_remove)
dats_to_remove
# Out:
# ['Schultze/Falk', 'Linnarsson', 'Spence', 'Misharin', 'Rawlins']

# %%
adata = adata[~adata.obs.dataset.isin(dats_to_remove)].copy()

# %%
adata.obs.lung_vs_nasal.value_counts()
# Out:
# lung     1096604
# nasal      57548
# Name: lung_vs_nasal, dtype: int64

# %%
# Filter for only lung data
adata = adata[adata.obs.lung_vs_nasal.isin(['lung']),].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1096604 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset'

# %%
adata.obs['sample'].nunique()
adata.obs['donor'].nunique()
adata.obs['dataset'].nunique()
# Out:
# 309
# 185
# 24

# %% [markdown]
# # Binarize smoking status

# %%
adata.obs.smoking.value_counts()
# Out:
# never              575345
# current            173020
# nan                111184
# former              53487
# non-smoker          42367
# never-smoker        33119
# active              29396
# smoked              28197
# current/former      23573
# heavy               15663
# current/former?      5162
# light                3316
# Former               1385
# Current               610
# Never Smoker          426
# Current Smoker        354
# Name: smoking, dtype: int64

# %%
adata.obs['smoking_status'] = adata.obs.smoked_boolean
#adata.obs['smoking_status'] = [True if stat in ['current', 'smoked', 'active', 'former', 'heavy', 'light'] else False if stat in ['never', 'nonsmoker'] else "nan" for stat in adata.obs.smoking]

# %%
adata.obs.smoking_status.value_counts()
# Out:
# False    651257
# True     334163
# nan      111184
# Name: smoking_status, dtype: int64

# %% [markdown]
# ## Filter out data w/o smoking status

# %%
pd.crosstab(adata.obs.dataset, adata.obs.smoking)
# Out:
# smoking                  Current  Current Smoker  Former  Never Smoker  \
# dataset
# Barbry/Leroy                   0               0       0             0
# Beane                          0               0       0             0
# Beane/Campbell                 0             354       0           426
# Eils/Conrad/Kreuter            0               0       0             0
# Kaminski                       0               0       0             0
# Koenigshoff                    0               0       0             0
# Krasnow/Quake                  0               0       0             0
# Kropski/Banovich_dnar          0               0       0             0
# Kropski/Banovich_vand          0               0       0             0
# Lafyatis/Rojas                 0               0       0             0
# Mazzilli/Campbell/Beane      610               0    1385             0
# Meyer                          0               0       0             0
# Meyer_b                        0               0       0             0
# Misharin/Budinger              0               0       0             0
# Nawijn                         0               0       0             0
# Regev                          0               0       0             0
# Regev/Rajagopal                0               0       0             0
# Schiller                       0               0       0             0
# Schultze                       0               0       0             0
# Seibold                        0               0       0             0
# Teichmann                      0               0       0             0
# Whitsett/Xu_10X                0               0       0             0
# Whitsett/Xu_dropSeq            0               0       0             0
# Xavier/Regev                   0               0       0             0
#
# smoking                  active  current  current/former  current/former?  \
# dataset
# Barbry/Leroy                  0        0               0                0
# Beane                         0      305               0                0
# Beane/Campbell                0        0               0                0
# Eils/Conrad/Kreuter           0    11185               0                0
# Kaminski                      0        0           23573                0
# Koenigshoff                   0        0               0                0
# Krasnow/Quake                 0        0               0                0
# Kropski/Banovich_dnar         0        0               0                0
# Kropski/Banovich_vand         0        0               0                0
# Lafyatis/Rojas                0        0               0                0
# Mazzilli/Campbell/Beane       0        0               0                0
# Meyer                      7272        0               0                0
# Meyer_b                       0   103449               0                0
# Misharin/Budinger         12557        0               0                0
# Nawijn                        0        0               0                0
# Regev                         0        0               0                0
# Regev/Rajagopal               0    58081               0                0
# Schiller                      0        0               0             5162
# Schultze                      0        0               0                0
# Seibold                       0        0               0                0
# Teichmann                  9567        0               0                0
# Whitsett/Xu_10X               0        0               0                0
# Whitsett/Xu_dropSeq           0        0               0                0
# Xavier/Regev                  0        0               0                0
#
# smoking                  former  heavy  light    nan   never  never-smoker  \
# dataset
# Barbry/Leroy              16423      0      0      0       0             0
# Beane                       581      0      0      0       0             0
# Beane/Campbell                0      0      0      0       0             0
# Eils/Conrad/Kreuter           0      0      0      0   28593             0
# Kaminski                      0      0      0   3850   67880             0
# Koenigshoff                   0      0      0      0       0         33119
# Krasnow/Quake              7524      0      0      0   53469             0
# Kropski/Banovich_dnar         0      0      0      0    2647             0
# Kropski/Banovich_vand         0      0      0      0     800             0
# Lafyatis/Rojas             3389      0      0      0   20831             0
# Mazzilli/Campbell/Beane       0      0      0      0       0             0
# Meyer                     13363      0      0      0   36385             0
# Meyer_b                       0      0      0      0   14086             0
# Misharin/Budinger          3845      0      0      0   24864             0
# Nawijn                     4958      0      0      0    6152             0
# Regev                         0      0      0  43527       0             0
# Regev/Rajagopal               0      0      0      0  264917             0
# Schiller                      0      0      0  15614       0             0
# Schultze                      0      0      0  22641       0             0
# Seibold                       0  15663   3316      0   17269             0
# Teichmann                  3404      0      0      0       0             0
# Whitsett/Xu_10X               0      0      0      0   34185             0
# Whitsett/Xu_dropSeq           0      0      0      0    3267             0
# Xavier/Regev                  0      0      0  25552       0             0
#
# smoking                  non-smoker  smoked
# dataset
# Barbry/Leroy                  42367       0
# Beane                             0       0
# Beane/Campbell                    0       0
# Eils/Conrad/Kreuter               0       0
# Kaminski                          0       0
# Koenigshoff                       0       0
# Krasnow/Quake                     0       0
# Kropski/Banovich_dnar             0    5712
# Kropski/Banovich_vand             0   22485
# Lafyatis/Rojas                    0       0
# Mazzilli/Campbell/Beane           0       0
# Meyer                             0       0
# Meyer_b                           0       0
# Misharin/Budinger                 0       0
# Nawijn                            0       0
# Regev                             0       0
# Regev/Rajagopal                   0       0
# Schiller                          0       0
# Schultze                          0       0
# Seibold                           0       0
# Teichmann                         0       0
# Whitsett/Xu_10X                   0       0
# Whitsett/Xu_dropSeq               0       0
# Xavier/Regev                      0       0

# %%
adata = adata[~adata.obs.smoking_status.isin(['nan']),].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 985420 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status'

# %%
adata.obs.dataset.value_counts()
adata.obs['sample'].nunique()
adata.obs['donor'].nunique()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    91453
# Krasnow/Quake               60993
# Barbry/Leroy                58790
# Meyer                       57020
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Teichmann                   12971
# Nawijn                      11110
# Kropski/Banovich_dnar        8359
# Schiller                     5162
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      1995
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64
# 286
# 164

# %% [markdown]
# # Check the data

# %%
np.mean(adata.X.astype(int) != adata.X)
# Out:
# 0.0

# %%
# Check if any non-integer data in a particular dataset
for dat in adata.obs.dataset.unique():
    val = np.mean(adata[adata.obs.dataset.isin([dat]),:].X.astype(int) != adata[adata.obs.dataset.isin([dat]),:].X)
    if val != 0:
        print(f'dataset= {dat}; value= {val}')
        adata[adata.obs.dataset.isin([dat]),:].X[:20,:20].A

# %% [markdown]
# All counts are integers

# %%
adata.obs.age.value_counts()
adata.obs.sex.value_counts()
# Out:
# 57.00    81833
# 66.00    69371
# 42.00    66596
# 59.00    59955
# 18.00    59849
# 46.00    56291
# 64.00    46130
# 35.00    45869
# 0.25     29908
# 67.50    28201
# 20.00    25362
# 51.00    24766
# 30.00    24095
# 29.00    19248
# 0.00     19065
# 32.00    19009
# 3.00     18387
# 42.50    16906
# 41.00    14943
# 58.00    14086
# 57.50    13840
# 23.00    13657
# 68.00    11852
# 65.00    11404
# 56.00    11024
# 75.00    10941
# 45.00    10939
# 55.00    10878
# 47.00    10278
# 49.00    10198
# 21.00     9430
# 27.00     8693
# 72.50     7983
# 22.00     7980
# 63.00     7600
# 31.00     7085
# 33.00     6906
# 44.00     6681
# 52.50     6326
# 38.00     5629
# 62.00     4679
# 24.00     4433
# 62.50     4073
# 26.00     4066
# 61.00     3922
# 67.00     3916
# 50.00     3831
# 32.50     3772
# 80.00     3261
# 10.00     2694
# 40.00     2647
# 17.00     2552
# 79.00     2550
# 54.00     2507
# 76.00     2447
# 36.00     2218
# 48.00     1153
# 25.00      823
# 70.00      168
# 69.00      130
# 87.00      112
# 43.00       79
# 34.00       76
# 78.00       65
# 74.00       52
# Name: age, dtype: int64
# female    550340
# male      435080
# Name: sex, dtype: int64

# %% [markdown]
# # Fit models and perform DE

# %%
cluster_key = 'ann_level_2'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Myeloid',
#  'Airway epithelium',
#  'Alveolar epithelium',
#  'Lymphoid',
#  'Fibroblast lineage',
#  'Blood vessels',
#  'Submucosal Gland',
#  'Smooth Muscle',
#  'Lymphatics',
#  'Mesothelium']

# %% [markdown]
# Calculate DE genes per cluster.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 985420 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status'

# %%
adata.obs['total_counts_scaled'] = adata.obs['total_counts']/adata.obs['total_counts'].mean()

# %%
formula = "1 + sex + age + smoking_status + dataset"
tested_coef = ["sex[T.male]", "age", "smoking_status[T.True]"]
dmat = de.utils.design_matrix(
    data=adata,
    formula="~" + formula,
    as_numeric=["age"],
    return_type="patsy"
)
dmat[1]
# Out:
# ['Intercept',
#  'sex[T.male]',
#  'smoking_status[T.True]',
#  'dataset[T.Beane]',
#  'dataset[T.Beane/Campbell]',
#  'dataset[T.Eils/Conrad/Kreuter]',
#  'dataset[T.Kaminski]',
#  'dataset[T.Koenigshoff]',
#  'dataset[T.Krasnow/Quake]',
#  'dataset[T.Kropski/Banovich_dnar]',
#  'dataset[T.Kropski/Banovich_vand]',
#  'dataset[T.Lafyatis/Rojas]',
#  'dataset[T.Mazzilli/Campbell/Beane]',
#  'dataset[T.Meyer]',
#  'dataset[T.Meyer_b]',
#  'dataset[T.Misharin/Budinger]',
#  'dataset[T.Nawijn]',
#  'dataset[T.Regev/Rajagopal]',
#  'dataset[T.Schiller]',
#  'dataset[T.Seibold]',
#  'dataset[T.Teichmann]',
#  'dataset[T.Whitsett/Xu_10X]',
#  'dataset[T.Whitsett/Xu_dropSeq]',
#  'age']

# %% [markdown]
# ## Poisson GLM

# %%
# Poisson GLM loop
de_results_lvl2_glm = dict()

# Test over clusters
for clust in clusters:
    adata_tmp = adata[adata.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_tmp.obs['smoking_status'].value_counts())
    print(adata_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_tmp, min_cells=10)
    if adata_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
        
    print(f'Testing {adata_tmp.n_vars} genes...')
    print(f'Testing in {adata_tmp.n_obs} cells...')
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_tmp, #[idx_train],
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_tmp.X[:, i].todense(), #[idx_train, :], 
            exog=dmat[0], 
            offset=np.log(adata_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()


        # Test over coefs
        for coef in tested_coef:
            de_results_temp = pois_results.wald_test(
                [x for i, x in enumerate(pois_model.exog_names) if dmat[1][i] in [coef]]
            )

            # Output the results nicely
            de_results_temp = pd.DataFrame({
                "gene": gene,
                "cell_identity": clust,
                "covariate": coef,
                "coef": pois_results.params[[y == coef for y in dmat[1]]],
                "coef_sd": pois_results.bse[[y == coef for y in dmat[1]]],                 
                "pval": de_results_temp.pvalue
            }, index= [clust+"_"+gene+"_"+coef])

            de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl2_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl2_glm = pd.concat([de_results_lvl2_glm[i] for i in de_results_lvl2_glm.keys()], ignore_index=True)
# Out:
# In cluster Myeloid:
# False    137441
# True     109516
# Name: smoking_status, dtype: int64
# male      130070
# female    116887
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 246957 cells...
#
# In cluster Airway epithelium:
# False    157085
# True      61702
# Name: smoking_status, dtype: int64
# female    125772
# male       93015
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 218787 cells...
#
# In cluster Alveolar epithelium:
# False    124700
# True      60785
# Name: smoking_status, dtype: int64
# female    123154
# male       62331
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 185485 cells...
#
# In cluster Lymphoid:
# False    84562
# True     48215
# Name: smoking_status, dtype: int64
# female    82702
# male      50075
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 132777 cells...
#
# In cluster Fibroblast lineage:
# False    40012
# True     13154
# Name: smoking_status, dtype: int64
# female    31351
# male      21815
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 53166 cells...
#
# In cluster Blood vessels:
# False    21455
# True     21064
# Name: smoking_status, dtype: int64
# male      31078
# female    11441
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 42519 cells...
#
# In cluster Submucosal Gland:
# False    25825
# True      7836
# Name: smoking_status, dtype: int64
# female    19901
# male      13760
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 33661 cells...
#
# In cluster Smooth Muscle:
# False    11548
# True      4724
# Name: smoking_status, dtype: int64
# female    9588
# male      6684
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 16272 cells...
#
# In cluster Lymphatics:
# True     2735
# False    2320
# Name: smoking_status, dtype: int64
# female    2937
# male      2118
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 5055 cells...
#
# In cluster Mesothelium:
# False    2250
# True      240
# Name: smoking_status, dtype: int64
# female    1593
# male       897
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 2490 cells...

# %%
# Also test how the model behaves without adding the smoking coviarate
formula_nosmoke = "1 + sex + age + dataset"
tested_coef_nosmoke = ["sex[T.male]", "age"]

# %%
# Poisson GLM loop
de_results_lvl2_glm_nosmoke = dict()

# Test over clusters
for clust in clusters:
    adata_tmp = adata[adata.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_tmp.obs['smoking_status'].value_counts())
    print(adata_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_tmp, min_cells=10)
    if adata_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
        
    print(f'Testing {adata_tmp.n_vars} genes...')
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_tmp, #[idx_train],
        formula="~" + formula_nosmoke,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_tmp.X[:, i].todense(), #[idx_train, :], 
            offset=np.log(adata_tmp.obs['total_counts_scaled'].values),
            exog=dmat[0], 
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()


        # Test over coefs
        for coef in tested_coef_nosmoke:
            de_results_temp = pois_results.wald_test(
                [x for i, x in enumerate(pois_model.exog_names) if dmat[1][i] in [coef]]
            )

            # Output the results nicely
            de_results_temp = pd.DataFrame({
                "gene": gene,
                "cell_identity": clust,
                "covariate": coef,
                "coef": pois_results.params[[y == coef for y in dmat[1]]],
                "coef_sd": pois_results.bse[[y == coef for y in dmat[1]]],                 
                "pval": de_results_temp.pvalue
            }, index= [clust+"_"+gene+"_"+coef])

            de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl2_glm_nosmoke[clust] = de_results
    
# Join the dataframes:
full_res_lvl2_glm_nosmoke = pd.concat([de_results_lvl2_glm_nosmoke[i] for i in de_results_lvl2_glm_nosmoke.keys()], ignore_index=True)
# Out:
# In cluster Myeloid:
# False    137441
# True     109516
# Name: smoking_status, dtype: int64
# male      130070
# female    116887
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Airway epithelium:
# False    157085
# True      61702
# Name: smoking_status, dtype: int64
# female    125772
# male       93015
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Alveolar epithelium:
# False    124700
# True      60785
# Name: smoking_status, dtype: int64
# female    123154
# male       62331
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Lymphoid:
# False    84562
# True     48215
# Name: smoking_status, dtype: int64
# female    82702
# male      50075
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Fibroblast lineage:
# False    40012
# True     13154
# Name: smoking_status, dtype: int64
# female    31351
# male      21815
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Blood vessels:
# False    21455
# True     21064
# Name: smoking_status, dtype: int64
# male      31078
# female    11441
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Submucosal Gland:
# False    25825
# True      7836
# Name: smoking_status, dtype: int64
# female    19901
# male      13760
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Smooth Muscle:
# False    11548
# True      4724
# Name: smoking_status, dtype: int64
# female    9588
# male      6684
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Lymphatics:
# True     2735
# False    2320
# Name: smoking_status, dtype: int64
# female    2937
# male      2118
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster Mesothelium:
# False    2250
# True      240
# Name: smoking_status, dtype: int64
# female    1593
# male       897
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl2_glm.keys()
# Out:
# dict_keys(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid', 'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland', 'Smooth Muscle', 'Lymphatics', 'Mesothelium'])

# %%
full_res_lvl2_glm
# Out:
#        gene        cell_identity               covariate       coef  \
# 0      ACE2              Myeloid             sex[T.male]   0.466549
# 1      ACE2              Myeloid                     age   0.001611
# 2      ACE2              Myeloid  smoking_status[T.True]  -0.395565
# 3   TMPRSS2              Myeloid             sex[T.male]   0.527096
# 4   TMPRSS2              Myeloid                     age  -0.001784
# 5   TMPRSS2              Myeloid  smoking_status[T.True]  -0.274375
# 6      CTSL              Myeloid             sex[T.male]  -0.097860
# 7      CTSL              Myeloid                     age  -0.000837
# 8      CTSL              Myeloid  smoking_status[T.True]   0.008360
# 9      ACE2    Airway epithelium             sex[T.male]   0.081978
# 10     ACE2    Airway epithelium                     age   0.003145
# 11     ACE2    Airway epithelium  smoking_status[T.True]   0.121530
# 12  TMPRSS2    Airway epithelium             sex[T.male]   0.180836
# 13  TMPRSS2    Airway epithelium                     age   0.001193
# 14  TMPRSS2    Airway epithelium  smoking_status[T.True]  -0.220317
# 15     CTSL    Airway epithelium             sex[T.male]  -0.120689
# 16     CTSL    Airway epithelium                     age   0.003741
# 17     CTSL    Airway epithelium  smoking_status[T.True]   0.039721
# 18     ACE2  Alveolar epithelium             sex[T.male]   0.790606
# 19     ACE2  Alveolar epithelium                     age   0.019934
# 20     ACE2  Alveolar epithelium  smoking_status[T.True]  -0.353888
# 21  TMPRSS2  Alveolar epithelium             sex[T.male]   0.073413
# 22  TMPRSS2  Alveolar epithelium                     age   0.020185
# 23  TMPRSS2  Alveolar epithelium  smoking_status[T.True]   0.145885
# 24     CTSL  Alveolar epithelium             sex[T.male]   0.154297
# 25     CTSL  Alveolar epithelium                     age  -0.005651
# 26     CTSL  Alveolar epithelium  smoking_status[T.True]   0.046193
# 27     ACE2             Lymphoid             sex[T.male]   0.269889
# 28     ACE2             Lymphoid                     age  -0.031751
# 29     ACE2             Lymphoid  smoking_status[T.True]  -0.106855
# 30  TMPRSS2             Lymphoid             sex[T.male]   0.306598
# 31  TMPRSS2             Lymphoid                     age  -0.006719
# 32  TMPRSS2             Lymphoid  smoking_status[T.True]   0.147052
# 33     CTSL             Lymphoid             sex[T.male]   0.556834
# 34     CTSL             Lymphoid                     age   0.008780
# 35     CTSL             Lymphoid  smoking_status[T.True]  -0.345445
# 36     ACE2   Fibroblast lineage             sex[T.male]  -0.031560
# 37     ACE2   Fibroblast lineage                     age   0.001047
# 38     ACE2   Fibroblast lineage  smoking_status[T.True]   0.377836
# 39  TMPRSS2   Fibroblast lineage             sex[T.male]   0.398966
# 40  TMPRSS2   Fibroblast lineage                     age   0.008268
# 41  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   1.024393
# 42     CTSL   Fibroblast lineage             sex[T.male]  -0.352246
# 43     CTSL   Fibroblast lineage                     age  -0.015589
# 44     CTSL   Fibroblast lineage  smoking_status[T.True]  -0.088681
# 45     ACE2        Blood vessels             sex[T.male]   0.970412
# 46     ACE2        Blood vessels                     age  -0.003619
# 47     ACE2        Blood vessels  smoking_status[T.True]  -0.136475
# 48  TMPRSS2        Blood vessels             sex[T.male]   0.313770
# 49  TMPRSS2        Blood vessels                     age  -0.007229
# 50  TMPRSS2        Blood vessels  smoking_status[T.True]  -0.300362
# 51     CTSL        Blood vessels             sex[T.male]   0.078786
# 52     CTSL        Blood vessels                     age   0.001320
# 53     CTSL        Blood vessels  smoking_status[T.True]   0.012610
# 54     ACE2     Submucosal Gland             sex[T.male]   0.053476
# 55     ACE2     Submucosal Gland                     age   0.002748
# 56     ACE2     Submucosal Gland  smoking_status[T.True]   0.476008
# 57  TMPRSS2     Submucosal Gland             sex[T.male]   0.303606
# 58  TMPRSS2     Submucosal Gland                     age   0.001992
# 59  TMPRSS2     Submucosal Gland  smoking_status[T.True]  -0.065982
# 60     CTSL     Submucosal Gland             sex[T.male]  -0.097038
# 61     CTSL     Submucosal Gland                     age   0.006540
# 62     CTSL     Submucosal Gland  smoking_status[T.True]   0.072334
# 63     ACE2        Smooth Muscle             sex[T.male]   0.086860
# 64     ACE2        Smooth Muscle                     age  -0.009741
# 65     ACE2        Smooth Muscle  smoking_status[T.True]   1.707142
# 66  TMPRSS2        Smooth Muscle             sex[T.male]   0.083848
# 67  TMPRSS2        Smooth Muscle                     age   0.003552
# 68  TMPRSS2        Smooth Muscle  smoking_status[T.True]   0.829539
# 69     CTSL        Smooth Muscle             sex[T.male]  -0.411154
# 70     CTSL        Smooth Muscle                     age  -0.011348
# 71     CTSL        Smooth Muscle  smoking_status[T.True]   0.072488
# 72  TMPRSS2           Lymphatics             sex[T.male]   0.567848
# 73  TMPRSS2           Lymphatics                     age  -0.011344
# 74  TMPRSS2           Lymphatics  smoking_status[T.True]   0.055680
# 75     CTSL           Lymphatics             sex[T.male]   0.015904
# 76     CTSL           Lymphatics                     age   0.004340
# 77     CTSL           Lymphatics  smoking_status[T.True]  -0.020372
# 78  TMPRSS2          Mesothelium             sex[T.male]  -1.663558
# 79  TMPRSS2          Mesothelium                     age   0.056052
# 80  TMPRSS2          Mesothelium  smoking_status[T.True] -19.800701
# 81     CTSL          Mesothelium             sex[T.male]   0.428510
# 82     CTSL          Mesothelium                     age   0.001612
# 9   2.287090e-02  2.287090e-02
# 10  3.263893e-03  3.671880e-03
# 11  1.407770e-03  1.809990e-03
# 18  1.214520e-51  3.643559e-51
# 19  3.564372e-29  5.346558e-29
# 20  2.144332e-08  2.412374e-08
# 27  4.471967e-01  5.030962e-01
# 28  1.068449e-02  1.602673e-02
# 29  8.056464e-01  8.056464e-01
# 36  8.527067e-01  8.577314e-01
# 37  8.577314e-01  8.577314e-01
# 38  2.624771e-01  3.374706e-01
# 45  3.708805e-02  1.668962e-01
# 46  7.436190e-01  7.983343e-01
# 47  7.983343e-01  7.983343e-01
# 54  5.919034e-01  5.919034e-01
# 55  2.581117e-01  2.903756e-01
# 56  4.053372e-09  1.216012e-08
# 63  8.556202e-01  8.556202e-01
# 64  4.809487e-01  7.050340e-01
# 65  3.113860e-02  7.006186e-02

# %%
full_res_lvl2_glm.loc[(full_res_lvl2_glm['gene'] == 'ACE2') & (full_res_lvl2_glm['adj_pvals'] < 0.05),]
# Out:
#     gene        cell_identity               covariate      coef   coef_sd  \
# 0   ACE2              Myeloid             sex[T.male]  0.466549  0.198569
# 9   ACE2    Airway epithelium             sex[T.male]  0.081978  0.036025
# 10  ACE2    Airway epithelium                     age  0.003145  0.001069
# 11  ACE2    Airway epithelium  smoking_status[T.True]  0.121530  0.038061
# 18  ACE2  Alveolar epithelium             sex[T.male]  0.790606  0.052292
# 19  ACE2  Alveolar epithelium                     age  0.019934  0.001778
# 20  ACE2  Alveolar epithelium  smoking_status[T.True] -0.353888  0.063195
# 28  ACE2             Lymphoid                     age -0.031751  0.012438
# 56  ACE2     Submucosal Gland  smoking_status[T.True]  0.476008  0.080926
#
#             pval     adj_pvals
# 0   1.879595e-02  2.819392e-02
# 9   2.287090e-02  2.287090e-02
# 10  3.263893e-03  3.671880e-03
# 11  1.407770e-03  1.809990e-03
# 18  1.214520e-51  3.643559e-51
# 19  3.564372e-29  5.346558e-29
# 20  2.144332e-08  2.412374e-08
# 28  1.068449e-02  1.602673e-02
# 56  4.053372e-09  1.216012e-08

# %%
full_res_lvl2_glm.loc[(full_res_lvl2_glm['gene'] == 'TMPRSS2') & (full_res_lvl2_glm['adj_pvals'] < 0.05),]
# Out:
#        gene        cell_identity               covariate      coef   coef_sd  \
# 3   TMPRSS2              Myeloid             sex[T.male]  0.527096  0.042296
# 5   TMPRSS2              Myeloid  smoking_status[T.True] -0.274375  0.048421
# 12  TMPRSS2    Airway epithelium             sex[T.male]  0.180836  0.011531
# 13  TMPRSS2    Airway epithelium                     age  0.001193  0.000329
# 14  TMPRSS2    Airway epithelium  smoking_status[T.True] -0.220317  0.013620
# 21  TMPRSS2  Alveolar epithelium             sex[T.male]  0.073413  0.007158
# 22  TMPRSS2  Alveolar epithelium                     age  0.020185  0.000249
# 23  TMPRSS2  Alveolar epithelium  smoking_status[T.True]  0.145885  0.008382
# 30  TMPRSS2             Lymphoid             sex[T.male]  0.306598  0.074111
# 31  TMPRSS2             Lymphoid                     age -0.006719  0.002547
# 39  TMPRSS2   Fibroblast lineage             sex[T.male]  0.398966  0.059348
# 40  TMPRSS2   Fibroblast lineage                     age  0.008268  0.001935
# 41  TMPRSS2   Fibroblast lineage  smoking_status[T.True]  1.024393  0.086464
# 57  TMPRSS2     Submucosal Gland             sex[T.male]  0.303606  0.024020
# 58  TMPRSS2     Submucosal Gland                     age  0.001992  0.000584
# 59  TMPRSS2     Submucosal Gland  smoking_status[T.True] -0.065982  0.024541
# 68  TMPRSS2        Smooth Muscle  smoking_status[T.True]  0.829539  0.321159
# 72  TMPRSS2           Lymphatics             sex[T.male]  0.567848  0.179319
# 78  TMPRSS2          Mesothelium             sex[T.male] -1.663558  0.366465
# 79  TMPRSS2          Mesothelium                     age  0.056052  0.012648
#
#             pval     adj_pvals
# 3   1.200709e-35  5.403191e-35
# 5   1.457873e-08  3.280215e-08
# 12  1.997748e-55  8.989864e-55
# 13  2.918464e-04  4.377695e-04
# 14  7.421204e-59  6.679083e-58
# 21  1.107144e-24  1.423471e-24
# 22  0.000000e+00  0.000000e+00
# 23  7.552207e-68  3.398493e-67
# 30  3.518912e-05  7.917551e-05
# 31  8.349621e-03  1.502932e-02
# 39  1.786947e-11  3.216504e-11
# 40  1.932706e-05  2.899060e-05
# 41  2.214460e-32  6.643379e-32
# 57  1.273589e-36  1.146230e-35
# 58  6.522876e-04  1.174118e-03
# 59  7.174169e-03  9.223932e-03
# 68  9.795871e-03  2.938761e-02
# 72  1.541841e-03  9.251045e-03
# 78  5.639596e-06  1.691879e-05
# 79  9.348742e-06  1.869748e-05

# %%
full_res_lvl2_glm_nosmoke.loc[full_res_lvl2_glm_nosmoke['gene'] == 'ACE2',]
# Out:
#     gene        cell_identity    covariate      coef   coef_sd          pval  \
# 0   ACE2              Myeloid  sex[T.male]  0.407683  0.197664  3.915962e-02
# 1   ACE2              Myeloid          age  0.000733  0.005974  9.023011e-01
# 6   ACE2    Airway epithelium  sex[T.male]  0.067291  0.035658  5.914717e-02
# 7   ACE2    Airway epithelium          age  0.003467  0.001059  1.061032e-03
# 12  ACE2  Alveolar epithelium  sex[T.male]  0.813865  0.053072  4.454637e-53
# 13  ACE2  Alveolar epithelium          age  0.014438  0.001502  6.874868e-22
# 18  ACE2             Lymphoid  sex[T.male]  0.247716  0.343651  4.710108e-01
# 19  ACE2             Lymphoid          age -0.032553  0.012006  6.697087e-03
# 24  ACE2   Fibroblast lineage  sex[T.male] -0.008491  0.167437  9.595539e-01
# 25  ACE2   Fibroblast lineage          age  0.002133  0.005753  7.107977e-01
# 30  ACE2        Blood vessels  sex[T.male]  0.909532  0.402306  2.377193e-02
# 31  ACE2        Blood vessels          age -0.004578  0.010483  6.622933e-01
# 36  ACE2     Submucosal Gland  sex[T.male]  0.004671  0.096946  9.615734e-01
# 37  ACE2     Submucosal Gland          age  0.005288  0.002329  2.319545e-02
# 42  ACE2        Smooth Muscle  sex[T.male]  0.207388  0.456033  6.492783e-01
# 43  ACE2        Smooth Muscle          age -0.000883  0.012384  9.431641e-01
#
#        adj_pvals
# 0   5.873944e-02
# 1   9.023011e-01
# 6   7.097660e-02
# 7   1.591549e-03
# 12  8.909273e-53
# 13  6.874868e-22
# 18  4.710108e-01
# 19  1.004563e-02
# 24  9.595539e-01
# 25  8.529573e-01
# 30  7.131580e-02
# 31  6.622933e-01
# 36  9.615734e-01
# 37  2.783454e-02
# 42  7.791340e-01
# 43  9.431641e-01

# %% [markdown]
# # Level 3 annotation

# %%
cluster_key = 'ann_level_3'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') or ct.startswith('2') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Macrophages',
#  'Basal',
#  'AT2',
#  'T cell lineage',
#  'Monocytes',
#  'Multiciliated lineage',
#  'Submucosal Secretory',
#  'AT1',
#  'Innate lymphoid cells',
#  'Secretory',
#  'Capillary',
#  'Mast cells',
#  'B cell lineage',
#  'Fibroblasts',
#  'Dendritic cells',
#  'Venous',
#  'Lymphatic EC',
#  'Arterial',
#  'Rare',
#  'Airway smooth muscle']

# %%
adata_sub = adata[adata.obs.ann_level_3.isin(clusters),:]

adata_sub
adata_sub.obs.donor.nunique()
adata_sub.obs['sample'].nunique()
# Out:
# View of AnnData object with n_obs × n_vars = 795195 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status', 'total_counts_scaled'
# 164
# 286

# %% [markdown]
# ## Poisson GLM

# %%
# Poisson GLM loop
de_results_lvl3_glm = dict()

# Test over clusters
for clust in clusters:
    adata_tmp = adata_sub[adata_sub.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_tmp.obs['smoking_status'].value_counts())
    print(adata_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_tmp, min_cells=10)
    if adata_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
        
    print(f'Testing {adata_tmp.n_vars} genes...')
    print(f'Testing in {adata_tmp.n_obs} cells...')
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_tmp, #[idx_train],
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_tmp.X[:, i].todense(), #[idx_train, :], 
            exog=dmat[0],
            offset=np.log(adata_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()


        # Test over coefs
        for coef in tested_coef:
            de_results_temp = pois_results.wald_test(
                [x for i, x in enumerate(pois_model.exog_names) if dmat[1][i] in [coef]]
            )

            # Output the results nicely
            de_results_temp = pd.DataFrame({
                "gene": gene,
                "cell_identity": clust,
                "covariate": coef,
                "coef": pois_results.params[[y == coef for y in dmat[1]]],
                "coef_sd": pois_results.bse[[y == coef for y in dmat[1]]],                 
                "pval": de_results_temp.pvalue
            }, index= [clust+"_"+gene+"_"+coef])

            de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl3_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl3_glm = pd.concat([de_results_lvl3_glm[i] for i in de_results_lvl3_glm.keys()], ignore_index=True)
# Out:
# In cluster Macrophages:
# False    84537
# True     72427
# Name: smoking_status, dtype: int64
# male      94376
# female    62588
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 156964 cells...
#
# In cluster Basal:
# False    113299
# True      42578
# Name: smoking_status, dtype: int64
# female    91571
# male      64306
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 155877 cells...
#
# In cluster AT2:
# False    100593
# True      54919
# Name: smoking_status, dtype: int64
# female    103012
# male       52500
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 155512 cells...
#
# In cluster T cell lineage:
# True     26540
# False    25599
# Name: smoking_status, dtype: int64
# female    27637
# male      24502
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 52139 cells...
#
# In cluster Monocytes:
# True     23487
# False    19216
# Name: smoking_status, dtype: int64
# female    21616
# male      21087
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 42703 cells...
#
# In cluster Multiciliated lineage:
# False    26913
# True     10617
# Name: smoking_status, dtype: int64
# female    21902
# male      15628
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 37530 cells...
#
# In cluster Submucosal Secretory:
# False    25825
# True      7836
# Name: smoking_status, dtype: int64
# female    19901
# male      13760
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 33661 cells...
#
# In cluster AT1:
# False    24107
# True      5866
# Name: smoking_status, dtype: int64
# female    20142
# male       9831
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 29973 cells...
#
# In cluster Innate lymphoid cells:
# False    19042
# True     10794
# Name: smoking_status, dtype: int64
# female    17465
# male      12371
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 29836 cells...
#
# In cluster Secretory:
# False    14450
# True      7856
# Name: smoking_status, dtype: int64
# male      11503
# female    10803
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 22306 cells...
#
# In cluster Capillary:
# False    11356
# True      4389
# Name: smoking_status, dtype: int64
# male      12487
# female     3258
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 15745 cells...
#
# In cluster Mast cells:
# False    7232
# True     6349
# Name: smoking_status, dtype: int64
# female    9051
# male      4530
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 13581 cells...
#
# In cluster B cell lineage:
# False    6564
# True     5197
# Name: smoking_status, dtype: int64
# female    6730
# male      5031
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 11761 cells...
#
# In cluster Fibroblasts:
# False    6854
# True     2258
# Name: smoking_status, dtype: int64
# male      4652
# female    4460
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 9112 cells...
#
# In cluster Dendritic cells:
# True     4832
# False    4185
# Name: smoking_status, dtype: int64
# female    4800
# male      4217
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 9017 cells...
#
# In cluster Venous:
# True     5605
# False    1568
# Name: smoking_status, dtype: int64
# male      6215
# female     958
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 7173 cells...
#
# In cluster Lymphatic EC:
# True     2735
# False    2320
# Name: smoking_status, dtype: int64
# female    2937
# male      2118
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
# Testing in 5055 cells...
#
# In cluster Arterial:
# True     1848
# False    1649
# Name: smoking_status, dtype: int64
# male      2563
# female     934
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 10 cells
# Testing 1 genes...
# Testing in 3497 cells...
#
# In cluster Rare:
# False    2218
# True      458
# Name: smoking_status, dtype: int64
# male      1488
# female    1188
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 2676 cells...
#
# In cluster Airway smooth muscle:
# False    601
# True     476
# Name: smoking_status, dtype: int64
# male      717
# female    360
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 10 cells
# Testing 1 genes...
# Testing in 1077 cells...

# %%
# Poisson GLM loop
de_results_lvl3_glm_nosmoke = dict()

# Test over clusters
for clust in clusters:
    adata_tmp = adata_sub[adata_sub.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_tmp.obs['smoking_status'].value_counts())
    print(adata_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_tmp, min_cells=10)
    if adata_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
        
    print(f'Testing {adata_tmp.n_vars} genes...')
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_tmp, #[idx_train],
        formula="~" + formula_nosmoke,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_tmp.X[:, i].todense(), #[idx_train, :], 
            exog=dmat[0], 
            offset=np.log(adata_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()


        # Test over coefs
        for coef in tested_coef_nosmoke:
            de_results_temp = pois_results.wald_test(
                [x for i, x in enumerate(pois_model.exog_names) if dmat[1][i] in [coef]]
            )

            # Output the results nicely
            de_results_temp = pd.DataFrame({
                "gene": gene,
                "cell_identity": clust,
                "covariate": coef,
                "coef": pois_results.params[[y == coef for y in dmat[1]]],
                "coef_sd": pois_results.bse[[y == coef for y in dmat[1]]],                 
                "pval": de_results_temp.pvalue
            }, index= [clust+"_"+gene+"_"+coef])

            de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl3_glm_nosmoke[clust] = de_results
    
# Join the dataframes:
full_res_lvl3_glm_nosmoke = pd.concat([de_results_lvl3_glm_nosmoke[i] for i in de_results_lvl3_glm_nosmoke.keys()], ignore_index=True)
# Out:
# In cluster Macrophages:
# False    84537
# True     72427
# Name: smoking_status, dtype: int64
# male      94376
# female    62588
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Basal:
# False    113299
# True      42578
# Name: smoking_status, dtype: int64
# female    91571
# male      64306
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster AT2:
# False    100593
# True      54919
# Name: smoking_status, dtype: int64
# female    103012
# male       52500
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster T cell lineage:
# True     26540
# False    25599
# Name: smoking_status, dtype: int64
# female    27637
# male      24502
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Monocytes:
# True     23487
# False    19216
# Name: smoking_status, dtype: int64
# female    21616
# male      21087
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Multiciliated lineage:
# False    26913
# True     10617
# Name: smoking_status, dtype: int64
# female    21902
# male      15628
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Submucosal Secretory:
# False    25825
# True      7836
# Name: smoking_status, dtype: int64
# female    19901
# male      13760
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster AT1:
# False    24107
# True      5866
# Name: smoking_status, dtype: int64
# female    20142
# male       9831
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Innate lymphoid cells:
# False    19042
# True     10794
# Name: smoking_status, dtype: int64
# female    17465
# male      12371
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster Secretory:
# False    14450
# True      7856
# Name: smoking_status, dtype: int64
# male      11503
# female    10803
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Capillary:
# False    11356
# True      4389
# Name: smoking_status, dtype: int64
# male      12487
# female     3258
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster Mast cells:
# False    7232
# True     6349
# Name: smoking_status, dtype: int64
# female    9051
# male      4530
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster B cell lineage:
# False    6564
# True     5197
# Name: smoking_status, dtype: int64
# female    6730
# male      5031
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster Fibroblasts:
# False    6854
# True     2258
# Name: smoking_status, dtype: int64
# male      4652
# female    4460
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Dendritic cells:
# True     4832
# False    4185
# Name: smoking_status, dtype: int64
# female    4800
# male      4217
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster Venous:
# True     5605
# False    1568
# Name: smoking_status, dtype: int64
# male      6215
# female     958
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster Lymphatic EC:
# True     2735
# False    2320
# Name: smoking_status, dtype: int64
# female    2937
# male      2118
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 10 cells
# Testing 2 genes...
#
# In cluster Arterial:
# True     1848
# False    1649
# Name: smoking_status, dtype: int64
# male      2563
# female     934
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 10 cells
# Testing 1 genes...
#
# In cluster Rare:
# False    2218
# True      458
# Name: smoking_status, dtype: int64
# male      1488
# female    1188
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Airway smooth muscle:
# False    601
# True     476
# Name: smoking_status, dtype: int64
# male      717
# female    360
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 10 cells
# Testing 1 genes...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl3_glm.keys()
# Out:
# dict_keys(['Macrophages', 'Basal', 'AT2', 'T cell lineage', 'Monocytes', 'Multiciliated lineage', 'Submucosal Secretory', 'AT1', 'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells', 'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous', 'Lymphatic EC', 'Arterial', 'Rare', 'Airway smooth muscle'])

# %%
full_res_lvl3_glm
# Out:
#         gene          cell_identity               covariate      coef  \
# 0       ACE2            Macrophages             sex[T.male]  0.079347
# 1       ACE2            Macrophages                     age  0.006745
# 2       ACE2            Macrophages  smoking_status[T.True] -0.183397
# 3    TMPRSS2            Macrophages             sex[T.male] -0.331306
# 4    TMPRSS2            Macrophages                     age -0.003322
# 5    TMPRSS2            Macrophages  smoking_status[T.True]  0.134248
# 6       CTSL            Macrophages             sex[T.male] -0.167304
# 7       CTSL            Macrophages                     age  0.002582
# 8       CTSL            Macrophages  smoking_status[T.True]  0.100365
# 9       ACE2                  Basal             sex[T.male]  0.050698
# 10      ACE2                  Basal                     age  0.003719
# 11      ACE2                  Basal  smoking_status[T.True]  0.191025
# 12   TMPRSS2                  Basal             sex[T.male]  0.294338
# 13   TMPRSS2                  Basal                     age  0.005119
# 14   TMPRSS2                  Basal  smoking_status[T.True] -0.360639
# 15      CTSL                  Basal             sex[T.male] -0.167472
# 16      CTSL                  Basal                     age  0.005348
# 17      CTSL                  Basal  smoking_status[T.True]  0.077169
# 18      ACE2                    AT2             sex[T.male]  0.827769
# 19      ACE2                    AT2                     age  0.019122
# 20      ACE2                    AT2  smoking_status[T.True] -0.406943
# 21   TMPRSS2                    AT2             sex[T.male] -0.004434
# 22   TMPRSS2                    AT2                     age  0.021023
# 23   TMPRSS2                    AT2  smoking_status[T.True]  0.136431
# 24      CTSL                    AT2             sex[T.male]  0.104171
# 25      CTSL                    AT2                     age -0.005396
# 26      CTSL                    AT2  smoking_status[T.True]  0.113451
# 27      ACE2         T cell lineage             sex[T.male]  0.614737
# 28      ACE2         T cell lineage                     age -0.011035
# 29      ACE2         T cell lineage  smoking_status[T.True] -0.724578
# 30   TMPRSS2         T cell lineage             sex[T.male]  0.389809
# 31   TMPRSS2         T cell lineage                     age -0.005053
# 32   TMPRSS2         T cell lineage  smoking_status[T.True] -0.099137
# 33      CTSL         T cell lineage             sex[T.male]  0.733059
# 34      CTSL         T cell lineage                     age  0.030221
# 35      CTSL         T cell lineage  smoking_status[T.True] -0.661709
# 36      ACE2              Monocytes             sex[T.male]  0.711762
# 37      ACE2              Monocytes                     age -0.024997
# 38      ACE2              Monocytes  smoking_status[T.True] -0.298505
# 39   TMPRSS2              Monocytes             sex[T.male]  1.204337
# 40   TMPRSS2              Monocytes                     age  0.007580
# 41   TMPRSS2              Monocytes  smoking_status[T.True]  0.143082
# 42      CTSL              Monocytes             sex[T.male] -0.147852
# 43      CTSL              Monocytes                     age -0.001845
# 44      CTSL              Monocytes  smoking_status[T.True] -0.160165
# 45      ACE2  Multiciliated lineage             sex[T.male]  0.247672
# 46      ACE2  Multiciliated lineage                     age  0.006830
# 47      ACE2  Multiciliated lineage  smoking_status[T.True]  0.200573
# 48   TMPRSS2  Multiciliated lineage             sex[T.male]  0.179693
# 49   TMPRSS2  Multiciliated lineage                     age  0.000304
# 50   TMPRSS2  Multiciliated lineage  smoking_status[T.True] -0.082698
# 51      CTSL  Multiciliated lineage             sex[T.male] -0.060682
# 52      CTSL  Multiciliated lineage                     age -0.001260
# 53      CTSL  Multiciliated lineage  smoking_status[T.True]  0.005015
# 54      ACE2   Submucosal Secretory             sex[T.male]  0.053476
# 55      ACE2   Submucosal Secretory                     age  0.002748
# 56      ACE2   Submucosal Secretory  smoking_status[T.True]  0.476008
# 57   TMPRSS2   Submucosal Secretory             sex[T.male]  0.303606
# 58   TMPRSS2   Submucosal Secretory                     age  0.001992
# 59   TMPRSS2   Submucosal Secretory  smoking_status[T.True] -0.065982
# 60      CTSL   Submucosal Secretory             sex[T.male] -0.097038
# 61      CTSL   Submucosal Secretory                     age  0.006540
# 62      CTSL   Submucosal Secretory  smoking_status[T.True]  0.072334
# 63      ACE2                    AT1             sex[T.male]  0.483887
# 64      ACE2                    AT1                     age  0.011905
# 65      ACE2                    AT1  smoking_status[T.True]  0.284824
# 66   TMPRSS2                    AT1             sex[T.male]  0.680930
# 67   TMPRSS2                    AT1                     age  0.011882
# 68   TMPRSS2                    AT1  smoking_status[T.True]  0.092228
# 69      CTSL                    AT1             sex[T.male]  0.259359
# 70      CTSL                    AT1                     age  0.001547
# 71      CTSL                    AT1  smoking_status[T.True]  0.152784
# 72   TMPRSS2  Innate lymphoid cells             sex[T.male]  0.237172
# 73   TMPRSS2  Innate lymphoid cells                     age  0.002862
# 74   TMPRSS2  Innate lymphoid cells  smoking_status[T.True] -0.751326
# 75      CTSL  Innate lymphoid cells             sex[T.male]  0.465933
# 76      CTSL  Innate lymphoid cells                     age  0.019030
# 77      CTSL  Innate lymphoid cells  smoking_status[T.True]  0.421752
# 78      ACE2              Secretory             sex[T.male]  0.248878
# 79      ACE2              Secretory                     age -0.007310
# 80      ACE2              Secretory  smoking_status[T.True] -0.009837
# 81   TMPRSS2              Secretory             sex[T.male]  0.266853
# 82   TMPRSS2              Secretory                     age -0.003502
# 83   TMPRSS2              Secretory  smoking_status[T.True]  0.003712
# 84      CTSL              Secretory             sex[T.male] -0.002958
# 85      CTSL              Secretory                     age  0.005070
# 86      CTSL              Secretory  smoking_status[T.True]  0.043263
# 87   TMPRSS2              Capillary             sex[T.male]  1.186622
# 88   TMPRSS2              Capillary                     age -0.027864
# 89   TMPRSS2              Capillary  smoking_status[T.True] -0.684139
# 90      CTSL              Capillary             sex[T.male] -0.047455
# 91      CTSL              Capillary                     age -0.001386
# 92      CTSL              Capillary  smoking_status[T.True]  0.297672
# 93   TMPRSS2             Mast cells             sex[T.male]  1.120987
# 94   TMPRSS2             Mast cells                     age -0.009912
# 95   TMPRSS2             Mast cells  smoking_status[T.True] -1.180041
# 96      CTSL             Mast cells             sex[T.male] -0.214675
# 97      CTSL             Mast cells                     age -0.007230
# 98      CTSL             Mast cells  smoking_status[T.True] -0.356793
# 99   TMPRSS2         B cell lineage             sex[T.male]  0.280367
# 100  TMPRSS2         B cell lineage                     age -0.007162
# 101  TMPRSS2         B cell lineage  smoking_status[T.True] -0.649469
# 102     CTSL         B cell lineage             sex[T.male] -0.176326
# 103     CTSL         B cell lineage                     age -0.002547
# 104     CTSL         B cell lineage  smoking_status[T.True] -0.106384
# 105     ACE2            Fibroblasts             sex[T.male] -0.992477
# 106     ACE2            Fibroblasts                     age -0.003820
# 107     ACE2            Fibroblasts  smoking_status[T.True] -0.217694
# 108  TMPRSS2            Fibroblasts             sex[T.male]  0.946428
# 109  TMPRSS2            Fibroblasts                     age -0.000950
# 110  TMPRSS2            Fibroblasts  smoking_status[T.True] -0.407290
# 111     CTSL            Fibroblasts             sex[T.male] -0.004878
# 112     CTSL            Fibroblasts                     age -0.014788
# 113     CTSL            Fibroblasts  smoking_status[T.True]  1.031132
# 114  TMPRSS2        Dendritic cells             sex[T.male]  0.251196
# 115  TMPRSS2        Dendritic cells                     age -0.007513
# 116  TMPRSS2        Dendritic cells  smoking_status[T.True] -0.495933
# 117     CTSL        Dendritic cells             sex[T.male] -0.409138
# 118     CTSL        Dendritic cells                     age  0.015850
# 119     CTSL        Dendritic cells  smoking_status[T.True] -0.194686
# 120  TMPRSS2                 Venous             sex[T.male]  0.856302
# 121  TMPRSS2                 Venous                     age -0.051988
# 122  TMPRSS2                 Venous  smoking_status[T.True] -2.144932
# 123     CTSL                 Venous             sex[T.male]  0.010482
# 124     CTSL                 Venous                     age  0.002033
# 125     CTSL                 Venous  smoking_status[T.True]  0.191225
# 126  TMPRSS2           Lymphatic EC             sex[T.male]  0.567848
# 127  TMPRSS2           Lymphatic EC                     age -0.011344
# 128  TMPRSS2           Lymphatic EC  smoking_status[T.True]  0.055680
# 129     CTSL           Lymphatic EC             sex[T.male]  0.015904
# 130     CTSL           Lymphatic EC                     age  0.004340
# 131     CTSL           Lymphatic EC  smoking_status[T.True] -0.020372
# 132     CTSL               Arterial             sex[T.male]  0.156750
# 133     CTSL               Arterial                     age  0.003528
# 134     CTSL               Arterial  smoking_status[T.True] -0.097793
# 135     ACE2                   Rare             sex[T.male] -0.256809
# 136     ACE2                   Rare                     age  0.008099
# 137     ACE2                   Rare  smoking_status[T.True]  0.203906
# 138  TMPRSS2                   Rare             sex[T.male]  0.282077
# 139  TMPRSS2                   Rare                     age -0.003152
# 140  TMPRSS2                   Rare  smoking_status[T.True]  0.100134
# 141     CTSL                   Rare             sex[T.male]  0.282241
# 142     CTSL                   Rare                     age  0.005546
# 143     CTSL                   Rare  smoking_status[T.True]  0.261578
# 144     CTSL   Airway smooth muscle             sex[T.male] -0.174513
# 145     CTSL   Airway smooth muscle                     age -0.009539
# 146     CTSL   Airway smooth muscle  smoking_status[T.True]  0.411671
#
#       coef_sd           pval      adj_pvals
# 0    0.268355   7.674755e-01   7.674755e-01
# 1    0.006974   3.334057e-01   4.286644e-01
# 2    0.328642   5.768144e-01   6.489162e-01
# 3    0.072662   5.125795e-06   1.153304e-05
# 4    0.002135   1.196886e-01   2.100394e-01
# 5    0.090973   1.400263e-01   2.100394e-01
# 6    0.002610   0.000000e+00   0.000000e+00
# 7    0.000084  2.672846e-207  1.202781e-206
# 8    0.003562  1.222302e-174  3.666907e-174
# 9    0.047738   2.882331e-01   2.882331e-01
# 10   0.001304   4.346742e-03   4.890085e-03
# 11   0.048163   7.301195e-05   9.387251e-05
# 12   0.019865   1.137475e-49   2.559319e-49
# 13   0.000486   5.922030e-26   1.065965e-25
# 14   0.022005   2.284573e-60   1.028058e-59
# 15   0.010586   2.235890e-56   6.707671e-56
# 16   0.000297   1.908543e-72   1.717688e-71
# 17   0.010720   6.077707e-13   9.116561e-13
# 18   0.054502   4.251463e-52   1.371084e-51
# 19   0.001890   4.552959e-24   8.195327e-24
# 20   0.065738   6.000591e-10   6.750665e-10
# 21   0.007640   5.616730e-01   5.616730e-01
# 22   0.000271   0.000000e+00   0.000000e+00
# 23   0.008986   4.570280e-52   1.371084e-51
# 24   0.013615   1.993684e-14   2.990526e-14
# 25   0.000459   7.452178e-32   1.676740e-31
# 26   0.017113   3.363359e-11   4.324319e-11
# 105  1.803577e-02  5.410730e-02
# 106  6.842386e-01  9.412516e-01
# 107  8.303895e-01  9.412516e-01
# 135  7.567065e-01  8.512948e-01
# 136  7.253915e-01  8.512948e-01
# 137  8.544585e-01  8.544585e-01

# %%
full_res_lvl3_glm.loc[(full_res_lvl3_glm['gene'] == 'ACE2') & (full_res_lvl3_glm['adj_pvals'] < 0.05),]
# Out:
#     gene          cell_identity               covariate      coef   coef_sd  \
# 10  ACE2                  Basal                     age  0.003719  0.001304
# 11  ACE2                  Basal  smoking_status[T.True]  0.191025  0.048163
# 18  ACE2                    AT2             sex[T.male]  0.827769  0.054502
# 19  ACE2                    AT2                     age  0.019122  0.001890
# 20  ACE2                    AT2  smoking_status[T.True] -0.406943  0.065738
# 45  ACE2  Multiciliated lineage             sex[T.male]  0.247672  0.080584
# 46  ACE2  Multiciliated lineage                     age  0.006830  0.002665
# 56  ACE2   Submucosal Secretory  smoking_status[T.True]  0.476008  0.080926
# 63  ACE2                    AT1             sex[T.male]  0.483887  0.205510
# 78  ACE2              Secretory             sex[T.male]  0.248878  0.081754
#
#             pval     adj_pvals
# 10  4.346742e-03  4.890085e-03
# 11  7.301195e-05  9.387251e-05
# 18  4.251463e-52  1.371084e-51
# 19  4.552959e-24  8.195327e-24
# 20  6.000591e-10  6.750665e-10
# 45  2.115948e-03  4.760882e-03
# 46  1.038334e-02  1.869002e-02
# 56  4.053372e-09  1.216012e-08
# 63  1.854418e-02  2.781628e-02
# 78  2.332912e-03  5.249052e-03

# %%
full_res_lvl3_glm.loc[full_res_lvl3_glm['gene'] == 'TMPRSS2',]
# Out:
#         gene          cell_identity               covariate      coef  \
# 3    TMPRSS2            Macrophages             sex[T.male] -0.331306
# 4    TMPRSS2            Macrophages                     age -0.003322
# 5    TMPRSS2            Macrophages  smoking_status[T.True]  0.134248
# 12   TMPRSS2                  Basal             sex[T.male]  0.294338
# 13   TMPRSS2                  Basal                     age  0.005119
# 14   TMPRSS2                  Basal  smoking_status[T.True] -0.360639
# 21   TMPRSS2                    AT2             sex[T.male] -0.004434
# 22   TMPRSS2                    AT2                     age  0.021023
# 23   TMPRSS2                    AT2  smoking_status[T.True]  0.136431
# 30   TMPRSS2         T cell lineage             sex[T.male]  0.389809
# 31   TMPRSS2         T cell lineage                     age -0.005053
# 32   TMPRSS2         T cell lineage  smoking_status[T.True] -0.099137
# 39   TMPRSS2              Monocytes             sex[T.male]  1.204337
# 40   TMPRSS2              Monocytes                     age  0.007580
# 41   TMPRSS2              Monocytes  smoking_status[T.True]  0.143082
# 48   TMPRSS2  Multiciliated lineage             sex[T.male]  0.179693
# 49   TMPRSS2  Multiciliated lineage                     age  0.000304
# 50   TMPRSS2  Multiciliated lineage  smoking_status[T.True] -0.082698
# 57   TMPRSS2   Submucosal Secretory             sex[T.male]  0.303606
# 58   TMPRSS2   Submucosal Secretory                     age  0.001992
# 59   TMPRSS2   Submucosal Secretory  smoking_status[T.True] -0.065982
# 66   TMPRSS2                    AT1             sex[T.male]  0.680930
# 67   TMPRSS2                    AT1                     age  0.011882
# 68   TMPRSS2                    AT1  smoking_status[T.True]  0.092228
# 72   TMPRSS2  Innate lymphoid cells             sex[T.male]  0.237172
# 73   TMPRSS2  Innate lymphoid cells                     age  0.002862
# 74   TMPRSS2  Innate lymphoid cells  smoking_status[T.True] -0.751326
# 81   TMPRSS2              Secretory             sex[T.male]  0.266853
# 82   TMPRSS2              Secretory                     age -0.003502
# 83   TMPRSS2              Secretory  smoking_status[T.True]  0.003712
# 87   TMPRSS2              Capillary             sex[T.male]  1.186622
# 88   TMPRSS2              Capillary                     age -0.027864
# 89   TMPRSS2              Capillary  smoking_status[T.True] -0.684139
# 93   TMPRSS2             Mast cells             sex[T.male]  1.120987
# 94   TMPRSS2             Mast cells                     age -0.009912
# 95   TMPRSS2             Mast cells  smoking_status[T.True] -1.180041
# 99   TMPRSS2         B cell lineage             sex[T.male]  0.280367
# 100  TMPRSS2         B cell lineage                     age -0.007162
# 101  TMPRSS2         B cell lineage  smoking_status[T.True] -0.649469
# 108  TMPRSS2            Fibroblasts             sex[T.male]  0.946428
# 109  TMPRSS2            Fibroblasts                     age -0.000950
# 110  TMPRSS2            Fibroblasts  smoking_status[T.True] -0.407290
# 114  TMPRSS2        Dendritic cells             sex[T.male]  0.251196
# 115  TMPRSS2        Dendritic cells                     age -0.007513
# 116  TMPRSS2        Dendritic cells  smoking_status[T.True] -0.495933
# 120  TMPRSS2                 Venous             sex[T.male]  0.856302
# 121  TMPRSS2                 Venous                     age -0.051988
# 122  TMPRSS2                 Venous  smoking_status[T.True] -2.144932
# 126  TMPRSS2           Lymphatic EC             sex[T.male]  0.567848
# 127  TMPRSS2           Lymphatic EC                     age -0.011344
# 128  TMPRSS2           Lymphatic EC  smoking_status[T.True]  0.055680
# 138  TMPRSS2                   Rare             sex[T.male]  0.282077
# 139  TMPRSS2                   Rare                     age -0.003152
# 140  TMPRSS2                   Rare  smoking_status[T.True]  0.100134
#
#       coef_sd           pval      adj_pvals
# 3    0.072662   5.125795e-06   1.153304e-05
# 4    0.002135   1.196886e-01   2.100394e-01
# 5    0.090973   1.400263e-01   2.100394e-01
# 12   0.019865   1.137475e-49   2.559319e-49
# 13   0.000486   5.922030e-26   1.065965e-25
# 14   0.022005   2.284573e-60   1.028058e-59
# 21   0.007640   5.616730e-01   5.616730e-01
# 22   0.000271   0.000000e+00   0.000000e+00
# 23   0.008986   4.570280e-52   1.371084e-51
# 30   0.089583   1.352804e-05   3.043809e-05
# 31   0.003576   1.577115e-01   2.838807e-01
# 32   0.116738   3.957565e-01   4.452260e-01
# 39   0.071956   7.018987e-63   6.317089e-62
# 40   0.002981   1.099027e-02   1.978249e-02
# 41   0.080283   7.471135e-02   9.605745e-02
# 48   0.018936   2.325644e-21   2.093079e-20
# 49   0.000631   6.301211e-01   7.088862e-01
# 50   0.024826   8.648743e-04   2.594623e-03
# 57   0.024020   1.273589e-36   1.146230e-35
# 58   0.000584   6.522876e-04   1.174118e-03
# 59   0.024541   7.174169e-03   9.223932e-03
# 66   0.020186  1.924583e-249  1.732124e-248
# 67   0.000746   4.273932e-57   1.923269e-56
# 68   0.029299   1.645028e-03   2.961051e-03
# 13   0.000486   5.922030e-26   1.065965e-25
# 14   0.022005   2.284573e-60   1.028058e-59
# 22   0.000271   0.000000e+00   0.000000e+00
# 23   0.008986   4.570280e-52   1.371084e-51
# 30   0.089583   1.352804e-05   3.043809e-05
# 39   0.071956   7.018987e-63   6.317089e-62
# 40   0.002981   1.099027e-02   1.978249e-02
# 48   0.018936   2.325644e-21   2.093079e-20
# 50   0.024826   8.648743e-04   2.594623e-03
# 57   0.024020   1.273589e-36   1.146230e-35
# 58   0.000584   6.522876e-04   1.174118e-03
# 59   0.024541   7.174169e-03   9.223932e-03
# 66   0.020186  1.924583e-249  1.732124e-248
# 67   0.000746   4.273932e-57   1.923269e-56
# 68   0.029299   1.645028e-03   2.961051e-03
# 81   0.023978   9.062946e-29   8.156651e-28
# 82   0.000919   1.388082e-04   6.246369e-04
# 126  0.179319   1.541841e-03   9.251045e-03
# 138  0.121165   1.991030e-02   4.479817e-02

# %%
full_res_lvl3_glm.loc[full_res_lvl3_glm['gene'] == 'CTSL',]
# Out:
#      gene          cell_identity               covariate      coef   coef_sd  \
# 6    CTSL            Macrophages             sex[T.male] -0.167304  0.002610
# 7    CTSL            Macrophages                     age  0.002582  0.000084
# 8    CTSL            Macrophages  smoking_status[T.True]  0.100365  0.003562
# 15   CTSL                  Basal             sex[T.male] -0.167472  0.010586
# 16   CTSL                  Basal                     age  0.005348  0.000297
# 17   CTSL                  Basal  smoking_status[T.True]  0.077169  0.010720
# 24   CTSL                    AT2             sex[T.male]  0.104171  0.013615
# 25   CTSL                    AT2                     age -0.005396  0.000459
# 26   CTSL                    AT2  smoking_status[T.True]  0.113451  0.017113
# 33   CTSL         T cell lineage             sex[T.male]  0.733059  0.042110
# 34   CTSL         T cell lineage                     age  0.030221  0.001357
# 35   CTSL         T cell lineage  smoking_status[T.True] -0.661709  0.052836
# 42   CTSL              Monocytes             sex[T.male] -0.147852  0.010715
# 43   CTSL              Monocytes                     age -0.001845  0.000415
# 44   CTSL              Monocytes  smoking_status[T.True] -0.160165  0.014834
# 51   CTSL  Multiciliated lineage             sex[T.male] -0.060682  0.016227
# 52   CTSL  Multiciliated lineage                     age -0.001260  0.000531
# 53   CTSL  Multiciliated lineage  smoking_status[T.True]  0.005015  0.020506
# 60   CTSL   Submucosal Secretory             sex[T.male] -0.097038  0.026834
# 61   CTSL   Submucosal Secretory                     age  0.006540  0.000699
# 62   CTSL   Submucosal Secretory  smoking_status[T.True]  0.072334  0.025804
# 69   CTSL                    AT1             sex[T.male]  0.259359  0.026330
# 70   CTSL                    AT1                     age  0.001547  0.000819
# 71   CTSL                    AT1  smoking_status[T.True]  0.152784  0.038328
# 75   CTSL  Innate lymphoid cells             sex[T.male]  0.465933  0.077852
# 76   CTSL  Innate lymphoid cells                     age  0.019030  0.002066
# 77   CTSL  Innate lymphoid cells  smoking_status[T.True]  0.421752  0.083765
# 84   CTSL              Secretory             sex[T.male] -0.002958  0.037491
# 85   CTSL              Secretory                     age  0.005070  0.001539
# 86   CTSL              Secretory  smoking_status[T.True]  0.043263  0.038721
# 90   CTSL              Capillary             sex[T.male] -0.047455  0.039031
# 91   CTSL              Capillary                     age -0.001386  0.002315
# 92   CTSL              Capillary  smoking_status[T.True]  0.297672  0.085133
# 96   CTSL             Mast cells             sex[T.male] -0.214675  0.059188
# 97   CTSL             Mast cells                     age -0.007230  0.002277
# 98   CTSL             Mast cells  smoking_status[T.True] -0.356793  0.081870
# 102  CTSL         B cell lineage             sex[T.male] -0.176326  0.081610
# 103  CTSL         B cell lineage                     age -0.002547  0.002522
# 104  CTSL         B cell lineage  smoking_status[T.True] -0.106384  0.108144
# 111  CTSL            Fibroblasts             sex[T.male] -0.004878  0.023659
# 112  CTSL            Fibroblasts                     age -0.014788  0.000817
# 113  CTSL            Fibroblasts  smoking_status[T.True]  1.031132  0.043653
# 117  CTSL        Dendritic cells             sex[T.male] -0.409138  0.034637
# 118  CTSL        Dendritic cells                     age  0.015850  0.000984
# 119  CTSL        Dendritic cells  smoking_status[T.True] -0.194686  0.046739
# 123  CTSL                 Venous             sex[T.male]  0.010482  0.050221
# 124  CTSL                 Venous                     age  0.002033  0.001538
# 125  CTSL                 Venous  smoking_status[T.True]  0.191225  0.093885
# 129  CTSL           Lymphatic EC             sex[T.male]  0.015904  0.032492
# 130  CTSL           Lymphatic EC                     age  0.004340  0.001490
# 131  CTSL           Lymphatic EC  smoking_status[T.True] -0.020372  0.063500
# 132  CTSL               Arterial             sex[T.male]  0.156750  0.072874
# 133  CTSL               Arterial                     age  0.003528  0.002912
# 134  CTSL               Arterial  smoking_status[T.True] -0.097793  0.130940
# 141  CTSL                   Rare             sex[T.male]  0.282241  0.078320
# 142  CTSL                   Rare                     age  0.005546  0.002226
# 143  CTSL                   Rare  smoking_status[T.True]  0.261578  0.083444
# 144  CTSL   Airway smooth muscle             sex[T.male] -0.174513  0.089891
# 145  CTSL   Airway smooth muscle                     age -0.009539  0.005927
# 146  CTSL   Airway smooth muscle  smoking_status[T.True]  0.411671  0.198120
#
#               pval      adj_pvals
# 6     0.000000e+00   0.000000e+00
# 7    2.672846e-207  1.202781e-206
# 8    1.222302e-174  3.666907e-174
# 15    2.235890e-56   6.707671e-56
# 16    1.908543e-72   1.717688e-71
# 17    6.077707e-13   9.116561e-13
# 24    1.993684e-14   2.990526e-14
# 25    7.452178e-32   1.676740e-31
# 26    3.363359e-11   4.324319e-11
# 33    7.157937e-68   3.221072e-67
# 34   8.132840e-110  7.319556e-109
# 35    5.534007e-36   1.660202e-35
# 42    2.614876e-43   1.176694e-42
# 43    8.695287e-06   1.956440e-05
# 44    3.546453e-27   1.063936e-26
# 51    1.844084e-04   8.298379e-04
# 52    1.767841e-02   2.651761e-02
# 53    8.067875e-01   8.067875e-01
# 60    2.988976e-04   6.725196e-04
# 61    8.674072e-21   3.903332e-20
# 62    5.059754e-03   7.589632e-03
# 69    6.837584e-23   2.051275e-22
# 70    5.886407e-02   6.622207e-02
# 71    6.713938e-05   1.510636e-04
# 75    2.165548e-09   6.496645e-09
# 76    3.245648e-20   1.947389e-19
# 77    4.779259e-07   9.558518e-07
# 84    9.371017e-01   9.371017e-01
# 85    9.888923e-04   2.966677e-03
# 86    2.638579e-01   3.957868e-01
# 90    2.240550e-01   3.360825e-01
# 91    5.494895e-01   5.717394e-01
# 92    4.712856e-04   2.827714e-03
# 96    2.867112e-04   8.601337e-04
# 97    1.495283e-03   2.990566e-03
# 98    1.312289e-05   7.873735e-05
# 102   3.072735e-02   1.843641e-01
# 103   3.126501e-01   4.878797e-01
# 104   3.252531e-01   4.878797e-01
# 111   8.366681e-01   9.412516e-01
# 112   3.407429e-73   1.533343e-72
# 113  2.354386e-123  2.118947e-122
# 117   3.384612e-32   1.015384e-31
# 118   2.483363e-58   1.490018e-57
# 119   3.107915e-05   6.215830e-05
# 123   8.346737e-01   8.346737e-01
# 124   1.862103e-01   3.724206e-01
# 125   4.166946e-02   2.500168e-01
# 129   6.245150e-01   7.898999e-01
# 130   3.583364e-03   1.075009e-02
# 131   7.483483e-01   7.898999e-01
# 132   3.147894e-02   9.443683e-02
# 133   2.257205e-01   3.385808e-01
# 134   4.551554e-01   4.551554e-01
# 141   3.137444e-04   2.823699e-03
# 142   1.271838e-02   3.815513e-02
# 143   1.719909e-03   7.739589e-03
# 144   5.221310e-02   7.831966e-02
# 145   1.074989e-01   1.074989e-01
# 146   3.771967e-02   7.831966e-02

# %%
#No smoking model
full_res_lvl3_glm_nosmoke.loc[full_res_lvl3_glm_nosmoke['gene'] == 'ACE2',]
full_res_lvl3_glm_nosmoke.loc[full_res_lvl3_glm_nosmoke['gene'] == 'TMPRSS2',]
# Out:
#     gene          cell_identity    covariate      coef   coef_sd  \
# 0   ACE2            Macrophages  sex[T.male]  0.008510  0.239116
# 1   ACE2            Macrophages          age  0.005999  0.006856
# 6   ACE2                  Basal  sex[T.male]  0.027442  0.047106
# 7   ACE2                  Basal          age  0.004157  0.001286
# 12  ACE2                    AT2  sex[T.male]  0.865860  0.055427
# 13  ACE2                    AT2          age  0.012488  0.001580
# 18  ACE2         T cell lineage  sex[T.male]  0.386654  0.541254
# 19  ACE2         T cell lineage          age -0.013028  0.019560
# 24  ACE2              Monocytes  sex[T.male]  0.833810  0.339512
# 25  ACE2              Monocytes          age -0.023647  0.015885
# 30  ACE2  Multiciliated lineage  sex[T.male]  0.236656  0.080213
# 31  ACE2  Multiciliated lineage          age  0.007576  0.002630
# 36  ACE2   Submucosal Secretory  sex[T.male]  0.004671  0.096946
# 37  ACE2   Submucosal Secretory          age  0.005288  0.002329
# 42  ACE2                    AT1  sex[T.male]  0.476816  0.204200
# 43  ACE2                    AT1          age  0.013678  0.006026
# 52  ACE2              Secretory  sex[T.male]  0.250750  0.080287
# 53  ACE2              Secretory          age -0.007369  0.003319
# 70  ACE2            Fibroblasts  sex[T.male] -1.012049  0.411001
# 71  ACE2            Fibroblasts          age -0.004430  0.009030
# 90  ACE2                   Rare  sex[T.male] -0.280205  0.817124
# 91  ACE2                   Rare          age  0.008384  0.022975
#
#             pval     adj_pvals
# 0   9.716084e-01  9.716084e-01
# 1   3.815489e-01  4.578586e-01
# 6   5.601964e-01  5.601964e-01
# 7   1.229571e-03  1.475486e-03
# 12  5.189930e-55  1.556979e-54
# 13  2.680154e-15  4.020230e-15
#
#              pval      adj_pvals
# 2    1.354162e-05   2.708324e-05
# 3    2.226501e-01   3.339752e-01
# 8    5.569659e-57   1.113932e-56
# 9    2.895972e-19   4.343959e-19
# 14   7.677888e-01   7.677888e-01
# 15   0.000000e+00   0.000000e+00
# 20   8.642011e-06   1.728402e-05
# 21   1.996597e-01   2.994895e-01
# 26   6.020818e-85   3.612491e-84
# 27   4.649438e-02   5.579326e-02
# 32   1.764789e-22   1.058874e-21
# 33   9.856807e-01   9.856807e-01
# 38   2.141115e-38   1.284669e-37
# 39   2.580443e-03   3.870664e-03
# 44  1.252311e-248  7.513867e-248
# 45   4.843084e-62   1.452925e-61
# 48   6.128840e-01   8.171786e-01
# 49   9.389744e-01   9.389744e-01
# 54   9.243609e-29   5.546165e-28
# 55   1.316222e-04   3.948667e-04
# 58   1.229963e-01   1.639951e-01
# 59   6.720202e-02   1.344040e-01
# 62   1.861441e-01   1.861441e-01
# 63   1.247859e-01   1.663813e-01
# 66   9.312565e-01   9.312565e-01
# 67   2.431124e-01   3.241499e-01
# 72   5.817858e-02   8.726787e-02
# 73   8.449447e-01   8.449447e-01
# 76   7.366573e-01   7.366573e-01
# 77   2.641984e-01   3.522645e-01
# 80   6.033451e-01   6.081852e-01
# 81   7.597741e-02   1.519548e-01
# 84   1.591241e-03   6.364963e-03
# 85   5.711677e-02   7.615569e-02
# 92   1.879975e-02   3.759949e-02
# 93   3.857606e-01   5.786408e-01

# %%
# No smoking model
full_res_lvl3_glm_nosmoke.loc[(full_res_lvl3_glm_nosmoke['gene'] == 'ACE2') & (full_res_lvl3_glm_nosmoke['adj_pvals'] < 0.05),]
# Out:
#     gene          cell_identity    covariate      coef   coef_sd  \
# 7   ACE2                  Basal          age  0.004157  0.001286
# 12  ACE2                    AT2  sex[T.male]  0.865860  0.055427
# 13  ACE2                    AT2          age  0.012488  0.001580
# 24  ACE2              Monocytes  sex[T.male]  0.833810  0.339512
# 30  ACE2  Multiciliated lineage  sex[T.male]  0.236656  0.080213
# 31  ACE2  Multiciliated lineage          age  0.007576  0.002630
# 37  ACE2   Submucosal Secretory          age  0.005288  0.002329
# 42  ACE2                    AT1  sex[T.male]  0.476816  0.204200
# 43  ACE2                    AT1          age  0.013678  0.006026
# 52  ACE2              Secretory  sex[T.male]  0.250750  0.080287
# 53  ACE2              Secretory          age -0.007369  0.003319
# 70  ACE2            Fibroblasts  sex[T.male] -1.012049  0.411001
#
#             pval     adj_pvals
# 7   1.229571e-03  1.475486e-03
# 12  5.189930e-55  1.556979e-54
# 13  2.680154e-15  4.020230e-15
# 24  1.405302e-02  2.107952e-02
# 30  3.174340e-03  5.959311e-03
# 31  3.972874e-03  5.959311e-03
# 37  2.319545e-02  2.783454e-02
# 42  1.954074e-02  2.320976e-02
# 43  2.320976e-02  2.320976e-02
# 52  1.789195e-03  2.683792e-03
# 53  2.638753e-02  3.166503e-02
# 70  1.380098e-02  2.760195e-02

# %% [markdown]
# # Store results

# %%
full_res_lvl2_glm.to_csv(folder+'/'+output_folder+de_output_base+'_lvl2_full.csv')

# %%
full_res_lvl3_glm.to_csv(folder+'/'+output_folder+de_output_base+'_lvl3_full.csv')
