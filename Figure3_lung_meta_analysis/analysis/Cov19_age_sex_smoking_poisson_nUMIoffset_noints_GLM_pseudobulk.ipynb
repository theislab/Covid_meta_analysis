# %% [markdown]
# This notebook contains the code for the meta-analysis of healthy lung data for ACE2, TMPRSS2, and CTSL. It contains the pseudo-bulk analysis for the simple model without interaction terms that was run on the patient-level data.

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors
from matplotlib import patches
import seaborn as sns
import batchglm
import diffxpy.api as de
import patsy as pat
from statsmodels.stats.multitest import multipletests
import logging, warnings
import statsmodels.api as sm
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
de.__version__

logging.getLogger("tensorflow").setLevel(logging.ERROR)
logging.getLogger("batchglm").setLevel(logging.INFO)
logging.getLogger("diffxpy").setLevel(logging.INFO)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1
# 'v0.7.3'

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

adata_diffxpy = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study/COVID19_lung_atlas_revision_v3.h5ad'

output_folder = 'diffxpy_out/'

de_output_base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm_smoking_pseudo_nUMIoffset_noInts'

# %% [markdown]
# # Read the data

# %%
adata = sc.read(adata_diffxpy)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1320896 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new'

# %%
adata.obs.age = adata.obs.age.astype(float)

# %%
adata.obs.dtypes
# Out:
# age                         float64
# anatomical_region          category
# donor                      category
# last_author/PI             category
# lung_vs_nasal              category
# notes                      category
# original_celltype_ann      category
# sample                     category
# sex                        category
# smoking                    category
# total_counts                float64
# smoked_boolean             category
# last_author_sample_name    category
# ann_level_1                category
# ann_level_2                category
# ann_level_3                category
# ann_level_4                category
# ann_level_5                category
# ann_highest_res               int64
# ann_new                        bool
# dtype: object

# %%
adata.obs['dataset'] = adata.obs['last_author/PI']

# %%
adata.obs.dataset.value_counts()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    95303
# Spence                      78401
# Barbry/Leroy                76981
# Krasnow/Quake               60993
# Meyer                       57020
# Rawlins                     53409
# Regev                       43527
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Misharin                    28329
# Xavier/Regev                25552
# Spira/Campbell              24455
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Schultze                    22641
# Schiller                    20776
# Nawijn                      18197
# Teichmann                   12971
# Kropski/Banovich_dnar        8359
# Shalek                       7603
# Linnarsson                   4640
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      2207
# Schultze/Falk                1965
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64

# %% [markdown]
# # Filter the data

# %% [markdown]
# Keep only datsets with:
# - more than 1 donor
# - non-fetal
# - lung

# %%
# Remove fetal datasets
dats_to_remove = set(['Rawlins', 'Spence', 'Linnarsson'])

# %%
dat = adata.obs.groupby(['donor']).agg({'sex':'first', 'age':'first', 'dataset':'first'})

# Single donor filter
don_tab = dat['dataset'].value_counts()
dats_to_remove.update(set(don_tab.index[don_tab == 1]))

# %%
dats_to_remove = list(dats_to_remove)
dats_to_remove
# Out:
# ['Spence', 'Rawlins', 'Misharin', 'Schultze/Falk', 'Linnarsson']

# %%
adata = adata[~adata.obs.dataset.isin(dats_to_remove)].copy()

# %%
adata.obs.lung_vs_nasal.value_counts()
# Out:
# lung     1096604
# nasal      57548
# Name: lung_vs_nasal, dtype: int64

# %%
# Filter for only lung data
adata = adata[adata.obs.lung_vs_nasal.isin(['lung']),].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1096604 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset'

# %%
adata.obs['sample'].nunique()
adata.obs['donor'].nunique()
adata.obs['dataset'].nunique()
# Out:
# 309
# 185
# 24

# %% [markdown]
# # Binarize smoking status

# %%
adata.obs.smoking.value_counts()
# Out:
# never              575345
# current            173020
# nan                111184
# former              53487
# non-smoker          42367
# never-smoker        33119
# active              29396
# smoked              28197
# current/former      23573
# heavy               15663
# current/former?      5162
# light                3316
# Former               1385
# Current               610
# Never Smoker          426
# Current Smoker        354
# Name: smoking, dtype: int64

# %%
adata.obs['smoking_status'] = adata.obs.smoked_boolean
#adata.obs['smoking_status'] = [True if stat in ['current', 'smoked', 'active', 'former', 'heavy', 'light'] else False if stat in ['never', 'nonsmoker'] else "nan" for stat in adata.obs.smoking]

# %%
adata.obs.smoking_status.value_counts()
# Out:
# False    651257
# True     334163
# nan      111184
# Name: smoking_status, dtype: int64

# %% [markdown]
# ## Filter out data w/o smoking status

# %%
pd.crosstab(adata.obs.dataset, adata.obs.smoking)
# Out:
# smoking                  Current  Current Smoker  Former  Never Smoker  \
# dataset
# Barbry/Leroy                   0               0       0             0
# Beane                          0               0       0             0
# Beane/Campbell                 0             354       0           426
# Eils/Conrad/Kreuter            0               0       0             0
# Kaminski                       0               0       0             0
# Koenigshoff                    0               0       0             0
# Krasnow/Quake                  0               0       0             0
# Kropski/Banovich_dnar          0               0       0             0
# Kropski/Banovich_vand          0               0       0             0
# Lafyatis/Rojas                 0               0       0             0
# Mazzilli/Campbell/Beane      610               0    1385             0
# Meyer                          0               0       0             0
# Meyer_b                        0               0       0             0
# Misharin/Budinger              0               0       0             0
# Nawijn                         0               0       0             0
# Regev                          0               0       0             0
# Regev/Rajagopal                0               0       0             0
# Schiller                       0               0       0             0
# Schultze                       0               0       0             0
# Seibold                        0               0       0             0
# Teichmann                      0               0       0             0
# Whitsett/Xu_10X                0               0       0             0
# Whitsett/Xu_dropSeq            0               0       0             0
# Xavier/Regev                   0               0       0             0
#
# smoking                  active  current  current/former  current/former?  \
# dataset
# Barbry/Leroy                  0        0               0                0
# Beane                         0      305               0                0
# Beane/Campbell                0        0               0                0
# Eils/Conrad/Kreuter           0    11185               0                0
# Kaminski                      0        0           23573                0
# Koenigshoff                   0        0               0                0
# Krasnow/Quake                 0        0               0                0
# Kropski/Banovich_dnar         0        0               0                0
# Kropski/Banovich_vand         0        0               0                0
# Lafyatis/Rojas                0        0               0                0
# Mazzilli/Campbell/Beane       0        0               0                0
# Meyer                      7272        0               0                0
# Meyer_b                       0   103449               0                0
# Misharin/Budinger         12557        0               0                0
# Nawijn                        0        0               0                0
# Regev                         0        0               0                0
# Regev/Rajagopal               0    58081               0                0
# Schiller                      0        0               0             5162
# Schultze                      0        0               0                0
# Seibold                       0        0               0                0
# Teichmann                  9567        0               0                0
# Whitsett/Xu_10X               0        0               0                0
# Whitsett/Xu_dropSeq           0        0               0                0
# Xavier/Regev                  0        0               0                0
#
# smoking                  former  heavy  light    nan   never  never-smoker  \
# dataset
# Barbry/Leroy              16423      0      0      0       0             0
# Beane                       581      0      0      0       0             0
# Beane/Campbell                0      0      0      0       0             0
# Eils/Conrad/Kreuter           0      0      0      0   28593             0
# Kaminski                      0      0      0   3850   67880             0
# Koenigshoff                   0      0      0      0       0         33119
# Krasnow/Quake              7524      0      0      0   53469             0
# Kropski/Banovich_dnar         0      0      0      0    2647             0
# Kropski/Banovich_vand         0      0      0      0     800             0
# Lafyatis/Rojas             3389      0      0      0   20831             0
# Mazzilli/Campbell/Beane       0      0      0      0       0             0
# Meyer                     13363      0      0      0   36385             0
# Meyer_b                       0      0      0      0   14086             0
# Misharin/Budinger          3845      0      0      0   24864             0
# Nawijn                     4958      0      0      0    6152             0
# Regev                         0      0      0  43527       0             0
# Regev/Rajagopal               0      0      0      0  264917             0
# Schiller                      0      0      0  15614       0             0
# Schultze                      0      0      0  22641       0             0
# Seibold                       0  15663   3316      0   17269             0
# Teichmann                  3404      0      0      0       0             0
# Whitsett/Xu_10X               0      0      0      0   34185             0
# Whitsett/Xu_dropSeq           0      0      0      0    3267             0
# Xavier/Regev                  0      0      0  25552       0             0
#
# smoking                  non-smoker  smoked
# dataset
# Barbry/Leroy                  42367       0
# Beane                             0       0
# Beane/Campbell                    0       0
# Eils/Conrad/Kreuter               0       0
# Kaminski                          0       0
# Koenigshoff                       0       0
# Krasnow/Quake                     0       0
# Kropski/Banovich_dnar             0    5712
# Kropski/Banovich_vand             0   22485
# Lafyatis/Rojas                    0       0
# Mazzilli/Campbell/Beane           0       0
# Meyer                             0       0
# Meyer_b                           0       0
# Misharin/Budinger                 0       0
# Nawijn                            0       0
# Regev                             0       0
# Regev/Rajagopal                   0       0
# Schiller                          0       0
# Schultze                          0       0
# Seibold                           0       0
# Teichmann                         0       0
# Whitsett/Xu_10X                   0       0
# Whitsett/Xu_dropSeq               0       0
# Xavier/Regev                      0       0

# %%
adata = adata[~adata.obs.smoking_status.isin(['nan']),].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 985420 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status'

# %%
adata.obs.dataset.value_counts()
adata.obs['sample'].nunique()
adata.obs['donor'].nunique()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    91453
# Krasnow/Quake               60993
# Barbry/Leroy                58790
# Meyer                       57020
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Teichmann                   12971
# Nawijn                      11110
# Kropski/Banovich_dnar        8359
# Schiller                     5162
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      1995
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64
# 286
# 164

# %% [markdown]
# # Check the data

# %%
np.mean(adata.X.astype(int) != adata.X)
# Out:
# 0.0

# %%
# Check if any non-integer data in a particular dataset
for dat in adata.obs.dataset.unique():
    val = np.mean(adata[adata.obs.dataset.isin([dat]),:].X.astype(int) != adata[adata.obs.dataset.isin([dat]),:].X)
    if val != 0:
        print(f'dataset= {dat}; value= {val}')
        adata[adata.obs.dataset.isin([dat]),:].X[:20,:20].A

# %% [markdown]
# All counts are integers

# %%
adata.obs.age.value_counts()
adata.obs.sex.value_counts()
# Out:
# 57.00    81833
# 66.00    69371
# 42.00    66596
# 59.00    59955
# 18.00    59849
# 46.00    56291
# 64.00    46130
# 35.00    45869
# 0.25     29908
# 67.50    28201
# 20.00    25362
# 51.00    24766
# 30.00    24095
# 29.00    19248
# 0.00     19065
# 32.00    19009
# 3.00     18387
# 42.50    16906
# 41.00    14943
# 58.00    14086
# 57.50    13840
# 23.00    13657
# 68.00    11852
# 65.00    11404
# 56.00    11024
# 75.00    10941
# 45.00    10939
# 55.00    10878
# 47.00    10278
# 49.00    10198
# 21.00     9430
# 27.00     8693
# 72.50     7983
# 22.00     7980
# 63.00     7600
# 31.00     7085
# 33.00     6906
# 44.00     6681
# 52.50     6326
# 38.00     5629
# 62.00     4679
# 24.00     4433
# 62.50     4073
# 26.00     4066
# 61.00     3922
# 67.00     3916
# 50.00     3831
# 32.50     3772
# 80.00     3261
# 10.00     2694
# 40.00     2647
# 17.00     2552
# 79.00     2550
# 54.00     2507
# 76.00     2447
# 36.00     2218
# 48.00     1153
# 25.00      823
# 70.00      168
# 69.00      130
# 87.00      112
# 43.00       79
# 34.00       76
# 78.00       65
# 74.00       52
# Name: age, dtype: int64
# female    550340
# male      435080
# Name: sex, dtype: int64

# %% [markdown]
# # Fit models and perform DE

# %%
cluster_key = 'ann_level_2'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Myeloid',
#  'Airway epithelium',
#  'Alveolar epithelium',
#  'Lymphoid',
#  'Fibroblast lineage',
#  'Blood vessels',
#  'Submucosal Gland',
#  'Smooth Muscle',
#  'Lymphatics',
#  'Mesothelium']

# %% [markdown]
# Calculate DE genes per cluster.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 985420 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status'

# %% [markdown]
# # Generate pseudobulks

# %%
for gene in adata.var_names:
    adata.obs[gene] = adata[:,gene].X.A

# %%
dat_pseudo = adata.obs.groupby(['donor', 'ann_level_2']).agg({'ACE2':'mean', 'TMPRSS2':'mean', 'CTSL':'mean', 'total_counts':'mean', 'age':'first', 'smoking_status':'first', 'sex':'first', 'dataset':'first'}).dropna().reset_index(level=[0,1])
adata_pseudo = sc.AnnData(dat_pseudo[['ACE2', 'TMPRSS2', 'CTSL']], obs=dat_pseudo.drop(columns=['ACE2', 'TMPRSS2', 'CTSL']))
# Out:
# Transforming to str index.

# %%
adata_pseudo.obs.head()
# Out:
#       donor          ann_level_2  total_counts   age smoking_status     sex  \
# 0  1A1DFBng        1_Endothelial   6307.156863  47.0           True  female
# 1  1A1DFBng    Airway epithelium   4948.705263  47.0           True  female
# 2  1A1DFBng  Alveolar epithelium   4268.209154  47.0           True  female
# 3  1A1DFBng   Fibroblast lineage   5888.260870  47.0           True  female
# 4  1A1DFBng           Lymphatics   5503.117647  47.0           True  female
#
#                dataset
# 0  Eils/Conrad/Kreuter
# 1  Eils/Conrad/Kreuter
# 2  Eils/Conrad/Kreuter
# 3  Eils/Conrad/Kreuter
# 4  Eils/Conrad/Kreuter

# %%
adata_pseudo.obs['total_counts_scaled'] = adata_pseudo.obs['total_counts']/adata_pseudo.obs['total_counts'].mean()

# %%
formula = "1 + sex + age + smoking_status + dataset"
tested_coef = ["sex[T.male]", "age", "smoking_status[T.True]"]
dmat = de.utils.design_matrix(
    data=adata_pseudo,
    formula="~" + formula,
    as_numeric=["age"],
    return_type="patsy"
)
dmat[1]
# Out:
# ['Intercept',
#  'sex[T.male]',
#  'smoking_status[T.True]',
#  'dataset[T.Beane]',
#  'dataset[T.Beane/Campbell]',
#  'dataset[T.Eils/Conrad/Kreuter]',
#  'dataset[T.Kaminski]',
#  'dataset[T.Koenigshoff]',
#  'dataset[T.Krasnow/Quake]',
#  'dataset[T.Kropski/Banovich_dnar]',
#  'dataset[T.Kropski/Banovich_vand]',
#  'dataset[T.Lafyatis/Rojas]',
#  'dataset[T.Mazzilli/Campbell/Beane]',
#  'dataset[T.Meyer]',
#  'dataset[T.Meyer_b]',
#  'dataset[T.Misharin/Budinger]',
#  'dataset[T.Nawijn]',
#  'dataset[T.Regev/Rajagopal]',
#  'dataset[T.Schiller]',
#  'dataset[T.Seibold]',
#  'dataset[T.Teichmann]',
#  'dataset[T.Whitsett/Xu_10X]',
#  'dataset[T.Whitsett/Xu_dropSeq]',
#  'age']

# %% [markdown]
# ## Poisson GLM

# %%
# Poisson GLM loop
de_results_lvl2_glm = dict()

# Test over clusters
for clust in clusters:
    adata_pseudo_tmp = adata_pseudo[adata_pseudo.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_pseudo_tmp.obs['smoking_status'].value_counts())
    print(adata_pseudo_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_pseudo_tmp, min_cells=4)
    if adata_pseudo_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_pseudo_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
        
    print(f'Testing {adata_pseudo_tmp.n_vars} genes...')
    print(f'Testing in {adata_pseudo_tmp.n_obs} donors...')    
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_pseudo_tmp, #[idx_train],
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_pseudo_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_pseudo_tmp.X[:, i], #[idx_train, :], 
            exog=dmat[0],
            offset=np.log(adata_pseudo_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()


        # Test over coefs
        for coef in tested_coef:
            de_results_temp = pois_results.wald_test(
                [x for i, x in enumerate(pois_model.exog_names) if dmat[1][i] in [coef]]
            )

            # Output the results nicely
            de_results_temp = pd.DataFrame({
                "gene": gene,
                "cell_identity": clust,
                "covariate": coef,
                "coef": pois_results.params[[y == coef for y in dmat[1]]],
                "coef_sd": pois_results.bse[[y == coef for y in dmat[1]]],                 
                "pval": de_results_temp.pvalue
            }, index= [clust+"_"+gene+"_"+coef])

            de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl2_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl2_glm = pd.concat([de_results_lvl2_glm[i] for i in de_results_lvl2_glm.keys()], ignore_index=True)
# Out:
# In cluster Myeloid:
# False    66
# True     55
# Name: smoking_status, dtype: int64
# male      64
# female    57
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 121 donors...
#
# In cluster Airway epithelium:
# False    90
# True     71
# Name: smoking_status, dtype: int64
# male      85
# female    76
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 161 donors...
#
# In cluster Alveolar epithelium:
# False    67
# True     39
# Name: smoking_status, dtype: int64
# male      55
# female    51
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 106 donors...
#
# In cluster Lymphoid:
# False    72
# True     62
# Name: smoking_status, dtype: int64
# male      70
# female    64
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 134 donors...
#
# In cluster Fibroblast lineage:
# False    54
# True     40
# Name: smoking_status, dtype: int64
# male      50
# female    44
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 94 donors...
#
# In cluster Blood vessels:
# False    48
# True     31
# Name: smoking_status, dtype: int64
# male      45
# female    34
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 79 donors...
#
# In cluster Submucosal Gland:
# False    28
# True     17
# Name: smoking_status, dtype: int64
# male      25
# female    20
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 45 donors...
#
# In cluster Smooth Muscle:
# False    35
# True     26
# Name: smoking_status, dtype: int64
# female    31
# male      30
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 61 donors...
#
# In cluster Lymphatics:
# False    45
# True     31
# Name: smoking_status, dtype: int64
# male      39
# female    37
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 76 donors...
#
# In cluster Mesothelium:
# True     15
# False    14
# Name: smoking_status, dtype: int64
# male      15
# female    14
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 29 donors...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl2_glm.keys()
# Out:
# dict_keys(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid', 'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland', 'Smooth Muscle', 'Lymphatics', 'Mesothelium'])

# %%
full_res_lvl2_glm
# Out:
#        gene        cell_identity               covariate       coef  \
# 0      ACE2              Myeloid             sex[T.male]   0.221611
# 1      ACE2              Myeloid                     age  -0.018497
# 2      ACE2              Myeloid  smoking_status[T.True]  -0.204864
# 3   TMPRSS2              Myeloid             sex[T.male]   0.795619
# 4   TMPRSS2              Myeloid                     age   0.004908
# 5   TMPRSS2              Myeloid  smoking_status[T.True]  -0.220177
# 6      CTSL              Myeloid             sex[T.male]  -0.000920
# 7      CTSL              Myeloid                     age   0.003918
# 8      CTSL              Myeloid  smoking_status[T.True]  -0.087094
# 9      ACE2    Airway epithelium             sex[T.male]   0.031009
# 10     ACE2    Airway epithelium                     age  -0.005680
# 11     ACE2    Airway epithelium  smoking_status[T.True]   0.074311
# 12  TMPRSS2    Airway epithelium             sex[T.male]   0.258566
# 13  TMPRSS2    Airway epithelium                     age  -0.003266
# 14  TMPRSS2    Airway epithelium  smoking_status[T.True]  -0.055584
# 15     CTSL    Airway epithelium             sex[T.male]  -0.010994
# 16     CTSL    Airway epithelium                     age   0.001673
# 17     CTSL    Airway epithelium  smoking_status[T.True]   0.045405
# 18     ACE2  Alveolar epithelium             sex[T.male]   0.367086
# 19     ACE2  Alveolar epithelium                     age   0.014020
# 20     ACE2  Alveolar epithelium  smoking_status[T.True]  -0.581271
# 21  TMPRSS2  Alveolar epithelium             sex[T.male]   0.147282
# 22  TMPRSS2  Alveolar epithelium                     age   0.007706
# 23  TMPRSS2  Alveolar epithelium  smoking_status[T.True]   0.323104
# 24     CTSL  Alveolar epithelium             sex[T.male]   0.098483
# 25     CTSL  Alveolar epithelium                     age  -0.004449
# 26     CTSL  Alveolar epithelium  smoking_status[T.True]  -0.167903
# 27     ACE2             Lymphoid             sex[T.male]   0.188154
# 28     ACE2             Lymphoid                     age  -0.156848
# 29     ACE2             Lymphoid  smoking_status[T.True]   1.222224
# 30  TMPRSS2             Lymphoid             sex[T.male]   0.601927
# 31  TMPRSS2             Lymphoid                     age  -0.003529
# 32  TMPRSS2             Lymphoid  smoking_status[T.True]   0.584867
# 33     CTSL             Lymphoid             sex[T.male]   0.262066
# 34     CTSL             Lymphoid                     age   0.018559
# 35     CTSL             Lymphoid  smoking_status[T.True]  -0.183446
# 36     ACE2   Fibroblast lineage             sex[T.male]  -0.104376
# 37     ACE2   Fibroblast lineage                     age  -0.021113
# 38     ACE2   Fibroblast lineage  smoking_status[T.True]   0.784406
# 39  TMPRSS2   Fibroblast lineage             sex[T.male]   0.550943
# 40  TMPRSS2   Fibroblast lineage                     age   0.011873
# 41  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   0.340461
# 42     CTSL   Fibroblast lineage             sex[T.male]  -0.269466
# 43     CTSL   Fibroblast lineage                     age  -0.002064
# 44     CTSL   Fibroblast lineage  smoking_status[T.True]   0.303269
# 45     ACE2        Blood vessels             sex[T.male]   0.595478
# 46     ACE2        Blood vessels                     age   0.008962
# 47     ACE2        Blood vessels  smoking_status[T.True]  -1.613588
# 48  TMPRSS2        Blood vessels             sex[T.male]   0.061179
# 49  TMPRSS2        Blood vessels                     age   0.025418
# 50  TMPRSS2        Blood vessels  smoking_status[T.True]  -0.419532
# 51     CTSL        Blood vessels             sex[T.male]   0.206364
# 52     CTSL        Blood vessels                     age   0.010324
# 53     CTSL        Blood vessels  smoking_status[T.True]  -0.238791
# 54     ACE2     Submucosal Gland             sex[T.male]  -0.053223
# 55     ACE2     Submucosal Gland                     age   0.004246
# 56     ACE2     Submucosal Gland  smoking_status[T.True]   0.103701
# 57  TMPRSS2     Submucosal Gland             sex[T.male]   0.083521
# 58  TMPRSS2     Submucosal Gland                     age   0.000526
# 59  TMPRSS2     Submucosal Gland  smoking_status[T.True]  -0.352479
# 60     CTSL     Submucosal Gland             sex[T.male]  -0.044331
# 61     CTSL     Submucosal Gland                     age   0.000750
# 62     CTSL     Submucosal Gland  smoking_status[T.True]   0.097627
# 63     ACE2        Smooth Muscle             sex[T.male]   0.656818
# 64     ACE2        Smooth Muscle                     age  -0.015317
# 65     ACE2        Smooth Muscle  smoking_status[T.True]   3.232622
# 66  TMPRSS2        Smooth Muscle             sex[T.male]  -0.989011
# 67  TMPRSS2        Smooth Muscle                     age   0.002524
# 68  TMPRSS2        Smooth Muscle  smoking_status[T.True]  -0.497620
# 69     CTSL        Smooth Muscle             sex[T.male]  -0.238704
# 70     CTSL        Smooth Muscle                     age  -0.018657
# 71     CTSL        Smooth Muscle  smoking_status[T.True]   0.111396
# 72     ACE2           Lymphatics             sex[T.male]   1.333554
# 73     ACE2           Lymphatics                     age   0.069008
# 74     ACE2           Lymphatics  smoking_status[T.True]  -0.328886
# 75  TMPRSS2           Lymphatics             sex[T.male]   0.556664
# 76  TMPRSS2           Lymphatics                     age  -0.011158
# 77  TMPRSS2           Lymphatics  smoking_status[T.True]   0.067875
# 78     CTSL           Lymphatics             sex[T.male]   0.067957
# 79     CTSL           Lymphatics                     age   0.001236
# 80     CTSL           Lymphatics  smoking_status[T.True]   0.096030
# 81  TMPRSS2          Mesothelium             sex[T.male]  -0.887433
# 82  TMPRSS2          Mesothelium                     age   0.075714
# 83  TMPRSS2          Mesothelium  smoking_status[T.True] -19.128939
# 84     CTSL          Mesothelium             sex[T.male]  -0.223896
# 85     CTSL          Mesothelium                     age   0.001248
# 86     CTSL          Mesothelium  smoking_status[T.True]  -0.254642
#
#          coef_sd      pval  adj_pvals
# 0       7.020798  0.974819   0.993497
# 1       0.241049  0.938833   0.993497
# 2       8.144168  0.979932   0.993497
# 3       1.355592  0.557260   0.993497
# 4       0.046647  0.916201   0.993497
# 5       1.711704  0.897650   0.993497
# 6       0.112928  0.993497   0.993497
# 7       0.003454  0.256681   0.993497
# 8       0.139397  0.532110   0.993497
# 9       1.115313  0.977820   0.977820
# 10      0.045035  0.899639   0.977820
# 11      1.362581  0.956507   0.977820
# 12      0.294559  0.380048   0.977820
# 13      0.009923  0.742030   0.977820
# 14      0.352938  0.874859   0.977820
# 15      0.286640  0.969404   0.977820
# 16      0.009573  0.861278   0.977820
# 17      0.329567  0.890422   0.977820
# 18      2.225475  0.868985   0.868985
# 19      0.069400  0.839904   0.868985
# 20      3.036217  0.848176   0.868985
# 21      0.249631  0.555193   0.868985
# 22      0.007829  0.324978   0.868985
# 23      0.299383  0.280485   0.868985
# 24      0.440179  0.822965   0.868985
# 25      0.013697  0.745340   0.868985
# 26      0.605073  0.781402   0.868985
# 27      1.869316  0.919825   0.919825
# 28      0.176604  0.374469   0.919825
# 29      1.952870  0.531406   0.919825
# 30      0.847928  0.477779   0.919825
# 31      0.030591  0.908166   0.919825
# 32      0.832716  0.482454   0.919825
# 33      0.598978  0.661733   0.919825
# 34      0.018426  0.313844   0.919825
# 35      0.702675  0.794040   0.919825
# 36      4.585222  0.981839   0.981839
# 37      0.149725  0.887863   0.981839
# 38      4.833142  0.871072   0.981839
# 39      1.013579  0.586743   0.981839
# 40      0.034665  0.731977   0.981839
# 41      1.117132  0.760546   0.981839
# 42      0.180035  0.134460   0.741126
# 43      0.005876  0.725345   0.981839
# 44      0.218265  0.164695   0.741126
# 45      3.292395  0.856474   0.984653
# 46      0.084850  0.915880   0.984653
# 47      5.098641  0.751643   0.984653
# 48      3.180538  0.984653   0.984653
# 49      0.090548  0.778934   0.984653
# 50      3.225621  0.896517   0.984653
# 51      0.435466  0.635577   0.984653
# 52      0.014767  0.484455   0.984653
# 53      0.459869  0.603580   0.984653
# 54      2.375454  0.982125   0.982125
# 55      0.066295  0.948935   0.982125
# 56      2.663909  0.968948   0.982125
# 57      0.595118  0.888388   0.982125
# 58      0.017350  0.975820   0.982125
# 59      0.762170  0.643745   0.982125
# 60      0.425981  0.917115   0.982125
# 61      0.013221  0.954776   0.982125
# 62      0.444370  0.826107   0.982125
# 63      3.706922  0.859362   0.979915
# 64      0.106903  0.886066   0.979915
# 65     12.622007  0.797866   0.979915
# 66      3.843764  0.796945   0.979915
# 67      0.100252  0.979915   0.979915
# 68      7.034698  0.943606   0.979915
# 69      0.354274  0.500448   0.979915
# 70      0.012797  0.144867   0.979915
# 71      0.459808  0.808573   0.979915
# 72      5.301818  0.801406   0.952411
# 73      0.198223  0.727742   0.952411
# 74      5.510912  0.952411   0.952411
# 75      0.893311  0.533188   0.952411
# 76      0.031078  0.719566   0.952411
# 77      0.949735  0.943026   0.952411
# 78      0.309926  0.826441   0.952411
# 79      0.009485  0.896310   0.952411
# 80      0.368245  0.794264   0.952411
# 81      3.862302  0.818272   0.999515
# 82      0.146498  0.605277   0.999515
# 83  31447.848010  0.999515   0.999515
# 84      0.358780  0.532596   0.999515
# 85      0.013078  0.923989   0.999515
# 86      0.972531  0.793449   0.999515

# %%
full_res_lvl2_glm.loc[full_res_lvl2_glm['gene'] == 'ACE2',]
# Out:
#     gene        cell_identity               covariate      coef    coef_sd  \
# 0   ACE2              Myeloid             sex[T.male]  0.221611   7.020798
# 1   ACE2              Myeloid                     age -0.018497   0.241049
# 2   ACE2              Myeloid  smoking_status[T.True] -0.204864   8.144168
# 9   ACE2    Airway epithelium             sex[T.male]  0.031009   1.115313
# 10  ACE2    Airway epithelium                     age -0.005680   0.045035
# 11  ACE2    Airway epithelium  smoking_status[T.True]  0.074311   1.362581
# 18  ACE2  Alveolar epithelium             sex[T.male]  0.367086   2.225475
# 19  ACE2  Alveolar epithelium                     age  0.014020   0.069400
# 20  ACE2  Alveolar epithelium  smoking_status[T.True] -0.581271   3.036217
# 27  ACE2             Lymphoid             sex[T.male]  0.188154   1.869316
# 28  ACE2             Lymphoid                     age -0.156848   0.176604
# 29  ACE2             Lymphoid  smoking_status[T.True]  1.222224   1.952870
# 36  ACE2   Fibroblast lineage             sex[T.male] -0.104376   4.585222
# 37  ACE2   Fibroblast lineage                     age -0.021113   0.149725
# 38  ACE2   Fibroblast lineage  smoking_status[T.True]  0.784406   4.833142
# 45  ACE2        Blood vessels             sex[T.male]  0.595478   3.292395
# 46  ACE2        Blood vessels                     age  0.008962   0.084850
# 47  ACE2        Blood vessels  smoking_status[T.True] -1.613588   5.098641
# 54  ACE2     Submucosal Gland             sex[T.male] -0.053223   2.375454
# 55  ACE2     Submucosal Gland                     age  0.004246   0.066295
# 56  ACE2     Submucosal Gland  smoking_status[T.True]  0.103701   2.663909
# 63  ACE2        Smooth Muscle             sex[T.male]  0.656818   3.706922
# 64  ACE2        Smooth Muscle                     age -0.015317   0.106903
# 65  ACE2        Smooth Muscle  smoking_status[T.True]  3.232622  12.622007
# 72  ACE2           Lymphatics             sex[T.male]  1.333554   5.301818
# 73  ACE2           Lymphatics                     age  0.069008   0.198223
# 74  ACE2           Lymphatics  smoking_status[T.True] -0.328886   5.510912
#
#         pval  adj_pvals
# 0   0.974819   0.993497
# 1   0.938833   0.993497
# 2   0.979932   0.993497
# 9   0.977820   0.977820
# 10  0.899639   0.977820
# 11  0.956507   0.977820
# 18  0.868985   0.868985
# 19  0.839904   0.868985
# 20  0.848176   0.868985
# 27  0.919825   0.919825
# 28  0.374469   0.919825
# 29  0.531406   0.919825
# 36  0.981839   0.981839
# 37  0.887863   0.981839
# 38  0.871072   0.981839
# 45  0.856474   0.984653
# 46  0.915880   0.984653
# 47  0.751643   0.984653
# 54  0.982125   0.982125
# 55  0.948935   0.982125
# 56  0.968948   0.982125
# 63  0.859362   0.979915
# 64  0.886066   0.979915
# 65  0.797866   0.979915
# 72  0.801406   0.952411
# 73  0.727742   0.952411
# 74  0.952411   0.952411

# %%
full_res_lvl2_glm.loc[full_res_lvl2_glm['gene'] == 'TMPRSS2',]
# Out:
#        gene        cell_identity               covariate       coef  \
# 3   TMPRSS2              Myeloid             sex[T.male]   0.795619
# 4   TMPRSS2              Myeloid                     age   0.004908
# 5   TMPRSS2              Myeloid  smoking_status[T.True]  -0.220177
# 12  TMPRSS2    Airway epithelium             sex[T.male]   0.258566
# 13  TMPRSS2    Airway epithelium                     age  -0.003266
# 14  TMPRSS2    Airway epithelium  smoking_status[T.True]  -0.055584
# 21  TMPRSS2  Alveolar epithelium             sex[T.male]   0.147282
# 22  TMPRSS2  Alveolar epithelium                     age   0.007706
# 23  TMPRSS2  Alveolar epithelium  smoking_status[T.True]   0.323104
# 30  TMPRSS2             Lymphoid             sex[T.male]   0.601927
# 31  TMPRSS2             Lymphoid                     age  -0.003529
# 32  TMPRSS2             Lymphoid  smoking_status[T.True]   0.584867
# 39  TMPRSS2   Fibroblast lineage             sex[T.male]   0.550943
# 40  TMPRSS2   Fibroblast lineage                     age   0.011873
# 41  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   0.340461
# 48  TMPRSS2        Blood vessels             sex[T.male]   0.061179
# 49  TMPRSS2        Blood vessels                     age   0.025418
# 50  TMPRSS2        Blood vessels  smoking_status[T.True]  -0.419532
# 57  TMPRSS2     Submucosal Gland             sex[T.male]   0.083521
# 58  TMPRSS2     Submucosal Gland                     age   0.000526
# 59  TMPRSS2     Submucosal Gland  smoking_status[T.True]  -0.352479
# 66  TMPRSS2        Smooth Muscle             sex[T.male]  -0.989011
# 67  TMPRSS2        Smooth Muscle                     age   0.002524
# 68  TMPRSS2        Smooth Muscle  smoking_status[T.True]  -0.497620
# 75  TMPRSS2           Lymphatics             sex[T.male]   0.556664
# 76  TMPRSS2           Lymphatics                     age  -0.011158
# 77  TMPRSS2           Lymphatics  smoking_status[T.True]   0.067875
# 81  TMPRSS2          Mesothelium             sex[T.male]  -0.887433
# 82  TMPRSS2          Mesothelium                     age   0.075714
# 83  TMPRSS2          Mesothelium  smoking_status[T.True] -19.128939
#
#          coef_sd      pval  adj_pvals
# 3       1.355592  0.557260   0.993497
# 4       0.046647  0.916201   0.993497
# 5       1.711704  0.897650   0.993497
# 12      0.294559  0.380048   0.977820
# 13      0.009923  0.742030   0.977820
# 14      0.352938  0.874859   0.977820
# 21      0.249631  0.555193   0.868985
# 22      0.007829  0.324978   0.868985
# 23      0.299383  0.280485   0.868985
# 30      0.847928  0.477779   0.919825
# 31      0.030591  0.908166   0.919825
# 32      0.832716  0.482454   0.919825
# 39      1.013579  0.586743   0.981839
# 40      0.034665  0.731977   0.981839
# 41      1.117132  0.760546   0.981839
# 48      3.180538  0.984653   0.984653
# 49      0.090548  0.778934   0.984653
# 50      3.225621  0.896517   0.984653
# 57      0.595118  0.888388   0.982125
# 58      0.017350  0.975820   0.982125
# 59      0.762170  0.643745   0.982125
# 66      3.843764  0.796945   0.979915
# 67      0.100252  0.979915   0.979915
# 68      7.034698  0.943606   0.979915
# 75      0.893311  0.533188   0.952411
# 76      0.031078  0.719566   0.952411
# 77      0.949735  0.943026   0.952411
# 81      3.862302  0.818272   0.999515
# 82      0.146498  0.605277   0.999515
# 83  31447.848010  0.999515   0.999515

# %% [markdown]
# # Level 3 annotation

# %%
cluster_key = 'ann_level_3'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') or ct.startswith('2') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Macrophages',
#  'Basal',
#  'AT2',
#  'T cell lineage',
#  'Monocytes',
#  'Multiciliated lineage',
#  'Submucosal Secretory',
#  'AT1',
#  'Innate lymphoid cells',
#  'Secretory',
#  'Capillary',
#  'Mast cells',
#  'B cell lineage',
#  'Fibroblasts',
#  'Dendritic cells',
#  'Venous',
#  'Lymphatic EC',
#  'Arterial',
#  'Rare',
#  'Airway smooth muscle']

# %%
adata_sub = adata[adata.obs.ann_level_3.isin(clusters),:]

adata_sub
adata_sub.obs.donor.nunique()
adata_sub.obs['sample'].nunique()
# Out:
# View of AnnData object with n_obs × n_vars = 795195 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status', 'ACE2', 'TMPRSS2', 'CTSL'
# 164
# 286

# %% [markdown]
# ## Generate pseudobulk

# %%
for gene in adata_sub.var_names:
    adata_sub.obs[gene] = adata_sub[:,gene].X.A
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
dat_pseudo_sub = adata_sub.obs.groupby(['donor', 'ann_level_3']).agg({'ACE2':'mean', 'TMPRSS2':'mean', 'CTSL':'mean', 'total_counts':'mean', 'age':'first', 'smoking_status':'first', 'sex':'first', 'dataset':'first'}).dropna().reset_index(level=[0,1])
adata_pseudo_sub = sc.AnnData(dat_pseudo_sub[['ACE2', 'TMPRSS2', 'CTSL']], obs=dat_pseudo_sub.drop(columns=['ACE2', 'TMPRSS2', 'CTSL']))
# Out:
# Transforming to str index.

# %%
adata_pseudo_sub.obs.head()
# Out:
#       donor            ann_level_3  total_counts   age smoking_status     sex  \
# 0  1A1DFBng                    AT1   3709.913265  47.0           True  female
# 1  1A1DFBng                    AT2   4453.519898  47.0           True  female
# 2  1A1DFBng           Lymphatic EC   5503.117647  47.0           True  female
# 3  1A1DFBng              Monocytes   3339.083948  47.0           True  female
# 4  1A1DFBng  Multiciliated lineage   6000.121212  47.0           True  female
#
#                dataset
# 0  Eils/Conrad/Kreuter
# 1  Eils/Conrad/Kreuter
# 2  Eils/Conrad/Kreuter
# 3  Eils/Conrad/Kreuter
# 4  Eils/Conrad/Kreuter

# %%
adata_pseudo_sub.obs['total_counts_scaled'] = adata_pseudo_sub.obs['total_counts']/adata_pseudo_sub.obs['total_counts'].mean()

# %% [markdown]
# ## Poisson GLM

# %% [markdown]
# First check if there are any datasets with only 1 sex or 1 smoking status, which would make the model overparameterized (not full rank).

# %%
np.any(adata_pseudo_tmp.obs.smoking_status.value_counts() == 1)
# Out:
# False

# %%
np.any(pd.crosstab(adata_pseudo_tmp.obs.smoking_status, adata_pseudo_tmp.obs.sex) == 1)
# Out:
# False

# %%
clusters
# Out:
# ['Macrophages',
#  'Basal',
#  'AT2',
#  'T cell lineage',
#  'Monocytes',
#  'Multiciliated lineage',
#  'Submucosal Secretory',
#  'AT1',
#  'Innate lymphoid cells',
#  'Secretory',
#  'Capillary',
#  'Mast cells',
#  'B cell lineage',
#  'Fibroblasts',
#  'Dendritic cells',
#  'Venous',
#  'Lymphatic EC',
#  'Arterial',
#  'Rare',
#  'Airway smooth muscle']

# %%
# Poisson GLM loop
de_results_lvl3_glm = dict()

# Test over clusters
for clust in clusters:
    adata_pseudo_tmp = adata_pseudo_sub[adata_pseudo_sub.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_pseudo_tmp.obs['smoking_status'].value_counts())
    print(adata_pseudo_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_pseudo_tmp, min_cells=4)
    if adata_pseudo_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_pseudo_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
    if np.any(adata_pseudo_tmp.obs.smoking_status.value_counts()==1):
        print(f'{clust} only has 1 smoker or 1 nonsmoker sample.')
        continue
    if np.any(adata_pseudo_tmp.obs.sex.value_counts()==1):
        print(f'{clust} only has 1 male or 1 female sample.')
        continue
    if np.any(pd.crosstab(adata_pseudo_tmp.obs.smoking_status, adata_pseudo_tmp.obs.sex) == 1):
        print('Want at least 2 in each smoking/sex category.')
        continue
        
    print(f'Testing {adata_pseudo_tmp.n_vars} genes...')
    print(f'Testing in {adata_pseudo_tmp.n_obs} donors...')    
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_pseudo_tmp,
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_pseudo_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_pseudo_tmp.X[:, i],
            exog=dmat[0],
            offset=np.log(adata_pseudo_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()

        # Test over coefs
        for coef in tested_coef:
            de_results_temp = pois_results.wald_test(
                [x for i, x in enumerate(pois_model.exog_names) if dmat[1][i] in [coef]]
            )

            # Output the results nicely
            de_results_temp = pd.DataFrame({
                "gene": gene,
                "cell_identity": clust,
                "covariate": coef,
                "coef": pois_results.params[[y == coef for y in dmat[1]]],
                "coef_sd": pois_results.bse[[y == coef for y in dmat[1]]],                 
                "pval": de_results_temp.pvalue
            }, index= [clust+"_"+gene+"_"+coef])

            de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl3_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl3_glm = pd.concat([de_results_lvl3_glm[i] for i in de_results_lvl3_glm.keys()], ignore_index=True)
# Out:
# In cluster Macrophages:
# False    49
# True     40
# Name: smoking_status, dtype: int64
# male      52
# female    37
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 89 donors...
#
# In cluster Basal:
# False    53
# True     52
# Name: smoking_status, dtype: int64
# male      58
# female    47
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 105 donors...
#
# In cluster AT2:
# False    66
# True     38
# Name: smoking_status, dtype: int64
# male      53
# female    51
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 104 donors...
#
# In cluster T cell lineage:
# False    51
# True     46
# Name: smoking_status, dtype: int64
# male      53
# female    44
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 97 donors...
#
# In cluster Monocytes:
# False    57
# True     39
# Name: smoking_status, dtype: int64
# male      51
# female    45
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 96 donors...
#
# In cluster Multiciliated lineage:
# False    88
# True     69
# Name: smoking_status, dtype: int64
# male      83
# female    74
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 157 donors...
#
# In cluster Submucosal Secretory:
# False    28
# True     17
# Name: smoking_status, dtype: int64
# male      25
# female    20
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 45 donors...
#
# In cluster AT1:
# False    65
# True     36
# Name: smoking_status, dtype: int64
# male      51
# female    50
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 101 donors...
#
# In cluster Innate lymphoid cells:
# False    33
# True     23
# Name: smoking_status, dtype: int64
# male      33
# female    23
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 56 donors...
#
# In cluster Secretory:
# False    75
# True     65
# Name: smoking_status, dtype: int64
# male      76
# female    64
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 140 donors...
#
# In cluster Capillary:
# False    22
# True     12
# Name: smoking_status, dtype: int64
# male      20
# female    14
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 34 donors...
#
# In cluster Mast cells:
# False    49
# True     39
# Name: smoking_status, dtype: int64
# male      46
# female    42
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 88 donors...
#
# In cluster B cell lineage:
# False    52
# True     38
# Name: smoking_status, dtype: int64
# male      53
# female    37
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 90 donors...
#
# In cluster Fibroblasts:
# False    31
# True     20
# Name: smoking_status, dtype: int64
# male      30
# female    21
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 51 donors...
#
# In cluster Dendritic cells:
# False    48
# True     42
# Name: smoking_status, dtype: int64
# male      50
# female    40
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 90 donors...
#
# In cluster Venous:
# False    22
# True     11
# Name: smoking_status, dtype: int64
# male      19
# female    14
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 33 donors...
#
# In cluster Lymphatic EC:
# False    45
# True     31
# Name: smoking_status, dtype: int64
# male      39
# female    37
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 76 donors...
#
# In cluster Arterial:
# False    25
# True     12
# Name: smoking_status, dtype: int64
# male      23
# female    14
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 37 donors...
#
# In cluster Rare:
# False    37
# True     34
# Name: smoking_status, dtype: int64
# male      39
# female    32
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 71 donors...
#
# In cluster Airway smooth muscle:
# True     7
# False    6
# Name: smoking_status, dtype: int64
# male      9
# female    4
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 4 cells
# Testing 1 genes...
# Testing in 13 donors...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl3_glm.keys()
# Out:
# dict_keys(['Macrophages', 'Basal', 'AT2', 'T cell lineage', 'Monocytes', 'Multiciliated lineage', 'Submucosal Secretory', 'AT1', 'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells', 'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous', 'Lymphatic EC', 'Arterial', 'Rare', 'Airway smooth muscle'])

# %%
full_res_lvl3_glm
# Out:
#         gene          cell_identity               covariate      coef  \
# 0       ACE2            Macrophages             sex[T.male] -1.369711
# 1       ACE2            Macrophages                     age -0.004721
# 2       ACE2            Macrophages  smoking_status[T.True]  0.589270
# 3    TMPRSS2            Macrophages             sex[T.male] -0.274432
# 4    TMPRSS2            Macrophages                     age  0.000789
# 5    TMPRSS2            Macrophages  smoking_status[T.True]  0.260110
# 6       CTSL            Macrophages             sex[T.male] -0.081822
# 7       CTSL            Macrophages                     age  0.007715
# 8       CTSL            Macrophages  smoking_status[T.True] -0.112935
# 9       ACE2                  Basal             sex[T.male]  0.185648
# 10      ACE2                  Basal                     age -0.017825
# 11      ACE2                  Basal  smoking_status[T.True]  0.351985
# 12   TMPRSS2                  Basal             sex[T.male]  0.472367
# 13   TMPRSS2                  Basal                     age  0.014899
# 14   TMPRSS2                  Basal  smoking_status[T.True] -0.289572
# 15      CTSL                  Basal             sex[T.male] -0.129552
# 16      CTSL                  Basal                     age -0.009273
# 17      CTSL                  Basal  smoking_status[T.True]  0.406826
# 18      ACE2                    AT2             sex[T.male]  0.450535
# 19      ACE2                    AT2                     age  0.008466
# 20      ACE2                    AT2  smoking_status[T.True] -0.743612
# 21   TMPRSS2                    AT2             sex[T.male]  0.162023
# 22   TMPRSS2                    AT2                     age  0.007968
# 23   TMPRSS2                    AT2  smoking_status[T.True]  0.244325
# 24      CTSL                    AT2             sex[T.male]  0.049721
# 25      CTSL                    AT2                     age -0.005229
# 26      CTSL                    AT2  smoking_status[T.True] -0.053486
# 27      ACE2         T cell lineage             sex[T.male]  0.866244
# 28      ACE2         T cell lineage                     age -0.009097
# 29      ACE2         T cell lineage  smoking_status[T.True] -1.441925
# 30   TMPRSS2         T cell lineage             sex[T.male]  0.639215
# 31   TMPRSS2         T cell lineage                     age -0.002976
# 32   TMPRSS2         T cell lineage  smoking_status[T.True]  0.542281
# 33      CTSL         T cell lineage             sex[T.male]  0.617347
# 34      CTSL         T cell lineage                     age  0.032278
# 35      CTSL         T cell lineage  smoking_status[T.True] -0.313474
# 36      ACE2              Monocytes             sex[T.male]  0.490639
# 37      ACE2              Monocytes                     age -0.033338
# 38      ACE2              Monocytes  smoking_status[T.True] -0.340043
# 39   TMPRSS2              Monocytes             sex[T.male]  0.847432
# 40   TMPRSS2              Monocytes                     age  0.007860
# 41   TMPRSS2              Monocytes  smoking_status[T.True] -0.380168
# 42      CTSL              Monocytes             sex[T.male] -0.251555
# 43      CTSL              Monocytes                     age  0.006737
# 44      CTSL              Monocytes  smoking_status[T.True] -0.230078
# 45      ACE2  Multiciliated lineage             sex[T.male]  0.080958
# 46      ACE2  Multiciliated lineage                     age  0.000957
# 47      ACE2  Multiciliated lineage  smoking_status[T.True]  0.217602
# 48   TMPRSS2  Multiciliated lineage             sex[T.male]  0.064932
# 49   TMPRSS2  Multiciliated lineage                     age -0.005161
# 50   TMPRSS2  Multiciliated lineage  smoking_status[T.True] -0.098005
# 51      CTSL  Multiciliated lineage             sex[T.male] -0.028217
# 52      CTSL  Multiciliated lineage                     age  0.004728
# 53      CTSL  Multiciliated lineage  smoking_status[T.True] -0.055379
# 54      ACE2   Submucosal Secretory             sex[T.male] -0.053223
# 55      ACE2   Submucosal Secretory                     age  0.004246
# 56      ACE2   Submucosal Secretory  smoking_status[T.True]  0.103701
# 57   TMPRSS2   Submucosal Secretory             sex[T.male]  0.083521
# 58   TMPRSS2   Submucosal Secretory                     age  0.000526
# 59   TMPRSS2   Submucosal Secretory  smoking_status[T.True] -0.352479
# 60      CTSL   Submucosal Secretory             sex[T.male] -0.044331
# 61      CTSL   Submucosal Secretory                     age  0.000750
# 62      CTSL   Submucosal Secretory  smoking_status[T.True]  0.097627
# 63      ACE2                    AT1             sex[T.male]  0.395915
# 64      ACE2                    AT1                     age -0.000905
# 65      ACE2                    AT1  smoking_status[T.True]  0.145603
# 66   TMPRSS2                    AT1             sex[T.male]  0.042236
# 67   TMPRSS2                    AT1                     age  0.007513
# 68   TMPRSS2                    AT1  smoking_status[T.True]  0.291607
# 69      CTSL                    AT1             sex[T.male]  0.298379
# 70      CTSL                    AT1                     age  0.005153
# 71      CTSL                    AT1  smoking_status[T.True] -0.464610
# 72   TMPRSS2  Innate lymphoid cells             sex[T.male] -0.176842
# 73   TMPRSS2  Innate lymphoid cells                     age  0.021001
# 74   TMPRSS2  Innate lymphoid cells  smoking_status[T.True] -1.373159
# 75      CTSL  Innate lymphoid cells             sex[T.male]  0.567587
# 76      CTSL  Innate lymphoid cells                     age  0.031854
# 77      CTSL  Innate lymphoid cells  smoking_status[T.True] -0.252922
# 78      ACE2              Secretory             sex[T.male]  0.000909
# 79      ACE2              Secretory                     age -0.009603
# 80      ACE2              Secretory  smoking_status[T.True]  0.033364
# 81   TMPRSS2              Secretory             sex[T.male]  0.367633
# 82   TMPRSS2              Secretory                     age -0.006363
# 83   TMPRSS2              Secretory  smoking_status[T.True]  0.021761
# 84      CTSL              Secretory             sex[T.male] -0.019757
# 85      CTSL              Secretory                     age -0.000357
# 86      CTSL              Secretory  smoking_status[T.True] -0.079542
# 87   TMPRSS2              Capillary             sex[T.male] -0.112542
# 88   TMPRSS2              Capillary                     age  0.015753
# 89   TMPRSS2              Capillary  smoking_status[T.True] -1.334749
# 90      CTSL              Capillary             sex[T.male] -0.025475
# 91      CTSL              Capillary                     age -0.003688
# 92      CTSL              Capillary  smoking_status[T.True]  0.159828
# 93   TMPRSS2             Mast cells             sex[T.male]  1.790266
# 94   TMPRSS2             Mast cells                     age -0.024884
# 95   TMPRSS2             Mast cells  smoking_status[T.True] -1.605777
# 96      CTSL             Mast cells             sex[T.male]  0.611184
# 97      CTSL             Mast cells                     age  0.016498
# 98      CTSL             Mast cells  smoking_status[T.True] -0.727370
# 99   TMPRSS2         B cell lineage             sex[T.male]  0.436229
# 100  TMPRSS2         B cell lineage                     age  0.011488
# 101  TMPRSS2         B cell lineage  smoking_status[T.True] -0.241165
# 102     CTSL         B cell lineage             sex[T.male] -0.266836
# 103     CTSL         B cell lineage                     age  0.016953
# 104     CTSL         B cell lineage  smoking_status[T.True]  0.235798
# 105     ACE2            Fibroblasts             sex[T.male] -0.033079
# 106     ACE2            Fibroblasts                     age -0.022537
# 107     ACE2            Fibroblasts  smoking_status[T.True]  0.696715
# 108  TMPRSS2            Fibroblasts             sex[T.male] -0.042824
# 109  TMPRSS2            Fibroblasts                     age -0.034403
# 110  TMPRSS2            Fibroblasts  smoking_status[T.True]  1.826973
# 111     CTSL            Fibroblasts             sex[T.male]  0.185751
# 112     CTSL            Fibroblasts                     age -0.008602
# 113     CTSL            Fibroblasts  smoking_status[T.True]  0.930932
# 114  TMPRSS2        Dendritic cells             sex[T.male]  0.496216
# 115  TMPRSS2        Dendritic cells                     age -0.007269
# 116  TMPRSS2        Dendritic cells  smoking_status[T.True] -0.286425
# 117     CTSL        Dendritic cells             sex[T.male] -0.431468
# 118     CTSL        Dendritic cells                     age  0.018252
# 119     CTSL        Dendritic cells  smoking_status[T.True] -0.191108
# 120  TMPRSS2                 Venous             sex[T.male] -2.474982
# 121  TMPRSS2                 Venous                     age  0.002493
# 122  TMPRSS2                 Venous  smoking_status[T.True] -3.945545
# 123     CTSL                 Venous             sex[T.male]  0.011934
# 124     CTSL                 Venous                     age  0.007260
# 125     CTSL                 Venous  smoking_status[T.True] -0.566502
# 126     ACE2           Lymphatic EC             sex[T.male]  1.333554
# 127     ACE2           Lymphatic EC                     age  0.069008
# 128     ACE2           Lymphatic EC  smoking_status[T.True] -0.328886
# 129  TMPRSS2           Lymphatic EC             sex[T.male]  0.556664
# 130  TMPRSS2           Lymphatic EC                     age -0.011158
# 131  TMPRSS2           Lymphatic EC  smoking_status[T.True]  0.067875
# 132     CTSL           Lymphatic EC             sex[T.male]  0.067957
# 133     CTSL           Lymphatic EC                     age  0.001236
# 134     CTSL           Lymphatic EC  smoking_status[T.True]  0.096030
# 135     ACE2               Arterial             sex[T.male]  2.322460
# 136     ACE2               Arterial                     age  0.038086
# 137     ACE2               Arterial  smoking_status[T.True] -2.224560
# 138  TMPRSS2               Arterial             sex[T.male]  1.358336
# 139  TMPRSS2               Arterial                     age  0.044836
# 140  TMPRSS2               Arterial  smoking_status[T.True] -2.758609
# 141     CTSL               Arterial             sex[T.male] -0.053416
# 142     CTSL               Arterial                     age  0.026077
# 143     CTSL               Arterial  smoking_status[T.True] -0.353427
# 144     ACE2                   Rare             sex[T.male]  1.000040
# 145     ACE2                   Rare                     age  0.012526
# 146     ACE2                   Rare  smoking_status[T.True] -0.119800
# 147  TMPRSS2                   Rare             sex[T.male] -0.410091
# 148  TMPRSS2                   Rare                     age -0.009791
# 149  TMPRSS2                   Rare  smoking_status[T.True] -0.259321
# 150     CTSL                   Rare             sex[T.male] -0.272999
# 151     CTSL                   Rare                     age  0.007101
# 152     CTSL                   Rare  smoking_status[T.True]  0.358993
# 153     CTSL   Airway smooth muscle             sex[T.male] -0.032551
# 154     CTSL   Airway smooth muscle                     age -0.006848
# 155     CTSL   Airway smooth muscle  smoking_status[T.True]  0.054384
#
#        coef_sd      pval  adj_pvals
# 0    10.242618  0.893619   0.992432
# 1     0.290223  0.987023   0.992432
# 2    10.105062  0.953498   0.992432
# 3     2.593207  0.915719   0.992432
# 4     0.083184  0.992432   0.992432
# 5     3.266171  0.936526   0.992432
# 6     0.101221  0.418891   0.992432
# 7     0.003341  0.020927   0.188344
# 8     0.121871  0.354096   0.992432
# 9     1.576010  0.906229   0.906229
# 10    0.061025  0.770217   0.906229
# 11    2.044729  0.863325   0.906229
# 12    0.579727  0.415182   0.906229
# 13    0.019658  0.448503   0.906229
# 14    0.727428  0.690574   0.906229
# 15    0.363367  0.721442   0.906229
# 16    0.012590  0.461439   0.906229
# 17    0.449681  0.365625   0.906229
# 18    2.038025  0.825042   0.930537
# 19    0.061311  0.890169   0.930537
# 20    2.966280  0.802055   0.930537
# 21    0.235920  0.492227   0.930537
# 22    0.007218  0.269621   0.930537
# 23    0.295147  0.407781   0.930537
# 24    0.434989  0.908997   0.930537
# 25    0.013469  0.697849   0.930537
# 26    0.613594  0.930537   0.930537
# 27    7.852721  0.912163   0.975524
# 28    0.296522  0.975524   0.975524
# 29   13.956447  0.917712   0.975524
# 30    1.081671  0.554553   0.975524
# 31    0.040406  0.941289   0.975524
# 32    1.103168  0.623026   0.975524
# 33    0.766593  0.420639   0.975524
# 34    0.021715  0.137163   0.975524
# 35    0.841163  0.709396   0.975524
# 36    9.129274  0.957140   0.976808
# 37    0.384727  0.930948   0.976808
# 38   11.697113  0.976808   0.976808
# 39    1.429758  0.553375   0.976808
# 40    0.049481  0.873795   0.976808
# 41    1.833843  0.835770   0.976808
# 42    0.186511  0.177419   0.976808
# 43    0.006920  0.330233   0.976808
# 44    0.215380  0.285411   0.976808
# 45    1.273875  0.949327   0.982883
# 46    0.044593  0.982883   0.982883
# 47    1.334803  0.870501   0.982883
# 48    0.260140  0.802893   0.982883
# 49    0.008605  0.548660   0.982883
# 50    0.302551  0.745991   0.982883
# 51    0.244200  0.908012   0.982883
# 52    0.008372  0.572265   0.982883
# 53    0.276085  0.841022   0.982883
# 54    2.375454  0.982125   0.982125
# 55    0.066295  0.948935   0.982125
# 56    2.663909  0.968948   0.982125
# 57    0.595118  0.888388   0.982125
# 58    0.017350  0.975820   0.982125
# 59    0.762170  0.643745   0.982125
# 60    0.425981  0.917115   0.982125
# 61    0.013221  0.954776   0.982125
# 62    0.444370  0.826107   0.982125
# 63    3.832658  0.917725   0.994027
# 64    0.120883  0.994027   0.994027
# 65    4.437482  0.973824   0.994027
# 66    0.323709  0.896191   0.994027
# 67    0.010655  0.480717   0.994027
# 68    0.374077  0.435663   0.994027
# 69    0.453464  0.510539   0.994027
# 70    0.014021  0.713260   0.994027
# 71    0.598978  0.437943   0.994027
# 72    6.173074  0.977146   0.977146
# 73    0.166848  0.899833   0.977146
# 74    9.171872  0.880990   0.977146
# 75    1.216368  0.640769   0.977146
# 76    0.033739  0.345094   0.977146
# 77    1.264842  0.841509   0.977146
# 78    0.837470  0.999134   0.999134
# 79    0.032958  0.770775   0.999134
# 80    0.998278  0.973338   0.999134
# 81    0.242725  0.129872   0.999134
# 82    0.007970  0.424637   0.999134
# 83    0.273755  0.936642   0.999134
# 84    0.368564  0.957249   0.999134
# 85    0.012244  0.976749   0.999134
# 86    0.429863  0.853197   0.999134
# 87    5.674475  0.984177   0.984177
# 88    0.140076  0.910460   0.984177
# 89   11.012988  0.903534   0.984177
# 90    0.928559  0.978113   0.984177
# 91    0.027324  0.892623   0.984177
# 92    1.269812  0.899837   0.984177
# 93   12.404740  0.885247   0.968676
# 94    0.201513  0.901724   0.968676
# 95   40.891427  0.968676   0.968676
# 96    0.562960  0.277628   0.832885
# 97    0.014890  0.267881   0.832885
# 98    1.140282  0.523548   0.968676
# 99    3.006522  0.884636   0.965920
# 100   0.102100  0.910417   0.965920
# 101   5.644404  0.965920   0.965920
# 102   0.705481  0.705258   0.965920
# 103   0.023998  0.479929   0.965920
# 104   0.941270  0.802193   0.965920
# 105   6.339079  0.995836   0.995836
# 106   0.170425  0.894793   0.995836
# 107   9.930276  0.944066   0.995836
# 108   7.432230  0.995403   0.995836
# 109   0.225577  0.878785   0.995836
# 110  10.389847  0.860418   0.995836
# 111   0.339325  0.584094   0.995836
# 112   0.010802  0.425846   0.995836
# 113   0.363344  0.010403   0.093631
# 114   2.829509  0.860788   0.942057
# 115   0.100006  0.942057   0.942057
# 116   2.990133  0.923687   0.942057
# 117   0.302568  0.153863   0.461589
# 118   0.009116  0.045266   0.271598
# 119   0.426510  0.654100   0.942057
# 120  15.060550  0.869467   0.988422
# 121   0.171810  0.988422   0.988422
# 122  28.892317  0.891378   0.988422
# 123   0.602418  0.984194   0.988422
# 124   0.021425  0.734730   0.988422
# 125   0.708758  0.424123   0.988422
# 126   5.301818  0.801406   0.952411
# 127   0.198223  0.727742   0.952411
# 128   5.510912  0.952411   0.952411
# 129   0.893311  0.533188   0.952411
# 130   0.031078  0.719566   0.952411
# 131   0.949735  0.943026   0.952411
# 132   0.309926  0.826441   0.952411
# 133   0.009485  0.896310   0.952411
# 134   0.368245  0.794264   0.952411
# 135   2.111697  0.271416   0.667926
# 136   0.035095  0.277814   0.667926
# 137   2.931756  0.447984   0.667926
# 138   2.029465  0.503299   0.667926
# 139   0.046999  0.340089   0.667926
# 140   4.930385  0.575812   0.667926
# 141   0.649581  0.934463   0.934463
# 142   0.021316  0.221192   0.667926
# 143   0.662512  0.593712   0.667926
# 144   4.183387  0.811066   0.992867
# 145   0.178134  0.943941   0.992867
# 146  13.399799  0.992867   0.992867
# 147   0.567039  0.469548   0.992867
# 148   0.018750  0.601531   0.992867
# 149   0.762625  0.733828   0.992867
# 150   0.332547  0.411683   0.992867
# 151   0.012283  0.563188   0.992867
# 152   0.385180  0.351329   0.992867
# 153   0.869376  0.970132   0.970132
# 154   0.055452  0.901717   0.970132
# 155   1.014539  0.957250   0.970132

# %%
full_res_lvl3_glm.loc[full_res_lvl3_glm['gene'] == 'ACE2',]
# Out:
#      gene          cell_identity               covariate      coef    coef_sd  \
# 0    ACE2            Macrophages             sex[T.male] -1.369711  10.242618
# 1    ACE2            Macrophages                     age -0.004721   0.290223
# 2    ACE2            Macrophages  smoking_status[T.True]  0.589270  10.105062
# 9    ACE2                  Basal             sex[T.male]  0.185648   1.576010
# 10   ACE2                  Basal                     age -0.017825   0.061025
# 11   ACE2                  Basal  smoking_status[T.True]  0.351985   2.044729
# 18   ACE2                    AT2             sex[T.male]  0.450535   2.038025
# 19   ACE2                    AT2                     age  0.008466   0.061311
# 20   ACE2                    AT2  smoking_status[T.True] -0.743612   2.966280
# 27   ACE2         T cell lineage             sex[T.male]  0.866244   7.852721
# 28   ACE2         T cell lineage                     age -0.009097   0.296522
# 29   ACE2         T cell lineage  smoking_status[T.True] -1.441925  13.956447
# 36   ACE2              Monocytes             sex[T.male]  0.490639   9.129274
# 37   ACE2              Monocytes                     age -0.033338   0.384727
# 38   ACE2              Monocytes  smoking_status[T.True] -0.340043  11.697113
# 45   ACE2  Multiciliated lineage             sex[T.male]  0.080958   1.273875
# 46   ACE2  Multiciliated lineage                     age  0.000957   0.044593
# 47   ACE2  Multiciliated lineage  smoking_status[T.True]  0.217602   1.334803
# 54   ACE2   Submucosal Secretory             sex[T.male] -0.053223   2.375454
# 55   ACE2   Submucosal Secretory                     age  0.004246   0.066295
# 56   ACE2   Submucosal Secretory  smoking_status[T.True]  0.103701   2.663909
# 63   ACE2                    AT1             sex[T.male]  0.395915   3.832658
# 64   ACE2                    AT1                     age -0.000905   0.120883
# 65   ACE2                    AT1  smoking_status[T.True]  0.145603   4.437482
# 78   ACE2              Secretory             sex[T.male]  0.000909   0.837470
# 79   ACE2              Secretory                     age -0.009603   0.032958
# 80   ACE2              Secretory  smoking_status[T.True]  0.033364   0.998278
# 105  ACE2            Fibroblasts             sex[T.male] -0.033079   6.339079
# 106  ACE2            Fibroblasts                     age -0.022537   0.170425
# 107  ACE2            Fibroblasts  smoking_status[T.True]  0.696715   9.930276
# 126  ACE2           Lymphatic EC             sex[T.male]  1.333554   5.301818
# 127  ACE2           Lymphatic EC                     age  0.069008   0.198223
# 128  ACE2           Lymphatic EC  smoking_status[T.True] -0.328886   5.510912
# 135  ACE2               Arterial             sex[T.male]  2.322460   2.111697
# 136  ACE2               Arterial                     age  0.038086   0.035095
# 137  ACE2               Arterial  smoking_status[T.True] -2.224560   2.931756
# 144  ACE2                   Rare             sex[T.male]  1.000040   4.183387
# 145  ACE2                   Rare                     age  0.012526   0.178134
# 146  ACE2                   Rare  smoking_status[T.True] -0.119800  13.399799
#
#          pval  adj_pvals
# 0    0.893619   0.992432
# 1    0.987023   0.992432
# 2    0.953498   0.992432
# 9    0.906229   0.906229
# 10   0.770217   0.906229
# 11   0.863325   0.906229
# 18   0.825042   0.930537
# 19   0.890169   0.930537
# 20   0.802055   0.930537
# 27   0.912163   0.975524
# 28   0.975524   0.975524
# 29   0.917712   0.975524
# 36   0.957140   0.976808
# 37   0.930948   0.976808
# 38   0.976808   0.976808
# 45   0.949327   0.982883
# 46   0.982883   0.982883
# 47   0.870501   0.982883
# 54   0.982125   0.982125
# 55   0.948935   0.982125
# 56   0.968948   0.982125
# 63   0.917725   0.994027
# 64   0.994027   0.994027
# 65   0.973824   0.994027
# 78   0.999134   0.999134
# 79   0.770775   0.999134
# 80   0.973338   0.999134
# 105  0.995836   0.995836
# 106  0.894793   0.995836
# 107  0.944066   0.995836
# 126  0.801406   0.952411
# 127  0.727742   0.952411
# 128  0.952411   0.952411
# 135  0.271416   0.667926
# 136  0.277814   0.667926
# 137  0.447984   0.667926
# 144  0.811066   0.992867
# 145  0.943941   0.992867
# 146  0.992867   0.992867

# %%
full_res_lvl3_glm.loc[full_res_lvl3_glm['gene'] == 'TMPRSS2',]
# Out:
#         gene          cell_identity               covariate      coef  \
# 3    TMPRSS2            Macrophages             sex[T.male] -0.274432
# 4    TMPRSS2            Macrophages                     age  0.000789
# 5    TMPRSS2            Macrophages  smoking_status[T.True]  0.260110
# 12   TMPRSS2                  Basal             sex[T.male]  0.472367
# 13   TMPRSS2                  Basal                     age  0.014899
# 14   TMPRSS2                  Basal  smoking_status[T.True] -0.289572
# 21   TMPRSS2                    AT2             sex[T.male]  0.162023
# 22   TMPRSS2                    AT2                     age  0.007968
# 23   TMPRSS2                    AT2  smoking_status[T.True]  0.244325
# 30   TMPRSS2         T cell lineage             sex[T.male]  0.639215
# 31   TMPRSS2         T cell lineage                     age -0.002976
# 32   TMPRSS2         T cell lineage  smoking_status[T.True]  0.542281
# 39   TMPRSS2              Monocytes             sex[T.male]  0.847432
# 40   TMPRSS2              Monocytes                     age  0.007860
# 41   TMPRSS2              Monocytes  smoking_status[T.True] -0.380168
# 48   TMPRSS2  Multiciliated lineage             sex[T.male]  0.064932
# 49   TMPRSS2  Multiciliated lineage                     age -0.005161
# 50   TMPRSS2  Multiciliated lineage  smoking_status[T.True] -0.098005
# 57   TMPRSS2   Submucosal Secretory             sex[T.male]  0.083521
# 58   TMPRSS2   Submucosal Secretory                     age  0.000526
# 59   TMPRSS2   Submucosal Secretory  smoking_status[T.True] -0.352479
# 66   TMPRSS2                    AT1             sex[T.male]  0.042236
# 67   TMPRSS2                    AT1                     age  0.007513
# 68   TMPRSS2                    AT1  smoking_status[T.True]  0.291607
# 72   TMPRSS2  Innate lymphoid cells             sex[T.male] -0.176842
# 73   TMPRSS2  Innate lymphoid cells                     age  0.021001
# 74   TMPRSS2  Innate lymphoid cells  smoking_status[T.True] -1.373159
# 81   TMPRSS2              Secretory             sex[T.male]  0.367633
# 82   TMPRSS2              Secretory                     age -0.006363
# 83   TMPRSS2              Secretory  smoking_status[T.True]  0.021761
# 87   TMPRSS2              Capillary             sex[T.male] -0.112542
# 88   TMPRSS2              Capillary                     age  0.015753
# 89   TMPRSS2              Capillary  smoking_status[T.True] -1.334749
# 93   TMPRSS2             Mast cells             sex[T.male]  1.790266
# 94   TMPRSS2             Mast cells                     age -0.024884
# 95   TMPRSS2             Mast cells  smoking_status[T.True] -1.605777
# 99   TMPRSS2         B cell lineage             sex[T.male]  0.436229
# 100  TMPRSS2         B cell lineage                     age  0.011488
# 101  TMPRSS2         B cell lineage  smoking_status[T.True] -0.241165
# 108  TMPRSS2            Fibroblasts             sex[T.male] -0.042824
# 109  TMPRSS2            Fibroblasts                     age -0.034403
# 110  TMPRSS2            Fibroblasts  smoking_status[T.True]  1.826973
# 114  TMPRSS2        Dendritic cells             sex[T.male]  0.496216
# 115  TMPRSS2        Dendritic cells                     age -0.007269
# 116  TMPRSS2        Dendritic cells  smoking_status[T.True] -0.286425
# 120  TMPRSS2                 Venous             sex[T.male] -2.474982
# 121  TMPRSS2                 Venous                     age  0.002493
# 122  TMPRSS2                 Venous  smoking_status[T.True] -3.945545
# 129  TMPRSS2           Lymphatic EC             sex[T.male]  0.556664
# 130  TMPRSS2           Lymphatic EC                     age -0.011158
# 131  TMPRSS2           Lymphatic EC  smoking_status[T.True]  0.067875
# 138  TMPRSS2               Arterial             sex[T.male]  1.358336
# 139  TMPRSS2               Arterial                     age  0.044836
# 140  TMPRSS2               Arterial  smoking_status[T.True] -2.758609
# 147  TMPRSS2                   Rare             sex[T.male] -0.410091
# 148  TMPRSS2                   Rare                     age -0.009791
# 149  TMPRSS2                   Rare  smoking_status[T.True] -0.259321
#
#        coef_sd      pval  adj_pvals
# 3     2.593207  0.915719   0.992432
# 4     0.083184  0.992432   0.992432
# 5     3.266171  0.936526   0.992432
# 12    0.579727  0.415182   0.906229
# 13    0.019658  0.448503   0.906229
# 14    0.727428  0.690574   0.906229
# 21    0.235920  0.492227   0.930537
# 22    0.007218  0.269621   0.930537
# 23    0.295147  0.407781   0.930537
# 30    1.081671  0.554553   0.975524
# 31    0.040406  0.941289   0.975524
# 32    1.103168  0.623026   0.975524
# 39    1.429758  0.553375   0.976808
# 40    0.049481  0.873795   0.976808
# 41    1.833843  0.835770   0.976808
# 48    0.260140  0.802893   0.982883
# 49    0.008605  0.548660   0.982883
# 50    0.302551  0.745991   0.982883
# 57    0.595118  0.888388   0.982125
# 58    0.017350  0.975820   0.982125
# 59    0.762170  0.643745   0.982125
# 66    0.323709  0.896191   0.994027
# 67    0.010655  0.480717   0.994027
# 68    0.374077  0.435663   0.994027
# 72    6.173074  0.977146   0.977146
# 73    0.166848  0.899833   0.977146
# 74    9.171872  0.880990   0.977146
# 81    0.242725  0.129872   0.999134
# 82    0.007970  0.424637   0.999134
# 83    0.273755  0.936642   0.999134
# 87    5.674475  0.984177   0.984177
# 88    0.140076  0.910460   0.984177
# 89   11.012988  0.903534   0.984177
# 93   12.404740  0.885247   0.968676
# 94    0.201513  0.901724   0.968676
# 95   40.891427  0.968676   0.968676
# 99    3.006522  0.884636   0.965920
# 100   0.102100  0.910417   0.965920
# 101   5.644404  0.965920   0.965920
# 108   7.432230  0.995403   0.995836
# 109   0.225577  0.878785   0.995836
# 110  10.389847  0.860418   0.995836
# 114   2.829509  0.860788   0.942057
# 115   0.100006  0.942057   0.942057
# 116   2.990133  0.923687   0.942057
# 120  15.060550  0.869467   0.988422
# 121   0.171810  0.988422   0.988422
# 122  28.892317  0.891378   0.988422
# 129   0.893311  0.533188   0.952411
# 130   0.031078  0.719566   0.952411
# 131   0.949735  0.943026   0.952411
# 138   2.029465  0.503299   0.667926
# 139   0.046999  0.340089   0.667926
# 140   4.930385  0.575812   0.667926
# 147   0.567039  0.469548   0.992867
# 148   0.018750  0.601531   0.992867
# 149   0.762625  0.733828   0.992867

# %% [markdown]
# # Store results

# %%
full_res_lvl2_glm.to_csv(folder+'/'+output_folder+de_output_base+'_lvl2_full.csv')

# %%
full_res_lvl3_glm.to_csv(folder+'/'+output_folder+de_output_base+'_lvl3_full.csv')
