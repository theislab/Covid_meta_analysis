# %% [markdown]
# This notebook contains the code for the meta-analysis of healthy lung data for ACE2, TMPRSS2, and CTSL. It contains the pseudo-bulk analysis for the complex model with interaction terms that was run on the patient-level data.

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors
from matplotlib import patches
import seaborn as sns
import batchglm
import diffxpy.api as de
import patsy as pat
from statsmodels.stats.multitest import multipletests
import logging, warnings
import statsmodels.api as sm
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
de.__version__

logging.getLogger("tensorflow").setLevel(logging.ERROR)
logging.getLogger("batchglm").setLevel(logging.INFO)
logging.getLogger("diffxpy").setLevel(logging.INFO)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1
# 'v0.7.3'

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

adata_diffxpy = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study/COVID19_lung_atlas_revision_v3.h5ad'

output_folder = 'diffxpy_out/'

de_output_base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm_smoking_pseudo_nUMIoffset_testInts'

# %% [markdown]
# # Read the data

# %%
adata = sc.read(adata_diffxpy)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1320896 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new'

# %%
adata.obs.age = adata.obs.age.astype(float)

# %%
adata.obs.dtypes
# Out:
# age                         float64
# anatomical_region          category
# donor                      category
# last_author/PI             category
# lung_vs_nasal              category
# notes                      category
# original_celltype_ann      category
# sample                     category
# sex                        category
# smoking                    category
# total_counts                float64
# smoked_boolean             category
# last_author_sample_name    category
# ann_level_1                category
# ann_level_2                category
# ann_level_3                category
# ann_level_4                category
# ann_level_5                category
# ann_highest_res               int64
# ann_new                        bool
# dtype: object

# %%
adata.obs['dataset'] = adata.obs['last_author/PI']

# %%
adata.obs.dataset.value_counts()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    95303
# Spence                      78401
# Barbry/Leroy                76981
# Krasnow/Quake               60993
# Meyer                       57020
# Rawlins                     53409
# Regev                       43527
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Misharin                    28329
# Xavier/Regev                25552
# Spira/Campbell              24455
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Schultze                    22641
# Schiller                    20776
# Nawijn                      18197
# Teichmann                   12971
# Kropski/Banovich_dnar        8359
# Shalek                       7603
# Linnarsson                   4640
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      2207
# Schultze/Falk                1965
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64

# %% [markdown]
# # Filter the data

# %% [markdown]
# Keep only datsets with:
# - more than 1 donor
# - non-fetal
# - lung

# %%
# Remove fetal datasets
dats_to_remove = set(['Rawlins', 'Spence', 'Linnarsson'])

# %%
dat = adata.obs.groupby(['donor']).agg({'sex':'first', 'age':'first', 'dataset':'first'})

# Single donor filter
don_tab = dat['dataset'].value_counts()
dats_to_remove.update(set(don_tab.index[don_tab == 1]))

# %%
dats_to_remove = list(dats_to_remove)
dats_to_remove
# Out:
# ['Spence', 'Linnarsson', 'Misharin', 'Schultze/Falk', 'Rawlins']

# %%
adata = adata[~adata.obs.dataset.isin(dats_to_remove)].copy()

# %%
adata.obs.lung_vs_nasal.value_counts()
# Out:
# lung     1096604
# nasal      57548
# Name: lung_vs_nasal, dtype: int64

# %%
# Filter for only lung data
adata = adata[adata.obs.lung_vs_nasal.isin(['lung']),].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1096604 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset'

# %%
adata.obs['sample'].nunique()
adata.obs['donor'].nunique()
adata.obs['dataset'].nunique()
# Out:
# 309
# 185
# 24

# %% [markdown]
# # Binarize smoking status

# %%
adata.obs.smoking.value_counts()
# Out:
# never              575345
# current            173020
# nan                111184
# former              53487
# non-smoker          42367
# never-smoker        33119
# active              29396
# smoked              28197
# current/former      23573
# heavy               15663
# current/former?      5162
# light                3316
# Former               1385
# Current               610
# Never Smoker          426
# Current Smoker        354
# Name: smoking, dtype: int64

# %%
adata.obs['smoking_status'] = adata.obs.smoked_boolean
#adata.obs['smoking_status'] = [True if stat in ['current', 'smoked', 'active', 'former', 'heavy', 'light'] else False if stat in ['never', 'nonsmoker'] else "nan" for stat in adata.obs.smoking]

# %%
adata.obs.smoking_status.value_counts()
# Out:
# False    651257
# True     334163
# nan      111184
# Name: smoking_status, dtype: int64

# %% [markdown]
# ## Filter out data w/o smoking status

# %%
pd.crosstab(adata.obs.dataset, adata.obs.smoking)
# Out:
# smoking                  Current  Current Smoker  Former  Never Smoker  \
# dataset
# Barbry/Leroy                   0               0       0             0
# Beane                          0               0       0             0
# Beane/Campbell                 0             354       0           426
# Eils/Conrad/Kreuter            0               0       0             0
# Kaminski                       0               0       0             0
# Koenigshoff                    0               0       0             0
# Krasnow/Quake                  0               0       0             0
# Kropski/Banovich_dnar          0               0       0             0
# Kropski/Banovich_vand          0               0       0             0
# Lafyatis/Rojas                 0               0       0             0
# Mazzilli/Campbell/Beane      610               0    1385             0
# Meyer                          0               0       0             0
# Meyer_b                        0               0       0             0
# Misharin/Budinger              0               0       0             0
# Nawijn                         0               0       0             0
# Regev                          0               0       0             0
# Regev/Rajagopal                0               0       0             0
# Schiller                       0               0       0             0
# Schultze                       0               0       0             0
# Seibold                        0               0       0             0
# Teichmann                      0               0       0             0
# Whitsett/Xu_10X                0               0       0             0
# Whitsett/Xu_dropSeq            0               0       0             0
# Xavier/Regev                   0               0       0             0
#
# smoking                  active  current  current/former  current/former?  \
# dataset
# Barbry/Leroy                  0        0               0                0
# Beane                         0      305               0                0
# Beane/Campbell                0        0               0                0
# Eils/Conrad/Kreuter           0    11185               0                0
# Kaminski                      0        0           23573                0
# Koenigshoff                   0        0               0                0
# Krasnow/Quake                 0        0               0                0
# Kropski/Banovich_dnar         0        0               0                0
# Kropski/Banovich_vand         0        0               0                0
# Lafyatis/Rojas                0        0               0                0
# Mazzilli/Campbell/Beane       0        0               0                0
# Meyer                      7272        0               0                0
# Meyer_b                       0   103449               0                0
# Misharin/Budinger         12557        0               0                0
# Nawijn                        0        0               0                0
# Regev                         0        0               0                0
# Regev/Rajagopal               0    58081               0                0
# Schiller                      0        0               0             5162
# Schultze                      0        0               0                0
# Seibold                       0        0               0                0
# Teichmann                  9567        0               0                0
# Whitsett/Xu_10X               0        0               0                0
# Whitsett/Xu_dropSeq           0        0               0                0
# Xavier/Regev                  0        0               0                0
#
# smoking                  former  heavy  light    nan   never  never-smoker  \
# dataset
# Barbry/Leroy              16423      0      0      0       0             0
# Beane                       581      0      0      0       0             0
# Beane/Campbell                0      0      0      0       0             0
# Eils/Conrad/Kreuter           0      0      0      0   28593             0
# Kaminski                      0      0      0   3850   67880             0
# Koenigshoff                   0      0      0      0       0         33119
# Krasnow/Quake              7524      0      0      0   53469             0
# Kropski/Banovich_dnar         0      0      0      0    2647             0
# Kropski/Banovich_vand         0      0      0      0     800             0
# Lafyatis/Rojas             3389      0      0      0   20831             0
# Mazzilli/Campbell/Beane       0      0      0      0       0             0
# Meyer                     13363      0      0      0   36385             0
# Meyer_b                       0      0      0      0   14086             0
# Misharin/Budinger          3845      0      0      0   24864             0
# Nawijn                     4958      0      0      0    6152             0
# Regev                         0      0      0  43527       0             0
# Regev/Rajagopal               0      0      0      0  264917             0
# Schiller                      0      0      0  15614       0             0
# Schultze                      0      0      0  22641       0             0
# Seibold                       0  15663   3316      0   17269             0
# Teichmann                  3404      0      0      0       0             0
# Whitsett/Xu_10X               0      0      0      0   34185             0
# Whitsett/Xu_dropSeq           0      0      0      0    3267             0
# Xavier/Regev                  0      0      0  25552       0             0
#
# smoking                  non-smoker  smoked
# dataset
# Barbry/Leroy                  42367       0
# Beane                             0       0
# Beane/Campbell                    0       0
# Eils/Conrad/Kreuter               0       0
# Kaminski                          0       0
# Koenigshoff                       0       0
# Krasnow/Quake                     0       0
# Kropski/Banovich_dnar             0    5712
# Kropski/Banovich_vand             0   22485
# Lafyatis/Rojas                    0       0
# Mazzilli/Campbell/Beane           0       0
# Meyer                             0       0
# Meyer_b                           0       0
# Misharin/Budinger                 0       0
# Nawijn                            0       0
# Regev                             0       0
# Regev/Rajagopal                   0       0
# Schiller                          0       0
# Schultze                          0       0
# Seibold                           0       0
# Teichmann                         0       0
# Whitsett/Xu_10X                   0       0
# Whitsett/Xu_dropSeq               0       0
# Xavier/Regev                      0       0

# %%
adata = adata[~adata.obs.smoking_status.isin(['nan']),].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 985420 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status'

# %%
adata.obs.dataset.value_counts()
adata.obs['sample'].nunique()
adata.obs['donor'].nunique()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    91453
# Krasnow/Quake               60993
# Barbry/Leroy                58790
# Meyer                       57020
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Teichmann                   12971
# Nawijn                      11110
# Kropski/Banovich_dnar        8359
# Schiller                     5162
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      1995
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64
# 286
# 164

# %% [markdown]
# # Check the data

# %%
np.mean(adata.X.astype(int) != adata.X)
# Out:
# 0.0

# %%
for dat in adata.obs.dataset.unique():
    val = np.mean(adata[adata.obs.dataset.isin([dat]),:].X.astype(int) != adata[adata.obs.dataset.isin([dat]),:].X)
    if val != 0:
        print(f'dataset= {dat}; value= {val}')
        adata[adata.obs.dataset.isin([dat]),:].X[:20,:20].A

# %% [markdown]
# All counts are (or nearly are) integers

# %%
adata.obs.age.value_counts()
adata.obs.sex.value_counts()
# Out:
# 57.00    81833
# 66.00    69371
# 42.00    66596
# 59.00    59955
# 18.00    59849
# 46.00    56291
# 64.00    46130
# 35.00    45869
# 0.25     29908
# 67.50    28201
# 20.00    25362
# 51.00    24766
# 30.00    24095
# 29.00    19248
# 0.00     19065
# 32.00    19009
# 3.00     18387
# 42.50    16906
# 41.00    14943
# 58.00    14086
# 57.50    13840
# 23.00    13657
# 68.00    11852
# 65.00    11404
# 56.00    11024
# 75.00    10941
# 45.00    10939
# 55.00    10878
# 47.00    10278
# 49.00    10198
# 21.00     9430
# 27.00     8693
# 72.50     7983
# 22.00     7980
# 63.00     7600
# 31.00     7085
# 33.00     6906
# 44.00     6681
# 52.50     6326
# 38.00     5629
# 62.00     4679
# 24.00     4433
# 62.50     4073
# 26.00     4066
# 61.00     3922
# 67.00     3916
# 50.00     3831
# 32.50     3772
# 80.00     3261
# 10.00     2694
# 40.00     2647
# 17.00     2552
# 79.00     2550
# 54.00     2507
# 76.00     2447
# 36.00     2218
# 48.00     1153
# 25.00      823
# 70.00      168
# 69.00      130
# 87.00      112
# 43.00       79
# 34.00       76
# 78.00       65
# 74.00       52
# Name: age, dtype: int64
# female    550340
# male      435080
# Name: sex, dtype: int64

# %% [markdown]
# # Fit models and perform DE

# %%
cluster_key = 'ann_level_2'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Myeloid',
#  'Airway epithelium',
#  'Alveolar epithelium',
#  'Lymphoid',
#  'Fibroblast lineage',
#  'Blood vessels',
#  'Submucosal Gland',
#  'Smooth Muscle',
#  'Lymphatics',
#  'Mesothelium']

# %% [markdown]
# Calculate DE genes per cluster.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 985420 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status'

# %% [markdown]
# # Generate pseudobulks

# %%
for gene in adata.var_names:
    adata.obs[gene] = adata[:,gene].X.A

# %%
dat_pseudo = adata.obs.groupby(['donor', 'ann_level_2']).agg({'ACE2':'mean', 'TMPRSS2':'mean', 'CTSL':'mean', 'total_counts':'mean', 'age':'first', 'smoking_status':'first', 'sex':'first', 'dataset':'first'}).dropna().reset_index(level=[0,1])
adata_pseudo = sc.AnnData(dat_pseudo[['ACE2', 'TMPRSS2', 'CTSL']], obs=dat_pseudo.drop(columns=['ACE2', 'TMPRSS2', 'CTSL']))
# Out:
# Transforming to str index.

# %%
adata_pseudo.obs.head()
# Out:
#       donor          ann_level_2  total_counts   age smoking_status     sex  \
# 0  1A1DFBng        1_Endothelial   6307.156863  47.0           True  female
# 1  1A1DFBng    Airway epithelium   4948.705263  47.0           True  female
# 2  1A1DFBng  Alveolar epithelium   4268.209154  47.0           True  female
# 3  1A1DFBng   Fibroblast lineage   5888.260870  47.0           True  female
# 4  1A1DFBng           Lymphatics   5503.117647  47.0           True  female
#
#                dataset
# 0  Eils/Conrad/Kreuter
# 1  Eils/Conrad/Kreuter
# 2  Eils/Conrad/Kreuter
# 3  Eils/Conrad/Kreuter
# 4  Eils/Conrad/Kreuter

# %%
adata_pseudo.obs['total_counts_scaled'] = adata_pseudo.obs['total_counts']/adata_pseudo.obs['total_counts'].mean()

# %%
# Get interquartile range for ages to test
adata_pseudo.obs.groupby(['donor']).agg({'age':'first'}).age.quantile([0.25,0.5,0.75])
# Out:
# 0.25    30.75
# 0.50    49.50
# 0.75    62.50
# Name: age, dtype: float64

# %%
formula = "1 + sex + age + sex:age + smoking_status + sex:smoking_status + age:smoking_status + dataset"
tested_coef = ["sex[T.male]", "age", "smoking_status[T.True]"]
dmat = de.utils.design_matrix(
    data=adata,
    formula="~" + formula,
    as_numeric=["age"],
    return_type="patsy"
)

to_test = dict()
to_test['age'] = [31,62]
to_test['sex[T.male]'] = [0,1]
to_test['smoking_status[T.True]'] = [0,1]

dmat[1]
# Out:
# ['Intercept',
#  'sex[T.male]',
#  'smoking_status[T.True]',
#  'dataset[T.Beane]',
#  'dataset[T.Beane/Campbell]',
#  'dataset[T.Eils/Conrad/Kreuter]',
#  'dataset[T.Kaminski]',
#  'dataset[T.Koenigshoff]',
#  'dataset[T.Krasnow/Quake]',
#  'dataset[T.Kropski/Banovich_dnar]',
#  'dataset[T.Kropski/Banovich_vand]',
#  'dataset[T.Lafyatis/Rojas]',
#  'dataset[T.Mazzilli/Campbell/Beane]',
#  'dataset[T.Meyer]',
#  'dataset[T.Meyer_b]',
#  'dataset[T.Misharin/Budinger]',
#  'dataset[T.Nawijn]',
#  'dataset[T.Regev/Rajagopal]',
#  'dataset[T.Schiller]',
#  'dataset[T.Seibold]',
#  'dataset[T.Teichmann]',
#  'dataset[T.Whitsett/Xu_10X]',
#  'dataset[T.Whitsett/Xu_dropSeq]',
#  'sex[T.male]:smoking_status[T.True]',
#  'age',
#  'sex[T.male]:age',
#  'age:smoking_status[T.True]']

# %% [markdown]
# ### Function definition to test effect sizes at particular covariate values

# %%
def calc_effects(dmat, cov_mat, params, effect, coefs):
    from patsy.design_info import DesignMatrix
    from diffxpy.api.stats import wald_test_chisq
    
    dmat_cond = isinstance(dmat, tuple) and isinstance(dmat[0], DesignMatrix)

    if not dmat_cond:
        raise ValueError("`dmat` should be a patsy output Design Matrix.")

    effect_list = ['sex[T.male]', 'age', 'smoking_status[T.True]']
    if not effect in effect_list:
        raise ValueError(f'{effect} is not one of: '
                         f'{effect_list}')

    if not isinstance(coefs, dict):
        raise TypeError('`coefs` should contain a dictionary of coefficients '
                        'where the effects should be evaluated.')
    
    ## Note: this is only correct when 3 covariates are tested in combinations
    #if np.sum([coef in coefs for coef in effect_list]) < 2:
    #    raise ValueError('The `coefs` dict must contain values for the two '
    #                     'coefficient not tested in:'
    #                     f'{effect_list}')
        
    if 'smoking_status[T.True]' in coefs and coefs['smoking_status[T.True]'] not in [0,1]:
        raise ValueError('Smoking status should be encoded as 0 or 1.')

    if 'sex[T.male]' in coefs and coefs['sex[T.male]'] not in [0,1]:
        raise ValueError('Sex should be encoded as 0 or 1.')

    if 'age' in coefs and not (isinstance(coefs['age'], float) or isinstance(coefs['age'], int)):
        raise ValueError('Age should be a numerical value.')

    coef_list = []

    for term in dmat[1]:
        if effect not in term:
            coef_list.append(0)
        elif term == effect:
            coef_list.append(1)
        else:
            t_list = term.split(':')
            t_list.remove(effect)
            coef_list.append(coefs[t_list[0]])

    C = np.array(coef_list)
    val = np.matmul(C,np.array(params))
    stderr = np.sqrt(np.matmul(np.matmul(C.T,cov_mat),C))
    pval = wald_test_chisq(np.array([val]).reshape(1,1), np.array([stderr**2]).reshape(1,1,1))[0]
    return (val, stderr, pval)

# %% [markdown]
# ## Poisson GLM

# %%
# Poisson GLM loop
de_results_lvl2_glm = dict()

# Test over clusters
for clust in clusters:
    adata_pseudo_tmp = adata_pseudo[adata_pseudo.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_pseudo_tmp.obs['smoking_status'].value_counts())
    print(adata_pseudo_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_pseudo_tmp, min_cells=4)
    if adata_pseudo_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_pseudo_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
        
    print(f'Testing {adata_pseudo_tmp.n_vars} genes...')
    print(f'Testing in {adata_pseudo_tmp.n_obs} donors...')   
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_pseudo_tmp, #[idx_train],
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_pseudo_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_pseudo_tmp.X[:, i], #[idx_train, :], 
            exog=dmat[0],
            offset=np.log(adata_pseudo_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()

        # Get the covariance matrix
        cov_mat = pois_results.cov_params()

        # Test over coefs
        for coef in tested_coef:
            iter_coefs = tested_coef.copy()
            iter_coefs.remove(coef)
            
            for c1 in to_test[iter_coefs[0]]:
                for c2 in to_test[iter_coefs[1]]:
                    coef_vals = {iter_coefs[0]:c1, iter_coefs[1]:c2}
                    val, stderr, pval = calc_effects(
                        dmat = dmat,
                        cov_mat = cov_mat,
                        params = pois_results.params,
                        effect = coef,
                        coefs = coef_vals)
                    
                    case = '_'.join([iter_coefs[0]+':'+str(c1), iter_coefs[1]+':'+str(c2)])
                    case = case.replace('smoking_status[T.True]:0','NS').replace('smoking_status[T.True]:1','S')
                    case = case.replace('sex[T.male]:0','F').replace('sex[T.male]:1','M')
                    case = case.replace('age:31','31yr').replace('age:62','62yr')
                    case = case.replace('_',' ')
                    
                    # Output the results nicely
                    de_results_temp = pd.DataFrame({
                        "gene": gene,
                        "cell_identity": clust,
                        "covariate": coef,
                        "eval_at": case,
                        "coef": val,
                        "coef_sd": stderr,                 
                        "pval": pval
                    }, index= [clust+"_"+gene+"_"+coef])
                    
                    de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl2_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl2_glm = pd.concat([de_results_lvl2_glm[i] for i in de_results_lvl2_glm.keys()], ignore_index=True)
# Out:
# In cluster Myeloid:
# False    66
# True     55
# Name: smoking_status, dtype: int64
# male      64
# female    57
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 121 donors...
#
# In cluster Airway epithelium:
# False    90
# True     71
# Name: smoking_status, dtype: int64
# male      85
# female    76
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 161 donors...
#
# In cluster Alveolar epithelium:
# False    67
# True     39
# Name: smoking_status, dtype: int64
# male      55
# female    51
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 106 donors...
#
# In cluster Lymphoid:
# False    72
# True     62
# Name: smoking_status, dtype: int64
# male      70
# female    64
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 134 donors...
#
# In cluster Fibroblast lineage:
# False    54
# True     40
# Name: smoking_status, dtype: int64
# male      50
# female    44
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 94 donors...
#
# In cluster Blood vessels:
# False    48
# True     31
# Name: smoking_status, dtype: int64
# male      45
# female    34
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 79 donors...
#
# In cluster Submucosal Gland:
# False    28
# True     17
# Name: smoking_status, dtype: int64
# male      25
# female    20
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 45 donors...
#
# In cluster Smooth Muscle:
# False    35
# True     26
# Name: smoking_status, dtype: int64
# female    31
# male      30
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 61 donors...
#
# In cluster Lymphatics:
# False    45
# True     31
# Name: smoking_status, dtype: int64
# male      39
# female    37
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 76 donors...
#
# In cluster Mesothelium:
# True     15
# False    14
# Name: smoking_status, dtype: int64
# male      15
# female    14
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 29 donors...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl2_glm.keys()
# Out:
# dict_keys(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid', 'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland', 'Smooth Muscle', 'Lymphatics', 'Mesothelium'])

# %%
full_res_lvl2_glm
# Out:
#         gene        cell_identity               covariate  eval_at       coef  \
# 0       ACE2              Myeloid             sex[T.male]  31yr NS   0.360704
# 1       ACE2              Myeloid             sex[T.male]   31yr S  -1.516361
# 2       ACE2              Myeloid             sex[T.male]  62yr NS   0.536208
# 3       ACE2              Myeloid             sex[T.male]   62yr S  -1.340856
# 4       ACE2              Myeloid                     age     F NS  -0.023072
# 5       ACE2              Myeloid                     age      F S   0.058640
# 6       ACE2              Myeloid                     age     M NS  -0.017411
# 7       ACE2              Myeloid                     age      M S   0.064302
# 8       ACE2              Myeloid  smoking_status[T.True]   F 31yr  -1.256606
# 9       ACE2              Myeloid  smoking_status[T.True]   F 62yr   1.276476
# 10      ACE2              Myeloid  smoking_status[T.True]   M 31yr  -3.133671
# 11      ACE2              Myeloid  smoking_status[T.True]   M 62yr  -0.600589
# 12   TMPRSS2              Myeloid             sex[T.male]  31yr NS   1.029464
# 13   TMPRSS2              Myeloid             sex[T.male]   31yr S   0.287078
# 14   TMPRSS2              Myeloid             sex[T.male]  62yr NS   1.044418
# 15   TMPRSS2              Myeloid             sex[T.male]   62yr S   0.302032
# 16   TMPRSS2              Myeloid                     age     F NS   0.012739
# 17   TMPRSS2              Myeloid                     age      F S  -0.018189
# 18   TMPRSS2              Myeloid                     age     M NS   0.013221
# 19   TMPRSS2              Myeloid                     age      M S  -0.017707
# 20   TMPRSS2              Myeloid  smoking_status[T.True]   F 31yr   0.564781
# 21   TMPRSS2              Myeloid  smoking_status[T.True]   F 62yr  -0.393970
# 22   TMPRSS2              Myeloid  smoking_status[T.True]   M 31yr  -0.177605
# 23   TMPRSS2              Myeloid  smoking_status[T.True]   M 62yr  -1.136356
# 24      CTSL              Myeloid             sex[T.male]  31yr NS  -0.272894
# 25      CTSL              Myeloid             sex[T.male]   31yr S   0.010574
# 26      CTSL              Myeloid             sex[T.male]  62yr NS   0.159694
# 27      CTSL              Myeloid             sex[T.male]   62yr S   0.443162
# 28      CTSL              Myeloid                     age     F NS   0.001942
# 29      CTSL              Myeloid                     age      F S  -0.024080
# 30      CTSL              Myeloid                     age     M NS   0.015896
# 31      CTSL              Myeloid                     age      M S  -0.010126
# 32      CTSL              Myeloid  smoking_status[T.True]   F 31yr   0.199362
# 33      CTSL              Myeloid  smoking_status[T.True]   F 62yr  -0.607312
# 34      CTSL              Myeloid  smoking_status[T.True]   M 31yr   0.482830
# 35      CTSL              Myeloid  smoking_status[T.True]   M 62yr  -0.323844
# 36      ACE2    Airway epithelium             sex[T.male]  31yr NS  -0.096773
# 37      ACE2    Airway epithelium             sex[T.male]   31yr S   0.372648
# 38      ACE2    Airway epithelium             sex[T.male]  62yr NS  -0.165866
# 39      ACE2    Airway epithelium             sex[T.male]   62yr S   0.303556
# 40      ACE2    Airway epithelium                     age     F NS   0.009145
# 41      ACE2    Airway epithelium                     age      F S  -0.031647
# 42      ACE2    Airway epithelium                     age     M NS   0.006917
# 43      ACE2    Airway epithelium                     age      M S  -0.033876
# 44      ACE2    Airway epithelium  smoking_status[T.True]   F 31yr   0.375826
# 45      ACE2    Airway epithelium  smoking_status[T.True]   F 62yr  -0.888751
# 46      ACE2    Airway epithelium  smoking_status[T.True]   M 31yr   0.845247
# 47      ACE2    Airway epithelium  smoking_status[T.True]   M 62yr  -0.419330
# 48   TMPRSS2    Airway epithelium             sex[T.male]  31yr NS   0.206870
# 49   TMPRSS2    Airway epithelium             sex[T.male]   31yr S   0.396631
# 50   TMPRSS2    Airway epithelium             sex[T.male]  62yr NS   0.194198
# 51   TMPRSS2    Airway epithelium             sex[T.male]   62yr S   0.383959
# 52   TMPRSS2    Airway epithelium                     age     F NS  -0.001460
# 53   TMPRSS2    Airway epithelium                     age      F S  -0.010463
# 54   TMPRSS2    Airway epithelium                     age     M NS  -0.001869
# 55   TMPRSS2    Airway epithelium                     age      M S  -0.010872
# 56   TMPRSS2    Airway epithelium  smoking_status[T.True]   F 31yr   0.005390
# 57   TMPRSS2    Airway epithelium  smoking_status[T.True]   F 62yr  -0.273688
# 58   TMPRSS2    Airway epithelium  smoking_status[T.True]   M 31yr   0.195151
# 59   TMPRSS2    Airway epithelium  smoking_status[T.True]   M 62yr  -0.083928
# 60      CTSL    Airway epithelium             sex[T.male]  31yr NS   0.045755
# 61      CTSL    Airway epithelium             sex[T.male]   31yr S   0.171323
# 62      CTSL    Airway epithelium             sex[T.male]  62yr NS  -0.195424
# 63      CTSL    Airway epithelium             sex[T.male]   62yr S  -0.069856
# 108     ACE2             Lymphoid             sex[T.male]  31yr NS   0.577541
# 109     ACE2             Lymphoid             sex[T.male]   31yr S  -1.567624
# 110     ACE2             Lymphoid             sex[T.male]  62yr NS   0.298559
# 111     ACE2             Lymphoid             sex[T.male]   62yr S  -1.846607
# 112     ACE2             Lymphoid                     age     F NS  -0.044453
# 113     ACE2             Lymphoid                     age      F S  -0.358582
# 114     ACE2             Lymphoid                     age     M NS  -0.053453
# 115     ACE2             Lymphoid                     age      M S  -0.367581
# 116     ACE2             Lymphoid  smoking_status[T.True]   F 31yr   0.531246
# 117     ACE2             Lymphoid  smoking_status[T.True]   F 62yr  -9.206731
# 118     ACE2             Lymphoid  smoking_status[T.True]   M 31yr  -1.613920
# 119     ACE2             Lymphoid  smoking_status[T.True]   M 62yr -11.351897
# 120  TMPRSS2             Lymphoid             sex[T.male]  31yr NS   0.727057
# 121  TMPRSS2             Lymphoid             sex[T.male]   31yr S  -0.083956
# 122  TMPRSS2             Lymphoid             sex[T.male]  62yr NS   0.814608
# 123  TMPRSS2             Lymphoid             sex[T.male]   62yr S   0.003595
# 124  TMPRSS2             Lymphoid                     age     F NS   0.001080
# 125  TMPRSS2             Lymphoid                     age      F S   0.000628
# 126  TMPRSS2             Lymphoid                     age     M NS   0.003904
# 127  TMPRSS2             Lymphoid                     age      M S   0.003452
# 128  TMPRSS2             Lymphoid  smoking_status[T.True]   F 31yr   0.731205
# 129  TMPRSS2             Lymphoid  smoking_status[T.True]   F 62yr   0.717187
# 130  TMPRSS2             Lymphoid  smoking_status[T.True]   M 31yr  -0.079808
# 131  TMPRSS2             Lymphoid  smoking_status[T.True]   M 62yr  -0.093826
# 132     CTSL             Lymphoid             sex[T.male]  31yr NS  -0.320315
# 133     CTSL             Lymphoid             sex[T.male]   31yr S  -0.608397
# 134     CTSL             Lymphoid             sex[T.male]  62yr NS   0.990729
# 135     CTSL             Lymphoid             sex[T.male]   62yr S   0.702647
# 136     CTSL             Lymphoid                     age     F NS   0.003875
# 137     CTSL             Lymphoid                     age      F S  -0.022476
# 138     CTSL             Lymphoid                     age     M NS   0.046167
# 139     CTSL             Lymphoid                     age      M S   0.019816
# 140     CTSL             Lymphoid  smoking_status[T.True]   F 31yr   0.374787
# 141     CTSL             Lymphoid  smoking_status[T.True]   F 62yr  -0.442091
# 142     CTSL             Lymphoid  smoking_status[T.True]   M 31yr   0.086705
# 143     CTSL             Lymphoid  smoking_status[T.True]   M 62yr  -0.730174
# 144     ACE2   Fibroblast lineage             sex[T.male]  31yr NS   0.028952
# 145     ACE2   Fibroblast lineage             sex[T.male]   31yr S   0.513482
# 146     ACE2   Fibroblast lineage             sex[T.male]  62yr NS  -0.680898
# 147     ACE2   Fibroblast lineage             sex[T.male]   62yr S  -0.196367
# 148     ACE2   Fibroblast lineage                     age     F NS  -0.005601
# 149     ACE2   Fibroblast lineage                     age      F S  -0.031127
# 150     ACE2   Fibroblast lineage                     age     M NS  -0.028499
# 151     ACE2   Fibroblast lineage                     age      M S  -0.054025
# 152     ACE2   Fibroblast lineage  smoking_status[T.True]   F 31yr   1.017611
# 153     ACE2   Fibroblast lineage  smoking_status[T.True]   F 62yr   0.226300
# 154     ACE2   Fibroblast lineage  smoking_status[T.True]   M 31yr   1.502141
# 155     ACE2   Fibroblast lineage  smoking_status[T.True]   M 62yr   0.710831
# 156  TMPRSS2   Fibroblast lineage             sex[T.male]  31yr NS   0.347611
# 157  TMPRSS2   Fibroblast lineage             sex[T.male]   31yr S  -1.166447
# 158  TMPRSS2   Fibroblast lineage             sex[T.male]  62yr NS   1.105339
# 159  TMPRSS2   Fibroblast lineage             sex[T.male]   62yr S  -0.408719
# 160  TMPRSS2   Fibroblast lineage                     age     F NS   0.013917
# 161  TMPRSS2   Fibroblast lineage                     age      F S   0.015545
# 162  TMPRSS2   Fibroblast lineage                     age     M NS   0.038360
# 163  TMPRSS2   Fibroblast lineage                     age      M S   0.039988
# 164  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   F 31yr   0.534427
# 165  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   F 62yr   0.584891
# 166  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   M 31yr  -0.979630
# 167  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   M 62yr  -0.929166
# 168     CTSL   Fibroblast lineage             sex[T.male]  31yr NS  -0.642633
# 169     CTSL   Fibroblast lineage             sex[T.male]   31yr S  -0.292534
# 170     CTSL   Fibroblast lineage             sex[T.male]  62yr NS  -0.186209
# 171     CTSL   Fibroblast lineage             sex[T.male]   62yr S   0.163890
# 172     CTSL   Fibroblast lineage                     age     F NS  -0.004794
# 173     CTSL   Fibroblast lineage                     age      F S  -0.018771
# 174     CTSL   Fibroblast lineage                     age     M NS   0.009929
# 175     CTSL   Fibroblast lineage                     age      M S  -0.004047
# 176     CTSL   Fibroblast lineage  smoking_status[T.True]   F 31yr   0.312828
# 177     CTSL   Fibroblast lineage  smoking_status[T.True]   F 62yr  -0.120448
# 178     CTSL   Fibroblast lineage  smoking_status[T.True]   M 31yr   0.662927
# 179     CTSL   Fibroblast lineage  smoking_status[T.True]   M 62yr   0.229651
# 180     ACE2        Blood vessels             sex[T.male]  31yr NS   0.139018
# 181     ACE2        Blood vessels             sex[T.male]   31yr S  18.012623
# 182     ACE2        Blood vessels             sex[T.male]  62yr NS   0.875486
# 183     ACE2        Blood vessels             sex[T.male]   62yr S  18.749091
# 184     ACE2        Blood vessels                     age     F NS  -0.007040
# 185     ACE2        Blood vessels                     age      F S   0.146416
# 186     ACE2        Blood vessels                     age     M NS   0.016717
# 187     ACE2        Blood vessels                     age      M S   0.170173
# 188     ACE2        Blood vessels  smoking_status[T.True]   F 31yr -23.237294
# 189     ACE2        Blood vessels  smoking_status[T.True]   F 62yr -18.480165
# 190     ACE2        Blood vessels  smoking_status[T.True]   M 31yr  -5.363689
# 191     ACE2        Blood vessels  smoking_status[T.True]   M 62yr  -0.606560
# 192  TMPRSS2        Blood vessels             sex[T.male]  31yr NS  -0.201570
# 193  TMPRSS2        Blood vessels             sex[T.male]   31yr S  -0.894115
# 194  TMPRSS2        Blood vessels             sex[T.male]  62yr NS   0.742353
# 195  TMPRSS2        Blood vessels             sex[T.male]   62yr S   0.049809
# 196  TMPRSS2        Blood vessels                     age     F NS   0.018530
# 197  TMPRSS2        Blood vessels                     age      F S  -0.004972
# 198  TMPRSS2        Blood vessels                     age     M NS   0.048979
# 199  TMPRSS2        Blood vessels                     age      M S   0.025477
# 200  TMPRSS2        Blood vessels  smoking_status[T.True]   F 31yr   0.267091
# 201  TMPRSS2        Blood vessels  smoking_status[T.True]   F 62yr  -0.461460
# 202  TMPRSS2        Blood vessels  smoking_status[T.True]   M 31yr  -0.425454
# 203  TMPRSS2        Blood vessels  smoking_status[T.True]   M 62yr  -1.154005
# 204     CTSL        Blood vessels             sex[T.male]  31yr NS   0.208048
# 205     CTSL        Blood vessels             sex[T.male]   31yr S   0.234731
# 206     CTSL        Blood vessels             sex[T.male]  62yr NS   0.215818
# 207     CTSL        Blood vessels             sex[T.male]   62yr S   0.242500
# 208     CTSL        Blood vessels                     age     F NS   0.012786
# 209     CTSL        Blood vessels                     age      F S   0.002563
# 210     CTSL        Blood vessels                     age     M NS   0.013036
# 211     CTSL        Blood vessels                     age      M S   0.002814
# 212     CTSL        Blood vessels  smoking_status[T.True]   F 31yr  -0.049204
# 213     CTSL        Blood vessels  smoking_status[T.True]   F 62yr  -0.366091
# 214     CTSL        Blood vessels  smoking_status[T.True]   M 31yr  -0.022521
# 215     CTSL        Blood vessels  smoking_status[T.True]   M 62yr  -0.339408
# 216     ACE2     Submucosal Gland             sex[T.male]  31yr NS   0.192212
# 217     ACE2     Submucosal Gland             sex[T.male]   31yr S  -0.057785
# 218     ACE2     Submucosal Gland             sex[T.male]  62yr NS  -0.150872
# 219     ACE2     Submucosal Gland             sex[T.male]   62yr S  -0.400869
# 220     ACE2     Submucosal Gland                     age     F NS   0.008731
# 221     ACE2     Submucosal Gland                     age      F S   0.015402
# 222     ACE2     Submucosal Gland                     age     M NS  -0.002337
# 223     ACE2     Submucosal Gland                     age      M S   0.004335
# 224     ACE2     Submucosal Gland  smoking_status[T.True]   F 31yr   0.053361
# 225     ACE2     Submucosal Gland  smoking_status[T.True]   F 62yr   0.260184
# 226     ACE2     Submucosal Gland  smoking_status[T.True]   M 31yr  -0.196636
# 227     ACE2     Submucosal Gland  smoking_status[T.True]   M 62yr   0.010187
# 228  TMPRSS2     Submucosal Gland             sex[T.male]  31yr NS   0.255080
# 229  TMPRSS2     Submucosal Gland             sex[T.male]   31yr S   0.317162
# 230  TMPRSS2     Submucosal Gland             sex[T.male]  62yr NS  -0.125310
# 231  TMPRSS2     Submucosal Gland             sex[T.male]   62yr S  -0.063228
# 232  TMPRSS2     Submucosal Gland                     age     F NS   0.008287
# 233  TMPRSS2     Submucosal Gland                     age      F S  -0.002753
# 234  TMPRSS2     Submucosal Gland                     age     M NS  -0.003983
# 235  TMPRSS2     Submucosal Gland                     age      M S  -0.015024
# 236  TMPRSS2     Submucosal Gland  smoking_status[T.True]   F 31yr  -0.155893
# 237  TMPRSS2     Submucosal Gland  smoking_status[T.True]   F 62yr  -0.498151
# 238  TMPRSS2     Submucosal Gland  smoking_status[T.True]   M 31yr  -0.093812
# 239  TMPRSS2     Submucosal Gland  smoking_status[T.True]   M 62yr  -0.436070
# 240     CTSL     Submucosal Gland             sex[T.male]  31yr NS  -0.185269
# 241     CTSL     Submucosal Gland             sex[T.male]   31yr S  -0.098506
# 242     CTSL     Submucosal Gland             sex[T.male]  62yr NS  -0.027950
# 243     CTSL     Submucosal Gland             sex[T.male]   62yr S   0.058813
# 244     CTSL     Submucosal Gland                     age     F NS  -0.002441
# 245     CTSL     Submucosal Gland                     age      F S   0.000669
# 246     CTSL     Submucosal Gland                     age     M NS   0.002634
# 247     CTSL     Submucosal Gland                     age      M S   0.005744
# 248     CTSL     Submucosal Gland  smoking_status[T.True]   F 31yr  -0.018245
# 249     CTSL     Submucosal Gland  smoking_status[T.True]   F 62yr   0.078164
# 250     CTSL     Submucosal Gland  smoking_status[T.True]   M 31yr   0.068518
# 251     CTSL     Submucosal Gland  smoking_status[T.True]   M 62yr   0.164926
# 252     ACE2        Smooth Muscle             sex[T.male]  31yr NS  -1.600453
# 253     ACE2        Smooth Muscle             sex[T.male]   31yr S   0.626238
# 254     ACE2        Smooth Muscle             sex[T.male]  62yr NS   2.027647
# 255     ACE2        Smooth Muscle             sex[T.male]   62yr S   4.254338
# 256     ACE2        Smooth Muscle                     age     F NS   0.011513
# 257     ACE2        Smooth Muscle                     age      F S  -0.132765
# 258     ACE2        Smooth Muscle                     age     M NS   0.128549
# 259     ACE2        Smooth Muscle                     age      M S  -0.015730
# 260     ACE2        Smooth Muscle  smoking_status[T.True]   F 31yr   4.590820
# 261     ACE2        Smooth Muscle  smoking_status[T.True]   F 62yr   0.118183
# 262     ACE2        Smooth Muscle  smoking_status[T.True]   M 31yr   6.817512
# 263     ACE2        Smooth Muscle  smoking_status[T.True]   M 62yr   2.344874
# 264  TMPRSS2        Smooth Muscle             sex[T.male]  31yr NS   3.705568
# 265  TMPRSS2        Smooth Muscle             sex[T.male]   31yr S   2.934087
# 266  TMPRSS2        Smooth Muscle             sex[T.male]  62yr NS  -0.808933
# 267  TMPRSS2        Smooth Muscle             sex[T.male]   62yr S  -1.580414
# 268  TMPRSS2        Smooth Muscle                     age     F NS   0.134391
# 269  TMPRSS2        Smooth Muscle                     age      F S  -0.064424
# 270  TMPRSS2        Smooth Muscle                     age     M NS  -0.011238
# 271  TMPRSS2        Smooth Muscle                     age      M S  -0.210053
# 272  TMPRSS2        Smooth Muscle  smoking_status[T.True]   F 31yr   5.606111
# 273  TMPRSS2        Smooth Muscle  smoking_status[T.True]   F 62yr  -0.557154
# 274  TMPRSS2        Smooth Muscle  smoking_status[T.True]   M 31yr   4.834630
# 275  TMPRSS2        Smooth Muscle  smoking_status[T.True]   M 62yr  -1.328635
# 276     CTSL        Smooth Muscle             sex[T.male]  31yr NS  -0.358519
# 277     CTSL        Smooth Muscle             sex[T.male]   31yr S  -0.548852
# 278     CTSL        Smooth Muscle             sex[T.male]  62yr NS   0.156797
# 279     CTSL        Smooth Muscle             sex[T.male]   62yr S  -0.033535
# 280     CTSL        Smooth Muscle                     age     F NS  -0.021727
# 281     CTSL        Smooth Muscle                     age      F S  -0.032592
# 282     CTSL        Smooth Muscle                     age     M NS  -0.005104
# 283     CTSL        Smooth Muscle                     age      M S  -0.015969
# 284     CTSL        Smooth Muscle  smoking_status[T.True]   F 31yr   0.347878
# 285     CTSL        Smooth Muscle  smoking_status[T.True]   F 62yr   0.011056
# 286     CTSL        Smooth Muscle  smoking_status[T.True]   M 31yr   0.157545
# 287     CTSL        Smooth Muscle  smoking_status[T.True]   M 62yr  -0.179276
# 288     ACE2           Lymphatics             sex[T.male]  31yr NS   1.346253
# 289     ACE2           Lymphatics             sex[T.male]   31yr S   4.784210
# 290     ACE2           Lymphatics             sex[T.male]  62yr NS   0.885253
# 291     ACE2           Lymphatics             sex[T.male]   62yr S   4.323210
# 292     ACE2           Lymphatics                     age     F NS   0.062464
# 293     ACE2           Lymphatics                     age      F S   0.296466
# 294     ACE2           Lymphatics                     age     M NS   0.047593
# 295     ACE2           Lymphatics                     age      M S   0.281595
# 296     ACE2           Lymphatics  smoking_status[T.True]   F 31yr -10.795707
# 297     ACE2           Lymphatics  smoking_status[T.True]   F 62yr  -3.541657
# 298     ACE2           Lymphatics  smoking_status[T.True]   M 31yr  -7.357749
# 299     ACE2           Lymphatics  smoking_status[T.True]   M 62yr  -0.103700
# 300  TMPRSS2           Lymphatics             sex[T.male]  31yr NS   0.332815
# 301  TMPRSS2           Lymphatics             sex[T.male]   31yr S   0.102583
# 302  TMPRSS2           Lymphatics             sex[T.male]  62yr NS   0.644022
# 303  TMPRSS2           Lymphatics             sex[T.male]   62yr S   0.413791
# 304  TMPRSS2           Lymphatics                     age     F NS  -0.016519
# 305  TMPRSS2           Lymphatics                     age      F S   0.035408
# 306  TMPRSS2           Lymphatics                     age     M NS  -0.006480
# 307  TMPRSS2           Lymphatics                     age      M S   0.045447
# 308  TMPRSS2           Lymphatics  smoking_status[T.True]   F 31yr  -0.836401
# 309  TMPRSS2           Lymphatics  smoking_status[T.True]   F 62yr   0.773334
# 310  TMPRSS2           Lymphatics  smoking_status[T.True]   M 31yr  -1.066632
# 311  TMPRSS2           Lymphatics  smoking_status[T.True]   M 62yr   0.543103
# 312     CTSL           Lymphatics             sex[T.male]  31yr NS  -0.069637
# 313     CTSL           Lymphatics             sex[T.male]   31yr S   0.191048
# 314     CTSL           Lymphatics             sex[T.male]  62yr NS   0.008844
# 315     CTSL           Lymphatics             sex[T.male]   62yr S   0.269530
# 316     CTSL           Lymphatics                     age     F NS   0.002495
# 317     CTSL           Lymphatics                     age      F S  -0.010636
# 318     CTSL           Lymphatics                     age     M NS   0.005027
# 319     CTSL           Lymphatics                     age      M S  -0.008105
# 320     CTSL           Lymphatics  smoking_status[T.True]   F 31yr   0.226999
# 321     CTSL           Lymphatics  smoking_status[T.True]   F 62yr  -0.180081
# 322     CTSL           Lymphatics  smoking_status[T.True]   M 31yr   0.487684
# 323     CTSL           Lymphatics  smoking_status[T.True]   M 62yr   0.080605
# 324  TMPRSS2          Mesothelium             sex[T.male]  31yr NS  -6.190964
# 325  TMPRSS2          Mesothelium             sex[T.male]   31yr S  15.813229
# 326  TMPRSS2          Mesothelium             sex[T.male]  62yr NS   2.338232
# 327  TMPRSS2          Mesothelium             sex[T.male]   62yr S  24.342426
# 328  TMPRSS2          Mesothelium                     age     F NS   0.075083
# 329  TMPRSS2          Mesothelium                     age      F S  -0.119322
# 330  TMPRSS2          Mesothelium                     age     M NS   0.350218
# 331  TMPRSS2          Mesothelium                     age      M S   0.155813
# 332  TMPRSS2          Mesothelium  smoking_status[T.True]   F 31yr -17.554941
# 333  TMPRSS2          Mesothelium  smoking_status[T.True]   F 62yr -23.581481
# 334  TMPRSS2          Mesothelium  smoking_status[T.True]   M 31yr   4.449252
# 335  TMPRSS2          Mesothelium  smoking_status[T.True]   M 62yr  -1.577288
# 336     CTSL          Mesothelium             sex[T.male]  31yr NS   0.799270
# 337     CTSL          Mesothelium             sex[T.male]   31yr S  -0.107288
# 338     CTSL          Mesothelium             sex[T.male]  62yr NS   0.215357
# 339     CTSL          Mesothelium             sex[T.male]   62yr S  -0.691200
# 340     CTSL          Mesothelium                     age     F NS   0.005470
# 341     CTSL          Mesothelium                     age      F S   0.011402
# 342     CTSL          Mesothelium                     age     M NS  -0.013366
# 343     CTSL          Mesothelium                     age      M S  -0.007434
# 344     CTSL          Mesothelium  smoking_status[T.True]   F 31yr  -0.225783
# 345     CTSL          Mesothelium  smoking_status[T.True]   F 62yr  -0.041889
# 346     CTSL          Mesothelium  smoking_status[T.True]   M 31yr  -1.132341
# 347     CTSL          Mesothelium  smoking_status[T.True]   M 62yr  -0.948446
#
#           coef_sd      pval  adj_pvals
# 0       10.722035  0.973163   0.979942
# 1       25.708715  0.952966   0.979942
# 2       11.653562  0.963300   0.979942
# 3       22.520670  0.952523   0.979942
# 4        0.306370  0.939970   0.979942
# 5        0.837871  0.944204   0.979942
# 6        0.468073  0.970328   0.979942
# 7        0.920595  0.944315   0.979942
# 8       21.668032  0.953754   0.979942
# 9       12.905233  0.921209   0.979942
# 10      30.231363  0.917442   0.979942
# 11      23.887993  0.979942   0.979942
# 12       2.779169  0.711069   0.979942
# 13       3.952527  0.942099   0.979942
# 14       2.328614  0.653782   0.979942
# 15       3.873930  0.937856   0.979942
# 16       0.060758  0.833933   0.979942
# 17       0.188118  0.922974   0.979942
# 18       0.114626  0.908175   0.979942
# 19       0.178052  0.920784   0.979942
# 20       3.706406  0.878887   0.979942
# 21       3.570754  0.912146   0.979942
# 22       4.816808  0.970587   0.979942
# 23       3.984554  0.775498   0.979942
# 24       0.177904  0.125045   0.602596
# 25       0.218702  0.961438   0.979942
# 26       0.183790  0.384906   0.979942
# 27       0.224383  0.048266   0.347512
# 28       0.004974  0.696238   0.979942
# 29       0.008681  0.005542   0.099752
# 30       0.005356  0.003000   0.099752
# 31       0.006755  0.133910   0.602596
# 116  ACE2             Lymphoid  smoking_status[T.True]   F 31yr   0.531246
# 117  ACE2             Lymphoid  smoking_status[T.True]   F 62yr  -9.206731
# 118  ACE2             Lymphoid  smoking_status[T.True]   M 31yr  -1.613920
# 119  ACE2             Lymphoid  smoking_status[T.True]   M 62yr -11.351897
# 144  ACE2   Fibroblast lineage             sex[T.male]  31yr NS   0.028952
# 145  ACE2   Fibroblast lineage             sex[T.male]   31yr S   0.513482
# 146  ACE2   Fibroblast lineage             sex[T.male]  62yr NS  -0.680898
# 147  ACE2   Fibroblast lineage             sex[T.male]   62yr S  -0.196367
# 148  ACE2   Fibroblast lineage                     age     F NS  -0.005601
# 149  ACE2   Fibroblast lineage                     age      F S  -0.031127
# 150  ACE2   Fibroblast lineage                     age     M NS  -0.028499
# 151  ACE2   Fibroblast lineage                     age      M S  -0.054025
# 152  ACE2   Fibroblast lineage  smoking_status[T.True]   F 31yr   1.017611
# 153  ACE2   Fibroblast lineage  smoking_status[T.True]   F 62yr   0.226300
# 154  ACE2   Fibroblast lineage  smoking_status[T.True]   M 31yr   1.502141
# 155  ACE2   Fibroblast lineage  smoking_status[T.True]   M 62yr   0.710831
# 180  ACE2        Blood vessels             sex[T.male]  31yr NS   0.139018
# 181  ACE2        Blood vessels             sex[T.male]   31yr S  18.012623
# 182  ACE2        Blood vessels             sex[T.male]  62yr NS   0.875486
# 183  ACE2        Blood vessels             sex[T.male]   62yr S  18.749091
# 184  ACE2        Blood vessels                     age     F NS  -0.007040
# 185  ACE2        Blood vessels                     age      F S   0.146416
# 186  ACE2        Blood vessels                     age     M NS   0.016717
# 187  ACE2        Blood vessels                     age      M S   0.170173
# 188  ACE2        Blood vessels  smoking_status[T.True]   F 31yr -23.237294
# 189  ACE2        Blood vessels  smoking_status[T.True]   F 62yr -18.480165
# 190  ACE2        Blood vessels  smoking_status[T.True]   M 31yr  -5.363689
# 191  ACE2        Blood vessels  smoking_status[T.True]   M 62yr  -0.606560
# 216  ACE2     Submucosal Gland             sex[T.male]  31yr NS   0.192212
# 217  ACE2     Submucosal Gland             sex[T.male]   31yr S  -0.057785
# 218  ACE2     Submucosal Gland             sex[T.male]  62yr NS  -0.150872
# 219  ACE2     Submucosal Gland             sex[T.male]   62yr S  -0.400869
# 220  ACE2     Submucosal Gland                     age     F NS   0.008731
# 221  ACE2     Submucosal Gland                     age      F S   0.015402
# 222  ACE2     Submucosal Gland                     age     M NS  -0.002337
# 223  ACE2     Submucosal Gland                     age      M S   0.004335
# 224  ACE2     Submucosal Gland  smoking_status[T.True]   F 31yr   0.053361
# 225  ACE2     Submucosal Gland  smoking_status[T.True]   F 62yr   0.260184
# 226  ACE2     Submucosal Gland  smoking_status[T.True]   M 31yr  -0.196636
# 227  ACE2     Submucosal Gland  smoking_status[T.True]   M 62yr   0.010187
# 252  ACE2        Smooth Muscle             sex[T.male]  31yr NS  -1.600453
# 253  ACE2        Smooth Muscle             sex[T.male]   31yr S   0.626238
# 16   TMPRSS2              Myeloid                     age     F NS   0.012739
# 17   TMPRSS2              Myeloid                     age      F S  -0.018189
# 18   TMPRSS2              Myeloid                     age     M NS   0.013221
# 19   TMPRSS2              Myeloid                     age      M S  -0.017707
# 20   TMPRSS2              Myeloid  smoking_status[T.True]   F 31yr   0.564781
# 21   TMPRSS2              Myeloid  smoking_status[T.True]   F 62yr  -0.393970
# 22   TMPRSS2              Myeloid  smoking_status[T.True]   M 31yr  -0.177605
# 23   TMPRSS2              Myeloid  smoking_status[T.True]   M 62yr  -1.136356
# 48   TMPRSS2    Airway epithelium             sex[T.male]  31yr NS   0.206870
# 49   TMPRSS2    Airway epithelium             sex[T.male]   31yr S   0.396631
# 50   TMPRSS2    Airway epithelium             sex[T.male]  62yr NS   0.194198
# 51   TMPRSS2    Airway epithelium             sex[T.male]   62yr S   0.383959
# 52   TMPRSS2    Airway epithelium                     age     F NS  -0.001460
# 53   TMPRSS2    Airway epithelium                     age      F S  -0.010463
# 54   TMPRSS2    Airway epithelium                     age     M NS  -0.001869
# 55   TMPRSS2    Airway epithelium                     age      M S  -0.010872
# 56   TMPRSS2    Airway epithelium  smoking_status[T.True]   F 31yr   0.005390
# 57   TMPRSS2    Airway epithelium  smoking_status[T.True]   F 62yr  -0.273688
# 58   TMPRSS2    Airway epithelium  smoking_status[T.True]   M 31yr   0.195151
# 59   TMPRSS2    Airway epithelium  smoking_status[T.True]   M 62yr  -0.083928
# 84   TMPRSS2  Alveolar epithelium             sex[T.male]  31yr NS   0.063673
# 85   TMPRSS2  Alveolar epithelium             sex[T.male]   31yr S   0.312200
# 86   TMPRSS2  Alveolar epithelium             sex[T.male]  62yr NS   0.166581
# 87   TMPRSS2  Alveolar epithelium             sex[T.male]   62yr S   0.415109
# 88   TMPRSS2  Alveolar epithelium                     age     F NS   0.013734
# 89   TMPRSS2  Alveolar epithelium                     age      F S  -0.018826
# 90   TMPRSS2  Alveolar epithelium                     age     M NS   0.017053
# 91   TMPRSS2  Alveolar epithelium                     age      M S  -0.015507
# 92   TMPRSS2  Alveolar epithelium  smoking_status[T.True]   F 31yr   0.765322
# 93   TMPRSS2  Alveolar epithelium  smoking_status[T.True]   F 62yr  -0.244034
# 94   TMPRSS2  Alveolar epithelium  smoking_status[T.True]   M 31yr   1.013849
# 95   TMPRSS2  Alveolar epithelium  smoking_status[T.True]   M 62yr   0.004493
# 120  TMPRSS2             Lymphoid             sex[T.male]  31yr NS   0.727057
# 121  TMPRSS2             Lymphoid             sex[T.male]   31yr S  -0.083956
# 122  TMPRSS2             Lymphoid             sex[T.male]  62yr NS   0.814608
# 123  TMPRSS2             Lymphoid             sex[T.male]   62yr S   0.003595
# 124  TMPRSS2             Lymphoid                     age     F NS   0.001080
# 125  TMPRSS2             Lymphoid                     age      F S   0.000628
# 126  TMPRSS2             Lymphoid                     age     M NS   0.003904
# 127  TMPRSS2             Lymphoid                     age      M S   0.003452
# 128  TMPRSS2             Lymphoid  smoking_status[T.True]   F 31yr   0.731205
# 129  TMPRSS2             Lymphoid  smoking_status[T.True]   F 62yr   0.717187
# 130  TMPRSS2             Lymphoid  smoking_status[T.True]   M 31yr  -0.079808
# 131  TMPRSS2             Lymphoid  smoking_status[T.True]   M 62yr  -0.093826
# 156  TMPRSS2   Fibroblast lineage             sex[T.male]  31yr NS   0.347611
# 157  TMPRSS2   Fibroblast lineage             sex[T.male]   31yr S  -1.166447
# 158  TMPRSS2   Fibroblast lineage             sex[T.male]  62yr NS   1.105339
# 159  TMPRSS2   Fibroblast lineage             sex[T.male]   62yr S  -0.408719
# 160  TMPRSS2   Fibroblast lineage                     age     F NS   0.013917
# 161  TMPRSS2   Fibroblast lineage                     age      F S   0.015545
# 162  TMPRSS2   Fibroblast lineage                     age     M NS   0.038360
# 163  TMPRSS2   Fibroblast lineage                     age      M S   0.039988
# 164  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   F 31yr   0.534427
# 165  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   F 62yr   0.584891
# 166  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   M 31yr  -0.979630
# 167  TMPRSS2   Fibroblast lineage  smoking_status[T.True]   M 62yr  -0.929166
# 192  TMPRSS2        Blood vessels             sex[T.male]  31yr NS  -0.201570
# 193  TMPRSS2        Blood vessels             sex[T.male]   31yr S  -0.894115
# 194  TMPRSS2        Blood vessels             sex[T.male]  62yr NS   0.742353
# 195  TMPRSS2        Blood vessels             sex[T.male]   62yr S   0.049809
# 196  TMPRSS2        Blood vessels                     age     F NS   0.018530
# 197  TMPRSS2        Blood vessels                     age      F S  -0.004972
# 198  TMPRSS2        Blood vessels                     age     M NS   0.048979
# 199  TMPRSS2        Blood vessels                     age      M S   0.025477
# 200  TMPRSS2        Blood vessels  smoking_status[T.True]   F 31yr   0.267091
# 201  TMPRSS2        Blood vessels  smoking_status[T.True]   F 62yr  -0.461460
# 202  TMPRSS2        Blood vessels  smoking_status[T.True]   M 31yr  -0.425454
# 203  TMPRSS2        Blood vessels  smoking_status[T.True]   M 62yr  -1.154005
# 228  TMPRSS2     Submucosal Gland             sex[T.male]  31yr NS   0.255080
# 229  TMPRSS2     Submucosal Gland             sex[T.male]   31yr S   0.317162
# 230  TMPRSS2     Submucosal Gland             sex[T.male]  62yr NS  -0.125310
# 231  TMPRSS2     Submucosal Gland             sex[T.male]   62yr S  -0.063228
# 232  TMPRSS2     Submucosal Gland                     age     F NS   0.008287
# 233  TMPRSS2     Submucosal Gland                     age      F S  -0.002753
# 234  TMPRSS2     Submucosal Gland                     age     M NS  -0.003983
# 235  TMPRSS2     Submucosal Gland                     age      M S  -0.015024
# 236  TMPRSS2     Submucosal Gland  smoking_status[T.True]   F 31yr  -0.155893
# 237  TMPRSS2     Submucosal Gland  smoking_status[T.True]   F 62yr  -0.498151
# 238  TMPRSS2     Submucosal Gland  smoking_status[T.True]   M 31yr  -0.093812
# 239  TMPRSS2     Submucosal Gland  smoking_status[T.True]   M 62yr  -0.436070
# 264  TMPRSS2        Smooth Muscle             sex[T.male]  31yr NS   3.705568
# 265  TMPRSS2        Smooth Muscle             sex[T.male]   31yr S   2.934087
# 266  TMPRSS2        Smooth Muscle             sex[T.male]  62yr NS  -0.808933
# 267  TMPRSS2        Smooth Muscle             sex[T.male]   62yr S  -1.580414
# 268  TMPRSS2        Smooth Muscle                     age     F NS   0.134391
# 269  TMPRSS2        Smooth Muscle                     age      F S  -0.064424
# 270  TMPRSS2        Smooth Muscle                     age     M NS  -0.011238
# 271  TMPRSS2        Smooth Muscle                     age      M S  -0.210053
# 272  TMPRSS2        Smooth Muscle  smoking_status[T.True]   F 31yr   5.606111
# 273  TMPRSS2        Smooth Muscle  smoking_status[T.True]   F 62yr  -0.557154
# 274  TMPRSS2        Smooth Muscle  smoking_status[T.True]   M 31yr   4.834630
# 275  TMPRSS2        Smooth Muscle  smoking_status[T.True]   M 62yr  -1.328635
# 300  TMPRSS2           Lymphatics             sex[T.male]  31yr NS   0.332815
# 301  TMPRSS2           Lymphatics             sex[T.male]   31yr S   0.102583
# 302  TMPRSS2           Lymphatics             sex[T.male]  62yr NS   0.644022
# 303  TMPRSS2           Lymphatics             sex[T.male]   62yr S   0.413791
# 304  TMPRSS2           Lymphatics                     age     F NS  -0.016519
# 305  TMPRSS2           Lymphatics                     age      F S   0.035408
# 306  TMPRSS2           Lymphatics                     age     M NS  -0.006480
# 307  TMPRSS2           Lymphatics                     age      M S   0.045447
# 308  TMPRSS2           Lymphatics  smoking_status[T.True]   F 31yr  -0.836401
# 309  TMPRSS2           Lymphatics  smoking_status[T.True]   F 62yr   0.773334
# 310  TMPRSS2           Lymphatics  smoking_status[T.True]   M 31yr  -1.066632
# 311  TMPRSS2           Lymphatics  smoking_status[T.True]   M 62yr   0.543103
# 324  TMPRSS2          Mesothelium             sex[T.male]  31yr NS  -6.190964
# 325  TMPRSS2          Mesothelium             sex[T.male]   31yr S  15.813229
# 326  TMPRSS2          Mesothelium             sex[T.male]  62yr NS   2.338232
# 327  TMPRSS2          Mesothelium             sex[T.male]   62yr S  24.342426
# 328  TMPRSS2          Mesothelium                     age     F NS   0.075083
# 329  TMPRSS2          Mesothelium                     age      F S  -0.119322
# 330  TMPRSS2          Mesothelium                     age     M NS   0.350218
# 331  TMPRSS2          Mesothelium                     age      M S   0.155813
# 332  TMPRSS2          Mesothelium  smoking_status[T.True]   F 31yr -17.554941
# 333  TMPRSS2          Mesothelium  smoking_status[T.True]   F 62yr -23.581481
# 334  TMPRSS2          Mesothelium  smoking_status[T.True]   M 31yr   4.449252
# 335  TMPRSS2          Mesothelium  smoking_status[T.True]   M 62yr  -1.577288
#
#           coef_sd      pval  adj_pvals
# 12       2.779169  0.711069   0.979942
# 13       3.952527  0.942099   0.979942
# 14       2.328614  0.653782   0.979942
# 15       3.873930  0.937856   0.979942
# 16       0.060758  0.833933   0.979942
# 17       0.188118  0.922974   0.979942
# 18       0.114626  0.908175   0.979942
# 19       0.178052  0.920784   0.979942
# 20       3.706406  0.878887   0.979942
# 21       3.570754  0.912146   0.979942
# 22       4.816808  0.970587   0.979942
# 23       3.984554  0.775498   0.979942
# 48       0.419813  0.622177   0.988021
# 49       0.575052  0.490364   0.988021
# 50       0.524820  0.711362   0.988021
# 51       0.494759  0.437718   0.988021
# 52       0.012836  0.909411   0.988021
# 301      3.086809  0.973489   0.992065
# 302      1.885531  0.732682   0.992065
# 303      2.595731  0.873344   0.992065
# 304      0.037546  0.659969   0.992065
# 305      0.201139  0.860264   0.992065
# 306      0.083311  0.938004   0.992065
# 307      0.199675  0.819953   0.992065
# 308      3.508072  0.811554   0.992065
# 309      3.236358  0.811143   0.992065
# 310      5.114253  0.834791   0.992065
# 311      3.030602  0.857776   0.992065
# 324  16806.112120  0.999706   0.999982
# 325  46913.805238  0.999731   0.999982
# 326  17926.520190  0.999896   0.999982
# 327  55028.557732  0.999647   0.999982
# 328      0.145038  0.604686   0.999982
# 329   1120.407735  0.999915   0.999982
# 330   1120.407408  0.999751   0.999982
# 331      0.874643  0.858609   0.999982
# 332  79445.377472  0.999824   0.999982
# 333  81643.007702  0.999770   0.999982
# 334  74276.054539  0.999952   0.999982
# 335  71292.510035  0.999982   0.999982

# %% [markdown]
# # Level 3 annotation

# %%
cluster_key = 'ann_level_3'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') or ct.startswith('2') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Macrophages',
#  'Basal',
#  'AT2',
#  'T cell lineage',
#  'Monocytes',
#  'Multiciliated lineage',
#  'Submucosal Secretory',
#  'AT1',
#  'Innate lymphoid cells',
#  'Secretory',
#  'Capillary',
#  'Mast cells',
#  'B cell lineage',
#  'Fibroblasts',
#  'Dendritic cells',
#  'Venous',
#  'Lymphatic EC',
#  'Arterial',
#  'Rare',
#  'Airway smooth muscle']

# %%
adata_sub = adata[adata.obs.ann_level_3.isin(clusters),:]

adata_sub
adata_sub.obs.donor.nunique()
adata_sub.obs['sample'].nunique()
# Out:
# View of AnnData object with n_obs × n_vars = 795195 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status', 'ACE2', 'TMPRSS2', 'CTSL'
# 164
# 286

# %% [markdown]
# ## Generate pseudobulk

# %%
for gene in adata_sub.var_names:
    adata_sub.obs[gene] = adata_sub[:,gene].X.A
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
dat_pseudo_sub = adata_sub.obs.groupby(['donor', 'ann_level_3']).agg({'ACE2':'mean', 'TMPRSS2':'mean', 'CTSL':'mean', 'total_counts':'mean', 'age':'first', 'smoking_status':'first', 'sex':'first', 'dataset':'first'}).dropna().reset_index(level=[0,1])
adata_pseudo_sub = sc.AnnData(dat_pseudo_sub[['ACE2', 'TMPRSS2', 'CTSL']], obs=dat_pseudo_sub.drop(columns=['ACE2', 'TMPRSS2', 'CTSL']))
# Out:
# Transforming to str index.

# %%
adata_pseudo_sub.obs.head()
# Out:
#       donor            ann_level_3  total_counts   age smoking_status     sex  \
# 0  1A1DFBng                    AT1   3709.913265  47.0           True  female
# 1  1A1DFBng                    AT2   4453.519898  47.0           True  female
# 2  1A1DFBng           Lymphatic EC   5503.117647  47.0           True  female
# 3  1A1DFBng              Monocytes   3339.083948  47.0           True  female
# 4  1A1DFBng  Multiciliated lineage   6000.121212  47.0           True  female
#
#                dataset
# 0  Eils/Conrad/Kreuter
# 1  Eils/Conrad/Kreuter
# 2  Eils/Conrad/Kreuter
# 3  Eils/Conrad/Kreuter
# 4  Eils/Conrad/Kreuter

# %%
adata_pseudo_sub.obs['total_counts_scaled'] = adata_pseudo_sub.obs['total_counts']/adata_pseudo_sub.obs['total_counts'].mean()

# %% [markdown]
# ## Poisson GLM

# %% [markdown]
# First check if there are any datasets with only 1 sex or 1 smoking status, which would make the model overparameterized (not full rank).

# %%
np.any(adata_pseudo_tmp.obs.smoking_status.value_counts() == 1)
# Out:
# False

# %%
np.any(pd.crosstab(adata_pseudo_tmp.obs.smoking_status, adata_pseudo_tmp.obs.sex) == 1)
# Out:
# False

# %%
clusters
# Out:
# ['Macrophages',
#  'Basal',
#  'AT2',
#  'T cell lineage',
#  'Monocytes',
#  'Multiciliated lineage',
#  'Submucosal Secretory',
#  'AT1',
#  'Innate lymphoid cells',
#  'Secretory',
#  'Capillary',
#  'Mast cells',
#  'B cell lineage',
#  'Fibroblasts',
#  'Dendritic cells',
#  'Venous',
#  'Lymphatic EC',
#  'Arterial',
#  'Rare',
#  'Airway smooth muscle']

# %%
# Poisson GLM loop
de_results_lvl3_glm = dict()

# Test over clusters
for clust in clusters:
    adata_pseudo_tmp = adata_pseudo_sub[adata_pseudo_sub.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_pseudo_tmp.obs['smoking_status'].value_counts())
    print(adata_pseudo_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_pseudo_tmp, min_cells=4)
    if adata_pseudo_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_pseudo_tmp.obs.smoking_status.value_counts())==1:
        print(f'{clust} only has 1 type of smoker/nonsmoker sample.')
        continue
    if np.any(adata_pseudo_tmp.obs.smoking_status.value_counts()==1):
        print(f'{clust} only has 1 smoker or 1 nonsmoker sample.')
        continue
    if np.any(adata_pseudo_tmp.obs.sex.value_counts()==1):
        print(f'{clust} only has 1 male or 1 female sample.')
        continue
    if np.any(pd.crosstab(adata_pseudo_tmp.obs.smoking_status, adata_pseudo_tmp.obs.sex) == 1):
        print('Want at least 2 in each smoking/sex category.')
        continue
        
    print(f'Testing {adata_pseudo_tmp.n_vars} genes...')
    print(f'Testing in {adata_pseudo_tmp.n_obs} donors...')
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_pseudo_tmp,
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_pseudo_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_pseudo_tmp.X[:, i],
            exog=dmat[0],
            offset=np.log(adata_pseudo_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()

        # Get the covariance matrix
        cov_mat = pois_results.cov_params()

        # Test over coefs
        for coef in tested_coef:
            iter_coefs = tested_coef.copy()
            iter_coefs.remove(coef)
            
            for c1 in to_test[iter_coefs[0]]:
                for c2 in to_test[iter_coefs[1]]:
                    coef_vals = {iter_coefs[0]:c1, iter_coefs[1]:c2}
                    val, stderr, pval = calc_effects(
                        dmat = dmat,
                        cov_mat = cov_mat,
                        params = pois_results.params,
                        effect = coef,
                        coefs = coef_vals)
                    
                    case = '_'.join([iter_coefs[0]+':'+str(c1), iter_coefs[1]+':'+str(c2)])
                    case = case.replace('smoking_status[T.True]:0','NS').replace('smoking_status[T.True]:1','S')
                    case = case.replace('sex[T.male]:0','F').replace('sex[T.male]:1','M')
                    case = case.replace('age:31','31yr').replace('age:62','62yr')
                    case = case.replace('_',' ')
                    
                    # Output the results nicely
                    de_results_temp = pd.DataFrame({
                        "gene": gene,
                        "cell_identity": clust,
                        "covariate": coef,
                        "eval_at": case,
                        "coef": val,
                        "coef_sd": stderr,                 
                        "pval": pval
                    }, index= [clust+"_"+gene+"_"+coef])
                    
                    de_results_list.append(de_results_temp)        

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl3_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl3_glm = pd.concat([de_results_lvl3_glm[i] for i in de_results_lvl3_glm.keys()], ignore_index=True)
# Out:
# In cluster Macrophages:
# False    49
# True     40
# Name: smoking_status, dtype: int64
# male      52
# female    37
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 89 donors...
#
# In cluster Basal:
# False    53
# True     52
# Name: smoking_status, dtype: int64
# male      58
# female    47
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 105 donors...
#
# In cluster AT2:
# False    66
# True     38
# Name: smoking_status, dtype: int64
# male      53
# female    51
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 104 donors...
#
# In cluster T cell lineage:
# False    51
# True     46
# Name: smoking_status, dtype: int64
# male      53
# female    44
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 97 donors...
#
# In cluster Monocytes:
# False    57
# True     39
# Name: smoking_status, dtype: int64
# male      51
# female    45
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 96 donors...
#
# In cluster Multiciliated lineage:
# False    88
# True     69
# Name: smoking_status, dtype: int64
# male      83
# female    74
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 157 donors...
#
# In cluster Submucosal Secretory:
# False    28
# True     17
# Name: smoking_status, dtype: int64
# male      25
# female    20
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 45 donors...
#
# In cluster AT1:
# False    65
# True     36
# Name: smoking_status, dtype: int64
# male      51
# female    50
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 101 donors...
#
# In cluster Innate lymphoid cells:
# False    33
# True     23
# Name: smoking_status, dtype: int64
# male      33
# female    23
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 56 donors...
#
# In cluster Secretory:
# False    75
# True     65
# Name: smoking_status, dtype: int64
# male      76
# female    64
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 140 donors...
#
# In cluster Capillary:
# False    22
# True     12
# Name: smoking_status, dtype: int64
# male      20
# female    14
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 34 donors...
#
# In cluster Mast cells:
# False    49
# True     39
# Name: smoking_status, dtype: int64
# male      46
# female    42
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 88 donors...
#
# In cluster B cell lineage:
# False    52
# True     38
# Name: smoking_status, dtype: int64
# male      53
# female    37
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 90 donors...
#
# In cluster Fibroblasts:
# False    31
# True     20
# Name: smoking_status, dtype: int64
# male      30
# female    21
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 51 donors...
#
# In cluster Dendritic cells:
# False    48
# True     42
# Name: smoking_status, dtype: int64
# male      50
# female    40
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 90 donors...
#
# In cluster Venous:
# False    22
# True     11
# Name: smoking_status, dtype: int64
# male      19
# female    14
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
# Testing in 33 donors...
#
# In cluster Lymphatic EC:
# False    45
# True     31
# Name: smoking_status, dtype: int64
# male      39
# female    37
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 76 donors...
#
# In cluster Arterial:
# False    25
# True     12
# Name: smoking_status, dtype: int64
# male      23
# female    14
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 37 donors...
#
# In cluster Rare:
# False    37
# True     34
# Name: smoking_status, dtype: int64
# male      39
# female    32
# Name: sex, dtype: int64
# Testing 3 genes...
# Testing in 71 donors...
#
# In cluster Airway smooth muscle:
# True     7
# False    6
# Name: smoking_status, dtype: int64
# male      9
# female    4
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 4 cells
# Testing 1 genes...
# Testing in 13 donors...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl3_glm.keys()
# Out:
# dict_keys(['Macrophages', 'Basal', 'AT2', 'T cell lineage', 'Monocytes', 'Multiciliated lineage', 'Submucosal Secretory', 'AT1', 'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells', 'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous', 'Lymphatic EC', 'Arterial', 'Rare', 'Airway smooth muscle'])

# %%
full_res_lvl3_glm
# Out:
#      gene         cell_identity               covariate  eval_at      coef  \
# 0    ACE2           Macrophages             sex[T.male]  31yr NS -0.297912
# 1    ACE2           Macrophages             sex[T.male]   31yr S -1.574722
# 2    ACE2           Macrophages             sex[T.male]  62yr NS -1.640307
# 3    ACE2           Macrophages             sex[T.male]   62yr S -2.917117
# 4    ACE2           Macrophages                     age     F NS  0.005383
# ..    ...                   ...                     ...      ...       ...
# 619  CTSL  Airway smooth muscle                     age      M S -0.017950
# 620  CTSL  Airway smooth muscle  smoking_status[T.True]   F 31yr  2.959046
# 621  CTSL  Airway smooth muscle  smoking_status[T.True]   F 62yr  0.097870
# 622  CTSL  Airway smooth muscle  smoking_status[T.True]   M 31yr  2.170441
# 623  CTSL  Airway smooth muscle  smoking_status[T.True]   M 62yr -0.690735
#
#        coef_sd      pval  adj_pvals
# 0    14.560428  0.983676   0.995306
# 1    31.857020  0.960576   0.995306
# 2    23.518489  0.944396   0.995306
# 3    24.878505  0.906658   0.995306
# 4     0.377046  0.988610   0.995306
# ..         ...       ...        ...
# 619   0.071221  0.801017   0.965744
# 620   6.590653  0.653449   0.965744
# 621   2.278868  0.965744   0.965744
# 622   6.084910  0.721322   0.965744
# 623   1.914520  0.718258   0.965744
#
# [624 rows x 8 columns]

# %%
full_res_lvl3_glm.loc[full_res_lvl3_glm['gene'] == 'ACE2',]
# Out:
#      gene          cell_identity               covariate  eval_at       coef  \
# 0    ACE2            Macrophages             sex[T.male]  31yr NS  -0.297912
# 1    ACE2            Macrophages             sex[T.male]   31yr S  -1.574722
# 2    ACE2            Macrophages             sex[T.male]  62yr NS  -1.640307
# 3    ACE2            Macrophages             sex[T.male]   62yr S  -2.917117
# 4    ACE2            Macrophages                     age     F NS   0.005383
# 5    ACE2            Macrophages                     age      F S   0.008195
# 6    ACE2            Macrophages                     age     M NS  -0.037920
# 7    ACE2            Macrophages                     age      M S  -0.035108
# 8    ACE2            Macrophages  smoking_status[T.True]   F 31yr   0.824854
# 9    ACE2            Macrophages  smoking_status[T.True]   F 62yr   0.912047
# 10   ACE2            Macrophages  smoking_status[T.True]   M 31yr  -0.451956
# 11   ACE2            Macrophages  smoking_status[T.True]   M 62yr  -0.364763
# 36   ACE2                  Basal             sex[T.male]  31yr NS  -0.729983
# 37   ACE2                  Basal             sex[T.male]   31yr S  -0.093310
# 38   ACE2                  Basal             sex[T.male]  62yr NS   0.263114
# 39   ACE2                  Basal             sex[T.male]   62yr S   0.899787
# 40   ACE2                  Basal                     age     F NS  -0.010143
# 41   ACE2                  Basal                     age      F S  -0.067244
# 42   ACE2                  Basal                     age     M NS   0.021892
# 43   ACE2                  Basal                     age      M S  -0.035208
# 44   ACE2                  Basal  smoking_status[T.True]   F 31yr   0.792410
# 45   ACE2                  Basal  smoking_status[T.True]   F 62yr  -0.977701
# 46   ACE2                  Basal  smoking_status[T.True]   M 31yr   1.429082
# 47   ACE2                  Basal  smoking_status[T.True]   M 62yr  -0.341029
# 72   ACE2                    AT2             sex[T.male]  31yr NS   0.680447
# 73   ACE2                    AT2             sex[T.male]   31yr S   1.022157
# 74   ACE2                    AT2             sex[T.male]  62yr NS  -0.118021
# 75   ACE2                    AT2             sex[T.male]   62yr S   0.223689
# 76   ACE2                    AT2                     age     F NS   0.018431
# 77   ACE2                    AT2                     age      F S   0.026247
# 78   ACE2                    AT2                     age     M NS  -0.007326
# 79   ACE2                    AT2                     age      M S   0.000490
# 80   ACE2                    AT2  smoking_status[T.True]   F 31yr  -0.962199
# 81   ACE2                    AT2  smoking_status[T.True]   F 62yr  -0.719890
# 82   ACE2                    AT2  smoking_status[T.True]   M 31yr  -0.620489
# 83   ACE2                    AT2  smoking_status[T.True]   M 62yr  -0.378180
# 108  ACE2         T cell lineage             sex[T.male]  31yr NS   0.962199
# 109  ACE2         T cell lineage             sex[T.male]   31yr S   4.618402
# 110  ACE2         T cell lineage             sex[T.male]  62yr NS   0.348029
# 111  ACE2         T cell lineage             sex[T.male]   62yr S   4.004232
# 112  ACE2         T cell lineage                     age     F NS  -0.011071
# 113  ACE2         T cell lineage                     age      F S  -0.076283
# 114  ACE2         T cell lineage                     age     M NS  -0.030883
# 115  ACE2         T cell lineage                     age      M S  -0.096095
# 116  ACE2         T cell lineage  smoking_status[T.True]   F 31yr  -2.704423
# 117  ACE2         T cell lineage  smoking_status[T.True]   F 62yr  -4.725983
# 118  ACE2         T cell lineage  smoking_status[T.True]   M 31yr   0.951780
# 119  ACE2         T cell lineage  smoking_status[T.True]   M 62yr  -1.069780
# 144  ACE2              Monocytes             sex[T.male]  31yr NS   0.486978
# 145  ACE2              Monocytes             sex[T.male]   31yr S -14.587172
# 146  ACE2              Monocytes             sex[T.male]  62yr NS   0.352988
# 147  ACE2              Monocytes             sex[T.male]   62yr S -14.721162
# 148  ACE2              Monocytes                     age     F NS  -0.048284
# 149  ACE2              Monocytes                     age      F S   0.153672
# 150  ACE2              Monocytes                     age     M NS  -0.052606
# 151  ACE2              Monocytes                     age      M S   0.149350
# 152  ACE2              Monocytes  smoking_status[T.True]   F 31yr  -3.623247
# 153  ACE2              Monocytes  smoking_status[T.True]   F 62yr   2.637382
# 154  ACE2              Monocytes  smoking_status[T.True]   M 31yr -18.697398
# 155  ACE2              Monocytes  smoking_status[T.True]   M 62yr -12.436769
# 180  ACE2  Multiciliated lineage             sex[T.male]  31yr NS   0.430115
# 181  ACE2  Multiciliated lineage             sex[T.male]   31yr S   0.375718
# 182  ACE2  Multiciliated lineage             sex[T.male]  62yr NS  -0.109609
# 183  ACE2  Multiciliated lineage             sex[T.male]   62yr S  -0.164006
# 184  ACE2  Multiciliated lineage                     age     F NS   0.018641
# 185  ACE2  Multiciliated lineage                     age      F S  -0.003324
# 186  ACE2  Multiciliated lineage                     age     M NS   0.001230
# 187  ACE2  Multiciliated lineage                     age      M S  -0.020734
# 188  ACE2  Multiciliated lineage  smoking_status[T.True]   F 31yr   0.641731
# 189  ACE2  Multiciliated lineage  smoking_status[T.True]   F 62yr  -0.039176
# 190  ACE2  Multiciliated lineage  smoking_status[T.True]   M 31yr   0.587334
# 191  ACE2  Multiciliated lineage  smoking_status[T.True]   M 62yr  -0.093573
# 216  ACE2   Submucosal Secretory             sex[T.male]  31yr NS   0.192212
# 217  ACE2   Submucosal Secretory             sex[T.male]   31yr S  -0.057785
# 218  ACE2   Submucosal Secretory             sex[T.male]  62yr NS  -0.150872
# 219  ACE2   Submucosal Secretory             sex[T.male]   62yr S  -0.400869
# 220  ACE2   Submucosal Secretory                     age     F NS   0.008731
# 221  ACE2   Submucosal Secretory                     age      F S   0.015402
# 222  ACE2   Submucosal Secretory                     age     M NS  -0.002337
# 223  ACE2   Submucosal Secretory                     age      M S   0.004335
# 224  ACE2   Submucosal Secretory  smoking_status[T.True]   F 31yr   0.053361
# 225  ACE2   Submucosal Secretory  smoking_status[T.True]   F 62yr   0.260184
# 226  ACE2   Submucosal Secretory  smoking_status[T.True]   M 31yr  -0.196636
# 227  ACE2   Submucosal Secretory  smoking_status[T.True]   M 62yr   0.010187
# 252  ACE2                    AT1             sex[T.male]  31yr NS   0.410115
# 253  ACE2                    AT1             sex[T.male]   31yr S   0.751345
# 254  ACE2                    AT1             sex[T.male]  62yr NS  -0.220985
# 255  ACE2                    AT1             sex[T.male]   62yr S   0.120245
# 256  ACE2                    AT1                     age     F NS  -0.001258
# 257  ACE2                    AT1                     age      F S   0.043456
# 258  ACE2                    AT1                     age     M NS  -0.021616
# 259  ACE2                    AT1                     age      M S   0.023098
# 260  ACE2                    AT1  smoking_status[T.True]   F 31yr  -0.723661
# 261  ACE2                    AT1  smoking_status[T.True]   F 62yr   0.662462
# 262  ACE2                    AT1  smoking_status[T.True]   M 31yr  -0.382432
# 263  ACE2                    AT1  smoking_status[T.True]   M 62yr   1.003692
# 312  ACE2              Secretory             sex[T.male]  31yr NS  -0.058144
# 313  ACE2              Secretory             sex[T.male]   31yr S   0.453372
# 314  ACE2              Secretory             sex[T.male]  62yr NS  -0.241305
# 315  ACE2              Secretory             sex[T.male]   62yr S   0.270212
# 316  ACE2              Secretory                     age     F NS   0.011787
# 317  ACE2              Secretory                     age      F S  -0.035567
# 318  ACE2              Secretory                     age     M NS   0.005879
# 319  ACE2              Secretory                     age      M S  -0.041476
# 320  ACE2              Secretory  smoking_status[T.True]   F 31yr   0.407598
# 321  ACE2              Secretory  smoking_status[T.True]   F 62yr  -1.060398
# 322  ACE2              Secretory  smoking_status[T.True]   M 31yr   0.919114
# 323  ACE2              Secretory  smoking_status[T.True]   M 62yr  -0.548881
# 420  ACE2            Fibroblasts             sex[T.male]  31yr NS  -0.647096
# 421  ACE2            Fibroblasts             sex[T.male]   31yr S  24.707120
# 422  ACE2            Fibroblasts             sex[T.male]  62yr NS  -0.656145
# 423  ACE2            Fibroblasts             sex[T.male]   62yr S  24.698071
# 424  ACE2            Fibroblasts                     age     F NS  -0.009685
# 425  ACE2            Fibroblasts                     age      F S  -0.831037
# 426  ACE2            Fibroblasts                     age     M NS  -0.009977
# 427  ACE2            Fibroblasts                     age      M S  -0.831329
# 428  ACE2            Fibroblasts  smoking_status[T.True]   F 31yr  11.093424
# 429  ACE2            Fibroblasts  smoking_status[T.True]   F 62yr -14.368498
# 430  ACE2            Fibroblasts  smoking_status[T.True]   M 31yr  36.447640
# 431  ACE2            Fibroblasts  smoking_status[T.True]   M 62yr  10.985718
# 504  ACE2           Lymphatic EC             sex[T.male]  31yr NS   1.346253
# 505  ACE2           Lymphatic EC             sex[T.male]   31yr S   4.784210
# 506  ACE2           Lymphatic EC             sex[T.male]  62yr NS   0.885253
# 507  ACE2           Lymphatic EC             sex[T.male]   62yr S   4.323210
# 508  ACE2           Lymphatic EC                     age     F NS   0.062464
# 509  ACE2           Lymphatic EC                     age      F S   0.296466
# 510  ACE2           Lymphatic EC                     age     M NS   0.047593
# 511  ACE2           Lymphatic EC                     age      M S   0.281595
# 512  ACE2           Lymphatic EC  smoking_status[T.True]   F 31yr -10.795707
# 513  ACE2           Lymphatic EC  smoking_status[T.True]   F 62yr  -3.541657
# 514  ACE2           Lymphatic EC  smoking_status[T.True]   M 31yr  -7.357749
# 515  ACE2           Lymphatic EC  smoking_status[T.True]   M 62yr  -0.103700
# 430   3154.423312  0.990781   0.997708
# 431    932.201915  0.990597   0.997708
# 504     13.586241  0.921067   0.992065
# 505     34.133636  0.888533   0.992065
# 506      6.060847  0.883873   0.992065
# 507     31.163602  0.889666   0.992065
# 508      0.305044  0.837751   0.992065
# 509      2.884254  0.918131   0.992065
# 510      0.258935  0.854167   0.992065
# 511      2.856451  0.921470   0.992065
# 512    104.917417  0.918045   0.992065
# 513     32.830897  0.914094   0.992065
# 514     96.944820  0.939502   0.992065
# 515     10.427008  0.992065   0.992065
# 540      2.226059  0.755797   0.999218
# 541  16125.188111  0.999218   0.999218
# 542      3.207612  0.318519   0.999218
# 543  16125.187778  0.999094   0.999218
# 544      0.104591  0.738674   0.999218
# 545    591.971835  0.998716   0.999218
# 546      0.037765  0.223326   0.999218
# 547    591.971826  0.998607   0.999218
# 548  23177.570511  0.998263   0.999218
# 549  15870.996334  0.999002   0.999218
# 550  20127.041838  0.998598   0.999218
# 551   1775.917522  0.997869   0.999218
# 576     16.432778  0.857097   0.982787
# 577     23.855696  0.913466   0.982787
# 578     31.266793  0.907161   0.982787
# 579      6.160069  0.757122   0.982787
# 580      0.327505  0.949932   0.982787
# 581      0.698817  0.982787   0.982787
# 582      0.669871  0.949133   0.982787
# 583      0.246062  0.977005   0.982787
# 584     14.203524  0.886441   0.982787
# 585     20.532149  0.964125   0.982787
# 586     30.557830  0.908215   0.982787
# 587     46.176370  0.920167   0.982787

# %%
full_res_lvl3_glm.loc[full_res_lvl3_glm['gene'] == 'TMPRSS2',]
# Out:
#         gene          cell_identity               covariate  eval_at  \
# 12   TMPRSS2            Macrophages             sex[T.male]  31yr NS
# 13   TMPRSS2            Macrophages             sex[T.male]   31yr S
# 14   TMPRSS2            Macrophages             sex[T.male]  62yr NS
# 15   TMPRSS2            Macrophages             sex[T.male]   62yr S
# 16   TMPRSS2            Macrophages                     age     F NS
# 17   TMPRSS2            Macrophages                     age      F S
# 18   TMPRSS2            Macrophages                     age     M NS
# 19   TMPRSS2            Macrophages                     age      M S
# 20   TMPRSS2            Macrophages  smoking_status[T.True]   F 31yr
# 21   TMPRSS2            Macrophages  smoking_status[T.True]   F 62yr
# 22   TMPRSS2            Macrophages  smoking_status[T.True]   M 31yr
# 23   TMPRSS2            Macrophages  smoking_status[T.True]   M 62yr
# 48   TMPRSS2                  Basal             sex[T.male]  31yr NS
# 49   TMPRSS2                  Basal             sex[T.male]   31yr S
# 50   TMPRSS2                  Basal             sex[T.male]  62yr NS
# 51   TMPRSS2                  Basal             sex[T.male]   62yr S
# 52   TMPRSS2                  Basal                     age     F NS
# 53   TMPRSS2                  Basal                     age      F S
# 54   TMPRSS2                  Basal                     age     M NS
# 55   TMPRSS2                  Basal                     age      M S
# 56   TMPRSS2                  Basal  smoking_status[T.True]   F 31yr
# 57   TMPRSS2                  Basal  smoking_status[T.True]   F 62yr
# 58   TMPRSS2                  Basal  smoking_status[T.True]   M 31yr
# 59   TMPRSS2                  Basal  smoking_status[T.True]   M 62yr
# 84   TMPRSS2                    AT2             sex[T.male]  31yr NS
# 85   TMPRSS2                    AT2             sex[T.male]   31yr S
# 86   TMPRSS2                    AT2             sex[T.male]  62yr NS
# 87   TMPRSS2                    AT2             sex[T.male]   62yr S
# 88   TMPRSS2                    AT2                     age     F NS
# 89   TMPRSS2                    AT2                     age      F S
# 90   TMPRSS2                    AT2                     age     M NS
# 91   TMPRSS2                    AT2                     age      M S
# 92   TMPRSS2                    AT2  smoking_status[T.True]   F 31yr
# 93   TMPRSS2                    AT2  smoking_status[T.True]   F 62yr
# 94   TMPRSS2                    AT2  smoking_status[T.True]   M 31yr
# 95   TMPRSS2                    AT2  smoking_status[T.True]   M 62yr
# 120  TMPRSS2         T cell lineage             sex[T.male]  31yr NS
# 121  TMPRSS2         T cell lineage             sex[T.male]   31yr S
# 122  TMPRSS2         T cell lineage             sex[T.male]  62yr NS
# 123  TMPRSS2         T cell lineage             sex[T.male]   62yr S
# 124  TMPRSS2         T cell lineage                     age     F NS
# 125  TMPRSS2         T cell lineage                     age      F S
# 126  TMPRSS2         T cell lineage                     age     M NS
# 127  TMPRSS2         T cell lineage                     age      M S
# 128  TMPRSS2         T cell lineage  smoking_status[T.True]   F 31yr
# 129  TMPRSS2         T cell lineage  smoking_status[T.True]   F 62yr
# 130  TMPRSS2         T cell lineage  smoking_status[T.True]   M 31yr
# 131  TMPRSS2         T cell lineage  smoking_status[T.True]   M 62yr
# 156  TMPRSS2              Monocytes             sex[T.male]  31yr NS
# 157  TMPRSS2              Monocytes             sex[T.male]   31yr S
# 158  TMPRSS2              Monocytes             sex[T.male]  62yr NS
# 159  TMPRSS2              Monocytes             sex[T.male]   62yr S
# 160  TMPRSS2              Monocytes                     age     F NS
# 161  TMPRSS2              Monocytes                     age      F S
# 162  TMPRSS2              Monocytes                     age     M NS
# 163  TMPRSS2              Monocytes                     age      M S
# 164  TMPRSS2              Monocytes  smoking_status[T.True]   F 31yr
# 165  TMPRSS2              Monocytes  smoking_status[T.True]   F 62yr
# 166  TMPRSS2              Monocytes  smoking_status[T.True]   M 31yr
# 167  TMPRSS2              Monocytes  smoking_status[T.True]   M 62yr
# 192  TMPRSS2  Multiciliated lineage             sex[T.male]  31yr NS
# 193  TMPRSS2  Multiciliated lineage             sex[T.male]   31yr S
# 194  TMPRSS2  Multiciliated lineage             sex[T.male]  62yr NS
# 195  TMPRSS2  Multiciliated lineage             sex[T.male]   62yr S
# 196  TMPRSS2  Multiciliated lineage                     age     F NS
# 197  TMPRSS2  Multiciliated lineage                     age      F S
# 198  TMPRSS2  Multiciliated lineage                     age     M NS
# 199  TMPRSS2  Multiciliated lineage                     age      M S
# 200  TMPRSS2  Multiciliated lineage  smoking_status[T.True]   F 31yr
# 201  TMPRSS2  Multiciliated lineage  smoking_status[T.True]   F 62yr
# 202  TMPRSS2  Multiciliated lineage  smoking_status[T.True]   M 31yr
# 203  TMPRSS2  Multiciliated lineage  smoking_status[T.True]   M 62yr
# 228  TMPRSS2   Submucosal Secretory             sex[T.male]  31yr NS
# 229  TMPRSS2   Submucosal Secretory             sex[T.male]   31yr S
# 230  TMPRSS2   Submucosal Secretory             sex[T.male]  62yr NS
# 231  TMPRSS2   Submucosal Secretory             sex[T.male]   62yr S
# 232  TMPRSS2   Submucosal Secretory                     age     F NS
# 233  TMPRSS2   Submucosal Secretory                     age      F S
# 234  TMPRSS2   Submucosal Secretory                     age     M NS
# 235  TMPRSS2   Submucosal Secretory                     age      M S
# 236  TMPRSS2   Submucosal Secretory  smoking_status[T.True]   F 31yr
# 237  TMPRSS2   Submucosal Secretory  smoking_status[T.True]   F 62yr
# 238  TMPRSS2   Submucosal Secretory  smoking_status[T.True]   M 31yr
# 239  TMPRSS2   Submucosal Secretory  smoking_status[T.True]   M 62yr
# 264  TMPRSS2                    AT1             sex[T.male]  31yr NS
# 265  TMPRSS2                    AT1             sex[T.male]   31yr S
# 266  TMPRSS2                    AT1             sex[T.male]  62yr NS
# 267  TMPRSS2                    AT1             sex[T.male]   62yr S
# 268  TMPRSS2                    AT1                     age     F NS
# 269  TMPRSS2                    AT1                     age      F S
# 270  TMPRSS2                    AT1                     age     M NS
# 271  TMPRSS2                    AT1                     age      M S
# 272  TMPRSS2                    AT1  smoking_status[T.True]   F 31yr
# 273  TMPRSS2                    AT1  smoking_status[T.True]   F 62yr
# 274  TMPRSS2                    AT1  smoking_status[T.True]   M 31yr
# 275  TMPRSS2                    AT1  smoking_status[T.True]   M 62yr
# 288  TMPRSS2  Innate lymphoid cells             sex[T.male]  31yr NS
# 289  TMPRSS2  Innate lymphoid cells             sex[T.male]   31yr S
# 290  TMPRSS2  Innate lymphoid cells             sex[T.male]  62yr NS
# 291  TMPRSS2  Innate lymphoid cells             sex[T.male]   62yr S
# 292  TMPRSS2  Innate lymphoid cells                     age     F NS
# 293  TMPRSS2  Innate lymphoid cells                     age      F S
# 294  TMPRSS2  Innate lymphoid cells                     age     M NS
# 295  TMPRSS2  Innate lymphoid cells                     age      M S
# 296  TMPRSS2  Innate lymphoid cells  smoking_status[T.True]   F 31yr
# 297  TMPRSS2  Innate lymphoid cells  smoking_status[T.True]   F 62yr
# 298  TMPRSS2  Innate lymphoid cells  smoking_status[T.True]   M 31yr
# 299  TMPRSS2  Innate lymphoid cells  smoking_status[T.True]   M 62yr
# 324  TMPRSS2              Secretory             sex[T.male]  31yr NS
# 325  TMPRSS2              Secretory             sex[T.male]   31yr S
# 326  TMPRSS2              Secretory             sex[T.male]  62yr NS
# 327  TMPRSS2              Secretory             sex[T.male]   62yr S
# 328  TMPRSS2              Secretory                     age     F NS
# 329  TMPRSS2              Secretory                     age      F S
# 330  TMPRSS2              Secretory                     age     M NS
# 331  TMPRSS2              Secretory                     age      M S
# 332  TMPRSS2              Secretory  smoking_status[T.True]   F 31yr
# 333  TMPRSS2              Secretory  smoking_status[T.True]   F 62yr
# 334  TMPRSS2              Secretory  smoking_status[T.True]   M 31yr
# 335  TMPRSS2              Secretory  smoking_status[T.True]   M 62yr
# 348  TMPRSS2              Capillary             sex[T.male]  31yr NS
# 349  TMPRSS2              Capillary             sex[T.male]   31yr S
# 350  TMPRSS2              Capillary             sex[T.male]  62yr NS
# 351  TMPRSS2              Capillary             sex[T.male]   62yr S
# 352  TMPRSS2              Capillary                     age     F NS
# 353  TMPRSS2              Capillary                     age      F S
# 354  TMPRSS2              Capillary                     age     M NS
# 355  TMPRSS2              Capillary                     age      M S
# 356  TMPRSS2              Capillary  smoking_status[T.True]   F 31yr
# 357  TMPRSS2              Capillary  smoking_status[T.True]   F 62yr
# 358  TMPRSS2              Capillary  smoking_status[T.True]   M 31yr
# 359  TMPRSS2              Capillary  smoking_status[T.True]   M 62yr
# 372  TMPRSS2             Mast cells             sex[T.male]  31yr NS
# 373  TMPRSS2             Mast cells             sex[T.male]   31yr S
# 374  TMPRSS2             Mast cells             sex[T.male]  62yr NS
# 375  TMPRSS2             Mast cells             sex[T.male]   62yr S
# 376  TMPRSS2             Mast cells                     age     F NS
# 377  TMPRSS2             Mast cells                     age      F S
# 378  TMPRSS2             Mast cells                     age     M NS
# 379  TMPRSS2             Mast cells                     age      M S
# 380  TMPRSS2             Mast cells  smoking_status[T.True]   F 31yr
# 381  TMPRSS2             Mast cells  smoking_status[T.True]   F 62yr
# 382  TMPRSS2             Mast cells  smoking_status[T.True]   M 31yr
# 383  TMPRSS2             Mast cells  smoking_status[T.True]   M 62yr
# 396  TMPRSS2         B cell lineage             sex[T.male]  31yr NS
# 397  TMPRSS2         B cell lineage             sex[T.male]   31yr S
# 398  TMPRSS2         B cell lineage             sex[T.male]  62yr NS
# 399  TMPRSS2         B cell lineage             sex[T.male]   62yr S
# 400  TMPRSS2         B cell lineage                     age     F NS
# 401  TMPRSS2         B cell lineage                     age      F S
# 402  TMPRSS2         B cell lineage                     age     M NS
# 403  TMPRSS2         B cell lineage                     age      M S
# 404  TMPRSS2         B cell lineage  smoking_status[T.True]   F 31yr
# 405  TMPRSS2         B cell lineage  smoking_status[T.True]   F 62yr
# 406  TMPRSS2         B cell lineage  smoking_status[T.True]   M 31yr
# 407  TMPRSS2         B cell lineage  smoking_status[T.True]   M 62yr
# 432  TMPRSS2            Fibroblasts             sex[T.male]  31yr NS
# 433  TMPRSS2            Fibroblasts             sex[T.male]   31yr S
# 434  TMPRSS2            Fibroblasts             sex[T.male]  62yr NS
# 435  TMPRSS2            Fibroblasts             sex[T.male]   62yr S
# 436  TMPRSS2            Fibroblasts                     age     F NS
# 437  TMPRSS2            Fibroblasts                     age      F S
# 438  TMPRSS2            Fibroblasts                     age     M NS
# 439  TMPRSS2            Fibroblasts                     age      M S
# 440  TMPRSS2            Fibroblasts  smoking_status[T.True]   F 31yr
# 441  TMPRSS2            Fibroblasts  smoking_status[T.True]   F 62yr
# 442  TMPRSS2            Fibroblasts  smoking_status[T.True]   M 31yr
# 443  TMPRSS2            Fibroblasts  smoking_status[T.True]   M 62yr
# 456  TMPRSS2        Dendritic cells             sex[T.male]  31yr NS
# 457  TMPRSS2        Dendritic cells             sex[T.male]   31yr S
# 458  TMPRSS2        Dendritic cells             sex[T.male]  62yr NS
# 459  TMPRSS2        Dendritic cells             sex[T.male]   62yr S
# 460  TMPRSS2        Dendritic cells                     age     F NS
# 461  TMPRSS2        Dendritic cells                     age      F S
# 462  TMPRSS2        Dendritic cells                     age     M NS
# 463  TMPRSS2        Dendritic cells                     age      M S
# 464  TMPRSS2        Dendritic cells  smoking_status[T.True]   F 31yr
# 465  TMPRSS2        Dendritic cells  smoking_status[T.True]   F 62yr
# 466  TMPRSS2        Dendritic cells  smoking_status[T.True]   M 31yr
# 467  TMPRSS2        Dendritic cells  smoking_status[T.True]   M 62yr
# 480  TMPRSS2                 Venous             sex[T.male]  31yr NS
# 481  TMPRSS2                 Venous             sex[T.male]   31yr S
# 482  TMPRSS2                 Venous             sex[T.male]  62yr NS
# 483  TMPRSS2                 Venous             sex[T.male]   62yr S
# 484  TMPRSS2                 Venous                     age     F NS
# 485  TMPRSS2                 Venous                     age      F S
# 486  TMPRSS2                 Venous                     age     M NS
# 487  TMPRSS2                 Venous                     age      M S
# 488  TMPRSS2                 Venous  smoking_status[T.True]   F 31yr
# 489  TMPRSS2                 Venous  smoking_status[T.True]   F 62yr
# 490  TMPRSS2                 Venous  smoking_status[T.True]   M 31yr
# 491  TMPRSS2                 Venous  smoking_status[T.True]   M 62yr
# 516  TMPRSS2           Lymphatic EC             sex[T.male]  31yr NS
# 517  TMPRSS2           Lymphatic EC             sex[T.male]   31yr S
# 518  TMPRSS2           Lymphatic EC             sex[T.male]  62yr NS
# 519  TMPRSS2           Lymphatic EC             sex[T.male]   62yr S
# 520  TMPRSS2           Lymphatic EC                     age     F NS
# 521  TMPRSS2           Lymphatic EC                     age      F S
# 522  TMPRSS2           Lymphatic EC                     age     M NS
# 523  TMPRSS2           Lymphatic EC                     age      M S
# 524  TMPRSS2           Lymphatic EC  smoking_status[T.True]   F 31yr
# 525  TMPRSS2           Lymphatic EC  smoking_status[T.True]   F 62yr
# 526  TMPRSS2           Lymphatic EC  smoking_status[T.True]   M 31yr
# 527  TMPRSS2           Lymphatic EC  smoking_status[T.True]   M 62yr
# 552  TMPRSS2               Arterial             sex[T.male]  31yr NS
# 553  TMPRSS2               Arterial             sex[T.male]   31yr S
# 554  TMPRSS2               Arterial             sex[T.male]  62yr NS
# 555  TMPRSS2               Arterial             sex[T.male]   62yr S
# 556  TMPRSS2               Arterial                     age     F NS
# 557  TMPRSS2               Arterial                     age      F S
# 558  TMPRSS2               Arterial                     age     M NS
# 559  TMPRSS2               Arterial                     age      M S
# 560  TMPRSS2               Arterial  smoking_status[T.True]   F 31yr
# 561  TMPRSS2               Arterial  smoking_status[T.True]   F 62yr
# 562  TMPRSS2               Arterial  smoking_status[T.True]   M 31yr
# 563  TMPRSS2               Arterial  smoking_status[T.True]   M 62yr
# 588  TMPRSS2                   Rare             sex[T.male]  31yr NS
# 589  TMPRSS2                   Rare             sex[T.male]   31yr S
