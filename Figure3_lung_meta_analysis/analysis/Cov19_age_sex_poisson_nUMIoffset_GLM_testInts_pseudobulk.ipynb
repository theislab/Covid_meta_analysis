# %% [markdown]
# This notebook contains the code for the meta-analysis of healthy lung data for ACE2, TMPRSS2, and CTSL. It contains the pseudo-bulk analysis for the complex model with interaction terms that was run on the patient-level data. This script contains the code that was run on the full data and does not test for smoking associations.

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors
from matplotlib import patches
import seaborn as sns
import batchglm
import diffxpy.api as de
import patsy as pat
from statsmodels.stats.multitest import multipletests
import logging, warnings
import statsmodels.api as sm
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()
de.__version__

logging.getLogger("tensorflow").setLevel(logging.ERROR)
logging.getLogger("batchglm").setLevel(logging.INFO)
logging.getLogger("diffxpy").setLevel(logging.INFO)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1
# 'v0.7.3'

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

adata_diffxpy = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study/COVID19_lung_atlas_revision_v3.h5ad'

output_folder = 'diffxpy_out/'

de_output_base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm_pseudo_nUMIoffset_testInts'

# %% [markdown]
# # Read the data

# %%
adata = sc.read(adata_diffxpy)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1320896 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new'

# %%
adata.obs.age = adata.obs.age.astype(float)

# %%
adata.obs.dtypes
# Out:
# age                         float64
# anatomical_region          category
# donor                      category
# last_author/PI             category
# lung_vs_nasal              category
# notes                      category
# original_celltype_ann      category
# sample                     category
# sex                        category
# smoking                    category
# total_counts                float64
# smoked_boolean             category
# last_author_sample_name    category
# ann_level_1                category
# ann_level_2                category
# ann_level_3                category
# ann_level_4                category
# ann_level_5                category
# ann_highest_res               int64
# ann_new                        bool
# dtype: object

# %%
adata.obs['dataset'] = adata.obs['last_author/PI']

# %%
adata.obs.dataset.value_counts()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    95303
# Spence                      78401
# Barbry/Leroy                76981
# Krasnow/Quake               60993
# Meyer                       57020
# Rawlins                     53409
# Regev                       43527
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Misharin                    28329
# Xavier/Regev                25552
# Spira/Campbell              24455
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Schultze                    22641
# Schiller                    20776
# Nawijn                      18197
# Teichmann                   12971
# Kropski/Banovich_dnar        8359
# Shalek                       7603
# Linnarsson                   4640
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      2207
# Schultze/Falk                1965
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64

# %% [markdown]
# # Filter the data

# %% [markdown]
# Keep only datsets with:
# - more than 1 donor
# - non-fetal
# - lung

# %%
# Remove fetal datasets
dats_to_remove = set(['Rawlins', 'Spence', 'Linnarsson'])

# %%
dat = adata.obs.groupby(['donor']).agg({'sex':'first', 'age':'first', 'dataset':'first'})

# Single donor filter
don_tab = dat['dataset'].value_counts()
dats_to_remove.update(set(don_tab.index[don_tab == 1]))

# %%
dats_to_remove = list(dats_to_remove)
dats_to_remove
# Out:
# ['Misharin', 'Spence', 'Rawlins', 'Schultze/Falk', 'Linnarsson']

# %%
adata = adata[~adata.obs.dataset.isin(dats_to_remove)].copy()

# %%
adata.obs.lung_vs_nasal.value_counts()
# Out:
# lung     1096604
# nasal      57548
# Name: lung_vs_nasal, dtype: int64

# %%
# Filter for only lung data
adata = adata[adata.obs.lung_vs_nasal.isin(['lung']),].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1096604 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset'

# %%
# Rename smoking status covariate
adata.obs['smoking_status'] = adata.obs.smoked_boolean

# %%
adata.obs.dataset.value_counts()
adata.obs['sample'].nunique()
adata.obs['donor'].nunique()
# Out:
# Regev/Rajagopal            322998
# Meyer_b                    117535
# Kaminski                    95303
# Krasnow/Quake               60993
# Barbry/Leroy                58790
# Meyer                       57020
# Regev                       43527
# Misharin/Budinger           41266
# Eils/Conrad/Kreuter         39778
# Seibold                     36248
# Whitsett/Xu_10X             34185
# Koenigshoff                 33119
# Xavier/Regev                25552
# Lafyatis/Rojas              24220
# Kropski/Banovich_vand       23285
# Schultze                    22641
# Schiller                    20776
# Teichmann                   12971
# Nawijn                      11110
# Kropski/Banovich_dnar        8359
# Whitsett/Xu_dropSeq          3267
# Mazzilli/Campbell/Beane      1995
# Beane                         886
# Beane/Campbell                780
# Name: dataset, dtype: int64
# 309
# 185

# %% [markdown]
# # Check the data

# %%
np.mean(adata.X.astype(int) != adata.X)
# Out:
# 0.0

# %%
# Check if any non-integer data in a particular dataset
for dat in adata.obs.dataset.unique():
    val = np.mean(adata[adata.obs.dataset.isin([dat]),:].X.astype(int) != adata[adata.obs.dataset.isin([dat]),:].X)
    if val != 0:
        print(f'dataset= {dat}; value= {val}')
        adata[adata.obs.dataset.isin([dat]),:].X[:20,:20].A

# %% [markdown]
# All counts are (or nearly are) integers

# %%
adata.obs.age.value_counts()
adata.obs.sex.value_counts()
# Out:
# 57.00    81833
# 66.00    69371
# 42.00    66596
# 59.00    59955
# 18.00    59849
# 46.00    56291
# 64.00    46130
# 35.00    45869
# 0.25     29908
# 67.50    28201
# 55.50    27176
# 20.00    25362
# 51.00    24766
# 72.50    24366
# 30.00    24095
# 58.00    23723
# 29.00    19248
# 0.00     19065
# 32.00    19009
# 3.00     18387
# 42.50    16906
# 45.50    16351
# 56.00    16011
# 23.00    15181
# 41.00    14943
# 49.00    14225
# 57.50    13840
# 55.00    13733
# 68.00    11852
# 65.00    11404
# 75.00    11243
# 45.00    10939
# 47.00    10278
# 52.50    10133
# 21.00     9430
# 67.00     9278
# 27.00     8693
# 22.00     7980
# 63.00     7600
# 31.00     7085
# 33.00     6906
# 44.00     6681
# 62.00     6228
# 38.00     5629
# 73.00     5251
# 24.00     4433
# 60.00     4231
# 62.50     4073
# 26.00     4066
# 61.00     3922
# 50.00     3831
# 32.50     3772
# 52.00     3765
# 80.00     3261
# 10.00     2694
# 40.00     2647
# 17.00     2552
# 79.00     2550
# 54.00     2507
# 76.00     2447
# 36.00     2218
# 53.00     1592
# 37.00     1240
# 48.00     1153
# 81.00     1145
# 25.00      823
# 70.00      168
# 69.00      130
# 87.00      112
# 43.00       79
# 34.00       76
# 78.00       65
# 74.00       52
# Name: age, dtype: int64
# female    583926
# male      512678
# Name: sex, dtype: int64

# %% [markdown]
# # Fit models and perform DE

# %%
cluster_key = 'ann_level_2'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Myeloid',
#  'Airway epithelium',
#  'Alveolar epithelium',
#  'Lymphoid',
#  'Fibroblast lineage',
#  'Blood vessels',
#  'Submucosal Gland',
#  'Smooth Muscle',
#  'Lymphatics',
#  'Mesothelium',
#  'Endothelial-like',
#  'Granulocytes']

# %% [markdown]
# Calculate DE genes per cluster.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1096604 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status'

# %% [markdown]
# # Generate pseudobulks

# %%
for gene in adata.var_names:
    adata.obs[gene] = adata[:,gene].X.A

# %%
dat_pseudo = adata.obs.groupby(['donor', 'ann_level_2']).agg({'ACE2':'mean', 'TMPRSS2':'mean', 'CTSL':'mean', 'total_counts':'mean', 'age':'first', 'smoking_status':'first', 'sex':'first', 'dataset':'first'}).dropna().reset_index(level=[0,1])
adata_pseudo = sc.AnnData(dat_pseudo[['ACE2', 'TMPRSS2', 'CTSL']], obs=dat_pseudo.drop(columns=['ACE2', 'TMPRSS2', 'CTSL']))
# Out:
# Transforming to str index.

# %%
adata_pseudo.obs.head()
# Out:
#       donor          ann_level_2  total_counts   age smoking_status     sex  \
# 0  1A1DFBng        1_Endothelial   6307.156863  47.0           True  female
# 1  1A1DFBng    Airway epithelium   4948.705263  47.0           True  female
# 2  1A1DFBng  Alveolar epithelium   4268.209154  47.0           True  female
# 3  1A1DFBng   Fibroblast lineage   5888.260870  47.0           True  female
# 4  1A1DFBng           Lymphatics   5503.117647  47.0           True  female
#
#                dataset
# 0  Eils/Conrad/Kreuter
# 1  Eils/Conrad/Kreuter
# 2  Eils/Conrad/Kreuter
# 3  Eils/Conrad/Kreuter
# 4  Eils/Conrad/Kreuter

# %%
adata_pseudo.obs['total_counts_scaled'] = adata_pseudo.obs['total_counts']/adata_pseudo.obs['total_counts'].mean()

# %%
# Get interquartile range for ages to test
adata_pseudo.obs.groupby(['donor']).agg({'age':'first'}).age.quantile([0.25,0.5,0.75])
# Out:
# 0.25    32.0
# 0.50    52.0
# 0.75    62.5
# Name: age, dtype: float64

# %%
formula = "1 + sex + age + sex:age + dataset"
tested_coef = ["sex[T.male]", "age"]
dmat = de.utils.design_matrix(
    data=adata,
    formula="~" + formula,
    as_numeric=["age"],
    return_type="patsy"
)

to_test = dict()
to_test['age'] = [32,62]
to_test['sex[T.male]'] = [0,1]

dmat[1]
# Out:
# ['Intercept',
#  'sex[T.male]',
#  'dataset[T.Beane]',
#  'dataset[T.Beane/Campbell]',
#  'dataset[T.Eils/Conrad/Kreuter]',
#  'dataset[T.Kaminski]',
#  'dataset[T.Koenigshoff]',
#  'dataset[T.Krasnow/Quake]',
#  'dataset[T.Kropski/Banovich_dnar]',
#  'dataset[T.Kropski/Banovich_vand]',
#  'dataset[T.Lafyatis/Rojas]',
#  'dataset[T.Mazzilli/Campbell/Beane]',
#  'dataset[T.Meyer]',
#  'dataset[T.Meyer_b]',
#  'dataset[T.Misharin/Budinger]',
#  'dataset[T.Nawijn]',
#  'dataset[T.Regev]',
#  'dataset[T.Regev/Rajagopal]',
#  'dataset[T.Schiller]',
#  'dataset[T.Schultze]',
#  'dataset[T.Seibold]',
#  'dataset[T.Teichmann]',
#  'dataset[T.Whitsett/Xu_10X]',
#  'dataset[T.Whitsett/Xu_dropSeq]',
#  'dataset[T.Xavier/Regev]',
#  'age',
#  'sex[T.male]:age']

# %% [markdown]
# ### Function definition to test effect sizes at particular covariate values

# %%
def calc_effects(dmat, cov_mat, params, effect, coefs):
    from patsy.design_info import DesignMatrix
    from diffxpy.api.stats import wald_test_chisq
    
    dmat_cond = isinstance(dmat, tuple) and isinstance(dmat[0], DesignMatrix)

    if not dmat_cond:
        raise ValueError("`dmat` should be a patsy output Design Matrix.")

    effect_list = ['sex[T.male]', 'age', 'smoking_status[T.True]']
    if not effect in effect_list:
        raise ValueError(f'{effect} is not one of: '
                         f'{effect_list}')

    if not isinstance(coefs, dict):
        raise TypeError('`coefs` should contain a dictionary of coefficients '
                        'where the effects should be evaluated.')
    
    ## Note: this is only correct when 3 covariates are tested in combinations
    #if np.sum([coef in coefs for coef in effect_list]) < 2:
    #    raise ValueError('The `coefs` dict must contain values for the two '
    #                     'coefficient not tested in:'
    #                     f'{effect_list}')
        
    if 'smoking_status[T.True]' in coefs and coefs['smoking_status[T.True]'] not in [0,1]:
        raise ValueError('Smoking status should be encoded as 0 or 1.')

    if 'sex[T.male]' in coefs and coefs['sex[T.male]'] not in [0,1]:
        raise ValueError('Sex should be encoded as 0 or 1.')

    if 'age' in coefs and not (isinstance(coefs['age'], float) or isinstance(coefs['age'], int)):
        raise ValueError('Age should be a numerical value.')

    coef_list = []

    for term in dmat[1]:
        if effect not in term:
            coef_list.append(0)
        elif term == effect:
            coef_list.append(1)
        else:
            t_list = term.split(':')
            t_list.remove(effect)
            coef_list.append(coefs[t_list[0]])

    C = np.array(coef_list)
    val = np.matmul(C,np.array(params))
    stderr = np.sqrt(np.matmul(np.matmul(C.T,cov_mat),C))
    pval = wald_test_chisq(np.array([val]).reshape(1,1), np.array([stderr**2]).reshape(1,1,1))[0]
    return (val, stderr, pval)

# %% [markdown]
# ## Poisson GLM

# %%
# Poisson GLM loop
de_results_lvl2_glm = dict()

# Test over clusters
for clust in clusters:
    adata_pseudo_tmp = adata_pseudo[adata_pseudo.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_pseudo_tmp.obs['smoking_status'].value_counts())
    print(adata_pseudo_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_pseudo_tmp, min_cells=4)
    if adata_pseudo_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_pseudo_tmp.obs.sex.value_counts())==1:
        print(f'{clust} only has 1 type of male/female sample.')
        continue
        
    print(f'Testing {adata_pseudo_tmp.n_vars} genes...')
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_pseudo_tmp, #[idx_train],
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_pseudo_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_pseudo_tmp.X[:, i], #[idx_train, :], 
            exog=dmat[0],
            offset=np.log(adata_pseudo_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()

        # Get the covariance matrix
        cov_mat = pois_results.cov_params()

        # Test over coefs
        for coef in tested_coef:
            iter_coefs = tested_coef.copy()
            iter_coefs.remove(coef)
            
            for c1 in to_test[iter_coefs[0]]:
                coef_vals = {iter_coefs[0]:c1}
                val, stderr, pval = calc_effects(
                    dmat = dmat,
                    cov_mat = cov_mat,
                    params = pois_results.params,
                    effect = coef,
                    coefs = coef_vals)
                
                case = iter_coefs[0]+':'+str(c1)
                case = case.replace('sex[T.male]:0','F').replace('sex[T.male]:1','M')
                case = case.replace('age:32','32yr').replace('age:62','62yr')
                case = case.replace('_',' ')
                
                # Output the results nicely
                de_results_temp = pd.DataFrame({
                    "gene": gene,
                    "cell_identity": clust,
                    "covariate": coef,
                    "eval_at": case,
                    "coef": val,
                    "coef_sd": stderr,                 
                    "pval": pval
                }, index= [clust+"_"+gene+"_"+coef])
                
                de_results_list.append(de_results_temp)

    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl2_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl2_glm = pd.concat([de_results_lvl2_glm[i] for i in de_results_lvl2_glm.keys()], ignore_index=True)
# Out:
# In cluster Myeloid:
# False    66
# True     55
# nan      21
# Name: smoking_status, dtype: int64
# male      76
# female    66
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Airway epithelium:
# False    90
# True     71
# nan      20
# Name: smoking_status, dtype: int64
# male      97
# female    84
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Alveolar epithelium:
# False    67
# True     39
# nan      14
# Name: smoking_status, dtype: int64
# male      64
# female    56
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Lymphoid:
# False    72
# True     62
# nan      21
# Name: smoking_status, dtype: int64
# male      82
# female    73
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Fibroblast lineage:
# False    54
# True     40
# nan      14
# Name: smoking_status, dtype: int64
# male      59
# female    49
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Blood vessels:
# False    48
# True     31
# nan      13
# Name: smoking_status, dtype: int64
# male      54
# female    38
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Submucosal Gland:
# False    28
# True     17
# Name: smoking_status, dtype: int64
# male      25
# female    20
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Smooth Muscle:
# False    35
# True     26
# nan       5
# Name: smoking_status, dtype: int64
# male      34
# female    32
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Lymphatics:
# False    45
# True     31
# nan      13
# Name: smoking_status, dtype: int64
# male      48
# female    41
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Mesothelium:
# True     15
# False    14
# nan       2
# Name: smoking_status, dtype: int64
# male      16
# female    15
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
#
# In cluster Endothelial-like:
# nan    3
# Name: smoking_status, dtype: int64
# male    3
# Name: sex, dtype: int64
# filtered out 3 genes that are detected in less than 4 cells
# No genes expressed in more than 10 cells!
# In cluster Granulocytes:
# nan     13
# True     1
# Name: smoking_status, dtype: int64
# female    7
# male      7
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 4 cells
# Testing 1 genes...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl2_glm.keys()
# Out:
# dict_keys(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid', 'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland', 'Smooth Muscle', 'Lymphatics', 'Mesothelium', 'Granulocytes'])

# %%
full_res_lvl2_glm
# Out:
#         gene        cell_identity    covariate eval_at      coef    coef_sd  \
# 0       ACE2              Myeloid  sex[T.male]    32yr  0.298059   9.510353
# 1       ACE2              Myeloid  sex[T.male]    62yr  0.288443   9.562100
# 2       ACE2              Myeloid          age       F -0.018231   0.277863
# 3       ACE2              Myeloid          age       M -0.018551   0.389273
# 4    TMPRSS2              Myeloid  sex[T.male]    32yr  0.995246   2.152080
# 5    TMPRSS2              Myeloid  sex[T.male]    62yr  0.603703   1.824983
# 6    TMPRSS2              Myeloid          age       F  0.006562   0.048913
# 7    TMPRSS2              Myeloid          age       M -0.006490   0.091134
# 8       CTSL              Myeloid  sex[T.male]    32yr -0.121609   0.142934
# 9       CTSL              Myeloid  sex[T.male]    62yr  0.056677   0.143601
# 10      CTSL              Myeloid          age       F -0.000182   0.004921
# 11      CTSL              Myeloid          age       M  0.005761   0.004328
# 12      ACE2    Airway epithelium  sex[T.male]    32yr  0.050874   1.500049
# 13      ACE2    Airway epithelium  sex[T.male]    62yr  0.013722   1.404795
# 14      ACE2    Airway epithelium          age       F -0.004533   0.055162
# 15      ACE2    Airway epithelium          age       M -0.005771   0.050994
# 16   TMPRSS2    Airway epithelium  sex[T.male]    32yr  0.256681   0.359212
# 17   TMPRSS2    Airway epithelium  sex[T.male]    62yr  0.195109   0.363213
# 18   TMPRSS2    Airway epithelium          age       F -0.003329   0.012262
# 19   TMPRSS2    Airway epithelium          age       M -0.005381   0.011938
# 20      CTSL    Airway epithelium  sex[T.male]    32yr  0.081198   0.398951
# 62      ACE2        Blood vessels          age       F -0.011093   0.120055
# 63      ACE2        Blood vessels          age       M  0.019180   0.131603
# 64   TMPRSS2        Blood vessels  sex[T.male]    32yr -0.540071   3.950133
# 65   TMPRSS2        Blood vessels  sex[T.male]    62yr  0.243518   3.162130
# 66   TMPRSS2        Blood vessels          age       F  0.010683   0.102405
# 67   TMPRSS2        Blood vessels          age       M  0.036803   0.132312
# 68      CTSL        Blood vessels  sex[T.male]    32yr  0.224192   0.571053
# 69      CTSL        Blood vessels  sex[T.male]    62yr  0.059578   0.536157
# 70      CTSL        Blood vessels          age       F  0.011858   0.020890
# 71      CTSL        Blood vessels          age       M  0.006371   0.017540
# 72      ACE2     Submucosal Gland  sex[T.male]    32yr  0.128038   3.024546
# 73      ACE2     Submucosal Gland  sex[T.male]    62yr -0.273110   3.111551
# 74      ACE2     Submucosal Gland          age       F  0.010867   0.091912
# 75      ACE2     Submucosal Gland          age       M -0.002505   0.092092
# 76   TMPRSS2     Submucosal Gland  sex[T.male]    32yr  0.277254   0.742534
# 77   TMPRSS2     Submucosal Gland  sex[T.male]    62yr -0.066143   0.796453
# 78   TMPRSS2     Submucosal Gland          age       F  0.005732   0.025030
# 79   TMPRSS2     Submucosal Gland          age       M -0.005715   0.022755
# 80      CTSL     Submucosal Gland  sex[T.male]    32yr -0.149420   0.617817
# 81      CTSL     Submucosal Gland  sex[T.male]    62yr  0.016246   0.521708
# 82      CTSL     Submucosal Gland          age       F -0.001399   0.016889
# 83      CTSL     Submucosal Gland          age       M  0.004123   0.019272
# 84      ACE2        Smooth Muscle  sex[T.male]    32yr  1.362052   3.559049
# 85      ACE2        Smooth Muscle  sex[T.male]    62yr  2.003600  15.072656
# 86      ACE2        Smooth Muscle          age       F -0.035123   0.495017
# 87      ACE2        Smooth Muscle          age       M -0.013738   0.107215
# 88   TMPRSS2        Smooth Muscle  sex[T.male]    32yr -0.524200   5.584378
# 89   TMPRSS2        Smooth Muscle  sex[T.male]    62yr -1.398958   4.577155
# 90   TMPRSS2        Smooth Muscle          age       F  0.015224   0.111466
# 91   TMPRSS2        Smooth Muscle          age       M -0.013935   0.200422
# 92      CTSL        Smooth Muscle  sex[T.male]    32yr -0.358325   0.459038
# 93      CTSL        Smooth Muscle  sex[T.male]    62yr -0.041834   0.463844
# 94      CTSL        Smooth Muscle          age       F -0.020788   0.015723
# 95      CTSL        Smooth Muscle          age       M -0.010239   0.017563
# 96      ACE2           Lymphatics  sex[T.male]    32yr  1.204611  14.226441
# 97      ACE2           Lymphatics  sex[T.male]    62yr  1.152026   5.170162
# 98      ACE2           Lymphatics          age       F  0.073182   0.320884
# 99      ACE2           Lymphatics          age       M  0.071430   0.278538
# 100  TMPRSS2           Lymphatics  sex[T.male]    32yr  0.368787   1.326066
# 101  TMPRSS2           Lymphatics  sex[T.male]    62yr  0.736776   1.356804
# 102  TMPRSS2           Lymphatics          age       F -0.013524   0.033863
# 66   0.916912   0.941357
# 67   0.780895   0.941357
# 68   0.694619   0.941357
# 69   0.911521   0.941357
# 70   0.570288   0.941357
# 71   0.716444   0.941357
# 72   0.966233   0.978300
# 73   0.930057   0.978300
# 74   0.905886   0.978300
# 75   0.978300   0.978300
# 76   0.708859   0.978300
# 77   0.933814   0.978300
# 78   0.818878   0.978300
# 79   0.801695   0.978300
# 80   0.808896   0.978300
# 81   0.975158   0.978300
# 82   0.933990   0.978300
# 83   0.830581   0.978300
# 84   0.701941   0.944571
# 85   0.894249   0.944571
# 86   0.943435   0.944571
# 87   0.898041   0.944571
# 88   0.925213   0.944571
# 89   0.759879   0.944571
# 90   0.891363   0.944571
# 91   0.944571   0.944571
# 92   0.435038   0.944571
# 93   0.928137   0.944571
# 94   0.186113   0.944571
# 95   0.559899   0.944571
# 96   0.932520   0.983884
# 97   0.823674   0.983884
# 98   0.819596   0.983884
# 99   0.797608   0.983884
# 100  0.780931   0.983884
# 101  0.587114   0.983884
# 102  0.689611   0.983884
# 103  0.983884   0.983884
# 104  0.747013   0.983884
# 105  0.825169   0.983884
# 106  0.819952   0.983884
# 107  0.921942   0.983884
# 108  0.761691   0.808146
# 109  0.808146   0.808146
# 110  0.631171   0.808146
# 111  0.739141   0.808146
# 112  0.776573   0.808146
# 113  0.516237   0.808146
# 114  0.636958   0.808146
# 115  0.704708   0.808146
# 116  0.706783   0.925378
# 117  0.670863   0.925378
# 118  0.925378   0.925378
# 119  0.790753   0.925378

# %%
full_res_lvl2_glm.loc[full_res_lvl2_glm['gene'] == 'ACE2',]
# Out:
#     gene        cell_identity    covariate eval_at      coef    coef_sd  \
# 0   ACE2              Myeloid  sex[T.male]    32yr  0.298059   9.510353
# 1   ACE2              Myeloid  sex[T.male]    62yr  0.288443   9.562100
# 2   ACE2              Myeloid          age       F -0.018231   0.277863
# 3   ACE2              Myeloid          age       M -0.018551   0.389273
# 12  ACE2    Airway epithelium  sex[T.male]    32yr  0.050874   1.500049
# 13  ACE2    Airway epithelium  sex[T.male]    62yr  0.013722   1.404795
# 14  ACE2    Airway epithelium          age       F -0.004533   0.055162
# 15  ACE2    Airway epithelium          age       M -0.005771   0.050994
# 24  ACE2  Alveolar epithelium  sex[T.male]    32yr  0.555897   2.934558
# 25  ACE2  Alveolar epithelium  sex[T.male]    62yr -0.083306   2.588266
# 26  ACE2  Alveolar epithelium          age       F  0.022139   0.092969
# 27  ACE2  Alveolar epithelium          age       M  0.000832   0.089397
# 36  ACE2             Lymphoid  sex[T.male]    32yr -0.214304   1.811011
# 37  ACE2             Lymphoid  sex[T.male]    62yr -0.012280   7.792421
# 38  ACE2             Lymphoid          age       F -0.110693   0.156690
# 39  ACE2             Lymphoid          age       M -0.103959   0.200481
# 48  ACE2   Fibroblast lineage  sex[T.male]    32yr  0.144854   5.406949
# 49  ACE2   Fibroblast lineage  sex[T.male]    62yr  0.107336   5.042307
# 50  ACE2   Fibroblast lineage          age       F -0.007591   0.167858
# 51  ACE2   Fibroblast lineage          age       M -0.008842   0.171606
# 60  ACE2        Blood vessels  sex[T.male]    32yr -0.292769   3.979777
# 61  ACE2        Blood vessels  sex[T.male]    62yr  0.615436   4.091070
# 62  ACE2        Blood vessels          age       F -0.011093   0.120055
# 63  ACE2        Blood vessels          age       M  0.019180   0.131603
# 72  ACE2     Submucosal Gland  sex[T.male]    32yr  0.128038   3.024546
# 73  ACE2     Submucosal Gland  sex[T.male]    62yr -0.273110   3.111551
# 74  ACE2     Submucosal Gland          age       F  0.010867   0.091912
# 75  ACE2     Submucosal Gland          age       M -0.002505   0.092092
# 84  ACE2        Smooth Muscle  sex[T.male]    32yr  1.362052   3.559049
# 85  ACE2        Smooth Muscle  sex[T.male]    62yr  2.003600  15.072656
# 86  ACE2        Smooth Muscle          age       F -0.035123   0.495017
# 87  ACE2        Smooth Muscle          age       M -0.013738   0.107215
# 96  ACE2           Lymphatics  sex[T.male]    32yr  1.204611  14.226441
# 97  ACE2           Lymphatics  sex[T.male]    62yr  1.152026   5.170162
# 98  ACE2           Lymphatics          age       F  0.073182   0.320884
# 99  ACE2           Lymphatics          age       M  0.071430   0.278538
#
#         pval  adj_pvals
# 0   0.974998   0.975935
# 1   0.975935   0.975935
# 2   0.947689   0.975935
# 3   0.961991   0.975935
# 12  0.972945   0.992206
# 13  0.992206   0.992206
# 14  0.934507   0.992206
# 15  0.909889   0.992206
# 24  0.849755   0.992571
# 25  0.974324   0.992571
# 26  0.811776   0.992571
# 27  0.992571   0.992571
# 36  0.905803   0.998743
# 37  0.998743   0.998743
# 38  0.479911   0.998743
# 39  0.604077   0.998743
# 48  0.978627   0.999073
# 49  0.983017   0.999073
# 50  0.963929   0.999073
# 51  0.958909   0.999073
# 60  0.941357   0.941357
# 61  0.880422   0.941357
# 62  0.926379   0.941357
# 63  0.884124   0.941357
# 72  0.966233   0.978300
# 73  0.930057   0.978300
# 74  0.905886   0.978300
# 75  0.978300   0.978300
# 84  0.701941   0.944571
# 85  0.894249   0.944571
# 86  0.943435   0.944571
# 87  0.898041   0.944571
# 96  0.932520   0.983884
# 97  0.823674   0.983884
# 98  0.819596   0.983884
# 99  0.797608   0.983884

# %%
full_res_lvl2_glm.loc[full_res_lvl2_glm['gene'] == 'TMPRSS2',]
# Out:
#         gene        cell_identity    covariate eval_at      coef    coef_sd  \
# 4    TMPRSS2              Myeloid  sex[T.male]    32yr  0.995246   2.152080
# 5    TMPRSS2              Myeloid  sex[T.male]    62yr  0.603703   1.824983
# 6    TMPRSS2              Myeloid          age       F  0.006562   0.048913
# 7    TMPRSS2              Myeloid          age       M -0.006490   0.091134
# 16   TMPRSS2    Airway epithelium  sex[T.male]    32yr  0.256681   0.359212
# 17   TMPRSS2    Airway epithelium  sex[T.male]    62yr  0.195109   0.363213
# 18   TMPRSS2    Airway epithelium          age       F -0.003329   0.012262
# 19   TMPRSS2    Airway epithelium          age       M -0.005381   0.011938
# 64   0.891250   0.941357
# 65   0.938615   0.941357
# 66   0.916912   0.941357
# 67   0.780895   0.941357
# 76   0.708859   0.978300
# 77   0.933814   0.978300
# 78   0.818878   0.978300
# 79   0.801695   0.978300
# 88   0.925213   0.944571
# 89   0.759879   0.944571
# 90   0.891363   0.944571
# 91   0.944571   0.944571
# 100  0.780931   0.983884
# 101  0.587114   0.983884
# 102  0.689611   0.983884
# 103  0.983884   0.983884
# 108  0.761691   0.808146
# 109  0.808146   0.808146
# 110  0.631171   0.808146
# 111  0.739141   0.808146

# %% [markdown]
# # Level 3 annotation

# %%
cluster_key = 'ann_level_3'
clust_tbl = adata.obs[cluster_key].value_counts()
clusters = clust_tbl.index[clust_tbl > 1000]
ct_to_rm = clusters[[ct.startswith('1') or ct.startswith('2') for ct in clusters]]
clusters = clusters.drop(ct_to_rm.tolist()).tolist()
clusters
# Out:
# ['Macrophages',
#  'AT2',
#  'Basal',
#  'T cell lineage',
#  'Monocytes',
#  'Multiciliated lineage',
#  'AT1',
#  'Submucosal Secretory',
#  'Innate lymphoid cells',
#  'Secretory',
#  'Capillary',
#  'Mast cells',
#  'B cell lineage',
#  'Fibroblasts',
#  'Dendritic cells',
#  'Venous',
#  'Lymphatic EC',
#  'Arterial',
#  'Rare',
#  'Myofibroblasts',
#  'MDC',
#  'Airway smooth muscle']

# %%
adata_sub = adata[adata.obs.ann_level_3.isin(clusters),:]

adata_sub
adata_sub.obs.donor.nunique()
adata_sub.obs['sample'].nunique()
# Out:
# View of AnnData object with n_obs × n_vars = 895743 × 3
#     obs: 'age', 'anatomical_region', 'donor', 'last_author/PI', 'lung_vs_nasal', 'notes', 'original_celltype_ann', 'sample', 'sex', 'smoking', 'total_counts', 'smoked_boolean', 'last_author_sample_name', 'ann_level_1', 'ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5', 'ann_highest_res', 'ann_new', 'dataset', 'smoking_status', 'ACE2', 'TMPRSS2', 'CTSL'
# 185
# 309

# %% [markdown]
# ## Generate pseudobulk

# %%
for gene in adata_sub.var_names:
    adata_sub.obs[gene] = adata_sub[:,gene].X.A
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
dat_pseudo_sub = adata_sub.obs.groupby(['donor', 'ann_level_3']).agg({'ACE2':'mean', 'TMPRSS2':'mean', 'CTSL':'mean', 'total_counts':'mean', 'age':'first', 'smoking_status':'first', 'sex':'first', 'dataset':'first'}).dropna().reset_index(level=[0,1])
adata_pseudo_sub = sc.AnnData(dat_pseudo_sub[['ACE2', 'TMPRSS2', 'CTSL']], obs=dat_pseudo_sub.drop(columns=['ACE2', 'TMPRSS2', 'CTSL']))
# Out:
# Transforming to str index.

# %%
adata_pseudo_sub.obs.head()
# Out:
#       donor            ann_level_3  total_counts   age smoking_status     sex  \
# 0  1A1DFBng                    AT1   3709.913265  47.0           True  female
# 1  1A1DFBng                    AT2   4453.519898  47.0           True  female
# 2  1A1DFBng           Lymphatic EC   5503.117647  47.0           True  female
# 3  1A1DFBng              Monocytes   3339.083948  47.0           True  female
# 4  1A1DFBng  Multiciliated lineage   6000.121212  47.0           True  female
#
#                dataset
# 0  Eils/Conrad/Kreuter
# 1  Eils/Conrad/Kreuter
# 2  Eils/Conrad/Kreuter
# 3  Eils/Conrad/Kreuter
# 4  Eils/Conrad/Kreuter

# %%
adata_pseudo_sub.obs['total_counts_scaled'] = adata_pseudo_sub.obs['total_counts']/adata_pseudo_sub.obs['total_counts'].mean()

# %% [markdown]
# ## Poisson GLM

# %% [markdown]
# First check if there are any datasets with only 1 sex or 1 smoking status, which would make the model overparameterized (not full rank).

# %%
np.any(adata_pseudo_tmp.obs.smoking_status.value_counts() == 1)
# Out:
# True

# %%
np.any(pd.crosstab(adata_pseudo_tmp.obs.smoking_status, adata_pseudo_tmp.obs.sex) == 1)
# Out:
# True

# %%
clusters
# Out:
# ['Macrophages',
#  'AT2',
#  'Basal',
#  'T cell lineage',
#  'Monocytes',
#  'Multiciliated lineage',
#  'AT1',
#  'Submucosal Secretory',
#  'Innate lymphoid cells',
#  'Secretory',
#  'Capillary',
#  'Mast cells',
#  'B cell lineage',
#  'Fibroblasts',
#  'Dendritic cells',
#  'Venous',
#  'Lymphatic EC',
#  'Arterial',
#  'Rare',
#  'Myofibroblasts',
#  'MDC',
#  'Airway smooth muscle']

# %%
# Poisson GLM loop
de_results_lvl3_glm = dict()

# Test over clusters
for clust in clusters:
    adata_pseudo_tmp = adata_pseudo_sub[adata_pseudo_sub.obs[cluster_key] == clust,:].copy()

    print(f'In cluster {clust}:')
    print(adata_pseudo_tmp.obs['smoking_status'].value_counts())
    print(adata_pseudo_tmp.obs['sex'].value_counts())

    # Filter out genes to reduce multiple testing burden
    sc.pp.filter_genes(adata_pseudo_tmp, min_cells=4)
    if adata_pseudo_tmp.n_vars == 0:
        print('No genes expressed in more than 10 cells!')
        continue
    if len(adata_pseudo_tmp.obs.sex.value_counts())==1:
        print(f'{clust} only has 1 type of male/female sample.')
        continue
    if np.any(adata_pseudo_tmp.obs.sex.value_counts()==1):
        print(f'{clust} only has 1 male or 1 female sample.')
        continue
        
    print(f'Testing {adata_pseudo_tmp.n_vars} genes...')
    print("")

    # List to store results
    de_results_list = []        

    # Set up design matrix
    dmat = de.utils.design_matrix(
        data=adata_pseudo_tmp,
        formula="~" + formula,
        as_numeric=["age"],
        return_type="patsy"
    )
    
    # Test if model is full rank
    if np.linalg.matrix_rank(np.asarray(dmat[0])) < np.min(dmat[0].shape):
        print(f'Cannot test {clust} as design matrix is not full rank.')
        continue
    
    for i, gene in enumerate(adata_pseudo_tmp.var_names):
        # Specify model
        pois_model = sm.GLM(
            endog=adata_pseudo_tmp.X[:, i],
            exog=dmat[0],
            offset=np.log(adata_pseudo_tmp.obs['total_counts_scaled'].values),
            family=sm.families.Poisson()
        )

        # Fit the model
        pois_results = pois_model.fit()

        # Get the covariance matrix
        cov_mat = pois_results.cov_params()

        # Test over coefs
        for coef in tested_coef:
            iter_coefs = tested_coef.copy()
            iter_coefs.remove(coef)
            
            for c1 in to_test[iter_coefs[0]]:
                coef_vals = {iter_coefs[0]:c1}
                val, stderr, pval = calc_effects(
                    dmat = dmat,
                    cov_mat = cov_mat,
                    params = pois_results.params,
                    effect = coef,
                    coefs = coef_vals)
                
                case = iter_coefs[0]+':'+str(c1)
                case = case.replace('sex[T.male]:0','F').replace('sex[T.male]:1','M')
                case = case.replace('age:32','32yr').replace('age:62','62yr')
                case = case.replace('_',' ')
                
                # Output the results nicely
                de_results_temp = pd.DataFrame({
                    "gene": gene,
                    "cell_identity": clust,
                    "covariate": coef,
                    "eval_at": case,
                    "coef": val,
                    "coef_sd": stderr,                 
                    "pval": pval
                }, index= [clust+"_"+gene+"_"+coef])
                
                de_results_list.append(de_results_temp)
                
    de_results = pd.concat(de_results_list)
    de_results['adj_pvals'] = multipletests(de_results['pval'].tolist(), method='fdr_bh')[1]
    
    # Store the results
    de_results_lvl3_glm[clust] = de_results
    
# Join the dataframes:
full_res_lvl3_glm = pd.concat([de_results_lvl3_glm[i] for i in de_results_lvl3_glm.keys()], ignore_index=True)
# Out:
# In cluster Macrophages:
# False    49
# True     40
# nan      21
# Name: smoking_status, dtype: int64
# male      64
# female    46
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster AT2:
# False    66
# True     38
# nan      14
# Name: smoking_status, dtype: int64
# male      62
# female    56
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Basal:
# False    53
# True     52
# nan       5
# Name: smoking_status, dtype: int64
# male      62
# female    48
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster T cell lineage:
# False    51
# True     46
# nan      21
# Name: smoking_status, dtype: int64
# male      65
# female    53
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Monocytes:
# False    57
# True     39
# nan      11
# Name: smoking_status, dtype: int64
# male      58
# female    49
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Multiciliated lineage:
# False    88
# True     69
# nan      13
# Name: smoking_status, dtype: int64
# male      91
# female    79
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster AT1:
# False    65
# True     36
# nan      14
# Name: smoking_status, dtype: int64
# male      60
# female    55
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Submucosal Secretory:
# False    28
# True     17
# Name: smoking_status, dtype: int64
# male      25
# female    20
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Innate lymphoid cells:
# False    33
# True     23
# nan      15
# Name: smoking_status, dtype: int64
# male      40
# female    31
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
#
# In cluster Secretory:
# False    75
# True     65
# nan      14
# Name: smoking_status, dtype: int64
# male      85
# female    69
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Capillary:
# False    22
# True     12
# nan       9
# Name: smoking_status, dtype: int64
# male      26
# female    17
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Mast cells:
# False    49
# True     39
# nan      19
# Name: smoking_status, dtype: int64
# male      57
# female    50
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
#
# In cluster B cell lineage:
# False    52
# True     38
# nan      15
# Name: smoking_status, dtype: int64
# male      62
# female    43
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Fibroblasts:
# False    31
# True     20
# nan       3
# Name: smoking_status, dtype: int64
# male      33
# female    21
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Dendritic cells:
# False    48
# True     42
# nan      11
# Name: smoking_status, dtype: int64
# male      57
# female    44
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
#
# In cluster Venous:
# False    22
# True     11
# nan       5
# Name: smoking_status, dtype: int64
# male      23
# female    15
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
#
# In cluster Lymphatic EC:
# False    45
# True     31
# nan      13
# Name: smoking_status, dtype: int64
# male      48
# female    41
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Arterial:
# False    25
# True     12
# nan       5
# Name: smoking_status, dtype: int64
# male      27
# female    15
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Rare:
# False    37
# True     34
# Name: smoking_status, dtype: int64
# male      39
# female    32
# Name: sex, dtype: int64
# Testing 3 genes...
#
# In cluster Myofibroblasts:
# False    19
# True     15
# nan      10
# Name: smoking_status, dtype: int64
# male      28
# female    16
# Name: sex, dtype: int64
# filtered out 1 genes that are detected in less than 4 cells
# Testing 2 genes...
#
# In cluster MDC:
# nan    6
# Name: smoking_status, dtype: int64
# female    3
# male      3
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 4 cells
# Testing 1 genes...
#
# In cluster Airway smooth muscle:
# True     7
# False    6
# Name: smoking_status, dtype: int64
# male      9
# female    4
# Name: sex, dtype: int64
# filtered out 2 genes that are detected in less than 4 cells
# Testing 1 genes...

# %% [markdown]
# ## Inspect some results

# %%
de_results_lvl3_glm.keys()
# Out:
# dict_keys(['Macrophages', 'AT2', 'Basal', 'T cell lineage', 'Monocytes', 'Multiciliated lineage', 'AT1', 'Submucosal Secretory', 'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells', 'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous', 'Lymphatic EC', 'Arterial', 'Rare', 'Myofibroblasts', 'MDC', 'Airway smooth muscle'])

# %%
full_res_lvl3_glm
# Out:
#         gene          cell_identity    covariate eval_at       coef  \
# 0       ACE2            Macrophages  sex[T.male]    32yr  -0.218032
# 1       ACE2            Macrophages  sex[T.male]    62yr  -1.553912
# 2       ACE2            Macrophages          age       F   0.016025
# 3       ACE2            Macrophages          age       M  -0.028505
# 4    TMPRSS2            Macrophages  sex[T.male]    32yr  -0.091657
# 5    TMPRSS2            Macrophages  sex[T.male]    62yr  -0.234202
# 6    TMPRSS2            Macrophages          age       F   0.000637
# 7    TMPRSS2            Macrophages          age       M  -0.004114
# 8       CTSL            Macrophages  sex[T.male]    32yr  -0.060452
# 9       CTSL            Macrophages  sex[T.male]    62yr  -0.173228
# 10      CTSL            Macrophages          age       F   0.009017
# 11      CTSL            Macrophages          age       M   0.005258
# 12      ACE2                    AT2  sex[T.male]    32yr   0.687516
# 13      ACE2                    AT2  sex[T.male]    62yr  -0.150136
# 14      ACE2                    AT2          age       F   0.019501
# 15      ACE2                    AT2          age       M  -0.008421
# 16   TMPRSS2                    AT2  sex[T.male]    32yr   0.221455
# 17   TMPRSS2                    AT2  sex[T.male]    62yr   0.156586
# 18   TMPRSS2                    AT2          age       F   0.009491
# 19   TMPRSS2                    AT2          age       M   0.007328
# 20      CTSL                    AT2  sex[T.male]    32yr   0.017552
# 21      CTSL                    AT2  sex[T.male]    62yr   0.046859
# 22      CTSL                    AT2          age       F  -0.006289
# 23      CTSL                    AT2          age       M  -0.005312
# 24      ACE2                  Basal  sex[T.male]    32yr  -0.387014
# 25      ACE2                  Basal  sex[T.male]    62yr   0.544868
# 26      ACE2                  Basal          age       F  -0.030214
# 27      ACE2                  Basal          age       M   0.000849
# 28   TMPRSS2                  Basal  sex[T.male]    32yr   0.454407
# 29   TMPRSS2                  Basal  sex[T.male]    62yr   0.336340
# 30   TMPRSS2                  Basal          age       F   0.014608
# 31   TMPRSS2                  Basal          age       M   0.010672
# 32      CTSL                  Basal  sex[T.male]    32yr  -0.074624
# 33      CTSL                  Basal  sex[T.male]    62yr  -0.140029
# 34      CTSL                  Basal          age       F  -0.006260
# 35      CTSL                  Basal          age       M  -0.008440
# 36      ACE2         T cell lineage  sex[T.male]    32yr   1.971822
# 37      ACE2         T cell lineage  sex[T.male]    62yr   0.674925
# 38      ACE2         T cell lineage          age       F   0.013006
# 39      ACE2         T cell lineage          age       M  -0.030224
# 40   TMPRSS2         T cell lineage  sex[T.male]    32yr   0.039085
# 41   TMPRSS2         T cell lineage  sex[T.male]    62yr   0.635307
# 42   TMPRSS2         T cell lineage          age       F  -0.014854
# 43   TMPRSS2         T cell lineage          age       M   0.005020
# 44      CTSL         T cell lineage  sex[T.male]    32yr  -0.471723
# 45      CTSL         T cell lineage  sex[T.male]    62yr   0.976027
# 46      CTSL         T cell lineage          age       F   0.006375
# 47      CTSL         T cell lineage          age       M   0.054633
# 48      ACE2              Monocytes  sex[T.male]    32yr   0.602664
# 49      ACE2              Monocytes  sex[T.male]    62yr   0.609651
# 50      ACE2              Monocytes          age       F  -0.030539
# 51      ACE2              Monocytes          age       M  -0.030306
# 52   TMPRSS2              Monocytes  sex[T.male]    32yr   1.220256
# 53   TMPRSS2              Monocytes  sex[T.male]    62yr   0.711327
# 54   TMPRSS2              Monocytes          age       F   0.013549
# 55   TMPRSS2              Monocytes          age       M  -0.003416
# 56      CTSL              Monocytes  sex[T.male]    32yr  -0.436163
# 57      CTSL              Monocytes  sex[T.male]    62yr   0.139061
# 58      CTSL              Monocytes          age       F  -0.003501
# 59      CTSL              Monocytes          age       M   0.015673
# 60      ACE2  Multiciliated lineage  sex[T.male]    32yr   0.333117
# 61      ACE2  Multiciliated lineage  sex[T.male]    62yr  -0.177753
# 62      ACE2  Multiciliated lineage          age       F   0.011379
# 63      ACE2  Multiciliated lineage          age       M  -0.005650
# 64   TMPRSS2  Multiciliated lineage  sex[T.male]    32yr   0.115193
# 65   TMPRSS2  Multiciliated lineage  sex[T.male]    62yr   0.003499
# 66   TMPRSS2  Multiciliated lineage          age       F  -0.003483
# 67   TMPRSS2  Multiciliated lineage          age       M  -0.007207
# 68      CTSL  Multiciliated lineage  sex[T.male]    32yr  -0.079760
# 69      CTSL  Multiciliated lineage  sex[T.male]    62yr  -0.017278
# 70      CTSL  Multiciliated lineage          age       F   0.003124
# 71      CTSL  Multiciliated lineage          age       M   0.005207
# 72      ACE2                    AT1  sex[T.male]    32yr   0.403448
# 73      ACE2                    AT1  sex[T.male]    62yr   0.187571
# 74      ACE2                    AT1          age       F   0.001556
# 75      ACE2                    AT1          age       M  -0.005640
# 76   TMPRSS2                    AT1  sex[T.male]    32yr   0.096193
# 77   TMPRSS2                    AT1  sex[T.male]    62yr   0.104185
# 78   TMPRSS2                    AT1          age       F   0.008642
# 79   TMPRSS2                    AT1          age       M   0.008909
# 80      CTSL                    AT1  sex[T.male]    32yr   0.146576
# 81      CTSL                    AT1  sex[T.male]    62yr   0.165556
# 82      CTSL                    AT1          age       F   0.003110
# 83      CTSL                    AT1          age       M   0.003743
# 84      ACE2   Submucosal Secretory  sex[T.male]    32yr   0.128038
# 85      ACE2   Submucosal Secretory  sex[T.male]    62yr  -0.273110
# 86      ACE2   Submucosal Secretory          age       F   0.010867
# 87      ACE2   Submucosal Secretory          age       M  -0.002505
# 88   TMPRSS2   Submucosal Secretory  sex[T.male]    32yr   0.277254
# 89   TMPRSS2   Submucosal Secretory  sex[T.male]    62yr  -0.066143
# 90   TMPRSS2   Submucosal Secretory          age       F   0.005732
# 91   TMPRSS2   Submucosal Secretory          age       M  -0.005715
# 92      CTSL   Submucosal Secretory  sex[T.male]    32yr  -0.149420
# 93      CTSL   Submucosal Secretory  sex[T.male]    62yr   0.016246
# 94      CTSL   Submucosal Secretory          age       F  -0.001399
# 95      CTSL   Submucosal Secretory          age       M   0.004123
# 96   TMPRSS2  Innate lymphoid cells  sex[T.male]    32yr  -0.169476
# 97   TMPRSS2  Innate lymphoid cells  sex[T.male]    62yr  -0.753809
# 98   TMPRSS2  Innate lymphoid cells          age       F   0.024682
# 99   TMPRSS2  Innate lymphoid cells          age       M   0.005204
# 100     CTSL  Innate lymphoid cells  sex[T.male]    32yr  -0.206251
# 101     CTSL  Innate lymphoid cells  sex[T.male]    62yr   0.521453
# 102     CTSL  Innate lymphoid cells          age       F   0.018111
# 103     CTSL  Innate lymphoid cells          age       M   0.042368
# 104     ACE2              Secretory  sex[T.male]    32yr   0.119627
# 105     ACE2              Secretory  sex[T.male]    62yr  -0.076385
# 106     ACE2              Secretory          age       F  -0.005733
# 107     ACE2              Secretory          age       M  -0.012267
# 108  TMPRSS2              Secretory  sex[T.male]    32yr   0.274832
# 109  TMPRSS2              Secretory  sex[T.male]    62yr   0.435093
# 110  TMPRSS2              Secretory          age       F  -0.009072
# 111  TMPRSS2              Secretory          age       M  -0.003730
# 112     CTSL              Secretory  sex[T.male]    32yr  -0.011946
# 113     CTSL              Secretory  sex[T.male]    62yr  -0.067009
# 114     CTSL              Secretory          age       F  -0.000194
# 115     CTSL              Secretory          age       M  -0.002030
# 116     ACE2              Capillary  sex[T.male]    32yr  27.636423
# 117     ACE2              Capillary  sex[T.male]    62yr  -0.973680
# 118     ACE2              Capillary          age       F   0.901455
# 119     ACE2              Capillary          age       M  -0.052216
# 120  TMPRSS2              Capillary  sex[T.male]    32yr  -2.618132
# 121  TMPRSS2              Capillary  sex[T.male]    62yr   0.617157
# 122  TMPRSS2              Capillary          age       F  -0.010290
# 123  TMPRSS2              Capillary          age       M   0.097553
# 124     CTSL              Capillary  sex[T.male]    32yr   0.021401
# 125     CTSL              Capillary  sex[T.male]    62yr   0.003902
# 126     CTSL              Capillary          age       F  -0.002315
# 127     CTSL              Capillary          age       M  -0.002898
# 128  TMPRSS2             Mast cells  sex[T.male]    32yr   3.852097
# 129  TMPRSS2             Mast cells  sex[T.male]    62yr   0.420690
# 130  TMPRSS2             Mast cells          age       F   0.086379
# 131  TMPRSS2             Mast cells          age       M  -0.028001
# 132     CTSL             Mast cells  sex[T.male]    32yr   0.478396
# 133     CTSL             Mast cells  sex[T.male]    62yr   0.486492
# 134     CTSL             Mast cells          age       F   0.014394
# 135     CTSL             Mast cells          age       M   0.014664
# 136     ACE2         B cell lineage  sex[T.male]    32yr  -2.557836
# 137     ACE2         B cell lineage  sex[T.male]    62yr  -1.155489
# 138     ACE2         B cell lineage          age       F   0.024900
# 139     ACE2         B cell lineage          age       M   0.071645
# 140  TMPRSS2         B cell lineage  sex[T.male]    32yr   1.520007
# 141  TMPRSS2         B cell lineage  sex[T.male]    62yr   0.045502
# 142  TMPRSS2         B cell lineage          age       F   0.047972
# 143  TMPRSS2         B cell lineage          age       M  -0.001178
# 144     CTSL         B cell lineage  sex[T.male]    32yr  -0.349743
# 145     CTSL         B cell lineage  sex[T.male]    62yr  -0.119654
# 146     CTSL         B cell lineage          age       F   0.011979
# 147     CTSL         B cell lineage          age       M   0.019648
# 148     ACE2            Fibroblasts  sex[T.male]    32yr   0.293152
# 149     ACE2            Fibroblasts  sex[T.male]    62yr  -0.175068
# 150     ACE2            Fibroblasts          age       F   0.000520
# 151     ACE2            Fibroblasts          age       M  -0.015088
# 152  TMPRSS2            Fibroblasts  sex[T.male]    32yr   0.172188
# 153  TMPRSS2            Fibroblasts  sex[T.male]    62yr  -1.220810
# 154  TMPRSS2            Fibroblasts          age       F   0.008274
# 155  TMPRSS2            Fibroblasts          age       M  -0.038159
# 156     CTSL            Fibroblasts  sex[T.male]    32yr   0.123828
# 157     CTSL            Fibroblasts  sex[T.male]    62yr   0.965308
# 158     CTSL            Fibroblasts          age       F  -0.022676
# 159     CTSL            Fibroblasts          age       M   0.005373
# 160  TMPRSS2        Dendritic cells  sex[T.male]    32yr   0.311453
# 161  TMPRSS2        Dendritic cells  sex[T.male]    62yr   0.943110
# 162  TMPRSS2        Dendritic cells          age       F  -0.015434
# 163  TMPRSS2        Dendritic cells          age       M   0.005621
# 164     CTSL        Dendritic cells  sex[T.male]    32yr  -0.796808
# 165     CTSL        Dendritic cells  sex[T.male]    62yr  -0.318161
# 166     CTSL        Dendritic cells          age       F   0.010573
# 167     CTSL        Dendritic cells          age       M   0.026528
# 168  TMPRSS2                 Venous  sex[T.male]    32yr  -0.169161
# 169  TMPRSS2                 Venous  sex[T.male]    62yr   0.949148
# 170  TMPRSS2                 Venous          age       F  -0.000139
# 171  TMPRSS2                 Venous          age       M   0.037138
# 172     CTSL                 Venous  sex[T.male]    32yr   0.092458
# 173     CTSL                 Venous  sex[T.male]    62yr  -0.029888
# 174     CTSL                 Venous          age       F   0.004508
# 175     CTSL                 Venous          age       M   0.000430
# 176     ACE2           Lymphatic EC  sex[T.male]    32yr   1.204611
# 177     ACE2           Lymphatic EC  sex[T.male]    62yr   1.152026
# 178     ACE2           Lymphatic EC          age       F   0.073182
# 179     ACE2           Lymphatic EC          age       M   0.071430
# 180  TMPRSS2           Lymphatic EC  sex[T.male]    32yr   0.368787
# 181  TMPRSS2           Lymphatic EC  sex[T.male]    62yr   0.736776
# 182  TMPRSS2           Lymphatic EC          age       F  -0.013524
# 183  TMPRSS2           Lymphatic EC          age       M  -0.001258
# 184     CTSL           Lymphatic EC  sex[T.male]    32yr   0.132785
# 185     CTSL           Lymphatic EC  sex[T.male]    62yr   0.074843
# 186     CTSL           Lymphatic EC          age       F   0.003059
# 187     CTSL           Lymphatic EC          age       M   0.001128
# 188     ACE2               Arterial  sex[T.male]    32yr   0.518808
# 189     ACE2               Arterial  sex[T.male]    62yr   2.770708
# 190     ACE2               Arterial          age       F  -0.039202
# 191     ACE2               Arterial          age       M   0.035861
# 192  TMPRSS2               Arterial  sex[T.male]    32yr   0.920991
# 193  TMPRSS2               Arterial  sex[T.male]    62yr   0.842215
# 194  TMPRSS2               Arterial          age       F   0.037248
# 195  TMPRSS2               Arterial          age       M   0.034622
# 196     CTSL               Arterial  sex[T.male]    32yr  -0.517536
# 197     CTSL               Arterial  sex[T.male]    62yr   0.127125
# 198     CTSL               Arterial          age       F   0.010714
# 199     CTSL               Arterial          age       M   0.032203
# 200     ACE2                   Rare  sex[T.male]    32yr  -0.777405
# 201     ACE2                   Rare  sex[T.male]    62yr   1.314525
# 202     ACE2                   Rare          age       F  -0.052219
# 203     ACE2                   Rare          age       M   0.017512
# 204  TMPRSS2                   Rare  sex[T.male]    32yr   0.503308
# 205  TMPRSS2                   Rare  sex[T.male]    62yr  -0.680552
# 206  TMPRSS2                   Rare          age       F   0.013208
# 207  TMPRSS2                   Rare          age       M  -0.026254
# 208     CTSL                   Rare  sex[T.male]    32yr  -0.490628
# 87   ACE2   Submucosal Secretory          age       M  -0.002505     0.092092
# 104  ACE2              Secretory  sex[T.male]    32yr   0.119627     1.168632
# 105  ACE2              Secretory  sex[T.male]    62yr  -0.076385     1.004646
# 106  ACE2              Secretory          age       F  -0.005733     0.041389
# 107  ACE2              Secretory          age       M  -0.012267     0.037422
# 116  ACE2              Capillary  sex[T.male]    32yr  27.636423  5389.977902
# 117  ACE2              Capillary  sex[T.male]    62yr  -0.973680  5358.383494
# 118  ACE2              Capillary          age       F   0.901455    23.953395
# 119  ACE2              Capillary          age       M  -0.052216     1.709379
# 136  ACE2         B cell lineage  sex[T.male]    32yr  -2.557836    31.524836
# 137  ACE2         B cell lineage  sex[T.male]    62yr  -1.155489    14.465917
# 138  ACE2         B cell lineage          age       F   0.024900     0.361244
# 139  ACE2         B cell lineage          age       M   0.071645     1.098857
# 148  ACE2            Fibroblasts  sex[T.male]    32yr   0.293152     6.451375
# 149  ACE2            Fibroblasts  sex[T.male]    62yr  -0.175068     9.838852
# 150  ACE2            Fibroblasts          age       F   0.000520     0.256562
# 151  ACE2            Fibroblasts          age       M  -0.015088     0.193656
# 176  ACE2           Lymphatic EC  sex[T.male]    32yr   1.204611    14.226441
# 177  ACE2           Lymphatic EC  sex[T.male]    62yr   1.152026     5.170162
# 178  ACE2           Lymphatic EC          age       F   0.073182     0.320884
# 179  ACE2           Lymphatic EC          age       M   0.071430     0.278538
# 188  ACE2               Arterial  sex[T.male]    32yr   0.518808     2.193517
# 189  ACE2               Arterial  sex[T.male]    62yr   2.770708     3.233818
# 190  ACE2               Arterial          age       F  -0.039202     0.106569
# 191  ACE2               Arterial          age       M   0.035861     0.038926
# 200  ACE2                   Rare  sex[T.male]    32yr  -0.777405     7.958583
# 201  ACE2                   Rare  sex[T.male]    62yr   1.314525     4.973534
# 202  ACE2                   Rare          age       F  -0.052219     0.287001
# 203  ACE2                   Rare          age       M   0.017512     0.191211
#
#          pval  adj_pvals
# 0    0.986504   0.994505
# 1    0.900478   0.994505
# 2    0.963335   0.994505
# 3    0.952366   0.994505
# 12   0.794517   0.972298
# 13   0.951234   0.972298
# 14   0.821430   0.972298
# 15   0.912635   0.972298
# 24   0.865373   0.959020
# 25   0.783606   0.959020
# 26   0.665835   0.959020
# 27   0.991190   0.991190
# 36   0.886849   0.989101
# 37   0.954747   0.989101
# 38   0.967663   0.989101
# 39   0.959792   0.989101
# 48   0.964998   0.975220
# 49   0.965199   0.975220
# 50   0.938160   0.975220
# 51   0.963648   0.975220
# 60   0.850496   0.991213
# 61   0.915787   0.991213
# 62   0.854847   0.991213
# 63   0.918639   0.991213
# 72   0.930218   0.990950
# 73   0.966195   0.990950
# 74   0.990950   0.990950
# 75   0.970908   0.990950
# 84   0.966233   0.978300
# 85   0.930057   0.978300
# 86   0.905886   0.978300
# 87   0.978300   0.978300
# 104  0.918467   0.990202
# 105  0.939394   0.990202
# 106  0.889836   0.990202
# 107  0.743071   0.990202
# 116  0.995909   0.999855
# 117  0.999855   0.999855
# 118  0.969980   0.999855
# 119  0.975631   0.999855
# 136  0.935333   0.992435
# 137  0.936335   0.992435
# 138  0.945045   0.992435
# 139  0.948015   0.992435
# 148  0.963756   0.998384
# 149  0.985804   0.998384
# 150  0.998384   0.998384
# 151  0.937900   0.998384
# 176  0.932520   0.983884
# 177  0.823674   0.983884
# 178  0.819596   0.983884
# 179  0.797608   0.983884
# 188  0.813030   0.856452
# 189  0.391560   0.856452
# 190  0.712978   0.856452
# 191  0.356912   0.856452
# 200  0.922185   0.927030
# 201  0.791546   0.927030
# 202  0.855624   0.927030
# 203  0.927030   0.927030

# %%
full_res_lvl3_glm.loc[full_res_lvl3_glm['gene'] == 'TMPRSS2',]
# Out:
#         gene          cell_identity    covariate eval_at      coef    coef_sd  \
# 4    TMPRSS2            Macrophages  sex[T.male]    32yr -0.091657   3.270424
# 5    TMPRSS2            Macrophages  sex[T.male]    62yr -0.234202   2.856403
# 6    TMPRSS2            Macrophages          age       F  0.000637   0.092524
# 7    TMPRSS2            Macrophages          age       M -0.004114   0.113119
# 16   TMPRSS2                    AT2  sex[T.male]    32yr  0.221455   0.276070
# 17   TMPRSS2                    AT2  sex[T.male]    62yr  0.156586   0.281139
# 18   TMPRSS2                    AT2          age       F  0.009491   0.008997
# 19   TMPRSS2                    AT2          age       M  0.007328   0.008778
# 28   TMPRSS2                  Basal  sex[T.male]    32yr  0.454407   0.877209
# 29   TMPRSS2                  Basal  sex[T.male]    62yr  0.336340   0.678193
# 30   TMPRSS2                  Basal          age       F  0.014608   0.030414
# 31   TMPRSS2                  Basal          age       M  0.010672   0.021987
# 40   TMPRSS2         T cell lineage  sex[T.male]    32yr  0.039085   2.861205
# 41   TMPRSS2         T cell lineage  sex[T.male]    62yr  0.635307   3.096292
# 42   TMPRSS2         T cell lineage          age       F -0.014854   0.031886
# 43   TMPRSS2         T cell lineage          age       M  0.005020   0.189212
# 52   TMPRSS2              Monocytes  sex[T.male]    32yr  1.220256   2.372595
# 53   TMPRSS2              Monocytes  sex[T.male]    62yr  0.711327   2.136567
# 54   TMPRSS2              Monocytes          age       F  0.013549   0.051532
# 55   TMPRSS2              Monocytes          age       M -0.003416   0.109961
# 64   TMPRSS2  Multiciliated lineage  sex[T.male]    32yr  0.115193   0.346455
# 65   TMPRSS2  Multiciliated lineage  sex[T.male]    62yr  0.003499   0.317747
# 66   TMPRSS2  Multiciliated lineage          age       F -0.003483   0.011405
# 67   TMPRSS2  Multiciliated lineage          age       M -0.007207   0.010600
# 76   TMPRSS2                    AT1  sex[T.male]    32yr  0.096193   0.360111
# 77   TMPRSS2                    AT1  sex[T.male]    62yr  0.104185   0.379171
# 78   TMPRSS2                    AT1          age       F  0.008642   0.011788
# 79   TMPRSS2                    AT1          age       M  0.008909   0.012872
# 88   TMPRSS2   Submucosal Secretory  sex[T.male]    32yr  0.277254   0.742534
# 89   TMPRSS2   Submucosal Secretory  sex[T.male]    62yr -0.066143   0.796453
# 90   TMPRSS2   Submucosal Secretory          age       F  0.005732   0.025030
# 91   TMPRSS2   Submucosal Secretory          age       M -0.005715   0.022755
# 96   TMPRSS2  Innate lymphoid cells  sex[T.male]    32yr -0.169476   8.245100
# 97   TMPRSS2  Innate lymphoid cells  sex[T.male]    62yr -0.753809   6.667150
# 98   TMPRSS2  Innate lymphoid cells          age       F  0.024682   0.202812
# 99   TMPRSS2  Innate lymphoid cells          age       M  0.005204   0.266226
# 108  TMPRSS2              Secretory  sex[T.male]    32yr  0.274832   0.305901
# 109  TMPRSS2              Secretory  sex[T.male]    62yr  0.435093   0.294199
# 110  TMPRSS2              Secretory          age       F -0.009072   0.009991
# 111  TMPRSS2              Secretory          age       M -0.003730   0.009662
# 120  TMPRSS2              Capillary  sex[T.male]    32yr -2.618132  11.082137
# 121  TMPRSS2              Capillary  sex[T.male]    62yr  0.617157   5.565873
# 122  TMPRSS2              Capillary          age       F -0.010290   0.150377
# 123  TMPRSS2              Capillary          age       M  0.097553   0.341195
# 128  TMPRSS2             Mast cells  sex[T.male]    32yr  3.852097  19.516430
# 129  TMPRSS2             Mast cells  sex[T.male]    62yr  0.420690   7.929744
# 130  TMPRSS2             Mast cells          age       F  0.086379   0.517598
# 131  TMPRSS2             Mast cells          age       M -0.028001   0.166731
# 140  TMPRSS2         B cell lineage  sex[T.male]    32yr  1.520007   5.221168
# 141  TMPRSS2         B cell lineage  sex[T.male]    62yr  0.045502   2.747002
# 142  TMPRSS2         B cell lineage          age       F  0.047972   0.135932
# 143  TMPRSS2         B cell lineage          age       M -0.001178   0.124220
# 152  TMPRSS2            Fibroblasts  sex[T.male]    32yr  0.172188   9.074508
# 153  TMPRSS2            Fibroblasts  sex[T.male]    62yr -1.220810  10.601923
# 154  TMPRSS2            Fibroblasts          age       F  0.008274   0.363555
# 155  TMPRSS2            Fibroblasts          age       M -0.038159   0.218857
# 160  TMPRSS2        Dendritic cells  sex[T.male]    32yr  0.311453   3.596942
# 161  TMPRSS2        Dendritic cells  sex[T.male]    62yr  0.943110   3.969448
# 162  TMPRSS2        Dendritic cells          age       F -0.015434   0.130782
# 163  TMPRSS2        Dendritic cells          age       M  0.005621   0.122609
# 168  TMPRSS2                 Venous  sex[T.male]    32yr -0.169161   7.651259
# 169  TMPRSS2                 Venous  sex[T.male]    62yr  0.949148   4.716629
# 170  TMPRSS2                 Venous          age       F -0.000139   0.181152
# 171  TMPRSS2                 Venous          age       M  0.037138   0.203105
# 180  TMPRSS2           Lymphatic EC  sex[T.male]    32yr  0.368787   1.326066
# 181  TMPRSS2           Lymphatic EC  sex[T.male]    62yr  0.736776   1.356804
# 182  TMPRSS2           Lymphatic EC          age       F -0.013524   0.033863
# 183  TMPRSS2           Lymphatic EC          age       M -0.001258   0.062283
# 192  TMPRSS2               Arterial  sex[T.male]    32yr  0.920991   3.768611
# 193  TMPRSS2               Arterial  sex[T.male]    62yr  0.842215   2.000286
# 194  TMPRSS2               Arterial          age       F  0.037248   0.103229
