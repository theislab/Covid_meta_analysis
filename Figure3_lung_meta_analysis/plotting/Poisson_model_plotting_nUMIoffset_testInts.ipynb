# %% [markdown]
# This notebook contains the plotting functions used to plot the results of the meta-analysis with interaction terms on the full data without modeling smoking associations (Supplementary Figures 9,10).

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors, patches
import seaborn as sns
import logging, warnings
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

output_folder = 'diffxpy_out/'

base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm'

# %%
res_lvl2 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_summary.csv', index_col=0)
res_lvl2_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl2_full.csv', index_col=0)

# %%
res_lvl3 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_summary.csv', index_col=0)
res_lvl3_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl3_full.csv', index_col=0)

# %%
res_lvl3.head()
# Out:
#       gene cell_identity    covariate eval_at      coef   coef_sd      pval  \
# 0     ACE2   Macrophages  sex[T.male]    32yr  0.930120  0.334093  0.005369
# 1     ACE2   Macrophages  sex[T.male]    62yr -0.201575  0.272548  0.459546
# 2     ACE2   Macrophages          age       F  0.028696  0.010247  0.005104
# 3     ACE2   Macrophages          age       M -0.009027  0.009343  0.333958
# 4  TMPRSS2   Macrophages  sex[T.male]    32yr -0.101809  0.080804  0.207686
#
#    adj_pvals
# 0   0.010738
# 1   0.551455
# 2   0.010738
# 3   0.445277
# 4   0.356032

# %%
res_lvl3.dtypes
# Out:
# gene              object
# cell_identity     object
# covariate         object
# eval_at           object
# coef             float64
# coef_sd          float64
# pval             float64
# adj_pvals        float64
# dtype: object

# %% [markdown]
# # Plotting

# %%
sns.set(font_scale=2.5, style='white')

# %% [markdown]
# ## Level 3

# %%
res_lvl3['cell_identity'].unique()
# Out:
# array(['Macrophages', 'AT2', 'Basal', 'T cell lineage', 'Monocytes',
#        'Multiciliated lineage', 'AT1', 'Submucosal Secretory',
#        'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells',
#        'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous',
#        'Lymphatic EC', 'Arterial', 'Rare', 'Myofibroblasts', 'MDC',
#        'Airway smooth muscle'], dtype=object)

# %%
# Prep plotting

# Order cell identity category
res_lvl3['cell_identity'] = res_lvl3['cell_identity'].astype('category').cat.set_categories(['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2', 'Arterial', 'Capillary', 'Venous', 'Lymphatic EC', 'Fibroblasts', 'Myofibroblasts', 'Airway smooth muscle', 'B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'MDC', 'Mast cells'], ordered=True)
res_lvl3 = res_lvl3.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2'], 'Endothelial':['Arterial', 'Capillary', 'Venous', 'Lymphatic EC'], 'Stroma':['Fibroblasts', 'Myofibroblasts', 'Airway smooth muscle'], 'Immune':['B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'MDC', 'Mast cells']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl3['compartment'] = [ct_mapping_up[ct] for ct in res_lvl3['cell_identity']]        

# Check if bulk and sc effect directions agree
res_lvl3_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl3_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl3[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl3['coef'].loc[res_lvl3.index[i]]* res_lvl3_pseudo['coef'].loc[res_lvl3.index[i]]) > 0) for i,val in enumerate(res_lvl3['adj_pvals'])]


res_lvl3['compartment'] = res_lvl3['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl3['covariate_simple'] = res_lvl3['covariate'].astype('category').cat.rename_categories(['Age', 'Sex'])

# Assign eval_at numbers
res_lvl3 = res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])

eval_encoding = {
    'age':{'F':0, 'M':1},
    'sex[T.male]':{'32yr':0, '62yr':1}
}

res_lvl3['eval_num'] = [eval_encoding[res_lvl3['covariate'].loc[idx]][res_lvl3['eval_at'].loc[idx]] 
                        for idx in res_lvl3.index]

res_lvl3['gene_eval'] = [' '.join([i,str(j)]) for i,j in zip(res_lvl3['gene'], res_lvl3['eval_num'])]

# %%
res_lvl3
# Out:
#                                                    gene  \
# Basal_age_ACE2_F                                   ACE2
# Basal_age_ACE2_M                                   ACE2
# Basal_age_CTSL_M                                   CTSL
# Basal_age_CTSL_F                                   CTSL
# Basal_age_TMPRSS2_F                             TMPRSS2
# Basal_age_TMPRSS2_M                             TMPRSS2
# Basal_sex[T.male]_ACE2_62yr                        ACE2
# Basal_sex[T.male]_ACE2_32yr                        ACE2
# Basal_sex[T.male]_CTSL_32yr                        CTSL
# Basal_sex[T.male]_CTSL_62yr                        CTSL
# Basal_sex[T.male]_TMPRSS2_32yr                  TMPRSS2
# Basal_sex[T.male]_TMPRSS2_62yr                  TMPRSS2
# Multiciliated_lineage_age_ACE2_F                   ACE2
# Multiciliated_lineage_age_ACE2_M                   ACE2
# Multiciliated_lineage_age_CTSL_M                   CTSL
# Multiciliated_lineage_age_CTSL_F                   CTSL
# Multiciliated_lineage_age_TMPRSS2_F             TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_M             TMPRSS2
# Multiciliated_lineage_sex[T.male]_ACE2_32yr        ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_62yr        ACE2
# Multiciliated_lineage_sex[T.male]_CTSL_32yr        CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_62yr        CTSL
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  TMPRSS2
# Secretory_age_ACE2_F                               ACE2
# Secretory_age_ACE2_M                               ACE2
# Secretory_age_CTSL_F                               CTSL
# Secretory_age_CTSL_M                               CTSL
# Secretory_age_TMPRSS2_F                         TMPRSS2
# Secretory_age_TMPRSS2_M                         TMPRSS2
# Secretory_sex[T.male]_ACE2_32yr                    ACE2
# Secretory_sex[T.male]_ACE2_62yr                    ACE2
# Secretory_sex[T.male]_CTSL_32yr                    CTSL
# Secretory_sex[T.male]_CTSL_62yr                    CTSL
# Secretory_sex[T.male]_TMPRSS2_62yr              TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_32yr              TMPRSS2
# Rare_age_ACE2_F                                    ACE2
# Rare_age_ACE2_M                                    ACE2
# Rare_age_CTSL_F                                    CTSL
# Rare_age_CTSL_M                                    CTSL
# Rare_age_TMPRSS2_M                              TMPRSS2
# Rare_age_TMPRSS2_F                              TMPRSS2
# Rare_sex[T.male]_ACE2_62yr                         ACE2
# Rare_sex[T.male]_ACE2_32yr                         ACE2
# Rare_sex[T.male]_CTSL_32yr                         CTSL
# Rare_sex[T.male]_CTSL_62yr                         CTSL
# Rare_sex[T.male]_TMPRSS2_32yr                   TMPRSS2
# Rare_sex[T.male]_TMPRSS2_62yr                   TMPRSS2
# Submucosal_Secretory_age_ACE2_F                    ACE2
# Submucosal_Secretory_age_ACE2_M                    ACE2
# Submucosal_Secretory_age_CTSL_F                    CTSL
# Submucosal_Secretory_age_CTSL_M                    CTSL
# Submucosal_Secretory_age_TMPRSS2_F              TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_M              TMPRSS2
# Submucosal_Secretory_sex[T.male]_ACE2_62yr         ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_32yr         ACE2
# Submucosal_Secretory_sex[T.male]_CTSL_32yr         CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_62yr         CTSL
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr   TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr   TMPRSS2
# AT1_age_ACE2_F                                     ACE2
# AT1_age_ACE2_M                                     ACE2
# AT1_age_CTSL_M                                     CTSL
# AT1_age_CTSL_F                                     CTSL
# AT1_age_TMPRSS2_F                               TMPRSS2
# AT1_age_TMPRSS2_M                               TMPRSS2
# AT1_sex[T.male]_ACE2_62yr                          ACE2
# AT1_sex[T.male]_ACE2_32yr                          ACE2
# AT1_sex[T.male]_CTSL_32yr                          CTSL
# AT1_sex[T.male]_CTSL_62yr                          CTSL
# AT1_sex[T.male]_TMPRSS2_32yr                    TMPRSS2
# AT1_sex[T.male]_TMPRSS2_62yr                    TMPRSS2
# AT2_age_ACE2_F                                     ACE2
# AT2_age_ACE2_M                                     ACE2
# AT2_age_CTSL_F                                     CTSL
# AT2_age_CTSL_M                                     CTSL
# AT2_age_TMPRSS2_F                               TMPRSS2
# AT2_age_TMPRSS2_M                               TMPRSS2
# AT2_sex[T.male]_ACE2_62yr                          ACE2
# AT2_sex[T.male]_ACE2_32yr                          ACE2
# AT2_sex[T.male]_CTSL_32yr                          CTSL
# AT2_sex[T.male]_CTSL_62yr                          CTSL
# AT2_sex[T.male]_TMPRSS2_62yr                    TMPRSS2
# AT2_sex[T.male]_TMPRSS2_32yr                    TMPRSS2
# Arterial_age_CTSL_M                                CTSL
# Arterial_age_CTSL_F                                CTSL
# Arterial_age_TMPRSS2_M                          TMPRSS2
# Arterial_age_TMPRSS2_F                          TMPRSS2
# Arterial_sex[T.male]_CTSL_62yr                     CTSL
# Arterial_sex[T.male]_CTSL_32yr                     CTSL
# Arterial_sex[T.male]_TMPRSS2_62yr               TMPRSS2
# Arterial_sex[T.male]_TMPRSS2_32yr               TMPRSS2
# Capillary_age_ACE2_M                               ACE2
# Capillary_age_ACE2_F                               ACE2
# Capillary_age_CTSL_F                               CTSL
# Capillary_age_CTSL_M                               CTSL
# Capillary_age_TMPRSS2_M                         TMPRSS2
# Capillary_age_TMPRSS2_F                         TMPRSS2
# Capillary_sex[T.male]_ACE2_32yr                    ACE2
# Capillary_sex[T.male]_ACE2_62yr                    ACE2
# Capillary_sex[T.male]_CTSL_32yr                    CTSL
# Capillary_sex[T.male]_CTSL_62yr                    CTSL
# Capillary_sex[T.male]_TMPRSS2_62yr              TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_32yr              TMPRSS2
# Venous_age_CTSL_M                                  CTSL
# Venous_age_CTSL_F                                  CTSL
# Venous_age_TMPRSS2_M                            TMPRSS2
# Venous_age_TMPRSS2_F                            TMPRSS2
# Venous_sex[T.male]_CTSL_62yr                       CTSL
# Venous_sex[T.male]_CTSL_32yr                       CTSL
# Venous_sex[T.male]_TMPRSS2_62yr                 TMPRSS2
# Venous_sex[T.male]_TMPRSS2_32yr                 TMPRSS2
# Lymphatic_EC_age_ACE2_F                            ACE2
# Lymphatic_EC_age_ACE2_M                            ACE2
# Lymphatic_EC_age_CTSL_F                            CTSL
# Lymphatic_EC_age_CTSL_M                            CTSL
# Lymphatic_EC_age_TMPRSS2_M                      TMPRSS2
# Lymphatic_EC_age_TMPRSS2_F                      TMPRSS2
# Lymphatic_EC_sex[T.male]_ACE2_32yr                 ACE2
# Lymphatic_EC_sex[T.male]_ACE2_62yr                 ACE2
# Lymphatic_EC_sex[T.male]_CTSL_32yr                 CTSL
# Lymphatic_EC_sex[T.male]_CTSL_62yr                 CTSL
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr           TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr           TMPRSS2
# Fibroblasts_age_ACE2_F                             ACE2
# Fibroblasts_age_ACE2_M                             ACE2
# Fibroblasts_age_CTSL_F                             CTSL
# Fibroblasts_age_CTSL_M                             CTSL
# Fibroblasts_age_TMPRSS2_F                       TMPRSS2
# Fibroblasts_age_TMPRSS2_M                       TMPRSS2
# Fibroblasts_sex[T.male]_ACE2_32yr                  ACE2
# Fibroblasts_sex[T.male]_ACE2_62yr                  ACE2
# Fibroblasts_sex[T.male]_CTSL_32yr                  CTSL
# Fibroblasts_sex[T.male]_CTSL_62yr                  CTSL
# Fibroblasts_sex[T.male]_TMPRSS2_32yr            TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_62yr            TMPRSS2
# Myofibroblasts_age_CTSL_M                          CTSL
# Myofibroblasts_age_CTSL_F                          CTSL
# Myofibroblasts_age_TMPRSS2_F                    TMPRSS2
# Myofibroblasts_age_TMPRSS2_M                    TMPRSS2
# Myofibroblasts_sex[T.male]_CTSL_62yr               CTSL
# Myofibroblasts_sex[T.male]_CTSL_32yr               CTSL
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr         TMPRSS2
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr         TMPRSS2
# Airway_smooth_muscle_age_CTSL_M                    CTSL
# Airway_smooth_muscle_age_CTSL_F                    CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr         CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr         CTSL
# B_cell_lineage_age_CTSL_M                          CTSL
# B_cell_lineage_age_CTSL_F                          CTSL
# B_cell_lineage_age_TMPRSS2_M                    TMPRSS2
# B_cell_lineage_age_TMPRSS2_F                    TMPRSS2
# B_cell_lineage_sex[T.male]_CTSL_32yr               CTSL
# B_cell_lineage_sex[T.male]_CTSL_62yr               CTSL
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2
# T_cell_lineage_age_ACE2_M                          ACE2
# T_cell_lineage_age_ACE2_F                          ACE2
# T_cell_lineage_age_CTSL_F                          CTSL
# T_cell_lineage_age_CTSL_M                          CTSL
# T_cell_lineage_age_TMPRSS2_M                    TMPRSS2
# T_cell_lineage_age_TMPRSS2_F                    TMPRSS2
# T_cell_lineage_sex[T.male]_ACE2_62yr               ACE2
# T_cell_lineage_sex[T.male]_ACE2_32yr               ACE2
# T_cell_lineage_sex[T.male]_CTSL_62yr               CTSL
# T_cell_lineage_sex[T.male]_CTSL_32yr               CTSL
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2
# Innate_lymphoid_cells_age_CTSL_F                   CTSL
# Innate_lymphoid_cells_age_CTSL_M                   CTSL
# Innate_lymphoid_cells_age_TMPRSS2_M             TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_F             TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr        CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr        CTSL
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  TMPRSS2
# Dendritic_cells_age_CTSL_F                         CTSL
# Dendritic_cells_age_CTSL_M                         CTSL
# Dendritic_cells_age_TMPRSS2_F                   TMPRSS2
# Dendritic_cells_age_TMPRSS2_M                   TMPRSS2
# Dendritic_cells_sex[T.male]_CTSL_32yr              CTSL
# Dendritic_cells_sex[T.male]_CTSL_62yr              CTSL
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr        TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr        TMPRSS2
# Macrophages_age_ACE2_F                             ACE2
# Macrophages_age_ACE2_M                             ACE2
# Macrophages_age_CTSL_F                             CTSL
# Macrophages_age_CTSL_M                             CTSL
# Macrophages_age_TMPRSS2_M                       TMPRSS2
# Macrophages_age_TMPRSS2_F                       TMPRSS2
# Macrophages_sex[T.male]_ACE2_62yr                  ACE2
# Macrophages_sex[T.male]_ACE2_32yr                  ACE2
# Macrophages_sex[T.male]_CTSL_62yr                  CTSL
# Macrophages_sex[T.male]_CTSL_32yr                  CTSL
# Macrophages_sex[T.male]_TMPRSS2_32yr            TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_62yr            TMPRSS2
# Monocytes_age_ACE2_M                               ACE2
# Monocytes_age_ACE2_F                               ACE2
# Monocytes_age_CTSL_M                               CTSL
# Monocytes_age_CTSL_F                               CTSL
# Monocytes_age_TMPRSS2_M                         TMPRSS2
# Monocytes_age_TMPRSS2_F                         TMPRSS2
# Monocytes_sex[T.male]_ACE2_62yr                    ACE2
# Monocytes_sex[T.male]_ACE2_32yr                    ACE2
# Monocytes_sex[T.male]_CTSL_62yr                    CTSL
# Monocytes_sex[T.male]_CTSL_32yr                    CTSL
# Monocytes_sex[T.male]_TMPRSS2_62yr              TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_32yr              TMPRSS2
# MDC_age_CTSL_M                                     CTSL
# MDC_age_CTSL_F                                     CTSL
# MDC_sex[T.male]_CTSL_32yr                          CTSL
# MDC_sex[T.male]_CTSL_62yr                          CTSL
# Mast_cells_age_CTSL_M                              CTSL
# Mast_cells_age_CTSL_F                              CTSL
# Mast_cells_age_TMPRSS2_M                        TMPRSS2
# Mast_cells_age_TMPRSS2_F                        TMPRSS2
# Mast_cells_sex[T.male]_CTSL_62yr                   CTSL
# Mast_cells_sex[T.male]_CTSL_32yr                   CTSL
# Mast_cells_sex[T.male]_TMPRSS2_32yr             TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_62yr             TMPRSS2
#
#                                                         cell_identity  \
# Basal_age_ACE2_F                                                Basal
# Basal_age_ACE2_M                                                Basal
# Basal_age_CTSL_M                                                Basal
# Basal_age_CTSL_F                                                Basal
# Basal_age_TMPRSS2_F                                             Basal
# Basal_age_TMPRSS2_M                                             Basal
# Basal_sex[T.male]_ACE2_62yr                                     Basal
# Basal_sex[T.male]_ACE2_32yr                                     Basal
# Basal_sex[T.male]_CTSL_32yr                                     Basal
# Basal_sex[T.male]_CTSL_62yr                                     Basal
# Basal_sex[T.male]_TMPRSS2_32yr                                  Basal
# Basal_sex[T.male]_TMPRSS2_62yr                                  Basal
# Multiciliated_lineage_age_ACE2_F                Multiciliated lineage
# Multiciliated_lineage_age_ACE2_M                Multiciliated lineage
# Multiciliated_lineage_age_CTSL_M                Multiciliated lineage
# Multiciliated_lineage_age_CTSL_F                Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_F             Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_M             Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_32yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_62yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_32yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_62yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  Multiciliated lineage
# Secretory_age_ACE2_F                                        Secretory
# Secretory_age_ACE2_M                                        Secretory
# Secretory_age_CTSL_F                                        Secretory
# Secretory_age_CTSL_M                                        Secretory
# Secretory_age_TMPRSS2_F                                     Secretory
# Secretory_age_TMPRSS2_M                                     Secretory
# Secretory_sex[T.male]_ACE2_32yr                             Secretory
# Secretory_sex[T.male]_ACE2_62yr                             Secretory
# Secretory_sex[T.male]_CTSL_32yr                             Secretory
# Secretory_sex[T.male]_CTSL_62yr                             Secretory
# Secretory_sex[T.male]_TMPRSS2_62yr                          Secretory
# Secretory_sex[T.male]_TMPRSS2_32yr                          Secretory
# Rare_age_ACE2_F                                                  Rare
# Rare_age_ACE2_M                                                  Rare
# Rare_age_CTSL_F                                                  Rare
# Rare_age_CTSL_M                                                  Rare
# Rare_age_TMPRSS2_M                                               Rare
# Rare_age_TMPRSS2_F                                               Rare
# Rare_sex[T.male]_ACE2_62yr                                       Rare
# Rare_sex[T.male]_ACE2_32yr                                       Rare
# Rare_sex[T.male]_CTSL_32yr                                       Rare
# Rare_sex[T.male]_CTSL_62yr                                       Rare
# Rare_sex[T.male]_TMPRSS2_32yr                                    Rare
# Rare_sex[T.male]_TMPRSS2_62yr                                    Rare
# Submucosal_Secretory_age_ACE2_F                  Submucosal Secretory
# Submucosal_Secretory_age_ACE2_M                  Submucosal Secretory
# Submucosal_Secretory_age_CTSL_F                  Submucosal Secretory
# Submucosal_Secretory_age_CTSL_M                  Submucosal Secretory
# Submucosal_Secretory_age_TMPRSS2_F               Submucosal Secretory
# Submucosal_Secretory_age_TMPRSS2_M               Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_ACE2_62yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_ACE2_32yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_CTSL_32yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_CTSL_62yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr    Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr    Submucosal Secretory
# AT1_age_ACE2_F                                                    AT1
# AT1_age_ACE2_M                                                    AT1
# AT1_age_CTSL_M                                                    AT1
# AT1_age_CTSL_F                                                    AT1
# AT1_age_TMPRSS2_F                                                 AT1
# AT1_age_TMPRSS2_M                                                 AT1
# AT1_sex[T.male]_ACE2_62yr                                         AT1
# AT1_sex[T.male]_ACE2_32yr                                         AT1
# AT1_sex[T.male]_CTSL_32yr                                         AT1
# AT1_sex[T.male]_CTSL_62yr                                         AT1
# AT1_sex[T.male]_TMPRSS2_32yr                                      AT1
# AT1_sex[T.male]_TMPRSS2_62yr                                      AT1
# AT2_age_ACE2_F                                                    AT2
# AT2_age_ACE2_M                                                    AT2
# AT2_age_CTSL_F                                                    AT2
# AT2_age_CTSL_M                                                    AT2
# AT2_age_TMPRSS2_F                                                 AT2
# AT2_age_TMPRSS2_M                                                 AT2
# AT2_sex[T.male]_ACE2_62yr                                         AT2
# AT2_sex[T.male]_ACE2_32yr                                         AT2
# AT2_sex[T.male]_CTSL_32yr                                         AT2
# AT2_sex[T.male]_CTSL_62yr                                         AT2
# AT2_sex[T.male]_TMPRSS2_62yr                                      AT2
# AT2_sex[T.male]_TMPRSS2_32yr                                      AT2
# Arterial_age_CTSL_M                                          Arterial
# Arterial_age_CTSL_F                                          Arterial
# Arterial_age_TMPRSS2_M                                       Arterial
# Arterial_age_TMPRSS2_F                                       Arterial
# Arterial_sex[T.male]_CTSL_62yr                               Arterial
# Arterial_sex[T.male]_CTSL_32yr                               Arterial
# Arterial_sex[T.male]_TMPRSS2_62yr                            Arterial
# Arterial_sex[T.male]_TMPRSS2_32yr                            Arterial
# Capillary_age_ACE2_M                                        Capillary
# Capillary_age_ACE2_F                                        Capillary
# Capillary_age_CTSL_F                                        Capillary
# Capillary_age_CTSL_M                                        Capillary
# Capillary_age_TMPRSS2_M                                     Capillary
# Capillary_age_TMPRSS2_F                                     Capillary
# Capillary_sex[T.male]_ACE2_32yr                             Capillary
# Capillary_sex[T.male]_ACE2_62yr                             Capillary
# Capillary_sex[T.male]_CTSL_32yr                             Capillary
# Capillary_sex[T.male]_CTSL_62yr                             Capillary
# Capillary_sex[T.male]_TMPRSS2_62yr                          Capillary
# Capillary_sex[T.male]_TMPRSS2_32yr                          Capillary
# Venous_age_CTSL_M                                              Venous
# Venous_age_CTSL_F                                              Venous
# Venous_age_TMPRSS2_M                                           Venous
# Venous_age_TMPRSS2_F                                           Venous
# Venous_sex[T.male]_CTSL_62yr                                   Venous
# Venous_sex[T.male]_CTSL_32yr                                   Venous
# Venous_sex[T.male]_TMPRSS2_62yr                                Venous
# Venous_sex[T.male]_TMPRSS2_32yr                                Venous
# Lymphatic_EC_age_ACE2_F                                  Lymphatic EC
# Lymphatic_EC_age_ACE2_M                                  Lymphatic EC
# Lymphatic_EC_age_CTSL_F                                  Lymphatic EC
# Lymphatic_EC_age_CTSL_M                                  Lymphatic EC
# Lymphatic_EC_age_TMPRSS2_M                               Lymphatic EC
# Lymphatic_EC_age_TMPRSS2_F                               Lymphatic EC
# Lymphatic_EC_sex[T.male]_ACE2_32yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_ACE2_62yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_CTSL_32yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_CTSL_62yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr                    Lymphatic EC
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr                    Lymphatic EC
# Fibroblasts_age_ACE2_F                                    Fibroblasts
# Fibroblasts_age_ACE2_M                                    Fibroblasts
# Fibroblasts_age_CTSL_F                                    Fibroblasts
# Fibroblasts_age_CTSL_M                                    Fibroblasts
# Fibroblasts_age_TMPRSS2_F                                 Fibroblasts
# Fibroblasts_age_TMPRSS2_M                                 Fibroblasts
# Fibroblasts_sex[T.male]_ACE2_32yr                         Fibroblasts
# Fibroblasts_sex[T.male]_ACE2_62yr                         Fibroblasts
# Fibroblasts_sex[T.male]_CTSL_32yr                         Fibroblasts
# Fibroblasts_sex[T.male]_CTSL_62yr                         Fibroblasts
# Fibroblasts_sex[T.male]_TMPRSS2_32yr                      Fibroblasts
# Fibroblasts_sex[T.male]_TMPRSS2_62yr                      Fibroblasts
# Myofibroblasts_age_CTSL_M                              Myofibroblasts
# Myofibroblasts_age_CTSL_F                              Myofibroblasts
# Myofibroblasts_age_TMPRSS2_F                           Myofibroblasts
# Myofibroblasts_age_TMPRSS2_M                           Myofibroblasts
# Myofibroblasts_sex[T.male]_CTSL_62yr                   Myofibroblasts
# Myofibroblasts_sex[T.male]_CTSL_32yr                   Myofibroblasts
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr                Myofibroblasts
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr                Myofibroblasts
# Airway_smooth_muscle_age_CTSL_M                  Airway smooth muscle
# Airway_smooth_muscle_age_CTSL_F                  Airway smooth muscle
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr       Airway smooth muscle
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr       Airway smooth muscle
# B_cell_lineage_age_CTSL_M                              B cell lineage
# B_cell_lineage_age_CTSL_F                              B cell lineage
# B_cell_lineage_age_TMPRSS2_M                           B cell lineage
# B_cell_lineage_age_TMPRSS2_F                           B cell lineage
# B_cell_lineage_sex[T.male]_CTSL_32yr                   B cell lineage
# B_cell_lineage_sex[T.male]_CTSL_62yr                   B cell lineage
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr                B cell lineage
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr                B cell lineage
# T_cell_lineage_age_ACE2_M                              T cell lineage
# T_cell_lineage_age_ACE2_F                              T cell lineage
# T_cell_lineage_age_CTSL_F                              T cell lineage
# T_cell_lineage_age_CTSL_M                              T cell lineage
# T_cell_lineage_age_TMPRSS2_M                           T cell lineage
# T_cell_lineage_age_TMPRSS2_F                           T cell lineage
# T_cell_lineage_sex[T.male]_ACE2_62yr                   T cell lineage
# T_cell_lineage_sex[T.male]_ACE2_32yr                   T cell lineage
# T_cell_lineage_sex[T.male]_CTSL_62yr                   T cell lineage
# T_cell_lineage_sex[T.male]_CTSL_32yr                   T cell lineage
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr                T cell lineage
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr                T cell lineage
# Innate_lymphoid_cells_age_CTSL_F                Innate lymphoid cells
# Innate_lymphoid_cells_age_CTSL_M                Innate lymphoid cells
# Innate_lymphoid_cells_age_TMPRSS2_M             Innate lymphoid cells
# Innate_lymphoid_cells_age_TMPRSS2_F             Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr     Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr     Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  Innate lymphoid cells
# Dendritic_cells_age_CTSL_F                            Dendritic cells
# Dendritic_cells_age_CTSL_M                            Dendritic cells
# Dendritic_cells_age_TMPRSS2_F                         Dendritic cells
# Dendritic_cells_age_TMPRSS2_M                         Dendritic cells
# Dendritic_cells_sex[T.male]_CTSL_32yr                 Dendritic cells
# Dendritic_cells_sex[T.male]_CTSL_62yr                 Dendritic cells
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr              Dendritic cells
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr              Dendritic cells
# Macrophages_age_ACE2_F                                    Macrophages
# Macrophages_age_ACE2_M                                    Macrophages
# Macrophages_age_CTSL_F                                    Macrophages
# Macrophages_age_CTSL_M                                    Macrophages
# Macrophages_age_TMPRSS2_M                                 Macrophages
# Macrophages_age_TMPRSS2_F                                 Macrophages
# Macrophages_sex[T.male]_ACE2_62yr                         Macrophages
# Macrophages_sex[T.male]_ACE2_32yr                         Macrophages
# Macrophages_sex[T.male]_CTSL_62yr                         Macrophages
# Macrophages_sex[T.male]_CTSL_32yr                         Macrophages
# Macrophages_sex[T.male]_TMPRSS2_32yr                      Macrophages
# Macrophages_sex[T.male]_TMPRSS2_62yr                      Macrophages
# Monocytes_age_ACE2_M                                        Monocytes
# Monocytes_age_ACE2_F                                        Monocytes
# Monocytes_age_CTSL_M                                        Monocytes
# Monocytes_age_CTSL_F                                        Monocytes
# Monocytes_age_TMPRSS2_M                                     Monocytes
# Monocytes_age_TMPRSS2_F                                     Monocytes
# Monocytes_sex[T.male]_ACE2_62yr                             Monocytes
# Monocytes_sex[T.male]_ACE2_32yr                             Monocytes
# Monocytes_sex[T.male]_CTSL_62yr                             Monocytes
# Monocytes_sex[T.male]_CTSL_32yr                             Monocytes
# Monocytes_sex[T.male]_TMPRSS2_62yr                          Monocytes
# Monocytes_sex[T.male]_TMPRSS2_32yr                          Monocytes
# MDC_age_CTSL_M                                                    MDC
# MDC_age_CTSL_F                                                    MDC
# MDC_sex[T.male]_CTSL_32yr                                         MDC
# MDC_sex[T.male]_CTSL_62yr                                         MDC
# Mast_cells_age_CTSL_M                                      Mast cells
# Mast_cells_age_CTSL_F                                      Mast cells
# Mast_cells_age_TMPRSS2_M                                   Mast cells
# Mast_cells_age_TMPRSS2_F                                   Mast cells
# Mast_cells_sex[T.male]_CTSL_62yr                           Mast cells
# Mast_cells_sex[T.male]_CTSL_32yr                           Mast cells
# Mast_cells_sex[T.male]_TMPRSS2_32yr                        Mast cells
# Mast_cells_sex[T.male]_TMPRSS2_62yr                        Mast cells
#
#                                                   covariate eval_at  \
# Basal_age_ACE2_F                                        age       F
# Basal_age_ACE2_M                                        age       M
# Basal_age_CTSL_M                                        age       M
# Basal_age_CTSL_F                                        age       F
# Basal_age_TMPRSS2_F                                     age       F
# Basal_age_TMPRSS2_M                                     age       M
# Basal_sex[T.male]_ACE2_62yr                     sex[T.male]    62yr
# Basal_sex[T.male]_ACE2_32yr                     sex[T.male]    32yr
# Basal_sex[T.male]_CTSL_32yr                     sex[T.male]    32yr
# Basal_sex[T.male]_CTSL_62yr                     sex[T.male]    62yr
# Basal_sex[T.male]_TMPRSS2_32yr                  sex[T.male]    32yr
# Basal_sex[T.male]_TMPRSS2_62yr                  sex[T.male]    62yr
# Multiciliated_lineage_age_ACE2_F                        age       F
# Multiciliated_lineage_age_ACE2_M                        age       M
# Multiciliated_lineage_age_CTSL_M                        age       M
# Multiciliated_lineage_age_CTSL_F                        age       F
# Multiciliated_lineage_age_TMPRSS2_F                     age       F
# Multiciliated_lineage_age_TMPRSS2_M                     age       M
# Multiciliated_lineage_sex[T.male]_ACE2_32yr     sex[T.male]    32yr
# Multiciliated_lineage_sex[T.male]_ACE2_62yr     sex[T.male]    62yr
# Multiciliated_lineage_sex[T.male]_CTSL_32yr     sex[T.male]    32yr
# Multiciliated_lineage_sex[T.male]_CTSL_62yr     sex[T.male]    62yr
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  sex[T.male]    32yr
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  sex[T.male]    62yr
# Secretory_age_ACE2_F                                    age       F
# Secretory_age_ACE2_M                                    age       M
# Secretory_age_CTSL_F                                    age       F
# Secretory_age_CTSL_M                                    age       M
# Secretory_age_TMPRSS2_F                                 age       F
# Secretory_age_TMPRSS2_M                                 age       M
# Secretory_sex[T.male]_ACE2_32yr                 sex[T.male]    32yr
# Secretory_sex[T.male]_ACE2_62yr                 sex[T.male]    62yr
# Secretory_sex[T.male]_CTSL_32yr                 sex[T.male]    32yr
# Secretory_sex[T.male]_CTSL_62yr                 sex[T.male]    62yr
# Secretory_sex[T.male]_TMPRSS2_62yr              sex[T.male]    62yr
# Secretory_sex[T.male]_TMPRSS2_32yr              sex[T.male]    32yr
# Rare_age_ACE2_F                                         age       F
# Rare_age_ACE2_M                                         age       M
# Rare_age_CTSL_F                                         age       F
# Rare_age_CTSL_M                                         age       M
# Rare_age_TMPRSS2_M                                      age       M
# Rare_age_TMPRSS2_F                                      age       F
# Rare_sex[T.male]_ACE2_62yr                      sex[T.male]    62yr
# Rare_sex[T.male]_ACE2_32yr                      sex[T.male]    32yr
# Rare_sex[T.male]_CTSL_32yr                      sex[T.male]    32yr
# Rare_sex[T.male]_CTSL_62yr                      sex[T.male]    62yr
# Rare_sex[T.male]_TMPRSS2_32yr                   sex[T.male]    32yr
# Rare_sex[T.male]_TMPRSS2_62yr                   sex[T.male]    62yr
# Submucosal_Secretory_age_ACE2_F                         age       F
# Submucosal_Secretory_age_ACE2_M                         age       M
# Submucosal_Secretory_age_CTSL_F                         age       F
# Submucosal_Secretory_age_CTSL_M                         age       M
# Submucosal_Secretory_age_TMPRSS2_F                      age       F
# Submucosal_Secretory_age_TMPRSS2_M                      age       M
# Submucosal_Secretory_sex[T.male]_ACE2_62yr      sex[T.male]    62yr
# Submucosal_Secretory_sex[T.male]_ACE2_32yr      sex[T.male]    32yr
# Submucosal_Secretory_sex[T.male]_CTSL_32yr      sex[T.male]    32yr
# Submucosal_Secretory_sex[T.male]_CTSL_62yr      sex[T.male]    62yr
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr   sex[T.male]    32yr
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr   sex[T.male]    62yr
# AT1_age_ACE2_F                                          age       F
# AT1_age_ACE2_M                                          age       M
# AT1_age_CTSL_M                                          age       M
# AT1_age_CTSL_F                                          age       F
# AT1_age_TMPRSS2_F                                       age       F
# AT1_age_TMPRSS2_M                                       age       M
# AT1_sex[T.male]_ACE2_62yr                       sex[T.male]    62yr
# AT1_sex[T.male]_ACE2_32yr                       sex[T.male]    32yr
# AT1_sex[T.male]_CTSL_32yr                       sex[T.male]    32yr
# AT1_sex[T.male]_CTSL_62yr                       sex[T.male]    62yr
# AT1_sex[T.male]_TMPRSS2_32yr                    sex[T.male]    32yr
# AT1_sex[T.male]_TMPRSS2_62yr                    sex[T.male]    62yr
# AT2_age_ACE2_F                                          age       F
# AT2_age_ACE2_M                                          age       M
# AT2_age_CTSL_F                                          age       F
# AT2_age_CTSL_M                                          age       M
# AT2_age_TMPRSS2_F                                       age       F
# AT2_age_TMPRSS2_M                                       age       M
# AT2_sex[T.male]_ACE2_62yr                       sex[T.male]    62yr
# AT2_sex[T.male]_ACE2_32yr                       sex[T.male]    32yr
# AT2_sex[T.male]_CTSL_32yr                       sex[T.male]    32yr
# AT2_sex[T.male]_CTSL_62yr                       sex[T.male]    62yr
# AT2_sex[T.male]_TMPRSS2_62yr                    sex[T.male]    62yr
# AT2_sex[T.male]_TMPRSS2_32yr                    sex[T.male]    32yr
# Arterial_age_CTSL_M                                     age       M
# Arterial_age_CTSL_F                                     age       F
# Arterial_age_TMPRSS2_M                                  age       M
# Arterial_age_TMPRSS2_F                                  age       F
# Arterial_sex[T.male]_CTSL_62yr                  sex[T.male]    62yr
# Arterial_sex[T.male]_CTSL_32yr                  sex[T.male]    32yr
# Arterial_sex[T.male]_TMPRSS2_62yr               sex[T.male]    62yr
# Arterial_sex[T.male]_TMPRSS2_32yr               sex[T.male]    32yr
# Capillary_age_ACE2_M                                    age       M
# Capillary_age_ACE2_F                                    age       F
# Capillary_age_CTSL_F                                    age       F
# Capillary_age_CTSL_M                                    age       M
# Capillary_age_TMPRSS2_M                                 age       M
# Capillary_age_TMPRSS2_F                                 age       F
# Capillary_sex[T.male]_ACE2_32yr                 sex[T.male]    32yr
# Capillary_sex[T.male]_ACE2_62yr                 sex[T.male]    62yr
# Capillary_sex[T.male]_CTSL_32yr                 sex[T.male]    32yr
# Capillary_sex[T.male]_CTSL_62yr                 sex[T.male]    62yr
# Capillary_sex[T.male]_TMPRSS2_62yr              sex[T.male]    62yr
# Capillary_sex[T.male]_TMPRSS2_32yr              sex[T.male]    32yr
# Venous_age_CTSL_M                                       age       M
# Venous_age_CTSL_F                                       age       F
# Venous_age_TMPRSS2_M                                    age       M
# Venous_age_TMPRSS2_F                                    age       F
# Venous_sex[T.male]_CTSL_62yr                    sex[T.male]    62yr
# Venous_sex[T.male]_CTSL_32yr                    sex[T.male]    32yr
# Venous_sex[T.male]_TMPRSS2_62yr                 sex[T.male]    62yr
# Venous_sex[T.male]_TMPRSS2_32yr                 sex[T.male]    32yr
# Lymphatic_EC_age_ACE2_F                                 age       F
# Lymphatic_EC_age_ACE2_M                                 age       M
# Lymphatic_EC_age_CTSL_F                                 age       F
# Lymphatic_EC_age_CTSL_M                                 age       M
# Lymphatic_EC_age_TMPRSS2_M                              age       M
# Lymphatic_EC_age_TMPRSS2_F                              age       F
# Lymphatic_EC_sex[T.male]_ACE2_32yr              sex[T.male]    32yr
# Lymphatic_EC_sex[T.male]_ACE2_62yr              sex[T.male]    62yr
# Lymphatic_EC_sex[T.male]_CTSL_32yr              sex[T.male]    32yr
# Lymphatic_EC_sex[T.male]_CTSL_62yr              sex[T.male]    62yr
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr           sex[T.male]    62yr
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr           sex[T.male]    32yr
# Fibroblasts_age_ACE2_F                                  age       F
# Fibroblasts_age_ACE2_M                                  age       M
# Fibroblasts_age_CTSL_F                                  age       F
# Fibroblasts_age_CTSL_M                                  age       M
# Fibroblasts_age_TMPRSS2_F                               age       F
# Fibroblasts_age_TMPRSS2_M                               age       M
# Fibroblasts_sex[T.male]_ACE2_32yr               sex[T.male]    32yr
# Fibroblasts_sex[T.male]_ACE2_62yr               sex[T.male]    62yr
# Fibroblasts_sex[T.male]_CTSL_32yr               sex[T.male]    32yr
# Fibroblasts_sex[T.male]_CTSL_62yr               sex[T.male]    62yr
# Fibroblasts_sex[T.male]_TMPRSS2_32yr            sex[T.male]    32yr
# Fibroblasts_sex[T.male]_TMPRSS2_62yr            sex[T.male]    62yr
# Myofibroblasts_age_CTSL_M                               age       M
# Myofibroblasts_age_CTSL_F                               age       F
# Myofibroblasts_age_TMPRSS2_F                            age       F
# Myofibroblasts_age_TMPRSS2_M                            age       M
# Myofibroblasts_sex[T.male]_CTSL_62yr            sex[T.male]    62yr
# Myofibroblasts_sex[T.male]_CTSL_32yr            sex[T.male]    32yr
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr         sex[T.male]    62yr
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr         sex[T.male]    32yr
# Airway_smooth_muscle_age_CTSL_M                         age       M
# Airway_smooth_muscle_age_CTSL_F                         age       F
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr      sex[T.male]    62yr
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr      sex[T.male]    32yr
# B_cell_lineage_age_CTSL_M                               age       M
# B_cell_lineage_age_CTSL_F                               age       F
# B_cell_lineage_age_TMPRSS2_M                            age       M
# B_cell_lineage_age_TMPRSS2_F                            age       F
# B_cell_lineage_sex[T.male]_CTSL_32yr            sex[T.male]    32yr
# B_cell_lineage_sex[T.male]_CTSL_62yr            sex[T.male]    62yr
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr         sex[T.male]    32yr
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr         sex[T.male]    62yr
# T_cell_lineage_age_ACE2_M                               age       M
# T_cell_lineage_age_ACE2_F                               age       F
# T_cell_lineage_age_CTSL_F                               age       F
# T_cell_lineage_age_CTSL_M                               age       M
# T_cell_lineage_age_TMPRSS2_M                            age       M
# T_cell_lineage_age_TMPRSS2_F                            age       F
# T_cell_lineage_sex[T.male]_ACE2_62yr            sex[T.male]    62yr
# T_cell_lineage_sex[T.male]_ACE2_32yr            sex[T.male]    32yr
# T_cell_lineage_sex[T.male]_CTSL_62yr            sex[T.male]    62yr
# T_cell_lineage_sex[T.male]_CTSL_32yr            sex[T.male]    32yr
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr         sex[T.male]    62yr
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr         sex[T.male]    32yr
# Innate_lymphoid_cells_age_CTSL_F                        age       F
# Innate_lymphoid_cells_age_CTSL_M                        age       M
# Innate_lymphoid_cells_age_TMPRSS2_M                     age       M
# Innate_lymphoid_cells_age_TMPRSS2_F                     age       F
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr     sex[T.male]    62yr
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr     sex[T.male]    32yr
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  sex[T.male]    32yr
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  sex[T.male]    62yr
# Dendritic_cells_age_CTSL_F                              age       F
# Dendritic_cells_age_CTSL_M                              age       M
# Dendritic_cells_age_TMPRSS2_F                           age       F
# Dendritic_cells_age_TMPRSS2_M                           age       M
# Dendritic_cells_sex[T.male]_CTSL_32yr           sex[T.male]    32yr
# Dendritic_cells_sex[T.male]_CTSL_62yr           sex[T.male]    62yr
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr        sex[T.male]    62yr
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr        sex[T.male]    32yr
# Macrophages_age_ACE2_F                                  age       F
# Macrophages_age_ACE2_M                                  age       M
# Macrophages_age_CTSL_F                                  age       F
# Macrophages_age_CTSL_M                                  age       M
# Macrophages_age_TMPRSS2_M                               age       M
# Macrophages_age_TMPRSS2_F                               age       F
# Macrophages_sex[T.male]_ACE2_62yr               sex[T.male]    62yr
# Macrophages_sex[T.male]_ACE2_32yr               sex[T.male]    32yr
# Macrophages_sex[T.male]_CTSL_62yr               sex[T.male]    62yr
# Macrophages_sex[T.male]_CTSL_32yr               sex[T.male]    32yr
# Macrophages_sex[T.male]_TMPRSS2_32yr            sex[T.male]    32yr
# Macrophages_sex[T.male]_TMPRSS2_62yr            sex[T.male]    62yr
# Monocytes_age_ACE2_M                                    age       M
# Monocytes_age_ACE2_F                                    age       F
# Monocytes_age_CTSL_M                                    age       M
# Monocytes_age_CTSL_F                                    age       F
# Monocytes_age_TMPRSS2_M                                 age       M
# Monocytes_age_TMPRSS2_F                                 age       F
# Monocytes_sex[T.male]_ACE2_62yr                 sex[T.male]    62yr
# Monocytes_sex[T.male]_ACE2_32yr                 sex[T.male]    32yr
# Monocytes_sex[T.male]_CTSL_62yr                 sex[T.male]    62yr
# Monocytes_sex[T.male]_CTSL_32yr                 sex[T.male]    32yr
# Monocytes_sex[T.male]_TMPRSS2_62yr              sex[T.male]    62yr
# Monocytes_sex[T.male]_TMPRSS2_32yr              sex[T.male]    32yr
# MDC_age_CTSL_M                                          age       M
# MDC_age_CTSL_F                                          age       F
# MDC_sex[T.male]_CTSL_32yr                       sex[T.male]    32yr
# MDC_sex[T.male]_CTSL_62yr                       sex[T.male]    62yr
# Mast_cells_age_CTSL_M                                   age       M
# Mast_cells_age_CTSL_F                                   age       F
# Mast_cells_age_TMPRSS2_M                                age       M
# Mast_cells_age_TMPRSS2_F                                age       F
# Mast_cells_sex[T.male]_CTSL_62yr                sex[T.male]    62yr
# Mast_cells_sex[T.male]_CTSL_32yr                sex[T.male]    32yr
# Mast_cells_sex[T.male]_TMPRSS2_32yr             sex[T.male]    32yr
# Mast_cells_sex[T.male]_TMPRSS2_62yr             sex[T.male]    62yr
#
#                                                      coef     coef_sd  \
# Basal_age_ACE2_F                                 0.001302    0.001921
# Basal_age_ACE2_M                                 0.006140    0.001642
# Basal_age_CTSL_M                                 0.006855    0.000388
# Basal_age_CTSL_F                                 0.003942    0.000417
# Basal_age_TMPRSS2_F                              0.010916    0.000858
# Basal_age_TMPRSS2_M                              0.001284    0.000590
# Basal_sex[T.male]_ACE2_62yr                      0.103370    0.061120
# Basal_sex[T.male]_ACE2_32yr                     -0.041766    0.058319
# Basal_sex[T.male]_CTSL_32yr                     -0.217960    0.012758
# Basal_sex[T.male]_CTSL_62yr                     -0.130591    0.013829
# Basal_sex[T.male]_TMPRSS2_32yr                   0.448393    0.025010
# Basal_sex[T.male]_TMPRSS2_62yr                   0.159454    0.025990
# Multiciliated_lineage_age_ACE2_F                 0.011557    0.003422
# Multiciliated_lineage_age_ACE2_M                 0.002488    0.003670
# Multiciliated_lineage_age_CTSL_M                 0.001055    0.000765
# Multiciliated_lineage_age_CTSL_F                -0.002707    0.000628
# Multiciliated_lineage_age_TMPRSS2_F              0.004044    0.000787
# Multiciliated_lineage_age_TMPRSS2_M             -0.004855    0.000850
# Multiciliated_lineage_sex[T.male]_ACE2_32yr      0.354480    0.103867
# Multiciliated_lineage_sex[T.male]_ACE2_62yr      0.082393    0.111829
# Multiciliated_lineage_sex[T.male]_CTSL_32yr     -0.103200    0.018902
# Multiciliated_lineage_sex[T.male]_CTSL_62yr      0.009646    0.023671
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr   0.288620    0.022916
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr   0.021671    0.026880
# Secretory_age_ACE2_F                             0.001639    0.004298
# Secretory_age_ACE2_M                            -0.015452    0.003907
# Secretory_age_CTSL_F                             0.005467    0.001849
# Secretory_age_CTSL_M                             0.004636    0.001935
# Secretory_age_TMPRSS2_F                         -0.007152    0.001067
# Secretory_age_TMPRSS2_M                         -0.000718    0.001037
# Secretory_sex[T.male]_ACE2_32yr                  0.507863    0.110348
# Secretory_sex[T.male]_ACE2_62yr                 -0.004864    0.102716
# Secretory_sex[T.male]_CTSL_32yr                  0.006176    0.057872
# Secretory_sex[T.male]_CTSL_62yr                 -0.018739    0.044487
# Secretory_sex[T.male]_TMPRSS2_62yr               0.349704    0.028795
# Secretory_sex[T.male]_TMPRSS2_32yr               0.156688    0.030129
# Rare_age_ACE2_F                                 -0.012184    0.032458
# Rare_age_ACE2_M                                  0.018525    0.026112
# Rare_age_CTSL_F                                  0.016175    0.004130
# Rare_age_CTSL_M                                  0.003509    0.002412
# Rare_age_TMPRSS2_M                              -0.006518    0.003634
# ...
# Macrophages_age_ACE2_M                                      Age         1
# Macrophages_age_CTSL_F                                      Age         0
# Macrophages_age_CTSL_M                                      Age         1
# Macrophages_age_TMPRSS2_M                                   Age         1
# Macrophages_age_TMPRSS2_F                                   Age         0
# Macrophages_sex[T.male]_ACE2_62yr                           Sex         1
# Macrophages_sex[T.male]_ACE2_32yr                           Sex         0
# Macrophages_sex[T.male]_CTSL_62yr                           Sex         1
# Macrophages_sex[T.male]_CTSL_32yr                           Sex         0
# Macrophages_sex[T.male]_TMPRSS2_32yr                        Sex         0
# Macrophages_sex[T.male]_TMPRSS2_62yr                        Sex         1
# Monocytes_age_ACE2_M                                        Age         1
# Monocytes_age_ACE2_F                                        Age         0
# Monocytes_age_CTSL_M                                        Age         1
# Monocytes_age_CTSL_F                                        Age         0
# Monocytes_age_TMPRSS2_M                                     Age         1
# Monocytes_age_TMPRSS2_F                                     Age         0
# Monocytes_sex[T.male]_ACE2_62yr                             Sex         1
# Monocytes_sex[T.male]_ACE2_32yr                             Sex         0
# Monocytes_sex[T.male]_CTSL_62yr                             Sex         1
# Monocytes_sex[T.male]_CTSL_32yr                             Sex         0
# Monocytes_sex[T.male]_TMPRSS2_62yr                          Sex         1
# Monocytes_sex[T.male]_TMPRSS2_32yr                          Sex         0
# MDC_age_CTSL_M                                              Age         1
# MDC_age_CTSL_F                                              Age         0
# MDC_sex[T.male]_CTSL_32yr                                   Sex         0
# MDC_sex[T.male]_CTSL_62yr                                   Sex         1
# Mast_cells_age_CTSL_M                                       Age         1
# Mast_cells_age_CTSL_F                                       Age         0
# Mast_cells_age_TMPRSS2_M                                    Age         1
# Mast_cells_age_TMPRSS2_F                                    Age         0
# Mast_cells_sex[T.male]_CTSL_62yr                            Sex         1
# Mast_cells_sex[T.male]_CTSL_32yr                            Sex         0
# Mast_cells_sex[T.male]_TMPRSS2_32yr                         Sex         0
# Mast_cells_sex[T.male]_TMPRSS2_62yr                         Sex         1
#
#                                                 gene_eval
# Basal_age_ACE2_F                                   ACE2 0
# Basal_age_ACE2_M                                   ACE2 1
# Basal_age_CTSL_M                                   CTSL 1
# Basal_age_CTSL_F                                   CTSL 0
# Basal_age_TMPRSS2_F                             TMPRSS2 0
# Basal_age_TMPRSS2_M                             TMPRSS2 1
# Basal_sex[T.male]_ACE2_62yr                        ACE2 1
# Basal_sex[T.male]_ACE2_32yr                        ACE2 0
# Basal_sex[T.male]_CTSL_32yr                        CTSL 0
# Basal_sex[T.male]_CTSL_62yr                        CTSL 1
# Basal_sex[T.male]_TMPRSS2_32yr                  TMPRSS2 0
# Basal_sex[T.male]_TMPRSS2_62yr                  TMPRSS2 1
# Multiciliated_lineage_age_ACE2_F                   ACE2 0
# Multiciliated_lineage_age_ACE2_M                   ACE2 1
# Multiciliated_lineage_age_CTSL_M                   CTSL 1
# Multiciliated_lineage_age_CTSL_F                   CTSL 0
# Multiciliated_lineage_age_TMPRSS2_F             TMPRSS2 0
# Multiciliated_lineage_age_TMPRSS2_M             TMPRSS2 1
# Multiciliated_lineage_sex[T.male]_ACE2_32yr        ACE2 0
# Multiciliated_lineage_sex[T.male]_ACE2_62yr        ACE2 1
# Multiciliated_lineage_sex[T.male]_CTSL_32yr        CTSL 0
# Multiciliated_lineage_sex[T.male]_CTSL_62yr        CTSL 1
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  TMPRSS2 0
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  TMPRSS2 1
# Secretory_age_ACE2_F                               ACE2 0
# Secretory_age_ACE2_M                               ACE2 1
# Secretory_age_CTSL_F                               CTSL 0
# Secretory_age_CTSL_M                               CTSL 1
# Secretory_age_TMPRSS2_F                         TMPRSS2 0
# Secretory_age_TMPRSS2_M                         TMPRSS2 1
# Secretory_sex[T.male]_ACE2_32yr                    ACE2 0
# Secretory_sex[T.male]_ACE2_62yr                    ACE2 1
# Secretory_sex[T.male]_CTSL_32yr                    CTSL 0
# Secretory_sex[T.male]_CTSL_62yr                    CTSL 1
# Secretory_sex[T.male]_TMPRSS2_62yr              TMPRSS2 1
# Secretory_sex[T.male]_TMPRSS2_32yr              TMPRSS2 0
# Rare_age_ACE2_F                                    ACE2 0
# Rare_age_ACE2_M                                    ACE2 1
# Rare_age_CTSL_F                                    CTSL 0
# Rare_age_CTSL_M                                    CTSL 1
# Rare_age_TMPRSS2_M                              TMPRSS2 1
# Rare_age_TMPRSS2_F                              TMPRSS2 0
# Rare_sex[T.male]_ACE2_62yr                         ACE2 1
# Rare_sex[T.male]_ACE2_32yr                         ACE2 0
# Rare_sex[T.male]_CTSL_32yr                         CTSL 0
# Rare_sex[T.male]_CTSL_62yr                         CTSL 1
# Rare_sex[T.male]_TMPRSS2_32yr                   TMPRSS2 0
# Rare_sex[T.male]_TMPRSS2_62yr                   TMPRSS2 1
# Submucosal_Secretory_age_ACE2_F                    ACE2 0
# Submucosal_Secretory_age_ACE2_M                    ACE2 1
# Submucosal_Secretory_age_CTSL_F                    CTSL 0
# Submucosal_Secretory_age_CTSL_M                    CTSL 1
# Submucosal_Secretory_age_TMPRSS2_F              TMPRSS2 0
# Submucosal_Secretory_age_TMPRSS2_M              TMPRSS2 1
# Submucosal_Secretory_sex[T.male]_ACE2_62yr         ACE2 1
# Submucosal_Secretory_sex[T.male]_ACE2_32yr         ACE2 0
# Submucosal_Secretory_sex[T.male]_CTSL_32yr         CTSL 0
# Submucosal_Secretory_sex[T.male]_CTSL_62yr         CTSL 1
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr   TMPRSS2 0
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr   TMPRSS2 1
# AT1_age_ACE2_F                                     ACE2 0
# AT1_age_ACE2_M                                     ACE2 1
# AT1_age_CTSL_M                                     CTSL 1
# AT1_age_CTSL_F                                     CTSL 0
# AT1_age_TMPRSS2_F                               TMPRSS2 0
# AT1_age_TMPRSS2_M                               TMPRSS2 1
# AT1_sex[T.male]_ACE2_62yr                          ACE2 1
# AT1_sex[T.male]_ACE2_32yr                          ACE2 0
# AT1_sex[T.male]_CTSL_32yr                          CTSL 0
# AT1_sex[T.male]_CTSL_62yr                          CTSL 1
# AT1_sex[T.male]_TMPRSS2_32yr                    TMPRSS2 0
# AT1_sex[T.male]_TMPRSS2_62yr                    TMPRSS2 1
# AT2_age_ACE2_F                                     ACE2 0
# AT2_age_ACE2_M                                     ACE2 1
# AT2_age_CTSL_F                                     CTSL 0
# AT2_age_CTSL_M                                     CTSL 1
# AT2_age_TMPRSS2_F                               TMPRSS2 0
# AT2_age_TMPRSS2_M                               TMPRSS2 1
# AT2_sex[T.male]_ACE2_62yr                          ACE2 1
# AT2_sex[T.male]_ACE2_32yr                          ACE2 0
# AT2_sex[T.male]_CTSL_32yr                          CTSL 0
# AT2_sex[T.male]_CTSL_62yr                          CTSL 1
# AT2_sex[T.male]_TMPRSS2_62yr                    TMPRSS2 1
# AT2_sex[T.male]_TMPRSS2_32yr                    TMPRSS2 0
# Arterial_age_CTSL_M                                CTSL 1
# Arterial_age_CTSL_F                                CTSL 0
# Arterial_age_TMPRSS2_M                          TMPRSS2 1
# Arterial_age_TMPRSS2_F                          TMPRSS2 0
# Arterial_sex[T.male]_CTSL_62yr                     CTSL 1
# Arterial_sex[T.male]_CTSL_32yr                     CTSL 0
# Arterial_sex[T.male]_TMPRSS2_62yr               TMPRSS2 1
# Arterial_sex[T.male]_TMPRSS2_32yr               TMPRSS2 0
# Capillary_age_ACE2_M                               ACE2 1
# Capillary_age_ACE2_F                               ACE2 0
# Capillary_age_CTSL_F                               CTSL 0
# Capillary_age_CTSL_M                               CTSL 1
# Capillary_age_TMPRSS2_M                         TMPRSS2 1
# Capillary_age_TMPRSS2_F                         TMPRSS2 0
# Capillary_sex[T.male]_ACE2_32yr                    ACE2 0
# Capillary_sex[T.male]_ACE2_62yr                    ACE2 1
# Capillary_sex[T.male]_CTSL_32yr                    CTSL 0
# Capillary_sex[T.male]_CTSL_62yr                    CTSL 1
# Capillary_sex[T.male]_TMPRSS2_62yr              TMPRSS2 1
# Capillary_sex[T.male]_TMPRSS2_32yr              TMPRSS2 0
# Venous_age_CTSL_M                                  CTSL 1
# Venous_age_CTSL_F                                  CTSL 0
# Venous_age_TMPRSS2_M                            TMPRSS2 1
# Venous_age_TMPRSS2_F                            TMPRSS2 0
# Venous_sex[T.male]_CTSL_62yr                       CTSL 1
# Venous_sex[T.male]_CTSL_32yr                       CTSL 0
# Venous_sex[T.male]_TMPRSS2_62yr                 TMPRSS2 1
# Venous_sex[T.male]_TMPRSS2_32yr                 TMPRSS2 0
# Lymphatic_EC_age_ACE2_F                            ACE2 0
# Lymphatic_EC_age_ACE2_M                            ACE2 1
# Lymphatic_EC_age_CTSL_F                            CTSL 0
# Lymphatic_EC_age_CTSL_M                            CTSL 1
# Lymphatic_EC_age_TMPRSS2_M                      TMPRSS2 1
# Lymphatic_EC_age_TMPRSS2_F                      TMPRSS2 0
# Lymphatic_EC_sex[T.male]_ACE2_32yr                 ACE2 0
# Lymphatic_EC_sex[T.male]_ACE2_62yr                 ACE2 1
# Lymphatic_EC_sex[T.male]_CTSL_32yr                 CTSL 0
# Lymphatic_EC_sex[T.male]_CTSL_62yr                 CTSL 1
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr           TMPRSS2 1
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr           TMPRSS2 0
# Fibroblasts_age_ACE2_F                             ACE2 0
# Fibroblasts_age_ACE2_M                             ACE2 1
# Fibroblasts_age_CTSL_F                             CTSL 0
# Fibroblasts_age_CTSL_M                             CTSL 1
# Fibroblasts_age_TMPRSS2_F                       TMPRSS2 0
# Fibroblasts_age_TMPRSS2_M                       TMPRSS2 1
# Fibroblasts_sex[T.male]_ACE2_32yr                  ACE2 0
# Fibroblasts_sex[T.male]_ACE2_62yr                  ACE2 1
# Fibroblasts_sex[T.male]_CTSL_32yr                  CTSL 0
# Fibroblasts_sex[T.male]_CTSL_62yr                  CTSL 1
# Fibroblasts_sex[T.male]_TMPRSS2_32yr            TMPRSS2 0
# Fibroblasts_sex[T.male]_TMPRSS2_62yr            TMPRSS2 1
# Myofibroblasts_age_CTSL_M                          CTSL 1
# Myofibroblasts_age_CTSL_F                          CTSL 0
# Myofibroblasts_age_TMPRSS2_F                    TMPRSS2 0
# Myofibroblasts_age_TMPRSS2_M                    TMPRSS2 1
# Myofibroblasts_sex[T.male]_CTSL_62yr               CTSL 1
# Myofibroblasts_sex[T.male]_CTSL_32yr               CTSL 0
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr         TMPRSS2 1
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr         TMPRSS2 0
# Airway_smooth_muscle_age_CTSL_M                    CTSL 1
# Airway_smooth_muscle_age_CTSL_F                    CTSL 0
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr         CTSL 1
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr         CTSL 0
# B_cell_lineage_age_CTSL_M                          CTSL 1
# B_cell_lineage_age_CTSL_F                          CTSL 0
# B_cell_lineage_age_TMPRSS2_M                    TMPRSS2 1
# B_cell_lineage_age_TMPRSS2_F                    TMPRSS2 0
# B_cell_lineage_sex[T.male]_CTSL_32yr               CTSL 0
# B_cell_lineage_sex[T.male]_CTSL_62yr               CTSL 1
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2 0
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2 1
# T_cell_lineage_age_ACE2_M                          ACE2 1
# T_cell_lineage_age_ACE2_F                          ACE2 0
# T_cell_lineage_age_CTSL_F                          CTSL 0
# T_cell_lineage_age_CTSL_M                          CTSL 1
# T_cell_lineage_age_TMPRSS2_M                    TMPRSS2 1
# T_cell_lineage_age_TMPRSS2_F                    TMPRSS2 0
# T_cell_lineage_sex[T.male]_ACE2_62yr               ACE2 1
# T_cell_lineage_sex[T.male]_ACE2_32yr               ACE2 0
# T_cell_lineage_sex[T.male]_CTSL_62yr               CTSL 1
# T_cell_lineage_sex[T.male]_CTSL_32yr               CTSL 0
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2 1
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2 0
# Innate_lymphoid_cells_age_CTSL_F                   CTSL 0
# Innate_lymphoid_cells_age_CTSL_M                   CTSL 1
# Innate_lymphoid_cells_age_TMPRSS2_M             TMPRSS2 1
# Innate_lymphoid_cells_age_TMPRSS2_F             TMPRSS2 0
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr        CTSL 1
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr        CTSL 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  TMPRSS2 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  TMPRSS2 1
# Dendritic_cells_age_CTSL_F                         CTSL 0
# Dendritic_cells_age_CTSL_M                         CTSL 1
# Dendritic_cells_age_TMPRSS2_F                   TMPRSS2 0
# Dendritic_cells_age_TMPRSS2_M                   TMPRSS2 1
# Dendritic_cells_sex[T.male]_CTSL_32yr              CTSL 0
# Dendritic_cells_sex[T.male]_CTSL_62yr              CTSL 1
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr        TMPRSS2 1
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr        TMPRSS2 0
# Macrophages_age_ACE2_F                             ACE2 0
# Macrophages_age_ACE2_M                             ACE2 1
# Macrophages_age_CTSL_F                             CTSL 0
# Macrophages_age_CTSL_M                             CTSL 1
# Macrophages_age_TMPRSS2_M                       TMPRSS2 1
# Macrophages_age_TMPRSS2_F                       TMPRSS2 0
# Macrophages_sex[T.male]_ACE2_62yr                  ACE2 1
# Macrophages_sex[T.male]_ACE2_32yr                  ACE2 0
# Macrophages_sex[T.male]_CTSL_62yr                  CTSL 1
# Macrophages_sex[T.male]_CTSL_32yr                  CTSL 0
# Macrophages_sex[T.male]_TMPRSS2_32yr            TMPRSS2 0
# Macrophages_sex[T.male]_TMPRSS2_62yr            TMPRSS2 1
# Monocytes_age_ACE2_M                               ACE2 1
# Monocytes_age_ACE2_F                               ACE2 0
# Monocytes_age_CTSL_M                               CTSL 1
# Monocytes_age_CTSL_F                               CTSL 0
# Monocytes_age_TMPRSS2_M                         TMPRSS2 1
# Monocytes_age_TMPRSS2_F                         TMPRSS2 0
# Monocytes_sex[T.male]_ACE2_62yr                    ACE2 1
# Monocytes_sex[T.male]_ACE2_32yr                    ACE2 0
# Monocytes_sex[T.male]_CTSL_62yr                    CTSL 1
# Monocytes_sex[T.male]_CTSL_32yr                    CTSL 0
# Monocytes_sex[T.male]_TMPRSS2_62yr              TMPRSS2 1
# Monocytes_sex[T.male]_TMPRSS2_32yr              TMPRSS2 0
# MDC_age_CTSL_M                                     CTSL 1
# MDC_age_CTSL_F                                     CTSL 0
# MDC_sex[T.male]_CTSL_32yr                          CTSL 0
# MDC_sex[T.male]_CTSL_62yr                          CTSL 1
# Mast_cells_age_CTSL_M                              CTSL 1
# Mast_cells_age_CTSL_F                              CTSL 0
# Mast_cells_age_TMPRSS2_M                        TMPRSS2 1
# Mast_cells_age_TMPRSS2_F                        TMPRSS2 0
# Mast_cells_sex[T.male]_CTSL_62yr                   CTSL 1
# Mast_cells_sex[T.male]_CTSL_32yr                   CTSL 0
# Mast_cells_sex[T.male]_TMPRSS2_32yr             TMPRSS2 0
# Mast_cells_sex[T.male]_TMPRSS2_62yr             TMPRSS2 1

# %%
def lighten_color(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    
    Thanks to: https://stackoverflow.com/questions/37765197/darken-or-lighten-a-color-in-matplotlib
    """
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.4
for i in range(3):
    for alpha in range(2):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.2
for alpha in range(2):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(2)]

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(2.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(2)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-0.75, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(2)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [0.55, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[2], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[4], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.25, 2.2], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl3_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.2
for i in range(3):
    for alpha in range(2):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.4
for alpha in range(2):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(2)]

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

xlims_top = [[None, None],
             [0.1, 3],
             [None, None],
             [None, None]]
xlims_bot = [[None, None],
             [None, None],
             [None, None],
             [None, None]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(2.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(2)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-0.75, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(2)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [0.55, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[2], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[4], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.25, 2.2], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl3_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# (-0.02161831904411874, 0.028073520393746)
# <ErrorbarContainer object of 3 artists>
# (-0.713155977559385, 1.1065099092421533)
# <ErrorbarContainer object of 3 artists>
# (-0.08320292597011836, 0.1)
# <ErrorbarContainer object of 3 artists>
# (-1.937291094268796, 3)
# <ErrorbarContainer object of 3 artists>
# (-0.08840127714399204, 0.03583652730130594)
# <ErrorbarContainer object of 3 artists>
# (-1.8655741378786663, 1.5179664534589121)
# <ErrorbarContainer object of 3 artists>
# (-0.07720967839759627, 0.21495658155327824)
# <ErrorbarContainer object of 3 artists>
# (-1.8148956497580855, 3.923972540842187)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])
# Out:
#                                                    gene  \
# Basal_age_ACE2_F                                   ACE2
# Basal_age_ACE2_M                                   ACE2
# Basal_age_CTSL_M                                   CTSL
# Basal_age_CTSL_F                                   CTSL
# Basal_age_TMPRSS2_F                             TMPRSS2
# Basal_age_TMPRSS2_M                             TMPRSS2
# Basal_sex[T.male]_ACE2_62yr                        ACE2
# Basal_sex[T.male]_ACE2_32yr                        ACE2
# Basal_sex[T.male]_CTSL_32yr                        CTSL
# Basal_sex[T.male]_CTSL_62yr                        CTSL
# Basal_sex[T.male]_TMPRSS2_32yr                  TMPRSS2
# Basal_sex[T.male]_TMPRSS2_62yr                  TMPRSS2
# Multiciliated_lineage_age_ACE2_F                   ACE2
# Multiciliated_lineage_age_ACE2_M                   ACE2
# Multiciliated_lineage_age_CTSL_M                   CTSL
# Multiciliated_lineage_age_CTSL_F                   CTSL
# Multiciliated_lineage_age_TMPRSS2_F             TMPRSS2
# Multiciliated_lineage_age_TMPRSS2_M             TMPRSS2
# Multiciliated_lineage_sex[T.male]_ACE2_32yr        ACE2
# Multiciliated_lineage_sex[T.male]_ACE2_62yr        ACE2
# Multiciliated_lineage_sex[T.male]_CTSL_32yr        CTSL
# Multiciliated_lineage_sex[T.male]_CTSL_62yr        CTSL
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  TMPRSS2
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  TMPRSS2
# Secretory_age_ACE2_F                               ACE2
# Secretory_age_ACE2_M                               ACE2
# Secretory_age_CTSL_F                               CTSL
# Secretory_age_CTSL_M                               CTSL
# Secretory_age_TMPRSS2_F                         TMPRSS2
# Secretory_age_TMPRSS2_M                         TMPRSS2
# Secretory_sex[T.male]_ACE2_32yr                    ACE2
# Secretory_sex[T.male]_ACE2_62yr                    ACE2
# Secretory_sex[T.male]_CTSL_32yr                    CTSL
# Secretory_sex[T.male]_CTSL_62yr                    CTSL
# Secretory_sex[T.male]_TMPRSS2_62yr              TMPRSS2
# Secretory_sex[T.male]_TMPRSS2_32yr              TMPRSS2
# Rare_age_ACE2_F                                    ACE2
# Rare_age_ACE2_M                                    ACE2
# Rare_age_CTSL_F                                    CTSL
# Rare_age_CTSL_M                                    CTSL
# Rare_age_TMPRSS2_M                              TMPRSS2
# Rare_age_TMPRSS2_F                              TMPRSS2
# Rare_sex[T.male]_ACE2_62yr                         ACE2
# Rare_sex[T.male]_ACE2_32yr                         ACE2
# Rare_sex[T.male]_CTSL_32yr                         CTSL
# Rare_sex[T.male]_CTSL_62yr                         CTSL
# Rare_sex[T.male]_TMPRSS2_32yr                   TMPRSS2
# Rare_sex[T.male]_TMPRSS2_62yr                   TMPRSS2
# Submucosal_Secretory_age_ACE2_F                    ACE2
# Submucosal_Secretory_age_ACE2_M                    ACE2
# Submucosal_Secretory_age_CTSL_F                    CTSL
# Submucosal_Secretory_age_CTSL_M                    CTSL
# Submucosal_Secretory_age_TMPRSS2_F              TMPRSS2
# Submucosal_Secretory_age_TMPRSS2_M              TMPRSS2
# Submucosal_Secretory_sex[T.male]_ACE2_62yr         ACE2
# Submucosal_Secretory_sex[T.male]_ACE2_32yr         ACE2
# Submucosal_Secretory_sex[T.male]_CTSL_32yr         CTSL
# Submucosal_Secretory_sex[T.male]_CTSL_62yr         CTSL
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr   TMPRSS2
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr   TMPRSS2
# AT1_age_ACE2_F                                     ACE2
# AT1_age_ACE2_M                                     ACE2
# AT1_age_CTSL_M                                     CTSL
# AT1_age_CTSL_F                                     CTSL
# AT1_age_TMPRSS2_F                               TMPRSS2
# AT1_age_TMPRSS2_M                               TMPRSS2
# AT1_sex[T.male]_ACE2_62yr                          ACE2
# AT1_sex[T.male]_ACE2_32yr                          ACE2
# AT1_sex[T.male]_CTSL_32yr                          CTSL
# AT1_sex[T.male]_CTSL_62yr                          CTSL
# AT1_sex[T.male]_TMPRSS2_32yr                    TMPRSS2
# AT1_sex[T.male]_TMPRSS2_62yr                    TMPRSS2
# AT2_age_ACE2_F                                     ACE2
# AT2_age_ACE2_M                                     ACE2
# AT2_age_CTSL_F                                     CTSL
# AT2_age_CTSL_M                                     CTSL
# AT2_age_TMPRSS2_F                               TMPRSS2
# AT2_age_TMPRSS2_M                               TMPRSS2
# AT2_sex[T.male]_ACE2_62yr                          ACE2
# AT2_sex[T.male]_ACE2_32yr                          ACE2
# AT2_sex[T.male]_CTSL_32yr                          CTSL
# AT2_sex[T.male]_CTSL_62yr                          CTSL
# AT2_sex[T.male]_TMPRSS2_62yr                    TMPRSS2
# AT2_sex[T.male]_TMPRSS2_32yr                    TMPRSS2
# Arterial_age_CTSL_M                                CTSL
# Arterial_age_CTSL_F                                CTSL
# Arterial_age_TMPRSS2_M                          TMPRSS2
# Arterial_age_TMPRSS2_F                          TMPRSS2
# Arterial_sex[T.male]_CTSL_62yr                     CTSL
# Arterial_sex[T.male]_CTSL_32yr                     CTSL
# Arterial_sex[T.male]_TMPRSS2_62yr               TMPRSS2
# Arterial_sex[T.male]_TMPRSS2_32yr               TMPRSS2
# Capillary_age_ACE2_M                               ACE2
# Capillary_age_ACE2_F                               ACE2
# Capillary_age_CTSL_F                               CTSL
# Capillary_age_CTSL_M                               CTSL
# Capillary_age_TMPRSS2_M                         TMPRSS2
# Capillary_age_TMPRSS2_F                         TMPRSS2
# Capillary_sex[T.male]_ACE2_32yr                    ACE2
# Capillary_sex[T.male]_ACE2_62yr                    ACE2
# Capillary_sex[T.male]_CTSL_32yr                    CTSL
# Capillary_sex[T.male]_CTSL_62yr                    CTSL
# Capillary_sex[T.male]_TMPRSS2_62yr              TMPRSS2
# Capillary_sex[T.male]_TMPRSS2_32yr              TMPRSS2
# Venous_age_CTSL_M                                  CTSL
# Venous_age_CTSL_F                                  CTSL
# Venous_age_TMPRSS2_M                            TMPRSS2
# Venous_age_TMPRSS2_F                            TMPRSS2
# Venous_sex[T.male]_CTSL_62yr                       CTSL
# Venous_sex[T.male]_CTSL_32yr                       CTSL
# Venous_sex[T.male]_TMPRSS2_62yr                 TMPRSS2
# Venous_sex[T.male]_TMPRSS2_32yr                 TMPRSS2
# Lymphatic_EC_age_ACE2_F                            ACE2
# Lymphatic_EC_age_ACE2_M                            ACE2
# Lymphatic_EC_age_CTSL_F                            CTSL
# Lymphatic_EC_age_CTSL_M                            CTSL
# Lymphatic_EC_age_TMPRSS2_M                      TMPRSS2
# Lymphatic_EC_age_TMPRSS2_F                      TMPRSS2
# Lymphatic_EC_sex[T.male]_ACE2_32yr                 ACE2
# Lymphatic_EC_sex[T.male]_ACE2_62yr                 ACE2
# Lymphatic_EC_sex[T.male]_CTSL_32yr                 CTSL
# Lymphatic_EC_sex[T.male]_CTSL_62yr                 CTSL
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr           TMPRSS2
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr           TMPRSS2
# Fibroblasts_age_ACE2_F                             ACE2
# Fibroblasts_age_ACE2_M                             ACE2
# Fibroblasts_age_CTSL_F                             CTSL
# Fibroblasts_age_CTSL_M                             CTSL
# Fibroblasts_age_TMPRSS2_F                       TMPRSS2
# Fibroblasts_age_TMPRSS2_M                       TMPRSS2
# Fibroblasts_sex[T.male]_ACE2_32yr                  ACE2
# Fibroblasts_sex[T.male]_ACE2_62yr                  ACE2
# Fibroblasts_sex[T.male]_CTSL_32yr                  CTSL
# Fibroblasts_sex[T.male]_CTSL_62yr                  CTSL
# Fibroblasts_sex[T.male]_TMPRSS2_32yr            TMPRSS2
# Fibroblasts_sex[T.male]_TMPRSS2_62yr            TMPRSS2
# Myofibroblasts_age_CTSL_M                          CTSL
# Myofibroblasts_age_CTSL_F                          CTSL
# Myofibroblasts_age_TMPRSS2_F                    TMPRSS2
# Myofibroblasts_age_TMPRSS2_M                    TMPRSS2
# Myofibroblasts_sex[T.male]_CTSL_62yr               CTSL
# Myofibroblasts_sex[T.male]_CTSL_32yr               CTSL
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr         TMPRSS2
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr         TMPRSS2
# Airway_smooth_muscle_age_CTSL_M                    CTSL
# Airway_smooth_muscle_age_CTSL_F                    CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr         CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr         CTSL
# B_cell_lineage_age_CTSL_M                          CTSL
# B_cell_lineage_age_CTSL_F                          CTSL
# B_cell_lineage_age_TMPRSS2_M                    TMPRSS2
# B_cell_lineage_age_TMPRSS2_F                    TMPRSS2
# B_cell_lineage_sex[T.male]_CTSL_32yr               CTSL
# B_cell_lineage_sex[T.male]_CTSL_62yr               CTSL
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2
# T_cell_lineage_age_ACE2_M                          ACE2
# T_cell_lineage_age_ACE2_F                          ACE2
# T_cell_lineage_age_CTSL_F                          CTSL
# T_cell_lineage_age_CTSL_M                          CTSL
# T_cell_lineage_age_TMPRSS2_M                    TMPRSS2
# T_cell_lineage_age_TMPRSS2_F                    TMPRSS2
# T_cell_lineage_sex[T.male]_ACE2_62yr               ACE2
# T_cell_lineage_sex[T.male]_ACE2_32yr               ACE2
# T_cell_lineage_sex[T.male]_CTSL_62yr               CTSL
# T_cell_lineage_sex[T.male]_CTSL_32yr               CTSL
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2
# Innate_lymphoid_cells_age_CTSL_F                   CTSL
# Innate_lymphoid_cells_age_CTSL_M                   CTSL
# Innate_lymphoid_cells_age_TMPRSS2_M             TMPRSS2
# Innate_lymphoid_cells_age_TMPRSS2_F             TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr        CTSL
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr        CTSL
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  TMPRSS2
# Dendritic_cells_age_CTSL_F                         CTSL
# Dendritic_cells_age_CTSL_M                         CTSL
# Dendritic_cells_age_TMPRSS2_F                   TMPRSS2
# Dendritic_cells_age_TMPRSS2_M                   TMPRSS2
# Dendritic_cells_sex[T.male]_CTSL_32yr              CTSL
# Dendritic_cells_sex[T.male]_CTSL_62yr              CTSL
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr        TMPRSS2
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr        TMPRSS2
# Macrophages_age_ACE2_F                             ACE2
# Macrophages_age_ACE2_M                             ACE2
# Macrophages_age_CTSL_F                             CTSL
# Macrophages_age_CTSL_M                             CTSL
# Macrophages_age_TMPRSS2_M                       TMPRSS2
# Macrophages_age_TMPRSS2_F                       TMPRSS2
# Macrophages_sex[T.male]_ACE2_62yr                  ACE2
# Macrophages_sex[T.male]_ACE2_32yr                  ACE2
# Macrophages_sex[T.male]_CTSL_62yr                  CTSL
# Macrophages_sex[T.male]_CTSL_32yr                  CTSL
# Macrophages_sex[T.male]_TMPRSS2_32yr            TMPRSS2
# Macrophages_sex[T.male]_TMPRSS2_62yr            TMPRSS2
# Monocytes_age_ACE2_M                               ACE2
# Monocytes_age_ACE2_F                               ACE2
# Monocytes_age_CTSL_M                               CTSL
# Monocytes_age_CTSL_F                               CTSL
# Monocytes_age_TMPRSS2_M                         TMPRSS2
# Monocytes_age_TMPRSS2_F                         TMPRSS2
# Monocytes_sex[T.male]_ACE2_62yr                    ACE2
# Monocytes_sex[T.male]_ACE2_32yr                    ACE2
# Monocytes_sex[T.male]_CTSL_62yr                    CTSL
# Monocytes_sex[T.male]_CTSL_32yr                    CTSL
# Monocytes_sex[T.male]_TMPRSS2_62yr              TMPRSS2
# Monocytes_sex[T.male]_TMPRSS2_32yr              TMPRSS2
# MDC_age_CTSL_M                                     CTSL
# MDC_age_CTSL_F                                     CTSL
# MDC_sex[T.male]_CTSL_32yr                          CTSL
# MDC_sex[T.male]_CTSL_62yr                          CTSL
# Mast_cells_age_CTSL_M                              CTSL
# Mast_cells_age_CTSL_F                              CTSL
# Mast_cells_age_TMPRSS2_M                        TMPRSS2
# Mast_cells_age_TMPRSS2_F                        TMPRSS2
# Mast_cells_sex[T.male]_CTSL_62yr                   CTSL
# Mast_cells_sex[T.male]_CTSL_32yr                   CTSL
# Mast_cells_sex[T.male]_TMPRSS2_32yr             TMPRSS2
# Mast_cells_sex[T.male]_TMPRSS2_62yr             TMPRSS2
#
#                                                         cell_identity  \
# Basal_age_ACE2_F                                                Basal
# Basal_age_ACE2_M                                                Basal
# Basal_age_CTSL_M                                                Basal
# Basal_age_CTSL_F                                                Basal
# Basal_age_TMPRSS2_F                                             Basal
# Basal_age_TMPRSS2_M                                             Basal
# Basal_sex[T.male]_ACE2_62yr                                     Basal
# Basal_sex[T.male]_ACE2_32yr                                     Basal
# Basal_sex[T.male]_CTSL_32yr                                     Basal
# Basal_sex[T.male]_CTSL_62yr                                     Basal
# Basal_sex[T.male]_TMPRSS2_32yr                                  Basal
# Basal_sex[T.male]_TMPRSS2_62yr                                  Basal
# Multiciliated_lineage_age_ACE2_F                Multiciliated lineage
# Multiciliated_lineage_age_ACE2_M                Multiciliated lineage
# Multiciliated_lineage_age_CTSL_M                Multiciliated lineage
# Multiciliated_lineage_age_CTSL_F                Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_F             Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2_M             Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_32yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2_62yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_32yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL_62yr     Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  Multiciliated lineage
# Secretory_age_ACE2_F                                        Secretory
# Secretory_age_ACE2_M                                        Secretory
# Secretory_age_CTSL_F                                        Secretory
# Secretory_age_CTSL_M                                        Secretory
# Secretory_age_TMPRSS2_F                                     Secretory
# Secretory_age_TMPRSS2_M                                     Secretory
# Secretory_sex[T.male]_ACE2_32yr                             Secretory
# Secretory_sex[T.male]_ACE2_62yr                             Secretory
# Secretory_sex[T.male]_CTSL_32yr                             Secretory
# Secretory_sex[T.male]_CTSL_62yr                             Secretory
# Secretory_sex[T.male]_TMPRSS2_62yr                          Secretory
# Secretory_sex[T.male]_TMPRSS2_32yr                          Secretory
# Rare_age_ACE2_F                                                  Rare
# Rare_age_ACE2_M                                                  Rare
# Rare_age_CTSL_F                                                  Rare
# Rare_age_CTSL_M                                                  Rare
# Rare_age_TMPRSS2_M                                               Rare
# Rare_age_TMPRSS2_F                                               Rare
# Rare_sex[T.male]_ACE2_62yr                                       Rare
# Rare_sex[T.male]_ACE2_32yr                                       Rare
# Rare_sex[T.male]_CTSL_32yr                                       Rare
# Rare_sex[T.male]_CTSL_62yr                                       Rare
# Rare_sex[T.male]_TMPRSS2_32yr                                    Rare
# Rare_sex[T.male]_TMPRSS2_62yr                                    Rare
# Submucosal_Secretory_age_ACE2_F                  Submucosal Secretory
# Submucosal_Secretory_age_ACE2_M                  Submucosal Secretory
# Submucosal_Secretory_age_CTSL_F                  Submucosal Secretory
# Submucosal_Secretory_age_CTSL_M                  Submucosal Secretory
# Submucosal_Secretory_age_TMPRSS2_F               Submucosal Secretory
# Submucosal_Secretory_age_TMPRSS2_M               Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_ACE2_62yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_ACE2_32yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_CTSL_32yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_CTSL_62yr       Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr    Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr    Submucosal Secretory
# AT1_age_ACE2_F                                                    AT1
# AT1_age_ACE2_M                                                    AT1
# AT1_age_CTSL_M                                                    AT1
# AT1_age_CTSL_F                                                    AT1
# AT1_age_TMPRSS2_F                                                 AT1
# AT1_age_TMPRSS2_M                                                 AT1
# AT1_sex[T.male]_ACE2_62yr                                         AT1
# AT1_sex[T.male]_ACE2_32yr                                         AT1
# AT1_sex[T.male]_CTSL_32yr                                         AT1
# AT1_sex[T.male]_CTSL_62yr                                         AT1
# AT1_sex[T.male]_TMPRSS2_32yr                                      AT1
# AT1_sex[T.male]_TMPRSS2_62yr                                      AT1
# AT2_age_ACE2_F                                                    AT2
# AT2_age_ACE2_M                                                    AT2
# AT2_age_CTSL_F                                                    AT2
# AT2_age_CTSL_M                                                    AT2
# AT2_age_TMPRSS2_F                                                 AT2
# AT2_age_TMPRSS2_M                                                 AT2
# AT2_sex[T.male]_ACE2_62yr                                         AT2
# AT2_sex[T.male]_ACE2_32yr                                         AT2
# AT2_sex[T.male]_CTSL_32yr                                         AT2
# AT2_sex[T.male]_CTSL_62yr                                         AT2
# AT2_sex[T.male]_TMPRSS2_62yr                                      AT2
# AT2_sex[T.male]_TMPRSS2_32yr                                      AT2
# Arterial_age_CTSL_M                                          Arterial
# Arterial_age_CTSL_F                                          Arterial
# Arterial_age_TMPRSS2_M                                       Arterial
# Arterial_age_TMPRSS2_F                                       Arterial
# Arterial_sex[T.male]_CTSL_62yr                               Arterial
# Arterial_sex[T.male]_CTSL_32yr                               Arterial
# Arterial_sex[T.male]_TMPRSS2_62yr                            Arterial
# Arterial_sex[T.male]_TMPRSS2_32yr                            Arterial
# Capillary_age_ACE2_M                                        Capillary
# Capillary_age_ACE2_F                                        Capillary
# Capillary_age_CTSL_F                                        Capillary
# Capillary_age_CTSL_M                                        Capillary
# Capillary_age_TMPRSS2_M                                     Capillary
# Capillary_age_TMPRSS2_F                                     Capillary
# Capillary_sex[T.male]_ACE2_32yr                             Capillary
# Capillary_sex[T.male]_ACE2_62yr                             Capillary
# Capillary_sex[T.male]_CTSL_32yr                             Capillary
# Capillary_sex[T.male]_CTSL_62yr                             Capillary
# Capillary_sex[T.male]_TMPRSS2_62yr                          Capillary
# Capillary_sex[T.male]_TMPRSS2_32yr                          Capillary
# Venous_age_CTSL_M                                              Venous
# Venous_age_CTSL_F                                              Venous
# Venous_age_TMPRSS2_M                                           Venous
# Venous_age_TMPRSS2_F                                           Venous
# Venous_sex[T.male]_CTSL_62yr                                   Venous
# Venous_sex[T.male]_CTSL_32yr                                   Venous
# Venous_sex[T.male]_TMPRSS2_62yr                                Venous
# Venous_sex[T.male]_TMPRSS2_32yr                                Venous
# Lymphatic_EC_age_ACE2_F                                  Lymphatic EC
# Lymphatic_EC_age_ACE2_M                                  Lymphatic EC
# Lymphatic_EC_age_CTSL_F                                  Lymphatic EC
# Lymphatic_EC_age_CTSL_M                                  Lymphatic EC
# Lymphatic_EC_age_TMPRSS2_M                               Lymphatic EC
# Lymphatic_EC_age_TMPRSS2_F                               Lymphatic EC
# Lymphatic_EC_sex[T.male]_ACE2_32yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_ACE2_62yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_CTSL_32yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_CTSL_62yr                       Lymphatic EC
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr                    Lymphatic EC
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr                    Lymphatic EC
# Fibroblasts_age_ACE2_F                                    Fibroblasts
# Fibroblasts_age_ACE2_M                                    Fibroblasts
# Fibroblasts_age_CTSL_F                                    Fibroblasts
# Fibroblasts_age_CTSL_M                                    Fibroblasts
# Fibroblasts_age_TMPRSS2_F                                 Fibroblasts
# Fibroblasts_age_TMPRSS2_M                                 Fibroblasts
# Fibroblasts_sex[T.male]_ACE2_32yr                         Fibroblasts
# Fibroblasts_sex[T.male]_ACE2_62yr                         Fibroblasts
# Fibroblasts_sex[T.male]_CTSL_32yr                         Fibroblasts
# Fibroblasts_sex[T.male]_CTSL_62yr                         Fibroblasts
# Fibroblasts_sex[T.male]_TMPRSS2_32yr                      Fibroblasts
# Fibroblasts_sex[T.male]_TMPRSS2_62yr                      Fibroblasts
# Myofibroblasts_age_CTSL_M                              Myofibroblasts
# Myofibroblasts_age_CTSL_F                              Myofibroblasts
# Myofibroblasts_age_TMPRSS2_F                           Myofibroblasts
# Myofibroblasts_age_TMPRSS2_M                           Myofibroblasts
# Myofibroblasts_sex[T.male]_CTSL_62yr                   Myofibroblasts
# Myofibroblasts_sex[T.male]_CTSL_32yr                   Myofibroblasts
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr                Myofibroblasts
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr                Myofibroblasts
# Airway_smooth_muscle_age_CTSL_M                  Airway smooth muscle
# Airway_smooth_muscle_age_CTSL_F                  Airway smooth muscle
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr       Airway smooth muscle
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr       Airway smooth muscle
# B_cell_lineage_age_CTSL_M                              B cell lineage
# B_cell_lineage_age_CTSL_F                              B cell lineage
# B_cell_lineage_age_TMPRSS2_M                           B cell lineage
# B_cell_lineage_age_TMPRSS2_F                           B cell lineage
# B_cell_lineage_sex[T.male]_CTSL_32yr                   B cell lineage
# B_cell_lineage_sex[T.male]_CTSL_62yr                   B cell lineage
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr                B cell lineage
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr                B cell lineage
# T_cell_lineage_age_ACE2_M                              T cell lineage
# T_cell_lineage_age_ACE2_F                              T cell lineage
# T_cell_lineage_age_CTSL_F                              T cell lineage
# T_cell_lineage_age_CTSL_M                              T cell lineage
# T_cell_lineage_age_TMPRSS2_M                           T cell lineage
# T_cell_lineage_age_TMPRSS2_F                           T cell lineage
# T_cell_lineage_sex[T.male]_ACE2_62yr                   T cell lineage
# T_cell_lineage_sex[T.male]_ACE2_32yr                   T cell lineage
# T_cell_lineage_sex[T.male]_CTSL_62yr                   T cell lineage
# T_cell_lineage_sex[T.male]_CTSL_32yr                   T cell lineage
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr                T cell lineage
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr                T cell lineage
# Innate_lymphoid_cells_age_CTSL_F                Innate lymphoid cells
# Innate_lymphoid_cells_age_CTSL_M                Innate lymphoid cells
# Innate_lymphoid_cells_age_TMPRSS2_M             Innate lymphoid cells
# Innate_lymphoid_cells_age_TMPRSS2_F             Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr     Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr     Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  Innate lymphoid cells
# Dendritic_cells_age_CTSL_F                            Dendritic cells
# Dendritic_cells_age_CTSL_M                            Dendritic cells
# Dendritic_cells_age_TMPRSS2_F                         Dendritic cells
# Dendritic_cells_age_TMPRSS2_M                         Dendritic cells
# Dendritic_cells_sex[T.male]_CTSL_32yr                 Dendritic cells
# Dendritic_cells_sex[T.male]_CTSL_62yr                 Dendritic cells
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr              Dendritic cells
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr              Dendritic cells
# Macrophages_age_ACE2_F                                    Macrophages
# Macrophages_age_ACE2_M                                    Macrophages
# Macrophages_age_CTSL_F                                    Macrophages
# Macrophages_age_CTSL_M                                    Macrophages
# Macrophages_age_TMPRSS2_M                                 Macrophages
# Macrophages_age_TMPRSS2_F                                 Macrophages
# Macrophages_sex[T.male]_ACE2_62yr                         Macrophages
# Macrophages_sex[T.male]_ACE2_32yr                         Macrophages
# Macrophages_sex[T.male]_CTSL_62yr                         Macrophages
# Macrophages_sex[T.male]_CTSL_32yr                         Macrophages
# Macrophages_sex[T.male]_TMPRSS2_32yr                      Macrophages
# Macrophages_sex[T.male]_TMPRSS2_62yr                      Macrophages
# Monocytes_age_ACE2_M                                        Monocytes
# Monocytes_age_ACE2_F                                        Monocytes
# Monocytes_age_CTSL_M                                        Monocytes
# Monocytes_age_CTSL_F                                        Monocytes
# Monocytes_age_TMPRSS2_M                                     Monocytes
# Monocytes_age_TMPRSS2_F                                     Monocytes
# Monocytes_sex[T.male]_ACE2_62yr                             Monocytes
# Monocytes_sex[T.male]_ACE2_32yr                             Monocytes
# Monocytes_sex[T.male]_CTSL_62yr                             Monocytes
# Monocytes_sex[T.male]_CTSL_32yr                             Monocytes
# Monocytes_sex[T.male]_TMPRSS2_62yr                          Monocytes
# Monocytes_sex[T.male]_TMPRSS2_32yr                          Monocytes
# MDC_age_CTSL_M                                                    MDC
# MDC_age_CTSL_F                                                    MDC
# MDC_sex[T.male]_CTSL_32yr                                         MDC
# MDC_sex[T.male]_CTSL_62yr                                         MDC
# Mast_cells_age_CTSL_M                                      Mast cells
# Mast_cells_age_CTSL_F                                      Mast cells
# Mast_cells_age_TMPRSS2_M                                   Mast cells
# Mast_cells_age_TMPRSS2_F                                   Mast cells
# Mast_cells_sex[T.male]_CTSL_62yr                           Mast cells
# Mast_cells_sex[T.male]_CTSL_32yr                           Mast cells
# Mast_cells_sex[T.male]_TMPRSS2_32yr                        Mast cells
# Mast_cells_sex[T.male]_TMPRSS2_62yr                        Mast cells
#
#                                                   covariate eval_at  \
# Basal_age_ACE2_F                                        age       F
# Basal_age_ACE2_M                                        age       M
# Basal_age_CTSL_M                                        age       M
# Basal_age_CTSL_F                                        age       F
# Basal_age_TMPRSS2_F                                     age       F
# Basal_age_TMPRSS2_M                                     age       M
# Basal_sex[T.male]_ACE2_62yr                     sex[T.male]    62yr
# Basal_sex[T.male]_ACE2_32yr                     sex[T.male]    32yr
# Basal_sex[T.male]_CTSL_32yr                     sex[T.male]    32yr
# Basal_sex[T.male]_CTSL_62yr                     sex[T.male]    62yr
# Basal_sex[T.male]_TMPRSS2_32yr                  sex[T.male]    32yr
# Basal_sex[T.male]_TMPRSS2_62yr                  sex[T.male]    62yr
# Multiciliated_lineage_age_ACE2_F                        age       F
# Multiciliated_lineage_age_ACE2_M                        age       M
# Multiciliated_lineage_age_CTSL_M                        age       M
# Multiciliated_lineage_age_CTSL_F                        age       F
# Multiciliated_lineage_age_TMPRSS2_F                     age       F
# Multiciliated_lineage_age_TMPRSS2_M                     age       M
# Multiciliated_lineage_sex[T.male]_ACE2_32yr     sex[T.male]    32yr
# Multiciliated_lineage_sex[T.male]_ACE2_62yr     sex[T.male]    62yr
# Multiciliated_lineage_sex[T.male]_CTSL_32yr     sex[T.male]    32yr
# Multiciliated_lineage_sex[T.male]_CTSL_62yr     sex[T.male]    62yr
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  sex[T.male]    32yr
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  sex[T.male]    62yr
# Secretory_age_ACE2_F                                    age       F
# Secretory_age_ACE2_M                                    age       M
# Secretory_age_CTSL_F                                    age       F
# Secretory_age_CTSL_M                                    age       M
# Secretory_age_TMPRSS2_F                                 age       F
# Secretory_age_TMPRSS2_M                                 age       M
# Secretory_sex[T.male]_ACE2_32yr                 sex[T.male]    32yr
# Secretory_sex[T.male]_ACE2_62yr                 sex[T.male]    62yr
# Secretory_sex[T.male]_CTSL_32yr                 sex[T.male]    32yr
# Secretory_sex[T.male]_CTSL_62yr                 sex[T.male]    62yr
# Secretory_sex[T.male]_TMPRSS2_62yr              sex[T.male]    62yr
# Secretory_sex[T.male]_TMPRSS2_32yr              sex[T.male]    32yr
# Rare_age_ACE2_F                                         age       F
# Rare_age_ACE2_M                                         age       M
# Rare_age_CTSL_F                                         age       F
# Rare_age_CTSL_M                                         age       M
# Rare_age_TMPRSS2_M                                      age       M
# Rare_age_TMPRSS2_F                                      age       F
# Rare_sex[T.male]_ACE2_62yr                      sex[T.male]    62yr
# Rare_sex[T.male]_ACE2_32yr                      sex[T.male]    32yr
# Rare_sex[T.male]_CTSL_32yr                      sex[T.male]    32yr
# Rare_sex[T.male]_CTSL_62yr                      sex[T.male]    62yr
# Rare_sex[T.male]_TMPRSS2_32yr                   sex[T.male]    32yr
# Rare_sex[T.male]_TMPRSS2_62yr                   sex[T.male]    62yr
# Submucosal_Secretory_age_ACE2_F                         age       F
# Submucosal_Secretory_age_ACE2_M                         age       M
# Submucosal_Secretory_age_CTSL_F                         age       F
# Submucosal_Secretory_age_CTSL_M                         age       M
# Submucosal_Secretory_age_TMPRSS2_F                      age       F
# Submucosal_Secretory_age_TMPRSS2_M                      age       M
# Submucosal_Secretory_sex[T.male]_ACE2_62yr      sex[T.male]    62yr
# Submucosal_Secretory_sex[T.male]_ACE2_32yr      sex[T.male]    32yr
# Submucosal_Secretory_sex[T.male]_CTSL_32yr      sex[T.male]    32yr
# Submucosal_Secretory_sex[T.male]_CTSL_62yr      sex[T.male]    62yr
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr   sex[T.male]    32yr
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr   sex[T.male]    62yr
# AT1_age_ACE2_F                                          age       F
# AT1_age_ACE2_M                                          age       M
# AT1_age_CTSL_M                                          age       M
# AT1_age_CTSL_F                                          age       F
# AT1_age_TMPRSS2_F                                       age       F
# AT1_age_TMPRSS2_M                                       age       M
# AT1_sex[T.male]_ACE2_62yr                       sex[T.male]    62yr
# AT1_sex[T.male]_ACE2_32yr                       sex[T.male]    32yr
# AT1_sex[T.male]_CTSL_32yr                       sex[T.male]    32yr
# AT1_sex[T.male]_CTSL_62yr                       sex[T.male]    62yr
# AT1_sex[T.male]_TMPRSS2_32yr                    sex[T.male]    32yr
# AT1_sex[T.male]_TMPRSS2_62yr                    sex[T.male]    62yr
# AT2_age_ACE2_F                                          age       F
# AT2_age_ACE2_M                                          age       M
# AT2_age_CTSL_F                                          age       F
# AT2_age_CTSL_M                                          age       M
# AT2_age_TMPRSS2_F                                       age       F
# AT2_age_TMPRSS2_M                                       age       M
# AT2_sex[T.male]_ACE2_62yr                       sex[T.male]    62yr
# AT2_sex[T.male]_ACE2_32yr                       sex[T.male]    32yr
# AT2_sex[T.male]_CTSL_32yr                       sex[T.male]    32yr
# AT2_sex[T.male]_CTSL_62yr                       sex[T.male]    62yr
# AT2_sex[T.male]_TMPRSS2_62yr                    sex[T.male]    62yr
# AT2_sex[T.male]_TMPRSS2_32yr                    sex[T.male]    32yr
# Arterial_age_CTSL_M                                     age       M
# Arterial_age_CTSL_F                                     age       F
# Arterial_age_TMPRSS2_M                                  age       M
# Arterial_age_TMPRSS2_F                                  age       F
# Arterial_sex[T.male]_CTSL_62yr                  sex[T.male]    62yr
# Arterial_sex[T.male]_CTSL_32yr                  sex[T.male]    32yr
# Arterial_sex[T.male]_TMPRSS2_62yr               sex[T.male]    62yr
# Arterial_sex[T.male]_TMPRSS2_32yr               sex[T.male]    32yr
# Capillary_age_ACE2_M                                    age       M
# Capillary_age_ACE2_F                                    age       F
# Capillary_age_CTSL_F                                    age       F
# Capillary_age_CTSL_M                                    age       M
# Capillary_age_TMPRSS2_M                                 age       M
# Capillary_age_TMPRSS2_F                                 age       F
# Capillary_sex[T.male]_ACE2_32yr                 sex[T.male]    32yr
# Capillary_sex[T.male]_ACE2_62yr                 sex[T.male]    62yr
# Capillary_sex[T.male]_CTSL_32yr                 sex[T.male]    32yr
# Capillary_sex[T.male]_CTSL_62yr                 sex[T.male]    62yr
# Capillary_sex[T.male]_TMPRSS2_62yr              sex[T.male]    62yr
# Capillary_sex[T.male]_TMPRSS2_32yr              sex[T.male]    32yr
# Venous_age_CTSL_M                                       age       M
# Venous_age_CTSL_F                                       age       F
# Venous_age_TMPRSS2_M                                    age       M
# Venous_age_TMPRSS2_F                                    age       F
# Venous_sex[T.male]_CTSL_62yr                    sex[T.male]    62yr
# Venous_sex[T.male]_CTSL_32yr                    sex[T.male]    32yr
# Venous_sex[T.male]_TMPRSS2_62yr                 sex[T.male]    62yr
# Venous_sex[T.male]_TMPRSS2_32yr                 sex[T.male]    32yr
# Lymphatic_EC_age_ACE2_F                                 age       F
# Lymphatic_EC_age_ACE2_M                                 age       M
# Lymphatic_EC_age_CTSL_F                                 age       F
# Lymphatic_EC_age_CTSL_M                                 age       M
# Lymphatic_EC_age_TMPRSS2_M                              age       M
# Lymphatic_EC_age_TMPRSS2_F                              age       F
# Lymphatic_EC_sex[T.male]_ACE2_32yr              sex[T.male]    32yr
# Lymphatic_EC_sex[T.male]_ACE2_62yr              sex[T.male]    62yr
# Lymphatic_EC_sex[T.male]_CTSL_32yr              sex[T.male]    32yr
# Lymphatic_EC_sex[T.male]_CTSL_62yr              sex[T.male]    62yr
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr           sex[T.male]    62yr
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr           sex[T.male]    32yr
# Fibroblasts_age_ACE2_F                                  age       F
# Fibroblasts_age_ACE2_M                                  age       M
# Fibroblasts_age_CTSL_F                                  age       F
# Fibroblasts_age_CTSL_M                                  age       M
# Fibroblasts_age_TMPRSS2_F                               age       F
# Fibroblasts_age_TMPRSS2_M                               age       M
# Fibroblasts_sex[T.male]_ACE2_32yr               sex[T.male]    32yr
# Fibroblasts_sex[T.male]_ACE2_62yr               sex[T.male]    62yr
# Fibroblasts_sex[T.male]_CTSL_32yr               sex[T.male]    32yr
# Fibroblasts_sex[T.male]_CTSL_62yr               sex[T.male]    62yr
# Fibroblasts_sex[T.male]_TMPRSS2_32yr            sex[T.male]    32yr
# Fibroblasts_sex[T.male]_TMPRSS2_62yr            sex[T.male]    62yr
# Myofibroblasts_age_CTSL_M                               age       M
# Myofibroblasts_age_CTSL_F                               age       F
# Myofibroblasts_age_TMPRSS2_F                            age       F
# Myofibroblasts_age_TMPRSS2_M                            age       M
# Myofibroblasts_sex[T.male]_CTSL_62yr            sex[T.male]    62yr
# Myofibroblasts_sex[T.male]_CTSL_32yr            sex[T.male]    32yr
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr         sex[T.male]    62yr
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr         sex[T.male]    32yr
# Airway_smooth_muscle_age_CTSL_M                         age       M
# Airway_smooth_muscle_age_CTSL_F                         age       F
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr      sex[T.male]    62yr
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr      sex[T.male]    32yr
# B_cell_lineage_age_CTSL_M                               age       M
# B_cell_lineage_age_CTSL_F                               age       F
# B_cell_lineage_age_TMPRSS2_M                            age       M
# B_cell_lineage_age_TMPRSS2_F                            age       F
# B_cell_lineage_sex[T.male]_CTSL_32yr            sex[T.male]    32yr
# B_cell_lineage_sex[T.male]_CTSL_62yr            sex[T.male]    62yr
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr         sex[T.male]    32yr
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr         sex[T.male]    62yr
# T_cell_lineage_age_ACE2_M                               age       M
# T_cell_lineage_age_ACE2_F                               age       F
# T_cell_lineage_age_CTSL_F                               age       F
# T_cell_lineage_age_CTSL_M                               age       M
# T_cell_lineage_age_TMPRSS2_M                            age       M
# T_cell_lineage_age_TMPRSS2_F                            age       F
# T_cell_lineage_sex[T.male]_ACE2_62yr            sex[T.male]    62yr
# T_cell_lineage_sex[T.male]_ACE2_32yr            sex[T.male]    32yr
# T_cell_lineage_sex[T.male]_CTSL_62yr            sex[T.male]    62yr
# T_cell_lineage_sex[T.male]_CTSL_32yr            sex[T.male]    32yr
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr         sex[T.male]    62yr
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr         sex[T.male]    32yr
# Innate_lymphoid_cells_age_CTSL_F                        age       F
# Innate_lymphoid_cells_age_CTSL_M                        age       M
# Innate_lymphoid_cells_age_TMPRSS2_M                     age       M
# Innate_lymphoid_cells_age_TMPRSS2_F                     age       F
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr     sex[T.male]    62yr
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr     sex[T.male]    32yr
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  sex[T.male]    32yr
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  sex[T.male]    62yr
# Dendritic_cells_age_CTSL_F                              age       F
# Dendritic_cells_age_CTSL_M                              age       M
# Dendritic_cells_age_TMPRSS2_F                           age       F
# Dendritic_cells_age_TMPRSS2_M                           age       M
# Dendritic_cells_sex[T.male]_CTSL_32yr           sex[T.male]    32yr
# Dendritic_cells_sex[T.male]_CTSL_62yr           sex[T.male]    62yr
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr        sex[T.male]    62yr
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr        sex[T.male]    32yr
# Macrophages_age_ACE2_F                                  age       F
# Macrophages_age_ACE2_M                                  age       M
# Macrophages_age_CTSL_F                                  age       F
# Macrophages_age_CTSL_M                                  age       M
# Macrophages_age_TMPRSS2_M                               age       M
# Macrophages_age_TMPRSS2_F                               age       F
# Macrophages_sex[T.male]_ACE2_62yr               sex[T.male]    62yr
# Macrophages_sex[T.male]_ACE2_32yr               sex[T.male]    32yr
# Macrophages_sex[T.male]_CTSL_62yr               sex[T.male]    62yr
# Macrophages_sex[T.male]_CTSL_32yr               sex[T.male]    32yr
# Macrophages_sex[T.male]_TMPRSS2_32yr            sex[T.male]    32yr
# Macrophages_sex[T.male]_TMPRSS2_62yr            sex[T.male]    62yr
# Monocytes_age_ACE2_M                                    age       M
# Monocytes_age_ACE2_F                                    age       F
# Monocytes_age_CTSL_M                                    age       M
# Monocytes_age_CTSL_F                                    age       F
# Monocytes_age_TMPRSS2_M                                 age       M
# Monocytes_age_TMPRSS2_F                                 age       F
# Monocytes_sex[T.male]_ACE2_62yr                 sex[T.male]    62yr
# Monocytes_sex[T.male]_ACE2_32yr                 sex[T.male]    32yr
# Monocytes_sex[T.male]_CTSL_62yr                 sex[T.male]    62yr
# Monocytes_sex[T.male]_CTSL_32yr                 sex[T.male]    32yr
# Monocytes_sex[T.male]_TMPRSS2_62yr              sex[T.male]    62yr
# Monocytes_sex[T.male]_TMPRSS2_32yr              sex[T.male]    32yr
# MDC_age_CTSL_M                                          age       M
# MDC_age_CTSL_F                                          age       F
# MDC_sex[T.male]_CTSL_32yr                       sex[T.male]    32yr
# MDC_sex[T.male]_CTSL_62yr                       sex[T.male]    62yr
# Mast_cells_age_CTSL_M                                   age       M
# Mast_cells_age_CTSL_F                                   age       F
# Mast_cells_age_TMPRSS2_M                                age       M
# Mast_cells_age_TMPRSS2_F                                age       F
# Mast_cells_sex[T.male]_CTSL_62yr                sex[T.male]    62yr
# Mast_cells_sex[T.male]_CTSL_32yr                sex[T.male]    32yr
# Mast_cells_sex[T.male]_TMPRSS2_32yr             sex[T.male]    32yr
# Mast_cells_sex[T.male]_TMPRSS2_62yr             sex[T.male]    62yr
#
#                                                      coef     coef_sd  \
# Basal_age_ACE2_F                                 0.001302    0.001921
# Basal_age_ACE2_M                                 0.006140    0.001642
# Basal_age_CTSL_M                                 0.006855    0.000388
# Basal_age_CTSL_F                                 0.003942    0.000417
# Basal_age_TMPRSS2_F                              0.010916    0.000858
# Basal_age_TMPRSS2_M                              0.001284    0.000590
# Basal_sex[T.male]_ACE2_62yr                      0.103370    0.061120
# Basal_sex[T.male]_ACE2_32yr                     -0.041766    0.058319
# Basal_sex[T.male]_CTSL_32yr                     -0.217960    0.012758
# Basal_sex[T.male]_CTSL_62yr                     -0.130591    0.013829
# Basal_sex[T.male]_TMPRSS2_32yr                   0.448393    0.025010
# Basal_sex[T.male]_TMPRSS2_62yr                   0.159454    0.025990
# Multiciliated_lineage_age_ACE2_F                 0.011557    0.003422
# Multiciliated_lineage_age_ACE2_M                 0.002488    0.003670
# Multiciliated_lineage_age_CTSL_M                 0.001055    0.000765
# Multiciliated_lineage_age_CTSL_F                -0.002707    0.000628
# Multiciliated_lineage_age_TMPRSS2_F              0.004044    0.000787
# Multiciliated_lineage_age_TMPRSS2_M             -0.004855    0.000850
# Multiciliated_lineage_sex[T.male]_ACE2_32yr      0.354480    0.103867
# Multiciliated_lineage_sex[T.male]_ACE2_62yr      0.082393    0.111829
# Multiciliated_lineage_sex[T.male]_CTSL_32yr     -0.103200    0.018902
# Multiciliated_lineage_sex[T.male]_CTSL_62yr      0.009646    0.023671
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr   0.288620    0.022916
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr   0.021671    0.026880
# Secretory_age_ACE2_F                             0.001639    0.004298
# Secretory_age_ACE2_M                            -0.015452    0.003907
# Secretory_age_CTSL_F                             0.005467    0.001849
# Secretory_age_CTSL_M                             0.004636    0.001935
# Secretory_age_TMPRSS2_F                         -0.007152    0.001067
# Secretory_age_TMPRSS2_M                         -0.000718    0.001037
# Secretory_sex[T.male]_ACE2_32yr                  0.507863    0.110348
# Secretory_sex[T.male]_ACE2_62yr                 -0.004864    0.102716
# Secretory_sex[T.male]_CTSL_32yr                  0.006176    0.057872
# Secretory_sex[T.male]_CTSL_62yr                 -0.018739    0.044487
# Secretory_sex[T.male]_TMPRSS2_62yr               0.349704    0.028795
# Secretory_sex[T.male]_TMPRSS2_32yr               0.156688    0.030129
# Rare_age_ACE2_F                                 -0.012184    0.032458
# Rare_age_ACE2_M                                  0.018525    0.026112
# Rare_age_CTSL_F                                  0.016175    0.004130
# Rare_age_CTSL_M                                  0.003509    0.002412
# Rare_age_TMPRSS2_M                              -0.006518    0.003634
# ...
# Macrophages_age_ACE2_M                                      Age         1
# Macrophages_age_CTSL_F                                      Age         0
# Macrophages_age_CTSL_M                                      Age         1
# Macrophages_age_TMPRSS2_M                                   Age         1
# Macrophages_age_TMPRSS2_F                                   Age         0
# Macrophages_sex[T.male]_ACE2_62yr                           Sex         1
# Macrophages_sex[T.male]_ACE2_32yr                           Sex         0
# Macrophages_sex[T.male]_CTSL_62yr                           Sex         1
# Macrophages_sex[T.male]_CTSL_32yr                           Sex         0
# Macrophages_sex[T.male]_TMPRSS2_32yr                        Sex         0
# Macrophages_sex[T.male]_TMPRSS2_62yr                        Sex         1
# Monocytes_age_ACE2_M                                        Age         1
# Monocytes_age_ACE2_F                                        Age         0
# Monocytes_age_CTSL_M                                        Age         1
# Monocytes_age_CTSL_F                                        Age         0
# Monocytes_age_TMPRSS2_M                                     Age         1
# Monocytes_age_TMPRSS2_F                                     Age         0
# Monocytes_sex[T.male]_ACE2_62yr                             Sex         1
# Monocytes_sex[T.male]_ACE2_32yr                             Sex         0
# Monocytes_sex[T.male]_CTSL_62yr                             Sex         1
# Monocytes_sex[T.male]_CTSL_32yr                             Sex         0
# Monocytes_sex[T.male]_TMPRSS2_62yr                          Sex         1
# Monocytes_sex[T.male]_TMPRSS2_32yr                          Sex         0
# MDC_age_CTSL_M                                              Age         1
# MDC_age_CTSL_F                                              Age         0
# MDC_sex[T.male]_CTSL_32yr                                   Sex         0
# MDC_sex[T.male]_CTSL_62yr                                   Sex         1
# Mast_cells_age_CTSL_M                                       Age         1
# Mast_cells_age_CTSL_F                                       Age         0
# Mast_cells_age_TMPRSS2_M                                    Age         1
# Mast_cells_age_TMPRSS2_F                                    Age         0
# Mast_cells_sex[T.male]_CTSL_62yr                            Sex         1
# Mast_cells_sex[T.male]_CTSL_32yr                            Sex         0
# Mast_cells_sex[T.male]_TMPRSS2_32yr                         Sex         0
# Mast_cells_sex[T.male]_TMPRSS2_62yr                         Sex         1
#
#                                                 gene_eval
# Basal_age_ACE2_F                                   ACE2 0
# Basal_age_ACE2_M                                   ACE2 1
# Basal_age_CTSL_M                                   CTSL 1
# Basal_age_CTSL_F                                   CTSL 0
# Basal_age_TMPRSS2_F                             TMPRSS2 0
# Basal_age_TMPRSS2_M                             TMPRSS2 1
# Basal_sex[T.male]_ACE2_62yr                        ACE2 1
# Basal_sex[T.male]_ACE2_32yr                        ACE2 0
# Basal_sex[T.male]_CTSL_32yr                        CTSL 0
# Basal_sex[T.male]_CTSL_62yr                        CTSL 1
# Basal_sex[T.male]_TMPRSS2_32yr                  TMPRSS2 0
# Basal_sex[T.male]_TMPRSS2_62yr                  TMPRSS2 1
# Multiciliated_lineage_age_ACE2_F                   ACE2 0
# Multiciliated_lineage_age_ACE2_M                   ACE2 1
# Multiciliated_lineage_age_CTSL_M                   CTSL 1
# Multiciliated_lineage_age_CTSL_F                   CTSL 0
# Multiciliated_lineage_age_TMPRSS2_F             TMPRSS2 0
# Multiciliated_lineage_age_TMPRSS2_M             TMPRSS2 1
# Multiciliated_lineage_sex[T.male]_ACE2_32yr        ACE2 0
# Multiciliated_lineage_sex[T.male]_ACE2_62yr        ACE2 1
# Multiciliated_lineage_sex[T.male]_CTSL_32yr        CTSL 0
# Multiciliated_lineage_sex[T.male]_CTSL_62yr        CTSL 1
# Multiciliated_lineage_sex[T.male]_TMPRSS2_32yr  TMPRSS2 0
# Multiciliated_lineage_sex[T.male]_TMPRSS2_62yr  TMPRSS2 1
# Secretory_age_ACE2_F                               ACE2 0
# Secretory_age_ACE2_M                               ACE2 1
# Secretory_age_CTSL_F                               CTSL 0
# Secretory_age_CTSL_M                               CTSL 1
# Secretory_age_TMPRSS2_F                         TMPRSS2 0
# Secretory_age_TMPRSS2_M                         TMPRSS2 1
# Secretory_sex[T.male]_ACE2_32yr                    ACE2 0
# Secretory_sex[T.male]_ACE2_62yr                    ACE2 1
# Secretory_sex[T.male]_CTSL_32yr                    CTSL 0
# Secretory_sex[T.male]_CTSL_62yr                    CTSL 1
# Secretory_sex[T.male]_TMPRSS2_62yr              TMPRSS2 1
# Secretory_sex[T.male]_TMPRSS2_32yr              TMPRSS2 0
# Rare_age_ACE2_F                                    ACE2 0
# Rare_age_ACE2_M                                    ACE2 1
# Rare_age_CTSL_F                                    CTSL 0
# Rare_age_CTSL_M                                    CTSL 1
# Rare_age_TMPRSS2_M                              TMPRSS2 1
# Rare_age_TMPRSS2_F                              TMPRSS2 0
# Rare_sex[T.male]_ACE2_62yr                         ACE2 1
# Rare_sex[T.male]_ACE2_32yr                         ACE2 0
# Rare_sex[T.male]_CTSL_32yr                         CTSL 0
# Rare_sex[T.male]_CTSL_62yr                         CTSL 1
# Rare_sex[T.male]_TMPRSS2_32yr                   TMPRSS2 0
# Rare_sex[T.male]_TMPRSS2_62yr                   TMPRSS2 1
# Submucosal_Secretory_age_ACE2_F                    ACE2 0
# Submucosal_Secretory_age_ACE2_M                    ACE2 1
# Submucosal_Secretory_age_CTSL_F                    CTSL 0
# Submucosal_Secretory_age_CTSL_M                    CTSL 1
# Submucosal_Secretory_age_TMPRSS2_F              TMPRSS2 0
# Submucosal_Secretory_age_TMPRSS2_M              TMPRSS2 1
# Submucosal_Secretory_sex[T.male]_ACE2_62yr         ACE2 1
# Submucosal_Secretory_sex[T.male]_ACE2_32yr         ACE2 0
# Submucosal_Secretory_sex[T.male]_CTSL_32yr         CTSL 0
# Submucosal_Secretory_sex[T.male]_CTSL_62yr         CTSL 1
# Submucosal_Secretory_sex[T.male]_TMPRSS2_32yr   TMPRSS2 0
# Submucosal_Secretory_sex[T.male]_TMPRSS2_62yr   TMPRSS2 1
# AT1_age_ACE2_F                                     ACE2 0
# AT1_age_ACE2_M                                     ACE2 1
# AT1_age_CTSL_M                                     CTSL 1
# AT1_age_CTSL_F                                     CTSL 0
# AT1_age_TMPRSS2_F                               TMPRSS2 0
# AT1_age_TMPRSS2_M                               TMPRSS2 1
# AT1_sex[T.male]_ACE2_62yr                          ACE2 1
# AT1_sex[T.male]_ACE2_32yr                          ACE2 0
# AT1_sex[T.male]_CTSL_32yr                          CTSL 0
# AT1_sex[T.male]_CTSL_62yr                          CTSL 1
# AT1_sex[T.male]_TMPRSS2_32yr                    TMPRSS2 0
# AT1_sex[T.male]_TMPRSS2_62yr                    TMPRSS2 1
# AT2_age_ACE2_F                                     ACE2 0
# AT2_age_ACE2_M                                     ACE2 1
# AT2_age_CTSL_F                                     CTSL 0
# AT2_age_CTSL_M                                     CTSL 1
# AT2_age_TMPRSS2_F                               TMPRSS2 0
# AT2_age_TMPRSS2_M                               TMPRSS2 1
# AT2_sex[T.male]_ACE2_62yr                          ACE2 1
# AT2_sex[T.male]_ACE2_32yr                          ACE2 0
# AT2_sex[T.male]_CTSL_32yr                          CTSL 0
# AT2_sex[T.male]_CTSL_62yr                          CTSL 1
# AT2_sex[T.male]_TMPRSS2_62yr                    TMPRSS2 1
# AT2_sex[T.male]_TMPRSS2_32yr                    TMPRSS2 0
# Arterial_age_CTSL_M                                CTSL 1
# Arterial_age_CTSL_F                                CTSL 0
# Arterial_age_TMPRSS2_M                          TMPRSS2 1
# Arterial_age_TMPRSS2_F                          TMPRSS2 0
# Arterial_sex[T.male]_CTSL_62yr                     CTSL 1
# Arterial_sex[T.male]_CTSL_32yr                     CTSL 0
# Arterial_sex[T.male]_TMPRSS2_62yr               TMPRSS2 1
# Arterial_sex[T.male]_TMPRSS2_32yr               TMPRSS2 0
# Capillary_age_ACE2_M                               ACE2 1
# Capillary_age_ACE2_F                               ACE2 0
# Capillary_age_CTSL_F                               CTSL 0
# Capillary_age_CTSL_M                               CTSL 1
# Capillary_age_TMPRSS2_M                         TMPRSS2 1
# Capillary_age_TMPRSS2_F                         TMPRSS2 0
# Capillary_sex[T.male]_ACE2_32yr                    ACE2 0
# Capillary_sex[T.male]_ACE2_62yr                    ACE2 1
# Capillary_sex[T.male]_CTSL_32yr                    CTSL 0
# Capillary_sex[T.male]_CTSL_62yr                    CTSL 1
# Capillary_sex[T.male]_TMPRSS2_62yr              TMPRSS2 1
# Capillary_sex[T.male]_TMPRSS2_32yr              TMPRSS2 0
# Venous_age_CTSL_M                                  CTSL 1
# Venous_age_CTSL_F                                  CTSL 0
# Venous_age_TMPRSS2_M                            TMPRSS2 1
# Venous_age_TMPRSS2_F                            TMPRSS2 0
# Venous_sex[T.male]_CTSL_62yr                       CTSL 1
# Venous_sex[T.male]_CTSL_32yr                       CTSL 0
# Venous_sex[T.male]_TMPRSS2_62yr                 TMPRSS2 1
# Venous_sex[T.male]_TMPRSS2_32yr                 TMPRSS2 0
# Lymphatic_EC_age_ACE2_F                            ACE2 0
# Lymphatic_EC_age_ACE2_M                            ACE2 1
# Lymphatic_EC_age_CTSL_F                            CTSL 0
# Lymphatic_EC_age_CTSL_M                            CTSL 1
# Lymphatic_EC_age_TMPRSS2_M                      TMPRSS2 1
# Lymphatic_EC_age_TMPRSS2_F                      TMPRSS2 0
# Lymphatic_EC_sex[T.male]_ACE2_32yr                 ACE2 0
# Lymphatic_EC_sex[T.male]_ACE2_62yr                 ACE2 1
# Lymphatic_EC_sex[T.male]_CTSL_32yr                 CTSL 0
# Lymphatic_EC_sex[T.male]_CTSL_62yr                 CTSL 1
# Lymphatic_EC_sex[T.male]_TMPRSS2_62yr           TMPRSS2 1
# Lymphatic_EC_sex[T.male]_TMPRSS2_32yr           TMPRSS2 0
# Fibroblasts_age_ACE2_F                             ACE2 0
# Fibroblasts_age_ACE2_M                             ACE2 1
# Fibroblasts_age_CTSL_F                             CTSL 0
# Fibroblasts_age_CTSL_M                             CTSL 1
# Fibroblasts_age_TMPRSS2_F                       TMPRSS2 0
# Fibroblasts_age_TMPRSS2_M                       TMPRSS2 1
# Fibroblasts_sex[T.male]_ACE2_32yr                  ACE2 0
# Fibroblasts_sex[T.male]_ACE2_62yr                  ACE2 1
# Fibroblasts_sex[T.male]_CTSL_32yr                  CTSL 0
# Fibroblasts_sex[T.male]_CTSL_62yr                  CTSL 1
# Fibroblasts_sex[T.male]_TMPRSS2_32yr            TMPRSS2 0
# Fibroblasts_sex[T.male]_TMPRSS2_62yr            TMPRSS2 1
# Myofibroblasts_age_CTSL_M                          CTSL 1
# Myofibroblasts_age_CTSL_F                          CTSL 0
# Myofibroblasts_age_TMPRSS2_F                    TMPRSS2 0
# Myofibroblasts_age_TMPRSS2_M                    TMPRSS2 1
# Myofibroblasts_sex[T.male]_CTSL_62yr               CTSL 1
# Myofibroblasts_sex[T.male]_CTSL_32yr               CTSL 0
# Myofibroblasts_sex[T.male]_TMPRSS2_62yr         TMPRSS2 1
# Myofibroblasts_sex[T.male]_TMPRSS2_32yr         TMPRSS2 0
# Airway_smooth_muscle_age_CTSL_M                    CTSL 1
# Airway_smooth_muscle_age_CTSL_F                    CTSL 0
# Airway_smooth_muscle_sex[T.male]_CTSL_62yr         CTSL 1
# Airway_smooth_muscle_sex[T.male]_CTSL_32yr         CTSL 0
# B_cell_lineage_age_CTSL_M                          CTSL 1
# B_cell_lineage_age_CTSL_F                          CTSL 0
# B_cell_lineage_age_TMPRSS2_M                    TMPRSS2 1
# B_cell_lineage_age_TMPRSS2_F                    TMPRSS2 0
# B_cell_lineage_sex[T.male]_CTSL_32yr               CTSL 0
# B_cell_lineage_sex[T.male]_CTSL_62yr               CTSL 1
# B_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2 0
# B_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2 1
# T_cell_lineage_age_ACE2_M                          ACE2 1
# T_cell_lineage_age_ACE2_F                          ACE2 0
# T_cell_lineage_age_CTSL_F                          CTSL 0
# T_cell_lineage_age_CTSL_M                          CTSL 1
# T_cell_lineage_age_TMPRSS2_M                    TMPRSS2 1
# T_cell_lineage_age_TMPRSS2_F                    TMPRSS2 0
# T_cell_lineage_sex[T.male]_ACE2_62yr               ACE2 1
# T_cell_lineage_sex[T.male]_ACE2_32yr               ACE2 0
# T_cell_lineage_sex[T.male]_CTSL_62yr               CTSL 1
# T_cell_lineage_sex[T.male]_CTSL_32yr               CTSL 0
# T_cell_lineage_sex[T.male]_TMPRSS2_62yr         TMPRSS2 1
# T_cell_lineage_sex[T.male]_TMPRSS2_32yr         TMPRSS2 0
# Innate_lymphoid_cells_age_CTSL_F                   CTSL 0
# Innate_lymphoid_cells_age_CTSL_M                   CTSL 1
# Innate_lymphoid_cells_age_TMPRSS2_M             TMPRSS2 1
# Innate_lymphoid_cells_age_TMPRSS2_F             TMPRSS2 0
# Innate_lymphoid_cells_sex[T.male]_CTSL_62yr        CTSL 1
# Innate_lymphoid_cells_sex[T.male]_CTSL_32yr        CTSL 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_32yr  TMPRSS2 0
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2_62yr  TMPRSS2 1
# Dendritic_cells_age_CTSL_F                         CTSL 0
# Dendritic_cells_age_CTSL_M                         CTSL 1
# Dendritic_cells_age_TMPRSS2_F                   TMPRSS2 0
# Dendritic_cells_age_TMPRSS2_M                   TMPRSS2 1
# Dendritic_cells_sex[T.male]_CTSL_32yr              CTSL 0
# Dendritic_cells_sex[T.male]_CTSL_62yr              CTSL 1
# Dendritic_cells_sex[T.male]_TMPRSS2_62yr        TMPRSS2 1
# Dendritic_cells_sex[T.male]_TMPRSS2_32yr        TMPRSS2 0
# Macrophages_age_ACE2_F                             ACE2 0
# Macrophages_age_ACE2_M                             ACE2 1
# Macrophages_age_CTSL_F                             CTSL 0
# Macrophages_age_CTSL_M                             CTSL 1
# Macrophages_age_TMPRSS2_M                       TMPRSS2 1
# Macrophages_age_TMPRSS2_F                       TMPRSS2 0
# Macrophages_sex[T.male]_ACE2_62yr                  ACE2 1
# Macrophages_sex[T.male]_ACE2_32yr                  ACE2 0
# Macrophages_sex[T.male]_CTSL_62yr                  CTSL 1
# Macrophages_sex[T.male]_CTSL_32yr                  CTSL 0
# Macrophages_sex[T.male]_TMPRSS2_32yr            TMPRSS2 0
# Macrophages_sex[T.male]_TMPRSS2_62yr            TMPRSS2 1
# Monocytes_age_ACE2_M                               ACE2 1
# Monocytes_age_ACE2_F                               ACE2 0
# Monocytes_age_CTSL_M                               CTSL 1
# Monocytes_age_CTSL_F                               CTSL 0
# Monocytes_age_TMPRSS2_M                         TMPRSS2 1
# Monocytes_age_TMPRSS2_F                         TMPRSS2 0
# Monocytes_sex[T.male]_ACE2_62yr                    ACE2 1
# Monocytes_sex[T.male]_ACE2_32yr                    ACE2 0
# Monocytes_sex[T.male]_CTSL_62yr                    CTSL 1
# Monocytes_sex[T.male]_CTSL_32yr                    CTSL 0
# Monocytes_sex[T.male]_TMPRSS2_62yr              TMPRSS2 1
# Monocytes_sex[T.male]_TMPRSS2_32yr              TMPRSS2 0
# MDC_age_CTSL_M                                     CTSL 1
# MDC_age_CTSL_F                                     CTSL 0
# MDC_sex[T.male]_CTSL_32yr                          CTSL 0
# MDC_sex[T.male]_CTSL_62yr                          CTSL 1
# Mast_cells_age_CTSL_M                              CTSL 1
# Mast_cells_age_CTSL_F                              CTSL 0
# Mast_cells_age_TMPRSS2_M                        TMPRSS2 1
# Mast_cells_age_TMPRSS2_F                        TMPRSS2 0
# Mast_cells_sex[T.male]_CTSL_62yr                   CTSL 1
# Mast_cells_sex[T.male]_CTSL_32yr                   CTSL 0
# Mast_cells_sex[T.male]_TMPRSS2_32yr             TMPRSS2 0
# Mast_cells_sex[T.male]_TMPRSS2_62yr             TMPRSS2 1

# %% [markdown]
# ## Level 2

# %%
res_lvl2['cell_identity'].unique()
# Out:
# array(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid',
#        'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland',
#        'Smooth Muscle', 'Lymphatics', 'Mesothelium', 'Granulocytes'],
#       dtype=object)

# %%
# Prep plotting

# Order cell identity category
res_lvl2['cell_identity'] = res_lvl2['cell_identity'].astype('category').cat.set_categories(['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium', 'Blood vessels', 'Lymphatics', 'Fibroblast lineage', 'Smooth Muscle', 'Mesothelium', 'Lymphoid', 'Myeloid', 'Granulocytes'], ordered=True)
res_lvl2 = res_lvl2.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium'], 'Endothelial':['Blood vessels', 'Lymphatics'], 'Stroma':['Fibroblast lineage', 'Smooth Muscle', 'Mesothelium'], 'Immune':['Lymphoid', 'Myeloid', 'Granulocytes']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl2['compartment'] = [ct_mapping_up[ct] for ct in res_lvl2['cell_identity']]        

# Check if bulk and sc effect directions agree
res_lvl2_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl2_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl2[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl2['coef'].loc[res_lvl2.index[i]]* res_lvl2_pseudo['coef'].loc[res_lvl2.index[i]]) > 0) for i,val in enumerate(res_lvl2['adj_pvals'])]


res_lvl2['compartment'] = res_lvl2['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl2['covariate_simple'] = res_lvl2['covariate'].astype('category').cat.rename_categories(['Age', 'Sex'])

# Assign eval_at numbers
res_lvl2 = res_lvl2.sort_values(by=['cell_identity', 'covariate', 'gene'])

eval_encoding = {
    'age':{'F':0, 'M':1},
    'sex[T.male]':{'32yr':0, '62yr':1}
}

res_lvl2['eval_num'] = [eval_encoding[res_lvl2['covariate'].loc[idx]][res_lvl2['eval_at'].loc[idx]] 
                        for idx in res_lvl2.index]

res_lvl2['gene_eval'] = [' '.join([i,str(j)]) for i,j in zip(res_lvl2['gene'], res_lvl2['eval_num'])]

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.4
for i in range(3):
    for alpha in range(2):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.2
for alpha in range(2):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(2)]

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(2.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(2)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-0.75, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(2)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [0.55, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[2], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[4], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.05, 2.2], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl2_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl2.sort_values(by=[ 'covariate', 'cell_identity',  'gene'])
# Out:
#                                                  gene        cell_identity  \
# Airway_epithelium_age_ACE2_F                     ACE2    Airway epithelium
# Airway_epithelium_age_ACE2_M                     ACE2    Airway epithelium
# Airway_epithelium_age_CTSL_M                     CTSL    Airway epithelium
# Airway_epithelium_age_CTSL_F                     CTSL    Airway epithelium
# Airway_epithelium_age_TMPRSS2_M               TMPRSS2    Airway epithelium
# Airway_epithelium_age_TMPRSS2_F               TMPRSS2    Airway epithelium
# Submucosal_Gland_age_ACE2_M                      ACE2     Submucosal Gland
# Submucosal_Gland_age_ACE2_F                      ACE2     Submucosal Gland
# Submucosal_Gland_age_CTSL_F                      CTSL     Submucosal Gland
# Submucosal_Gland_age_CTSL_M                      CTSL     Submucosal Gland
# Submucosal_Gland_age_TMPRSS2_M                TMPRSS2     Submucosal Gland
# Submucosal_Gland_age_TMPRSS2_F                TMPRSS2     Submucosal Gland
# Alveolar_epithelium_age_ACE2_M                   ACE2  Alveolar epithelium
# Alveolar_epithelium_age_ACE2_F                   ACE2  Alveolar epithelium
# Alveolar_epithelium_age_CTSL_F                   CTSL  Alveolar epithelium
# Alveolar_epithelium_age_CTSL_M                   CTSL  Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2_M             TMPRSS2  Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2_F             TMPRSS2  Alveolar epithelium
# Blood_vessels_age_ACE2_F                         ACE2        Blood vessels
# Blood_vessels_age_ACE2_M                         ACE2        Blood vessels
# Blood_vessels_age_CTSL_M                         CTSL        Blood vessels
# Blood_vessels_age_CTSL_F                         CTSL        Blood vessels
# Blood_vessels_age_TMPRSS2_F                   TMPRSS2        Blood vessels
# Blood_vessels_age_TMPRSS2_M                   TMPRSS2        Blood vessels
# Lymphatics_age_ACE2_F                            ACE2           Lymphatics
# Lymphatics_age_ACE2_M                            ACE2           Lymphatics
# Lymphatics_age_CTSL_F                            CTSL           Lymphatics
# Lymphatics_age_CTSL_M                            CTSL           Lymphatics
# Lymphatics_age_TMPRSS2_F                      TMPRSS2           Lymphatics
# Lymphatics_age_TMPRSS2_M                      TMPRSS2           Lymphatics
# Fibroblast_lineage_age_ACE2_F                    ACE2   Fibroblast lineage
# Fibroblast_lineage_age_ACE2_M                    ACE2   Fibroblast lineage
# Fibroblast_lineage_age_CTSL_M                    CTSL   Fibroblast lineage
# Fibroblast_lineage_age_CTSL_F                    CTSL   Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2_F              TMPRSS2   Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2_M              TMPRSS2   Fibroblast lineage
# Smooth_Muscle_age_ACE2_M                         ACE2        Smooth Muscle
# Smooth_Muscle_age_ACE2_F                         ACE2        Smooth Muscle
# Smooth_Muscle_age_CTSL_M                         CTSL        Smooth Muscle
# Smooth_Muscle_age_CTSL_F                         CTSL        Smooth Muscle
# Smooth_Muscle_age_TMPRSS2_M                   TMPRSS2        Smooth Muscle
# Smooth_Muscle_age_TMPRSS2_F                   TMPRSS2        Smooth Muscle
# Mesothelium_age_CTSL_M                           CTSL          Mesothelium
# Mesothelium_age_CTSL_F                           CTSL          Mesothelium
# Mesothelium_age_TMPRSS2_M                     TMPRSS2          Mesothelium
# Mesothelium_age_TMPRSS2_F                     TMPRSS2          Mesothelium
# Lymphoid_age_ACE2_M                              ACE2             Lymphoid
# Lymphoid_age_ACE2_F                              ACE2             Lymphoid
# Lymphoid_age_CTSL_M                              CTSL             Lymphoid
# Lymphoid_age_CTSL_F                              CTSL             Lymphoid
# Lymphoid_age_TMPRSS2_M                        TMPRSS2             Lymphoid
# Lymphoid_age_TMPRSS2_F                        TMPRSS2             Lymphoid
# Myeloid_age_ACE2_M                               ACE2              Myeloid
# Myeloid_age_ACE2_F                               ACE2              Myeloid
# Myeloid_age_CTSL_M                               CTSL              Myeloid
# Myeloid_age_CTSL_F                               CTSL              Myeloid
# Myeloid_age_TMPRSS2_M                         TMPRSS2              Myeloid
# Myeloid_age_TMPRSS2_F                         TMPRSS2              Myeloid
# Granulocytes_age_CTSL_F                          CTSL         Granulocytes
# Granulocytes_age_CTSL_M                          CTSL         Granulocytes
# Airway_epithelium_sex[T.male]_ACE2_62yr          ACE2    Airway epithelium
# Airway_epithelium_sex[T.male]_ACE2_32yr          ACE2    Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL_62yr          CTSL    Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL_32yr          CTSL    Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr    TMPRSS2    Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2_32yr    TMPRSS2    Airway epithelium
# Submucosal_Gland_sex[T.male]_ACE2_62yr           ACE2     Submucosal Gland
# Submucosal_Gland_sex[T.male]_ACE2_32yr           ACE2     Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL_62yr           CTSL     Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL_32yr           CTSL     Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr     TMPRSS2     Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2_32yr     TMPRSS2     Submucosal Gland
# Alveolar_epithelium_sex[T.male]_ACE2_32yr        ACE2  Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_ACE2_62yr        ACE2  Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL_62yr        CTSL  Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL_32yr        CTSL  Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr  TMPRSS2  Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2_32yr  TMPRSS2  Alveolar epithelium
# Blood_vessels_sex[T.male]_ACE2_32yr              ACE2        Blood vessels
# Blood_vessels_sex[T.male]_ACE2_62yr              ACE2        Blood vessels
# Blood_vessels_sex[T.male]_CTSL_62yr              CTSL        Blood vessels
# Blood_vessels_sex[T.male]_CTSL_32yr              CTSL        Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2_32yr        TMPRSS2        Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2_62yr        TMPRSS2        Blood vessels
# Lymphatics_sex[T.male]_ACE2_32yr                 ACE2           Lymphatics
# Lymphatics_sex[T.male]_ACE2_62yr                 ACE2           Lymphatics
# Lymphatics_sex[T.male]_CTSL_62yr                 CTSL           Lymphatics
# Lymphatics_sex[T.male]_CTSL_32yr                 CTSL           Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2_32yr           TMPRSS2           Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2_62yr           TMPRSS2           Lymphatics
# Fibroblast_lineage_sex[T.male]_ACE2_32yr         ACE2   Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_ACE2_62yr         ACE2   Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL_62yr         CTSL   Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL_32yr         CTSL   Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr   TMPRSS2   Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2_32yr   TMPRSS2   Fibroblast lineage
# Smooth_Muscle_sex[T.male]_ACE2_32yr              ACE2        Smooth Muscle
# Smooth_Muscle_sex[T.male]_ACE2_62yr              ACE2        Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL_62yr              CTSL        Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL_32yr              CTSL        Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr        TMPRSS2        Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2_32yr        TMPRSS2        Smooth Muscle
# Mesothelium_sex[T.male]_CTSL_62yr                CTSL          Mesothelium
# Mesothelium_sex[T.male]_CTSL_32yr                CTSL          Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2_32yr          TMPRSS2          Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2_62yr          TMPRSS2          Mesothelium
# Lymphoid_sex[T.male]_ACE2_32yr                   ACE2             Lymphoid
# Lymphoid_sex[T.male]_ACE2_62yr                   ACE2             Lymphoid
# Lymphoid_sex[T.male]_CTSL_32yr                   CTSL             Lymphoid
# Lymphoid_sex[T.male]_CTSL_62yr                   CTSL             Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2_62yr             TMPRSS2             Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2_32yr             TMPRSS2             Lymphoid
# Myeloid_sex[T.male]_ACE2_32yr                    ACE2              Myeloid
# Myeloid_sex[T.male]_ACE2_62yr                    ACE2              Myeloid
# Myeloid_sex[T.male]_CTSL_62yr                    CTSL              Myeloid
# Myeloid_sex[T.male]_CTSL_32yr                    CTSL              Myeloid
# Myeloid_sex[T.male]_TMPRSS2_62yr              TMPRSS2              Myeloid
# Myeloid_sex[T.male]_TMPRSS2_32yr              TMPRSS2              Myeloid
# Granulocytes_sex[T.male]_CTSL_32yr               CTSL         Granulocytes
# Granulocytes_sex[T.male]_CTSL_62yr               CTSL         Granulocytes
#
#                                                 covariate eval_at      coef  \
# Airway_epithelium_age_ACE2_F                          age       F  0.004849
# Airway_epithelium_age_ACE2_M                          age       M  0.002382
# Airway_epithelium_age_CTSL_M                          age       M  0.005605
# Airway_epithelium_age_CTSL_F                          age       F  0.001715
# Airway_epithelium_age_TMPRSS2_M                       age       M -0.001499
# Airway_epithelium_age_TMPRSS2_F                       age       F  0.003398
# Submucosal_Gland_age_ACE2_M                           age       M  0.010597
# Submucosal_Gland_age_ACE2_F                           age       F  0.001151
# Submucosal_Gland_age_CTSL_F                           age       F  0.003188
# Submucosal_Gland_age_CTSL_M                           age       M  0.010335
# Submucosal_Gland_age_TMPRSS2_M                        age       M -0.006296
# Submucosal_Gland_age_TMPRSS2_F                        age       F  0.011020
# Alveolar_epithelium_age_ACE2_M                        age       M  0.010225
# Alveolar_epithelium_age_ACE2_F                        age       F  0.015845
# Alveolar_epithelium_age_CTSL_F                        age       F -0.004984
# Alveolar_epithelium_age_CTSL_M                        age       M -0.004454
# Alveolar_epithelium_age_TMPRSS2_M                     age       M  0.008018
# Alveolar_epithelium_age_TMPRSS2_F                     age       F  0.025354
# Blood_vessels_age_ACE2_F                              age       F  0.001558
# Blood_vessels_age_ACE2_M                              age       M -0.012802
# Blood_vessels_age_CTSL_M                              age       M -0.000888
# Blood_vessels_age_CTSL_F                              age       F  0.008912
# Blood_vessels_age_TMPRSS2_F                           age       F  0.002390
# Blood_vessels_age_TMPRSS2_M                           age       M -0.003150
# Lymphatics_age_ACE2_F                                 age       F  0.075025
# Lymphatics_age_ACE2_M                                 age       M  0.052436
# Lymphatics_age_CTSL_F                                 age       F  0.005075
# Lymphatics_age_CTSL_M                                 age       M  0.004098
# Lymphatics_age_TMPRSS2_F                              age       F -0.011480
# Lymphatics_age_TMPRSS2_M                              age       M  0.002230
# Fibroblast_lineage_age_ACE2_F                         age       F  0.013793
# Fibroblast_lineage_age_ACE2_M                         age       M -0.014771
# Fibroblast_lineage_age_CTSL_M                         age       M  0.005038
# Fibroblast_lineage_age_CTSL_F                         age       F -0.024474
# Fibroblast_lineage_age_TMPRSS2_F                      age       F  0.006864
# Fibroblast_lineage_age_TMPRSS2_M                      age       M  0.009228
# Smooth_Muscle_age_ACE2_M                              age       M -0.006100
# Smooth_Muscle_age_ACE2_F                              age       F  0.005748
# Smooth_Muscle_age_CTSL_M                              age       M -0.000936
# Smooth_Muscle_age_CTSL_F                              age       F -0.015667
# Smooth_Muscle_age_TMPRSS2_M                           age       M -0.005781
# Smooth_Muscle_age_TMPRSS2_F                           age       F  0.014451
# Mesothelium_age_CTSL_M                                age       M -0.015282
# Mesothelium_age_CTSL_F                                age       F  0.002693
# Mesothelium_age_TMPRSS2_M                             age       M  0.155022
# Mesothelium_age_TMPRSS2_F                             age       F  0.054293
# Lymphoid_age_ACE2_M                                   age       M -0.027558
# Lymphoid_age_ACE2_F                                   age       F -0.028911
# Lymphoid_age_CTSL_M                                   age       M  0.024636
# Lymphoid_age_CTSL_F                                   age       F -0.010385
# Lymphoid_age_TMPRSS2_M                                age       M -0.012595
# Lymphoid_age_TMPRSS2_F                                age       F -0.002770
# Myeloid_age_ACE2_M                                    age       M -0.012150
# Myeloid_age_ACE2_F                                    age       F  0.015873
# Myeloid_age_CTSL_M                                    age       M  0.001099
# Myeloid_age_CTSL_F                                    age       F -0.002814
# Myeloid_age_TMPRSS2_M                                 age       M -0.005261
# Myeloid_age_TMPRSS2_F                                 age       F -0.000341
# Granulocytes_age_CTSL_F                               age       F -0.019195
# Granulocytes_age_CTSL_M                               age       M -0.079483
# Airway_epithelium_sex[T.male]_ACE2_62yr       sex[T.male]    62yr  0.026012
# Airway_epithelium_sex[T.male]_ACE2_32yr       sex[T.male]    32yr  0.100034
# Airway_epithelium_sex[T.male]_CTSL_62yr       sex[T.male]    62yr -0.061157
# Airway_epithelium_sex[T.male]_CTSL_32yr       sex[T.male]    32yr -0.177850
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr    sex[T.male]    62yr  0.104907
# Airway_epithelium_sex[T.male]_TMPRSS2_32yr    sex[T.male]    32yr  0.251825
# Submucosal_Gland_sex[T.male]_ACE2_62yr        sex[T.male]    62yr  0.248496
# Submucosal_Gland_sex[T.male]_ACE2_32yr        sex[T.male]    32yr -0.034899
# Submucosal_Gland_sex[T.male]_CTSL_62yr        sex[T.male]    62yr  0.029085
# Submucosal_Gland_sex[T.male]_CTSL_32yr        sex[T.male]    32yr -0.185336
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr     sex[T.male]    62yr -0.106174
# Submucosal_Gland_sex[T.male]_TMPRSS2_32yr     sex[T.male]    32yr  0.413305
# Alveolar_epithelium_sex[T.male]_ACE2_32yr     sex[T.male]    32yr  0.888541
# Alveolar_epithelium_sex[T.male]_ACE2_62yr     sex[T.male]    62yr  0.719960
# Alveolar_epithelium_sex[T.male]_CTSL_62yr     sex[T.male]    62yr  0.155479
# Alveolar_epithelium_sex[T.male]_CTSL_32yr     sex[T.male]    32yr  0.139600
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr  sex[T.male]    62yr -0.118468
# Alveolar_epithelium_sex[T.male]_TMPRSS2_32yr  sex[T.male]    32yr  0.401614
# Blood_vessels_sex[T.male]_ACE2_32yr           sex[T.male]    32yr  1.395216
# Blood_vessels_sex[T.male]_ACE2_62yr           sex[T.male]    62yr  0.964407
# Blood_vessels_sex[T.male]_CTSL_62yr           sex[T.male]    62yr -0.029766
# Blood_vessels_sex[T.male]_CTSL_32yr           sex[T.male]    32yr  0.264209
# Blood_vessels_sex[T.male]_TMPRSS2_32yr        sex[T.male]    32yr  0.334456
# Blood_vessels_sex[T.male]_TMPRSS2_62yr        sex[T.male]    62yr  0.168263
# Lymphatics_sex[T.male]_ACE2_32yr              sex[T.male]    32yr  2.024032
# Lymphatics_sex[T.male]_ACE2_62yr              sex[T.male]    62yr  1.346348
# Lymphatics_sex[T.male]_CTSL_62yr              sex[T.male]    62yr  0.003411
# Lymphatics_sex[T.male]_CTSL_32yr              sex[T.male]    32yr  0.032719
# Lymphatics_sex[T.male]_TMPRSS2_32yr           sex[T.male]    32yr  0.443611
# Lymphatics_sex[T.male]_TMPRSS2_62yr           sex[T.male]    62yr  0.854917
# Fibroblast_lineage_sex[T.male]_ACE2_32yr      sex[T.male]    32yr  0.394325
# Fibroblast_lineage_sex[T.male]_ACE2_62yr      sex[T.male]    62yr -0.462597
# Fibroblast_lineage_sex[T.male]_CTSL_62yr      sex[T.male]    62yr  0.340884
# Fibroblast_lineage_sex[T.male]_CTSL_32yr      sex[T.male]    32yr -0.544475
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr   sex[T.male]    62yr  0.335332
# Fibroblast_lineage_sex[T.male]_TMPRSS2_32yr   sex[T.male]    32yr  0.264396
# Smooth_Muscle_sex[T.male]_ACE2_32yr           sex[T.male]    32yr  0.295840
# Smooth_Muscle_sex[T.male]_ACE2_62yr           sex[T.male]    62yr -0.059604
# Smooth_Muscle_sex[T.male]_CTSL_62yr           sex[T.male]    62yr  0.004667
# Smooth_Muscle_sex[T.male]_CTSL_32yr           sex[T.male]    32yr -0.437256
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr        sex[T.male]    62yr -0.433593
# Smooth_Muscle_sex[T.male]_TMPRSS2_32yr        sex[T.male]    32yr  0.173371
# Mesothelium_sex[T.male]_CTSL_62yr             sex[T.male]    62yr  0.120770
# Mesothelium_sex[T.male]_CTSL_32yr             sex[T.male]    32yr  0.660019
# Mesothelium_sex[T.male]_TMPRSS2_32yr          sex[T.male]    32yr -3.034692
# Mesothelium_sex[T.male]_TMPRSS2_62yr          sex[T.male]    62yr -0.012819
# Lymphoid_sex[T.male]_ACE2_32yr                sex[T.male]    32yr  0.298552
# Lymphoid_sex[T.male]_ACE2_62yr                sex[T.male]    62yr  0.339136
# Lymphoid_sex[T.male]_CTSL_32yr                sex[T.male]    32yr -0.327362
# Lymphoid_sex[T.male]_CTSL_62yr                sex[T.male]    62yr  0.723250
# Lymphoid_sex[T.male]_TMPRSS2_62yr             sex[T.male]    62yr  0.184087
# Lymphoid_sex[T.male]_TMPRSS2_32yr             sex[T.male]    32yr  0.478823
# Myeloid_sex[T.male]_ACE2_32yr                 sex[T.male]    32yr  0.994277
# Myeloid_sex[T.male]_ACE2_62yr                 sex[T.male]    62yr  0.153591
# Myeloid_sex[T.male]_CTSL_62yr                 sex[T.male]    62yr -0.043937
# Myeloid_sex[T.male]_CTSL_32yr                 sex[T.male]    32yr -0.161315
# Myeloid_sex[T.male]_TMPRSS2_62yr              sex[T.male]    62yr  0.478947
# Myeloid_sex[T.male]_TMPRSS2_32yr              sex[T.male]    32yr  0.626547
# Granulocytes_sex[T.male]_CTSL_32yr            sex[T.male]    32yr  2.574039
# Granulocytes_sex[T.male]_CTSL_62yr            sex[T.male]    62yr  0.765410
#
#                                                coef_sd          pval  \
# Airway_epithelium_age_ACE2_F                  0.001574  2.059883e-03
# Airway_epithelium_age_ACE2_M                  0.001308  6.873417e-02
# Airway_epithelium_age_CTSL_M                  0.000318  0.000000e+00
# Airway_epithelium_age_CTSL_F                  0.000342  5.483837e-07
# Airway_epithelium_age_TMPRSS2_M               0.000394  1.396106e-04
# Airway_epithelium_age_TMPRSS2_F               0.000496  7.133849e-12
# Submucosal_Gland_age_ACE2_M                   0.003481  2.329719e-03
# Submucosal_Gland_age_ACE2_F                   0.003013  7.025407e-01
# Submucosal_Gland_age_CTSL_F                   0.000952  8.177602e-04
# Submucosal_Gland_age_CTSL_M                   0.000950  0.000000e+00
# Submucosal_Gland_age_TMPRSS2_M                0.000809  6.883383e-15
# Submucosal_Gland_age_TMPRSS2_F                0.000903  0.000000e+00
# Alveolar_epithelium_age_ACE2_M                0.002777  2.310765e-04
# Alveolar_epithelium_age_ACE2_F                0.001631  0.000000e+00
# Alveolar_epithelium_age_CTSL_F                0.000325  0.000000e+00
# Alveolar_epithelium_age_CTSL_M                0.000637  2.761680e-12
# Alveolar_epithelium_age_TMPRSS2_M             0.000358  0.000000e+00
# Alveolar_epithelium_age_TMPRSS2_F             0.000230  0.000000e+00
# Blood_vessels_age_ACE2_F                      0.013920  9.108669e-01
# Blood_vessels_age_ACE2_M                      0.014988  3.930362e-01
# Blood_vessels_age_CTSL_M                      0.000816  2.766235e-01
# Blood_vessels_age_CTSL_F                      0.001321  1.495992e-11
# Blood_vessels_age_TMPRSS2_F                   0.010067  8.123358e-01
# Blood_vessels_age_TMPRSS2_M                   0.007679  6.816759e-01
# Lymphatics_age_ACE2_F                         0.034740  3.080293e-02
# Lymphatics_age_ACE2_M                         0.039964  1.894963e-01
# Lymphatics_age_CTSL_F                         0.001757  3.878470e-03
# Lymphatics_age_CTSL_M                         0.001755  1.951928e-02
# Lymphatics_age_TMPRSS2_F                      0.006462  7.564682e-02
# Lymphatics_age_TMPRSS2_M                      0.011253  8.429151e-01
# Fibroblast_lineage_age_ACE2_F                 0.006097  2.368065e-02
# Fibroblast_lineage_age_ACE2_M                 0.007243  4.141011e-02
# Fibroblast_lineage_age_CTSL_M                 0.000325  0.000000e+00
# Fibroblast_lineage_age_CTSL_F                 0.000208  0.000000e+00
# Fibroblast_lineage_age_TMPRSS2_F              0.001966  4.803202e-04
# Fibroblast_lineage_age_TMPRSS2_M              0.004914  6.040099e-02
# Smooth_Muscle_age_ACE2_M                      0.015419  6.924081e-01
# Smooth_Muscle_age_ACE2_F                      0.017159  7.376251e-01
# Smooth_Muscle_age_CTSL_M                      0.000863  2.779533e-01
# Smooth_Muscle_age_CTSL_F                      0.000627  0.000000e+00
# Smooth_Muscle_age_TMPRSS2_M                   0.008738  5.082455e-01
# Smooth_Muscle_age_TMPRSS2_F                   0.006313  2.207685e-02
# Mesothelium_age_CTSL_M                        0.005780  8.197092e-03
# Mesothelium_age_CTSL_F                        0.002173  2.152382e-01
# Mesothelium_age_TMPRSS2_M                     0.129005  2.294902e-01
# Mesothelium_age_TMPRSS2_F                     0.012662  1.802830e-05
# Lymphoid_age_ACE2_M                           0.014907  6.450773e-02
# Lymphoid_age_ACE2_F                           0.015002  5.396352e-02
# Lymphoid_age_CTSL_M                           0.001192  0.000000e+00
# Lymphoid_age_CTSL_F                           0.001025  0.000000e+00
# Lymphoid_age_TMPRSS2_M                        0.004202  2.721216e-03
# Lymphoid_age_TMPRSS2_F                        0.002775  3.181951e-01
# Myeloid_age_ACE2_M                            0.008231  1.399257e-01
# Myeloid_age_ACE2_F                            0.008312  5.616867e-02
# Myeloid_age_CTSL_M                            0.000098  0.000000e+00
# Myeloid_age_CTSL_F                            0.000094  0.000000e+00
# Myeloid_age_TMPRSS2_M                         0.002303  2.232904e-02
# Myeloid_age_TMPRSS2_F                         0.001830  8.522688e-01
# Granulocytes_age_CTSL_F                       0.011078  8.315761e-02
# Granulocytes_age_CTSL_M                       0.036916  3.131516e-02
# Airway_epithelium_sex[T.male]_ACE2_62yr       0.046047  5.721392e-01
# Airway_epithelium_sex[T.male]_ACE2_32yr       0.045824  2.903340e-02
# Airway_epithelium_sex[T.male]_CTSL_62yr       0.011144  4.067273e-08
# Airway_epithelium_sex[T.male]_CTSL_32yr       0.010181  0.000000e+00
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr    0.015044  3.096967e-12
# Airway_epithelium_sex[T.male]_TMPRSS2_32yr    0.014075  0.000000e+00
# Submucosal_Gland_sex[T.male]_ACE2_62yr        0.151703  1.014129e-01
# Submucosal_Gland_sex[T.male]_ACE2_32yr        0.095501  7.147945e-01
# Submucosal_Gland_sex[T.male]_CTSL_62yr        0.036549  4.261644e-01
# Submucosal_Gland_sex[T.male]_CTSL_32yr        0.030048  6.913184e-10
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr     0.038178  5.419051e-03
# Submucosal_Gland_sex[T.male]_TMPRSS2_32yr     0.026981  0.000000e+00
# Alveolar_epithelium_sex[T.male]_ACE2_32yr     0.064718  0.000000e+00
# Alveolar_epithelium_sex[T.male]_ACE2_62yr     0.071947  0.000000e+00
# Alveolar_epithelium_sex[T.male]_CTSL_62yr     0.016183  0.000000e+00
# Alveolar_epithelium_sex[T.male]_CTSL_32yr     0.014821  0.000000e+00
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr  0.008021  0.000000e+00
# Alveolar_epithelium_sex[T.male]_TMPRSS2_32yr  0.009370  0.000000e+00
# Blood_vessels_sex[T.male]_ACE2_32yr           0.551240  1.137219e-02
# Blood_vessels_sex[T.male]_ACE2_62yr           0.416512  2.058904e-02
# Blood_vessels_sex[T.male]_CTSL_62yr           0.024733  2.287991e-01
# Blood_vessels_sex[T.male]_CTSL_32yr           0.033197  1.776357e-15
# Blood_vessels_sex[T.male]_TMPRSS2_32yr        0.281389  2.346011e-01
# Blood_vessels_sex[T.male]_TMPRSS2_62yr        0.232463  4.691728e-01
# Lymphatics_sex[T.male]_ACE2_32yr              1.702070  2.343770e-01
# Lymphatics_sex[T.male]_ACE2_62yr              0.679204  4.745185e-02
# Lymphatics_sex[T.male]_CTSL_62yr              0.035234  9.228774e-01
# Lymphatics_sex[T.male]_CTSL_32yr              0.051862  5.281232e-01
# Lymphatics_sex[T.male]_TMPRSS2_32yr           0.261140  8.936633e-02
# Lymphatics_sex[T.male]_TMPRSS2_62yr           0.246965  5.367919e-04
# Fibroblast_lineage_sex[T.male]_ACE2_32yr      0.184338  3.242445e-02
# Fibroblast_lineage_sex[T.male]_ACE2_62yr      0.222845  3.790639e-02
# Fibroblast_lineage_sex[T.male]_CTSL_62yr      0.009491  0.000000e+00
# Fibroblast_lineage_sex[T.male]_CTSL_32yr      0.006629  0.000000e+00
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr   0.096671  5.228141e-04
# Fibroblast_lineage_sex[T.male]_TMPRSS2_32yr   0.091178  3.734214e-03
# Smooth_Muscle_sex[T.male]_ACE2_32yr           0.482445  5.397380e-01
# Smooth_Muscle_sex[T.male]_ACE2_62yr           0.661535  9.282078e-01
# Smooth_Muscle_sex[T.male]_CTSL_62yr           0.034782  8.932530e-01
# Smooth_Muscle_sex[T.male]_CTSL_32yr           0.023761  0.000000e+00
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr        0.392612  2.694281e-01
# Smooth_Muscle_sex[T.male]_TMPRSS2_32yr        0.256072  4.983816e-01
# Mesothelium_sex[T.male]_CTSL_62yr             0.122213  3.230581e-01
# Mesothelium_sex[T.male]_CTSL_32yr             0.090753  3.523848e-13
# Mesothelium_sex[T.male]_TMPRSS2_32yr          1.828514  9.698504e-02
# Mesothelium_sex[T.male]_TMPRSS2_62yr          2.130015  9.951983e-01
# Lymphoid_sex[T.male]_ACE2_32yr                0.370453  4.202953e-01
# Lymphoid_sex[T.male]_ACE2_62yr                0.539761  5.298018e-01
# Lymphoid_sex[T.male]_CTSL_32yr                0.039861  2.220446e-16
# Lymphoid_sex[T.male]_CTSL_62yr                0.027440  0.000000e+00
# Lymphoid_sex[T.male]_TMPRSS2_62yr             0.102476  7.243220e-02
# Lymphoid_sex[T.male]_TMPRSS2_32yr             0.100806  2.034438e-06
# Myeloid_sex[T.male]_ACE2_32yr                 0.269131  2.204139e-04
# Myeloid_sex[T.male]_ACE2_62yr                 0.242150  5.258983e-01
# Myeloid_sex[T.male]_CTSL_62yr                 0.002881  0.000000e+00
# Myeloid_sex[T.male]_CTSL_32yr                 0.002873  0.000000e+00
# Myeloid_sex[T.male]_TMPRSS2_62yr              0.058551  3.330669e-16
# Myeloid_sex[T.male]_TMPRSS2_32yr              0.059655  0.000000e+00
# Granulocytes_sex[T.male]_CTSL_32yr            1.438810  7.361391e-02
# Granulocytes_sex[T.male]_CTSL_62yr            0.388822  4.900656e-02
#
#                                                  adj_pvals  compartment  \
# Airway_epithelium_age_ACE2_F                  2.746511e-03   Epithelial
# Airway_epithelium_age_ACE2_M                  7.498273e-02   Epithelial
# Airway_epithelium_age_CTSL_M                  0.000000e+00   Epithelial
# Airway_epithelium_age_CTSL_F                  9.400863e-07   Epithelial
# Airway_epithelium_age_TMPRSS2_M               2.094160e-04   Epithelial
# Airway_epithelium_age_TMPRSS2_F               1.712124e-11   Epithelial
# Submucosal_Gland_age_ACE2_M                   3.993804e-03   Epithelial
# Submucosal_Gland_age_ACE2_F                   7.147945e-01   Epithelial
# Submucosal_Gland_age_CTSL_F                   1.635520e-03   Epithelial
# Submucosal_Gland_age_CTSL_M                   0.000000e+00   Epithelial
# Submucosal_Gland_age_TMPRSS2_M                2.065015e-14   Epithelial
# Submucosal_Gland_age_TMPRSS2_F                0.000000e+00   Epithelial
# Alveolar_epithelium_age_ACE2_M                2.310765e-04   Epithelial
# Alveolar_epithelium_age_ACE2_F                0.000000e+00   Epithelial
# Alveolar_epithelium_age_CTSL_F                0.000000e+00   Epithelial
# Alveolar_epithelium_age_CTSL_M                3.012742e-12   Epithelial
# Alveolar_epithelium_age_TMPRSS2_M             0.000000e+00   Epithelial
# Alveolar_epithelium_age_TMPRSS2_F             0.000000e+00   Epithelial
# Blood_vessels_age_ACE2_F                      9.108669e-01  Endothelial
# Blood_vessels_age_ACE2_M                      5.895543e-01  Endothelial
# Blood_vessels_age_CTSL_M                      4.742118e-01  Endothelial
# Blood_vessels_age_CTSL_F                      8.975953e-11  Endothelial
# Blood_vessels_age_TMPRSS2_F                   8.861845e-01  Endothelial
# Blood_vessels_age_TMPRSS2_M                   8.180110e-01  Endothelial
# Lymphatics_age_ACE2_F                         9.240879e-02  Endothelial
# Lymphatics_age_ACE2_M                         2.842445e-01  Endothelial
# Lymphatics_age_CTSL_F                         2.327082e-02  Endothelial
# Lymphatics_age_CTSL_M                         7.807710e-02  Endothelial
# Lymphatics_age_TMPRSS2_F                      1.512936e-01  Endothelial
# Lymphatics_age_TMPRSS2_M                      9.195438e-01  Endothelial
# Fibroblast_lineage_age_ACE2_F                 3.552097e-02       Stroma
# Fibroblast_lineage_age_ACE2_M                 4.517467e-02       Stroma
# Fibroblast_lineage_age_CTSL_M                 0.000000e+00       Stroma
# Fibroblast_lineage_age_CTSL_F                 0.000000e+00       Stroma
# Fibroblast_lineage_age_TMPRSS2_F              1.045628e-03       Stroma
# Fibroblast_lineage_age_TMPRSS2_M              6.040099e-02       Stroma
# Smooth_Muscle_age_ACE2_M                      8.851502e-01       Stroma
# Smooth_Muscle_age_ACE2_F                      8.851502e-01       Stroma
# Smooth_Muscle_age_CTSL_M                      6.670879e-01       Stroma
# Smooth_Muscle_age_CTSL_F                      0.000000e+00       Stroma
# Smooth_Muscle_age_TMPRSS2_M                   8.096070e-01       Stroma
# Smooth_Muscle_age_TMPRSS2_F                   8.830740e-02       Stroma
# Mesothelium_age_CTSL_M                        2.185891e-02       Stroma
# Mesothelium_age_CTSL_F                        3.059869e-01       Stroma
# Mesothelium_age_TMPRSS2_M                     3.059869e-01       Stroma
# Mesothelium_age_TMPRSS2_F                     7.211321e-05       Stroma
# Lymphoid_age_ACE2_M                           9.657627e-02       Immune
# Lymphoid_age_ACE2_F                           9.250889e-02       Immune
# Lymphoid_age_CTSL_M                           0.000000e+00       Immune
# Lymphoid_age_CTSL_F                           0.000000e+00       Immune
# Lymphoid_age_TMPRSS2_M                        5.442431e-03       Immune
# Lymphoid_age_TMPRSS2_F                        3.818342e-01       Immune
# Myeloid_age_ACE2_M                            1.679108e-01       Immune
# Myeloid_age_ACE2_F                            7.489156e-02       Immune
# Myeloid_age_CTSL_M                            0.000000e+00       Immune
# Myeloid_age_CTSL_F                            0.000000e+00       Immune
# Myeloid_age_TMPRSS2_M                         3.349357e-02       Immune
# Myeloid_age_TMPRSS2_F                         8.522688e-01       Immune
# Granulocytes_age_CTSL_F                       8.315761e-02       Immune
# Granulocytes_age_CTSL_M                       8.315761e-02       Immune
# Airway_epithelium_sex[T.male]_ACE2_62yr       5.721392e-01   Epithelial
# Airway_epithelium_sex[T.male]_ACE2_32yr       3.484008e-02   Epithelial
# Airway_epithelium_sex[T.male]_CTSL_62yr       8.134546e-08   Epithelial
# Airway_epithelium_sex[T.male]_CTSL_32yr       0.000000e+00   Epithelial
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr    9.290901e-12   Epithelial
# Airway_epithelium_sex[T.male]_TMPRSS2_32yr    0.000000e+00   Epithelial
# Submucosal_Gland_sex[T.male]_ACE2_62yr        1.352172e-01   Epithelial
# Submucosal_Gland_sex[T.male]_ACE2_32yr        7.147945e-01   Epithelial
# Submucosal_Gland_sex[T.male]_CTSL_62yr        5.113973e-01   Epithelial
# Submucosal_Gland_sex[T.male]_CTSL_32yr        1.659164e-09   Epithelial
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr     8.128577e-03   Epithelial
# Submucosal_Gland_sex[T.male]_TMPRSS2_32yr     0.000000e+00   Epithelial
# Alveolar_epithelium_sex[T.male]_ACE2_32yr     0.000000e+00   Epithelial
# Alveolar_epithelium_sex[T.male]_ACE2_62yr     0.000000e+00   Epithelial
# Alveolar_epithelium_sex[T.male]_CTSL_62yr     0.000000e+00   Epithelial
# Alveolar_epithelium_sex[T.male]_CTSL_32yr     0.000000e+00   Epithelial
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr  0.000000e+00   Epithelial
# Alveolar_epithelium_sex[T.male]_TMPRSS2_32yr  0.000000e+00   Epithelial
# Blood_vessels_sex[T.male]_ACE2_32yr           4.548876e-02  Endothelial
# Blood_vessels_sex[T.male]_ACE2_62yr           6.176713e-02  Endothelial
# Blood_vessels_sex[T.male]_CTSL_62yr           4.692021e-01  Endothelial
# Blood_vessels_sex[T.male]_CTSL_32yr           2.131628e-14  Endothelial
# Blood_vessels_sex[T.male]_TMPRSS2_32yr        4.692021e-01  Endothelial
# Blood_vessels_sex[T.male]_TMPRSS2_62yr        6.255637e-01  Endothelial
# Lymphatics_sex[T.male]_ACE2_32yr              3.125027e-01  Endothelial
# Lymphatics_sex[T.male]_ACE2_62yr              1.138844e-01  Endothelial
# Lymphatics_sex[T.male]_CTSL_62yr              9.228774e-01  Endothelial
# Lymphatics_sex[T.male]_CTSL_32yr              6.337479e-01  Endothelial
# Lymphatics_sex[T.male]_TMPRSS2_32yr           1.531994e-01  Endothelial
# Lymphatics_sex[T.male]_TMPRSS2_62yr           6.441503e-03  Endothelial
# Fibroblast_lineage_sex[T.male]_ACE2_32yr      4.323260e-02       Stroma
# Fibroblast_lineage_sex[T.male]_ACE2_62yr      4.517467e-02       Stroma
# Fibroblast_lineage_sex[T.male]_CTSL_62yr      0.000000e+00       Stroma
# Fibroblast_lineage_sex[T.male]_CTSL_32yr      0.000000e+00       Stroma
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr   1.045628e-03       Stroma
# Fibroblast_lineage_sex[T.male]_TMPRSS2_32yr   6.401509e-03       Stroma
# Smooth_Muscle_sex[T.male]_ACE2_32yr           8.096070e-01       Stroma
# Smooth_Muscle_sex[T.male]_ACE2_62yr           9.282078e-01       Stroma
# Smooth_Muscle_sex[T.male]_CTSL_62yr           9.282078e-01       Stroma
# Smooth_Muscle_sex[T.male]_CTSL_32yr           0.000000e+00       Stroma
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr        6.670879e-01       Stroma
# Smooth_Muscle_sex[T.male]_TMPRSS2_32yr        8.096070e-01       Stroma
# Mesothelium_sex[T.male]_CTSL_62yr             3.692093e-01       Stroma
# Mesothelium_sex[T.male]_CTSL_32yr             2.819078e-12       Stroma
# Mesothelium_sex[T.male]_TMPRSS2_32yr          1.939701e-01       Stroma
# Mesothelium_sex[T.male]_TMPRSS2_62yr          9.951983e-01       Stroma
# Lymphoid_sex[T.male]_ACE2_32yr                4.585039e-01       Immune
# Lymphoid_sex[T.male]_ACE2_62yr                5.298018e-01       Immune
# Lymphoid_sex[T.male]_CTSL_32yr                6.661338e-16       Immune
# Lymphoid_sex[T.male]_CTSL_62yr                0.000000e+00       Immune
# Lymphoid_sex[T.male]_TMPRSS2_62yr             9.657627e-02       Immune
# Lymphoid_sex[T.male]_TMPRSS2_32yr             4.882651e-06       Immune
# Myeloid_sex[T.male]_ACE2_32yr                 3.778524e-04       Immune
# Myeloid_sex[T.male]_ACE2_62yr                 5.737072e-01       Immune
# Myeloid_sex[T.male]_CTSL_62yr                 0.000000e+00       Immune
# Myeloid_sex[T.male]_CTSL_32yr                 0.000000e+00       Immune
# Myeloid_sex[T.male]_TMPRSS2_62yr              6.661338e-16       Immune
# Myeloid_sex[T.male]_TMPRSS2_32yr              0.000000e+00       Immune
# Granulocytes_sex[T.male]_CTSL_32yr            8.315761e-02       Immune
# Granulocytes_sex[T.male]_CTSL_62yr            8.315761e-02       Immune
#
#                                               signif_bulk_agree  \
# Airway_epithelium_age_ACE2_F                              False
# Airway_epithelium_age_ACE2_M                              False
# Airway_epithelium_age_CTSL_M                              False
# Airway_epithelium_age_CTSL_F                               True
# Airway_epithelium_age_TMPRSS2_M                            True
# Airway_epithelium_age_TMPRSS2_F                           False
# Submucosal_Gland_age_ACE2_M                               False
# Submucosal_Gland_age_ACE2_F                               False
# Submucosal_Gland_age_CTSL_F                               False
# Submucosal_Gland_age_CTSL_M                                True
# Submucosal_Gland_age_TMPRSS2_M                             True
# Submucosal_Gland_age_TMPRSS2_F                             True
# Alveolar_epithelium_age_ACE2_M                             True
# Alveolar_epithelium_age_ACE2_F                             True
# Alveolar_epithelium_age_CTSL_F                             True
# Alveolar_epithelium_age_CTSL_M                             True
# Alveolar_epithelium_age_TMPRSS2_M                          True
# Alveolar_epithelium_age_TMPRSS2_F                          True
# Blood_vessels_age_ACE2_F                                  False
# Blood_vessels_age_ACE2_M                                  False
# Blood_vessels_age_CTSL_M                                  False
# Blood_vessels_age_CTSL_F                                   True
# Blood_vessels_age_TMPRSS2_F                               False
# Blood_vessels_age_TMPRSS2_M                               False
# Lymphatics_age_ACE2_F                                     False
# Lymphatics_age_ACE2_M                                     False
# Lymphatics_age_CTSL_F                                      True
# Lymphatics_age_CTSL_M                                     False
# Lymphatics_age_TMPRSS2_F                                  False
# Lymphatics_age_TMPRSS2_M                                  False
# Fibroblast_lineage_age_ACE2_F                             False
# Fibroblast_lineage_age_ACE2_M                              True
# Fibroblast_lineage_age_CTSL_M                              True
# Fibroblast_lineage_age_CTSL_F                              True
# Fibroblast_lineage_age_TMPRSS2_F                           True
# Fibroblast_lineage_age_TMPRSS2_M                          False
# Smooth_Muscle_age_ACE2_M                                  False
# Smooth_Muscle_age_ACE2_F                                  False
# Smooth_Muscle_age_CTSL_M                                  False
# Smooth_Muscle_age_CTSL_F                                   True
# Smooth_Muscle_age_TMPRSS2_M                               False
# Smooth_Muscle_age_TMPRSS2_F                               False
# Mesothelium_age_CTSL_M                                     True
# Mesothelium_age_CTSL_F                                    False
# Mesothelium_age_TMPRSS2_M                                 False
# Mesothelium_age_TMPRSS2_F                                  True
# Lymphoid_age_ACE2_M                                       False
# Lymphoid_age_ACE2_F                                       False
# Lymphoid_age_CTSL_M                                        True
# Lymphoid_age_CTSL_F                                       False
# Lymphoid_age_TMPRSS2_M                                    False
# Lymphoid_age_TMPRSS2_F                                    False
# Myeloid_age_ACE2_M                                        False
# Myeloid_age_ACE2_F                                        False
# Myeloid_age_CTSL_M                                         True
# Myeloid_age_CTSL_F                                         True
# Myeloid_age_TMPRSS2_M                                      True
# Myeloid_age_TMPRSS2_F                                     False
# Granulocytes_age_CTSL_F                                   False
# Granulocytes_age_CTSL_M                                   False
# Airway_epithelium_sex[T.male]_ACE2_62yr                   False
# Airway_epithelium_sex[T.male]_ACE2_32yr                    True
# Airway_epithelium_sex[T.male]_CTSL_62yr                    True
# Airway_epithelium_sex[T.male]_CTSL_32yr                   False
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr                 True
# Airway_epithelium_sex[T.male]_TMPRSS2_32yr                 True
# Submucosal_Gland_sex[T.male]_ACE2_62yr                    False
# Submucosal_Gland_sex[T.male]_ACE2_32yr                    False
# Submucosal_Gland_sex[T.male]_CTSL_62yr                    False
# Submucosal_Gland_sex[T.male]_CTSL_32yr                     True
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr                  True
# Submucosal_Gland_sex[T.male]_TMPRSS2_32yr                  True
# Alveolar_epithelium_sex[T.male]_ACE2_32yr                  True
# Alveolar_epithelium_sex[T.male]_ACE2_62yr                 False
# Alveolar_epithelium_sex[T.male]_CTSL_62yr                  True
# Alveolar_epithelium_sex[T.male]_CTSL_32yr                  True
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr              False
# Alveolar_epithelium_sex[T.male]_TMPRSS2_32yr               True
# Blood_vessels_sex[T.male]_ACE2_32yr                       False
# Blood_vessels_sex[T.male]_ACE2_62yr                       False
# Blood_vessels_sex[T.male]_CTSL_62yr                       False
# Blood_vessels_sex[T.male]_CTSL_32yr                        True
# Blood_vessels_sex[T.male]_TMPRSS2_32yr                    False
# Blood_vessels_sex[T.male]_TMPRSS2_62yr                    False
# Lymphatics_sex[T.male]_ACE2_32yr                          False
# Lymphatics_sex[T.male]_ACE2_62yr                          False
# Lymphatics_sex[T.male]_CTSL_62yr                          False
# Lymphatics_sex[T.male]_CTSL_32yr                          False
# Lymphatics_sex[T.male]_TMPRSS2_32yr                       False
# Lymphatics_sex[T.male]_TMPRSS2_62yr                        True
# Fibroblast_lineage_sex[T.male]_ACE2_32yr                   True
# Fibroblast_lineage_sex[T.male]_ACE2_62yr                  False
# Fibroblast_lineage_sex[T.male]_CTSL_62yr                  False
# Fibroblast_lineage_sex[T.male]_CTSL_32yr                   True
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr                True
# Fibroblast_lineage_sex[T.male]_TMPRSS2_32yr                True
# Smooth_Muscle_sex[T.male]_ACE2_32yr                       False
# Smooth_Muscle_sex[T.male]_ACE2_62yr                       False
# Smooth_Muscle_sex[T.male]_CTSL_62yr                       False
# Smooth_Muscle_sex[T.male]_CTSL_32yr                        True
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr                    False
# Smooth_Muscle_sex[T.male]_TMPRSS2_32yr                    False
# Mesothelium_sex[T.male]_CTSL_62yr                         False
# Mesothelium_sex[T.male]_CTSL_32yr                          True
# Mesothelium_sex[T.male]_TMPRSS2_32yr                      False
# Mesothelium_sex[T.male]_TMPRSS2_62yr                      False
# Lymphoid_sex[T.male]_ACE2_32yr                            False
# Lymphoid_sex[T.male]_ACE2_62yr                            False
# Lymphoid_sex[T.male]_CTSL_32yr                             True
# Lymphoid_sex[T.male]_CTSL_62yr                             True
# Lymphoid_sex[T.male]_TMPRSS2_62yr                         False
# Lymphoid_sex[T.male]_TMPRSS2_32yr                          True
# Myeloid_sex[T.male]_ACE2_32yr                              True
# Myeloid_sex[T.male]_ACE2_62yr                             False
# Myeloid_sex[T.male]_CTSL_62yr                             False
# Myeloid_sex[T.male]_CTSL_32yr                              True
# Myeloid_sex[T.male]_TMPRSS2_62yr                           True
# Myeloid_sex[T.male]_TMPRSS2_32yr                           True
# Granulocytes_sex[T.male]_CTSL_32yr                        False
# Granulocytes_sex[T.male]_CTSL_62yr                        False
#
#                                              covariate_simple  eval_num  \
# Airway_epithelium_age_ACE2_F                              Age         0
# Airway_epithelium_age_ACE2_M                              Age         1
# Airway_epithelium_age_CTSL_M                              Age         1
# Airway_epithelium_age_CTSL_F                              Age         0
# Airway_epithelium_age_TMPRSS2_M                           Age         1
# Airway_epithelium_age_TMPRSS2_F                           Age         0
# Submucosal_Gland_age_ACE2_M                               Age         1
# Submucosal_Gland_age_ACE2_F                               Age         0
# Submucosal_Gland_age_CTSL_F                               Age         0
# Submucosal_Gland_age_CTSL_M                               Age         1
# Submucosal_Gland_age_TMPRSS2_M                            Age         1
# Submucosal_Gland_age_TMPRSS2_F                            Age         0
# Alveolar_epithelium_age_ACE2_M                            Age         1
# Alveolar_epithelium_age_ACE2_F                            Age         0
# Alveolar_epithelium_age_CTSL_F                            Age         0
# Alveolar_epithelium_age_CTSL_M                            Age         1
# Alveolar_epithelium_age_TMPRSS2_M                         Age         1
# Alveolar_epithelium_age_TMPRSS2_F                         Age         0
# Blood_vessels_age_ACE2_F                                  Age         0
# Blood_vessels_age_ACE2_M                                  Age         1
# Blood_vessels_age_CTSL_M                                  Age         1
# Blood_vessels_age_CTSL_F                                  Age         0
# Blood_vessels_age_TMPRSS2_F                               Age         0
# Blood_vessels_age_TMPRSS2_M                               Age         1
# Lymphatics_age_ACE2_F                                     Age         0
# Lymphatics_age_ACE2_M                                     Age         1
# Lymphatics_age_CTSL_F                                     Age         0
# Lymphatics_age_CTSL_M                                     Age         1
# Lymphatics_age_TMPRSS2_F                                  Age         0
# Lymphatics_age_TMPRSS2_M                                  Age         1
# Fibroblast_lineage_age_ACE2_F                             Age         0
# Fibroblast_lineage_age_ACE2_M                             Age         1
# Fibroblast_lineage_age_CTSL_M                             Age         1
# Fibroblast_lineage_age_CTSL_F                             Age         0
# Fibroblast_lineage_age_TMPRSS2_F                          Age         0
# Fibroblast_lineage_age_TMPRSS2_M                          Age         1
# Smooth_Muscle_age_ACE2_M                                  Age         1
# Smooth_Muscle_age_ACE2_F                                  Age         0
# Smooth_Muscle_age_CTSL_M                                  Age         1
# Smooth_Muscle_age_CTSL_F                                  Age         0
# Smooth_Muscle_age_TMPRSS2_M                               Age         1
# Smooth_Muscle_age_TMPRSS2_F                               Age         0
# Mesothelium_age_CTSL_M                                    Age         1
# Mesothelium_age_CTSL_F                                    Age         0
# Mesothelium_age_TMPRSS2_M                                 Age         1
# Mesothelium_age_TMPRSS2_F                                 Age         0
# Lymphoid_age_ACE2_M                                       Age         1
# Lymphoid_age_ACE2_F                                       Age         0
# Lymphoid_age_CTSL_M                                       Age         1
# Lymphoid_age_CTSL_F                                       Age         0
# Lymphoid_age_TMPRSS2_M                                    Age         1
# Lymphoid_age_TMPRSS2_F                                    Age         0
# Myeloid_age_ACE2_M                                        Age         1
# Myeloid_age_ACE2_F                                        Age         0
# Myeloid_age_CTSL_M                                        Age         1
# Myeloid_age_CTSL_F                                        Age         0
# Myeloid_age_TMPRSS2_M                                     Age         1
# Myeloid_age_TMPRSS2_F                                     Age         0
# Granulocytes_age_CTSL_F                                   Age         0
# Granulocytes_age_CTSL_M                                   Age         1
# Airway_epithelium_sex[T.male]_ACE2_62yr                   Sex         1
# Airway_epithelium_sex[T.male]_ACE2_32yr                   Sex         0
# Airway_epithelium_sex[T.male]_CTSL_62yr                   Sex         1
# Airway_epithelium_sex[T.male]_CTSL_32yr                   Sex         0
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr                Sex         1
# Airway_epithelium_sex[T.male]_TMPRSS2_32yr                Sex         0
# Submucosal_Gland_sex[T.male]_ACE2_62yr                    Sex         1
# Submucosal_Gland_sex[T.male]_ACE2_32yr                    Sex         0
# Submucosal_Gland_sex[T.male]_CTSL_62yr                    Sex         1
# Submucosal_Gland_sex[T.male]_CTSL_32yr                    Sex         0
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr                 Sex         1
# Submucosal_Gland_sex[T.male]_TMPRSS2_32yr                 Sex         0
# Alveolar_epithelium_sex[T.male]_ACE2_32yr                 Sex         0
# Alveolar_epithelium_sex[T.male]_ACE2_62yr                 Sex         1
# Alveolar_epithelium_sex[T.male]_CTSL_62yr                 Sex         1
# Alveolar_epithelium_sex[T.male]_CTSL_32yr                 Sex         0
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr              Sex         1
# Alveolar_epithelium_sex[T.male]_TMPRSS2_32yr              Sex         0
# Blood_vessels_sex[T.male]_ACE2_32yr                       Sex         0
# Blood_vessels_sex[T.male]_ACE2_62yr                       Sex         1
# Blood_vessels_sex[T.male]_CTSL_62yr                       Sex         1
# Blood_vessels_sex[T.male]_CTSL_32yr                       Sex         0
# Blood_vessels_sex[T.male]_TMPRSS2_32yr                    Sex         0
# Blood_vessels_sex[T.male]_TMPRSS2_62yr                    Sex         1
# Lymphatics_sex[T.male]_ACE2_32yr                          Sex         0
# Lymphatics_sex[T.male]_ACE2_62yr                          Sex         1
# Lymphatics_sex[T.male]_CTSL_62yr                          Sex         1
# Lymphatics_sex[T.male]_CTSL_32yr                          Sex         0
# Lymphatics_sex[T.male]_TMPRSS2_32yr                       Sex         0
# Lymphatics_sex[T.male]_TMPRSS2_62yr                       Sex         1
# Fibroblast_lineage_sex[T.male]_ACE2_32yr                  Sex         0
# Fibroblast_lineage_sex[T.male]_ACE2_62yr                  Sex         1
# Fibroblast_lineage_sex[T.male]_CTSL_62yr                  Sex         1
# Fibroblast_lineage_sex[T.male]_CTSL_32yr                  Sex         0
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr               Sex         1
# Fibroblast_lineage_sex[T.male]_TMPRSS2_32yr               Sex         0
# Smooth_Muscle_sex[T.male]_ACE2_32yr                       Sex         0
# Smooth_Muscle_sex[T.male]_ACE2_62yr                       Sex         1
# Smooth_Muscle_sex[T.male]_CTSL_62yr                       Sex         1
# Smooth_Muscle_sex[T.male]_CTSL_32yr                       Sex         0
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr                    Sex         1
# Smooth_Muscle_sex[T.male]_TMPRSS2_32yr                    Sex         0
# Mesothelium_sex[T.male]_CTSL_62yr                         Sex         1
# Mesothelium_sex[T.male]_CTSL_32yr                         Sex         0
# Mesothelium_sex[T.male]_TMPRSS2_32yr                      Sex         0
# Mesothelium_sex[T.male]_TMPRSS2_62yr                      Sex         1
# Lymphoid_sex[T.male]_ACE2_32yr                            Sex         0
# Lymphoid_sex[T.male]_ACE2_62yr                            Sex         1
# Lymphoid_sex[T.male]_CTSL_32yr                            Sex         0
# Lymphoid_sex[T.male]_CTSL_62yr                            Sex         1
# Lymphoid_sex[T.male]_TMPRSS2_62yr                         Sex         1
# Lymphoid_sex[T.male]_TMPRSS2_32yr                         Sex         0
# Myeloid_sex[T.male]_ACE2_32yr                             Sex         0
# Myeloid_sex[T.male]_ACE2_62yr                             Sex         1
# Myeloid_sex[T.male]_CTSL_62yr                             Sex         1
# Myeloid_sex[T.male]_CTSL_32yr                             Sex         0
# Myeloid_sex[T.male]_TMPRSS2_62yr                          Sex         1
# Myeloid_sex[T.male]_TMPRSS2_32yr                          Sex         0
# Granulocytes_sex[T.male]_CTSL_32yr                        Sex         0
# Granulocytes_sex[T.male]_CTSL_62yr                        Sex         1
#
#                                               gene_eval
# Airway_epithelium_age_ACE2_F                     ACE2 0
# Airway_epithelium_age_ACE2_M                     ACE2 1
# Airway_epithelium_age_CTSL_M                     CTSL 1
# Airway_epithelium_age_CTSL_F                     CTSL 0
# Airway_epithelium_age_TMPRSS2_M               TMPRSS2 1
# Airway_epithelium_age_TMPRSS2_F               TMPRSS2 0
# Submucosal_Gland_age_ACE2_M                      ACE2 1
# Submucosal_Gland_age_ACE2_F                      ACE2 0
# Submucosal_Gland_age_CTSL_F                      CTSL 0
# Submucosal_Gland_age_CTSL_M                      CTSL 1
# Submucosal_Gland_age_TMPRSS2_M                TMPRSS2 1
# Submucosal_Gland_age_TMPRSS2_F                TMPRSS2 0
# Alveolar_epithelium_age_ACE2_M                   ACE2 1
# Alveolar_epithelium_age_ACE2_F                   ACE2 0
# Alveolar_epithelium_age_CTSL_F                   CTSL 0
# Alveolar_epithelium_age_CTSL_M                   CTSL 1
# Alveolar_epithelium_age_TMPRSS2_M             TMPRSS2 1
# Alveolar_epithelium_age_TMPRSS2_F             TMPRSS2 0
# Blood_vessels_age_ACE2_F                         ACE2 0
# Blood_vessels_age_ACE2_M                         ACE2 1
# Blood_vessels_age_CTSL_M                         CTSL 1
# Blood_vessels_age_CTSL_F                         CTSL 0
# Blood_vessels_age_TMPRSS2_F                   TMPRSS2 0
# Blood_vessels_age_TMPRSS2_M                   TMPRSS2 1
# Lymphatics_age_ACE2_F                            ACE2 0
# Lymphatics_age_ACE2_M                            ACE2 1
# Lymphatics_age_CTSL_F                            CTSL 0
# Lymphatics_age_CTSL_M                            CTSL 1
# Lymphatics_age_TMPRSS2_F                      TMPRSS2 0
# Lymphatics_age_TMPRSS2_M                      TMPRSS2 1
# Fibroblast_lineage_age_ACE2_F                    ACE2 0
# Fibroblast_lineage_age_ACE2_M                    ACE2 1
# Fibroblast_lineage_age_CTSL_M                    CTSL 1
# Fibroblast_lineage_age_CTSL_F                    CTSL 0
# Fibroblast_lineage_age_TMPRSS2_F              TMPRSS2 0
# Fibroblast_lineage_age_TMPRSS2_M              TMPRSS2 1
# Smooth_Muscle_age_ACE2_M                         ACE2 1
# Smooth_Muscle_age_ACE2_F                         ACE2 0
# Smooth_Muscle_age_CTSL_M                         CTSL 1
# Smooth_Muscle_age_CTSL_F                         CTSL 0
# Smooth_Muscle_age_TMPRSS2_M                   TMPRSS2 1
# Smooth_Muscle_age_TMPRSS2_F                   TMPRSS2 0
# Mesothelium_age_CTSL_M                           CTSL 1
# Mesothelium_age_CTSL_F                           CTSL 0
# Mesothelium_age_TMPRSS2_M                     TMPRSS2 1
# Mesothelium_age_TMPRSS2_F                     TMPRSS2 0
# Lymphoid_age_ACE2_M                              ACE2 1
# Lymphoid_age_ACE2_F                              ACE2 0
# Lymphoid_age_CTSL_M                              CTSL 1
# Lymphoid_age_CTSL_F                              CTSL 0
# Lymphoid_age_TMPRSS2_M                        TMPRSS2 1
# Lymphoid_age_TMPRSS2_F                        TMPRSS2 0
# Myeloid_age_ACE2_M                               ACE2 1
# Myeloid_age_ACE2_F                               ACE2 0
# Myeloid_age_CTSL_M                               CTSL 1
# Myeloid_age_CTSL_F                               CTSL 0
# Myeloid_age_TMPRSS2_M                         TMPRSS2 1
# Myeloid_age_TMPRSS2_F                         TMPRSS2 0
# Granulocytes_age_CTSL_F                          CTSL 0
# Granulocytes_age_CTSL_M                          CTSL 1
# Airway_epithelium_sex[T.male]_ACE2_62yr          ACE2 1
# Airway_epithelium_sex[T.male]_ACE2_32yr          ACE2 0
# Airway_epithelium_sex[T.male]_CTSL_62yr          CTSL 1
# Airway_epithelium_sex[T.male]_CTSL_32yr          CTSL 0
# Airway_epithelium_sex[T.male]_TMPRSS2_62yr    TMPRSS2 1
# Airway_epithelium_sex[T.male]_TMPRSS2_32yr    TMPRSS2 0
# Submucosal_Gland_sex[T.male]_ACE2_62yr           ACE2 1
# Submucosal_Gland_sex[T.male]_ACE2_32yr           ACE2 0
# Submucosal_Gland_sex[T.male]_CTSL_62yr           CTSL 1
# Submucosal_Gland_sex[T.male]_CTSL_32yr           CTSL 0
# Submucosal_Gland_sex[T.male]_TMPRSS2_62yr     TMPRSS2 1
# Submucosal_Gland_sex[T.male]_TMPRSS2_32yr     TMPRSS2 0
# Alveolar_epithelium_sex[T.male]_ACE2_32yr        ACE2 0
# Alveolar_epithelium_sex[T.male]_ACE2_62yr        ACE2 1
# Alveolar_epithelium_sex[T.male]_CTSL_62yr        CTSL 1
# Alveolar_epithelium_sex[T.male]_CTSL_32yr        CTSL 0
# Alveolar_epithelium_sex[T.male]_TMPRSS2_62yr  TMPRSS2 1
# Alveolar_epithelium_sex[T.male]_TMPRSS2_32yr  TMPRSS2 0
# Blood_vessels_sex[T.male]_ACE2_32yr              ACE2 0
# Blood_vessels_sex[T.male]_ACE2_62yr              ACE2 1
# Blood_vessels_sex[T.male]_CTSL_62yr              CTSL 1
# Blood_vessels_sex[T.male]_CTSL_32yr              CTSL 0
# Blood_vessels_sex[T.male]_TMPRSS2_32yr        TMPRSS2 0
# Blood_vessels_sex[T.male]_TMPRSS2_62yr        TMPRSS2 1
# Lymphatics_sex[T.male]_ACE2_32yr                 ACE2 0
# Lymphatics_sex[T.male]_ACE2_62yr                 ACE2 1
# Lymphatics_sex[T.male]_CTSL_62yr                 CTSL 1
# Lymphatics_sex[T.male]_CTSL_32yr                 CTSL 0
# Lymphatics_sex[T.male]_TMPRSS2_32yr           TMPRSS2 0
# Lymphatics_sex[T.male]_TMPRSS2_62yr           TMPRSS2 1
# Fibroblast_lineage_sex[T.male]_ACE2_32yr         ACE2 0
# Fibroblast_lineage_sex[T.male]_ACE2_62yr         ACE2 1
# Fibroblast_lineage_sex[T.male]_CTSL_62yr         CTSL 1
# Fibroblast_lineage_sex[T.male]_CTSL_32yr         CTSL 0
# Fibroblast_lineage_sex[T.male]_TMPRSS2_62yr   TMPRSS2 1
# Fibroblast_lineage_sex[T.male]_TMPRSS2_32yr   TMPRSS2 0
# Smooth_Muscle_sex[T.male]_ACE2_32yr              ACE2 0
# Smooth_Muscle_sex[T.male]_ACE2_62yr              ACE2 1
# Smooth_Muscle_sex[T.male]_CTSL_62yr              CTSL 1
# Smooth_Muscle_sex[T.male]_CTSL_32yr              CTSL 0
# Smooth_Muscle_sex[T.male]_TMPRSS2_62yr        TMPRSS2 1
# Smooth_Muscle_sex[T.male]_TMPRSS2_32yr        TMPRSS2 0
# Mesothelium_sex[T.male]_CTSL_62yr                CTSL 1
# Mesothelium_sex[T.male]_CTSL_32yr                CTSL 0
# Mesothelium_sex[T.male]_TMPRSS2_32yr          TMPRSS2 0
# Mesothelium_sex[T.male]_TMPRSS2_62yr          TMPRSS2 1
# Lymphoid_sex[T.male]_ACE2_32yr                   ACE2 0
# Lymphoid_sex[T.male]_ACE2_62yr                   ACE2 1
# Lymphoid_sex[T.male]_CTSL_32yr                   CTSL 0
# Lymphoid_sex[T.male]_CTSL_62yr                   CTSL 1
# Lymphoid_sex[T.male]_TMPRSS2_62yr             TMPRSS2 1
# Lymphoid_sex[T.male]_TMPRSS2_32yr             TMPRSS2 0
# Myeloid_sex[T.male]_ACE2_32yr                    ACE2 0
# Myeloid_sex[T.male]_ACE2_62yr                    ACE2 1
# Myeloid_sex[T.male]_CTSL_62yr                    CTSL 1
# Myeloid_sex[T.male]_CTSL_32yr                    CTSL 0
# Myeloid_sex[T.male]_TMPRSS2_62yr              TMPRSS2 1
# Myeloid_sex[T.male]_TMPRSS2_32yr              TMPRSS2 0
# Granulocytes_sex[T.male]_CTSL_32yr               CTSL 0
# Granulocytes_sex[T.male]_CTSL_62yr               CTSL 1

# %%
color_base = sns.color_palette('colorblind')[:3]

colors = []
d_alpha = 0.2
for i in range(3):
    for alpha in range(2):
        col = lighten_color(color_base[i], amount=1-(alpha*d_alpha))
        colors.append(col)
    
base_grey = (0.5,0.5,0.5)    
shades = []
d_alpha = 0.4
for alpha in range(2):
    shade = lighten_color(base_grey, amount=1-(alpha*d_alpha))
    shades.append(shade)

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']
gene_eval_order = [' '.join([g, str(i)]) for g in gene_order for i in range(2)]

cat_order = ['Age', 'Sex']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene_eval'

xlims_top = [[None, None],
             [None, None],
             [0.08, None],
             [None, 1.5]]
xlims_bot = [[None, None],
             [None, None],
             [None, -0.7],
             [-0.04, None]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_eval_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-(2.5))*bar_width for i,g in enumerate(gene_eval_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene_eval'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_eval_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

#Age legend
age_labs = [j[0] for j in sorted(list(eval_encoding['age'].items()), key=lambda i: i[1])]
age_handles = [patches.Patch(color=shades[i], label=age_labs[i]) for i in range(2)]
leg_age = plt.legend(handles=age_handles, bbox_to_anchor = [-0.75, -0.1], frameon=False, title=None)

#Sex legend
sex_labs = [j[0] for j in sorted(list(eval_encoding['sex[T.male]'].items()), key=lambda i: i[1])]
sex_handles = [patches.Patch(color=shades[i], label=sex_labs[i]) for i in range(2)]
leg_sex = plt.legend(handles=sex_handles, bbox_to_anchor = [0.55, -0.1], frameon=False, title=None)

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[2], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[4], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.05, 2.2], frameon=False, title=None)

plt.gca().add_artist(leg_age)
plt.gca().add_artist(leg_sex)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_testInts_annlvl2_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# (-0.008739158505536422, 0.02721866631957206)
# <ErrorbarContainer object of 3 artists>
# (-0.2738162407805002, 1.0116920417027178)
# <ErrorbarContainer object of 3 artists>
# (-0.017193342822806768, 0.07941663280232768)
# <ErrorbarContainer object of 3 artists>
# (-0.1324555415571013, 2.126721550662437)
# <ErrorbarContainer object of 3 artists>
# (-0.03366727211628494, 0.08)
# <ErrorbarContainer object of 3 artists>
# (-0.7, 0.9400451325398719)
# <ErrorbarContainer object of 3 artists>
# (-0.04, 0.031093306054889108)
# <ErrorbarContainer object of 3 artists>
# (-0.5142864793237671, 1.5)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')
