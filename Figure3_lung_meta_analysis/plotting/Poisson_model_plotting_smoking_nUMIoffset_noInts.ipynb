# %% [markdown]
# This notebook contains the plotting functions used to plot the results of the meta-analysis without interaction terms (Figure 3d, Extended Data Figure 9, and Supplementary Figures 4). Note that the model results with interaction terms are taken into account in these plots.

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rcParams
from matplotlib import colors, patches
import seaborn as sns
import logging, warnings
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
plt.rcParams['figure.figsize']=(8,8) #rescale figures
sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 35)
warnings.filterwarnings("ignore", category=DeprecationWarning, module="tensorflow")
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.18.1 scipy==1.4.1 pandas==1.0.1 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.0 louvain==0.6.1

# %%
#User inputs
folder = '/storage/groups/ml01/workspace/malte.luecken/2020_cov19_study'

output_folder = 'diffxpy_out/'

base = 'COVID19_lung_atlas_revision_v3_lung_cov19_poissonglm_smoking'

# %%
res_lvl2_ints = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ints_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_full.csv', index_col=0)
res_lvl2_ints_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl2_summary.csv', index_col=0)
res_lvl2_ints_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl2_full.csv', index_col=0)

# %%
res_lvl2 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_noInts_lvl2_full.csv', index_col=0)
res_lvl2_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl2_full.csv', index_col=0)
res_lvl2_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl2_summary.csv', index_col=0)
res_lvl2_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_noInts_lvl2_full.csv', index_col=0)

# %%
res_lvl3_ints = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ints_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_full.csv', index_col=0)
res_lvl3_ints_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_testInts_lvl3_summary.csv', index_col=0)
res_lvl3_ints_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_testInts_lvl3_full.csv', index_col=0)

# %%
res_lvl3 = pd.read_csv(folder+'/'+output_folder+base+'_nUMIoffset_noInts_lvl3_full.csv', index_col=0)
res_lvl3_ho = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl3_full.csv', index_col=0)
res_lvl3_ho_summary = pd.read_csv(folder+'/'+output_folder+base+'_holdouts_nUMIoffset_noInts_lvl3_summary.csv', index_col=0)
res_lvl3_pseudo = pd.read_csv(folder+'/'+output_folder+base+'_pseudo_nUMIoffset_noInts_lvl3_full.csv', index_col=0)

# %%
res_lvl3.head()
# Out:
#       gene cell_identity               covariate      coef   coef_sd  \
# 0     ACE2   Macrophages             sex[T.male]  0.079347  0.268355
# 1     ACE2   Macrophages                     age  0.006745  0.006974
# 2     ACE2   Macrophages  smoking_status[T.True] -0.183397  0.328642
# 3  TMPRSS2   Macrophages             sex[T.male] -0.331306  0.072662
# 4  TMPRSS2   Macrophages                     age -0.003322  0.002135
#
#        pval  adj_pvals
# 0  0.767475   0.767475
# 1  0.333406   0.428664
# 2  0.576814   0.648916
# 3  0.000005   0.000012
# 4  0.119689   0.210039

# %%
res_lvl3.dtypes
# Out:
# gene              object
# cell_identity     object
# covariate         object
# coef             float64
# coef_sd          float64
# pval             float64
# adj_pvals        float64
# dtype: object

# %% [markdown]
# # Plotting

# %%
sns.set(font_scale=2.5, style='white')

# %%
res_lvl3['cell_identity'].unique()
# Out:
# array(['Macrophages', 'Basal', 'AT2', 'T cell lineage', 'Monocytes',
#        'Multiciliated lineage', 'Submucosal Secretory', 'AT1',
#        'Innate lymphoid cells', 'Secretory', 'Capillary', 'Mast cells',
#        'B cell lineage', 'Fibroblasts', 'Dendritic cells', 'Venous',
#        'Lymphatic EC', 'Arterial', 'Rare', 'Airway smooth muscle'],
#       dtype=object)

# %%
res_lvl3.head()
res_lvl3_ints.head()
# Out:
#       gene cell_identity               covariate      coef   coef_sd  \
# 0     ACE2   Macrophages             sex[T.male]  0.079347  0.268355
# 1     ACE2   Macrophages                     age  0.006745  0.006974
# 2     ACE2   Macrophages  smoking_status[T.True] -0.183397  0.328642
# 3  TMPRSS2   Macrophages             sex[T.male] -0.331306  0.072662
# 4  TMPRSS2   Macrophages                     age -0.003322  0.002135
#
#        pval  adj_pvals
# 0  0.767475   0.767475
# 1  0.333406   0.428664
# 2  0.576814   0.648916
# 3  0.000005   0.000012
# 4  0.119689   0.210039
#    gene cell_identity    covariate  eval_at      coef   coef_sd      pval  \
# 0  ACE2   Macrophages  sex[T.male]  31yr NS  0.815131  0.363377  0.024883
# 1  ACE2   Macrophages  sex[T.male]   31yr S  0.103947  0.766362  0.892108
# 2  ACE2   Macrophages  sex[T.male]  62yr NS -0.621819  0.501752  0.215236
# 3  ACE2   Macrophages  sex[T.male]   62yr S -1.333003  0.584259  0.022517
# 4  ACE2   Macrophages          age     F NS  0.021959  0.009962  0.027511
#
#    adj_pvals
# 0   0.049766
# 1   0.917597
# 2   0.286981
# 3   0.047683
# 4   0.052126

# %%
res_lvl3
# Out:
#         gene          cell_identity               covariate      coef  \
# 0       ACE2            Macrophages             sex[T.male]  0.079347
# 1       ACE2            Macrophages                     age  0.006745
# 2       ACE2            Macrophages  smoking_status[T.True] -0.183397
# 3    TMPRSS2            Macrophages             sex[T.male] -0.331306
# 4    TMPRSS2            Macrophages                     age -0.003322
# 5    TMPRSS2            Macrophages  smoking_status[T.True]  0.134248
# 6       CTSL            Macrophages             sex[T.male] -0.167304
# 7       CTSL            Macrophages                     age  0.002582
# 8       CTSL            Macrophages  smoking_status[T.True]  0.100365
# 9       ACE2                  Basal             sex[T.male]  0.050698
# 10      ACE2                  Basal                     age  0.003719
# 11      ACE2                  Basal  smoking_status[T.True]  0.191025
# 12   TMPRSS2                  Basal             sex[T.male]  0.294338
# 13   TMPRSS2                  Basal                     age  0.005119
# 14   TMPRSS2                  Basal  smoking_status[T.True] -0.360639
# 15      CTSL                  Basal             sex[T.male] -0.167472
# 16      CTSL                  Basal                     age  0.005348
# 17      CTSL                  Basal  smoking_status[T.True]  0.077169
# 18      ACE2                    AT2             sex[T.male]  0.827769
# 19      ACE2                    AT2                     age  0.019122
# 20      ACE2                    AT2  smoking_status[T.True] -0.406943
# 21   TMPRSS2                    AT2             sex[T.male] -0.004434
# 22   TMPRSS2                    AT2                     age  0.021023
# 23   TMPRSS2                    AT2  smoking_status[T.True]  0.136431
# 24      CTSL                    AT2             sex[T.male]  0.104171
# 25      CTSL                    AT2                     age -0.005396
# 26      CTSL                    AT2  smoking_status[T.True]  0.113451
# 27      ACE2         T cell lineage             sex[T.male]  0.614737
# 28      ACE2         T cell lineage                     age -0.011035
# 29      ACE2         T cell lineage  smoking_status[T.True] -0.724578
# 30   TMPRSS2         T cell lineage             sex[T.male]  0.389809
# 31   TMPRSS2         T cell lineage                     age -0.005053
# 32   TMPRSS2         T cell lineage  smoking_status[T.True] -0.099137
# 33      CTSL         T cell lineage             sex[T.male]  0.733059
# 34      CTSL         T cell lineage                     age  0.030221
# 35      CTSL         T cell lineage  smoking_status[T.True] -0.661709
# 36      ACE2              Monocytes             sex[T.male]  0.711762
# 37      ACE2              Monocytes                     age -0.024997
# 38      ACE2              Monocytes  smoking_status[T.True] -0.298505
# 39   TMPRSS2              Monocytes             sex[T.male]  1.204337
# 40   TMPRSS2              Monocytes                     age  0.007580
# 41   TMPRSS2              Monocytes  smoking_status[T.True]  0.143082
# 42      CTSL              Monocytes             sex[T.male] -0.147852
# 43      CTSL              Monocytes                     age -0.001845
# 44      CTSL              Monocytes  smoking_status[T.True] -0.160165
# 45      ACE2  Multiciliated lineage             sex[T.male]  0.247672
# 46      ACE2  Multiciliated lineage                     age  0.006830
# 47      ACE2  Multiciliated lineage  smoking_status[T.True]  0.200573
# 48   TMPRSS2  Multiciliated lineage             sex[T.male]  0.179693
# 49   TMPRSS2  Multiciliated lineage                     age  0.000304
# 50   TMPRSS2  Multiciliated lineage  smoking_status[T.True] -0.082698
# 51      CTSL  Multiciliated lineage             sex[T.male] -0.060682
# 52      CTSL  Multiciliated lineage                     age -0.001260
# 53      CTSL  Multiciliated lineage  smoking_status[T.True]  0.005015
# 54      ACE2   Submucosal Secretory             sex[T.male]  0.053476
# 55      ACE2   Submucosal Secretory                     age  0.002748
# 56      ACE2   Submucosal Secretory  smoking_status[T.True]  0.476008
# 57   TMPRSS2   Submucosal Secretory             sex[T.male]  0.303606
# 58   TMPRSS2   Submucosal Secretory                     age  0.001992
# 59   TMPRSS2   Submucosal Secretory  smoking_status[T.True] -0.065982
# 60      CTSL   Submucosal Secretory             sex[T.male] -0.097038
# 61      CTSL   Submucosal Secretory                     age  0.006540
# 62      CTSL   Submucosal Secretory  smoking_status[T.True]  0.072334
# 63      ACE2                    AT1             sex[T.male]  0.483887
# 64      ACE2                    AT1                     age  0.011905
# 65      ACE2                    AT1  smoking_status[T.True]  0.284824
# 66   TMPRSS2                    AT1             sex[T.male]  0.680930
# 67   TMPRSS2                    AT1                     age  0.011882
# 68   TMPRSS2                    AT1  smoking_status[T.True]  0.092228
# 69      CTSL                    AT1             sex[T.male]  0.259359
# 70      CTSL                    AT1                     age  0.001547
# 71      CTSL                    AT1  smoking_status[T.True]  0.152784
# 72   TMPRSS2  Innate lymphoid cells             sex[T.male]  0.237172
# 73   TMPRSS2  Innate lymphoid cells                     age  0.002862
# 74   TMPRSS2  Innate lymphoid cells  smoking_status[T.True] -0.751326
# 75      CTSL  Innate lymphoid cells             sex[T.male]  0.465933
# 76      CTSL  Innate lymphoid cells                     age  0.019030
# 77      CTSL  Innate lymphoid cells  smoking_status[T.True]  0.421752
# 78      ACE2              Secretory             sex[T.male]  0.248878
# 79      ACE2              Secretory                     age -0.007310
# 80      ACE2              Secretory  smoking_status[T.True] -0.009837
# 81   TMPRSS2              Secretory             sex[T.male]  0.266853
# 82   TMPRSS2              Secretory                     age -0.003502
# 83   TMPRSS2              Secretory  smoking_status[T.True]  0.003712
# 84      CTSL              Secretory             sex[T.male] -0.002958
# 85      CTSL              Secretory                     age  0.005070
# 86      CTSL              Secretory  smoking_status[T.True]  0.043263
# 87   TMPRSS2              Capillary             sex[T.male]  1.186622
# 88   TMPRSS2              Capillary                     age -0.027864
# 89   TMPRSS2              Capillary  smoking_status[T.True] -0.684139
# 90      CTSL              Capillary             sex[T.male] -0.047455
# 91      CTSL              Capillary                     age -0.001386
# 92      CTSL              Capillary  smoking_status[T.True]  0.297672
# 93   TMPRSS2             Mast cells             sex[T.male]  1.120987
# 94   TMPRSS2             Mast cells                     age -0.009912
# 95   TMPRSS2             Mast cells  smoking_status[T.True] -1.180041
# 96      CTSL             Mast cells             sex[T.male] -0.214675
# 97      CTSL             Mast cells                     age -0.007230
# 98      CTSL             Mast cells  smoking_status[T.True] -0.356793
# 99   TMPRSS2         B cell lineage             sex[T.male]  0.280367
# 100  TMPRSS2         B cell lineage                     age -0.007162
# 101  TMPRSS2         B cell lineage  smoking_status[T.True] -0.649469
# 102     CTSL         B cell lineage             sex[T.male] -0.176326
# 103     CTSL         B cell lineage                     age -0.002547
# 104     CTSL         B cell lineage  smoking_status[T.True] -0.106384
# 105     ACE2            Fibroblasts             sex[T.male] -0.992477
# 106     ACE2            Fibroblasts                     age -0.003820
# 107     ACE2            Fibroblasts  smoking_status[T.True] -0.217694
# 108  TMPRSS2            Fibroblasts             sex[T.male]  0.946428
# 109  TMPRSS2            Fibroblasts                     age -0.000950
# 110  TMPRSS2            Fibroblasts  smoking_status[T.True] -0.407290
# 111     CTSL            Fibroblasts             sex[T.male] -0.004878
# 112     CTSL            Fibroblasts                     age -0.014788
# 113     CTSL            Fibroblasts  smoking_status[T.True]  1.031132
# 114  TMPRSS2        Dendritic cells             sex[T.male]  0.251196
# 115  TMPRSS2        Dendritic cells                     age -0.007513
# 116  TMPRSS2        Dendritic cells  smoking_status[T.True] -0.495933
# 117     CTSL        Dendritic cells             sex[T.male] -0.409138
# 118     CTSL        Dendritic cells                     age  0.015850
# 119     CTSL        Dendritic cells  smoking_status[T.True] -0.194686
# 120  TMPRSS2                 Venous             sex[T.male]  0.856302
# 121  TMPRSS2                 Venous                     age -0.051988
# 122  TMPRSS2                 Venous  smoking_status[T.True] -2.144932
# 123     CTSL                 Venous             sex[T.male]  0.010482
# 124     CTSL                 Venous                     age  0.002033
# 125     CTSL                 Venous  smoking_status[T.True]  0.191225
# 126  TMPRSS2           Lymphatic EC             sex[T.male]  0.567848
# 127  TMPRSS2           Lymphatic EC                     age -0.011344
# 128  TMPRSS2           Lymphatic EC  smoking_status[T.True]  0.055680
# 129     CTSL           Lymphatic EC             sex[T.male]  0.015904
# 130     CTSL           Lymphatic EC                     age  0.004340
# 131     CTSL           Lymphatic EC  smoking_status[T.True] -0.020372
# 132     CTSL               Arterial             sex[T.male]  0.156750
# 133     CTSL               Arterial                     age  0.003528
# 134     CTSL               Arterial  smoking_status[T.True] -0.097793
# 135     ACE2                   Rare             sex[T.male] -0.256809
# 136     ACE2                   Rare                     age  0.008099
# 137     ACE2                   Rare  smoking_status[T.True]  0.203906
# 138  TMPRSS2                   Rare             sex[T.male]  0.282077
# 139  TMPRSS2                   Rare                     age -0.003152
# 140  TMPRSS2                   Rare  smoking_status[T.True]  0.100134
# 141     CTSL                   Rare             sex[T.male]  0.282241
# 142     CTSL                   Rare                     age  0.005546
# 143     CTSL                   Rare  smoking_status[T.True]  0.261578
# 144     CTSL   Airway smooth muscle             sex[T.male] -0.174513
# 145     CTSL   Airway smooth muscle                     age -0.009539
# 146     CTSL   Airway smooth muscle  smoking_status[T.True]  0.411671
#
#       coef_sd           pval      adj_pvals
# 0    0.268355   7.674755e-01   7.674755e-01
# 1    0.006974   3.334057e-01   4.286644e-01
# 2    0.328642   5.768144e-01   6.489162e-01
# 3    0.072662   5.125795e-06   1.153304e-05
# 4    0.002135   1.196886e-01   2.100394e-01
# 5    0.090973   1.400263e-01   2.100394e-01
# 6    0.002610   0.000000e+00   0.000000e+00
# 7    0.000084  2.672846e-207  1.202781e-206
# 8    0.003562  1.222302e-174  3.666907e-174
# 9    0.047738   2.882331e-01   2.882331e-01
# 10   0.001304   4.346742e-03   4.890085e-03
# 11   0.048163   7.301195e-05   9.387251e-05
# 12   0.019865   1.137475e-49   2.559319e-49
# 13   0.000486   5.922030e-26   1.065965e-25
# 14   0.022005   2.284573e-60   1.028058e-59
# 15   0.010586   2.235890e-56   6.707671e-56
# 16   0.000297   1.908543e-72   1.717688e-71
# 17   0.010720   6.077707e-13   9.116561e-13
# 18   0.054502   4.251463e-52   1.371084e-51
# 19   0.001890   4.552959e-24   8.195327e-24
# 20   0.065738   6.000591e-10   6.750665e-10
# 21   0.007640   5.616730e-01   5.616730e-01
# 22   0.000271   0.000000e+00   0.000000e+00
# 23   0.008986   4.570280e-52   1.371084e-51
# 24   0.013615   1.993684e-14   2.990526e-14
# 25   0.000459   7.452178e-32   1.676740e-31
# 26   0.017113   3.363359e-11   4.324319e-11
# 27   0.590384   2.977596e-01   4.428981e-01
# 28   0.019765   5.766385e-01   5.766385e-01
# 29   0.766459   3.444763e-01   4.428981e-01
# 30   0.089583   1.352804e-05   3.043809e-05
# 31   0.003576   1.577115e-01   2.838807e-01
# 32   0.116738   3.957565e-01   4.452260e-01
# 33   0.042110   7.157937e-68   3.221072e-67
# 34   0.001357  8.132840e-110  7.319556e-109
# 35   0.052836   5.534007e-36   1.660202e-35
# 36   0.377030   5.905110e-02   8.857664e-02
# 37   0.015915   1.162524e-01   1.307840e-01
# 38   0.425435   4.828992e-01   4.828992e-01
# 39   0.071956   7.018987e-63   6.317089e-62
# 40   0.002981   1.099027e-02   1.978249e-02
# 41   0.080283   7.471135e-02   9.605745e-02
# 42   0.010715   2.614876e-43   1.176694e-42
# 43   0.000415   8.695287e-06   1.956440e-05
# 44   0.014834   3.546453e-27   1.063936e-26
# 45   0.080584   2.115948e-03   4.760882e-03
# 46   0.002665   1.038334e-02   1.869002e-02
# 47   0.098314   4.133809e-02   5.314898e-02
# 48   0.018936   2.325644e-21   2.093079e-20
# 49   0.000631   6.301211e-01   7.088862e-01
# 50   0.024826   8.648743e-04   2.594623e-03
# 51   0.016227   1.844084e-04   8.298379e-04
# 52   0.000531   1.767841e-02   2.651761e-02
# 53   0.020506   8.067875e-01   8.067875e-01
# 54   0.099754   5.919034e-01   5.919034e-01
# 55   0.002430   2.581117e-01   2.903756e-01
# 56   0.080926   4.053372e-09   1.216012e-08
# 57   0.024020   1.273589e-36   1.146230e-35
# 58   0.000584   6.522876e-04   1.174118e-03
# 59   0.024541   7.174169e-03   9.223932e-03
# 60   0.026834   2.988976e-04   6.725196e-04
# 61   0.000699   8.674072e-21   3.903332e-20
# 62   0.025804   5.059754e-03   7.589632e-03
# 63   0.205510   1.854418e-02   2.781628e-02
# 64   0.006286   5.823080e-02   6.622207e-02
# 65   0.269453   2.904905e-01   2.904905e-01
# 66   0.020186  1.924583e-249  1.732124e-248
# 67   0.000746   4.273932e-57   1.923269e-56
# 68   0.029299   1.645028e-03   2.961051e-03
# 69   0.026330   6.837584e-23   2.051275e-22
# 70   0.000819   5.886407e-02   6.622207e-02
# 71   0.038328   6.713938e-05   1.510636e-04
# 72   0.427875   5.793724e-01   6.952469e-01
# 73   0.010942   7.936783e-01   7.936783e-01
# 74   0.547680   1.701151e-01   2.551726e-01
# 75   0.077852   2.165548e-09   6.496645e-09
# 76   0.002066   3.245648e-20   1.947389e-19
# 77   0.083765   4.779259e-07   9.558518e-07
# 78   0.081754   2.332912e-03   5.249052e-03
# 79   0.003352   2.921238e-02   5.258228e-02
# 80   0.081236   9.036183e-01   9.371017e-01
# 81   0.023978   9.062946e-29   8.156651e-28
# 82   0.000919   1.388082e-04   6.246369e-04
# 83   0.025451   8.840384e-01   9.371017e-01
# 84   0.037491   9.371017e-01   9.371017e-01
# 85   0.001539   9.888923e-04   2.966677e-03
# 86   0.038721   2.638579e-01   3.957868e-01
# 87   0.730603   1.043398e-01   3.130194e-01
# 88   0.020725   1.788015e-01   3.360825e-01
# 89   1.209813   5.717394e-01   5.717394e-01
# 90   0.039031   2.240550e-01   3.360825e-01
# 91   0.002315   5.494895e-01   5.717394e-01
# 92   0.085133   4.712856e-04   2.827714e-03
# 93   0.671604   9.509372e-02   1.426406e-01
# 94   0.023100   6.678583e-01   6.678583e-01
# 95   0.891055   1.853973e-01   2.224767e-01
# 96   0.059188   2.867112e-04   8.601337e-04
# 97   0.002277   1.495283e-03   2.990566e-03
# 98   0.081870   1.312289e-05   7.873735e-05
# 99   0.399911   4.832568e-01   4.954520e-01
# 100  0.010507   4.954520e-01   4.954520e-01
# 101  0.538598   2.278744e-01   4.878797e-01
# 102  0.081610   3.072735e-02   1.843641e-01
# 103  0.002522   3.126501e-01   4.878797e-01
# 104  0.108144   3.252531e-01   4.878797e-01
# 105  0.419673   1.803577e-02   5.410730e-02
# 106  0.009394   6.842386e-01   9.412516e-01
# 107  1.016302   8.303895e-01   9.412516e-01
# 108  0.492932   5.485828e-02   1.234311e-01
# 109  0.013524   9.439898e-01   9.439898e-01
# 110  1.102044   7.116980e-01   9.412516e-01
# 111  0.023659   8.366681e-01   9.412516e-01
# 112  0.000817   3.407429e-73   1.533343e-72
# 113  0.043653  2.354386e-123  2.118947e-122
# 114  0.326929   4.422794e-01   5.086489e-01
# 115  0.011367   5.086489e-01   5.086489e-01
# 116  0.412950   2.297699e-01   3.446549e-01
# 117  0.034637   3.384612e-32   1.015384e-31
# 118  0.000984   2.483363e-58   1.490018e-57
# 119  0.046739   3.107915e-05   6.215830e-05
# 120  1.255368   4.951677e-01   5.942012e-01
# 121  0.032594   1.107110e-01   3.321329e-01
# 122  3.050744   4.820029e-01   5.942012e-01
# 123  0.050221   8.346737e-01   8.346737e-01
# 124  0.001538   1.862103e-01   3.724206e-01
# 125  0.093885   4.166946e-02   2.500168e-01
# 126  0.179319   1.541841e-03   9.251045e-03
# 127  0.005926   5.559267e-02   1.111853e-01
# 128  0.208976   7.898999e-01   7.898999e-01
# 129  0.032492   6.245150e-01   7.898999e-01
# 130  0.001490   3.583364e-03   1.075009e-02
# 131  0.063500   7.483483e-01   7.898999e-01
# 132  0.072874   3.147894e-02   9.443683e-02
# 133  0.002912   2.257205e-01   3.385808e-01
# 134  0.130940   4.551554e-01   4.551554e-01
# 135  0.828928   7.567065e-01   8.512948e-01
# 136  0.023058   7.253915e-01   8.512948e-01
# 137  1.111614   8.544585e-01   8.544585e-01
# 138  0.121165   1.991030e-02   4.479817e-02
# 139  0.003319   3.423037e-01   6.161466e-01
# 140  0.151173   5.077255e-01   7.615883e-01
# 141  0.078320   3.137444e-04   2.823699e-03
# 142  0.002226   1.271838e-02   3.815513e-02
# 143  0.083444   1.719909e-03   7.739589e-03
# 144  0.089891   5.221310e-02   7.831966e-02
# 145  0.005927   1.074989e-01   1.074989e-01
# 146  0.198120   3.771967e-02   7.831966e-02

# %% [markdown]
# ## Level 3

# %%
# Prep plotting

# Order cell identity category
res_lvl3['cell_identity'] = res_lvl3['cell_identity'].astype('category').cat.set_categories(['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2', 'Arterial', 'Capillary', 'Venous', 'Lymphatic EC', 'Fibroblasts', 'Airway smooth muscle', 'B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'Mast cells'], ordered=True)
res_lvl3 = res_lvl3.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Basal', 'Multiciliated lineage', 'Secretory', 'Rare', 'Submucosal Secretory', 'AT1', 'AT2'], 'Endothelial':['Arterial', 'Capillary', 'Venous', 'Lymphatic EC'], 'Stroma':['Fibroblasts', 'Airway smooth muscle'], 'Immune':['B cell lineage', 'T cell lineage', 'Innate lymphoid cells', 'Dendritic cells', 'Macrophages', 'Monocytes', 'Mast cells']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl3['compartment'] = [ct_mapping_up[ct] for ct in res_lvl3['cell_identity']]        

# Check if bulk and sc effect directions agree
res_lvl3_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl3_pseudo[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl3.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl3[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl3['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl3['coef'].loc[res_lvl3.index[i]]* res_lvl3_pseudo['coef'].loc[res_lvl3.index[i]]) > 0) for i,val in enumerate(res_lvl3['adj_pvals'])]


# Check if simple and complex models agree

# Check if bulk and sc effect directions agree in interaction model
res_lvl3_ints_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl3_ints_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3_ints.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl3_ints[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl3_ints['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl3_ints['coef'].loc[res_lvl3_ints.index[i]]* res_lvl3_ints_pseudo['coef'].loc[res_lvl3_ints.index[i]]) > 0) for i,val in enumerate(res_lvl3_ints['adj_pvals'])]

# Criteria:
# 1. No "indication" in opposite direction (significant and pseudo agrees)
# 2. At least 1 "indication" in the correct direction.

bulk_complex_agree = []

for idx in res_lvl3.index:
    mask = [str(idx) in str(i) for i in res_lvl3_ints.index]
    tmp = res_lvl3_ints.loc[mask]
    complex_vals = tmp['coef'].loc[tmp['signif_bulk_agree'].values].values

    if len(complex_vals) == 0:
        # No indication in complex interaction model
        bulk_complex_agree.append(False)

    else:
        # Check that all indications or robust trends point in the same direction
        # as the simple model case:
        int_agree = np.all([res_lvl3['coef'].loc[idx]*val > 0 for val in complex_vals])
        val = res_lvl3['signif_bulk_agree'].loc[idx] and int_agree
        bulk_complex_agree.append(val)
        
res_lvl3['signif_bulk_complex_agree'] = bulk_complex_agree


res_lvl3['compartment'] = res_lvl3['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl3['covariate_simple'] = res_lvl3['covariate'].astype('category').cat.rename_categories(['Age', 'Sex', 'Smoking_status'])

# Assign eval_at numbers
res_lvl3 = res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()


leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.1, 2.1], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl3_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

xlims_top = [[None, None, None],
             [None, None, None],
             [None, None, None],
             [None, None, None]]
xlims_bot = [[None, None, None],
             [None ,None, None],
             [None, None, None],
             [None, None, None]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl3, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl3.loc[(res_lvl3['covariate_simple'] == cat_order[i]) & (res_lvl3['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl3.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.1, 2.1], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl3_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# (-0.008740301009623183, 0.022724370269385112)
# <ErrorbarContainer object of 3 artists>
# (-0.3137629728310568, 0.9392242081139494)
# <ErrorbarContainer object of 3 artists>
# (-0.5241610875055738, 0.6084148467428853)
# <ErrorbarContainer object of 3 artists>
# (-0.05480466445872441, 0.007156309004104524)
# <ErrorbarContainer object of 3 artists>
# (-0.10915889453651882, 1.248325756315579)
# <ErrorbarContainer object of 3 artists>
# (-2.26706224303332, 0.419802088913107)
# <ErrorbarContainer object of 3 artists>
# (-0.015527502541761721, 0.0)
# <ErrorbarContainer object of 3 artists>
# (-1.089422500512248, 1.0433733131444738)
# <ErrorbarContainer object of 3 artists>
# (-0.48139336991974524, 1.1488893342855868)
# <ErrorbarContainer object of 3 artists>
# (-0.0277580184887998, 0.03298171350294217)
# <ErrorbarContainer object of 3 artists>
# (-0.529778396424126, 1.362295497063558)
# <ErrorbarContainer object of 3 artists>
# (-1.2601305920133936, 0.5018419291186511)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl3.sort_values(by=['cell_identity', 'covariate', 'gene'])
# Out:
#                                                        gene  \
# Basal_age_ACE2                                         ACE2
# Basal_age_CTSL                                         CTSL
# Basal_age_TMPRSS2                                   TMPRSS2
# Basal_sex[T.male]_ACE2                                 ACE2
# Basal_sex[T.male]_CTSL                                 CTSL
# Basal_sex[T.male]_TMPRSS2                           TMPRSS2
# Basal_smoking_status[T.True]_ACE2                      ACE2
# Basal_smoking_status[T.True]_CTSL                      CTSL
# Basal_smoking_status[T.True]_TMPRSS2                TMPRSS2
# Multiciliated_lineage_age_ACE2                         ACE2
# Multiciliated_lineage_age_CTSL                         CTSL
# Multiciliated_lineage_age_TMPRSS2                   TMPRSS2
# Multiciliated_lineage_sex[T.male]_ACE2                 ACE2
# Multiciliated_lineage_sex[T.male]_CTSL                 CTSL
# Multiciliated_lineage_sex[T.male]_TMPRSS2           TMPRSS2
# Multiciliated_lineage_smoking_status[T.True]_ACE2      ACE2
# Multiciliated_lineage_smoking_status[T.True]_CTSL      CTSL
# Multiciliated_lineage_smoking_status[T.True]_TM...  TMPRSS2
# Secretory_age_ACE2                                     ACE2
# Secretory_age_CTSL                                     CTSL
# Secretory_age_TMPRSS2                               TMPRSS2
# Secretory_sex[T.male]_ACE2                             ACE2
# Secretory_sex[T.male]_CTSL                             CTSL
# Secretory_sex[T.male]_TMPRSS2                       TMPRSS2
# Secretory_smoking_status[T.True]_ACE2                  ACE2
# Secretory_smoking_status[T.True]_CTSL                  CTSL
# Secretory_smoking_status[T.True]_TMPRSS2            TMPRSS2
# Rare_age_ACE2                                          ACE2
# Rare_age_CTSL                                          CTSL
# Rare_age_TMPRSS2                                    TMPRSS2
# Rare_sex[T.male]_ACE2                                  ACE2
# Rare_sex[T.male]_CTSL                                  CTSL
# Rare_sex[T.male]_TMPRSS2                            TMPRSS2
# Rare_smoking_status[T.True]_ACE2                       ACE2
# Rare_smoking_status[T.True]_CTSL                       CTSL
# Rare_smoking_status[T.True]_TMPRSS2                 TMPRSS2
# Submucosal_Secretory_age_ACE2                          ACE2
# Submucosal_Secretory_age_CTSL                          CTSL
# Submucosal_Secretory_age_TMPRSS2                    TMPRSS2
# Submucosal_Secretory_sex[T.male]_ACE2                  ACE2
# Submucosal_Secretory_sex[T.male]_CTSL                  CTSL
# Submucosal_Secretory_sex[T.male]_TMPRSS2            TMPRSS2
# Submucosal_Secretory_smoking_status[T.True]_ACE2       ACE2
# Submucosal_Secretory_smoking_status[T.True]_CTSL       CTSL
# Submucosal_Secretory_smoking_status[T.True]_TMP...  TMPRSS2
# AT1_age_ACE2                                           ACE2
# AT1_age_CTSL                                           CTSL
# AT1_age_TMPRSS2                                     TMPRSS2
# AT1_sex[T.male]_ACE2                                   ACE2
# AT1_sex[T.male]_CTSL                                   CTSL
# AT1_sex[T.male]_TMPRSS2                             TMPRSS2
# AT1_smoking_status[T.True]_ACE2                        ACE2
# AT1_smoking_status[T.True]_CTSL                        CTSL
# AT1_smoking_status[T.True]_TMPRSS2                  TMPRSS2
# AT2_age_ACE2                                           ACE2
# AT2_age_CTSL                                           CTSL
# AT2_age_TMPRSS2                                     TMPRSS2
# AT2_sex[T.male]_ACE2                                   ACE2
# AT2_sex[T.male]_CTSL                                   CTSL
# AT2_sex[T.male]_TMPRSS2                             TMPRSS2
# AT2_smoking_status[T.True]_ACE2                        ACE2
# AT2_smoking_status[T.True]_CTSL                        CTSL
# AT2_smoking_status[T.True]_TMPRSS2                  TMPRSS2
# Arterial_age_CTSL                                      CTSL
# Arterial_sex[T.male]_CTSL                              CTSL
# Arterial_smoking_status[T.True]_CTSL                   CTSL
# Capillary_age_CTSL                                     CTSL
# Capillary_age_TMPRSS2                               TMPRSS2
# Capillary_sex[T.male]_CTSL                             CTSL
# Capillary_sex[T.male]_TMPRSS2                       TMPRSS2
# Capillary_smoking_status[T.True]_CTSL                  CTSL
# Capillary_smoking_status[T.True]_TMPRSS2            TMPRSS2
# Venous_age_CTSL                                        CTSL
# Venous_age_TMPRSS2                                  TMPRSS2
# Venous_sex[T.male]_CTSL                                CTSL
# Venous_sex[T.male]_TMPRSS2                          TMPRSS2
# Venous_smoking_status[T.True]_CTSL                     CTSL
# Venous_smoking_status[T.True]_TMPRSS2               TMPRSS2
# Lymphatic_EC_age_CTSL                                  CTSL
# Lymphatic_EC_age_TMPRSS2                            TMPRSS2
# Lymphatic_EC_sex[T.male]_CTSL                          CTSL
# Lymphatic_EC_sex[T.male]_TMPRSS2                    TMPRSS2
# Lymphatic_EC_smoking_status[T.True]_CTSL               CTSL
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2         TMPRSS2
# Fibroblasts_age_ACE2                                   ACE2
# Fibroblasts_age_CTSL                                   CTSL
# Fibroblasts_age_TMPRSS2                             TMPRSS2
# Fibroblasts_sex[T.male]_ACE2                           ACE2
# Fibroblasts_sex[T.male]_CTSL                           CTSL
# Fibroblasts_sex[T.male]_TMPRSS2                     TMPRSS2
# Fibroblasts_smoking_status[T.True]_ACE2                ACE2
# Fibroblasts_smoking_status[T.True]_CTSL                CTSL
# Fibroblasts_smoking_status[T.True]_TMPRSS2          TMPRSS2
# Airway_smooth_muscle_age_CTSL                          CTSL
# Airway_smooth_muscle_sex[T.male]_CTSL                  CTSL
# Airway_smooth_muscle_smoking_status[T.True]_CTSL       CTSL
# B_cell_lineage_age_CTSL                                CTSL
# B_cell_lineage_age_TMPRSS2                          TMPRSS2
# B_cell_lineage_sex[T.male]_CTSL                        CTSL
# B_cell_lineage_sex[T.male]_TMPRSS2                  TMPRSS2
# B_cell_lineage_smoking_status[T.True]_CTSL             CTSL
# B_cell_lineage_smoking_status[T.True]_TMPRSS2       TMPRSS2
# T_cell_lineage_age_ACE2                                ACE2
# T_cell_lineage_age_CTSL                                CTSL
# T_cell_lineage_age_TMPRSS2                          TMPRSS2
# T_cell_lineage_sex[T.male]_ACE2                        ACE2
# T_cell_lineage_sex[T.male]_CTSL                        CTSL
# T_cell_lineage_sex[T.male]_TMPRSS2                  TMPRSS2
# T_cell_lineage_smoking_status[T.True]_ACE2             ACE2
# T_cell_lineage_smoking_status[T.True]_CTSL             CTSL
# T_cell_lineage_smoking_status[T.True]_TMPRSS2       TMPRSS2
# Innate_lymphoid_cells_age_CTSL                         CTSL
# Innate_lymphoid_cells_age_TMPRSS2                   TMPRSS2
# Innate_lymphoid_cells_sex[T.male]_CTSL                 CTSL
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2           TMPRSS2
# Innate_lymphoid_cells_smoking_status[T.True]_CTSL      CTSL
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  TMPRSS2
# Dendritic_cells_age_CTSL                               CTSL
# Dendritic_cells_age_TMPRSS2                         TMPRSS2
# Dendritic_cells_sex[T.male]_CTSL                       CTSL
# Dendritic_cells_sex[T.male]_TMPRSS2                 TMPRSS2
# Dendritic_cells_smoking_status[T.True]_CTSL            CTSL
# Dendritic_cells_smoking_status[T.True]_TMPRSS2      TMPRSS2
# Macrophages_age_ACE2                                   ACE2
# Macrophages_age_CTSL                                   CTSL
# Macrophages_age_TMPRSS2                             TMPRSS2
# Macrophages_sex[T.male]_ACE2                           ACE2
# Macrophages_sex[T.male]_CTSL                           CTSL
# Macrophages_sex[T.male]_TMPRSS2                     TMPRSS2
# Macrophages_smoking_status[T.True]_ACE2                ACE2
# Macrophages_smoking_status[T.True]_CTSL                CTSL
# Macrophages_smoking_status[T.True]_TMPRSS2          TMPRSS2
# Monocytes_age_ACE2                                     ACE2
# Monocytes_age_CTSL                                     CTSL
# Monocytes_age_TMPRSS2                               TMPRSS2
# Monocytes_sex[T.male]_ACE2                             ACE2
# Monocytes_sex[T.male]_CTSL                             CTSL
# Monocytes_sex[T.male]_TMPRSS2                       TMPRSS2
# Monocytes_smoking_status[T.True]_ACE2                  ACE2
# Monocytes_smoking_status[T.True]_CTSL                  CTSL
# Monocytes_smoking_status[T.True]_TMPRSS2            TMPRSS2
# Mast_cells_age_CTSL                                    CTSL
# Mast_cells_age_TMPRSS2                              TMPRSS2
# Mast_cells_sex[T.male]_CTSL                            CTSL
# Mast_cells_sex[T.male]_TMPRSS2                      TMPRSS2
# Mast_cells_smoking_status[T.True]_CTSL                 CTSL
# Mast_cells_smoking_status[T.True]_TMPRSS2           TMPRSS2
#
#                                                             cell_identity  \
# Basal_age_ACE2                                                      Basal
# Basal_age_CTSL                                                      Basal
# Basal_age_TMPRSS2                                                   Basal
# Basal_sex[T.male]_ACE2                                              Basal
# Basal_sex[T.male]_CTSL                                              Basal
# Basal_sex[T.male]_TMPRSS2                                           Basal
# Basal_smoking_status[T.True]_ACE2                                   Basal
# Basal_smoking_status[T.True]_CTSL                                   Basal
# Basal_smoking_status[T.True]_TMPRSS2                                Basal
# Multiciliated_lineage_age_ACE2                      Multiciliated lineage
# Multiciliated_lineage_age_CTSL                      Multiciliated lineage
# Multiciliated_lineage_age_TMPRSS2                   Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_ACE2              Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_CTSL              Multiciliated lineage
# Multiciliated_lineage_sex[T.male]_TMPRSS2           Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_ACE2   Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_CTSL   Multiciliated lineage
# Multiciliated_lineage_smoking_status[T.True]_TM...  Multiciliated lineage
# Secretory_age_ACE2                                              Secretory
# Secretory_age_CTSL                                              Secretory
# Secretory_age_TMPRSS2                                           Secretory
# Secretory_sex[T.male]_ACE2                                      Secretory
# Secretory_sex[T.male]_CTSL                                      Secretory
# Secretory_sex[T.male]_TMPRSS2                                   Secretory
# Secretory_smoking_status[T.True]_ACE2                           Secretory
# Secretory_smoking_status[T.True]_CTSL                           Secretory
# Secretory_smoking_status[T.True]_TMPRSS2                        Secretory
# Rare_age_ACE2                                                        Rare
# Rare_age_CTSL                                                        Rare
# Rare_age_TMPRSS2                                                     Rare
# Rare_sex[T.male]_ACE2                                                Rare
# Rare_sex[T.male]_CTSL                                                Rare
# Rare_sex[T.male]_TMPRSS2                                             Rare
# Rare_smoking_status[T.True]_ACE2                                     Rare
# Rare_smoking_status[T.True]_CTSL                                     Rare
# Rare_smoking_status[T.True]_TMPRSS2                                  Rare
# Submucosal_Secretory_age_ACE2                        Submucosal Secretory
# Submucosal_Secretory_age_CTSL                        Submucosal Secretory
# Submucosal_Secretory_age_TMPRSS2                     Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_ACE2                Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_CTSL                Submucosal Secretory
# Submucosal_Secretory_sex[T.male]_TMPRSS2             Submucosal Secretory
# Submucosal_Secretory_smoking_status[T.True]_ACE2     Submucosal Secretory
# Submucosal_Secretory_smoking_status[T.True]_CTSL     Submucosal Secretory
# Submucosal_Secretory_smoking_status[T.True]_TMP...   Submucosal Secretory
# AT1_age_ACE2                                                          AT1
# AT1_age_CTSL                                                          AT1
# AT1_age_TMPRSS2                                                       AT1
# AT1_sex[T.male]_ACE2                                                  AT1
# AT1_sex[T.male]_CTSL                                                  AT1
# AT1_sex[T.male]_TMPRSS2                                               AT1
# AT1_smoking_status[T.True]_ACE2                                       AT1
# AT1_smoking_status[T.True]_CTSL                                       AT1
# AT1_smoking_status[T.True]_TMPRSS2                                    AT1
# AT2_age_ACE2                                                          AT2
# AT2_age_CTSL                                                          AT2
# AT2_age_TMPRSS2                                                       AT2
# AT2_sex[T.male]_ACE2                                                  AT2
# AT2_sex[T.male]_CTSL                                                  AT2
# AT2_sex[T.male]_TMPRSS2                                               AT2
# AT2_smoking_status[T.True]_ACE2                                       AT2
# AT2_smoking_status[T.True]_CTSL                                       AT2
# AT2_smoking_status[T.True]_TMPRSS2                                    AT2
# Arterial_age_CTSL                                                Arterial
# Arterial_sex[T.male]_CTSL                                        Arterial
# Arterial_smoking_status[T.True]_CTSL                             Arterial
# Capillary_age_CTSL                                              Capillary
# Capillary_age_TMPRSS2                                           Capillary
# Capillary_sex[T.male]_CTSL                                      Capillary
# Capillary_sex[T.male]_TMPRSS2                                   Capillary
# Capillary_smoking_status[T.True]_CTSL                           Capillary
# Capillary_smoking_status[T.True]_TMPRSS2                        Capillary
# Venous_age_CTSL                                                    Venous
# Venous_age_TMPRSS2                                                 Venous
# Venous_sex[T.male]_CTSL                                            Venous
# Venous_sex[T.male]_TMPRSS2                                         Venous
# Venous_smoking_status[T.True]_CTSL                                 Venous
# Venous_smoking_status[T.True]_TMPRSS2                              Venous
# Lymphatic_EC_age_CTSL                                        Lymphatic EC
# Lymphatic_EC_age_TMPRSS2                                     Lymphatic EC
# Lymphatic_EC_sex[T.male]_CTSL                                Lymphatic EC
# Lymphatic_EC_sex[T.male]_TMPRSS2                             Lymphatic EC
# Lymphatic_EC_smoking_status[T.True]_CTSL                     Lymphatic EC
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2                  Lymphatic EC
# Fibroblasts_age_ACE2                                          Fibroblasts
# Fibroblasts_age_CTSL                                          Fibroblasts
# Fibroblasts_age_TMPRSS2                                       Fibroblasts
# Fibroblasts_sex[T.male]_ACE2                                  Fibroblasts
# Fibroblasts_sex[T.male]_CTSL                                  Fibroblasts
# Fibroblasts_sex[T.male]_TMPRSS2                               Fibroblasts
# Fibroblasts_smoking_status[T.True]_ACE2                       Fibroblasts
# Fibroblasts_smoking_status[T.True]_CTSL                       Fibroblasts
# Fibroblasts_smoking_status[T.True]_TMPRSS2                    Fibroblasts
# Airway_smooth_muscle_age_CTSL                        Airway smooth muscle
# Airway_smooth_muscle_sex[T.male]_CTSL                Airway smooth muscle
# Airway_smooth_muscle_smoking_status[T.True]_CTSL     Airway smooth muscle
# B_cell_lineage_age_CTSL                                    B cell lineage
# B_cell_lineage_age_TMPRSS2                                 B cell lineage
# B_cell_lineage_sex[T.male]_CTSL                            B cell lineage
# B_cell_lineage_sex[T.male]_TMPRSS2                         B cell lineage
# B_cell_lineage_smoking_status[T.True]_CTSL                 B cell lineage
# B_cell_lineage_smoking_status[T.True]_TMPRSS2              B cell lineage
# T_cell_lineage_age_ACE2                                    T cell lineage
# T_cell_lineage_age_CTSL                                    T cell lineage
# T_cell_lineage_age_TMPRSS2                                 T cell lineage
# T_cell_lineage_sex[T.male]_ACE2                            T cell lineage
# T_cell_lineage_sex[T.male]_CTSL                            T cell lineage
# T_cell_lineage_sex[T.male]_TMPRSS2                         T cell lineage
# T_cell_lineage_smoking_status[T.True]_ACE2                 T cell lineage
# T_cell_lineage_smoking_status[T.True]_CTSL                 T cell lineage
# T_cell_lineage_smoking_status[T.True]_TMPRSS2              T cell lineage
# Innate_lymphoid_cells_age_CTSL                      Innate lymphoid cells
# Innate_lymphoid_cells_age_TMPRSS2                   Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_CTSL              Innate lymphoid cells
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2           Innate lymphoid cells
# Innate_lymphoid_cells_smoking_status[T.True]_CTSL   Innate lymphoid cells
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  Innate lymphoid cells
# Dendritic_cells_age_CTSL                                  Dendritic cells
# Dendritic_cells_age_TMPRSS2                               Dendritic cells
# Dendritic_cells_sex[T.male]_CTSL                          Dendritic cells
# Dendritic_cells_sex[T.male]_TMPRSS2                       Dendritic cells
# Dendritic_cells_smoking_status[T.True]_CTSL               Dendritic cells
# Dendritic_cells_smoking_status[T.True]_TMPRSS2            Dendritic cells
# Macrophages_age_ACE2                                          Macrophages
# Macrophages_age_CTSL                                          Macrophages
# Macrophages_age_TMPRSS2                                       Macrophages
# Macrophages_sex[T.male]_ACE2                                  Macrophages
# Macrophages_sex[T.male]_CTSL                                  Macrophages
# Macrophages_sex[T.male]_TMPRSS2                               Macrophages
# Macrophages_smoking_status[T.True]_ACE2                       Macrophages
# Macrophages_smoking_status[T.True]_CTSL                       Macrophages
# Macrophages_smoking_status[T.True]_TMPRSS2                    Macrophages
# Monocytes_age_ACE2                                              Monocytes
# Monocytes_age_CTSL                                              Monocytes
# Monocytes_age_TMPRSS2                                           Monocytes
# Monocytes_sex[T.male]_ACE2                                      Monocytes
# Monocytes_sex[T.male]_CTSL                                      Monocytes
# Monocytes_sex[T.male]_TMPRSS2                                   Monocytes
# Monocytes_smoking_status[T.True]_ACE2                           Monocytes
# Monocytes_smoking_status[T.True]_CTSL                           Monocytes
# Monocytes_smoking_status[T.True]_TMPRSS2                        Monocytes
# Mast_cells_age_CTSL                                            Mast cells
# Mast_cells_age_TMPRSS2                                         Mast cells
# Mast_cells_sex[T.male]_CTSL                                    Mast cells
# Mast_cells_sex[T.male]_TMPRSS2                                 Mast cells
# Mast_cells_smoking_status[T.True]_CTSL                         Mast cells
# Mast_cells_smoking_status[T.True]_TMPRSS2                      Mast cells
#
#                                                                  covariate  \
# Basal_age_ACE2                                                         age
# Basal_age_CTSL                                                         age
# Basal_age_TMPRSS2                                                      age
# Basal_sex[T.male]_ACE2                                         sex[T.male]
# Basal_sex[T.male]_CTSL                                         sex[T.male]
# Basal_sex[T.male]_TMPRSS2                                      sex[T.male]
# Basal_smoking_status[T.True]_ACE2                   smoking_status[T.True]
# Basal_smoking_status[T.True]_CTSL                   smoking_status[T.True]
# Basal_smoking_status[T.True]_TMPRSS2                smoking_status[T.True]
# Multiciliated_lineage_age_ACE2                                         age
# Multiciliated_lineage_age_CTSL                                         age
# Multiciliated_lineage_age_TMPRSS2                                      age
# Multiciliated_lineage_sex[T.male]_ACE2                         sex[T.male]
# Multiciliated_lineage_sex[T.male]_CTSL                         sex[T.male]
# Multiciliated_lineage_sex[T.male]_TMPRSS2                      sex[T.male]
# Multiciliated_lineage_smoking_status[T.True]_ACE2   smoking_status[T.True]
# Multiciliated_lineage_smoking_status[T.True]_CTSL   smoking_status[T.True]
# Multiciliated_lineage_smoking_status[T.True]_TM...  smoking_status[T.True]
# Secretory_age_ACE2                                                     age
# Secretory_age_CTSL                                                     age
# Secretory_age_TMPRSS2                                                  age
# Secretory_sex[T.male]_ACE2                                     sex[T.male]
# Secretory_sex[T.male]_CTSL                                     sex[T.male]
# Secretory_sex[T.male]_TMPRSS2                                  sex[T.male]
# Secretory_smoking_status[T.True]_ACE2               smoking_status[T.True]
# Secretory_smoking_status[T.True]_CTSL               smoking_status[T.True]
# Secretory_smoking_status[T.True]_TMPRSS2            smoking_status[T.True]
# Rare_age_ACE2                                                          age
# Rare_age_CTSL                                                          age
# Rare_age_TMPRSS2                                                       age
# Rare_sex[T.male]_ACE2                                          sex[T.male]
# Rare_sex[T.male]_CTSL                                          sex[T.male]
# Rare_sex[T.male]_TMPRSS2                                       sex[T.male]
# Rare_smoking_status[T.True]_ACE2                    smoking_status[T.True]
# Rare_smoking_status[T.True]_CTSL                    smoking_status[T.True]
# Rare_smoking_status[T.True]_TMPRSS2                 smoking_status[T.True]
# Submucosal_Secretory_age_ACE2                                          age
# Submucosal_Secretory_age_CTSL                                          age
# Submucosal_Secretory_age_TMPRSS2                                       age
# Submucosal_Secretory_sex[T.male]_ACE2                          sex[T.male]
# Submucosal_Secretory_sex[T.male]_CTSL                          sex[T.male]
# Submucosal_Secretory_sex[T.male]_TMPRSS2                       sex[T.male]
# Submucosal_Secretory_smoking_status[T.True]_ACE2    smoking_status[T.True]
# Submucosal_Secretory_smoking_status[T.True]_CTSL    smoking_status[T.True]
# Submucosal_Secretory_smoking_status[T.True]_TMP...  smoking_status[T.True]
# AT1_age_ACE2                                                           age
# AT1_age_CTSL                                                           age
# AT1_age_TMPRSS2                                                        age
# AT1_sex[T.male]_ACE2                                           sex[T.male]
# AT1_sex[T.male]_CTSL                                           sex[T.male]
# AT1_sex[T.male]_TMPRSS2                                        sex[T.male]
# AT1_smoking_status[T.True]_ACE2                     smoking_status[T.True]
# AT1_smoking_status[T.True]_CTSL                     smoking_status[T.True]
# AT1_smoking_status[T.True]_TMPRSS2                  smoking_status[T.True]
# AT2_age_ACE2                                                           age
# AT2_age_CTSL                                                           age
# AT2_age_TMPRSS2                                                        age
# AT2_sex[T.male]_ACE2                                           sex[T.male]
# AT2_sex[T.male]_CTSL                                           sex[T.male]
# AT2_sex[T.male]_TMPRSS2                                        sex[T.male]
# AT2_smoking_status[T.True]_ACE2                     smoking_status[T.True]
# AT2_smoking_status[T.True]_CTSL                     smoking_status[T.True]
# AT2_smoking_status[T.True]_TMPRSS2                  smoking_status[T.True]
# Arterial_age_CTSL                                                      age
# Arterial_sex[T.male]_CTSL                                      sex[T.male]
# Arterial_smoking_status[T.True]_CTSL                smoking_status[T.True]
# Capillary_age_CTSL                                                     age
# Capillary_age_TMPRSS2                                                  age
# Capillary_sex[T.male]_CTSL                                     sex[T.male]
# Capillary_sex[T.male]_TMPRSS2                                  sex[T.male]
# Capillary_smoking_status[T.True]_CTSL               smoking_status[T.True]
# Capillary_smoking_status[T.True]_TMPRSS2            smoking_status[T.True]
# Venous_age_CTSL                                                        age
# Venous_age_TMPRSS2                                                     age
# Venous_sex[T.male]_CTSL                                        sex[T.male]
# Venous_sex[T.male]_TMPRSS2                                     sex[T.male]
# Venous_smoking_status[T.True]_CTSL                  smoking_status[T.True]
# Venous_smoking_status[T.True]_TMPRSS2               smoking_status[T.True]
# Lymphatic_EC_age_CTSL                                                  age
# Lymphatic_EC_age_TMPRSS2                                               age
# Lymphatic_EC_sex[T.male]_CTSL                                  sex[T.male]
# Lymphatic_EC_sex[T.male]_TMPRSS2                               sex[T.male]
# Lymphatic_EC_smoking_status[T.True]_CTSL            smoking_status[T.True]
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2         smoking_status[T.True]
# Fibroblasts_age_ACE2                                                   age
# Fibroblasts_age_CTSL                                                   age
# Fibroblasts_age_TMPRSS2                                                age
# Fibroblasts_sex[T.male]_ACE2                                   sex[T.male]
# Fibroblasts_sex[T.male]_CTSL                                   sex[T.male]
# Fibroblasts_sex[T.male]_TMPRSS2                                sex[T.male]
# Fibroblasts_smoking_status[T.True]_ACE2             smoking_status[T.True]
# Fibroblasts_smoking_status[T.True]_CTSL             smoking_status[T.True]
# Fibroblasts_smoking_status[T.True]_TMPRSS2          smoking_status[T.True]
# Airway_smooth_muscle_age_CTSL                                          age
# Airway_smooth_muscle_sex[T.male]_CTSL                          sex[T.male]
# Airway_smooth_muscle_smoking_status[T.True]_CTSL    smoking_status[T.True]
# B_cell_lineage_age_CTSL                                                age
# B_cell_lineage_age_TMPRSS2                                             age
# B_cell_lineage_sex[T.male]_CTSL                                sex[T.male]
# B_cell_lineage_sex[T.male]_TMPRSS2                             sex[T.male]
# B_cell_lineage_smoking_status[T.True]_CTSL          smoking_status[T.True]
# B_cell_lineage_smoking_status[T.True]_TMPRSS2       smoking_status[T.True]
# T_cell_lineage_age_ACE2                                                age
# T_cell_lineage_age_CTSL                                                age
# T_cell_lineage_age_TMPRSS2                                             age
# T_cell_lineage_sex[T.male]_ACE2                                sex[T.male]
# T_cell_lineage_sex[T.male]_CTSL                                sex[T.male]
# T_cell_lineage_sex[T.male]_TMPRSS2                             sex[T.male]
# T_cell_lineage_smoking_status[T.True]_ACE2          smoking_status[T.True]
# T_cell_lineage_smoking_status[T.True]_CTSL          smoking_status[T.True]
# T_cell_lineage_smoking_status[T.True]_TMPRSS2       smoking_status[T.True]
# Innate_lymphoid_cells_age_CTSL                                         age
# Innate_lymphoid_cells_age_TMPRSS2                                      age
# Innate_lymphoid_cells_sex[T.male]_CTSL                         sex[T.male]
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2                      sex[T.male]
# Innate_lymphoid_cells_smoking_status[T.True]_CTSL   smoking_status[T.True]
# Innate_lymphoid_cells_smoking_status[T.True]_TM...  smoking_status[T.True]
# Dendritic_cells_age_CTSL                                               age
# Dendritic_cells_age_TMPRSS2                                            age
# Dendritic_cells_sex[T.male]_CTSL                               sex[T.male]
# Dendritic_cells_sex[T.male]_TMPRSS2                            sex[T.male]
# Dendritic_cells_smoking_status[T.True]_CTSL         smoking_status[T.True]
# Dendritic_cells_smoking_status[T.True]_TMPRSS2      smoking_status[T.True]
# Macrophages_age_ACE2                                                   age
# Macrophages_age_CTSL                                                   age
# Macrophages_age_TMPRSS2                                                age
# Macrophages_sex[T.male]_ACE2                                   sex[T.male]
# Macrophages_sex[T.male]_CTSL                                   sex[T.male]
# Macrophages_sex[T.male]_TMPRSS2                                sex[T.male]
# Macrophages_smoking_status[T.True]_ACE2             smoking_status[T.True]
# Macrophages_smoking_status[T.True]_CTSL             smoking_status[T.True]
# Macrophages_smoking_status[T.True]_TMPRSS2          smoking_status[T.True]
# Monocytes_age_ACE2                                                     age
# Monocytes_age_CTSL                                                     age
# Monocytes_age_TMPRSS2                                                  age
# Monocytes_sex[T.male]_ACE2                                     sex[T.male]
# Monocytes_sex[T.male]_CTSL                                     sex[T.male]
# Monocytes_sex[T.male]_TMPRSS2                                  sex[T.male]
# Monocytes_smoking_status[T.True]_ACE2               smoking_status[T.True]
# Monocytes_smoking_status[T.True]_CTSL               smoking_status[T.True]
# Monocytes_smoking_status[T.True]_TMPRSS2            smoking_status[T.True]
# Mast_cells_age_CTSL                                                    age
# Mast_cells_age_TMPRSS2                                                 age
# Mast_cells_sex[T.male]_CTSL                                    sex[T.male]
# Mast_cells_sex[T.male]_TMPRSS2                                 sex[T.male]
# Mast_cells_smoking_status[T.True]_CTSL              smoking_status[T.True]
# Mast_cells_smoking_status[T.True]_TMPRSS2           smoking_status[T.True]
#
#                                                         coef   coef_sd  \
# Basal_age_ACE2                                      0.003719  0.001304
# Basal_age_CTSL                                      0.005348  0.000297
# Basal_age_TMPRSS2                                   0.005119  0.000486
# Basal_sex[T.male]_ACE2                              0.050698  0.047738
# Basal_sex[T.male]_CTSL                             -0.167472  0.010586
# Basal_sex[T.male]_TMPRSS2                           0.294338  0.019865
# Basal_smoking_status[T.True]_ACE2                   0.191025  0.048163
# Basal_smoking_status[T.True]_CTSL                   0.077169  0.010720
# Basal_smoking_status[T.True]_TMPRSS2               -0.360639  0.022005
# Multiciliated_lineage_age_ACE2                      0.006830  0.002665
# Multiciliated_lineage_age_CTSL                     -0.001260  0.000531
# Multiciliated_lineage_age_TMPRSS2                   0.000304  0.000631
# Multiciliated_lineage_sex[T.male]_ACE2              0.247672  0.080584
# Multiciliated_lineage_sex[T.male]_CTSL             -0.060682  0.016227
# Multiciliated_lineage_sex[T.male]_TMPRSS2           0.179693  0.018936
# Multiciliated_lineage_smoking_status[T.True]_ACE2   0.200573  0.098314
# Multiciliated_lineage_smoking_status[T.True]_CTSL   0.005015  0.020506
# Multiciliated_lineage_smoking_status[T.True]_TM... -0.082698  0.024826
# Secretory_age_ACE2                                 -0.007310  0.003352
# Secretory_age_CTSL                                  0.005070  0.001539
# Secretory_age_TMPRSS2                              -0.003502  0.000919
# Secretory_sex[T.male]_ACE2                          0.248878  0.081754
# Secretory_sex[T.male]_CTSL                         -0.002958  0.037491
# Secretory_sex[T.male]_TMPRSS2                       0.266853  0.023978
# Secretory_smoking_status[T.True]_ACE2              -0.009837  0.081236
# Secretory_smoking_status[T.True]_CTSL               0.043263  0.038721
# Secretory_smoking_status[T.True]_TMPRSS2            0.003712  0.025451
# Rare_age_ACE2                                       0.008099  0.023058
# Rare_age_CTSL                                       0.005546  0.002226
# Rare_age_TMPRSS2                                   -0.003152  0.003319
# Rare_sex[T.male]_ACE2                              -0.256809  0.828928
# Rare_sex[T.male]_CTSL                               0.282241  0.078320
# Rare_sex[T.male]_TMPRSS2                            0.282077  0.121165
# Rare_smoking_status[T.True]_ACE2                    0.203906  1.111614
# Rare_smoking_status[T.True]_CTSL                    0.261578  0.083444
# Rare_smoking_status[T.True]_TMPRSS2                 0.100134  0.151173
# Submucosal_Secretory_age_ACE2                       0.002748  0.002430
# Submucosal_Secretory_age_CTSL                       0.006540  0.000699
# Submucosal_Secretory_age_TMPRSS2                    0.001992  0.000584
# Submucosal_Secretory_sex[T.male]_ACE2               0.053476  0.099754
# Submucosal_Secretory_sex[T.male]_CTSL              -0.097038  0.026834
# Submucosal_Secretory_sex[T.male]_TMPRSS2            0.303606  0.024020
# Submucosal_Secretory_smoking_status[T.True]_ACE2    0.476008  0.080926
# Submucosal_Secretory_smoking_status[T.True]_CTSL    0.072334  0.025804
# Submucosal_Secretory_smoking_status[T.True]_TMP... -0.065982  0.024541
# AT1_age_ACE2                                        0.011905  0.006286
# AT1_age_CTSL                                        0.001547  0.000819
# AT1_age_TMPRSS2                                     0.011882  0.000746
# AT1_sex[T.male]_ACE2                                0.483887  0.205510
# AT1_sex[T.male]_CTSL                                0.259359  0.026330
# AT1_sex[T.male]_TMPRSS2                             0.680930  0.020186
# AT1_smoking_status[T.True]_ACE2                     0.284824  0.269453
# AT1_smoking_status[T.True]_CTSL                     0.152784  0.038328
# AT1_smoking_status[T.True]_TMPRSS2                  0.092228  0.029299
# AT2_age_ACE2                                        0.019122  0.001890
# AT2_age_CTSL                                       -0.005396  0.000459
# AT2_age_TMPRSS2                                     0.021023  0.000271
# AT2_sex[T.male]_ACE2                                0.827769  0.054502
# AT2_sex[T.male]_CTSL                                0.104171  0.013615
# AT2_sex[T.male]_TMPRSS2                            -0.004434  0.007640
# AT2_smoking_status[T.True]_ACE2                    -0.406943  0.065738
# AT2_smoking_status[T.True]_CTSL                     0.113451  0.017113
# AT2_smoking_status[T.True]_TMPRSS2                  0.136431  0.008986
# Arterial_age_CTSL                                   0.003528  0.002912
# Arterial_sex[T.male]_CTSL                           0.156750  0.072874
# Arterial_smoking_status[T.True]_CTSL               -0.097793  0.130940
# Capillary_age_CTSL                                 -0.001386  0.002315
# Capillary_age_TMPRSS2                              -0.027864  0.020725
# Capillary_sex[T.male]_CTSL                         -0.047455  0.039031
# Capillary_sex[T.male]_TMPRSS2                       1.186622  0.730603
# Capillary_smoking_status[T.True]_CTSL               0.297672  0.085133
# Capillary_smoking_status[T.True]_TMPRSS2           -0.684139  1.209813
# Venous_age_CTSL                                     0.002033  0.001538
# Venous_age_TMPRSS2                                 -0.051988  0.032594
# Venous_sex[T.male]_CTSL                             0.010482  0.050221
# Venous_sex[T.male]_TMPRSS2                          0.856302  1.255368
# Venous_smoking_status[T.True]_CTSL                  0.191225  0.093885
# Venous_smoking_status[T.True]_TMPRSS2              -2.144932  3.050744
# Lymphatic_EC_age_CTSL                               0.004340  0.001490
# Lymphatic_EC_age_TMPRSS2                           -0.011344  0.005926
# Lymphatic_EC_sex[T.male]_CTSL                       0.015904  0.032492
# Lymphatic_EC_sex[T.male]_TMPRSS2                    0.567848  0.179319
# Lymphatic_EC_smoking_status[T.True]_CTSL           -0.020372  0.063500
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2         0.055680  0.208976
# Fibroblasts_age_ACE2                               -0.003820  0.009394
# Fibroblasts_age_CTSL                               -0.014788  0.000817
# Fibroblasts_age_TMPRSS2                            -0.000950  0.013524
# Fibroblasts_sex[T.male]_ACE2                       -0.992477  0.419673
# Fibroblasts_sex[T.male]_CTSL                       -0.004878  0.023659
# Fibroblasts_sex[T.male]_TMPRSS2                     0.946428  0.492932
# Fibroblasts_smoking_status[T.True]_ACE2            -0.217694  1.016302
# Fibroblasts_smoking_status[T.True]_CTSL             1.031132  0.043653
# Fibroblasts_smoking_status[T.True]_TMPRSS2         -0.407290  1.102044
# Airway_smooth_muscle_age_CTSL                      -0.009539  0.005927
# Airway_smooth_muscle_sex[T.male]_CTSL              -0.174513  0.089891
# Airway_smooth_muscle_smoking_status[T.True]_CTSL    0.411671  0.198120
# B_cell_lineage_age_CTSL                            -0.002547  0.002522
# B_cell_lineage_age_TMPRSS2                         -0.007162  0.010507
# B_cell_lineage_sex[T.male]_CTSL                    -0.176326  0.081610
# B_cell_lineage_sex[T.male]_TMPRSS2                  0.280367  0.399911
# B_cell_lineage_smoking_status[T.True]_CTSL         -0.106384  0.108144
# B_cell_lineage_smoking_status[T.True]_TMPRSS2      -0.649469  0.538598
# T_cell_lineage_age_ACE2                            -0.011035  0.019765
# T_cell_lineage_age_CTSL                             0.030221  0.001357
# T_cell_lineage_age_TMPRSS2                         -0.005053  0.003576
# T_cell_lineage_sex[T.male]_ACE2                     0.614737  0.590384
# T_cell_lineage_sex[T.male]_CTSL                     0.733059  0.042110
# T_cell_lineage_sex[T.male]_TMPRSS2                  0.389809  0.089583
# T_cell_lineage_smoking_status[T.True]_ACE2         -0.724578  0.766459
# T_cell_lineage_smoking_status[T.True]_CTSL         -0.661709  0.052836
# T_cell_lineage_smoking_status[T.True]_TMPRSS2      -0.099137  0.116738
# Innate_lymphoid_cells_age_CTSL                      0.019030  0.002066
# Innate_lymphoid_cells_age_TMPRSS2                   0.002862  0.010942
# Innate_lymphoid_cells_sex[T.male]_CTSL              0.465933  0.077852
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2           0.237172  0.427875
# Innate_lymphoid_cells_smoking_status[T.True]_CTSL   0.421752  0.083765
# Innate_lymphoid_cells_smoking_status[T.True]_TM... -0.751326  0.547680
# Dendritic_cells_age_CTSL                            0.015850  0.000984
# Dendritic_cells_age_TMPRSS2                        -0.007513  0.011367
# Dendritic_cells_sex[T.male]_CTSL                   -0.409138  0.034637
# Dendritic_cells_sex[T.male]_TMPRSS2                 0.251196  0.326929
# Dendritic_cells_smoking_status[T.True]_CTSL        -0.194686  0.046739
# Dendritic_cells_smoking_status[T.True]_TMPRSS2     -0.495933  0.412950
# Macrophages_age_ACE2                                0.006745  0.006974
# Macrophages_age_CTSL                                0.002582  0.000084
# Macrophages_age_TMPRSS2                            -0.003322  0.002135
# Macrophages_sex[T.male]_ACE2                        0.079347  0.268355
# Macrophages_sex[T.male]_CTSL                       -0.167304  0.002610
# Macrophages_sex[T.male]_TMPRSS2                    -0.331306  0.072662
# Macrophages_smoking_status[T.True]_ACE2            -0.183397  0.328642
# Macrophages_smoking_status[T.True]_CTSL             0.100365  0.003562
# Macrophages_smoking_status[T.True]_TMPRSS2          0.134248  0.090973
# Monocytes_age_ACE2                                 -0.024997  0.015915
# Monocytes_age_CTSL                                 -0.001845  0.000415
# Monocytes_age_TMPRSS2                               0.007580  0.002981
# Monocytes_sex[T.male]_ACE2                          0.711762  0.377030
# Monocytes_sex[T.male]_CTSL                         -0.147852  0.010715
# Monocytes_sex[T.male]_TMPRSS2                       1.204337  0.071956
# Monocytes_smoking_status[T.True]_ACE2              -0.298505  0.425435
# Monocytes_smoking_status[T.True]_CTSL              -0.160165  0.014834
# Monocytes_smoking_status[T.True]_TMPRSS2            0.143082  0.080283
# Mast_cells_age_CTSL                                -0.007230  0.002277
# Mast_cells_age_TMPRSS2                             -0.009912  0.023100
# Mast_cells_sex[T.male]_CTSL                        -0.214675  0.059188
# Mast_cells_sex[T.male]_TMPRSS2                      1.120987  0.671604
# Mast_cells_smoking_status[T.True]_CTSL             -0.356793  0.081870
# Mast_cells_smoking_status[T.True]_TMPRSS2          -1.180041  0.891055
#
#                                                              pval  \
# Basal_age_ACE2                                       4.346742e-03
# Basal_age_CTSL                                       1.908543e-72
# Basal_age_TMPRSS2                                    5.922030e-26
# Basal_sex[T.male]_ACE2                               2.882331e-01
# Basal_sex[T.male]_CTSL                               2.235890e-56
# Basal_sex[T.male]_TMPRSS2                            1.137475e-49
# Basal_smoking_status[T.True]_ACE2                    7.301195e-05
# Basal_smoking_status[T.True]_CTSL                    6.077707e-13
# Basal_smoking_status[T.True]_TMPRSS2                 2.284573e-60
# Multiciliated_lineage_age_ACE2                       1.038334e-02
# Multiciliated_lineage_age_CTSL                       1.767841e-02
# Multiciliated_lineage_age_TMPRSS2                    6.301211e-01
# Multiciliated_lineage_sex[T.male]_ACE2               2.115948e-03
# Multiciliated_lineage_sex[T.male]_CTSL               1.844084e-04
# Multiciliated_lineage_sex[T.male]_TMPRSS2            2.325644e-21
# Multiciliated_lineage_smoking_status[T.True]_ACE2    4.133809e-02
# Multiciliated_lineage_smoking_status[T.True]_CTSL    8.067875e-01
# Multiciliated_lineage_smoking_status[T.True]_TM...   8.648743e-04
# Secretory_age_ACE2                                   2.921238e-02
# Secretory_age_CTSL                                   9.888923e-04
# Secretory_age_TMPRSS2                                1.388082e-04
# Secretory_sex[T.male]_ACE2                           2.332912e-03
# Secretory_sex[T.male]_CTSL                           9.371017e-01
# Secretory_sex[T.male]_TMPRSS2                        9.062946e-29
# Secretory_smoking_status[T.True]_ACE2                9.036183e-01
# Secretory_smoking_status[T.True]_CTSL                2.638579e-01
# Secretory_smoking_status[T.True]_TMPRSS2             8.840384e-01
# Rare_age_ACE2                                        7.253915e-01
# Rare_age_CTSL                                        1.271838e-02
# Rare_age_TMPRSS2                                     3.423037e-01
# Rare_sex[T.male]_ACE2                                7.567065e-01
# Rare_sex[T.male]_CTSL                                3.137444e-04
# Rare_sex[T.male]_TMPRSS2                             1.991030e-02
# Rare_smoking_status[T.True]_ACE2                     8.544585e-01
# Rare_smoking_status[T.True]_CTSL                     1.719909e-03
# Rare_smoking_status[T.True]_TMPRSS2                  5.077255e-01
# Submucosal_Secretory_age_ACE2                        2.581117e-01
# Submucosal_Secretory_age_CTSL                        8.674072e-21
# Submucosal_Secretory_age_TMPRSS2                     6.522876e-04
# Submucosal_Secretory_sex[T.male]_ACE2                5.919034e-01
# Submucosal_Secretory_sex[T.male]_CTSL                2.988976e-04
# Submucosal_Secretory_sex[T.male]_TMPRSS2             1.273589e-36
# Submucosal_Secretory_smoking_status[T.True]_ACE2     4.053372e-09
# Submucosal_Secretory_smoking_status[T.True]_CTSL     5.059754e-03
# Submucosal_Secretory_smoking_status[T.True]_TMP...   7.174169e-03
# AT1_age_ACE2                                         5.823080e-02
# AT1_age_CTSL                                         5.886407e-02
# AT1_age_TMPRSS2                                      4.273932e-57
# AT1_sex[T.male]_ACE2                                 1.854418e-02
# AT1_sex[T.male]_CTSL                                 6.837584e-23
# AT1_sex[T.male]_TMPRSS2                             1.924583e-249
# AT1_smoking_status[T.True]_ACE2                      2.904905e-01
# AT1_smoking_status[T.True]_CTSL                      6.713938e-05
# AT1_smoking_status[T.True]_TMPRSS2                   1.645028e-03
# AT2_age_ACE2                                         4.552959e-24
# AT2_age_CTSL                                         7.452178e-32
# AT2_age_TMPRSS2                                      0.000000e+00
# AT2_sex[T.male]_ACE2                                 4.251463e-52
# AT2_sex[T.male]_CTSL                                 1.993684e-14
# AT2_sex[T.male]_TMPRSS2                              5.616730e-01
# AT2_smoking_status[T.True]_ACE2                      6.000591e-10
# AT2_smoking_status[T.True]_CTSL                      3.363359e-11
# AT2_smoking_status[T.True]_TMPRSS2                   4.570280e-52
# Arterial_age_CTSL                                    2.257205e-01
# Arterial_sex[T.male]_CTSL                            3.147894e-02
# Arterial_smoking_status[T.True]_CTSL                 4.551554e-01
# Capillary_age_CTSL                                   5.494895e-01
# Capillary_age_TMPRSS2                                1.788015e-01
# ...
# Lymphatic_EC_age_CTSL                                                   False
# Lymphatic_EC_age_TMPRSS2                                                False
# Lymphatic_EC_sex[T.male]_CTSL                                           False
# Lymphatic_EC_sex[T.male]_TMPRSS2                                        False
# Lymphatic_EC_smoking_status[T.True]_CTSL                                False
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2                             False
# Fibroblasts_age_ACE2                                                    False
# Fibroblasts_age_CTSL                                                    False
# Fibroblasts_age_TMPRSS2                                                 False
# Fibroblasts_sex[T.male]_ACE2                                            False
# Fibroblasts_sex[T.male]_CTSL                                            False
# Fibroblasts_sex[T.male]_TMPRSS2                                         False
# Fibroblasts_smoking_status[T.True]_ACE2                                 False
# Fibroblasts_smoking_status[T.True]_CTSL                                  True
# Fibroblasts_smoking_status[T.True]_TMPRSS2                              False
# Airway_smooth_muscle_age_CTSL                                           False
# Airway_smooth_muscle_sex[T.male]_CTSL                                   False
# Airway_smooth_muscle_smoking_status[T.True]_CTSL                        False
# B_cell_lineage_age_CTSL                                                 False
# B_cell_lineage_age_TMPRSS2                                              False
# B_cell_lineage_sex[T.male]_CTSL                                         False
# B_cell_lineage_sex[T.male]_TMPRSS2                                      False
# B_cell_lineage_smoking_status[T.True]_CTSL                              False
# B_cell_lineage_smoking_status[T.True]_TMPRSS2                           False
# T_cell_lineage_age_ACE2                                                 False
# T_cell_lineage_age_CTSL                                                 False
# T_cell_lineage_age_TMPRSS2                                              False
# T_cell_lineage_sex[T.male]_ACE2                                         False
# T_cell_lineage_sex[T.male]_CTSL                                         False
# T_cell_lineage_sex[T.male]_TMPRSS2                                       True
# T_cell_lineage_smoking_status[T.True]_ACE2                              False
# T_cell_lineage_smoking_status[T.True]_CTSL                              False
# T_cell_lineage_smoking_status[T.True]_TMPRSS2                           False
# Innate_lymphoid_cells_age_CTSL                                          False
# Innate_lymphoid_cells_age_TMPRSS2                                       False
# Innate_lymphoid_cells_sex[T.male]_CTSL                                   True
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2                               False
# Innate_lymphoid_cells_smoking_status[T.True]_CTSL                       False
# Innate_lymphoid_cells_smoking_status[T.True]_TM...                      False
# Dendritic_cells_age_CTSL                                                 True
# Dendritic_cells_age_TMPRSS2                                             False
# Dendritic_cells_sex[T.male]_CTSL                                         True
# Dendritic_cells_sex[T.male]_TMPRSS2                                     False
# Dendritic_cells_smoking_status[T.True]_CTSL                              True
# Dendritic_cells_smoking_status[T.True]_TMPRSS2                          False
# Macrophages_age_ACE2                                                    False
# Macrophages_age_CTSL                                                    False
# Macrophages_age_TMPRSS2                                                 False
# Macrophages_sex[T.male]_ACE2                                            False
# Macrophages_sex[T.male]_CTSL                                             True
# Macrophages_sex[T.male]_TMPRSS2                                          True
# Macrophages_smoking_status[T.True]_ACE2                                 False
# Macrophages_smoking_status[T.True]_CTSL                                 False
# Macrophages_smoking_status[T.True]_TMPRSS2                              False
# Monocytes_age_ACE2                                                      False
# Monocytes_age_CTSL                                                      False
# Monocytes_age_TMPRSS2                                                    True
# Monocytes_sex[T.male]_ACE2                                              False
# Monocytes_sex[T.male]_CTSL                                              False
# Monocytes_sex[T.male]_TMPRSS2                                            True
# Monocytes_smoking_status[T.True]_ACE2                                   False
# Monocytes_smoking_status[T.True]_CTSL                                    True
# Monocytes_smoking_status[T.True]_TMPRSS2                                False
# Mast_cells_age_CTSL                                                     False
# Mast_cells_age_TMPRSS2                                                  False
# Mast_cells_sex[T.male]_CTSL                                             False
# Mast_cells_sex[T.male]_TMPRSS2                                          False
# Mast_cells_smoking_status[T.True]_CTSL                                   True
# Mast_cells_smoking_status[T.True]_TMPRSS2                               False
#
#                                                    covariate_simple
# Basal_age_ACE2                                                  Age
# Basal_age_CTSL                                                  Age
# Basal_age_TMPRSS2                                               Age
# Basal_sex[T.male]_ACE2                                          Sex
# Basal_sex[T.male]_CTSL                                          Sex
# Basal_sex[T.male]_TMPRSS2                                       Sex
# Basal_smoking_status[T.True]_ACE2                    Smoking_status
# Basal_smoking_status[T.True]_CTSL                    Smoking_status
# Basal_smoking_status[T.True]_TMPRSS2                 Smoking_status
# Multiciliated_lineage_age_ACE2                                  Age
# Multiciliated_lineage_age_CTSL                                  Age
# Multiciliated_lineage_age_TMPRSS2                               Age
# Multiciliated_lineage_sex[T.male]_ACE2                          Sex
# Multiciliated_lineage_sex[T.male]_CTSL                          Sex
# Multiciliated_lineage_sex[T.male]_TMPRSS2                       Sex
# Multiciliated_lineage_smoking_status[T.True]_ACE2    Smoking_status
# Multiciliated_lineage_smoking_status[T.True]_CTSL    Smoking_status
# Multiciliated_lineage_smoking_status[T.True]_TM...   Smoking_status
# Secretory_age_ACE2                                              Age
# Secretory_age_CTSL                                              Age
# Secretory_age_TMPRSS2                                           Age
# Secretory_sex[T.male]_ACE2                                      Sex
# Secretory_sex[T.male]_CTSL                                      Sex
# Secretory_sex[T.male]_TMPRSS2                                   Sex
# Secretory_smoking_status[T.True]_ACE2                Smoking_status
# Secretory_smoking_status[T.True]_CTSL                Smoking_status
# Secretory_smoking_status[T.True]_TMPRSS2             Smoking_status
# Rare_age_ACE2                                                   Age
# Rare_age_CTSL                                                   Age
# Rare_age_TMPRSS2                                                Age
# Rare_sex[T.male]_ACE2                                           Sex
# Rare_sex[T.male]_CTSL                                           Sex
# Rare_sex[T.male]_TMPRSS2                                        Sex
# Rare_smoking_status[T.True]_ACE2                     Smoking_status
# Rare_smoking_status[T.True]_CTSL                     Smoking_status
# Rare_smoking_status[T.True]_TMPRSS2                  Smoking_status
# Submucosal_Secretory_age_ACE2                                   Age
# Submucosal_Secretory_age_CTSL                                   Age
# Submucosal_Secretory_age_TMPRSS2                                Age
# Submucosal_Secretory_sex[T.male]_ACE2                           Sex
# Submucosal_Secretory_sex[T.male]_CTSL                           Sex
# Submucosal_Secretory_sex[T.male]_TMPRSS2                        Sex
# Submucosal_Secretory_smoking_status[T.True]_ACE2     Smoking_status
# Submucosal_Secretory_smoking_status[T.True]_CTSL     Smoking_status
# Submucosal_Secretory_smoking_status[T.True]_TMP...   Smoking_status
# AT1_age_ACE2                                                    Age
# AT1_age_CTSL                                                    Age
# AT1_age_TMPRSS2                                                 Age
# AT1_sex[T.male]_ACE2                                            Sex
# AT1_sex[T.male]_CTSL                                            Sex
# AT1_sex[T.male]_TMPRSS2                                         Sex
# AT1_smoking_status[T.True]_ACE2                      Smoking_status
# AT1_smoking_status[T.True]_CTSL                      Smoking_status
# AT1_smoking_status[T.True]_TMPRSS2                   Smoking_status
# AT2_age_ACE2                                                    Age
# AT2_age_CTSL                                                    Age
# AT2_age_TMPRSS2                                                 Age
# AT2_sex[T.male]_ACE2                                            Sex
# AT2_sex[T.male]_CTSL                                            Sex
# AT2_sex[T.male]_TMPRSS2                                         Sex
# AT2_smoking_status[T.True]_ACE2                      Smoking_status
# AT2_smoking_status[T.True]_CTSL                      Smoking_status
# AT2_smoking_status[T.True]_TMPRSS2                   Smoking_status
# Arterial_age_CTSL                                               Age
# Arterial_sex[T.male]_CTSL                                       Sex
# Arterial_smoking_status[T.True]_CTSL                 Smoking_status
# Capillary_age_CTSL                                              Age
# Capillary_age_TMPRSS2                                           Age
# Capillary_sex[T.male]_CTSL                                      Sex
# Capillary_sex[T.male]_TMPRSS2                                   Sex
# Capillary_smoking_status[T.True]_CTSL                Smoking_status
# Capillary_smoking_status[T.True]_TMPRSS2             Smoking_status
# Venous_age_CTSL                                                 Age
# Venous_age_TMPRSS2                                              Age
# Venous_sex[T.male]_CTSL                                         Sex
# Venous_sex[T.male]_TMPRSS2                                      Sex
# Venous_smoking_status[T.True]_CTSL                   Smoking_status
# Venous_smoking_status[T.True]_TMPRSS2                Smoking_status
# Lymphatic_EC_age_CTSL                                           Age
# Lymphatic_EC_age_TMPRSS2                                        Age
# Lymphatic_EC_sex[T.male]_CTSL                                   Sex
# Lymphatic_EC_sex[T.male]_TMPRSS2                                Sex
# Lymphatic_EC_smoking_status[T.True]_CTSL             Smoking_status
# Lymphatic_EC_smoking_status[T.True]_TMPRSS2          Smoking_status
# Fibroblasts_age_ACE2                                            Age
# Fibroblasts_age_CTSL                                            Age
# Fibroblasts_age_TMPRSS2                                         Age
# Fibroblasts_sex[T.male]_ACE2                                    Sex
# Fibroblasts_sex[T.male]_CTSL                                    Sex
# Fibroblasts_sex[T.male]_TMPRSS2                                 Sex
# Fibroblasts_smoking_status[T.True]_ACE2              Smoking_status
# Fibroblasts_smoking_status[T.True]_CTSL              Smoking_status
# Fibroblasts_smoking_status[T.True]_TMPRSS2           Smoking_status
# Airway_smooth_muscle_age_CTSL                                   Age
# Airway_smooth_muscle_sex[T.male]_CTSL                           Sex
# Airway_smooth_muscle_smoking_status[T.True]_CTSL     Smoking_status
# B_cell_lineage_age_CTSL                                         Age
# B_cell_lineage_age_TMPRSS2                                      Age
# B_cell_lineage_sex[T.male]_CTSL                                 Sex
# B_cell_lineage_sex[T.male]_TMPRSS2                              Sex
# B_cell_lineage_smoking_status[T.True]_CTSL           Smoking_status
# B_cell_lineage_smoking_status[T.True]_TMPRSS2        Smoking_status
# T_cell_lineage_age_ACE2                                         Age
# T_cell_lineage_age_CTSL                                         Age
# T_cell_lineage_age_TMPRSS2                                      Age
# T_cell_lineage_sex[T.male]_ACE2                                 Sex
# T_cell_lineage_sex[T.male]_CTSL                                 Sex
# T_cell_lineage_sex[T.male]_TMPRSS2                              Sex
# T_cell_lineage_smoking_status[T.True]_ACE2           Smoking_status
# T_cell_lineage_smoking_status[T.True]_CTSL           Smoking_status
# T_cell_lineage_smoking_status[T.True]_TMPRSS2        Smoking_status
# Innate_lymphoid_cells_age_CTSL                                  Age
# Innate_lymphoid_cells_age_TMPRSS2                               Age
# Innate_lymphoid_cells_sex[T.male]_CTSL                          Sex
# Innate_lymphoid_cells_sex[T.male]_TMPRSS2                       Sex
# Innate_lymphoid_cells_smoking_status[T.True]_CTSL    Smoking_status
# Innate_lymphoid_cells_smoking_status[T.True]_TM...   Smoking_status
# Dendritic_cells_age_CTSL                                        Age
# Dendritic_cells_age_TMPRSS2                                     Age
# Dendritic_cells_sex[T.male]_CTSL                                Sex
# Dendritic_cells_sex[T.male]_TMPRSS2                             Sex
# Dendritic_cells_smoking_status[T.True]_CTSL          Smoking_status
# Dendritic_cells_smoking_status[T.True]_TMPRSS2       Smoking_status
# Macrophages_age_ACE2                                            Age
# Macrophages_age_CTSL                                            Age
# Macrophages_age_TMPRSS2                                         Age
# Macrophages_sex[T.male]_ACE2                                    Sex
# Macrophages_sex[T.male]_CTSL                                    Sex
# Macrophages_sex[T.male]_TMPRSS2                                 Sex
# Macrophages_smoking_status[T.True]_ACE2              Smoking_status
# Macrophages_smoking_status[T.True]_CTSL              Smoking_status
# Macrophages_smoking_status[T.True]_TMPRSS2           Smoking_status
# Monocytes_age_ACE2                                              Age
# Monocytes_age_CTSL                                              Age
# Monocytes_age_TMPRSS2                                           Age
# Monocytes_sex[T.male]_ACE2                                      Sex
# Monocytes_sex[T.male]_CTSL                                      Sex
# Monocytes_sex[T.male]_TMPRSS2                                   Sex
# Monocytes_smoking_status[T.True]_ACE2                Smoking_status
# Monocytes_smoking_status[T.True]_CTSL                Smoking_status
# Monocytes_smoking_status[T.True]_TMPRSS2             Smoking_status
# Mast_cells_age_CTSL                                             Age
# Mast_cells_age_TMPRSS2                                          Age
# Mast_cells_sex[T.male]_CTSL                                     Sex
# Mast_cells_sex[T.male]_TMPRSS2                                  Sex
# Mast_cells_smoking_status[T.True]_CTSL               Smoking_status
# Mast_cells_smoking_status[T.True]_TMPRSS2            Smoking_status

# %% [markdown]
# ## Level 2

# %%
res_lvl2['cell_identity'].unique()
# Out:
# array(['Myeloid', 'Airway epithelium', 'Alveolar epithelium', 'Lymphoid',
#        'Fibroblast lineage', 'Blood vessels', 'Submucosal Gland',
#        'Smooth Muscle', 'Lymphatics', 'Mesothelium'], dtype=object)

# %%
# Prep plotting

# Order cell identity category
res_lvl2['cell_identity'] = res_lvl2['cell_identity'].astype('category').cat.set_categories(['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium', 'Blood vessels', 'Lymphatics', 'Fibroblast lineage', 'Smooth Muscle', 'Mesothelium', 'Lymphoid', 'Myeloid'], ordered=True)
res_lvl2 = res_lvl2.sort_values(by='cell_identity')

# Create hierarchy of cell identities
ct_hierarchy = {'Epithelial':['Airway epithelium', 'Submucosal Gland', 'Alveolar epithelium'], 'Endothelial':['Blood vessels', 'Lymphatics'], 'Stroma':['Fibroblast lineage', 'Smooth Muscle', 'Mesothelium'], 'Immune':['Lymphoid', 'Myeloid']}
ct_mapping_up = dict()
for key,val in ct_hierarchy.items():
    for v in val:
        ct_mapping_up[v] = key

# Assign cell type compartment covariate
res_lvl2['compartment'] = [ct_mapping_up[ct] for ct in res_lvl2['cell_identity']]        

# Check if bulk and sc effect directions agree
res_lvl2_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl2_pseudo[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl2.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl2[['cell_identity', 'covariate', 'gene']].values.tolist()]
res_lvl2['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl2['coef'].loc[res_lvl2.index[i]]* res_lvl2_pseudo['coef'].loc[res_lvl2.index[i]]) > 0) for i,val in enumerate(res_lvl2['adj_pvals'])]


# Check if simple and complex models agree

# Check if bulk and sc effect directions agree in interaction model
res_lvl2_ints_pseudo.index = ['_'.join(vals).replace(' ','_') for vals in res_lvl2_ints_pseudo[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2_ints.index = ['_'.join(vals).replace(' ', '_') for vals in res_lvl2_ints[['cell_identity', 'covariate', 'gene', 'eval_at']].values.tolist()]
res_lvl2_ints['signif_bulk_agree'] = [(val < 0.05) and ((res_lvl2_ints['coef'].loc[res_lvl2_ints.index[i]]* res_lvl2_ints_pseudo['coef'].loc[res_lvl2_ints.index[i]]) > 0) for i,val in enumerate(res_lvl2_ints['adj_pvals'])]

# Criteria:
# 1. No "indication" in opposite direction (significant and pseudo agrees)
# 2. At least 1 "indication" in the correct direction.

bulk_complex_agree = []

for idx in res_lvl2.index:
    mask = [str(idx) in str(i) for i in res_lvl2_ints.index]
    tmp = res_lvl2_ints.loc[mask]
    complex_vals = tmp['coef'].loc[tmp['signif_bulk_agree'].values].values

    if len(complex_vals) == 0:
        # No indication in complex interaction model
        bulk_complex_agree.append(False)

    else:
        # Check that all indications or robust trends point in the same direction
        # as the simple model case:
        int_agree = np.all([res_lvl2['coef'].loc[idx]*val > 0 for val in complex_vals])
        val = res_lvl2['signif_bulk_agree'].loc[idx] and int_agree
        bulk_complex_agree.append(val)
        
res_lvl2['signif_bulk_complex_agree'] = bulk_complex_agree


res_lvl2['compartment'] = res_lvl2['compartment'].astype('category').cat.set_categories(['Epithelial', 'Endothelial', 'Stroma', 'Immune'], ordered=True)
res_lvl2['covariate_simple'] = res_lvl2['covariate'].astype('category').cat.rename_categories(['Age', 'Sex', 'Smoking_status'])

res_lvl2 = res_lvl2.sort_values(by=['cell_identity', 'covariate', 'gene'])

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()


leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.45, 2.3], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl2_barplots_lvl1_separated.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# <ErrorbarContainer object of 3 artists>
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')

# %%
res_lvl2.sort_values(by=[ 'covariate', 'cell_identity',  'gene'])
# Out:
#                                                        gene  \
# Airway_epithelium_age_ACE2                             ACE2
# Airway_epithelium_age_CTSL                             CTSL
# Airway_epithelium_age_TMPRSS2                       TMPRSS2
# Submucosal_Gland_age_ACE2                              ACE2
# Submucosal_Gland_age_CTSL                              CTSL
# Submucosal_Gland_age_TMPRSS2                        TMPRSS2
# Alveolar_epithelium_age_ACE2                           ACE2
# Alveolar_epithelium_age_CTSL                           CTSL
# Alveolar_epithelium_age_TMPRSS2                     TMPRSS2
# Blood_vessels_age_ACE2                                 ACE2
# Blood_vessels_age_CTSL                                 CTSL
# Blood_vessels_age_TMPRSS2                           TMPRSS2
# Lymphatics_age_CTSL                                    CTSL
# Lymphatics_age_TMPRSS2                              TMPRSS2
# Fibroblast_lineage_age_ACE2                            ACE2
# Fibroblast_lineage_age_CTSL                            CTSL
# Fibroblast_lineage_age_TMPRSS2                      TMPRSS2
# Smooth_Muscle_age_ACE2                                 ACE2
# Smooth_Muscle_age_CTSL                                 CTSL
# Smooth_Muscle_age_TMPRSS2                           TMPRSS2
# Mesothelium_age_CTSL                                   CTSL
# Mesothelium_age_TMPRSS2                             TMPRSS2
# Lymphoid_age_ACE2                                      ACE2
# Lymphoid_age_CTSL                                      CTSL
# Lymphoid_age_TMPRSS2                                TMPRSS2
# Myeloid_age_ACE2                                       ACE2
# Myeloid_age_CTSL                                       CTSL
# Myeloid_age_TMPRSS2                                 TMPRSS2
# Airway_epithelium_sex[T.male]_ACE2                     ACE2
# Airway_epithelium_sex[T.male]_CTSL                     CTSL
# Airway_epithelium_sex[T.male]_TMPRSS2               TMPRSS2
# Submucosal_Gland_sex[T.male]_ACE2                      ACE2
# Submucosal_Gland_sex[T.male]_CTSL                      CTSL
# Submucosal_Gland_sex[T.male]_TMPRSS2                TMPRSS2
# Alveolar_epithelium_sex[T.male]_ACE2                   ACE2
# Alveolar_epithelium_sex[T.male]_CTSL                   CTSL
# Alveolar_epithelium_sex[T.male]_TMPRSS2             TMPRSS2
# Blood_vessels_sex[T.male]_ACE2                         ACE2
# Blood_vessels_sex[T.male]_CTSL                         CTSL
# Blood_vessels_sex[T.male]_TMPRSS2                   TMPRSS2
# Lymphatics_sex[T.male]_CTSL                            CTSL
# Lymphatics_sex[T.male]_TMPRSS2                      TMPRSS2
# Fibroblast_lineage_sex[T.male]_ACE2                    ACE2
# Fibroblast_lineage_sex[T.male]_CTSL                    CTSL
# Fibroblast_lineage_sex[T.male]_TMPRSS2              TMPRSS2
# Smooth_Muscle_sex[T.male]_ACE2                         ACE2
# Smooth_Muscle_sex[T.male]_CTSL                         CTSL
# Smooth_Muscle_sex[T.male]_TMPRSS2                   TMPRSS2
# Mesothelium_sex[T.male]_CTSL                           CTSL
# Mesothelium_sex[T.male]_TMPRSS2                     TMPRSS2
# Lymphoid_sex[T.male]_ACE2                              ACE2
# Lymphoid_sex[T.male]_CTSL                              CTSL
# Lymphoid_sex[T.male]_TMPRSS2                        TMPRSS2
# Myeloid_sex[T.male]_ACE2                               ACE2
# Myeloid_sex[T.male]_CTSL                               CTSL
# Myeloid_sex[T.male]_TMPRSS2                         TMPRSS2
# Airway_epithelium_smoking_status[T.True]_ACE2          ACE2
# Airway_epithelium_smoking_status[T.True]_CTSL          CTSL
# Airway_epithelium_smoking_status[T.True]_TMPRSS2    TMPRSS2
# Submucosal_Gland_smoking_status[T.True]_ACE2           ACE2
# Submucosal_Gland_smoking_status[T.True]_CTSL           CTSL
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2     TMPRSS2
# Alveolar_epithelium_smoking_status[T.True]_ACE2        ACE2
# Alveolar_epithelium_smoking_status[T.True]_CTSL        CTSL
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2  TMPRSS2
# Blood_vessels_smoking_status[T.True]_ACE2              ACE2
# Blood_vessels_smoking_status[T.True]_CTSL              CTSL
# Blood_vessels_smoking_status[T.True]_TMPRSS2        TMPRSS2
# Lymphatics_smoking_status[T.True]_CTSL                 CTSL
# Lymphatics_smoking_status[T.True]_TMPRSS2           TMPRSS2
# Fibroblast_lineage_smoking_status[T.True]_ACE2         ACE2
# Fibroblast_lineage_smoking_status[T.True]_CTSL         CTSL
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2   TMPRSS2
# Smooth_Muscle_smoking_status[T.True]_ACE2              ACE2
# Smooth_Muscle_smoking_status[T.True]_CTSL              CTSL
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2        TMPRSS2
# Mesothelium_smoking_status[T.True]_CTSL                CTSL
# Mesothelium_smoking_status[T.True]_TMPRSS2          TMPRSS2
# Lymphoid_smoking_status[T.True]_ACE2                   ACE2
# Lymphoid_smoking_status[T.True]_CTSL                   CTSL
# Lymphoid_smoking_status[T.True]_TMPRSS2             TMPRSS2
# Myeloid_smoking_status[T.True]_ACE2                    ACE2
# Myeloid_smoking_status[T.True]_CTSL                    CTSL
# Myeloid_smoking_status[T.True]_TMPRSS2              TMPRSS2
#
#                                                           cell_identity  \
# Airway_epithelium_age_ACE2                            Airway epithelium
# Airway_epithelium_age_CTSL                            Airway epithelium
# Airway_epithelium_age_TMPRSS2                         Airway epithelium
# Submucosal_Gland_age_ACE2                              Submucosal Gland
# Submucosal_Gland_age_CTSL                              Submucosal Gland
# Submucosal_Gland_age_TMPRSS2                           Submucosal Gland
# Alveolar_epithelium_age_ACE2                        Alveolar epithelium
# Alveolar_epithelium_age_CTSL                        Alveolar epithelium
# Alveolar_epithelium_age_TMPRSS2                     Alveolar epithelium
# Blood_vessels_age_ACE2                                    Blood vessels
# Blood_vessels_age_CTSL                                    Blood vessels
# Blood_vessels_age_TMPRSS2                                 Blood vessels
# Lymphatics_age_CTSL                                          Lymphatics
# Lymphatics_age_TMPRSS2                                       Lymphatics
# Fibroblast_lineage_age_ACE2                          Fibroblast lineage
# Fibroblast_lineage_age_CTSL                          Fibroblast lineage
# Fibroblast_lineage_age_TMPRSS2                       Fibroblast lineage
# Smooth_Muscle_age_ACE2                                    Smooth Muscle
# Smooth_Muscle_age_CTSL                                    Smooth Muscle
# Smooth_Muscle_age_TMPRSS2                                 Smooth Muscle
# Mesothelium_age_CTSL                                        Mesothelium
# Mesothelium_age_TMPRSS2                                     Mesothelium
# Lymphoid_age_ACE2                                              Lymphoid
# Lymphoid_age_CTSL                                              Lymphoid
# Lymphoid_age_TMPRSS2                                           Lymphoid
# Myeloid_age_ACE2                                                Myeloid
# Myeloid_age_CTSL                                                Myeloid
# Myeloid_age_TMPRSS2                                             Myeloid
# Airway_epithelium_sex[T.male]_ACE2                    Airway epithelium
# Airway_epithelium_sex[T.male]_CTSL                    Airway epithelium
# Airway_epithelium_sex[T.male]_TMPRSS2                 Airway epithelium
# Submucosal_Gland_sex[T.male]_ACE2                      Submucosal Gland
# Submucosal_Gland_sex[T.male]_CTSL                      Submucosal Gland
# Submucosal_Gland_sex[T.male]_TMPRSS2                   Submucosal Gland
# Alveolar_epithelium_sex[T.male]_ACE2                Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_CTSL                Alveolar epithelium
# Alveolar_epithelium_sex[T.male]_TMPRSS2             Alveolar epithelium
# Blood_vessels_sex[T.male]_ACE2                            Blood vessels
# Blood_vessels_sex[T.male]_CTSL                            Blood vessels
# Blood_vessels_sex[T.male]_TMPRSS2                         Blood vessels
# Lymphatics_sex[T.male]_CTSL                                  Lymphatics
# Lymphatics_sex[T.male]_TMPRSS2                               Lymphatics
# Fibroblast_lineage_sex[T.male]_ACE2                  Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_CTSL                  Fibroblast lineage
# Fibroblast_lineage_sex[T.male]_TMPRSS2               Fibroblast lineage
# Smooth_Muscle_sex[T.male]_ACE2                            Smooth Muscle
# Smooth_Muscle_sex[T.male]_CTSL                            Smooth Muscle
# Smooth_Muscle_sex[T.male]_TMPRSS2                         Smooth Muscle
# Mesothelium_sex[T.male]_CTSL                                Mesothelium
# Mesothelium_sex[T.male]_TMPRSS2                             Mesothelium
# Lymphoid_sex[T.male]_ACE2                                      Lymphoid
# Lymphoid_sex[T.male]_CTSL                                      Lymphoid
# Lymphoid_sex[T.male]_TMPRSS2                                   Lymphoid
# Myeloid_sex[T.male]_ACE2                                        Myeloid
# Myeloid_sex[T.male]_CTSL                                        Myeloid
# Myeloid_sex[T.male]_TMPRSS2                                     Myeloid
# Airway_epithelium_smoking_status[T.True]_ACE2         Airway epithelium
# Airway_epithelium_smoking_status[T.True]_CTSL         Airway epithelium
# Airway_epithelium_smoking_status[T.True]_TMPRSS2      Airway epithelium
# Submucosal_Gland_smoking_status[T.True]_ACE2           Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_CTSL           Submucosal Gland
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2        Submucosal Gland
# Alveolar_epithelium_smoking_status[T.True]_ACE2     Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_CTSL     Alveolar epithelium
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2  Alveolar epithelium
# Blood_vessels_smoking_status[T.True]_ACE2                 Blood vessels
# Blood_vessels_smoking_status[T.True]_CTSL                 Blood vessels
# Blood_vessels_smoking_status[T.True]_TMPRSS2              Blood vessels
# Lymphatics_smoking_status[T.True]_CTSL                       Lymphatics
# Lymphatics_smoking_status[T.True]_TMPRSS2                    Lymphatics
# Fibroblast_lineage_smoking_status[T.True]_ACE2       Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_CTSL       Fibroblast lineage
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2    Fibroblast lineage
# Smooth_Muscle_smoking_status[T.True]_ACE2                 Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_CTSL                 Smooth Muscle
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2              Smooth Muscle
# Mesothelium_smoking_status[T.True]_CTSL                     Mesothelium
# Mesothelium_smoking_status[T.True]_TMPRSS2                  Mesothelium
# Lymphoid_smoking_status[T.True]_ACE2                           Lymphoid
# Lymphoid_smoking_status[T.True]_CTSL                           Lymphoid
# Lymphoid_smoking_status[T.True]_TMPRSS2                        Lymphoid
# Myeloid_smoking_status[T.True]_ACE2                             Myeloid
# Myeloid_smoking_status[T.True]_CTSL                             Myeloid
# Myeloid_smoking_status[T.True]_TMPRSS2                          Myeloid
#
#                                                                  covariate  \
# Airway_epithelium_age_ACE2                                             age
# Airway_epithelium_age_CTSL                                             age
# Airway_epithelium_age_TMPRSS2                                          age
# Submucosal_Gland_age_ACE2                                              age
# Submucosal_Gland_age_CTSL                                              age
# Submucosal_Gland_age_TMPRSS2                                           age
# Alveolar_epithelium_age_ACE2                                           age
# Alveolar_epithelium_age_CTSL                                           age
# Alveolar_epithelium_age_TMPRSS2                                        age
# Blood_vessels_age_ACE2                                                 age
# Blood_vessels_age_CTSL                                                 age
# Blood_vessels_age_TMPRSS2                                              age
# Lymphatics_age_CTSL                                                    age
# Lymphatics_age_TMPRSS2                                                 age
# Fibroblast_lineage_age_ACE2                                            age
# Fibroblast_lineage_age_CTSL                                            age
# Fibroblast_lineage_age_TMPRSS2                                         age
# Smooth_Muscle_age_ACE2                                                 age
# Smooth_Muscle_age_CTSL                                                 age
# Smooth_Muscle_age_TMPRSS2                                              age
# Mesothelium_age_CTSL                                                   age
# Mesothelium_age_TMPRSS2                                                age
# Lymphoid_age_ACE2                                                      age
# Lymphoid_age_CTSL                                                      age
# Lymphoid_age_TMPRSS2                                                   age
# Myeloid_age_ACE2                                                       age
# Myeloid_age_CTSL                                                       age
# Myeloid_age_TMPRSS2                                                    age
# Airway_epithelium_sex[T.male]_ACE2                             sex[T.male]
# Airway_epithelium_sex[T.male]_CTSL                             sex[T.male]
# Airway_epithelium_sex[T.male]_TMPRSS2                          sex[T.male]
# Submucosal_Gland_sex[T.male]_ACE2                              sex[T.male]
# Submucosal_Gland_sex[T.male]_CTSL                              sex[T.male]
# Submucosal_Gland_sex[T.male]_TMPRSS2                           sex[T.male]
# Alveolar_epithelium_sex[T.male]_ACE2                           sex[T.male]
# Alveolar_epithelium_sex[T.male]_CTSL                           sex[T.male]
# Alveolar_epithelium_sex[T.male]_TMPRSS2                        sex[T.male]
# Blood_vessels_sex[T.male]_ACE2                                 sex[T.male]
# Blood_vessels_sex[T.male]_CTSL                                 sex[T.male]
# Blood_vessels_sex[T.male]_TMPRSS2                              sex[T.male]
# Lymphatics_sex[T.male]_CTSL                                    sex[T.male]
# Lymphatics_sex[T.male]_TMPRSS2                                 sex[T.male]
# Fibroblast_lineage_sex[T.male]_ACE2                            sex[T.male]
# Fibroblast_lineage_sex[T.male]_CTSL                            sex[T.male]
# Fibroblast_lineage_sex[T.male]_TMPRSS2                         sex[T.male]
# Smooth_Muscle_sex[T.male]_ACE2                                 sex[T.male]
# Smooth_Muscle_sex[T.male]_CTSL                                 sex[T.male]
# Smooth_Muscle_sex[T.male]_TMPRSS2                              sex[T.male]
# Mesothelium_sex[T.male]_CTSL                                   sex[T.male]
# Mesothelium_sex[T.male]_TMPRSS2                                sex[T.male]
# Lymphoid_sex[T.male]_ACE2                                      sex[T.male]
# Lymphoid_sex[T.male]_CTSL                                      sex[T.male]
# Lymphoid_sex[T.male]_TMPRSS2                                   sex[T.male]
# Myeloid_sex[T.male]_ACE2                                       sex[T.male]
# Myeloid_sex[T.male]_CTSL                                       sex[T.male]
# Myeloid_sex[T.male]_TMPRSS2                                    sex[T.male]
# Airway_epithelium_smoking_status[T.True]_ACE2       smoking_status[T.True]
# Airway_epithelium_smoking_status[T.True]_CTSL       smoking_status[T.True]
# Airway_epithelium_smoking_status[T.True]_TMPRSS2    smoking_status[T.True]
# Submucosal_Gland_smoking_status[T.True]_ACE2        smoking_status[T.True]
# Submucosal_Gland_smoking_status[T.True]_CTSL        smoking_status[T.True]
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2     smoking_status[T.True]
# Alveolar_epithelium_smoking_status[T.True]_ACE2     smoking_status[T.True]
# Alveolar_epithelium_smoking_status[T.True]_CTSL     smoking_status[T.True]
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2  smoking_status[T.True]
# Blood_vessels_smoking_status[T.True]_ACE2           smoking_status[T.True]
# Blood_vessels_smoking_status[T.True]_CTSL           smoking_status[T.True]
# Blood_vessels_smoking_status[T.True]_TMPRSS2        smoking_status[T.True]
# Lymphatics_smoking_status[T.True]_CTSL              smoking_status[T.True]
# Lymphatics_smoking_status[T.True]_TMPRSS2           smoking_status[T.True]
# Fibroblast_lineage_smoking_status[T.True]_ACE2      smoking_status[T.True]
# Fibroblast_lineage_smoking_status[T.True]_CTSL      smoking_status[T.True]
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2   smoking_status[T.True]
# Smooth_Muscle_smoking_status[T.True]_ACE2           smoking_status[T.True]
# Smooth_Muscle_smoking_status[T.True]_CTSL           smoking_status[T.True]
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2        smoking_status[T.True]
# Mesothelium_smoking_status[T.True]_CTSL             smoking_status[T.True]
# Mesothelium_smoking_status[T.True]_TMPRSS2          smoking_status[T.True]
# Lymphoid_smoking_status[T.True]_ACE2                smoking_status[T.True]
# Lymphoid_smoking_status[T.True]_CTSL                smoking_status[T.True]
# Lymphoid_smoking_status[T.True]_TMPRSS2             smoking_status[T.True]
# Myeloid_smoking_status[T.True]_ACE2                 smoking_status[T.True]
# Myeloid_smoking_status[T.True]_CTSL                 smoking_status[T.True]
# Myeloid_smoking_status[T.True]_TMPRSS2              smoking_status[T.True]
#
#                                                          coef       coef_sd  \
# Airway_epithelium_age_ACE2                           0.003145      0.001069
# Airway_epithelium_age_CTSL                           0.003741      0.000247
# Airway_epithelium_age_TMPRSS2                        0.001193      0.000329
# Submucosal_Gland_age_ACE2                            0.002748      0.002430
# Submucosal_Gland_age_CTSL                            0.006540      0.000699
# Submucosal_Gland_age_TMPRSS2                         0.001992      0.000584
# Alveolar_epithelium_age_ACE2                         0.019934      0.001778
# Alveolar_epithelium_age_CTSL                        -0.005651      0.000398
# Alveolar_epithelium_age_TMPRSS2                      0.020185      0.000249
# Blood_vessels_age_ACE2                              -0.003619      0.011064
# Blood_vessels_age_CTSL                               0.001320      0.000825
# Blood_vessels_age_TMPRSS2                           -0.007229      0.008750
# Lymphatics_age_CTSL                                  0.004340      0.001490
# Lymphatics_age_TMPRSS2                              -0.011344      0.005926
# Fibroblast_lineage_age_ACE2                          0.001047      0.005839
# Fibroblast_lineage_age_CTSL                         -0.015589      0.000164
# Fibroblast_lineage_age_TMPRSS2                       0.008268      0.001935
# Smooth_Muscle_age_ACE2                              -0.009741      0.013822
# Smooth_Muscle_age_CTSL                              -0.011348      0.000565
# Smooth_Muscle_age_TMPRSS2                            0.003552      0.005918
# Mesothelium_age_CTSL                                 0.001612      0.002171
# Mesothelium_age_TMPRSS2                              0.056052      0.012648
# Lymphoid_age_ACE2                                   -0.031751      0.012438
# Lymphoid_age_CTSL                                    0.008780      0.000805
# Lymphoid_age_TMPRSS2                                -0.006719      0.002547
# Myeloid_age_ACE2                                     0.001611      0.005975
# Myeloid_age_CTSL                                    -0.000837      0.000076
# Myeloid_age_TMPRSS2                                 -0.001784      0.001485
# Airway_epithelium_sex[T.male]_ACE2                   0.081978      0.036025
# Airway_epithelium_sex[T.male]_CTSL                  -0.120689      0.008413
# Airway_epithelium_sex[T.male]_TMPRSS2                0.180836      0.011531
# Submucosal_Gland_sex[T.male]_ACE2                    0.053476      0.099754
# Submucosal_Gland_sex[T.male]_CTSL                   -0.097038      0.026834
# Submucosal_Gland_sex[T.male]_TMPRSS2                 0.303606      0.024020
# Alveolar_epithelium_sex[T.male]_ACE2                 0.790606      0.052292
# Alveolar_epithelium_sex[T.male]_CTSL                 0.154297      0.012132
# Alveolar_epithelium_sex[T.male]_TMPRSS2              0.073413      0.007158
# Blood_vessels_sex[T.male]_ACE2                       0.970412      0.465472
# Blood_vessels_sex[T.male]_CTSL                       0.078786      0.020905
# Blood_vessels_sex[T.male]_TMPRSS2                    0.313770      0.273492
# Lymphatics_sex[T.male]_CTSL                          0.015904      0.032492
# Lymphatics_sex[T.male]_TMPRSS2                       0.567848      0.179319
# Fibroblast_lineage_sex[T.male]_ACE2                 -0.031560      0.169980
# Fibroblast_lineage_sex[T.male]_CTSL                 -0.352246      0.005250
# Fibroblast_lineage_sex[T.male]_TMPRSS2               0.398966      0.059348
# Smooth_Muscle_sex[T.male]_ACE2                       0.086860      0.477379
# Smooth_Muscle_sex[T.male]_CTSL                      -0.411154      0.023496
# Smooth_Muscle_sex[T.male]_TMPRSS2                    0.083848      0.257809
# Mesothelium_sex[T.male]_CTSL                         0.428510      0.058953
# Mesothelium_sex[T.male]_TMPRSS2                     -1.663558      0.366465
# Lymphoid_sex[T.male]_ACE2                            0.269889      0.355072
# Lymphoid_sex[T.male]_CTSL                            0.556834      0.026645
# Lymphoid_sex[T.male]_TMPRSS2                         0.306598      0.074111
# Myeloid_sex[T.male]_ACE2                             0.466549      0.198569
# Myeloid_sex[T.male]_CTSL                            -0.097860      0.002349
# Myeloid_sex[T.male]_TMPRSS2                          0.527096      0.042296
# Airway_epithelium_smoking_status[T.True]_ACE2        0.121530      0.038061
# Airway_epithelium_smoking_status[T.True]_CTSL        0.039721      0.009080
# Airway_epithelium_smoking_status[T.True]_TMPRSS2    -0.220317      0.013620
# Submucosal_Gland_smoking_status[T.True]_ACE2         0.476008      0.080926
# Submucosal_Gland_smoking_status[T.True]_CTSL         0.072334      0.025804
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2     -0.065982      0.024541
# Alveolar_epithelium_smoking_status[T.True]_ACE2     -0.353888      0.063195
# Alveolar_epithelium_smoking_status[T.True]_CTSL      0.046193      0.015258
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2   0.145885      0.008382
# Blood_vessels_smoking_status[T.True]_ACE2           -0.136475      0.534140
# Blood_vessels_smoking_status[T.True]_CTSL            0.012610      0.032649
# Blood_vessels_smoking_status[T.True]_TMPRSS2        -0.300362      0.353536
# Lymphatics_smoking_status[T.True]_CTSL              -0.020372      0.063500
# Lymphatics_smoking_status[T.True]_TMPRSS2            0.055680      0.208976
# Fibroblast_lineage_smoking_status[T.True]_ACE2       0.377836      0.337186
# Fibroblast_lineage_smoking_status[T.True]_CTSL      -0.088681      0.012755
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2    1.024393      0.086464
# Smooth_Muscle_smoking_status[T.True]_ACE2            1.707142      0.792068
# Smooth_Muscle_smoking_status[T.True]_CTSL            0.072488      0.040215
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2         0.829539      0.321159
# Mesothelium_smoking_status[T.True]_CTSL              0.451892      0.277214
# Mesothelium_smoking_status[T.True]_TMPRSS2         -19.800701  28318.751409
# Lymphoid_smoking_status[T.True]_ACE2                -0.106855      0.434286
# Lymphoid_smoking_status[T.True]_CTSL                -0.345445      0.034771
# Lymphoid_smoking_status[T.True]_TMPRSS2              0.147052      0.084223
# Myeloid_smoking_status[T.True]_ACE2                 -0.395565      0.233139
# Myeloid_smoking_status[T.True]_CTSL                  0.008360      0.003255
# Myeloid_smoking_status[T.True]_TMPRSS2              -0.274375      0.048421
#
#                                                             pval  \
# Airway_epithelium_age_ACE2                          3.263893e-03
# Airway_epithelium_age_CTSL                          7.412355e-52
# Airway_epithelium_age_TMPRSS2                       2.918464e-04
# Submucosal_Gland_age_ACE2                           2.581117e-01
# Submucosal_Gland_age_CTSL                           8.674072e-21
# Submucosal_Gland_age_TMPRSS2                        6.522876e-04
# Alveolar_epithelium_age_ACE2                        3.564372e-29
# Alveolar_epithelium_age_CTSL                        1.178172e-45
# Alveolar_epithelium_age_TMPRSS2                     0.000000e+00
# Blood_vessels_age_ACE2                              7.436190e-01
# Blood_vessels_age_CTSL                              1.097516e-01
# Blood_vessels_age_TMPRSS2                           4.087400e-01
# Lymphatics_age_CTSL                                 3.583364e-03
# Lymphatics_age_TMPRSS2                              5.559267e-02
# Fibroblast_lineage_age_ACE2                         8.577314e-01
# Fibroblast_lineage_age_CTSL                         0.000000e+00
# Fibroblast_lineage_age_TMPRSS2                      1.932706e-05
# Smooth_Muscle_age_ACE2                              4.809487e-01
# Smooth_Muscle_age_CTSL                              1.180825e-89
# Smooth_Muscle_age_TMPRSS2                           5.483597e-01
# Mesothelium_age_CTSL                                4.577887e-01
# Mesothelium_age_TMPRSS2                             9.348742e-06
# Lymphoid_age_ACE2                                   1.068449e-02
# Lymphoid_age_CTSL                                   1.064860e-27
# Lymphoid_age_TMPRSS2                                8.349621e-03
# Myeloid_age_ACE2                                    7.873725e-01
# Myeloid_age_CTSL                                    5.928750e-28
# Myeloid_age_TMPRSS2                                 2.294559e-01
# Airway_epithelium_sex[T.male]_ACE2                  2.287090e-02
# Airway_epithelium_sex[T.male]_CTSL                  1.142095e-46
# Airway_epithelium_sex[T.male]_TMPRSS2               1.997748e-55
# Submucosal_Gland_sex[T.male]_ACE2                   5.919034e-01
# Submucosal_Gland_sex[T.male]_CTSL                   2.988976e-04
# Submucosal_Gland_sex[T.male]_TMPRSS2                1.273589e-36
# Alveolar_epithelium_sex[T.male]_ACE2                1.214520e-51
# Alveolar_epithelium_sex[T.male]_CTSL                4.658514e-37
# Alveolar_epithelium_sex[T.male]_TMPRSS2             1.107144e-24
# Blood_vessels_sex[T.male]_ACE2                      3.708805e-02
# Blood_vessels_sex[T.male]_CTSL                      1.640730e-04
# Blood_vessels_sex[T.male]_TMPRSS2                   2.512690e-01
# Lymphatics_sex[T.male]_CTSL                         6.245150e-01
# Lymphatics_sex[T.male]_TMPRSS2                      1.541841e-03
# Fibroblast_lineage_sex[T.male]_ACE2                 8.527067e-01
# Fibroblast_lineage_sex[T.male]_CTSL                 0.000000e+00
# Fibroblast_lineage_sex[T.male]_TMPRSS2              1.786947e-11
# Smooth_Muscle_sex[T.male]_ACE2                      8.556202e-01
# Smooth_Muscle_sex[T.male]_CTSL                      1.465449e-68
# Smooth_Muscle_sex[T.male]_TMPRSS2                   7.450052e-01
# Mesothelium_sex[T.male]_CTSL                        3.630670e-13
# Mesothelium_sex[T.male]_TMPRSS2                     5.639596e-06
# Lymphoid_sex[T.male]_ACE2                           4.471967e-01
# Lymphoid_sex[T.male]_CTSL                           5.524862e-97
# Lymphoid_sex[T.male]_TMPRSS2                        3.518912e-05
# Myeloid_sex[T.male]_ACE2                            1.879595e-02
# Myeloid_sex[T.male]_CTSL                            0.000000e+00
# Myeloid_sex[T.male]_TMPRSS2                         1.200709e-35
# Airway_epithelium_smoking_status[T.True]_ACE2       1.407770e-03
# Airway_epithelium_smoking_status[T.True]_CTSL       1.216111e-05
# Airway_epithelium_smoking_status[T.True]_TMPRSS2    7.421204e-59
# Submucosal_Gland_smoking_status[T.True]_ACE2        4.053372e-09
# Submucosal_Gland_smoking_status[T.True]_CTSL        5.059754e-03
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2     7.174169e-03
# Alveolar_epithelium_smoking_status[T.True]_ACE2     2.144332e-08
# Alveolar_epithelium_smoking_status[T.True]_CTSL     2.465572e-03
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2  7.552207e-68
# Blood_vessels_smoking_status[T.True]_ACE2           7.983343e-01
# Blood_vessels_smoking_status[T.True]_CTSL           6.993270e-01
# Blood_vessels_smoking_status[T.True]_TMPRSS2        3.955513e-01
# Lymphatics_smoking_status[T.True]_CTSL              7.483483e-01
# Lymphatics_smoking_status[T.True]_TMPRSS2           7.898999e-01
# Fibroblast_lineage_smoking_status[T.True]_ACE2      2.624771e-01
# Fibroblast_lineage_smoking_status[T.True]_CTSL      3.590825e-12
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2   2.214460e-32
# Smooth_Muscle_smoking_status[T.True]_ACE2           3.113860e-02
# Smooth_Muscle_smoking_status[T.True]_CTSL           7.146581e-02
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2        9.795871e-03
# Mesothelium_smoking_status[T.True]_CTSL             1.030765e-01
# Mesothelium_smoking_status[T.True]_TMPRSS2          9.994421e-01
# Lymphoid_smoking_status[T.True]_ACE2                8.056464e-01
# Lymphoid_smoking_status[T.True]_CTSL                2.939647e-23
# Lymphoid_smoking_status[T.True]_TMPRSS2             8.081532e-02
# Myeloid_smoking_status[T.True]_ACE2                 8.975567e-02
# Myeloid_smoking_status[T.True]_CTSL                 1.020989e-02
# Myeloid_smoking_status[T.True]_TMPRSS2              1.457873e-08
#
#                                                        adj_pvals  compartment  \
# Airway_epithelium_age_ACE2                          3.671880e-03   Epithelial
# Airway_epithelium_age_CTSL                          2.223706e-51   Epithelial
# Airway_epithelium_age_TMPRSS2                       4.377695e-04   Epithelial
# Submucosal_Gland_age_ACE2                           2.903756e-01   Epithelial
# Submucosal_Gland_age_CTSL                           3.903332e-20   Epithelial
# Submucosal_Gland_age_TMPRSS2                        1.174118e-03   Epithelial
# Alveolar_epithelium_age_ACE2                        5.346558e-29   Epithelial
# Alveolar_epithelium_age_CTSL                        2.650887e-45   Epithelial
# Alveolar_epithelium_age_TMPRSS2                     0.000000e+00   Epithelial
# Blood_vessels_age_ACE2                              7.983343e-01  Endothelial
# Blood_vessels_age_CTSL                              3.292548e-01  Endothelial
# Blood_vessels_age_TMPRSS2                           6.131101e-01  Endothelial
# Lymphatics_age_CTSL                                 1.075009e-02  Endothelial
# Lymphatics_age_TMPRSS2                              1.111853e-01  Endothelial
# Fibroblast_lineage_age_ACE2                         8.577314e-01       Stroma
# Fibroblast_lineage_age_CTSL                         0.000000e+00       Stroma
# Fibroblast_lineage_age_TMPRSS2                      2.899060e-05       Stroma
# Smooth_Muscle_age_ACE2                              7.050340e-01       Stroma
# Smooth_Muscle_age_CTSL                              1.062742e-88       Stroma
# Smooth_Muscle_age_TMPRSS2                           7.050340e-01       Stroma
# Mesothelium_age_CTSL                                5.493464e-01       Stroma
# Mesothelium_age_TMPRSS2                             1.869748e-05       Stroma
# Lymphoid_age_ACE2                                   1.602673e-02       Immune
# Lymphoid_age_CTSL                                   4.791871e-27       Immune
# Lymphoid_age_TMPRSS2                                1.502932e-02       Immune
# Myeloid_age_ACE2                                    7.873725e-01       Immune
# Myeloid_age_CTSL                                    1.778625e-27       Immune
# Myeloid_age_TMPRSS2                                 2.581378e-01       Immune
# Airway_epithelium_sex[T.male]_ACE2                  2.287090e-02   Epithelial
# Airway_epithelium_sex[T.male]_CTSL                  2.569715e-46   Epithelial
# Airway_epithelium_sex[T.male]_TMPRSS2               8.989864e-55   Epithelial
# Submucosal_Gland_sex[T.male]_ACE2                   5.919034e-01   Epithelial
# Submucosal_Gland_sex[T.male]_CTSL                   6.725196e-04   Epithelial
# Submucosal_Gland_sex[T.male]_TMPRSS2                1.146230e-35   Epithelial
# Alveolar_epithelium_sex[T.male]_ACE2                3.643559e-51   Epithelial
# Alveolar_epithelium_sex[T.male]_CTSL                8.385326e-37   Epithelial
# Alveolar_epithelium_sex[T.male]_TMPRSS2             1.423471e-24   Epithelial
# Blood_vessels_sex[T.male]_ACE2                      1.668962e-01  Endothelial
# Blood_vessels_sex[T.male]_CTSL                      1.476657e-03  Endothelial
# Blood_vessels_sex[T.male]_TMPRSS2                   5.653552e-01  Endothelial
# Lymphatics_sex[T.male]_CTSL                         7.898999e-01  Endothelial
# Lymphatics_sex[T.male]_TMPRSS2                      9.251045e-03  Endothelial
# Fibroblast_lineage_sex[T.male]_ACE2                 8.577314e-01       Stroma
# Fibroblast_lineage_sex[T.male]_CTSL                 0.000000e+00       Stroma
# Fibroblast_lineage_sex[T.male]_TMPRSS2              3.216504e-11       Stroma
# Smooth_Muscle_sex[T.male]_ACE2                      8.556202e-01       Stroma
# Smooth_Muscle_sex[T.male]_CTSL                      6.594518e-68       Stroma
# Smooth_Muscle_sex[T.male]_TMPRSS2                   8.381308e-01       Stroma
# Mesothelium_sex[T.male]_CTSL                        2.178402e-12       Stroma
# Mesothelium_sex[T.male]_TMPRSS2                     1.691879e-05       Stroma
# Lymphoid_sex[T.male]_ACE2                           5.030962e-01       Immune
# Lymphoid_sex[T.male]_CTSL                           4.972376e-96       Immune
# Lymphoid_sex[T.male]_TMPRSS2                        7.917551e-05       Immune
# Myeloid_sex[T.male]_ACE2                            2.819392e-02       Immune
# Myeloid_sex[T.male]_CTSL                            0.000000e+00       Immune
# Myeloid_sex[T.male]_TMPRSS2                         5.403191e-35       Immune
# Airway_epithelium_smoking_status[T.True]_ACE2       1.809990e-03   Epithelial
# Airway_epithelium_smoking_status[T.True]_CTSL       2.188999e-05   Epithelial
# Airway_epithelium_smoking_status[T.True]_TMPRSS2    6.679083e-58   Epithelial
# Submucosal_Gland_smoking_status[T.True]_ACE2        1.216012e-08   Epithelial
# Submucosal_Gland_smoking_status[T.True]_CTSL        7.589632e-03   Epithelial
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2     9.223932e-03   Epithelial
# Alveolar_epithelium_smoking_status[T.True]_ACE2     2.412374e-08   Epithelial
# Alveolar_epithelium_smoking_status[T.True]_CTSL     2.465572e-03   Epithelial
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2  3.398493e-67   Epithelial
# Blood_vessels_smoking_status[T.True]_ACE2           7.983343e-01  Endothelial
# Blood_vessels_smoking_status[T.True]_CTSL           7.983343e-01  Endothelial
# Blood_vessels_smoking_status[T.True]_TMPRSS2        6.131101e-01  Endothelial
# Lymphatics_smoking_status[T.True]_CTSL              7.898999e-01  Endothelial
# Lymphatics_smoking_status[T.True]_TMPRSS2           7.898999e-01  Endothelial
# Fibroblast_lineage_smoking_status[T.True]_ACE2      3.374706e-01       Stroma
# Fibroblast_lineage_smoking_status[T.True]_CTSL      8.079357e-12       Stroma
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2   6.643379e-32       Stroma
# Smooth_Muscle_smoking_status[T.True]_ACE2           7.006186e-02       Stroma
# Smooth_Muscle_smoking_status[T.True]_CTSL           1.286385e-01       Stroma
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2        2.938761e-02       Stroma
# Mesothelium_smoking_status[T.True]_CTSL             1.546147e-01       Stroma
# Mesothelium_smoking_status[T.True]_TMPRSS2          9.994421e-01       Stroma
# Lymphoid_smoking_status[T.True]_ACE2                8.056464e-01       Immune
# Lymphoid_smoking_status[T.True]_CTSL                8.818941e-23       Immune
# Lymphoid_smoking_status[T.True]_TMPRSS2             1.039054e-01       Immune
# Myeloid_smoking_status[T.True]_ACE2                 1.154001e-01       Immune
# Myeloid_smoking_status[T.True]_CTSL                 1.837780e-02       Immune
# Myeloid_smoking_status[T.True]_TMPRSS2              3.280215e-08       Immune
#
#                                                     signif_bulk_agree  \
# Airway_epithelium_age_ACE2                                      False
# Airway_epithelium_age_CTSL                                       True
# Airway_epithelium_age_TMPRSS2                                   False
# Submucosal_Gland_age_ACE2                                       False
# Submucosal_Gland_age_CTSL                                        True
# Submucosal_Gland_age_TMPRSS2                                     True
# Alveolar_epithelium_age_ACE2                                     True
# Alveolar_epithelium_age_CTSL                                     True
# Alveolar_epithelium_age_TMPRSS2                                  True
# Blood_vessels_age_ACE2                                          False
# Blood_vessels_age_CTSL                                          False
# Blood_vessels_age_TMPRSS2                                       False
# Lymphatics_age_CTSL                                              True
# Lymphatics_age_TMPRSS2                                          False
# Fibroblast_lineage_age_ACE2                                     False
# Fibroblast_lineage_age_CTSL                                      True
# Fibroblast_lineage_age_TMPRSS2                                   True
# Smooth_Muscle_age_ACE2                                          False
# Smooth_Muscle_age_CTSL                                           True
# Smooth_Muscle_age_TMPRSS2                                       False
# Mesothelium_age_CTSL                                            False
# Mesothelium_age_TMPRSS2                                          True
# Lymphoid_age_ACE2                                                True
# Lymphoid_age_CTSL                                                True
# Lymphoid_age_TMPRSS2                                             True
# Myeloid_age_ACE2                                                False
# Myeloid_age_CTSL                                                False
# Myeloid_age_TMPRSS2                                             False
# Airway_epithelium_sex[T.male]_ACE2                               True
# Airway_epithelium_sex[T.male]_CTSL                               True
# Airway_epithelium_sex[T.male]_TMPRSS2                            True
# Submucosal_Gland_sex[T.male]_ACE2                               False
# Submucosal_Gland_sex[T.male]_CTSL                                True
# Submucosal_Gland_sex[T.male]_TMPRSS2                             True
# Alveolar_epithelium_sex[T.male]_ACE2                             True
# Alveolar_epithelium_sex[T.male]_CTSL                             True
# Alveolar_epithelium_sex[T.male]_TMPRSS2                          True
# Blood_vessels_sex[T.male]_ACE2                                  False
# Blood_vessels_sex[T.male]_CTSL                                   True
# Blood_vessels_sex[T.male]_TMPRSS2                               False
# Lymphatics_sex[T.male]_CTSL                                     False
# Lymphatics_sex[T.male]_TMPRSS2                                   True
# Fibroblast_lineage_sex[T.male]_ACE2                             False
# Fibroblast_lineage_sex[T.male]_CTSL                              True
# Fibroblast_lineage_sex[T.male]_TMPRSS2                           True
# Smooth_Muscle_sex[T.male]_ACE2                                  False
# Smooth_Muscle_sex[T.male]_CTSL                                   True
# Smooth_Muscle_sex[T.male]_TMPRSS2                               False
# Mesothelium_sex[T.male]_CTSL                                    False
# Mesothelium_sex[T.male]_TMPRSS2                                  True
# Lymphoid_sex[T.male]_ACE2                                       False
# Lymphoid_sex[T.male]_CTSL                                        True
# Lymphoid_sex[T.male]_TMPRSS2                                     True
# Myeloid_sex[T.male]_ACE2                                         True
# Myeloid_sex[T.male]_CTSL                                         True
# Myeloid_sex[T.male]_TMPRSS2                                      True
# Airway_epithelium_smoking_status[T.True]_ACE2                    True
# Airway_epithelium_smoking_status[T.True]_CTSL                    True
# Airway_epithelium_smoking_status[T.True]_TMPRSS2                 True
# Submucosal_Gland_smoking_status[T.True]_ACE2                     True
# Submucosal_Gland_smoking_status[T.True]_CTSL                     True
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2                  True
# Alveolar_epithelium_smoking_status[T.True]_ACE2                  True
# Alveolar_epithelium_smoking_status[T.True]_CTSL                 False
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2               True
# Blood_vessels_smoking_status[T.True]_ACE2                       False
# Blood_vessels_smoking_status[T.True]_CTSL                       False
# Blood_vessels_smoking_status[T.True]_TMPRSS2                    False
# Lymphatics_smoking_status[T.True]_CTSL                          False
# Lymphatics_smoking_status[T.True]_TMPRSS2                       False
# Fibroblast_lineage_smoking_status[T.True]_ACE2                  False
# Fibroblast_lineage_smoking_status[T.True]_CTSL                  False
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2                True
# Smooth_Muscle_smoking_status[T.True]_ACE2                       False
# Smooth_Muscle_smoking_status[T.True]_CTSL                       False
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2                    False
# Mesothelium_smoking_status[T.True]_CTSL                         False
# Mesothelium_smoking_status[T.True]_TMPRSS2                      False
# Lymphoid_smoking_status[T.True]_ACE2                            False
# Lymphoid_smoking_status[T.True]_CTSL                             True
# Lymphoid_smoking_status[T.True]_TMPRSS2                         False
# Myeloid_smoking_status[T.True]_ACE2                             False
# Myeloid_smoking_status[T.True]_CTSL                             False
# Myeloid_smoking_status[T.True]_TMPRSS2                           True
#
#                                                     signif_bulk_complex_agree  \
# Airway_epithelium_age_ACE2                                              False
# Airway_epithelium_age_CTSL                                               True
# Airway_epithelium_age_TMPRSS2                                           False
# Submucosal_Gland_age_ACE2                                               False
# Submucosal_Gland_age_CTSL                                                True
# Submucosal_Gland_age_TMPRSS2                                            False
# Alveolar_epithelium_age_ACE2                                             True
# Alveolar_epithelium_age_CTSL                                            False
# Alveolar_epithelium_age_TMPRSS2                                          True
# Blood_vessels_age_ACE2                                                  False
# Blood_vessels_age_CTSL                                                  False
# Blood_vessels_age_TMPRSS2                                               False
# Lymphatics_age_CTSL                                                     False
# Lymphatics_age_TMPRSS2                                                  False
# Fibroblast_lineage_age_ACE2                                             False
# Fibroblast_lineage_age_CTSL                                             False
# Fibroblast_lineage_age_TMPRSS2                                           True
# Smooth_Muscle_age_ACE2                                                  False
# Smooth_Muscle_age_CTSL                                                   True
# Smooth_Muscle_age_TMPRSS2                                               False
# Mesothelium_age_CTSL                                                    False
# Mesothelium_age_TMPRSS2                                                  True
# Lymphoid_age_ACE2                                                       False
# Lymphoid_age_CTSL                                                       False
# Lymphoid_age_TMPRSS2                                                    False
# Myeloid_age_ACE2                                                        False
# Myeloid_age_CTSL                                                        False
# Myeloid_age_TMPRSS2                                                     False
# Airway_epithelium_sex[T.male]_ACE2                                       True
# Airway_epithelium_sex[T.male]_CTSL                                       True
# Airway_epithelium_sex[T.male]_TMPRSS2                                    True
# Submucosal_Gland_sex[T.male]_ACE2                                       False
# Submucosal_Gland_sex[T.male]_CTSL                                        True
# Submucosal_Gland_sex[T.male]_TMPRSS2                                    False
# Alveolar_epithelium_sex[T.male]_ACE2                                     True
# Alveolar_epithelium_sex[T.male]_CTSL                                     True
# Alveolar_epithelium_sex[T.male]_TMPRSS2                                  True
# Blood_vessels_sex[T.male]_ACE2                                          False
# Blood_vessels_sex[T.male]_CTSL                                           True
# Blood_vessels_sex[T.male]_TMPRSS2                                       False
# Lymphatics_sex[T.male]_CTSL                                             False
# Lymphatics_sex[T.male]_TMPRSS2                                          False
# Fibroblast_lineage_sex[T.male]_ACE2                                     False
# Fibroblast_lineage_sex[T.male]_CTSL                                     False
# Fibroblast_lineage_sex[T.male]_TMPRSS2                                  False
# Smooth_Muscle_sex[T.male]_ACE2                                          False
# Smooth_Muscle_sex[T.male]_CTSL                                          False
# Smooth_Muscle_sex[T.male]_TMPRSS2                                       False
# Mesothelium_sex[T.male]_CTSL                                            False
# Mesothelium_sex[T.male]_TMPRSS2                                         False
# Lymphoid_sex[T.male]_ACE2                                               False
# Lymphoid_sex[T.male]_CTSL                                               False
# Lymphoid_sex[T.male]_TMPRSS2                                            False
# Myeloid_sex[T.male]_ACE2                                                 True
# Myeloid_sex[T.male]_CTSL                                                False
# Myeloid_sex[T.male]_TMPRSS2                                              True
# Airway_epithelium_smoking_status[T.True]_ACE2                            True
# Airway_epithelium_smoking_status[T.True]_CTSL                           False
# Airway_epithelium_smoking_status[T.True]_TMPRSS2                        False
# Submucosal_Gland_smoking_status[T.True]_ACE2                             True
# Submucosal_Gland_smoking_status[T.True]_CTSL                             True
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2                          True
# Alveolar_epithelium_smoking_status[T.True]_ACE2                          True
# Alveolar_epithelium_smoking_status[T.True]_CTSL                         False
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2                       True
# Blood_vessels_smoking_status[T.True]_ACE2                               False
# Blood_vessels_smoking_status[T.True]_CTSL                               False
# Blood_vessels_smoking_status[T.True]_TMPRSS2                            False
# Lymphatics_smoking_status[T.True]_CTSL                                  False
# Lymphatics_smoking_status[T.True]_TMPRSS2                               False
# Fibroblast_lineage_smoking_status[T.True]_ACE2                          False
# Fibroblast_lineage_smoking_status[T.True]_CTSL                          False
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2                       False
# Smooth_Muscle_smoking_status[T.True]_ACE2                               False
# Smooth_Muscle_smoking_status[T.True]_CTSL                               False
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2                            False
# Mesothelium_smoking_status[T.True]_CTSL                                 False
# Mesothelium_smoking_status[T.True]_TMPRSS2                              False
# Lymphoid_smoking_status[T.True]_ACE2                                    False
# Lymphoid_smoking_status[T.True]_CTSL                                    False
# Lymphoid_smoking_status[T.True]_TMPRSS2                                 False
# Myeloid_smoking_status[T.True]_ACE2                                     False
# Myeloid_smoking_status[T.True]_CTSL                                     False
# Myeloid_smoking_status[T.True]_TMPRSS2                                  False
#
#                                                    covariate_simple
# Airway_epithelium_age_ACE2                                      Age
# Airway_epithelium_age_CTSL                                      Age
# Airway_epithelium_age_TMPRSS2                                   Age
# Submucosal_Gland_age_ACE2                                       Age
# Submucosal_Gland_age_CTSL                                       Age
# Submucosal_Gland_age_TMPRSS2                                    Age
# Alveolar_epithelium_age_ACE2                                    Age
# Alveolar_epithelium_age_CTSL                                    Age
# Alveolar_epithelium_age_TMPRSS2                                 Age
# Blood_vessels_age_ACE2                                          Age
# Blood_vessels_age_CTSL                                          Age
# Blood_vessels_age_TMPRSS2                                       Age
# Lymphatics_age_CTSL                                             Age
# Lymphatics_age_TMPRSS2                                          Age
# Fibroblast_lineage_age_ACE2                                     Age
# Fibroblast_lineage_age_CTSL                                     Age
# Fibroblast_lineage_age_TMPRSS2                                  Age
# Smooth_Muscle_age_ACE2                                          Age
# Smooth_Muscle_age_CTSL                                          Age
# Smooth_Muscle_age_TMPRSS2                                       Age
# Mesothelium_age_CTSL                                            Age
# Mesothelium_age_TMPRSS2                                         Age
# Lymphoid_age_ACE2                                               Age
# Lymphoid_age_CTSL                                               Age
# Lymphoid_age_TMPRSS2                                            Age
# Myeloid_age_ACE2                                                Age
# Myeloid_age_CTSL                                                Age
# Myeloid_age_TMPRSS2                                             Age
# Airway_epithelium_sex[T.male]_ACE2                              Sex
# Airway_epithelium_sex[T.male]_CTSL                              Sex
# Airway_epithelium_sex[T.male]_TMPRSS2                           Sex
# Submucosal_Gland_sex[T.male]_ACE2                               Sex
# Submucosal_Gland_sex[T.male]_CTSL                               Sex
# Submucosal_Gland_sex[T.male]_TMPRSS2                            Sex
# Alveolar_epithelium_sex[T.male]_ACE2                            Sex
# Alveolar_epithelium_sex[T.male]_CTSL                            Sex
# Alveolar_epithelium_sex[T.male]_TMPRSS2                         Sex
# Blood_vessels_sex[T.male]_ACE2                                  Sex
# Blood_vessels_sex[T.male]_CTSL                                  Sex
# Blood_vessels_sex[T.male]_TMPRSS2                               Sex
# Lymphatics_sex[T.male]_CTSL                                     Sex
# Lymphatics_sex[T.male]_TMPRSS2                                  Sex
# Fibroblast_lineage_sex[T.male]_ACE2                             Sex
# Fibroblast_lineage_sex[T.male]_CTSL                             Sex
# Fibroblast_lineage_sex[T.male]_TMPRSS2                          Sex
# Smooth_Muscle_sex[T.male]_ACE2                                  Sex
# Smooth_Muscle_sex[T.male]_CTSL                                  Sex
# Smooth_Muscle_sex[T.male]_TMPRSS2                               Sex
# Mesothelium_sex[T.male]_CTSL                                    Sex
# Mesothelium_sex[T.male]_TMPRSS2                                 Sex
# Lymphoid_sex[T.male]_ACE2                                       Sex
# Lymphoid_sex[T.male]_CTSL                                       Sex
# Lymphoid_sex[T.male]_TMPRSS2                                    Sex
# Myeloid_sex[T.male]_ACE2                                        Sex
# Myeloid_sex[T.male]_CTSL                                        Sex
# Myeloid_sex[T.male]_TMPRSS2                                     Sex
# Airway_epithelium_smoking_status[T.True]_ACE2        Smoking_status
# Airway_epithelium_smoking_status[T.True]_CTSL        Smoking_status
# Airway_epithelium_smoking_status[T.True]_TMPRSS2     Smoking_status
# Submucosal_Gland_smoking_status[T.True]_ACE2         Smoking_status
# Submucosal_Gland_smoking_status[T.True]_CTSL         Smoking_status
# Submucosal_Gland_smoking_status[T.True]_TMPRSS2      Smoking_status
# Alveolar_epithelium_smoking_status[T.True]_ACE2      Smoking_status
# Alveolar_epithelium_smoking_status[T.True]_CTSL      Smoking_status
# Alveolar_epithelium_smoking_status[T.True]_TMPRSS2   Smoking_status
# Blood_vessels_smoking_status[T.True]_ACE2            Smoking_status
# Blood_vessels_smoking_status[T.True]_CTSL            Smoking_status
# Blood_vessels_smoking_status[T.True]_TMPRSS2         Smoking_status
# Lymphatics_smoking_status[T.True]_CTSL               Smoking_status
# Lymphatics_smoking_status[T.True]_TMPRSS2            Smoking_status
# Fibroblast_lineage_smoking_status[T.True]_ACE2       Smoking_status
# Fibroblast_lineage_smoking_status[T.True]_CTSL       Smoking_status
# Fibroblast_lineage_smoking_status[T.True]_TMPRSS2    Smoking_status
# Smooth_Muscle_smoking_status[T.True]_ACE2            Smoking_status
# Smooth_Muscle_smoking_status[T.True]_CTSL            Smoking_status
# Smooth_Muscle_smoking_status[T.True]_TMPRSS2         Smoking_status
# Mesothelium_smoking_status[T.True]_CTSL              Smoking_status
# Mesothelium_smoking_status[T.True]_TMPRSS2           Smoking_status
# Lymphoid_smoking_status[T.True]_ACE2                 Smoking_status
# Lymphoid_smoking_status[T.True]_CTSL                 Smoking_status
# Lymphoid_smoking_status[T.True]_TMPRSS2              Smoking_status
# Myeloid_smoking_status[T.True]_ACE2                  Smoking_status
# Myeloid_smoking_status[T.True]_CTSL                  Smoking_status
# Myeloid_smoking_status[T.True]_TMPRSS2               Smoking_status

# %%
color_base = sns.color_palette('colorblind')[:3]
colors = color_base

gene_order = ['ACE2', 'TMPRSS2', 'CTSL']

cat_order = ['Age', 'Sex', 'Smoking_status']
comp_order = ['Epithelial', 'Endothelial', 'Stroma', 'Immune']
hue_col = 'gene'

xlims_top = [[None, None, None],
             [0.009, None, None],
             [None, None, None],
             [None, None, None]]
xlims_bot = [[None, None, None],
             [-0.012 ,None, None],
             [None, None, None],
             [None, None, None]]

p1 = sns.catplot(y='cell_identity', x='coef', hue=hue_col, ci=None, kind='bar', col='covariate_simple', row='compartment', sharey='none', sharex='none', orient='h', data=res_lvl2, legend=False, palette=sns.color_palette(colors), hue_order=gene_order)

for j,group in enumerate(p1.axes):
    for i,ax in enumerate(group):
        ax.axvline(0, ls='--')
        tmp = plt.setp(ax.patches, linewidth=1, edgecolor='black')
        
        dat_sub = res_lvl2.loc[(res_lvl2['covariate_simple'] == cat_order[i]) & (res_lvl2['compartment'] == comp_order[j])].copy()
        dat_sub.reset_index(inplace=True, drop=True);
        ct_dict = {ct:idx for idx,ct in enumerate(dat_sub['cell_identity'].unique())}
        bar_width = ax.patches[0].get_height()
        gen_dict = {g:(i-1)*bar_width for i,g in enumerate(gene_order)}
        offset_yloc = res_lvl2.groupby(['compartment'])['cell_identity'].nunique()[comp_order[:j]].sum()
        dat_sub['yloc'] = [offset_yloc+ct_dict[ct]+gen_dict[dat_sub[hue_col][i]] for i,ct in enumerate(dat_sub['cell_identity'])]
        signif = dat_sub['signif_bulk_complex_agree'].values
        ax.errorbar(y=dat_sub['yloc'][signif], x=dat_sub['coef'][signif], xerr=dat_sub['coef_sd'][signif], linestyle='None', marker='None')
        
        ax.set_xlim(left=xlims_bot[j][i], right=xlims_top[j][i])
        
        for a in ax.patches:

            idx = dat_sub.index[np.isclose(dat_sub['yloc'], a.get_y()+(bar_width/2))]
            if len(idx) == 1:
                g = dat_sub.loc[idx]['gene'].values[0]
                a.set_edgecolor(sns.color_palette(colors)[gene_order.index(g)])
                
                if (~dat_sub.loc[idx]['signif_bulk_complex_agree']).values[0]:
                    a.set_facecolor('white')

p1.set_titles(row_template = '', col_template = '')

p1.set_axis_labels(y_var='', x_var='Effect Size')
p1.fig.set_size_inches(40,50)

for ax, col in zip(p1.axes[0], cat_order):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, 6),
                xycoords='axes fraction', textcoords='offset points',
                size='large', ha='center', va='baseline')

for ax, row in zip(p1.axes[:,0], comp_order):
    ax.annotate(row, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 6, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size='large', ha='right', va='center', rotation=90)

plt.subplots_adjust(wspace=0.3)
plt.tight_layout()

leg_ace2 = patches.Patch(color=colors[0], label='ACE2')
leg_tmprss2 = patches.Patch(color=colors[1], label='TMPRSS2')
leg_ctsl = patches.Patch(color=colors[2], label='CTSL')
plt.legend(handles=[leg_ace2, leg_tmprss2, leg_ctsl], bbox_to_anchor = [1.45, 2.3], frameon=False, title=None)

plt.savefig(folder+'/'+output_folder+base+'_nUMIoffset_noInts_annlvl2_barplots_lvl1_separated_lim.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/icb/malte.luecken/anaconda3/envs/cov19_py/lib/python3.7/site-packages/seaborn/axisgrid.py:861: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout()
# <ErrorbarContainer object of 3 artists>
# (-0.007019450090017675, 0.023080065703996976)
# <ErrorbarContainer object of 3 artists>
# (-0.17770227277939335, 0.8914978720297969)
# <ErrorbarContainer object of 3 artists>
# (-0.46578371886329295, 0.6056349720456338)
# <ErrorbarContainer object of 3 artists>
# (-0.012, 0.009)
# <ErrorbarContainer object of 3 artists>
# (0.0, 1.0189329970524357)
# <ErrorbarContainer object of 3 artists>
# (-0.31816407888989323, 0.07348175634476778)
# <ErrorbarContainer object of 3 artists>
# (-0.019803713623538353, 0.07291383886138665)
# <ErrorbarContainer object of 3 artists>
# (-1.7681615103563557, 0.5331135569625425)
# <ErrorbarContainer object of 3 artists>
# (-20.87609312647678, 2.782534143396827)
# <ErrorbarContainer object of 3 artists>
# (-0.03377797389441211, 0.010806130614592055)
# <ErrorbarContainer object of 3 artists>
# (-0.13600901575935226, 0.7032664900523707)
# <ErrorbarContainer object of 3 artists>
# (-0.4226956552097493, 0.17418237802550482)
# Text(0, 6, 'Age')
# Text(0, 6, 'Sex')
# Text(0, 6, 'Smoking_status')
# Text(-10.0, 0, 'Epithelial')
# Text(-10.0, 0, 'Endothelial')
# Text(-10.0, 0, 'Stroma')
# Text(-10.0, 0, 'Immune')
